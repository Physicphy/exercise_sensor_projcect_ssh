# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 20, # #10#, #20#
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # #3#, ##5##, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      1460        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1020)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,270,331
# Trainable params: 2,263,671
# Non-trainable params: 6,660
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 59s 560ms/step - loss: 15.1714 - accuracy: 0.4159 - val_loss: 11.6992 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 11.69917, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 8.4331 - accuracy: 0.5611 - val_loss: 7.6090 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 11.69917 to 7.60900, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 4.9307 - accuracy: 0.6562 - val_loss: 5.8534 - val_accuracy: 0.4141
#
# Epoch 00003: val_loss improved from 7.60900 to 5.85345, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 3.3301 - accuracy: 0.6604 - val_loss: 5.3563 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 5.85345 to 5.35635, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 2.4011 - accuracy: 0.6916 - val_loss: 5.0291 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 5.35635 to 5.02908, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 1.8775 - accuracy: 0.7091 - val_loss: 4.8132 - val_accuracy: 0.0938
#
# Epoch 00006: val_loss improved from 5.02908 to 4.81322, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 1.5040 - accuracy: 0.7353 - val_loss: 4.9358 - val_accuracy: 0.4570
#
# Epoch 00007: val_loss did not improve from 4.81322
# Epoch 8/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 1.3010 - accuracy: 0.7574 - val_loss: 4.9922 - val_accuracy: 0.4180
#
# Epoch 00008: val_loss did not improve from 4.81322
# Epoch 9/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 1.1712 - accuracy: 0.7790 - val_loss: 5.1281 - val_accuracy: 0.3203
#
# Epoch 00009: val_loss did not improve from 4.81322
# Epoch 10/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 1.2275 - accuracy: 0.7560 - val_loss: 6.6454 - val_accuracy: 0.0703
#
# Epoch 00010: val_loss did not improve from 4.81322
# Epoch 11/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 1.1652 - accuracy: 0.7642 - val_loss: 5.1804 - val_accuracy: 0.3047
#
# Epoch 00011: val_loss did not improve from 4.81322
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 1.0320 - accuracy: 0.7845 - val_loss: 4.4243 - val_accuracy: 0.3359
#
# Epoch 00012: val_loss improved from 4.81322 to 4.42434, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.8614 - accuracy: 0.8235 - val_loss: 4.5350 - val_accuracy: 0.3320
#
# Epoch 00013: val_loss did not improve from 4.42434
# Epoch 14/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.8013 - accuracy: 0.8350 - val_loss: 3.7640 - val_accuracy: 0.3750
#
# Epoch 00014: val_loss improved from 4.42434 to 3.76403, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.8550 - accuracy: 0.8107 - val_loss: 3.4950 - val_accuracy: 0.4414
#
# Epoch 00015: val_loss improved from 3.76403 to 3.49502, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.8590 - accuracy: 0.8065 - val_loss: 2.7168 - val_accuracy: 0.5469
#
# Epoch 00016: val_loss improved from 3.49502 to 2.71685, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.8904 - accuracy: 0.8033 - val_loss: 2.4813 - val_accuracy: 0.5469
#
# Epoch 00017: val_loss improved from 2.71685 to 2.48134, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.7639 - accuracy: 0.8396 - val_loss: 1.9363 - val_accuracy: 0.6289
#
# Epoch 00018: val_loss improved from 2.48134 to 1.93627, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.7060 - accuracy: 0.8460 - val_loss: 1.9617 - val_accuracy: 0.5898
#
# Epoch 00019: val_loss did not improve from 1.93627
# Epoch 20/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.9254 - accuracy: 0.7937 - val_loss: 1.6383 - val_accuracy: 0.7070
#
# Epoch 00020: val_loss improved from 1.93627 to 1.63830, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.8025 - accuracy: 0.8258 - val_loss: 1.3501 - val_accuracy: 0.7031
#
# Epoch 00021: val_loss improved from 1.63830 to 1.35009, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.7504 - accuracy: 0.8364 - val_loss: 1.2792 - val_accuracy: 0.7344
#
# Epoch 00022: val_loss improved from 1.35009 to 1.27920, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.7662 - accuracy: 0.8313 - val_loss: 1.3502 - val_accuracy: 0.7148
#
# Epoch 00023: val_loss did not improve from 1.27920
# Epoch 24/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.7261 - accuracy: 0.8447 - val_loss: 1.0628 - val_accuracy: 0.7578
#
# Epoch 00024: val_loss improved from 1.27920 to 1.06282, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.6791 - accuracy: 0.8493 - val_loss: 1.0096 - val_accuracy: 0.7617
#
# Epoch 00025: val_loss improved from 1.06282 to 1.00961, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.6594 - accuracy: 0.8566 - val_loss: 1.1164 - val_accuracy: 0.7695
#
# Epoch 00026: val_loss did not improve from 1.00961
# Epoch 27/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.7163 - accuracy: 0.8483 - val_loss: 1.1834 - val_accuracy: 0.7500
#
# Epoch 00027: val_loss did not improve from 1.00961
# Epoch 28/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.7735 - accuracy: 0.8309 - val_loss: 1.1689 - val_accuracy: 0.7344
#
# Epoch 00028: val_loss did not improve from 1.00961
# Epoch 29/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.7401 - accuracy: 0.8373 - val_loss: 1.1308 - val_accuracy: 0.7461
#
# Epoch 00029: val_loss did not improve from 1.00961
# Epoch 30/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.6373 - accuracy: 0.8805 - val_loss: 0.9310 - val_accuracy: 0.7930
#
# Epoch 00030: val_loss improved from 1.00961 to 0.93098, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.6234 - accuracy: 0.8667 - val_loss: 1.0689 - val_accuracy: 0.7422
#
# Epoch 00031: val_loss did not improve from 0.93098
# Epoch 32/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.6386 - accuracy: 0.8631 - val_loss: 1.5279 - val_accuracy: 0.6797
#
# Epoch 00032: val_loss did not improve from 0.93098
# Epoch 33/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.6530 - accuracy: 0.8571 - val_loss: 1.1461 - val_accuracy: 0.7305
#
# Epoch 00033: val_loss did not improve from 0.93098
# Epoch 34/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.6243 - accuracy: 0.8755 - val_loss: 1.2773 - val_accuracy: 0.7617
#
# Epoch 00034: val_loss did not improve from 0.93098
# Epoch 35/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.6399 - accuracy: 0.8631 - val_loss: 0.9838 - val_accuracy: 0.7695
#
# Epoch 00035: val_loss did not improve from 0.93098
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 36/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.5909 - accuracy: 0.8755 - val_loss: 0.9139 - val_accuracy: 0.7812
#
# Epoch 00036: val_loss improved from 0.93098 to 0.91390, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.5298 - accuracy: 0.8837 - val_loss: 0.8946 - val_accuracy: 0.7891
#
# Epoch 00037: val_loss improved from 0.91390 to 0.89459, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.4708 - accuracy: 0.9021 - val_loss: 0.9121 - val_accuracy: 0.7812
#
# Epoch 00038: val_loss did not improve from 0.89459
# Epoch 39/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.4822 - accuracy: 0.9030 - val_loss: 0.8335 - val_accuracy: 0.8125
#
# Epoch 00039: val_loss improved from 0.89459 to 0.83349, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.4886 - accuracy: 0.8929 - val_loss: 0.9220 - val_accuracy: 0.7852
#
# Epoch 00040: val_loss did not improve from 0.83349
# Epoch 41/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.4871 - accuracy: 0.8989 - val_loss: 0.9904 - val_accuracy: 0.7852
#
# Epoch 00041: val_loss did not improve from 0.83349
# Epoch 42/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.5083 - accuracy: 0.8837 - val_loss: 0.9776 - val_accuracy: 0.7969
#
# Epoch 00042: val_loss did not improve from 0.83349
# Epoch 43/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.4858 - accuracy: 0.9026 - val_loss: 0.9396 - val_accuracy: 0.7969
#
# Epoch 00043: val_loss did not improve from 0.83349
# Epoch 44/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.3679 - accuracy: 0.9343 - val_loss: 0.9850 - val_accuracy: 0.7617
#
# Epoch 00044: val_loss did not improve from 0.83349
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 45/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.4665 - accuracy: 0.9017 - val_loss: 0.8050 - val_accuracy: 0.8008
#
# Epoch 00045: val_loss improved from 0.83349 to 0.80500, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2998 - accuracy: 0.9508 - val_loss: 0.8140 - val_accuracy: 0.7930
#
# Epoch 00046: val_loss did not improve from 0.80500
# Epoch 47/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.3836 - accuracy: 0.9205 - val_loss: 0.8458 - val_accuracy: 0.8086
#
# Epoch 00047: val_loss did not improve from 0.80500
# Epoch 48/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.3411 - accuracy: 0.9389 - val_loss: 0.7962 - val_accuracy: 0.8047
#
# Epoch 00048: val_loss improved from 0.80500 to 0.79618, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.5026 - accuracy: 0.8851 - val_loss: 0.8512 - val_accuracy: 0.7812
#
# Epoch 00049: val_loss did not improve from 0.79618
# Epoch 50/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.4416 - accuracy: 0.9062 - val_loss: 0.8353 - val_accuracy: 0.8086
#
# Epoch 00050: val_loss did not improve from 0.79618
# Epoch 51/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.3231 - accuracy: 0.9398 - val_loss: 0.7886 - val_accuracy: 0.8164
#
# Epoch 00051: val_loss improved from 0.79618 to 0.78861, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3496 - accuracy: 0.9269 - val_loss: 0.7889 - val_accuracy: 0.8281
#
# Epoch 00052: val_loss did not improve from 0.78861
# Epoch 53/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.3450 - accuracy: 0.9338 - val_loss: 0.7788 - val_accuracy: 0.8164
#
# Epoch 00053: val_loss improved from 0.78861 to 0.77879, saving model to ./save/cnn_gru_best.hdf5
# Epoch 54/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.4022 - accuracy: 0.9131 - val_loss: 0.8307 - val_accuracy: 0.8164
#
# Epoch 00054: val_loss did not improve from 0.77879
# Epoch 55/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.3675 - accuracy: 0.9200 - val_loss: 0.9181 - val_accuracy: 0.7852
#
# Epoch 00055: val_loss did not improve from 0.77879
# Epoch 56/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3571 - accuracy: 0.9260 - val_loss: 0.8344 - val_accuracy: 0.8164
#
# Epoch 00056: val_loss did not improve from 0.77879
# Epoch 57/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3070 - accuracy: 0.9375 - val_loss: 0.8854 - val_accuracy: 0.7891
#
# Epoch 00057: val_loss did not improve from 0.77879
# Epoch 58/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3579 - accuracy: 0.9210 - val_loss: 0.8678 - val_accuracy: 0.8086
#
# Epoch 00058: val_loss did not improve from 0.77879
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 59/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2958 - accuracy: 0.9430 - val_loss: 0.7835 - val_accuracy: 0.8164
#
# Epoch 00059: val_loss did not improve from 0.77879
# Epoch 60/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3143 - accuracy: 0.9283 - val_loss: 0.7942 - val_accuracy: 0.8281
#
# Epoch 00060: val_loss did not improve from 0.77879
# Epoch 61/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3138 - accuracy: 0.9352 - val_loss: 0.7806 - val_accuracy: 0.8320
#
# Epoch 00061: val_loss did not improve from 0.77879
# Epoch 62/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3230 - accuracy: 0.9306 - val_loss: 0.8030 - val_accuracy: 0.8281
#
# Epoch 00062: val_loss did not improve from 0.77879
# Epoch 63/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2804 - accuracy: 0.9494 - val_loss: 0.8437 - val_accuracy: 0.8086
#
# Epoch 00063: val_loss did not improve from 0.77879
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 64/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.3073 - accuracy: 0.9412 - val_loss: 0.7399 - val_accuracy: 0.8438
#
# Epoch 00064: val_loss improved from 0.77879 to 0.73986, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2666 - accuracy: 0.9499 - val_loss: 0.7764 - val_accuracy: 0.8359
#
# Epoch 00065: val_loss did not improve from 0.73986
# Epoch 66/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2716 - accuracy: 0.9407 - val_loss: 0.8111 - val_accuracy: 0.8125
#
# Epoch 00066: val_loss did not improve from 0.73986
# Epoch 67/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2316 - accuracy: 0.9619 - val_loss: 0.7684 - val_accuracy: 0.8242
#
# Epoch 00067: val_loss did not improve from 0.73986
# Epoch 68/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2486 - accuracy: 0.9490 - val_loss: 0.7912 - val_accuracy: 0.8203
#
# Epoch 00068: val_loss did not improve from 0.73986
# Epoch 69/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2562 - accuracy: 0.9490 - val_loss: 0.7645 - val_accuracy: 0.8164
#
# Epoch 00069: val_loss did not improve from 0.73986
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 70/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2948 - accuracy: 0.9366 - val_loss: 0.7835 - val_accuracy: 0.8086
#
# Epoch 00070: val_loss did not improve from 0.73986
# Epoch 71/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2798 - accuracy: 0.9467 - val_loss: 0.7713 - val_accuracy: 0.8203
#
# Epoch 00071: val_loss did not improve from 0.73986
# Epoch 72/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2492 - accuracy: 0.9527 - val_loss: 0.7885 - val_accuracy: 0.8281
#
# Epoch 00072: val_loss did not improve from 0.73986
# Epoch 73/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2792 - accuracy: 0.9412 - val_loss: 0.7852 - val_accuracy: 0.8242
#
# Epoch 00073: val_loss did not improve from 0.73986
# Epoch 74/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2676 - accuracy: 0.9508 - val_loss: 0.7872 - val_accuracy: 0.8242
#
# Epoch 00074: val_loss did not improve from 0.73986
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 75/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2186 - accuracy: 0.9637 - val_loss: 0.7662 - val_accuracy: 0.8320
#
# Epoch 00075: val_loss did not improve from 0.73986
# Epoch 76/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2452 - accuracy: 0.9568 - val_loss: 0.7480 - val_accuracy: 0.8242
#
# Epoch 00076: val_loss did not improve from 0.73986
# Epoch 77/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2145 - accuracy: 0.9642 - val_loss: 0.7711 - val_accuracy: 0.8242
#
# Epoch 00077: val_loss did not improve from 0.73986
# Epoch 78/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2319 - accuracy: 0.9600 - val_loss: 0.7650 - val_accuracy: 0.8359
#
# Epoch 00078: val_loss did not improve from 0.73986
# Epoch 79/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3203 - accuracy: 0.9324 - val_loss: 0.7928 - val_accuracy: 0.8164
#
# Epoch 00079: val_loss did not improve from 0.73986
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 80/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2543 - accuracy: 0.9517 - val_loss: 0.7784 - val_accuracy: 0.8242
#
# Epoch 00080: val_loss did not improve from 0.73986
# Epoch 81/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2544 - accuracy: 0.9536 - val_loss: 0.7537 - val_accuracy: 0.8359
#
# Epoch 00081: val_loss did not improve from 0.73986
# Epoch 82/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2292 - accuracy: 0.9605 - val_loss: 0.7346 - val_accuracy: 0.8281
#
# Epoch 00082: val_loss improved from 0.73986 to 0.73461, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.1955 - accuracy: 0.9729 - val_loss: 0.7461 - val_accuracy: 0.8359
#
# Epoch 00083: val_loss did not improve from 0.73461
# Epoch 84/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2120 - accuracy: 0.9642 - val_loss: 0.7820 - val_accuracy: 0.8359
#
# Epoch 00084: val_loss did not improve from 0.73461
# Epoch 85/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.1890 - accuracy: 0.9733 - val_loss: 0.7616 - val_accuracy: 0.8359
#
# Epoch 00085: val_loss did not improve from 0.73461
# Epoch 86/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.1779 - accuracy: 0.9752 - val_loss: 0.7725 - val_accuracy: 0.8359
#
# Epoch 00086: val_loss did not improve from 0.73461
# Epoch 87/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2845 - accuracy: 0.9416 - val_loss: 0.7816 - val_accuracy: 0.8320
#
# Epoch 00087: val_loss did not improve from 0.73461
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 88/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2695 - accuracy: 0.9398 - val_loss: 0.7944 - val_accuracy: 0.8359
#
# Epoch 00088: val_loss did not improve from 0.73461
# Epoch 89/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2238 - accuracy: 0.9623 - val_loss: 0.7695 - val_accuracy: 0.8398
#
# Epoch 00089: val_loss did not improve from 0.73461
# Epoch 90/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2294 - accuracy: 0.9600 - val_loss: 0.7546 - val_accuracy: 0.8438
#
# Epoch 00090: val_loss did not improve from 0.73461
# Epoch 91/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2358 - accuracy: 0.9554 - val_loss: 0.7501 - val_accuracy: 0.8398
#
# Epoch 00091: val_loss did not improve from 0.73461
# Epoch 92/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2226 - accuracy: 0.9619 - val_loss: 0.7427 - val_accuracy: 0.8438
#
# Epoch 00092: val_loss did not improve from 0.73461
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 93/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2642 - accuracy: 0.9527 - val_loss: 0.7637 - val_accuracy: 0.8359
#
# Epoch 00093: val_loss did not improve from 0.73461
# Epoch 94/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2000 - accuracy: 0.9678 - val_loss: 0.7777 - val_accuracy: 0.8320
#
# Epoch 00094: val_loss did not improve from 0.73461
# Epoch 95/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2234 - accuracy: 0.9623 - val_loss: 0.7830 - val_accuracy: 0.8242
#
# Epoch 00095: val_loss did not improve from 0.73461
# Epoch 96/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2550 - accuracy: 0.9490 - val_loss: 0.7368 - val_accuracy: 0.8281
#
# Epoch 00096: val_loss did not improve from 0.73461
# Epoch 97/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3019 - accuracy: 0.9361 - val_loss: 0.7972 - val_accuracy: 0.8203
#
# Epoch 00097: val_loss did not improve from 0.73461
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 98/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2272 - accuracy: 0.9628 - val_loss: 0.7309 - val_accuracy: 0.8359
#
# Epoch 00098: val_loss improved from 0.73461 to 0.73087, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2590 - accuracy: 0.9462 - val_loss: 0.7506 - val_accuracy: 0.8438
#
# Epoch 00099: val_loss did not improve from 0.73087
# Epoch 100/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2111 - accuracy: 0.9628 - val_loss: 0.7445 - val_accuracy: 0.8438
#
# Epoch 00100: val_loss did not improve from 0.73087
# Epoch 101/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2244 - accuracy: 0.9563 - val_loss: 0.7983 - val_accuracy: 0.8281
#
# Epoch 00101: val_loss did not improve from 0.73087
# Epoch 102/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2462 - accuracy: 0.9591 - val_loss: 0.7535 - val_accuracy: 0.8320
#
# Epoch 00102: val_loss did not improve from 0.73087
# Epoch 103/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2689 - accuracy: 0.9444 - val_loss: 0.7631 - val_accuracy: 0.8320
#
# Epoch 00103: val_loss did not improve from 0.73087
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 104/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2050 - accuracy: 0.9637 - val_loss: 0.7733 - val_accuracy: 0.8438
#
# Epoch 00104: val_loss did not improve from 0.73087
# Epoch 105/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2455 - accuracy: 0.9545 - val_loss: 0.7599 - val_accuracy: 0.8438
#
# Epoch 00105: val_loss did not improve from 0.73087
# Epoch 106/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2328 - accuracy: 0.9577 - val_loss: 0.6855 - val_accuracy: 0.8555
#
# Epoch 00106: val_loss improved from 0.73087 to 0.68552, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2049 - accuracy: 0.9669 - val_loss: 0.7065 - val_accuracy: 0.8516
#
# Epoch 00107: val_loss did not improve from 0.68552
# Epoch 108/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2340 - accuracy: 0.9536 - val_loss: 0.6847 - val_accuracy: 0.8555
#
# Epoch 00108: val_loss improved from 0.68552 to 0.68474, saving model to ./save/cnn_gru_best.hdf5
# Epoch 109/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2631 - accuracy: 0.9476 - val_loss: 0.7196 - val_accuracy: 0.8438
#
# Epoch 00109: val_loss did not improve from 0.68474
# Epoch 110/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2238 - accuracy: 0.9614 - val_loss: 0.7512 - val_accuracy: 0.8477
#
# Epoch 00110: val_loss did not improve from 0.68474
# Epoch 111/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2838 - accuracy: 0.9439 - val_loss: 0.7712 - val_accuracy: 0.8320
#
# Epoch 00111: val_loss did not improve from 0.68474
# Epoch 112/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2316 - accuracy: 0.9582 - val_loss: 0.7797 - val_accuracy: 0.8281
#
# Epoch 00112: val_loss did not improve from 0.68474
# Epoch 113/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2306 - accuracy: 0.9591 - val_loss: 0.7523 - val_accuracy: 0.8398
#
# Epoch 00113: val_loss did not improve from 0.68474
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 114/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2465 - accuracy: 0.9508 - val_loss: 0.7923 - val_accuracy: 0.8281
#
# Epoch 00114: val_loss did not improve from 0.68474
# Epoch 115/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2268 - accuracy: 0.9563 - val_loss: 0.7490 - val_accuracy: 0.8320
#
# Epoch 00115: val_loss did not improve from 0.68474
# Epoch 116/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2218 - accuracy: 0.9605 - val_loss: 0.7678 - val_accuracy: 0.8320
#
# Epoch 00116: val_loss did not improve from 0.68474
# Epoch 117/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2457 - accuracy: 0.9545 - val_loss: 0.7651 - val_accuracy: 0.8320
#
# Epoch 00117: val_loss did not improve from 0.68474
# Epoch 118/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2148 - accuracy: 0.9665 - val_loss: 0.7582 - val_accuracy: 0.8359
#
# Epoch 00118: val_loss did not improve from 0.68474
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 119/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2443 - accuracy: 0.9508 - val_loss: 0.7973 - val_accuracy: 0.8281
#
# Epoch 00119: val_loss did not improve from 0.68474
# Epoch 120/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2890 - accuracy: 0.9370 - val_loss: 0.8030 - val_accuracy: 0.8242
#
# Epoch 00120: val_loss did not improve from 0.68474
# Epoch 121/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2715 - accuracy: 0.9481 - val_loss: 0.7710 - val_accuracy: 0.8359
#
# Epoch 00121: val_loss did not improve from 0.68474
# Epoch 122/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2090 - accuracy: 0.9619 - val_loss: 0.7321 - val_accuracy: 0.8438
#
# Epoch 00122: val_loss did not improve from 0.68474
# Epoch 123/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2510 - accuracy: 0.9504 - val_loss: 0.7739 - val_accuracy: 0.8359
#
# Epoch 00123: val_loss did not improve from 0.68474
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 124/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2461 - accuracy: 0.9550 - val_loss: 0.7764 - val_accuracy: 0.8320
#
# Epoch 00124: val_loss did not improve from 0.68474
# Epoch 125/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2448 - accuracy: 0.9517 - val_loss: 0.7826 - val_accuracy: 0.8281
#
# Epoch 00125: val_loss did not improve from 0.68474
# Epoch 126/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2318 - accuracy: 0.9550 - val_loss: 0.7905 - val_accuracy: 0.8281
#
# Epoch 00126: val_loss did not improve from 0.68474
# Epoch 127/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2775 - accuracy: 0.9393 - val_loss: 0.7854 - val_accuracy: 0.8320
#
# Epoch 00127: val_loss did not improve from 0.68474
# Epoch 128/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2082 - accuracy: 0.9669 - val_loss: 0.7327 - val_accuracy: 0.8438
#
# Epoch 00128: val_loss did not improve from 0.68474
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 129/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2309 - accuracy: 0.9591 - val_loss: 0.8024 - val_accuracy: 0.8242
#
# Epoch 00129: val_loss did not improve from 0.68474
# Epoch 130/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.1957 - accuracy: 0.9683 - val_loss: 0.7988 - val_accuracy: 0.8281
#
# Epoch 00130: val_loss did not improve from 0.68474
# Epoch 131/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2483 - accuracy: 0.9550 - val_loss: 0.7844 - val_accuracy: 0.8359
#
# Epoch 00131: val_loss did not improve from 0.68474
# Epoch 132/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2466 - accuracy: 0.9582 - val_loss: 0.7647 - val_accuracy: 0.8398
#
# Epoch 00132: val_loss did not improve from 0.68474
# Epoch 133/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2485 - accuracy: 0.9522 - val_loss: 0.7726 - val_accuracy: 0.8281
#
# Epoch 00133: val_loss did not improve from 0.68474
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 134/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2476 - accuracy: 0.9531 - val_loss: 0.7644 - val_accuracy: 0.8281
#
# Epoch 00134: val_loss did not improve from 0.68474
# Epoch 135/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2359 - accuracy: 0.9582 - val_loss: 0.7847 - val_accuracy: 0.8281
#
# Epoch 00135: val_loss did not improve from 0.68474
# Epoch 136/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2508 - accuracy: 0.9513 - val_loss: 0.7820 - val_accuracy: 0.8320
#
# Epoch 00136: val_loss did not improve from 0.68474
# Epoch 137/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2541 - accuracy: 0.9462 - val_loss: 0.7877 - val_accuracy: 0.8320
#
# Epoch 00137: val_loss did not improve from 0.68474
# Epoch 138/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.1993 - accuracy: 0.9706 - val_loss: 0.7620 - val_accuracy: 0.8359
#
# Epoch 00138: val_loss did not improve from 0.68474
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 00138: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5997 - accuracy: 0.8592
# [0.5997388362884521, 0.8592000007629395]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
