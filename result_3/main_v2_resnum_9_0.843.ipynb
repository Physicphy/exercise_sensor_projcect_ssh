# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#, ##11##, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      910         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 10)      1450        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 10)      730         concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 10)      730         concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1810        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      1810        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1810        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 5)       1805        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 10)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 10)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 10)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 5)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 10)      40          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 10)      40          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 10)      40          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 5)       20          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 20)      1920        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 20)      1920        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 20)      1920        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 10)      510         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 20)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 20)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 20)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 10)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 20)      80          leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 20)      80          leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 20)      80          leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 10)      40          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      3660        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      3660        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      3660        batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      7260        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      7260        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 30)      1830        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 30)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 30)      120         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 60)      21960       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 60)      21960       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 60)      21960       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 30)      5580        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 30)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 30)      120         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 510)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      275460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      275460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_59[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_62[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 150, 60)      240         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 150, 120)     480         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 150, 60)      240         conv1d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_65[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 150, 60)      240         conv1d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 150, 120)     480         conv1d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 150, 60)      240         conv1d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_68[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 150, 60)      240         conv1d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 150, 120)     480         conv1d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 150, 60)      240         conv1d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_71[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 150, 60)      240         conv1d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 150, 120)     480         conv1d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 150, 60)      240         conv1d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_74[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,466,126
# Trainable params: 1,459,136
# Non-trainable params: 6,990
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 62s 564ms/step - loss: 36.9804 - accuracy: 0.3957 - val_loss: 27.3715 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 27.37154, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 19.8575 - accuracy: 0.5469 - val_loss: 15.5506 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 27.37154 to 15.55060, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 10.7628 - accuracy: 0.6305 - val_loss: 9.6989 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 15.55060 to 9.69888, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 6.3995 - accuracy: 0.6415 - val_loss: 7.2843 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 9.69888 to 7.28427, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 4.0783 - accuracy: 0.6521 - val_loss: 6.1596 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 7.28427 to 6.15964, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 2.7764 - accuracy: 0.6696 - val_loss: 5.5594 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 6.15964 to 5.55942, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 2.0550 - accuracy: 0.6916 - val_loss: 5.2523 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 5.55942 to 5.25233, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 1.6697 - accuracy: 0.7206 - val_loss: 4.9088 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 5.25233 to 4.90883, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 1.4400 - accuracy: 0.7362 - val_loss: 4.0887 - val_accuracy: 0.4297
#
# Epoch 00009: val_loss improved from 4.90883 to 4.08865, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 1.4184 - accuracy: 0.7188 - val_loss: 4.3382 - val_accuracy: 0.4375
#
# Epoch 00010: val_loss did not improve from 4.08865
# Epoch 11/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 1.4031 - accuracy: 0.7165 - val_loss: 4.3232 - val_accuracy: 0.3906
#
# Epoch 00011: val_loss did not improve from 4.08865
# Epoch 12/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 1.3183 - accuracy: 0.7348 - val_loss: 3.6219 - val_accuracy: 0.4414
#
# Epoch 00012: val_loss improved from 4.08865 to 3.62187, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 1.2060 - accuracy: 0.7482 - val_loss: 3.4710 - val_accuracy: 0.4180
#
# Epoch 00013: val_loss improved from 3.62187 to 3.47101, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 1.1486 - accuracy: 0.7587 - val_loss: 3.0832 - val_accuracy: 0.4531
#
# Epoch 00014: val_loss improved from 3.47101 to 3.08321, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 1.1648 - accuracy: 0.7403 - val_loss: 3.0943 - val_accuracy: 0.4609
#
# Epoch 00015: val_loss did not improve from 3.08321
# Epoch 16/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 1.1817 - accuracy: 0.7408 - val_loss: 2.2877 - val_accuracy: 0.5859
#
# Epoch 00016: val_loss improved from 3.08321 to 2.28769, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 1.2136 - accuracy: 0.7518 - val_loss: 2.5585 - val_accuracy: 0.5820
#
# Epoch 00017: val_loss did not improve from 2.28769
# Epoch 18/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 1.0614 - accuracy: 0.7785 - val_loss: 1.9746 - val_accuracy: 0.6211
#
# Epoch 00018: val_loss improved from 2.28769 to 1.97464, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 1.0053 - accuracy: 0.7881 - val_loss: 2.0687 - val_accuracy: 0.5703
#
# Epoch 00019: val_loss did not improve from 1.97464
# Epoch 20/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 1.1591 - accuracy: 0.7523 - val_loss: 1.6174 - val_accuracy: 0.6484
#
# Epoch 00020: val_loss improved from 1.97464 to 1.61735, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 1.0597 - accuracy: 0.7721 - val_loss: 1.6560 - val_accuracy: 0.6680
#
# Epoch 00021: val_loss did not improve from 1.61735
# Epoch 22/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 1.0458 - accuracy: 0.7757 - val_loss: 1.6040 - val_accuracy: 0.6797
#
# Epoch 00022: val_loss improved from 1.61735 to 1.60400, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.9643 - accuracy: 0.7992 - val_loss: 1.2797 - val_accuracy: 0.7500
#
# Epoch 00023: val_loss improved from 1.60400 to 1.27974, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.9418 - accuracy: 0.7987 - val_loss: 1.4240 - val_accuracy: 0.7031
#
# Epoch 00024: val_loss did not improve from 1.27974
# Epoch 25/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.9216 - accuracy: 0.8097 - val_loss: 1.4184 - val_accuracy: 0.6836
#
# Epoch 00025: val_loss did not improve from 1.27974
# Epoch 26/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 0.8964 - accuracy: 0.8093 - val_loss: 1.2288 - val_accuracy: 0.7266
#
# Epoch 00026: val_loss improved from 1.27974 to 1.22877, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.9189 - accuracy: 0.8033 - val_loss: 1.5384 - val_accuracy: 0.6758
#
# Epoch 00027: val_loss did not improve from 1.22877
# Epoch 28/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.9973 - accuracy: 0.7845 - val_loss: 1.5368 - val_accuracy: 0.6562
#
# Epoch 00028: val_loss did not improve from 1.22877
# Epoch 29/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 1.0087 - accuracy: 0.7835 - val_loss: 1.2293 - val_accuracy: 0.7266
#
# Epoch 00029: val_loss did not improve from 1.22877
# Epoch 30/2000
# 34/34 [==============================] - 13s 379ms/step - loss: 0.8862 - accuracy: 0.8162 - val_loss: 1.2420 - val_accuracy: 0.7070
#
# Epoch 00030: val_loss did not improve from 1.22877
# Epoch 31/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.8534 - accuracy: 0.8240 - val_loss: 1.2681 - val_accuracy: 0.6953
#
# Epoch 00031: val_loss did not improve from 1.22877
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.7732 - accuracy: 0.8392 - val_loss: 1.1949 - val_accuracy: 0.7070
#
# Epoch 00032: val_loss improved from 1.22877 to 1.19486, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.7136 - accuracy: 0.8460 - val_loss: 1.1275 - val_accuracy: 0.7188
#
# Epoch 00033: val_loss improved from 1.19486 to 1.12752, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.6971 - accuracy: 0.8470 - val_loss: 0.9894 - val_accuracy: 0.7656
#
# Epoch 00034: val_loss improved from 1.12752 to 0.98941, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.7373 - accuracy: 0.8378 - val_loss: 1.0718 - val_accuracy: 0.7188
#
# Epoch 00035: val_loss did not improve from 0.98941
# Epoch 36/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.7285 - accuracy: 0.8392 - val_loss: 1.0636 - val_accuracy: 0.7227
#
# Epoch 00036: val_loss did not improve from 0.98941
# Epoch 37/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.6911 - accuracy: 0.8483 - val_loss: 1.1374 - val_accuracy: 0.7148
#
# Epoch 00037: val_loss did not improve from 0.98941
# Epoch 38/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.6411 - accuracy: 0.8566 - val_loss: 1.0800 - val_accuracy: 0.7305
#
# Epoch 00038: val_loss did not improve from 0.98941
# Epoch 39/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.6857 - accuracy: 0.8520 - val_loss: 1.1716 - val_accuracy: 0.7500
#
# Epoch 00039: val_loss did not improve from 0.98941
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 40/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.6282 - accuracy: 0.8594 - val_loss: 1.0639 - val_accuracy: 0.7383
#
# Epoch 00040: val_loss did not improve from 0.98941
# Epoch 41/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.5793 - accuracy: 0.8732 - val_loss: 1.0427 - val_accuracy: 0.7578
#
# Epoch 00041: val_loss did not improve from 0.98941
# Epoch 42/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.6009 - accuracy: 0.8626 - val_loss: 1.0029 - val_accuracy: 0.7344
#
# Epoch 00042: val_loss did not improve from 0.98941
# Epoch 43/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.5678 - accuracy: 0.8718 - val_loss: 1.0835 - val_accuracy: 0.7266
#
# Epoch 00043: val_loss did not improve from 0.98941
# Epoch 44/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.4620 - accuracy: 0.9049 - val_loss: 0.9882 - val_accuracy: 0.7578
#
# Epoch 00044: val_loss improved from 0.98941 to 0.98817, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.5694 - accuracy: 0.8626 - val_loss: 0.9426 - val_accuracy: 0.7656
#
# Epoch 00045: val_loss improved from 0.98817 to 0.94260, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.4437 - accuracy: 0.9040 - val_loss: 1.0082 - val_accuracy: 0.7500
#
# Epoch 00046: val_loss did not improve from 0.94260
# Epoch 47/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 0.5086 - accuracy: 0.8837 - val_loss: 0.9404 - val_accuracy: 0.7734
#
# Epoch 00047: val_loss improved from 0.94260 to 0.94035, saving model to ./save/cnn_gru_best.hdf5
# Epoch 48/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.4746 - accuracy: 0.8952 - val_loss: 0.9198 - val_accuracy: 0.7656
#
# Epoch 00048: val_loss improved from 0.94035 to 0.91982, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.6672 - accuracy: 0.8396 - val_loss: 1.0981 - val_accuracy: 0.7461
#
# Epoch 00049: val_loss did not improve from 0.91982
# Epoch 50/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.6034 - accuracy: 0.8562 - val_loss: 0.9651 - val_accuracy: 0.7734
#
# Epoch 00050: val_loss did not improve from 0.91982
# Epoch 51/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.4719 - accuracy: 0.8984 - val_loss: 0.8867 - val_accuracy: 0.8008
#
# Epoch 00051: val_loss improved from 0.91982 to 0.88674, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.4907 - accuracy: 0.8883 - val_loss: 0.8787 - val_accuracy: 0.7734
#
# Epoch 00052: val_loss improved from 0.88674 to 0.87866, saving model to ./save/cnn_gru_best.hdf5
# Epoch 53/2000
# 34/34 [==============================] - 13s 379ms/step - loss: 0.4700 - accuracy: 0.9017 - val_loss: 0.8671 - val_accuracy: 0.7969
#
# Epoch 00053: val_loss improved from 0.87866 to 0.86713, saving model to ./save/cnn_gru_best.hdf5
# Epoch 54/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.5473 - accuracy: 0.8773 - val_loss: 0.9964 - val_accuracy: 0.7617
#
# Epoch 00054: val_loss did not improve from 0.86713
# Epoch 55/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.5122 - accuracy: 0.8805 - val_loss: 0.9797 - val_accuracy: 0.7891
#
# Epoch 00055: val_loss did not improve from 0.86713
# Epoch 56/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.5159 - accuracy: 0.8837 - val_loss: 1.0386 - val_accuracy: 0.7578
#
# Epoch 00056: val_loss did not improve from 0.86713
# Epoch 57/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.4629 - accuracy: 0.8998 - val_loss: 0.9445 - val_accuracy: 0.7852
#
# Epoch 00057: val_loss did not improve from 0.86713
# Epoch 58/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.5237 - accuracy: 0.8764 - val_loss: 0.9179 - val_accuracy: 0.7656
#
# Epoch 00058: val_loss did not improve from 0.86713
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 59/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.4578 - accuracy: 0.8984 - val_loss: 0.8215 - val_accuracy: 0.7695
#
# Epoch 00059: val_loss improved from 0.86713 to 0.82149, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.4494 - accuracy: 0.9012 - val_loss: 0.8509 - val_accuracy: 0.7695
#
# Epoch 00060: val_loss did not improve from 0.82149
# Epoch 61/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.4607 - accuracy: 0.8989 - val_loss: 0.8685 - val_accuracy: 0.7969
#
# Epoch 00061: val_loss did not improve from 0.82149
# Epoch 62/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.4386 - accuracy: 0.9017 - val_loss: 0.8993 - val_accuracy: 0.7773
#
# Epoch 00062: val_loss did not improve from 0.82149
# Epoch 63/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3989 - accuracy: 0.9242 - val_loss: 0.9070 - val_accuracy: 0.7930
#
# Epoch 00063: val_loss did not improve from 0.82149
# Epoch 64/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.4412 - accuracy: 0.8994 - val_loss: 0.8570 - val_accuracy: 0.7734
#
# Epoch 00064: val_loss did not improve from 0.82149
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 65/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.3700 - accuracy: 0.9288 - val_loss: 0.8615 - val_accuracy: 0.7734
#
# Epoch 00065: val_loss did not improve from 0.82149
# Epoch 66/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.3876 - accuracy: 0.9177 - val_loss: 0.8733 - val_accuracy: 0.7695
#
# Epoch 00066: val_loss did not improve from 0.82149
# Epoch 67/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3329 - accuracy: 0.9449 - val_loss: 0.8326 - val_accuracy: 0.7812
#
# Epoch 00067: val_loss did not improve from 0.82149
# Epoch 68/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.3585 - accuracy: 0.9269 - val_loss: 0.8692 - val_accuracy: 0.7930
#
# Epoch 00068: val_loss did not improve from 0.82149
# Epoch 69/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3745 - accuracy: 0.9182 - val_loss: 0.7966 - val_accuracy: 0.7930
#
# Epoch 00069: val_loss improved from 0.82149 to 0.79662, saving model to ./save/cnn_gru_best.hdf5
# Epoch 70/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.4164 - accuracy: 0.9044 - val_loss: 0.8957 - val_accuracy: 0.7656
#
# Epoch 00070: val_loss did not improve from 0.79662
# Epoch 71/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.3996 - accuracy: 0.9113 - val_loss: 0.8428 - val_accuracy: 0.7656
#
# Epoch 00071: val_loss did not improve from 0.79662
# Epoch 72/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.3795 - accuracy: 0.9177 - val_loss: 0.8567 - val_accuracy: 0.7812
#
# Epoch 00072: val_loss did not improve from 0.79662
# Epoch 73/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.3861 - accuracy: 0.9095 - val_loss: 0.8184 - val_accuracy: 0.7852
#
# Epoch 00073: val_loss did not improve from 0.79662
# Epoch 74/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.3937 - accuracy: 0.9131 - val_loss: 0.8523 - val_accuracy: 0.7852
#
# Epoch 00074: val_loss did not improve from 0.79662
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 75/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.3181 - accuracy: 0.9366 - val_loss: 0.8034 - val_accuracy: 0.7852
#
# Epoch 00075: val_loss did not improve from 0.79662
# Epoch 76/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3411 - accuracy: 0.9288 - val_loss: 0.8013 - val_accuracy: 0.7852
#
# Epoch 00076: val_loss did not improve from 0.79662
# Epoch 77/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3089 - accuracy: 0.9380 - val_loss: 0.8246 - val_accuracy: 0.7969
#
# Epoch 00077: val_loss did not improve from 0.79662
# Epoch 78/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3256 - accuracy: 0.9334 - val_loss: 0.7992 - val_accuracy: 0.7891
#
# Epoch 00078: val_loss did not improve from 0.79662
# Epoch 79/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.4486 - accuracy: 0.8929 - val_loss: 0.8498 - val_accuracy: 0.7930
#
# Epoch 00079: val_loss did not improve from 0.79662
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 80/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.3371 - accuracy: 0.9311 - val_loss: 0.8202 - val_accuracy: 0.8008
#
# Epoch 00080: val_loss did not improve from 0.79662
# Epoch 81/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.3423 - accuracy: 0.9292 - val_loss: 0.7833 - val_accuracy: 0.8008
#
# Epoch 00081: val_loss improved from 0.79662 to 0.78331, saving model to ./save/cnn_gru_best.hdf5
# Epoch 82/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3192 - accuracy: 0.9311 - val_loss: 0.7889 - val_accuracy: 0.7969
#
# Epoch 00082: val_loss did not improve from 0.78331
# Epoch 83/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2659 - accuracy: 0.9536 - val_loss: 0.8049 - val_accuracy: 0.7969
#
# Epoch 00083: val_loss did not improve from 0.78331
# Epoch 84/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2847 - accuracy: 0.9444 - val_loss: 0.8436 - val_accuracy: 0.7891
#
# Epoch 00084: val_loss did not improve from 0.78331
# Epoch 85/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.2707 - accuracy: 0.9467 - val_loss: 0.8241 - val_accuracy: 0.8008
#
# Epoch 00085: val_loss did not improve from 0.78331
# Epoch 86/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2497 - accuracy: 0.9573 - val_loss: 0.8208 - val_accuracy: 0.7812
#
# Epoch 00086: val_loss did not improve from 0.78331
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 87/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 0.3582 - accuracy: 0.9173 - val_loss: 0.8194 - val_accuracy: 0.7969
#
# Epoch 00087: val_loss did not improve from 0.78331
# Epoch 88/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.3402 - accuracy: 0.9265 - val_loss: 0.8248 - val_accuracy: 0.8086
#
# Epoch 00088: val_loss did not improve from 0.78331
# Epoch 89/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2936 - accuracy: 0.9389 - val_loss: 0.7981 - val_accuracy: 0.8047
#
# Epoch 00089: val_loss did not improve from 0.78331
# Epoch 90/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.3078 - accuracy: 0.9338 - val_loss: 0.8169 - val_accuracy: 0.8047
#
# Epoch 00090: val_loss did not improve from 0.78331
# Epoch 91/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3104 - accuracy: 0.9347 - val_loss: 0.7918 - val_accuracy: 0.8047
#
# Epoch 00091: val_loss did not improve from 0.78331
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 92/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2942 - accuracy: 0.9472 - val_loss: 0.7855 - val_accuracy: 0.8125
#
# Epoch 00092: val_loss did not improve from 0.78331
# Epoch 93/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3264 - accuracy: 0.9334 - val_loss: 0.8052 - val_accuracy: 0.8047
#
# Epoch 00093: val_loss did not improve from 0.78331
# Epoch 94/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2746 - accuracy: 0.9490 - val_loss: 0.8023 - val_accuracy: 0.8047
#
# Epoch 00094: val_loss did not improve from 0.78331
# Epoch 95/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2856 - accuracy: 0.9393 - val_loss: 0.8040 - val_accuracy: 0.8008
#
# Epoch 00095: val_loss did not improve from 0.78331
# Epoch 96/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.3184 - accuracy: 0.9315 - val_loss: 0.7618 - val_accuracy: 0.8047
#
# Epoch 00096: val_loss improved from 0.78331 to 0.76183, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.3622 - accuracy: 0.9168 - val_loss: 0.8245 - val_accuracy: 0.7930
#
# Epoch 00097: val_loss did not improve from 0.76183
# Epoch 98/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2793 - accuracy: 0.9430 - val_loss: 0.7595 - val_accuracy: 0.8086
#
# Epoch 00098: val_loss improved from 0.76183 to 0.75948, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3211 - accuracy: 0.9357 - val_loss: 0.7557 - val_accuracy: 0.8125
#
# Epoch 00099: val_loss improved from 0.75948 to 0.75571, saving model to ./save/cnn_gru_best.hdf5
# Epoch 100/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2739 - accuracy: 0.9416 - val_loss: 0.7597 - val_accuracy: 0.8047
#
# Epoch 00100: val_loss did not improve from 0.75571
# Epoch 101/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2850 - accuracy: 0.9430 - val_loss: 0.8211 - val_accuracy: 0.7969
#
# Epoch 00101: val_loss did not improve from 0.75571
# Epoch 102/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3078 - accuracy: 0.9398 - val_loss: 0.7790 - val_accuracy: 0.8008
#
# Epoch 00102: val_loss did not improve from 0.75571
# Epoch 103/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3331 - accuracy: 0.9237 - val_loss: 0.7849 - val_accuracy: 0.8086
#
# Epoch 00103: val_loss did not improve from 0.75571
# Epoch 104/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2633 - accuracy: 0.9517 - val_loss: 0.7840 - val_accuracy: 0.8164
#
# Epoch 00104: val_loss did not improve from 0.75571
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 105/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.3029 - accuracy: 0.9384 - val_loss: 0.7758 - val_accuracy: 0.8203
#
# Epoch 00105: val_loss did not improve from 0.75571
# Epoch 106/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.2857 - accuracy: 0.9476 - val_loss: 0.7048 - val_accuracy: 0.8281
#
# Epoch 00106: val_loss improved from 0.75571 to 0.70482, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 0.2691 - accuracy: 0.9490 - val_loss: 0.7425 - val_accuracy: 0.8125
#
# Epoch 00107: val_loss did not improve from 0.70482
# Epoch 108/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2844 - accuracy: 0.9430 - val_loss: 0.7261 - val_accuracy: 0.8203
#
# Epoch 00108: val_loss did not improve from 0.70482
# Epoch 109/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3075 - accuracy: 0.9288 - val_loss: 0.7408 - val_accuracy: 0.8164
#
# Epoch 00109: val_loss did not improve from 0.70482
# Epoch 110/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2682 - accuracy: 0.9499 - val_loss: 0.7807 - val_accuracy: 0.8125
#
# Epoch 00110: val_loss did not improve from 0.70482
# Epoch 111/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3450 - accuracy: 0.9251 - val_loss: 0.7936 - val_accuracy: 0.8086
#
# Epoch 00111: val_loss did not improve from 0.70482
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 112/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.2825 - accuracy: 0.9490 - val_loss: 0.8102 - val_accuracy: 0.8086
#
# Epoch 00112: val_loss did not improve from 0.70482
# Epoch 113/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2884 - accuracy: 0.9444 - val_loss: 0.7550 - val_accuracy: 0.8242
#
# Epoch 00113: val_loss did not improve from 0.70482
# Epoch 114/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.3025 - accuracy: 0.9311 - val_loss: 0.8102 - val_accuracy: 0.8086
#
# Epoch 00114: val_loss did not improve from 0.70482
# Epoch 115/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2805 - accuracy: 0.9467 - val_loss: 0.7678 - val_accuracy: 0.8125
#
# Epoch 00115: val_loss did not improve from 0.70482
# Epoch 116/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.2907 - accuracy: 0.9393 - val_loss: 0.7829 - val_accuracy: 0.8125
#
# Epoch 00116: val_loss did not improve from 0.70482
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 117/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3038 - accuracy: 0.9357 - val_loss: 0.7751 - val_accuracy: 0.8203
#
# Epoch 00117: val_loss did not improve from 0.70482
# Epoch 118/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.2709 - accuracy: 0.9485 - val_loss: 0.7754 - val_accuracy: 0.8203
#
# Epoch 00118: val_loss did not improve from 0.70482
# Epoch 119/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3064 - accuracy: 0.9412 - val_loss: 0.8185 - val_accuracy: 0.8086
#
# Epoch 00119: val_loss did not improve from 0.70482
# Epoch 120/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.3433 - accuracy: 0.9196 - val_loss: 0.8262 - val_accuracy: 0.8047
#
# Epoch 00120: val_loss did not improve from 0.70482
# Epoch 121/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3335 - accuracy: 0.9251 - val_loss: 0.8002 - val_accuracy: 0.8047
#
# Epoch 00121: val_loss did not improve from 0.70482
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 122/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2639 - accuracy: 0.9476 - val_loss: 0.7778 - val_accuracy: 0.8281
#
# Epoch 00122: val_loss did not improve from 0.70482
# Epoch 123/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.3250 - accuracy: 0.9196 - val_loss: 0.7920 - val_accuracy: 0.8203
#
# Epoch 00123: val_loss did not improve from 0.70482
# Epoch 124/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3061 - accuracy: 0.9320 - val_loss: 0.7940 - val_accuracy: 0.8164
#
# Epoch 00124: val_loss did not improve from 0.70482
# Epoch 125/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2926 - accuracy: 0.9421 - val_loss: 0.8139 - val_accuracy: 0.8164
#
# Epoch 00125: val_loss did not improve from 0.70482
# Epoch 126/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.3017 - accuracy: 0.9334 - val_loss: 0.8056 - val_accuracy: 0.8164
#
# Epoch 00126: val_loss did not improve from 0.70482
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 127/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.3245 - accuracy: 0.9288 - val_loss: 0.8101 - val_accuracy: 0.8086
#
# Epoch 00127: val_loss did not improve from 0.70482
# Epoch 128/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2565 - accuracy: 0.9522 - val_loss: 0.7666 - val_accuracy: 0.8242
#
# Epoch 00128: val_loss did not improve from 0.70482
# Epoch 129/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2965 - accuracy: 0.9398 - val_loss: 0.8192 - val_accuracy: 0.8047
#
# Epoch 00129: val_loss did not improve from 0.70482
# Epoch 130/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2478 - accuracy: 0.9554 - val_loss: 0.8161 - val_accuracy: 0.8086
#
# Epoch 00130: val_loss did not improve from 0.70482
# Epoch 131/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2958 - accuracy: 0.9352 - val_loss: 0.7936 - val_accuracy: 0.8125
#
# Epoch 00131: val_loss did not improve from 0.70482
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 132/2000
# 34/34 [==============================] - 13s 379ms/step - loss: 0.2951 - accuracy: 0.9384 - val_loss: 0.7800 - val_accuracy: 0.8203
#
# Epoch 00132: val_loss did not improve from 0.70482
# Epoch 133/2000
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3028 - accuracy: 0.9347 - val_loss: 0.8075 - val_accuracy: 0.8125
#
# Epoch 00133: val_loss did not improve from 0.70482
# Epoch 134/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2952 - accuracy: 0.9370 - val_loss: 0.7916 - val_accuracy: 0.8164
#
# Epoch 00134: val_loss did not improve from 0.70482
# Epoch 135/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2894 - accuracy: 0.9384 - val_loss: 0.8027 - val_accuracy: 0.8125
#
# Epoch 00135: val_loss did not improve from 0.70482
# Epoch 136/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.3166 - accuracy: 0.9301 - val_loss: 0.7866 - val_accuracy: 0.8203
#
# Epoch 00136: val_loss did not improve from 0.70482
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6053 - accuracy: 0.8432
# [0.6052565574645996, 0.8432000279426575]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
