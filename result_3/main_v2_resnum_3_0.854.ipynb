# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3, # 3, 5, 7, #9#, ##11##, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      910         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 10)      1450        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 10)      730         concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 10)      730         concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1810        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      1810        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1810        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 5)       1805        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 10)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 10)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 10)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 5)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 10)      40          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 10)      40          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 10)      40          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 5)       20          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 20)      1920        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 20)      1920        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 20)      1920        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 10)      510         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 20)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 20)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 20)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 10)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 20)      80          leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 20)      80          leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 20)      80          leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 10)      40          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      3660        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      3660        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      3660        batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      7260        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      7260        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 30)      1830        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 30)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 30)      120         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 60)      21960       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 60)      21960       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 60)      21960       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 30)      5580        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 30)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 30)      120         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 510)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      275460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      275460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,005,326
# Trainable params: 1,001,216
# Non-trainable params: 4,110
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 56s 517ms/step - loss: 15.5539 - accuracy: 0.4122 - val_loss: 12.4726 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 12.47258, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 9.2274 - accuracy: 0.5634 - val_loss: 8.2685 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 12.47258 to 8.26848, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 5.6058 - accuracy: 0.6503 - val_loss: 6.2554 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 8.26848 to 6.25545, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 3.8874 - accuracy: 0.6484 - val_loss: 5.5610 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 6.25545 to 5.56096, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 11s 325ms/step - loss: 2.8339 - accuracy: 0.6714 - val_loss: 5.7423 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss did not improve from 5.56096
# Epoch 6/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 2.1968 - accuracy: 0.6834 - val_loss: 4.8052 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 5.56096 to 4.80516, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 11s 325ms/step - loss: 1.7302 - accuracy: 0.7142 - val_loss: 4.6000 - val_accuracy: 0.4414
#
# Epoch 00007: val_loss improved from 4.80516 to 4.59998, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 1.4936 - accuracy: 0.7381 - val_loss: 5.0392 - val_accuracy: 0.4453
#
# Epoch 00008: val_loss did not improve from 4.59998
# Epoch 9/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 1.2771 - accuracy: 0.7606 - val_loss: 4.4730 - val_accuracy: 0.2969
#
# Epoch 00009: val_loss improved from 4.59998 to 4.47300, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 1.3040 - accuracy: 0.7413 - val_loss: 4.4796 - val_accuracy: 0.4453
#
# Epoch 00010: val_loss did not improve from 4.47300
# Epoch 11/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 1.2721 - accuracy: 0.7330 - val_loss: 4.7049 - val_accuracy: 0.3047
#
# Epoch 00011: val_loss did not improve from 4.47300
# Epoch 12/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 1.2239 - accuracy: 0.7330 - val_loss: 4.1738 - val_accuracy: 0.2539
#
# Epoch 00012: val_loss improved from 4.47300 to 4.17384, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 11s 329ms/step - loss: 1.1069 - accuracy: 0.7698 - val_loss: 3.3755 - val_accuracy: 0.3867
#
# Epoch 00013: val_loss improved from 4.17384 to 3.37547, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 11s 327ms/step - loss: 1.0436 - accuracy: 0.7734 - val_loss: 3.6618 - val_accuracy: 0.3711
#
# Epoch 00014: val_loss did not improve from 3.37547
# Epoch 15/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 1.0617 - accuracy: 0.7716 - val_loss: 3.6654 - val_accuracy: 0.3555
#
# Epoch 00015: val_loss did not improve from 3.37547
# Epoch 16/2000
# 34/34 [==============================] - 11s 324ms/step - loss: 1.0987 - accuracy: 0.7532 - val_loss: 2.3879 - val_accuracy: 0.5742
#
# Epoch 00016: val_loss improved from 3.37547 to 2.38789, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 1.1158 - accuracy: 0.7477 - val_loss: 1.8808 - val_accuracy: 0.6250
#
# Epoch 00017: val_loss improved from 2.38789 to 1.88083, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.9620 - accuracy: 0.7964 - val_loss: 1.4578 - val_accuracy: 0.6797
#
# Epoch 00018: val_loss improved from 1.88083 to 1.45778, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.9102 - accuracy: 0.8042 - val_loss: 1.6338 - val_accuracy: 0.6328
#
# Epoch 00019: val_loss did not improve from 1.45778
# Epoch 20/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 1.1053 - accuracy: 0.7449 - val_loss: 1.9817 - val_accuracy: 0.4961
#
# Epoch 00020: val_loss did not improve from 1.45778
# Epoch 21/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.9550 - accuracy: 0.7891 - val_loss: 1.3194 - val_accuracy: 0.6836
#
# Epoch 00021: val_loss improved from 1.45778 to 1.31943, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.9135 - accuracy: 0.7969 - val_loss: 1.5113 - val_accuracy: 0.6875
#
# Epoch 00022: val_loss did not improve from 1.31943
# Epoch 23/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.8998 - accuracy: 0.7996 - val_loss: 1.3066 - val_accuracy: 0.7109
#
# Epoch 00023: val_loss improved from 1.31943 to 1.30657, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 11s 324ms/step - loss: 0.9096 - accuracy: 0.8024 - val_loss: 1.2706 - val_accuracy: 0.7188
#
# Epoch 00024: val_loss improved from 1.30657 to 1.27065, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.8234 - accuracy: 0.8143 - val_loss: 1.2249 - val_accuracy: 0.7344
#
# Epoch 00025: val_loss improved from 1.27065 to 1.22492, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.8111 - accuracy: 0.8199 - val_loss: 1.1083 - val_accuracy: 0.7461
#
# Epoch 00026: val_loss improved from 1.22492 to 1.10830, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.8389 - accuracy: 0.8235 - val_loss: 1.1663 - val_accuracy: 0.7656
#
# Epoch 00027: val_loss did not improve from 1.10830
# Epoch 28/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.9162 - accuracy: 0.7918 - val_loss: 1.2250 - val_accuracy: 0.7383
#
# Epoch 00028: val_loss did not improve from 1.10830
# Epoch 29/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.9118 - accuracy: 0.8038 - val_loss: 1.3424 - val_accuracy: 0.6992
#
# Epoch 00029: val_loss did not improve from 1.10830
# Epoch 30/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.7782 - accuracy: 0.8327 - val_loss: 1.4046 - val_accuracy: 0.7148
#
# Epoch 00030: val_loss did not improve from 1.10830
# Epoch 31/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.7579 - accuracy: 0.8286 - val_loss: 1.2579 - val_accuracy: 0.6953
#
# Epoch 00031: val_loss did not improve from 1.10830
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.7094 - accuracy: 0.8428 - val_loss: 1.2150 - val_accuracy: 0.7148
#
# Epoch 00032: val_loss did not improve from 1.10830
# Epoch 33/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.6550 - accuracy: 0.8571 - val_loss: 1.0707 - val_accuracy: 0.7500
#
# Epoch 00033: val_loss improved from 1.10830 to 1.07070, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.6230 - accuracy: 0.8594 - val_loss: 1.0094 - val_accuracy: 0.7695
#
# Epoch 00034: val_loss improved from 1.07070 to 1.00943, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.6698 - accuracy: 0.8479 - val_loss: 0.9250 - val_accuracy: 0.7617
#
# Epoch 00035: val_loss improved from 1.00943 to 0.92502, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.6681 - accuracy: 0.8516 - val_loss: 1.0010 - val_accuracy: 0.7695
#
# Epoch 00036: val_loss did not improve from 0.92502
# Epoch 37/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.6255 - accuracy: 0.8585 - val_loss: 0.9585 - val_accuracy: 0.7578
#
# Epoch 00037: val_loss did not improve from 0.92502
# Epoch 38/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.5635 - accuracy: 0.8718 - val_loss: 1.0669 - val_accuracy: 0.7227
#
# Epoch 00038: val_loss did not improve from 0.92502
# Epoch 39/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.6218 - accuracy: 0.8635 - val_loss: 0.9944 - val_accuracy: 0.7852
#
# Epoch 00039: val_loss did not improve from 0.92502
# Epoch 40/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.5991 - accuracy: 0.8612 - val_loss: 1.1074 - val_accuracy: 0.7461
#
# Epoch 00040: val_loss did not improve from 0.92502
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 41/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.5534 - accuracy: 0.8801 - val_loss: 0.9870 - val_accuracy: 0.7891
#
# Epoch 00041: val_loss did not improve from 0.92502
# Epoch 42/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.5598 - accuracy: 0.8635 - val_loss: 0.9090 - val_accuracy: 0.7695
#
# Epoch 00042: val_loss improved from 0.92502 to 0.90896, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.5297 - accuracy: 0.8814 - val_loss: 0.9218 - val_accuracy: 0.7891
#
# Epoch 00043: val_loss did not improve from 0.90896
# Epoch 44/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.4028 - accuracy: 0.9214 - val_loss: 0.9354 - val_accuracy: 0.7930
#
# Epoch 00044: val_loss did not improve from 0.90896
# Epoch 45/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.5272 - accuracy: 0.8709 - val_loss: 0.8864 - val_accuracy: 0.7969
#
# Epoch 00045: val_loss improved from 0.90896 to 0.88644, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3770 - accuracy: 0.9237 - val_loss: 0.9017 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss did not improve from 0.88644
# Epoch 47/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.4786 - accuracy: 0.8801 - val_loss: 0.9090 - val_accuracy: 0.7930
#
# Epoch 00047: val_loss did not improve from 0.88644
# Epoch 48/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.4321 - accuracy: 0.9003 - val_loss: 0.7749 - val_accuracy: 0.8047
#
# Epoch 00048: val_loss improved from 0.88644 to 0.77492, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.6119 - accuracy: 0.8539 - val_loss: 0.8837 - val_accuracy: 0.8086
#
# Epoch 00049: val_loss did not improve from 0.77492
# Epoch 50/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.5402 - accuracy: 0.8695 - val_loss: 0.8546 - val_accuracy: 0.7773
#
# Epoch 00050: val_loss did not improve from 0.77492
# Epoch 51/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.4149 - accuracy: 0.9067 - val_loss: 0.8935 - val_accuracy: 0.7930
#
# Epoch 00051: val_loss did not improve from 0.77492
# Epoch 52/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.4377 - accuracy: 0.9012 - val_loss: 1.0219 - val_accuracy: 0.7812
#
# Epoch 00052: val_loss did not improve from 0.77492
# Epoch 53/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.4269 - accuracy: 0.9017 - val_loss: 0.8483 - val_accuracy: 0.7852
#
# Epoch 00053: val_loss did not improve from 0.77492
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 54/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.4753 - accuracy: 0.8952 - val_loss: 0.8000 - val_accuracy: 0.8008
#
# Epoch 00054: val_loss did not improve from 0.77492
# Epoch 55/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.4111 - accuracy: 0.9072 - val_loss: 0.8583 - val_accuracy: 0.7852
#
# Epoch 00055: val_loss did not improve from 0.77492
# Epoch 56/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.4075 - accuracy: 0.9113 - val_loss: 0.8081 - val_accuracy: 0.8086
#
# Epoch 00056: val_loss did not improve from 0.77492
# Epoch 57/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3717 - accuracy: 0.9168 - val_loss: 0.8439 - val_accuracy: 0.7969
#
# Epoch 00057: val_loss did not improve from 0.77492
# Epoch 58/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.4224 - accuracy: 0.9067 - val_loss: 0.8115 - val_accuracy: 0.8164
#
# Epoch 00058: val_loss did not improve from 0.77492
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 59/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.3576 - accuracy: 0.9237 - val_loss: 0.7501 - val_accuracy: 0.8164
#
# Epoch 00059: val_loss improved from 0.77492 to 0.75011, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.3660 - accuracy: 0.9223 - val_loss: 0.7622 - val_accuracy: 0.8164
#
# Epoch 00060: val_loss did not improve from 0.75011
# Epoch 61/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.3911 - accuracy: 0.9076 - val_loss: 0.7950 - val_accuracy: 0.8047
#
# Epoch 00061: val_loss did not improve from 0.75011
# Epoch 62/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3736 - accuracy: 0.9150 - val_loss: 0.8326 - val_accuracy: 0.8008
#
# Epoch 00062: val_loss did not improve from 0.75011
# Epoch 63/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3376 - accuracy: 0.9301 - val_loss: 0.8966 - val_accuracy: 0.7852
#
# Epoch 00063: val_loss did not improve from 0.75011
# Epoch 64/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.3909 - accuracy: 0.9072 - val_loss: 0.7693 - val_accuracy: 0.8125
#
# Epoch 00064: val_loss did not improve from 0.75011
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 65/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3263 - accuracy: 0.9389 - val_loss: 0.8034 - val_accuracy: 0.8008
#
# Epoch 00065: val_loss did not improve from 0.75011
# Epoch 66/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3439 - accuracy: 0.9260 - val_loss: 0.8250 - val_accuracy: 0.7891
#
# Epoch 00066: val_loss did not improve from 0.75011
# Epoch 67/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2864 - accuracy: 0.9504 - val_loss: 0.7727 - val_accuracy: 0.7969
#
# Epoch 00067: val_loss did not improve from 0.75011
# Epoch 68/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3054 - accuracy: 0.9384 - val_loss: 0.8143 - val_accuracy: 0.7930
#
# Epoch 00068: val_loss did not improve from 0.75011
# Epoch 69/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3304 - accuracy: 0.9260 - val_loss: 0.7902 - val_accuracy: 0.7891
#
# Epoch 00069: val_loss did not improve from 0.75011
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 70/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3674 - accuracy: 0.9150 - val_loss: 0.8183 - val_accuracy: 0.7773
#
# Epoch 00070: val_loss did not improve from 0.75011
# Epoch 71/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3453 - accuracy: 0.9168 - val_loss: 0.8118 - val_accuracy: 0.7969
#
# Epoch 00071: val_loss did not improve from 0.75011
# Epoch 72/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3305 - accuracy: 0.9283 - val_loss: 0.7998 - val_accuracy: 0.8008
#
# Epoch 00072: val_loss did not improve from 0.75011
# Epoch 73/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3421 - accuracy: 0.9219 - val_loss: 0.8028 - val_accuracy: 0.8008
#
# Epoch 00073: val_loss did not improve from 0.75011
# Epoch 74/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.3513 - accuracy: 0.9288 - val_loss: 0.8004 - val_accuracy: 0.7969
#
# Epoch 00074: val_loss did not improve from 0.75011
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 75/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2849 - accuracy: 0.9467 - val_loss: 0.7735 - val_accuracy: 0.7969
#
# Epoch 00075: val_loss did not improve from 0.75011
# Epoch 76/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3190 - accuracy: 0.9357 - val_loss: 0.7489 - val_accuracy: 0.8086
#
# Epoch 00076: val_loss improved from 0.75011 to 0.74885, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.2771 - accuracy: 0.9513 - val_loss: 0.7866 - val_accuracy: 0.8008
#
# Epoch 00077: val_loss did not improve from 0.74885
# Epoch 78/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3007 - accuracy: 0.9384 - val_loss: 0.7763 - val_accuracy: 0.8008
#
# Epoch 00078: val_loss did not improve from 0.74885
# Epoch 79/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.4109 - accuracy: 0.8980 - val_loss: 0.8002 - val_accuracy: 0.7930
#
# Epoch 00079: val_loss did not improve from 0.74885
# Epoch 80/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3106 - accuracy: 0.9384 - val_loss: 0.7915 - val_accuracy: 0.8008
#
# Epoch 00080: val_loss did not improve from 0.74885
# Epoch 81/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3179 - accuracy: 0.9338 - val_loss: 0.7697 - val_accuracy: 0.8008
#
# Epoch 00081: val_loss did not improve from 0.74885
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 82/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3065 - accuracy: 0.9412 - val_loss: 0.7492 - val_accuracy: 0.8047
#
# Epoch 00082: val_loss did not improve from 0.74885
# Epoch 83/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2506 - accuracy: 0.9550 - val_loss: 0.7660 - val_accuracy: 0.8008
#
# Epoch 00083: val_loss did not improve from 0.74885
# Epoch 84/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2739 - accuracy: 0.9435 - val_loss: 0.7924 - val_accuracy: 0.7930
#
# Epoch 00084: val_loss did not improve from 0.74885
# Epoch 85/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.2605 - accuracy: 0.9573 - val_loss: 0.7702 - val_accuracy: 0.8008
#
# Epoch 00085: val_loss did not improve from 0.74885
# Epoch 86/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.2418 - accuracy: 0.9596 - val_loss: 0.7750 - val_accuracy: 0.7930
#
# Epoch 00086: val_loss did not improve from 0.74885
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 87/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3595 - accuracy: 0.9205 - val_loss: 0.7851 - val_accuracy: 0.7969
#
# Epoch 00087: val_loss did not improve from 0.74885
# Epoch 88/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3300 - accuracy: 0.9242 - val_loss: 0.8020 - val_accuracy: 0.7930
#
# Epoch 00088: val_loss did not improve from 0.74885
# Epoch 89/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2882 - accuracy: 0.9416 - val_loss: 0.7788 - val_accuracy: 0.7969
#
# Epoch 00089: val_loss did not improve from 0.74885
# Epoch 90/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2965 - accuracy: 0.9398 - val_loss: 0.7537 - val_accuracy: 0.8125
#
# Epoch 00090: val_loss did not improve from 0.74885
# Epoch 91/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3025 - accuracy: 0.9361 - val_loss: 0.7540 - val_accuracy: 0.8125
#
# Epoch 00091: val_loss did not improve from 0.74885
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 92/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2916 - accuracy: 0.9435 - val_loss: 0.7662 - val_accuracy: 0.8125
#
# Epoch 00092: val_loss did not improve from 0.74885
# Epoch 93/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3268 - accuracy: 0.9352 - val_loss: 0.7682 - val_accuracy: 0.7969
#
# Epoch 00093: val_loss did not improve from 0.74885
# Epoch 94/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2635 - accuracy: 0.9536 - val_loss: 0.7829 - val_accuracy: 0.7969
#
# Epoch 00094: val_loss did not improve from 0.74885
# Epoch 95/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2905 - accuracy: 0.9416 - val_loss: 0.7736 - val_accuracy: 0.7969
#
# Epoch 00095: val_loss did not improve from 0.74885
# Epoch 96/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3404 - accuracy: 0.9251 - val_loss: 0.7490 - val_accuracy: 0.8008
#
# Epoch 00096: val_loss did not improve from 0.74885
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 97/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3622 - accuracy: 0.9246 - val_loss: 0.7897 - val_accuracy: 0.8047
#
# Epoch 00097: val_loss did not improve from 0.74885
# Epoch 98/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.2931 - accuracy: 0.9384 - val_loss: 0.7479 - val_accuracy: 0.8047
#
# Epoch 00098: val_loss improved from 0.74885 to 0.74789, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3332 - accuracy: 0.9260 - val_loss: 0.7657 - val_accuracy: 0.8125
#
# Epoch 00099: val_loss did not improve from 0.74789
# Epoch 100/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2808 - accuracy: 0.9439 - val_loss: 0.7329 - val_accuracy: 0.8125
#
# Epoch 00100: val_loss improved from 0.74789 to 0.73292, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2948 - accuracy: 0.9430 - val_loss: 0.7975 - val_accuracy: 0.7969
#
# Epoch 00101: val_loss did not improve from 0.73292
# Epoch 102/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3158 - accuracy: 0.9306 - val_loss: 0.7520 - val_accuracy: 0.8086
#
# Epoch 00102: val_loss did not improve from 0.73292
# Epoch 103/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.3474 - accuracy: 0.9260 - val_loss: 0.7705 - val_accuracy: 0.8086
#
# Epoch 00103: val_loss did not improve from 0.73292
# Epoch 104/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2663 - accuracy: 0.9481 - val_loss: 0.7761 - val_accuracy: 0.8047
#
# Epoch 00104: val_loss did not improve from 0.73292
# Epoch 105/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3169 - accuracy: 0.9301 - val_loss: 0.7629 - val_accuracy: 0.8125
#
# Epoch 00105: val_loss did not improve from 0.73292
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 106/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2936 - accuracy: 0.9426 - val_loss: 0.7067 - val_accuracy: 0.8125
#
# Epoch 00106: val_loss improved from 0.73292 to 0.70674, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.2715 - accuracy: 0.9472 - val_loss: 0.7248 - val_accuracy: 0.8125
#
# Epoch 00107: val_loss did not improve from 0.70674
# Epoch 108/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2996 - accuracy: 0.9426 - val_loss: 0.6941 - val_accuracy: 0.8203
#
# Epoch 00108: val_loss improved from 0.70674 to 0.69409, saving model to ./save/cnn_gru_best.hdf5
# Epoch 109/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.3270 - accuracy: 0.9265 - val_loss: 0.7307 - val_accuracy: 0.8164
#
# Epoch 00109: val_loss did not improve from 0.69409
# Epoch 110/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.2875 - accuracy: 0.9439 - val_loss: 0.7576 - val_accuracy: 0.8086
#
# Epoch 00110: val_loss did not improve from 0.69409
# Epoch 111/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.3682 - accuracy: 0.9173 - val_loss: 0.7791 - val_accuracy: 0.7969
#
# Epoch 00111: val_loss did not improve from 0.69409
# Epoch 112/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3024 - accuracy: 0.9407 - val_loss: 0.7851 - val_accuracy: 0.8008
#
# Epoch 00112: val_loss did not improve from 0.69409
# Epoch 113/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3019 - accuracy: 0.9384 - val_loss: 0.7492 - val_accuracy: 0.8125
#
# Epoch 00113: val_loss did not improve from 0.69409
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 114/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3123 - accuracy: 0.9343 - val_loss: 0.7882 - val_accuracy: 0.8008
#
# Epoch 00114: val_loss did not improve from 0.69409
# Epoch 115/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2930 - accuracy: 0.9449 - val_loss: 0.7645 - val_accuracy: 0.7969
#
# Epoch 00115: val_loss did not improve from 0.69409
# Epoch 116/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.3006 - accuracy: 0.9375 - val_loss: 0.7689 - val_accuracy: 0.8008
#
# Epoch 00116: val_loss did not improve from 0.69409
# Epoch 117/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3256 - accuracy: 0.9269 - val_loss: 0.7574 - val_accuracy: 0.8086
#
# Epoch 00117: val_loss did not improve from 0.69409
# Epoch 118/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2868 - accuracy: 0.9421 - val_loss: 0.7557 - val_accuracy: 0.8086
#
# Epoch 00118: val_loss did not improve from 0.69409
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 119/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.3104 - accuracy: 0.9334 - val_loss: 0.8007 - val_accuracy: 0.7930
#
# Epoch 00119: val_loss did not improve from 0.69409
# Epoch 120/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3559 - accuracy: 0.9200 - val_loss: 0.8071 - val_accuracy: 0.7969
#
# Epoch 00120: val_loss did not improve from 0.69409
# Epoch 121/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3472 - accuracy: 0.9242 - val_loss: 0.7879 - val_accuracy: 0.7969
#
# Epoch 00121: val_loss did not improve from 0.69409
# Epoch 122/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2716 - accuracy: 0.9504 - val_loss: 0.7535 - val_accuracy: 0.8086
#
# Epoch 00122: val_loss did not improve from 0.69409
# Epoch 123/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.3341 - accuracy: 0.9219 - val_loss: 0.7770 - val_accuracy: 0.8047
#
# Epoch 00123: val_loss did not improve from 0.69409
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 124/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3218 - accuracy: 0.9301 - val_loss: 0.7716 - val_accuracy: 0.8086
#
# Epoch 00124: val_loss did not improve from 0.69409
# Epoch 125/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3177 - accuracy: 0.9375 - val_loss: 0.7963 - val_accuracy: 0.7969
#
# Epoch 00125: val_loss did not improve from 0.69409
# Epoch 126/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3144 - accuracy: 0.9320 - val_loss: 0.7903 - val_accuracy: 0.8047
#
# Epoch 00126: val_loss did not improve from 0.69409
# Epoch 127/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3551 - accuracy: 0.9246 - val_loss: 0.7843 - val_accuracy: 0.8008
#
# Epoch 00127: val_loss did not improve from 0.69409
# Epoch 128/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2665 - accuracy: 0.9458 - val_loss: 0.7447 - val_accuracy: 0.8086
#
# Epoch 00128: val_loss did not improve from 0.69409
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 129/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.3059 - accuracy: 0.9421 - val_loss: 0.8002 - val_accuracy: 0.7930
#
# Epoch 00129: val_loss did not improve from 0.69409
# Epoch 130/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2555 - accuracy: 0.9536 - val_loss: 0.7954 - val_accuracy: 0.8008
#
# Epoch 00130: val_loss did not improve from 0.69409
# Epoch 131/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3175 - accuracy: 0.9301 - val_loss: 0.7678 - val_accuracy: 0.8125
#
# Epoch 00131: val_loss did not improve from 0.69409
# Epoch 132/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.3206 - accuracy: 0.9251 - val_loss: 0.7613 - val_accuracy: 0.8086
#
# Epoch 00132: val_loss did not improve from 0.69409
# Epoch 133/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3271 - accuracy: 0.9301 - val_loss: 0.7807 - val_accuracy: 0.8008
#
# Epoch 00133: val_loss did not improve from 0.69409
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 134/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.3110 - accuracy: 0.9366 - val_loss: 0.7762 - val_accuracy: 0.8008
#
# Epoch 00134: val_loss did not improve from 0.69409
# Epoch 135/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3226 - accuracy: 0.9292 - val_loss: 0.7775 - val_accuracy: 0.8008
#
# Epoch 00135: val_loss did not improve from 0.69409
# Epoch 136/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3302 - accuracy: 0.9265 - val_loss: 0.7770 - val_accuracy: 0.8047
#
# Epoch 00136: val_loss did not improve from 0.69409
# Epoch 137/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.3313 - accuracy: 0.9278 - val_loss: 0.7782 - val_accuracy: 0.8047
#
# Epoch 00137: val_loss did not improve from 0.69409
# Epoch 138/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2708 - accuracy: 0.9481 - val_loss: 0.7504 - val_accuracy: 0.8125
#
# Epoch 00138: val_loss did not improve from 0.69409
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 00138: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6173 - accuracy: 0.8544
# [0.6173141598701477, 0.8543999791145325]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
