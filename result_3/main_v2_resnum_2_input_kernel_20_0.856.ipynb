# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 20, # #10#
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 2 # #3#, ##5##, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      1460        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1020)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         add_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,193,531
# Trainable params: 2,187,351
# Non-trainable params: 6,180
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 59s 554ms/step - loss: 11.4720 - accuracy: 0.4177 - val_loss: 9.0882 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 9.08818, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 6.4708 - accuracy: 0.5666 - val_loss: 6.2518 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 9.08818 to 6.25180, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 3.9088 - accuracy: 0.6558 - val_loss: 5.1556 - val_accuracy: 0.2773
#
# Epoch 00003: val_loss improved from 6.25180 to 5.15560, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 2.8048 - accuracy: 0.6668 - val_loss: 4.8170 - val_accuracy: 0.4531
#
# Epoch 00004: val_loss improved from 5.15560 to 4.81697, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 2.1233 - accuracy: 0.6880 - val_loss: 5.0729 - val_accuracy: 0.4531
#
# Epoch 00005: val_loss did not improve from 4.81697
# Epoch 6/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 1.7134 - accuracy: 0.7054 - val_loss: 5.0227 - val_accuracy: 0.0312
#
# Epoch 00006: val_loss did not improve from 4.81697
# Epoch 7/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 1.4289 - accuracy: 0.7298 - val_loss: 5.0616 - val_accuracy: 0.1211
#
# Epoch 00007: val_loss did not improve from 4.81697
# Epoch 8/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 1.2340 - accuracy: 0.7624 - val_loss: 5.1060 - val_accuracy: 0.2070
#
# Epoch 00008: val_loss did not improve from 4.81697
# Epoch 9/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 1.1250 - accuracy: 0.7762 - val_loss: 5.2895 - val_accuracy: 0.2070
#
# Epoch 00009: val_loss did not improve from 4.81697
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 1.0819 - accuracy: 0.7799 - val_loss: 5.3259 - val_accuracy: 0.1758
#
# Epoch 00010: val_loss did not improve from 4.81697
# Epoch 11/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.9970 - accuracy: 0.7923 - val_loss: 4.9468 - val_accuracy: 0.3086
#
# Epoch 00011: val_loss did not improve from 4.81697
# Epoch 12/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.9503 - accuracy: 0.7937 - val_loss: 4.5286 - val_accuracy: 0.2656
#
# Epoch 00012: val_loss improved from 4.81697 to 4.52864, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.8360 - accuracy: 0.8244 - val_loss: 4.2184 - val_accuracy: 0.3320
#
# Epoch 00013: val_loss improved from 4.52864 to 4.21839, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.8128 - accuracy: 0.8244 - val_loss: 3.8040 - val_accuracy: 0.3789
#
# Epoch 00014: val_loss improved from 4.21839 to 3.80403, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.8530 - accuracy: 0.8157 - val_loss: 3.5211 - val_accuracy: 0.3906
#
# Epoch 00015: val_loss improved from 3.80403 to 3.52111, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.8670 - accuracy: 0.8116 - val_loss: 2.7750 - val_accuracy: 0.5430
#
# Epoch 00016: val_loss improved from 3.52111 to 2.77498, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.8908 - accuracy: 0.8143 - val_loss: 2.7160 - val_accuracy: 0.5156
#
# Epoch 00017: val_loss improved from 2.77498 to 2.71603, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.7512 - accuracy: 0.8396 - val_loss: 2.1797 - val_accuracy: 0.6055
#
# Epoch 00018: val_loss improved from 2.71603 to 2.17973, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.6915 - accuracy: 0.8525 - val_loss: 2.1817 - val_accuracy: 0.5938
#
# Epoch 00019: val_loss did not improve from 2.17973
# Epoch 20/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.9091 - accuracy: 0.7983 - val_loss: 1.6815 - val_accuracy: 0.6602
#
# Epoch 00020: val_loss improved from 2.17973 to 1.68154, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.7986 - accuracy: 0.8272 - val_loss: 1.2708 - val_accuracy: 0.7148
#
# Epoch 00021: val_loss improved from 1.68154 to 1.27079, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.7355 - accuracy: 0.8424 - val_loss: 1.2362 - val_accuracy: 0.7148
#
# Epoch 00022: val_loss improved from 1.27079 to 1.23623, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.7440 - accuracy: 0.8419 - val_loss: 1.0903 - val_accuracy: 0.7305
#
# Epoch 00023: val_loss improved from 1.23623 to 1.09032, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.7182 - accuracy: 0.8410 - val_loss: 1.1614 - val_accuracy: 0.7148
#
# Epoch 00024: val_loss did not improve from 1.09032
# Epoch 25/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.6613 - accuracy: 0.8612 - val_loss: 1.0173 - val_accuracy: 0.7695
#
# Epoch 00025: val_loss improved from 1.09032 to 1.01725, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.6558 - accuracy: 0.8649 - val_loss: 0.9793 - val_accuracy: 0.7734
#
# Epoch 00026: val_loss improved from 1.01725 to 0.97928, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.6891 - accuracy: 0.8557 - val_loss: 1.1319 - val_accuracy: 0.7578
#
# Epoch 00027: val_loss did not improve from 0.97928
# Epoch 28/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.7657 - accuracy: 0.8254 - val_loss: 1.0309 - val_accuracy: 0.7812
#
# Epoch 00028: val_loss did not improve from 0.97928
# Epoch 29/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.7490 - accuracy: 0.8336 - val_loss: 1.1000 - val_accuracy: 0.7500
#
# Epoch 00029: val_loss did not improve from 0.97928
# Epoch 30/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.6318 - accuracy: 0.8796 - val_loss: 1.1974 - val_accuracy: 0.7344
#
# Epoch 00030: val_loss did not improve from 0.97928
# Epoch 31/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.6168 - accuracy: 0.8699 - val_loss: 1.1241 - val_accuracy: 0.7344
#
# Epoch 00031: val_loss did not improve from 0.97928
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 32/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.5597 - accuracy: 0.8768 - val_loss: 1.0216 - val_accuracy: 0.7617
#
# Epoch 00032: val_loss did not improve from 0.97928
# Epoch 33/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.5219 - accuracy: 0.8948 - val_loss: 0.9466 - val_accuracy: 0.7773
#
# Epoch 00033: val_loss improved from 0.97928 to 0.94662, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.5032 - accuracy: 0.8906 - val_loss: 0.8691 - val_accuracy: 0.7969
#
# Epoch 00034: val_loss improved from 0.94662 to 0.86914, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.5363 - accuracy: 0.8888 - val_loss: 0.8915 - val_accuracy: 0.7930
#
# Epoch 00035: val_loss did not improve from 0.86914
# Epoch 36/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.5467 - accuracy: 0.8778 - val_loss: 0.9266 - val_accuracy: 0.7734
#
# Epoch 00036: val_loss did not improve from 0.86914
# Epoch 37/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.5044 - accuracy: 0.8925 - val_loss: 0.9375 - val_accuracy: 0.7734
#
# Epoch 00037: val_loss did not improve from 0.86914
# Epoch 38/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.4657 - accuracy: 0.8980 - val_loss: 0.8779 - val_accuracy: 0.8008
#
# Epoch 00038: val_loss did not improve from 0.86914
# Epoch 39/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.4696 - accuracy: 0.8957 - val_loss: 0.9099 - val_accuracy: 0.7695
#
# Epoch 00039: val_loss did not improve from 0.86914
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 40/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.4446 - accuracy: 0.9053 - val_loss: 0.8983 - val_accuracy: 0.7695
#
# Epoch 00040: val_loss did not improve from 0.86914
# Epoch 41/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.4164 - accuracy: 0.9159 - val_loss: 0.8954 - val_accuracy: 0.7930
#
# Epoch 00041: val_loss did not improve from 0.86914
# Epoch 42/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.4362 - accuracy: 0.9095 - val_loss: 0.8835 - val_accuracy: 0.7656
#
# Epoch 00042: val_loss did not improve from 0.86914
# Epoch 43/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.4274 - accuracy: 0.9118 - val_loss: 0.8860 - val_accuracy: 0.7812
#
# Epoch 00043: val_loss did not improve from 0.86914
# Epoch 44/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.3007 - accuracy: 0.9472 - val_loss: 0.8395 - val_accuracy: 0.8008
#
# Epoch 00044: val_loss improved from 0.86914 to 0.83947, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.4295 - accuracy: 0.9044 - val_loss: 0.8258 - val_accuracy: 0.8008
#
# Epoch 00045: val_loss improved from 0.83947 to 0.82584, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2749 - accuracy: 0.9550 - val_loss: 0.8615 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss did not improve from 0.82584
# Epoch 47/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.3778 - accuracy: 0.9191 - val_loss: 0.9119 - val_accuracy: 0.7734
#
# Epoch 00047: val_loss did not improve from 0.82584
# Epoch 48/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.3235 - accuracy: 0.9370 - val_loss: 0.8211 - val_accuracy: 0.7969
#
# Epoch 00048: val_loss improved from 0.82584 to 0.82107, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.5049 - accuracy: 0.8773 - val_loss: 0.8514 - val_accuracy: 0.8242
#
# Epoch 00049: val_loss did not improve from 0.82107
# Epoch 50/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.4449 - accuracy: 0.8984 - val_loss: 0.8277 - val_accuracy: 0.8047
#
# Epoch 00050: val_loss did not improve from 0.82107
# Epoch 51/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.3241 - accuracy: 0.9352 - val_loss: 0.7556 - val_accuracy: 0.8164
#
# Epoch 00051: val_loss improved from 0.82107 to 0.75558, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.3520 - accuracy: 0.9311 - val_loss: 0.8156 - val_accuracy: 0.8047
#
# Epoch 00052: val_loss did not improve from 0.75558
# Epoch 53/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.3384 - accuracy: 0.9329 - val_loss: 0.7956 - val_accuracy: 0.8164
#
# Epoch 00053: val_loss did not improve from 0.75558
# Epoch 54/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.4023 - accuracy: 0.9154 - val_loss: 0.8458 - val_accuracy: 0.8125
#
# Epoch 00054: val_loss did not improve from 0.75558
# Epoch 55/2000
# 34/34 [==============================] - 12s 339ms/step - loss: 0.3625 - accuracy: 0.9214 - val_loss: 0.8894 - val_accuracy: 0.7969
#
# Epoch 00055: val_loss did not improve from 0.75558
# Epoch 56/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.3562 - accuracy: 0.9223 - val_loss: 0.8199 - val_accuracy: 0.8125
#
# Epoch 00056: val_loss did not improve from 0.75558
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2883 - accuracy: 0.9421 - val_loss: 0.8421 - val_accuracy: 0.8008
#
# Epoch 00057: val_loss did not improve from 0.75558
# Epoch 58/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.3428 - accuracy: 0.9265 - val_loss: 0.8023 - val_accuracy: 0.8125
#
# Epoch 00058: val_loss did not improve from 0.75558
# Epoch 59/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2867 - accuracy: 0.9389 - val_loss: 0.7817 - val_accuracy: 0.8164
#
# Epoch 00059: val_loss did not improve from 0.75558
# Epoch 60/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.3042 - accuracy: 0.9352 - val_loss: 0.7867 - val_accuracy: 0.8047
#
# Epoch 00060: val_loss did not improve from 0.75558
# Epoch 61/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.3127 - accuracy: 0.9366 - val_loss: 0.7702 - val_accuracy: 0.8164
#
# Epoch 00061: val_loss did not improve from 0.75558
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 62/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.3060 - accuracy: 0.9343 - val_loss: 0.8077 - val_accuracy: 0.8242
#
# Epoch 00062: val_loss did not improve from 0.75558
# Epoch 63/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2636 - accuracy: 0.9485 - val_loss: 0.8189 - val_accuracy: 0.8203
#
# Epoch 00063: val_loss did not improve from 0.75558
# Epoch 64/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2992 - accuracy: 0.9384 - val_loss: 0.7513 - val_accuracy: 0.8438
#
# Epoch 00064: val_loss improved from 0.75558 to 0.75134, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.2583 - accuracy: 0.9540 - val_loss: 0.7878 - val_accuracy: 0.8164
#
# Epoch 00065: val_loss did not improve from 0.75134
# Epoch 66/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.2748 - accuracy: 0.9458 - val_loss: 0.8163 - val_accuracy: 0.8086
#
# Epoch 00066: val_loss did not improve from 0.75134
# Epoch 67/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2162 - accuracy: 0.9678 - val_loss: 0.7791 - val_accuracy: 0.8086
#
# Epoch 00067: val_loss did not improve from 0.75134
# Epoch 68/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2445 - accuracy: 0.9582 - val_loss: 0.8119 - val_accuracy: 0.8047
#
# Epoch 00068: val_loss did not improve from 0.75134
# Epoch 69/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2591 - accuracy: 0.9517 - val_loss: 0.7703 - val_accuracy: 0.8242
#
# Epoch 00069: val_loss did not improve from 0.75134
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 70/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.2964 - accuracy: 0.9352 - val_loss: 0.8007 - val_accuracy: 0.8047
#
# Epoch 00070: val_loss did not improve from 0.75134
# Epoch 71/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2787 - accuracy: 0.9453 - val_loss: 0.7800 - val_accuracy: 0.8164
#
# Epoch 00071: val_loss did not improve from 0.75134
# Epoch 72/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2470 - accuracy: 0.9499 - val_loss: 0.8091 - val_accuracy: 0.8125
#
# Epoch 00072: val_loss did not improve from 0.75134
# Epoch 73/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.2748 - accuracy: 0.9435 - val_loss: 0.8048 - val_accuracy: 0.8086
#
# Epoch 00073: val_loss did not improve from 0.75134
# Epoch 74/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2713 - accuracy: 0.9490 - val_loss: 0.8016 - val_accuracy: 0.8164
#
# Epoch 00074: val_loss did not improve from 0.75134
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 75/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2161 - accuracy: 0.9623 - val_loss: 0.7754 - val_accuracy: 0.8242
#
# Epoch 00075: val_loss did not improve from 0.75134
# Epoch 76/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2450 - accuracy: 0.9540 - val_loss: 0.7626 - val_accuracy: 0.8320
#
# Epoch 00076: val_loss did not improve from 0.75134
# Epoch 77/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2131 - accuracy: 0.9632 - val_loss: 0.7926 - val_accuracy: 0.8203
#
# Epoch 00077: val_loss did not improve from 0.75134
# Epoch 78/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.2342 - accuracy: 0.9554 - val_loss: 0.7721 - val_accuracy: 0.8281
#
# Epoch 00078: val_loss did not improve from 0.75134
# Epoch 79/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.3266 - accuracy: 0.9278 - val_loss: 0.8115 - val_accuracy: 0.8086
#
# Epoch 00079: val_loss did not improve from 0.75134
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 80/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2648 - accuracy: 0.9467 - val_loss: 0.7964 - val_accuracy: 0.8203
#
# Epoch 00080: val_loss did not improve from 0.75134
# Epoch 81/2000
# 34/34 [==============================] - 12s 340ms/step - loss: 0.2430 - accuracy: 0.9614 - val_loss: 0.7657 - val_accuracy: 0.8203
#
# Epoch 00081: val_loss did not improve from 0.75134
# Epoch 82/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2306 - accuracy: 0.9582 - val_loss: 0.7371 - val_accuracy: 0.8203
#
# Epoch 00082: val_loss improved from 0.75134 to 0.73712, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 12s 340ms/step - loss: 0.1893 - accuracy: 0.9738 - val_loss: 0.7629 - val_accuracy: 0.8320
#
# Epoch 00083: val_loss did not improve from 0.73712
# Epoch 84/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2039 - accuracy: 0.9669 - val_loss: 0.7910 - val_accuracy: 0.8242
#
# Epoch 00084: val_loss did not improve from 0.73712
# Epoch 85/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.1920 - accuracy: 0.9724 - val_loss: 0.7786 - val_accuracy: 0.8242
#
# Epoch 00085: val_loss did not improve from 0.73712
# Epoch 86/2000
# 34/34 [==============================] - 12s 339ms/step - loss: 0.1761 - accuracy: 0.9738 - val_loss: 0.7747 - val_accuracy: 0.8203
#
# Epoch 00086: val_loss did not improve from 0.73712
# Epoch 87/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.2871 - accuracy: 0.9407 - val_loss: 0.7772 - val_accuracy: 0.8281
#
# Epoch 00087: val_loss did not improve from 0.73712
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 88/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2673 - accuracy: 0.9458 - val_loss: 0.7999 - val_accuracy: 0.8281
#
# Epoch 00088: val_loss did not improve from 0.73712
# Epoch 89/2000
# 34/34 [==============================] - 12s 340ms/step - loss: 0.2192 - accuracy: 0.9609 - val_loss: 0.7677 - val_accuracy: 0.8281
#
# Epoch 00089: val_loss did not improve from 0.73712
# Epoch 90/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.2303 - accuracy: 0.9559 - val_loss: 0.7656 - val_accuracy: 0.8281
#
# Epoch 00090: val_loss did not improve from 0.73712
# Epoch 91/2000
# 34/34 [==============================] - 12s 339ms/step - loss: 0.2397 - accuracy: 0.9545 - val_loss: 0.7558 - val_accuracy: 0.8242
#
# Epoch 00091: val_loss did not improve from 0.73712
# Epoch 92/2000
# 34/34 [==============================] - 12s 339ms/step - loss: 0.2280 - accuracy: 0.9591 - val_loss: 0.7638 - val_accuracy: 0.8320
#
# Epoch 00092: val_loss did not improve from 0.73712
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 93/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.2600 - accuracy: 0.9522 - val_loss: 0.7617 - val_accuracy: 0.8320
#
# Epoch 00093: val_loss did not improve from 0.73712
# Epoch 94/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.1944 - accuracy: 0.9706 - val_loss: 0.7839 - val_accuracy: 0.8242
#
# Epoch 00094: val_loss did not improve from 0.73712
# Epoch 95/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.2243 - accuracy: 0.9591 - val_loss: 0.7903 - val_accuracy: 0.8203
#
# Epoch 00095: val_loss did not improve from 0.73712
# Epoch 96/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.2624 - accuracy: 0.9444 - val_loss: 0.7389 - val_accuracy: 0.8242
#
# Epoch 00096: val_loss did not improve from 0.73712
# Epoch 97/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.3049 - accuracy: 0.9338 - val_loss: 0.8059 - val_accuracy: 0.8203
#
# Epoch 00097: val_loss did not improve from 0.73712
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 98/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2254 - accuracy: 0.9591 - val_loss: 0.7382 - val_accuracy: 0.8320
#
# Epoch 00098: val_loss did not improve from 0.73712
# Epoch 99/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2584 - accuracy: 0.9504 - val_loss: 0.7609 - val_accuracy: 0.8281
#
# Epoch 00099: val_loss did not improve from 0.73712
# Epoch 100/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2073 - accuracy: 0.9651 - val_loss: 0.7449 - val_accuracy: 0.8320
#
# Epoch 00100: val_loss did not improve from 0.73712
# Epoch 101/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2267 - accuracy: 0.9614 - val_loss: 0.8037 - val_accuracy: 0.8164
#
# Epoch 00101: val_loss did not improve from 0.73712
# Epoch 102/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2434 - accuracy: 0.9550 - val_loss: 0.7569 - val_accuracy: 0.8242
#
# Epoch 00102: val_loss did not improve from 0.73712
#
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 103/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.2642 - accuracy: 0.9490 - val_loss: 0.7737 - val_accuracy: 0.8242
#
# Epoch 00103: val_loss did not improve from 0.73712
# Epoch 104/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2056 - accuracy: 0.9678 - val_loss: 0.7718 - val_accuracy: 0.8242
#
# Epoch 00104: val_loss did not improve from 0.73712
# Epoch 105/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2514 - accuracy: 0.9550 - val_loss: 0.7607 - val_accuracy: 0.8281
#
# Epoch 00105: val_loss did not improve from 0.73712
# Epoch 106/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2369 - accuracy: 0.9586 - val_loss: 0.6839 - val_accuracy: 0.8359
#
# Epoch 00106: val_loss improved from 0.73712 to 0.68388, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2040 - accuracy: 0.9660 - val_loss: 0.7015 - val_accuracy: 0.8359
#
# Epoch 00107: val_loss did not improve from 0.68388
# Epoch 108/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2288 - accuracy: 0.9605 - val_loss: 0.6930 - val_accuracy: 0.8320
#
# Epoch 00108: val_loss did not improve from 0.68388
# Epoch 109/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2575 - accuracy: 0.9499 - val_loss: 0.7179 - val_accuracy: 0.8281
#
# Epoch 00109: val_loss did not improve from 0.68388
# Epoch 110/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2207 - accuracy: 0.9628 - val_loss: 0.7564 - val_accuracy: 0.8281
#
# Epoch 00110: val_loss did not improve from 0.68388
# Epoch 111/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2934 - accuracy: 0.9393 - val_loss: 0.7715 - val_accuracy: 0.8242
#
# Epoch 00111: val_loss did not improve from 0.68388
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 112/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2341 - accuracy: 0.9559 - val_loss: 0.7876 - val_accuracy: 0.8242
#
# Epoch 00112: val_loss did not improve from 0.68388
# Epoch 113/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2383 - accuracy: 0.9596 - val_loss: 0.7591 - val_accuracy: 0.8281
#
# Epoch 00113: val_loss did not improve from 0.68388
# Epoch 114/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2432 - accuracy: 0.9508 - val_loss: 0.7947 - val_accuracy: 0.8203
#
# Epoch 00114: val_loss did not improve from 0.68388
# Epoch 115/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2255 - accuracy: 0.9600 - val_loss: 0.7514 - val_accuracy: 0.8203
#
# Epoch 00115: val_loss did not improve from 0.68388
# Epoch 116/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2163 - accuracy: 0.9646 - val_loss: 0.7733 - val_accuracy: 0.8242
#
# Epoch 00116: val_loss did not improve from 0.68388
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 117/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.2502 - accuracy: 0.9554 - val_loss: 0.7676 - val_accuracy: 0.8281
#
# Epoch 00117: val_loss did not improve from 0.68388
# Epoch 118/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2199 - accuracy: 0.9655 - val_loss: 0.7533 - val_accuracy: 0.8281
#
# Epoch 00118: val_loss did not improve from 0.68388
# Epoch 119/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.2427 - accuracy: 0.9559 - val_loss: 0.8031 - val_accuracy: 0.8164
#
# Epoch 00119: val_loss did not improve from 0.68388
# Epoch 120/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2881 - accuracy: 0.9334 - val_loss: 0.8122 - val_accuracy: 0.8164
#
# Epoch 00120: val_loss did not improve from 0.68388
# Epoch 121/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2723 - accuracy: 0.9531 - val_loss: 0.7836 - val_accuracy: 0.8164
#
# Epoch 00121: val_loss did not improve from 0.68388
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 122/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2091 - accuracy: 0.9655 - val_loss: 0.7393 - val_accuracy: 0.8359
#
# Epoch 00122: val_loss did not improve from 0.68388
# Epoch 123/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2554 - accuracy: 0.9490 - val_loss: 0.7835 - val_accuracy: 0.8242
#
# Epoch 00123: val_loss did not improve from 0.68388
# Epoch 124/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2498 - accuracy: 0.9527 - val_loss: 0.7831 - val_accuracy: 0.8281
#
# Epoch 00124: val_loss did not improve from 0.68388
# Epoch 125/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2535 - accuracy: 0.9476 - val_loss: 0.7969 - val_accuracy: 0.8242
#
# Epoch 00125: val_loss did not improve from 0.68388
# Epoch 126/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2339 - accuracy: 0.9609 - val_loss: 0.7941 - val_accuracy: 0.8281
#
# Epoch 00126: val_loss did not improve from 0.68388
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 127/2000
# 34/34 [==============================] - 12s 341ms/step - loss: 0.2746 - accuracy: 0.9426 - val_loss: 0.7935 - val_accuracy: 0.8242
#
# Epoch 00127: val_loss did not improve from 0.68388
# Epoch 128/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.2077 - accuracy: 0.9609 - val_loss: 0.7331 - val_accuracy: 0.8398
#
# Epoch 00128: val_loss did not improve from 0.68388
# Epoch 129/2000
# 34/34 [==============================] - 12s 342ms/step - loss: 0.2367 - accuracy: 0.9582 - val_loss: 0.8063 - val_accuracy: 0.8164
#
# Epoch 00129: val_loss did not improve from 0.68388
# Epoch 130/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.1921 - accuracy: 0.9683 - val_loss: 0.8003 - val_accuracy: 0.8164
#
# Epoch 00130: val_loss did not improve from 0.68388
# Epoch 131/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.2520 - accuracy: 0.9527 - val_loss: 0.7787 - val_accuracy: 0.8242
#
# Epoch 00131: val_loss did not improve from 0.68388
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 132/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.2455 - accuracy: 0.9536 - val_loss: 0.7614 - val_accuracy: 0.8359
#
# Epoch 00132: val_loss did not improve from 0.68388
# Epoch 133/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2486 - accuracy: 0.9540 - val_loss: 0.7796 - val_accuracy: 0.8281
#
# Epoch 00133: val_loss did not improve from 0.68388
# Epoch 134/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2486 - accuracy: 0.9490 - val_loss: 0.7699 - val_accuracy: 0.8281
#
# Epoch 00134: val_loss did not improve from 0.68388
# Epoch 135/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2431 - accuracy: 0.9563 - val_loss: 0.7865 - val_accuracy: 0.8281
#
# Epoch 00135: val_loss did not improve from 0.68388
# Epoch 136/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.2476 - accuracy: 0.9540 - val_loss: 0.7839 - val_accuracy: 0.8281
#
# Epoch 00136: val_loss did not improve from 0.68388
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6247 - accuracy: 0.8560
# [0.6246574521064758, 0.8560000061988831]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
