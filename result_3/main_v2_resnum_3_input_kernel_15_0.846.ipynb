# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset #, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 15, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 15)      1365        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 15)      1365        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 15)      2175        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 15)      1095        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 15)      1095        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 15)      2715        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 15)      2715        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 15)      2715        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 7)       2527        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 15)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 15)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 15)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 15)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 15)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 15)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 15)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 15)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 7)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 15)      60          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 15)      60          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 15)      60          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 15)      60          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 15)      60          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 15)      60          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 15)      60          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 15)      60          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 7)       28          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 30)      4230        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 30)      4230        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 30)      4230        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 30)      4230        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 30)      4230        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 30)      4230        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 30)      4230        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 30)      4230        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 14)      966         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 30)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 30)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 30)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 30)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 30)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 30)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 30)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 30)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 14)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 30)      120         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 30)      120         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 30)      120         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 30)      120         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 30)      120         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 30)      120         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 30)      120         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 30)      120         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 14)      56          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 90)      8190        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 90)      8190        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 90)      8190        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 90)      8190        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 90)      8190        batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 90)      8190        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 90)      16290       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 90)      16290       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 42)      3570        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 90)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 90)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 90)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 90)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 90)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 90)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 90)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 90)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 42)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 90)      360         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 90)      360         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 90)      360         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 90)      360         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 90)      360         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 90)      360         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 90)      360         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 90)      360         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 42)      168         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 90)      49140       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 90)      49140       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 90)      49140       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 90)      49140       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 90)      49140       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 90)      49140       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 90)      49140       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 90)      49140       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 42)      10836       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 90)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 90)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 90)      0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 90)      0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 90)      0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 90)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 90)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 90)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 42)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 90)      360         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 90)      360         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 90)      360         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 90)      360         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 90)      360         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 90)      360         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 90)      360         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 90)      360         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 42)      168         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 762)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      411540      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      411540      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,574,420
# Trainable params: 1,569,050
# Non-trainable params: 5,370
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 58s 584ms/step - loss: 15.2944 - accuracy: 0.4030 - val_loss: 11.8693 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 11.86929, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 8.6913 - accuracy: 0.5648 - val_loss: 7.9110 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 11.86929 to 7.91101, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 13s 388ms/step - loss: 5.1352 - accuracy: 0.6507 - val_loss: 5.8022 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 7.91101 to 5.80224, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 3.5121 - accuracy: 0.6572 - val_loss: 5.2880 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 5.80224 to 5.28796, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 2.5430 - accuracy: 0.6765 - val_loss: 4.6674 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 5.28796 to 4.66741, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 1.9741 - accuracy: 0.6921 - val_loss: 4.8391 - val_accuracy: 0.1484
#
# Epoch 00006: val_loss did not improve from 4.66741
# Epoch 7/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 1.5748 - accuracy: 0.7238 - val_loss: 4.6059 - val_accuracy: 0.3242
#
# Epoch 00007: val_loss improved from 4.66741 to 4.60593, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 1.3380 - accuracy: 0.7546 - val_loss: 4.6848 - val_accuracy: 0.3633
#
# Epoch 00008: val_loss did not improve from 4.60593
# Epoch 9/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 1.1853 - accuracy: 0.7794 - val_loss: 4.4040 - val_accuracy: 0.3867
#
# Epoch 00009: val_loss improved from 4.60593 to 4.40398, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 1.2379 - accuracy: 0.7440 - val_loss: 4.5487 - val_accuracy: 0.3945
#
# Epoch 00010: val_loss did not improve from 4.40398
# Epoch 11/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 1.2273 - accuracy: 0.7431 - val_loss: 5.4186 - val_accuracy: 0.2344
#
# Epoch 00011: val_loss did not improve from 4.40398
# Epoch 12/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 1.1467 - accuracy: 0.7629 - val_loss: 3.6189 - val_accuracy: 0.4648
#
# Epoch 00012: val_loss improved from 4.40398 to 3.61889, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 1.0424 - accuracy: 0.7803 - val_loss: 3.9648 - val_accuracy: 0.3281
#
# Epoch 00013: val_loss did not improve from 3.61889
# Epoch 14/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 0.9860 - accuracy: 0.7886 - val_loss: 3.4259 - val_accuracy: 0.4023
#
# Epoch 00014: val_loss improved from 3.61889 to 3.42595, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 1.0163 - accuracy: 0.7808 - val_loss: 4.1941 - val_accuracy: 0.3203
#
# Epoch 00015: val_loss did not improve from 3.42595
# Epoch 16/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 1.0297 - accuracy: 0.7716 - val_loss: 2.6365 - val_accuracy: 0.5547
#
# Epoch 00016: val_loss improved from 3.42595 to 2.63645, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 1.0552 - accuracy: 0.7757 - val_loss: 1.9978 - val_accuracy: 0.5781
#
# Epoch 00017: val_loss improved from 2.63645 to 1.99782, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.9161 - accuracy: 0.8051 - val_loss: 1.7699 - val_accuracy: 0.6445
#
# Epoch 00018: val_loss improved from 1.99782 to 1.76986, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.8350 - accuracy: 0.8244 - val_loss: 1.6227 - val_accuracy: 0.6836
#
# Epoch 00019: val_loss improved from 1.76986 to 1.62272, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 1.0429 - accuracy: 0.7684 - val_loss: 1.4894 - val_accuracy: 0.6953
#
# Epoch 00020: val_loss improved from 1.62272 to 1.48942, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.9664 - accuracy: 0.7845 - val_loss: 1.3998 - val_accuracy: 0.6641
#
# Epoch 00021: val_loss improved from 1.48942 to 1.39977, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.8902 - accuracy: 0.8047 - val_loss: 1.2290 - val_accuracy: 0.7344
#
# Epoch 00022: val_loss improved from 1.39977 to 1.22905, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.8575 - accuracy: 0.8254 - val_loss: 1.2720 - val_accuracy: 0.6836
#
# Epoch 00023: val_loss did not improve from 1.22905
# Epoch 24/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.8300 - accuracy: 0.8208 - val_loss: 1.1360 - val_accuracy: 0.7461
#
# Epoch 00024: val_loss improved from 1.22905 to 1.13603, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.8085 - accuracy: 0.8300 - val_loss: 1.2397 - val_accuracy: 0.7305
#
# Epoch 00025: val_loss did not improve from 1.13603
# Epoch 26/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.7924 - accuracy: 0.8309 - val_loss: 1.2415 - val_accuracy: 0.7344
#
# Epoch 00026: val_loss did not improve from 1.13603
# Epoch 27/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.8096 - accuracy: 0.8327 - val_loss: 1.1890 - val_accuracy: 0.7344
#
# Epoch 00027: val_loss did not improve from 1.13603
# Epoch 28/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.8714 - accuracy: 0.8097 - val_loss: 1.6731 - val_accuracy: 0.6094
#
# Epoch 00028: val_loss did not improve from 1.13603
# Epoch 29/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 0.8702 - accuracy: 0.8116 - val_loss: 1.3234 - val_accuracy: 0.7070
#
# Epoch 00029: val_loss did not improve from 1.13603
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 30/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.6842 - accuracy: 0.8672 - val_loss: 1.0693 - val_accuracy: 0.7617
#
# Epoch 00030: val_loss improved from 1.13603 to 1.06929, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.6012 - accuracy: 0.8750 - val_loss: 1.0295 - val_accuracy: 0.7305
#
# Epoch 00031: val_loss improved from 1.06929 to 1.02947, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.5970 - accuracy: 0.8653 - val_loss: 1.1447 - val_accuracy: 0.7227
#
# Epoch 00032: val_loss did not improve from 1.02947
# Epoch 33/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.6113 - accuracy: 0.8676 - val_loss: 1.0301 - val_accuracy: 0.7578
#
# Epoch 00033: val_loss did not improve from 1.02947
# Epoch 34/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.5610 - accuracy: 0.8828 - val_loss: 0.9268 - val_accuracy: 0.8086
#
# Epoch 00034: val_loss improved from 1.02947 to 0.92680, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.5938 - accuracy: 0.8672 - val_loss: 0.9363 - val_accuracy: 0.7969
#
# Epoch 00035: val_loss did not improve from 0.92680
# Epoch 36/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.6190 - accuracy: 0.8598 - val_loss: 0.9469 - val_accuracy: 0.7773
#
# Epoch 00036: val_loss did not improve from 0.92680
# Epoch 37/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.5737 - accuracy: 0.8782 - val_loss: 0.9612 - val_accuracy: 0.7930
#
# Epoch 00037: val_loss did not improve from 0.92680
# Epoch 38/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.5310 - accuracy: 0.8833 - val_loss: 0.9040 - val_accuracy: 0.7930
#
# Epoch 00038: val_loss improved from 0.92680 to 0.90397, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.5826 - accuracy: 0.8704 - val_loss: 1.0487 - val_accuracy: 0.7695
#
# Epoch 00039: val_loss did not improve from 0.90397
# Epoch 40/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.5709 - accuracy: 0.8810 - val_loss: 1.1043 - val_accuracy: 0.7617
#
# Epoch 00040: val_loss did not improve from 0.90397
# Epoch 41/2000
# 34/34 [==============================] - 13s 379ms/step - loss: 0.5653 - accuracy: 0.8837 - val_loss: 0.9796 - val_accuracy: 0.7734
#
# Epoch 00041: val_loss did not improve from 0.90397
# Epoch 42/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.5890 - accuracy: 0.8649 - val_loss: 1.0874 - val_accuracy: 0.7656
#
# Epoch 00042: val_loss did not improve from 0.90397
# Epoch 43/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.5641 - accuracy: 0.8773 - val_loss: 1.0349 - val_accuracy: 0.7578
#
# Epoch 00043: val_loss did not improve from 0.90397
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 44/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.3986 - accuracy: 0.9288 - val_loss: 0.9346 - val_accuracy: 0.7969
#
# Epoch 00044: val_loss did not improve from 0.90397
# Epoch 45/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.4970 - accuracy: 0.8879 - val_loss: 0.8307 - val_accuracy: 0.8008
#
# Epoch 00045: val_loss improved from 0.90397 to 0.83072, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.3217 - accuracy: 0.9485 - val_loss: 0.8376 - val_accuracy: 0.7930
#
# Epoch 00046: val_loss did not improve from 0.83072
# Epoch 47/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.4181 - accuracy: 0.9127 - val_loss: 0.8393 - val_accuracy: 0.7852
#
# Epoch 00047: val_loss did not improve from 0.83072
# Epoch 48/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.3578 - accuracy: 0.9343 - val_loss: 0.7770 - val_accuracy: 0.8047
#
# Epoch 00048: val_loss improved from 0.83072 to 0.77700, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.5388 - accuracy: 0.8745 - val_loss: 0.8382 - val_accuracy: 0.7969
#
# Epoch 00049: val_loss did not improve from 0.77700
# Epoch 50/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.4657 - accuracy: 0.8957 - val_loss: 0.8556 - val_accuracy: 0.8086
#
# Epoch 00050: val_loss did not improve from 0.77700
# Epoch 51/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.3576 - accuracy: 0.9320 - val_loss: 0.8712 - val_accuracy: 0.7852
#
# Epoch 00051: val_loss did not improve from 0.77700
# Epoch 52/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.3770 - accuracy: 0.9214 - val_loss: 0.8119 - val_accuracy: 0.8086
#
# Epoch 00052: val_loss did not improve from 0.77700
# Epoch 53/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.3723 - accuracy: 0.9196 - val_loss: 0.8020 - val_accuracy: 0.7891
#
# Epoch 00053: val_loss did not improve from 0.77700
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 54/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.3982 - accuracy: 0.9113 - val_loss: 0.7643 - val_accuracy: 0.8398
#
# Epoch 00054: val_loss improved from 0.77700 to 0.76432, saving model to ./save/cnn_gru_best.hdf5
# Epoch 55/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.3463 - accuracy: 0.9233 - val_loss: 0.8312 - val_accuracy: 0.8008
#
# Epoch 00055: val_loss did not improve from 0.76432
# Epoch 56/2000
# 34/34 [==============================] - 13s 380ms/step - loss: 0.3466 - accuracy: 0.9297 - val_loss: 0.7632 - val_accuracy: 0.8164
#
# Epoch 00056: val_loss improved from 0.76432 to 0.76318, saving model to ./save/cnn_gru_best.hdf5
# Epoch 57/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2973 - accuracy: 0.9421 - val_loss: 0.8034 - val_accuracy: 0.8203
#
# Epoch 00057: val_loss did not improve from 0.76318
# Epoch 58/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.3446 - accuracy: 0.9265 - val_loss: 0.7233 - val_accuracy: 0.8047
#
# Epoch 00058: val_loss improved from 0.76318 to 0.72329, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.3034 - accuracy: 0.9366 - val_loss: 0.7330 - val_accuracy: 0.8125
#
# Epoch 00059: val_loss did not improve from 0.72329
# Epoch 60/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.3255 - accuracy: 0.9278 - val_loss: 0.7284 - val_accuracy: 0.8281
#
# Epoch 00060: val_loss did not improve from 0.72329
# Epoch 61/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.3481 - accuracy: 0.9196 - val_loss: 0.7549 - val_accuracy: 0.8242
#
# Epoch 00061: val_loss did not improve from 0.72329
# Epoch 62/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.3371 - accuracy: 0.9301 - val_loss: 0.7479 - val_accuracy: 0.8281
#
# Epoch 00062: val_loss did not improve from 0.72329
# Epoch 63/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2859 - accuracy: 0.9453 - val_loss: 0.7725 - val_accuracy: 0.8320
#
# Epoch 00063: val_loss did not improve from 0.72329
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 64/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.3140 - accuracy: 0.9301 - val_loss: 0.6812 - val_accuracy: 0.8398
#
# Epoch 00064: val_loss improved from 0.72329 to 0.68122, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2643 - accuracy: 0.9513 - val_loss: 0.7271 - val_accuracy: 0.8164
#
# Epoch 00065: val_loss did not improve from 0.68122
# Epoch 66/2000
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2854 - accuracy: 0.9384 - val_loss: 0.7686 - val_accuracy: 0.8125
#
# Epoch 00066: val_loss did not improve from 0.68122
# Epoch 67/2000
# 34/34 [==============================] - 13s 389ms/step - loss: 0.2302 - accuracy: 0.9586 - val_loss: 0.7006 - val_accuracy: 0.8281
#
# Epoch 00067: val_loss did not improve from 0.68122
# Epoch 68/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2460 - accuracy: 0.9508 - val_loss: 0.7503 - val_accuracy: 0.8203
#
# Epoch 00068: val_loss did not improve from 0.68122
# Epoch 69/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2652 - accuracy: 0.9476 - val_loss: 0.7156 - val_accuracy: 0.8320
#
# Epoch 00069: val_loss did not improve from 0.68122
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 70/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2948 - accuracy: 0.9357 - val_loss: 0.7518 - val_accuracy: 0.8164
#
# Epoch 00070: val_loss did not improve from 0.68122
# Epoch 71/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2767 - accuracy: 0.9416 - val_loss: 0.7260 - val_accuracy: 0.8359
#
# Epoch 00071: val_loss did not improve from 0.68122
# Epoch 72/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2575 - accuracy: 0.9458 - val_loss: 0.7368 - val_accuracy: 0.8359
#
# Epoch 00072: val_loss did not improve from 0.68122
# Epoch 73/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2775 - accuracy: 0.9324 - val_loss: 0.7458 - val_accuracy: 0.8242
#
# Epoch 00073: val_loss did not improve from 0.68122
# Epoch 74/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2670 - accuracy: 0.9494 - val_loss: 0.7361 - val_accuracy: 0.8281
#
# Epoch 00074: val_loss did not improve from 0.68122
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 75/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2119 - accuracy: 0.9609 - val_loss: 0.6984 - val_accuracy: 0.8359
#
# Epoch 00075: val_loss did not improve from 0.68122
# Epoch 76/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2458 - accuracy: 0.9481 - val_loss: 0.6700 - val_accuracy: 0.8320
#
# Epoch 00076: val_loss improved from 0.68122 to 0.67001, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2199 - accuracy: 0.9596 - val_loss: 0.7194 - val_accuracy: 0.8242
#
# Epoch 00077: val_loss did not improve from 0.67001
# Epoch 78/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2312 - accuracy: 0.9545 - val_loss: 0.7334 - val_accuracy: 0.8281
#
# Epoch 00078: val_loss did not improve from 0.67001
# Epoch 79/2000
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3105 - accuracy: 0.9265 - val_loss: 0.7452 - val_accuracy: 0.8086
#
# Epoch 00079: val_loss did not improve from 0.67001
# Epoch 80/2000
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2495 - accuracy: 0.9476 - val_loss: 0.7138 - val_accuracy: 0.8281
#
# Epoch 00080: val_loss did not improve from 0.67001
# Epoch 81/2000
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2486 - accuracy: 0.9485 - val_loss: 0.6981 - val_accuracy: 0.8320
#
# Epoch 00081: val_loss did not improve from 0.67001
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 82/2000
# 34/34 [==============================] - 13s 390ms/step - loss: 0.2346 - accuracy: 0.9536 - val_loss: 0.6678 - val_accuracy: 0.8242
#
# Epoch 00082: val_loss improved from 0.67001 to 0.66780, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.1836 - accuracy: 0.9706 - val_loss: 0.6923 - val_accuracy: 0.8281
#
# Epoch 00083: val_loss did not improve from 0.66780
# Epoch 84/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.1975 - accuracy: 0.9660 - val_loss: 0.7144 - val_accuracy: 0.8164
#
# Epoch 00084: val_loss did not improve from 0.66780
# Epoch 85/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.1887 - accuracy: 0.9688 - val_loss: 0.7035 - val_accuracy: 0.8242
#
# Epoch 00085: val_loss did not improve from 0.66780
# Epoch 86/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.1765 - accuracy: 0.9710 - val_loss: 0.7076 - val_accuracy: 0.8281
#
# Epoch 00086: val_loss did not improve from 0.66780
# Epoch 87/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2750 - accuracy: 0.9380 - val_loss: 0.7173 - val_accuracy: 0.8320
#
# Epoch 00087: val_loss did not improve from 0.66780
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 88/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2578 - accuracy: 0.9449 - val_loss: 0.7197 - val_accuracy: 0.8281
#
# Epoch 00088: val_loss did not improve from 0.66780
# Epoch 89/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2218 - accuracy: 0.9559 - val_loss: 0.7151 - val_accuracy: 0.8281
#
# Epoch 00089: val_loss did not improve from 0.66780
# Epoch 90/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2163 - accuracy: 0.9586 - val_loss: 0.6913 - val_accuracy: 0.8281
#
# Epoch 00090: val_loss did not improve from 0.66780
# Epoch 91/2000
# 34/34 [==============================] - 13s 389ms/step - loss: 0.2330 - accuracy: 0.9517 - val_loss: 0.7034 - val_accuracy: 0.8164
#
# Epoch 00091: val_loss did not improve from 0.66780
# Epoch 92/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2116 - accuracy: 0.9646 - val_loss: 0.6987 - val_accuracy: 0.8203
#
# Epoch 00092: val_loss did not improve from 0.66780
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 93/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2522 - accuracy: 0.9481 - val_loss: 0.6918 - val_accuracy: 0.8242
#
# Epoch 00093: val_loss did not improve from 0.66780
# Epoch 94/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.1912 - accuracy: 0.9665 - val_loss: 0.7114 - val_accuracy: 0.8203
#
# Epoch 00094: val_loss did not improve from 0.66780
# Epoch 95/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2127 - accuracy: 0.9591 - val_loss: 0.7116 - val_accuracy: 0.8203
#
# Epoch 00095: val_loss did not improve from 0.66780
# Epoch 96/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2544 - accuracy: 0.9439 - val_loss: 0.6705 - val_accuracy: 0.8281
#
# Epoch 00096: val_loss did not improve from 0.66780
# Epoch 97/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2761 - accuracy: 0.9453 - val_loss: 0.7182 - val_accuracy: 0.8164
#
# Epoch 00097: val_loss did not improve from 0.66780
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 98/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2143 - accuracy: 0.9609 - val_loss: 0.6646 - val_accuracy: 0.8398
#
# Epoch 00098: val_loss improved from 0.66780 to 0.66459, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2468 - accuracy: 0.9494 - val_loss: 0.6841 - val_accuracy: 0.8359
#
# Epoch 00099: val_loss did not improve from 0.66459
# Epoch 100/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.1998 - accuracy: 0.9596 - val_loss: 0.6667 - val_accuracy: 0.8320
#
# Epoch 00100: val_loss did not improve from 0.66459
# Epoch 101/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2200 - accuracy: 0.9596 - val_loss: 0.7199 - val_accuracy: 0.8203
#
# Epoch 00101: val_loss did not improve from 0.66459
# Epoch 102/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2320 - accuracy: 0.9559 - val_loss: 0.6589 - val_accuracy: 0.8281
#
# Epoch 00102: val_loss improved from 0.66459 to 0.65894, saving model to ./save/cnn_gru_best.hdf5
# Epoch 103/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2534 - accuracy: 0.9485 - val_loss: 0.6936 - val_accuracy: 0.8242
#
# Epoch 00103: val_loss did not improve from 0.65894
# Epoch 104/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.1958 - accuracy: 0.9678 - val_loss: 0.6957 - val_accuracy: 0.8242
#
# Epoch 00104: val_loss did not improve from 0.65894
# Epoch 105/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2283 - accuracy: 0.9577 - val_loss: 0.6721 - val_accuracy: 0.8359
#
# Epoch 00105: val_loss did not improve from 0.65894
# Epoch 106/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2163 - accuracy: 0.9605 - val_loss: 0.6200 - val_accuracy: 0.8398
#
# Epoch 00106: val_loss improved from 0.65894 to 0.62001, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.1911 - accuracy: 0.9665 - val_loss: 0.6429 - val_accuracy: 0.8359
#
# Epoch 00107: val_loss did not improve from 0.62001
# Epoch 108/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2139 - accuracy: 0.9591 - val_loss: 0.6301 - val_accuracy: 0.8398
#
# Epoch 00108: val_loss did not improve from 0.62001
# Epoch 109/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2329 - accuracy: 0.9531 - val_loss: 0.6409 - val_accuracy: 0.8359
#
# Epoch 00109: val_loss did not improve from 0.62001
# Epoch 110/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2127 - accuracy: 0.9596 - val_loss: 0.6848 - val_accuracy: 0.8320
#
# Epoch 00110: val_loss did not improve from 0.62001
# Epoch 111/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2700 - accuracy: 0.9426 - val_loss: 0.7034 - val_accuracy: 0.8242
#
# Epoch 00111: val_loss did not improve from 0.62001
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 112/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2122 - accuracy: 0.9577 - val_loss: 0.7046 - val_accuracy: 0.8320
#
# Epoch 00112: val_loss did not improve from 0.62001
# Epoch 113/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2254 - accuracy: 0.9545 - val_loss: 0.6725 - val_accuracy: 0.8281
#
# Epoch 00113: val_loss did not improve from 0.62001
# Epoch 114/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2465 - accuracy: 0.9485 - val_loss: 0.7174 - val_accuracy: 0.8164
#
# Epoch 00114: val_loss did not improve from 0.62001
# Epoch 115/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2143 - accuracy: 0.9582 - val_loss: 0.6746 - val_accuracy: 0.8320
#
# Epoch 00115: val_loss did not improve from 0.62001
# Epoch 116/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2145 - accuracy: 0.9550 - val_loss: 0.6929 - val_accuracy: 0.8242
#
# Epoch 00116: val_loss did not improve from 0.62001
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 117/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2475 - accuracy: 0.9462 - val_loss: 0.6919 - val_accuracy: 0.8242
#
# Epoch 00117: val_loss did not improve from 0.62001
# Epoch 118/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2035 - accuracy: 0.9605 - val_loss: 0.6902 - val_accuracy: 0.8359
#
# Epoch 00118: val_loss did not improve from 0.62001
# Epoch 119/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2295 - accuracy: 0.9568 - val_loss: 0.7131 - val_accuracy: 0.8281
#
# Epoch 00119: val_loss did not improve from 0.62001
# Epoch 120/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2674 - accuracy: 0.9449 - val_loss: 0.7213 - val_accuracy: 0.8164
#
# Epoch 00120: val_loss did not improve from 0.62001
# Epoch 121/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2558 - accuracy: 0.9481 - val_loss: 0.6976 - val_accuracy: 0.8164
#
# Epoch 00121: val_loss did not improve from 0.62001
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 122/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2007 - accuracy: 0.9632 - val_loss: 0.6791 - val_accuracy: 0.8398
#
# Epoch 00122: val_loss did not improve from 0.62001
# Epoch 123/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2375 - accuracy: 0.9462 - val_loss: 0.6934 - val_accuracy: 0.8281
#
# Epoch 00123: val_loss did not improve from 0.62001
# Epoch 124/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2315 - accuracy: 0.9513 - val_loss: 0.6982 - val_accuracy: 0.8281
#
# Epoch 00124: val_loss did not improve from 0.62001
# Epoch 125/2000
# 34/34 [==============================] - 13s 385ms/step - loss: 0.2390 - accuracy: 0.9540 - val_loss: 0.7110 - val_accuracy: 0.8203
#
# Epoch 00125: val_loss did not improve from 0.62001
# Epoch 126/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2327 - accuracy: 0.9527 - val_loss: 0.7074 - val_accuracy: 0.8242
#
# Epoch 00126: val_loss did not improve from 0.62001
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 127/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2584 - accuracy: 0.9476 - val_loss: 0.7068 - val_accuracy: 0.8203
#
# Epoch 00127: val_loss did not improve from 0.62001
# Epoch 128/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.1961 - accuracy: 0.9609 - val_loss: 0.6592 - val_accuracy: 0.8398
#
# Epoch 00128: val_loss did not improve from 0.62001
# Epoch 129/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.2349 - accuracy: 0.9481 - val_loss: 0.7188 - val_accuracy: 0.8203
#
# Epoch 00129: val_loss did not improve from 0.62001
# Epoch 130/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.1897 - accuracy: 0.9660 - val_loss: 0.7165 - val_accuracy: 0.8203
#
# Epoch 00130: val_loss did not improve from 0.62001
# Epoch 131/2000
# 34/34 [==============================] - 13s 381ms/step - loss: 0.2364 - accuracy: 0.9476 - val_loss: 0.6972 - val_accuracy: 0.8281
#
# Epoch 00131: val_loss did not improve from 0.62001
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 132/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2394 - accuracy: 0.9508 - val_loss: 0.6875 - val_accuracy: 0.8359
#
# Epoch 00132: val_loss did not improve from 0.62001
# Epoch 133/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2386 - accuracy: 0.9554 - val_loss: 0.6956 - val_accuracy: 0.8242
#
# Epoch 00133: val_loss did not improve from 0.62001
# Epoch 134/2000
# 34/34 [==============================] - 13s 382ms/step - loss: 0.2338 - accuracy: 0.9545 - val_loss: 0.6939 - val_accuracy: 0.8242
#
# Epoch 00134: val_loss did not improve from 0.62001
# Epoch 135/2000
# 34/34 [==============================] - 13s 383ms/step - loss: 0.2321 - accuracy: 0.9563 - val_loss: 0.7004 - val_accuracy: 0.8203
#
# Epoch 00135: val_loss did not improve from 0.62001
# Epoch 136/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.2297 - accuracy: 0.9573 - val_loss: 0.7093 - val_accuracy: 0.8242
#
# Epoch 00136: val_loss did not improve from 0.62001
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6039 - accuracy: 0.8464
# [0.603855550289154, 0.8464000225067139]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
