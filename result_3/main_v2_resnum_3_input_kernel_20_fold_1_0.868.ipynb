# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset #, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 1
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      1460        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1020)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,270,331
# Trainable params: 2,263,671
# Non-trainable params: 6,660
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 58s 551ms/step - loss: 15.2423 - accuracy: 0.3989 - val_loss: 11.5356 - val_accuracy: 0.4531
#
# Epoch 00001: val_loss improved from inf to 11.53559, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 8.3429 - accuracy: 0.5813 - val_loss: 7.6155 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 11.53559 to 7.61545, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 4.9113 - accuracy: 0.6507 - val_loss: 6.1758 - val_accuracy: 0.4531
#
# Epoch 00003: val_loss improved from 7.61545 to 6.17579, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 3.3657 - accuracy: 0.6438 - val_loss: 5.2949 - val_accuracy: 0.4531
#
# Epoch 00004: val_loss improved from 6.17579 to 5.29490, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 2.3591 - accuracy: 0.6774 - val_loss: 4.7317 - val_accuracy: 0.4531
#
# Epoch 00005: val_loss improved from 5.29490 to 4.73166, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 1.8690 - accuracy: 0.7022 - val_loss: 4.8670 - val_accuracy: 0.4688
#
# Epoch 00006: val_loss did not improve from 4.73166
# Epoch 7/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 1.4826 - accuracy: 0.7275 - val_loss: 4.7959 - val_accuracy: 0.4570
#
# Epoch 00007: val_loss did not improve from 4.73166
# Epoch 8/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 1.3599 - accuracy: 0.7390 - val_loss: 4.9670 - val_accuracy: 0.2773
#
# Epoch 00008: val_loss did not improve from 4.73166
# Epoch 9/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 1.1347 - accuracy: 0.7909 - val_loss: 4.8688 - val_accuracy: 0.1875
#
# Epoch 00009: val_loss did not improve from 4.73166
# Epoch 10/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 1.2523 - accuracy: 0.7482 - val_loss: 5.9204 - val_accuracy: 0.1719
#
# Epoch 00010: val_loss did not improve from 4.73166
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 1.0473 - accuracy: 0.7932 - val_loss: 4.7251 - val_accuracy: 0.3008
#
# Epoch 00011: val_loss improved from 4.73166 to 4.72515, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 1.0211 - accuracy: 0.7835 - val_loss: 4.3459 - val_accuracy: 0.3711
#
# Epoch 00012: val_loss improved from 4.72515 to 4.34585, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.9027 - accuracy: 0.8102 - val_loss: 4.0774 - val_accuracy: 0.3477
#
# Epoch 00013: val_loss improved from 4.34585 to 4.07741, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.8577 - accuracy: 0.8139 - val_loss: 3.2792 - val_accuracy: 0.4688
#
# Epoch 00014: val_loss improved from 4.07741 to 3.27917, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.9100 - accuracy: 0.7987 - val_loss: 3.2345 - val_accuracy: 0.5156
#
# Epoch 00015: val_loss improved from 3.27917 to 3.23447, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.8668 - accuracy: 0.8153 - val_loss: 2.1203 - val_accuracy: 0.5938
#
# Epoch 00016: val_loss improved from 3.23447 to 2.12034, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.8529 - accuracy: 0.8116 - val_loss: 1.7304 - val_accuracy: 0.6094
#
# Epoch 00017: val_loss improved from 2.12034 to 1.73040, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.7727 - accuracy: 0.8254 - val_loss: 1.5286 - val_accuracy: 0.6719
#
# Epoch 00018: val_loss improved from 1.73040 to 1.52855, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.8164 - accuracy: 0.8189 - val_loss: 1.6891 - val_accuracy: 0.6211
#
# Epoch 00019: val_loss did not improve from 1.52855
# Epoch 20/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.9028 - accuracy: 0.7927 - val_loss: 1.1780 - val_accuracy: 0.7109
#
# Epoch 00020: val_loss improved from 1.52855 to 1.17796, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.8156 - accuracy: 0.8281 - val_loss: 1.0175 - val_accuracy: 0.7656
#
# Epoch 00021: val_loss improved from 1.17796 to 1.01747, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.6904 - accuracy: 0.8626 - val_loss: 1.1119 - val_accuracy: 0.7500
#
# Epoch 00022: val_loss did not improve from 1.01747
# Epoch 23/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.7525 - accuracy: 0.8405 - val_loss: 1.0357 - val_accuracy: 0.7500
#
# Epoch 00023: val_loss did not improve from 1.01747
# Epoch 24/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.7168 - accuracy: 0.8396 - val_loss: 1.0374 - val_accuracy: 0.8008
#
# Epoch 00024: val_loss did not improve from 1.01747
# Epoch 25/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.6713 - accuracy: 0.8552 - val_loss: 0.9242 - val_accuracy: 0.7812
#
# Epoch 00025: val_loss improved from 1.01747 to 0.92422, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.7658 - accuracy: 0.8415 - val_loss: 0.9214 - val_accuracy: 0.8047
#
# Epoch 00026: val_loss improved from 0.92422 to 0.92145, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.7096 - accuracy: 0.8493 - val_loss: 1.0234 - val_accuracy: 0.7852
#
# Epoch 00027: val_loss did not improve from 0.92145
# Epoch 28/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.7381 - accuracy: 0.8410 - val_loss: 0.9346 - val_accuracy: 0.8008
#
# Epoch 00028: val_loss did not improve from 0.92145
# Epoch 29/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.6863 - accuracy: 0.8612 - val_loss: 0.9436 - val_accuracy: 0.7852
#
# Epoch 00029: val_loss did not improve from 0.92145
# Epoch 30/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.6545 - accuracy: 0.8626 - val_loss: 0.9311 - val_accuracy: 0.7930
#
# Epoch 00030: val_loss did not improve from 0.92145
# Epoch 31/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.7253 - accuracy: 0.8456 - val_loss: 1.1186 - val_accuracy: 0.7227
#
# Epoch 00031: val_loss did not improve from 0.92145
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 32/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.6835 - accuracy: 0.8543 - val_loss: 0.8814 - val_accuracy: 0.8242
#
# Epoch 00032: val_loss improved from 0.92145 to 0.88140, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.5780 - accuracy: 0.8782 - val_loss: 0.8382 - val_accuracy: 0.8164
#
# Epoch 00033: val_loss improved from 0.88140 to 0.83815, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.4970 - accuracy: 0.8994 - val_loss: 0.9030 - val_accuracy: 0.8047
#
# Epoch 00034: val_loss did not improve from 0.83815
# Epoch 35/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.5449 - accuracy: 0.8860 - val_loss: 0.8037 - val_accuracy: 0.8203
#
# Epoch 00035: val_loss improved from 0.83815 to 0.80371, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.5023 - accuracy: 0.9007 - val_loss: 0.8854 - val_accuracy: 0.8164
#
# Epoch 00036: val_loss did not improve from 0.80371
# Epoch 37/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.5402 - accuracy: 0.8837 - val_loss: 0.8283 - val_accuracy: 0.8203
#
# Epoch 00037: val_loss did not improve from 0.80371
# Epoch 38/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.6104 - accuracy: 0.8658 - val_loss: 0.9424 - val_accuracy: 0.8008
#
# Epoch 00038: val_loss did not improve from 0.80371
# Epoch 39/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.5297 - accuracy: 0.8879 - val_loss: 0.9387 - val_accuracy: 0.7930
#
# Epoch 00039: val_loss did not improve from 0.80371
# Epoch 40/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.5197 - accuracy: 0.8879 - val_loss: 0.8069 - val_accuracy: 0.8086
#
# Epoch 00040: val_loss did not improve from 0.80371
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 41/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.4410 - accuracy: 0.9030 - val_loss: 0.7772 - val_accuracy: 0.8477
#
# Epoch 00041: val_loss improved from 0.80371 to 0.77724, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.4560 - accuracy: 0.9118 - val_loss: 0.7502 - val_accuracy: 0.8398
#
# Epoch 00042: val_loss improved from 0.77724 to 0.75021, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.4102 - accuracy: 0.9173 - val_loss: 0.7329 - val_accuracy: 0.8320
#
# Epoch 00043: val_loss improved from 0.75021 to 0.73293, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.4672 - accuracy: 0.9021 - val_loss: 0.7235 - val_accuracy: 0.8359
#
# Epoch 00044: val_loss improved from 0.73293 to 0.72349, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3041 - accuracy: 0.9527 - val_loss: 0.7123 - val_accuracy: 0.8438
#
# Epoch 00045: val_loss improved from 0.72349 to 0.71229, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.4234 - accuracy: 0.9085 - val_loss: 0.7425 - val_accuracy: 0.8281
#
# Epoch 00046: val_loss did not improve from 0.71229
# Epoch 47/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.3635 - accuracy: 0.9223 - val_loss: 0.7859 - val_accuracy: 0.8125
#
# Epoch 00047: val_loss did not improve from 0.71229
# Epoch 48/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3901 - accuracy: 0.9256 - val_loss: 0.7291 - val_accuracy: 0.8164
#
# Epoch 00048: val_loss did not improve from 0.71229
# Epoch 49/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.3253 - accuracy: 0.9380 - val_loss: 0.7206 - val_accuracy: 0.8359
#
# Epoch 00049: val_loss did not improve from 0.71229
# Epoch 50/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.3757 - accuracy: 0.9219 - val_loss: 0.7513 - val_accuracy: 0.8281
#
# Epoch 00050: val_loss did not improve from 0.71229
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 51/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.4043 - accuracy: 0.9099 - val_loss: 0.7279 - val_accuracy: 0.8359
#
# Epoch 00051: val_loss did not improve from 0.71229
# Epoch 52/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3081 - accuracy: 0.9435 - val_loss: 0.6935 - val_accuracy: 0.8398
#
# Epoch 00052: val_loss improved from 0.71229 to 0.69347, saving model to ./save/cnn_gru_best.hdf5
# Epoch 53/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.4125 - accuracy: 0.9099 - val_loss: 0.7140 - val_accuracy: 0.8242
#
# Epoch 00053: val_loss did not improve from 0.69347
# Epoch 54/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3590 - accuracy: 0.9265 - val_loss: 0.6861 - val_accuracy: 0.8359
#
# Epoch 00054: val_loss improved from 0.69347 to 0.68607, saving model to ./save/cnn_gru_best.hdf5
# Epoch 55/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.3651 - accuracy: 0.9223 - val_loss: 0.7079 - val_accuracy: 0.8555
#
# Epoch 00055: val_loss did not improve from 0.68607
# Epoch 56/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.3735 - accuracy: 0.9182 - val_loss: 0.6978 - val_accuracy: 0.8320
#
# Epoch 00056: val_loss did not improve from 0.68607
# Epoch 57/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3332 - accuracy: 0.9283 - val_loss: 0.6901 - val_accuracy: 0.8320
#
# Epoch 00057: val_loss did not improve from 0.68607
# Epoch 58/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3125 - accuracy: 0.9407 - val_loss: 0.6519 - val_accuracy: 0.8438
#
# Epoch 00058: val_loss improved from 0.68607 to 0.65191, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.3576 - accuracy: 0.9191 - val_loss: 0.6881 - val_accuracy: 0.8281
#
# Epoch 00059: val_loss did not improve from 0.65191
# Epoch 60/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.3546 - accuracy: 0.9210 - val_loss: 0.6858 - val_accuracy: 0.8359
#
# Epoch 00060: val_loss did not improve from 0.65191
# Epoch 61/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2797 - accuracy: 0.9485 - val_loss: 0.6613 - val_accuracy: 0.8555
#
# Epoch 00061: val_loss did not improve from 0.65191
# Epoch 62/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3709 - accuracy: 0.9205 - val_loss: 0.6660 - val_accuracy: 0.8516
#
# Epoch 00062: val_loss did not improve from 0.65191
# Epoch 63/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3138 - accuracy: 0.9352 - val_loss: 0.6558 - val_accuracy: 0.8477
#
# Epoch 00063: val_loss did not improve from 0.65191
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 64/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3236 - accuracy: 0.9389 - val_loss: 0.6792 - val_accuracy: 0.8438
#
# Epoch 00064: val_loss did not improve from 0.65191
# Epoch 65/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1997 - accuracy: 0.9720 - val_loss: 0.6503 - val_accuracy: 0.8516
#
# Epoch 00065: val_loss improved from 0.65191 to 0.65035, saving model to ./save/cnn_gru_best.hdf5
# Epoch 66/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2865 - accuracy: 0.9458 - val_loss: 0.6466 - val_accuracy: 0.8477
#
# Epoch 00066: val_loss improved from 0.65035 to 0.64659, saving model to ./save/cnn_gru_best.hdf5
# Epoch 67/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2667 - accuracy: 0.9458 - val_loss: 0.6701 - val_accuracy: 0.8633
#
# Epoch 00067: val_loss did not improve from 0.64659
# Epoch 68/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2786 - accuracy: 0.9476 - val_loss: 0.6821 - val_accuracy: 0.8398
#
# Epoch 00068: val_loss did not improve from 0.64659
# Epoch 69/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2881 - accuracy: 0.9398 - val_loss: 0.6132 - val_accuracy: 0.8594
#
# Epoch 00069: val_loss improved from 0.64659 to 0.61321, saving model to ./save/cnn_gru_best.hdf5
# Epoch 70/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.3793 - accuracy: 0.9067 - val_loss: 0.6772 - val_accuracy: 0.8398
#
# Epoch 00070: val_loss did not improve from 0.61321
# Epoch 71/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2780 - accuracy: 0.9439 - val_loss: 0.6651 - val_accuracy: 0.8477
#
# Epoch 00071: val_loss did not improve from 0.61321
# Epoch 72/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2958 - accuracy: 0.9375 - val_loss: 0.6478 - val_accuracy: 0.8359
#
# Epoch 00072: val_loss did not improve from 0.61321
# Epoch 73/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2811 - accuracy: 0.9430 - val_loss: 0.6502 - val_accuracy: 0.8672
#
# Epoch 00073: val_loss did not improve from 0.61321
# Epoch 74/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.3219 - accuracy: 0.9361 - val_loss: 0.6502 - val_accuracy: 0.8398
#
# Epoch 00074: val_loss did not improve from 0.61321
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 75/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2937 - accuracy: 0.9407 - val_loss: 0.6480 - val_accuracy: 0.8516
#
# Epoch 00075: val_loss did not improve from 0.61321
# Epoch 76/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2490 - accuracy: 0.9513 - val_loss: 0.6537 - val_accuracy: 0.8359
#
# Epoch 00076: val_loss did not improve from 0.61321
# Epoch 77/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2412 - accuracy: 0.9577 - val_loss: 0.6285 - val_accuracy: 0.8516
#
# Epoch 00077: val_loss did not improve from 0.61321
# Epoch 78/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2771 - accuracy: 0.9449 - val_loss: 0.6352 - val_accuracy: 0.8477
#
# Epoch 00078: val_loss did not improve from 0.61321
# Epoch 79/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3188 - accuracy: 0.9265 - val_loss: 0.6569 - val_accuracy: 0.8477
#
# Epoch 00079: val_loss did not improve from 0.61321
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 80/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2247 - accuracy: 0.9665 - val_loss: 0.5928 - val_accuracy: 0.8516
#
# Epoch 00080: val_loss improved from 0.61321 to 0.59281, saving model to ./save/cnn_gru_best.hdf5
# Epoch 81/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2378 - accuracy: 0.9600 - val_loss: 0.6371 - val_accuracy: 0.8398
#
# Epoch 00081: val_loss did not improve from 0.59281
# Epoch 82/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2352 - accuracy: 0.9600 - val_loss: 0.6502 - val_accuracy: 0.8438
#
# Epoch 00082: val_loss did not improve from 0.59281
# Epoch 83/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2387 - accuracy: 0.9573 - val_loss: 0.6568 - val_accuracy: 0.8477
#
# Epoch 00083: val_loss did not improve from 0.59281
# Epoch 84/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2786 - accuracy: 0.9421 - val_loss: 0.6320 - val_accuracy: 0.8477
#
# Epoch 00084: val_loss did not improve from 0.59281
# Epoch 85/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2190 - accuracy: 0.9628 - val_loss: 0.6475 - val_accuracy: 0.8477
#
# Epoch 00085: val_loss did not improve from 0.59281
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 86/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2073 - accuracy: 0.9651 - val_loss: 0.6055 - val_accuracy: 0.8594
#
# Epoch 00086: val_loss did not improve from 0.59281
# Epoch 87/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2285 - accuracy: 0.9559 - val_loss: 0.6360 - val_accuracy: 0.8516
#
# Epoch 00087: val_loss did not improve from 0.59281
# Epoch 88/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2930 - accuracy: 0.9366 - val_loss: 0.6344 - val_accuracy: 0.8516
#
# Epoch 00088: val_loss did not improve from 0.59281
# Epoch 89/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2610 - accuracy: 0.9435 - val_loss: 0.6516 - val_accuracy: 0.8438
#
# Epoch 00089: val_loss did not improve from 0.59281
# Epoch 90/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2737 - accuracy: 0.9421 - val_loss: 0.6467 - val_accuracy: 0.8398
#
# Epoch 00090: val_loss did not improve from 0.59281
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 91/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2331 - accuracy: 0.9582 - val_loss: 0.6424 - val_accuracy: 0.8398
#
# Epoch 00091: val_loss did not improve from 0.59281
# Epoch 92/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2006 - accuracy: 0.9710 - val_loss: 0.6472 - val_accuracy: 0.8398
#
# Epoch 00092: val_loss did not improve from 0.59281
# Epoch 93/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2061 - accuracy: 0.9678 - val_loss: 0.6484 - val_accuracy: 0.8438
#
# Epoch 00093: val_loss did not improve from 0.59281
# Epoch 94/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2643 - accuracy: 0.9504 - val_loss: 0.5787 - val_accuracy: 0.8516
#
# Epoch 00094: val_loss improved from 0.59281 to 0.57875, saving model to ./save/cnn_gru_best.hdf5
# Epoch 95/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2058 - accuracy: 0.9692 - val_loss: 0.6431 - val_accuracy: 0.8438
#
# Epoch 00095: val_loss did not improve from 0.57875
# Epoch 96/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2333 - accuracy: 0.9582 - val_loss: 0.6480 - val_accuracy: 0.8477
#
# Epoch 00096: val_loss did not improve from 0.57875
# Epoch 97/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2446 - accuracy: 0.9531 - val_loss: 0.6468 - val_accuracy: 0.8438
#
# Epoch 00097: val_loss did not improve from 0.57875
# Epoch 98/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2445 - accuracy: 0.9596 - val_loss: 0.6342 - val_accuracy: 0.8398
#
# Epoch 00098: val_loss did not improve from 0.57875
# Epoch 99/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2711 - accuracy: 0.9449 - val_loss: 0.6354 - val_accuracy: 0.8438
#
# Epoch 00099: val_loss did not improve from 0.57875
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 100/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2410 - accuracy: 0.9545 - val_loss: 0.5872 - val_accuracy: 0.8477
#
# Epoch 00100: val_loss did not improve from 0.57875
# Epoch 101/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2968 - accuracy: 0.9384 - val_loss: 0.6373 - val_accuracy: 0.8398
#
# Epoch 00101: val_loss did not improve from 0.57875
# Epoch 102/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2479 - accuracy: 0.9494 - val_loss: 0.6388 - val_accuracy: 0.8398
#
# Epoch 00102: val_loss did not improve from 0.57875
# Epoch 103/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.1970 - accuracy: 0.9669 - val_loss: 0.6284 - val_accuracy: 0.8398
#
# Epoch 00103: val_loss did not improve from 0.57875
# Epoch 104/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2536 - accuracy: 0.9540 - val_loss: 0.6504 - val_accuracy: 0.8398
#
# Epoch 00104: val_loss did not improve from 0.57875
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 105/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2639 - accuracy: 0.9494 - val_loss: 0.6507 - val_accuracy: 0.8359
#
# Epoch 00105: val_loss did not improve from 0.57875
# Epoch 106/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2600 - accuracy: 0.9531 - val_loss: 0.5643 - val_accuracy: 0.8398
#
# Epoch 00106: val_loss improved from 0.57875 to 0.56432, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2491 - accuracy: 0.9550 - val_loss: 0.6316 - val_accuracy: 0.8438
#
# Epoch 00107: val_loss did not improve from 0.56432
# Epoch 108/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2228 - accuracy: 0.9573 - val_loss: 0.6474 - val_accuracy: 0.8398
#
# Epoch 00108: val_loss did not improve from 0.56432
# Epoch 109/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2407 - accuracy: 0.9568 - val_loss: 0.6414 - val_accuracy: 0.8359
#
# Epoch 00109: val_loss did not improve from 0.56432
# Epoch 110/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2312 - accuracy: 0.9573 - val_loss: 0.5892 - val_accuracy: 0.8438
#
# Epoch 00110: val_loss did not improve from 0.56432
# Epoch 111/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2281 - accuracy: 0.9609 - val_loss: 0.6364 - val_accuracy: 0.8438
#
# Epoch 00111: val_loss did not improve from 0.56432
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 112/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2200 - accuracy: 0.9651 - val_loss: 0.6240 - val_accuracy: 0.8555
#
# Epoch 00112: val_loss did not improve from 0.56432
# Epoch 113/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2742 - accuracy: 0.9472 - val_loss: 0.5901 - val_accuracy: 0.8438
#
# Epoch 00113: val_loss did not improve from 0.56432
# Epoch 114/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2306 - accuracy: 0.9559 - val_loss: 0.6196 - val_accuracy: 0.8438
#
# Epoch 00114: val_loss did not improve from 0.56432
# Epoch 115/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2705 - accuracy: 0.9449 - val_loss: 0.6446 - val_accuracy: 0.8438
#
# Epoch 00115: val_loss did not improve from 0.56432
# Epoch 116/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2288 - accuracy: 0.9637 - val_loss: 0.6169 - val_accuracy: 0.8516
#
# Epoch 00116: val_loss did not improve from 0.56432
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 117/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2089 - accuracy: 0.9678 - val_loss: 0.6131 - val_accuracy: 0.8555
#
# Epoch 00117: val_loss did not improve from 0.56432
# Epoch 118/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.2128 - accuracy: 0.9642 - val_loss: 0.6522 - val_accuracy: 0.8359
#
# Epoch 00118: val_loss did not improve from 0.56432
# Epoch 119/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2722 - accuracy: 0.9476 - val_loss: 0.6239 - val_accuracy: 0.8438
#
# Epoch 00119: val_loss did not improve from 0.56432
# Epoch 120/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.2507 - accuracy: 0.9527 - val_loss: 0.6492 - val_accuracy: 0.8438
#
# Epoch 00120: val_loss did not improve from 0.56432
# Epoch 121/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2422 - accuracy: 0.9586 - val_loss: 0.6228 - val_accuracy: 0.8555
#
# Epoch 00121: val_loss did not improve from 0.56432
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 122/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.3006 - accuracy: 0.9283 - val_loss: 0.6386 - val_accuracy: 0.8438
#
# Epoch 00122: val_loss did not improve from 0.56432
# Epoch 123/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2330 - accuracy: 0.9600 - val_loss: 0.6494 - val_accuracy: 0.8398
#
# Epoch 00123: val_loss did not improve from 0.56432
# Epoch 124/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2173 - accuracy: 0.9642 - val_loss: 0.6299 - val_accuracy: 0.8477
#
# Epoch 00124: val_loss did not improve from 0.56432
# Epoch 125/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2532 - accuracy: 0.9508 - val_loss: 0.6526 - val_accuracy: 0.8320
#
# Epoch 00125: val_loss did not improve from 0.56432
# Epoch 126/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2786 - accuracy: 0.9416 - val_loss: 0.6594 - val_accuracy: 0.8320
#
# Epoch 00126: val_loss did not improve from 0.56432
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 127/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2454 - accuracy: 0.9545 - val_loss: 0.6099 - val_accuracy: 0.8516
#
# Epoch 00127: val_loss did not improve from 0.56432
# Epoch 128/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.1844 - accuracy: 0.9743 - val_loss: 0.6026 - val_accuracy: 0.8516
#
# Epoch 00128: val_loss did not improve from 0.56432
# Epoch 129/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2655 - accuracy: 0.9453 - val_loss: 0.6475 - val_accuracy: 0.8438
#
# Epoch 00129: val_loss did not improve from 0.56432
# Epoch 130/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2526 - accuracy: 0.9522 - val_loss: 0.6038 - val_accuracy: 0.8555
#
# Epoch 00130: val_loss did not improve from 0.56432
# Epoch 131/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.2081 - accuracy: 0.9665 - val_loss: 0.6480 - val_accuracy: 0.8477
#
# Epoch 00131: val_loss did not improve from 0.56432
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 132/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2231 - accuracy: 0.9591 - val_loss: 0.6363 - val_accuracy: 0.8477
#
# Epoch 00132: val_loss did not improve from 0.56432
# Epoch 133/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2652 - accuracy: 0.9490 - val_loss: 0.6443 - val_accuracy: 0.8477
#
# Epoch 00133: val_loss did not improve from 0.56432
# Epoch 134/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2786 - accuracy: 0.9421 - val_loss: 0.6403 - val_accuracy: 0.8477
#
# Epoch 00134: val_loss did not improve from 0.56432
# Epoch 135/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2786 - accuracy: 0.9357 - val_loss: 0.6384 - val_accuracy: 0.8477
#
# Epoch 00135: val_loss did not improve from 0.56432
# Epoch 136/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2426 - accuracy: 0.9550 - val_loss: 0.6592 - val_accuracy: 0.8359
#
# Epoch 00136: val_loss did not improve from 0.56432
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5365 - accuracy: 0.8688
# [0.5365173816680908, 0.8687999844551086]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
