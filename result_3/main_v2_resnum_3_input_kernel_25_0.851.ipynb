# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset #, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 25, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 25)      2275        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 25)      2275        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 25)      3625        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 25)      1825        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 25)      1825        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 25)      4525        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 25)      4525        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 25)      4525        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 12)      4332        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 25)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 25)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 25)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 25)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 25)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 25)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 25)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 25)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 12)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 25)      100         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 25)      100         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 25)      100         leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 25)      100         leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 25)      100         leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 25)      100         leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 25)      100         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 25)      100         leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 12)      48          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 50)      11550       batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 50)      11550       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 50)      11550       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 50)      11550       batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 50)      11550       batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 50)      11550       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 50)      11550       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 50)      11550       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 24)      2736        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 50)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 50)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 50)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 50)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 50)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 50)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 50)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 50)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 24)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 50)      200         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 50)      200         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 50)      200         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 50)      200         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 50)      200         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 50)      200         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 50)      200         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 50)      200         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 24)      96          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 150)     22650       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 150)     22650       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 150)     22650       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 150)     22650       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 150)     22650       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 150)     22650       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 150)     45150       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 150)     45150       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 72)      10440       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 150)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 150)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 150)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 150)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 150)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 150)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 150)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 150)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 72)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 150)     600         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 150)     600         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 150)     600         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 150)     600         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 150)     600         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 150)     600         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 150)     600         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 150)     600         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 72)      288         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 150)     135900      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 150)     135900      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 150)     135900      batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 150)     135900      batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 150)     135900      batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 150)     135900      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 150)     135900      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 150)     135900      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 72)      31536       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 150)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 150)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 150)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 150)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 150)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 150)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 150)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 150)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 72)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 150)     600         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 150)     600         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 150)     600         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 150)     600         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 150)     600         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 150)     600         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 150)     600         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 150)     600         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 72)      288         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1272)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      686940      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      686940      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 3,068,745
# Trainable params: 3,060,825
# Non-trainable params: 7,920
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 61s 660ms/step - loss: 15.0512 - accuracy: 0.4200 - val_loss: 11.4739 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 11.47388, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 8.2441 - accuracy: 0.5524 - val_loss: 8.0167 - val_accuracy: 0.0234
#
# Epoch 00002: val_loss improved from 11.47388 to 8.01669, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 4.7093 - accuracy: 0.6521 - val_loss: 6.9116 - val_accuracy: 0.0117
#
# Epoch 00003: val_loss improved from 8.01669 to 6.91163, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 3.2074 - accuracy: 0.6572 - val_loss: 6.1762 - val_accuracy: 0.0117
#
# Epoch 00004: val_loss improved from 6.91163 to 6.17621, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 2.3106 - accuracy: 0.6944 - val_loss: 5.3102 - val_accuracy: 0.0195
#
# Epoch 00005: val_loss improved from 6.17621 to 5.31019, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 1.8129 - accuracy: 0.7004 - val_loss: 5.9368 - val_accuracy: 0.0156
#
# Epoch 00006: val_loss did not improve from 5.31019
# Epoch 7/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 1.4704 - accuracy: 0.7381 - val_loss: 6.0714 - val_accuracy: 0.0195
#
# Epoch 00007: val_loss did not improve from 5.31019
# Epoch 8/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 1.2914 - accuracy: 0.7486 - val_loss: 5.9449 - val_accuracy: 0.0859
#
# Epoch 00008: val_loss did not improve from 5.31019
# Epoch 9/2000
# 34/34 [==============================] - 16s 472ms/step - loss: 1.1532 - accuracy: 0.7803 - val_loss: 5.7435 - val_accuracy: 0.1016
#
# Epoch 00009: val_loss did not improve from 5.31019
# Epoch 10/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 1.2011 - accuracy: 0.7560 - val_loss: 5.9716 - val_accuracy: 0.1719
#
# Epoch 00010: val_loss did not improve from 5.31019
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 1.0729 - accuracy: 0.7854 - val_loss: 5.9845 - val_accuracy: 0.0781
#
# Epoch 00011: val_loss did not improve from 5.31019
# Epoch 12/2000
# 34/34 [==============================] - 16s 472ms/step - loss: 0.9466 - accuracy: 0.8047 - val_loss: 4.5764 - val_accuracy: 0.2305
#
# Epoch 00012: val_loss improved from 5.31019 to 4.57639, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.8427 - accuracy: 0.8263 - val_loss: 3.5590 - val_accuracy: 0.3633
#
# Epoch 00013: val_loss improved from 4.57639 to 3.55901, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.8185 - accuracy: 0.8235 - val_loss: 3.3869 - val_accuracy: 0.3828
#
# Epoch 00014: val_loss improved from 3.55901 to 3.38693, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.8394 - accuracy: 0.8226 - val_loss: 4.1424 - val_accuracy: 0.2422
#
# Epoch 00015: val_loss did not improve from 3.38693
# Epoch 16/2000
# 34/34 [==============================] - 16s 472ms/step - loss: 0.8755 - accuracy: 0.8024 - val_loss: 2.4274 - val_accuracy: 0.5273
#
# Epoch 00016: val_loss improved from 3.38693 to 2.42745, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.9032 - accuracy: 0.8061 - val_loss: 2.4464 - val_accuracy: 0.4922
#
# Epoch 00017: val_loss did not improve from 2.42745
# Epoch 18/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.7504 - accuracy: 0.8428 - val_loss: 1.5854 - val_accuracy: 0.6562
#
# Epoch 00018: val_loss improved from 2.42745 to 1.58541, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.6766 - accuracy: 0.8594 - val_loss: 1.5848 - val_accuracy: 0.6562
#
# Epoch 00019: val_loss improved from 1.58541 to 1.58478, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.9156 - accuracy: 0.7987 - val_loss: 1.4412 - val_accuracy: 0.6953
#
# Epoch 00020: val_loss improved from 1.58478 to 1.44122, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.8002 - accuracy: 0.8212 - val_loss: 1.3647 - val_accuracy: 0.7227
#
# Epoch 00021: val_loss improved from 1.44122 to 1.36471, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.7499 - accuracy: 0.8401 - val_loss: 1.2237 - val_accuracy: 0.7188
#
# Epoch 00022: val_loss improved from 1.36471 to 1.22374, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.7439 - accuracy: 0.8529 - val_loss: 1.1219 - val_accuracy: 0.7266
#
# Epoch 00023: val_loss improved from 1.22374 to 1.12187, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.6924 - accuracy: 0.8552 - val_loss: 1.0649 - val_accuracy: 0.7500
#
# Epoch 00024: val_loss improved from 1.12187 to 1.06492, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.6535 - accuracy: 0.8608 - val_loss: 1.1303 - val_accuracy: 0.7578
#
# Epoch 00025: val_loss did not improve from 1.06492
# Epoch 26/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.6466 - accuracy: 0.8589 - val_loss: 1.0636 - val_accuracy: 0.7578
#
# Epoch 00026: val_loss improved from 1.06492 to 1.06356, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.6789 - accuracy: 0.8676 - val_loss: 1.2110 - val_accuracy: 0.7344
#
# Epoch 00027: val_loss did not improve from 1.06356
# Epoch 28/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.7233 - accuracy: 0.8428 - val_loss: 1.1120 - val_accuracy: 0.7383
#
# Epoch 00028: val_loss did not improve from 1.06356
# Epoch 29/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.7320 - accuracy: 0.8415 - val_loss: 1.2102 - val_accuracy: 0.7266
#
# Epoch 00029: val_loss did not improve from 1.06356
# Epoch 30/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.6256 - accuracy: 0.8778 - val_loss: 1.0660 - val_accuracy: 0.7266
#
# Epoch 00030: val_loss did not improve from 1.06356
# Epoch 31/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.6019 - accuracy: 0.8796 - val_loss: 1.0828 - val_accuracy: 0.7461
#
# Epoch 00031: val_loss did not improve from 1.06356
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 32/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.5418 - accuracy: 0.8980 - val_loss: 1.0251 - val_accuracy: 0.7656
#
# Epoch 00032: val_loss improved from 1.06356 to 1.02511, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.5184 - accuracy: 0.8971 - val_loss: 0.9778 - val_accuracy: 0.7695
#
# Epoch 00033: val_loss improved from 1.02511 to 0.97776, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.4619 - accuracy: 0.9062 - val_loss: 0.8965 - val_accuracy: 0.8047
#
# Epoch 00034: val_loss improved from 0.97776 to 0.89645, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.5008 - accuracy: 0.8934 - val_loss: 0.8804 - val_accuracy: 0.7812
#
# Epoch 00035: val_loss improved from 0.89645 to 0.88044, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.5180 - accuracy: 0.8851 - val_loss: 0.9008 - val_accuracy: 0.7852
#
# Epoch 00036: val_loss did not improve from 0.88044
# Epoch 37/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.4775 - accuracy: 0.9058 - val_loss: 0.9010 - val_accuracy: 0.7812
#
# Epoch 00037: val_loss did not improve from 0.88044
# Epoch 38/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.4301 - accuracy: 0.9118 - val_loss: 0.9012 - val_accuracy: 0.7812
#
# Epoch 00038: val_loss did not improve from 0.88044
# Epoch 39/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.4642 - accuracy: 0.9081 - val_loss: 0.9134 - val_accuracy: 0.7891
#
# Epoch 00039: val_loss did not improve from 0.88044
# Epoch 40/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.4434 - accuracy: 0.9113 - val_loss: 0.9076 - val_accuracy: 0.8008
#
# Epoch 00040: val_loss did not improve from 0.88044
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 41/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.4130 - accuracy: 0.9219 - val_loss: 0.8651 - val_accuracy: 0.8203
#
# Epoch 00041: val_loss improved from 0.88044 to 0.86514, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.4088 - accuracy: 0.9164 - val_loss: 0.8134 - val_accuracy: 0.8281
#
# Epoch 00042: val_loss improved from 0.86514 to 0.81340, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.3989 - accuracy: 0.9223 - val_loss: 0.9094 - val_accuracy: 0.7930
#
# Epoch 00043: val_loss did not improve from 0.81340
# Epoch 44/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.2889 - accuracy: 0.9513 - val_loss: 0.9132 - val_accuracy: 0.8008
#
# Epoch 00044: val_loss did not improve from 0.81340
# Epoch 45/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.3918 - accuracy: 0.9159 - val_loss: 0.8281 - val_accuracy: 0.8242
#
# Epoch 00045: val_loss did not improve from 0.81340
# Epoch 46/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2553 - accuracy: 0.9637 - val_loss: 0.7634 - val_accuracy: 0.8164
#
# Epoch 00046: val_loss improved from 0.81340 to 0.76344, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.3429 - accuracy: 0.9260 - val_loss: 0.8534 - val_accuracy: 0.8164
#
# Epoch 00047: val_loss did not improve from 0.76344
# Epoch 48/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.2931 - accuracy: 0.9476 - val_loss: 0.7940 - val_accuracy: 0.8320
#
# Epoch 00048: val_loss did not improve from 0.76344
# Epoch 49/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.4666 - accuracy: 0.8998 - val_loss: 0.9243 - val_accuracy: 0.7773
#
# Epoch 00049: val_loss did not improve from 0.76344
# Epoch 50/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.3899 - accuracy: 0.9233 - val_loss: 0.8010 - val_accuracy: 0.8086
#
# Epoch 00050: val_loss did not improve from 0.76344
# Epoch 51/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.2870 - accuracy: 0.9531 - val_loss: 0.7508 - val_accuracy: 0.8242
#
# Epoch 00051: val_loss improved from 0.76344 to 0.75084, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.3076 - accuracy: 0.9389 - val_loss: 0.7809 - val_accuracy: 0.8320
#
# Epoch 00052: val_loss did not improve from 0.75084
# Epoch 53/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.3186 - accuracy: 0.9370 - val_loss: 0.7634 - val_accuracy: 0.8281
#
# Epoch 00053: val_loss did not improve from 0.75084
# Epoch 54/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.3698 - accuracy: 0.9274 - val_loss: 0.8198 - val_accuracy: 0.8086
#
# Epoch 00054: val_loss did not improve from 0.75084
# Epoch 55/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.3200 - accuracy: 0.9306 - val_loss: 0.8424 - val_accuracy: 0.7852
#
# Epoch 00055: val_loss did not improve from 0.75084
# Epoch 56/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.3376 - accuracy: 0.9324 - val_loss: 0.8049 - val_accuracy: 0.8125
#
# Epoch 00056: val_loss did not improve from 0.75084
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/2000
# 34/34 [==============================] - 16s 472ms/step - loss: 0.2705 - accuracy: 0.9517 - val_loss: 0.8194 - val_accuracy: 0.8281
#
# Epoch 00057: val_loss did not improve from 0.75084
# Epoch 58/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.3120 - accuracy: 0.9352 - val_loss: 0.7696 - val_accuracy: 0.8203
#
# Epoch 00058: val_loss did not improve from 0.75084
# Epoch 59/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.2539 - accuracy: 0.9554 - val_loss: 0.7316 - val_accuracy: 0.8242
#
# Epoch 00059: val_loss improved from 0.75084 to 0.73161, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.2815 - accuracy: 0.9421 - val_loss: 0.7587 - val_accuracy: 0.8203
#
# Epoch 00060: val_loss did not improve from 0.73161
# Epoch 61/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2874 - accuracy: 0.9462 - val_loss: 0.7552 - val_accuracy: 0.8125
#
# Epoch 00061: val_loss did not improve from 0.73161
# Epoch 62/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.2909 - accuracy: 0.9472 - val_loss: 0.7869 - val_accuracy: 0.8125
#
# Epoch 00062: val_loss did not improve from 0.73161
# Epoch 63/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2508 - accuracy: 0.9508 - val_loss: 0.8413 - val_accuracy: 0.7969
#
# Epoch 00063: val_loss did not improve from 0.73161
# Epoch 64/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2790 - accuracy: 0.9449 - val_loss: 0.7171 - val_accuracy: 0.8359
#
# Epoch 00064: val_loss improved from 0.73161 to 0.71705, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 16s 472ms/step - loss: 0.2399 - accuracy: 0.9577 - val_loss: 0.7893 - val_accuracy: 0.8086
#
# Epoch 00065: val_loss did not improve from 0.71705
# Epoch 66/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.2681 - accuracy: 0.9472 - val_loss: 0.8424 - val_accuracy: 0.7891
#
# Epoch 00066: val_loss did not improve from 0.71705
# Epoch 67/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.2123 - accuracy: 0.9642 - val_loss: 0.7641 - val_accuracy: 0.8281
#
# Epoch 00067: val_loss did not improve from 0.71705
# Epoch 68/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.2247 - accuracy: 0.9582 - val_loss: 0.8254 - val_accuracy: 0.8086
#
# Epoch 00068: val_loss did not improve from 0.71705
# Epoch 69/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.2392 - accuracy: 0.9559 - val_loss: 0.7726 - val_accuracy: 0.8164
#
# Epoch 00069: val_loss did not improve from 0.71705
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 70/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.2607 - accuracy: 0.9508 - val_loss: 0.8176 - val_accuracy: 0.8086
#
# Epoch 00070: val_loss did not improve from 0.71705
# Epoch 71/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.2518 - accuracy: 0.9504 - val_loss: 0.8004 - val_accuracy: 0.8125
#
# Epoch 00071: val_loss did not improve from 0.71705
# Epoch 72/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.2242 - accuracy: 0.9577 - val_loss: 0.8152 - val_accuracy: 0.8203
#
# Epoch 00072: val_loss did not improve from 0.71705
# Epoch 73/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.2482 - accuracy: 0.9499 - val_loss: 0.7655 - val_accuracy: 0.8164
#
# Epoch 00073: val_loss did not improve from 0.71705
# Epoch 74/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.2311 - accuracy: 0.9577 - val_loss: 0.7823 - val_accuracy: 0.8086
#
# Epoch 00074: val_loss did not improve from 0.71705
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 75/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.1960 - accuracy: 0.9665 - val_loss: 0.7322 - val_accuracy: 0.8242
#
# Epoch 00075: val_loss did not improve from 0.71705
# Epoch 76/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2151 - accuracy: 0.9628 - val_loss: 0.7283 - val_accuracy: 0.8281
#
# Epoch 00076: val_loss did not improve from 0.71705
# Epoch 77/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.1828 - accuracy: 0.9779 - val_loss: 0.7617 - val_accuracy: 0.8242
#
# Epoch 00077: val_loss did not improve from 0.71705
# Epoch 78/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.2015 - accuracy: 0.9674 - val_loss: 0.7383 - val_accuracy: 0.8281
#
# Epoch 00078: val_loss did not improve from 0.71705
# Epoch 79/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.2806 - accuracy: 0.9389 - val_loss: 0.7917 - val_accuracy: 0.8164
#
# Epoch 00079: val_loss did not improve from 0.71705
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 80/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2140 - accuracy: 0.9577 - val_loss: 0.7599 - val_accuracy: 0.8242
#
# Epoch 00080: val_loss did not improve from 0.71705
# Epoch 81/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.2084 - accuracy: 0.9655 - val_loss: 0.7262 - val_accuracy: 0.8203
#
# Epoch 00081: val_loss did not improve from 0.71705
# Epoch 82/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.2030 - accuracy: 0.9646 - val_loss: 0.7113 - val_accuracy: 0.8203
#
# Epoch 00082: val_loss improved from 0.71705 to 0.71131, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.1661 - accuracy: 0.9770 - val_loss: 0.7416 - val_accuracy: 0.8320
#
# Epoch 00083: val_loss did not improve from 0.71131
# Epoch 84/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.1708 - accuracy: 0.9784 - val_loss: 0.7697 - val_accuracy: 0.8281
#
# Epoch 00084: val_loss did not improve from 0.71131
# Epoch 85/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.1643 - accuracy: 0.9784 - val_loss: 0.7431 - val_accuracy: 0.8320
#
# Epoch 00085: val_loss did not improve from 0.71131
# Epoch 86/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.1475 - accuracy: 0.9825 - val_loss: 0.7496 - val_accuracy: 0.8203
#
# Epoch 00086: val_loss did not improve from 0.71131
# Epoch 87/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.2349 - accuracy: 0.9508 - val_loss: 0.7483 - val_accuracy: 0.8242
#
# Epoch 00087: val_loss did not improve from 0.71131
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 88/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.2128 - accuracy: 0.9642 - val_loss: 0.7687 - val_accuracy: 0.8203
#
# Epoch 00088: val_loss did not improve from 0.71131
# Epoch 89/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.1888 - accuracy: 0.9683 - val_loss: 0.7449 - val_accuracy: 0.8203
#
# Epoch 00089: val_loss did not improve from 0.71131
# Epoch 90/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.1914 - accuracy: 0.9697 - val_loss: 0.7369 - val_accuracy: 0.8203
#
# Epoch 00090: val_loss did not improve from 0.71131
# Epoch 91/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.2068 - accuracy: 0.9596 - val_loss: 0.7339 - val_accuracy: 0.8164
#
# Epoch 00091: val_loss did not improve from 0.71131
# Epoch 92/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.1786 - accuracy: 0.9747 - val_loss: 0.7256 - val_accuracy: 0.8281
#
# Epoch 00092: val_loss did not improve from 0.71131
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 93/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.2210 - accuracy: 0.9600 - val_loss: 0.7288 - val_accuracy: 0.8242
#
# Epoch 00093: val_loss did not improve from 0.71131
# Epoch 94/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.1648 - accuracy: 0.9747 - val_loss: 0.7529 - val_accuracy: 0.8242
#
# Epoch 00094: val_loss did not improve from 0.71131
# Epoch 95/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.1810 - accuracy: 0.9697 - val_loss: 0.7402 - val_accuracy: 0.8242
#
# Epoch 00095: val_loss did not improve from 0.71131
# Epoch 96/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.2084 - accuracy: 0.9651 - val_loss: 0.6999 - val_accuracy: 0.8203
#
# Epoch 00096: val_loss improved from 0.71131 to 0.69994, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.2467 - accuracy: 0.9517 - val_loss: 0.7663 - val_accuracy: 0.8125
#
# Epoch 00097: val_loss did not improve from 0.69994
# Epoch 98/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.1871 - accuracy: 0.9655 - val_loss: 0.6935 - val_accuracy: 0.8281
#
# Epoch 00098: val_loss improved from 0.69994 to 0.69349, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.2126 - accuracy: 0.9550 - val_loss: 0.7184 - val_accuracy: 0.8359
#
# Epoch 00099: val_loss did not improve from 0.69349
# Epoch 100/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.1683 - accuracy: 0.9752 - val_loss: 0.7108 - val_accuracy: 0.8242
#
# Epoch 00100: val_loss did not improve from 0.69349
# Epoch 101/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.1808 - accuracy: 0.9646 - val_loss: 0.7600 - val_accuracy: 0.8164
#
# Epoch 00101: val_loss did not improve from 0.69349
# Epoch 102/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 0.1986 - accuracy: 0.9674 - val_loss: 0.7095 - val_accuracy: 0.8203
#
# Epoch 00102: val_loss did not improve from 0.69349
# Epoch 103/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.2219 - accuracy: 0.9550 - val_loss: 0.7268 - val_accuracy: 0.8203
#
# Epoch 00103: val_loss did not improve from 0.69349
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 104/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.1706 - accuracy: 0.9729 - val_loss: 0.7328 - val_accuracy: 0.8320
#
# Epoch 00104: val_loss did not improve from 0.69349
# Epoch 105/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.1995 - accuracy: 0.9669 - val_loss: 0.7202 - val_accuracy: 0.8359
#
# Epoch 00105: val_loss did not improve from 0.69349
# Epoch 106/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.1913 - accuracy: 0.9706 - val_loss: 0.6455 - val_accuracy: 0.8398
#
# Epoch 00106: val_loss improved from 0.69349 to 0.64554, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.1638 - accuracy: 0.9784 - val_loss: 0.6791 - val_accuracy: 0.8359
#
# Epoch 00107: val_loss did not improve from 0.64554
# Epoch 108/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.1868 - accuracy: 0.9688 - val_loss: 0.6768 - val_accuracy: 0.8359
#
# Epoch 00108: val_loss did not improve from 0.64554
# Epoch 109/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2036 - accuracy: 0.9637 - val_loss: 0.6805 - val_accuracy: 0.8398
#
# Epoch 00109: val_loss did not improve from 0.64554
# Epoch 110/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.1855 - accuracy: 0.9669 - val_loss: 0.7210 - val_accuracy: 0.8320
#
# Epoch 00110: val_loss did not improve from 0.64554
# Epoch 111/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.2312 - accuracy: 0.9563 - val_loss: 0.7364 - val_accuracy: 0.8203
#
# Epoch 00111: val_loss did not improve from 0.64554
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 112/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.1851 - accuracy: 0.9706 - val_loss: 0.7445 - val_accuracy: 0.8242
#
# Epoch 00112: val_loss did not improve from 0.64554
# Epoch 113/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.1983 - accuracy: 0.9701 - val_loss: 0.7267 - val_accuracy: 0.8281
#
# Epoch 00113: val_loss did not improve from 0.64554
# Epoch 114/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.2024 - accuracy: 0.9642 - val_loss: 0.7523 - val_accuracy: 0.8164
#
# Epoch 00114: val_loss did not improve from 0.64554
# Epoch 115/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.1823 - accuracy: 0.9756 - val_loss: 0.7105 - val_accuracy: 0.8203
#
# Epoch 00115: val_loss did not improve from 0.64554
# Epoch 116/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.1777 - accuracy: 0.9715 - val_loss: 0.7339 - val_accuracy: 0.8242
#
# Epoch 00116: val_loss did not improve from 0.64554
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 117/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.2082 - accuracy: 0.9637 - val_loss: 0.7340 - val_accuracy: 0.8203
#
# Epoch 00117: val_loss did not improve from 0.64554
# Epoch 118/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.1788 - accuracy: 0.9724 - val_loss: 0.7248 - val_accuracy: 0.8203
#
# Epoch 00118: val_loss did not improve from 0.64554
# Epoch 119/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2029 - accuracy: 0.9632 - val_loss: 0.7521 - val_accuracy: 0.8203
#
# Epoch 00119: val_loss did not improve from 0.64554
# Epoch 120/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.2425 - accuracy: 0.9531 - val_loss: 0.7621 - val_accuracy: 0.8164
#
# Epoch 00120: val_loss did not improve from 0.64554
# Epoch 121/2000
# 34/34 [==============================] - 16s 473ms/step - loss: 0.2259 - accuracy: 0.9582 - val_loss: 0.7386 - val_accuracy: 0.8203
#
# Epoch 00121: val_loss did not improve from 0.64554
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 122/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.1657 - accuracy: 0.9766 - val_loss: 0.7146 - val_accuracy: 0.8320
#
# Epoch 00122: val_loss did not improve from 0.64554
# Epoch 123/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2108 - accuracy: 0.9605 - val_loss: 0.7328 - val_accuracy: 0.8242
#
# Epoch 00123: val_loss did not improve from 0.64554
# Epoch 124/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.1983 - accuracy: 0.9674 - val_loss: 0.7339 - val_accuracy: 0.8242
#
# Epoch 00124: val_loss did not improve from 0.64554
# Epoch 125/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.1946 - accuracy: 0.9665 - val_loss: 0.7566 - val_accuracy: 0.8164
#
# Epoch 00125: val_loss did not improve from 0.64554
# Epoch 126/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.1901 - accuracy: 0.9655 - val_loss: 0.7477 - val_accuracy: 0.8203
#
# Epoch 00126: val_loss did not improve from 0.64554
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 127/2000
# 34/34 [==============================] - 16s 472ms/step - loss: 0.2371 - accuracy: 0.9568 - val_loss: 0.7453 - val_accuracy: 0.8203
#
# Epoch 00127: val_loss did not improve from 0.64554
# Epoch 128/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.1637 - accuracy: 0.9733 - val_loss: 0.6984 - val_accuracy: 0.8320
#
# Epoch 00128: val_loss did not improve from 0.64554
# Epoch 129/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2069 - accuracy: 0.9614 - val_loss: 0.7605 - val_accuracy: 0.8125
#
# Epoch 00129: val_loss did not improve from 0.64554
# Epoch 130/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.1517 - accuracy: 0.9844 - val_loss: 0.7557 - val_accuracy: 0.8164
#
# Epoch 00130: val_loss did not improve from 0.64554
# Epoch 131/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.2096 - accuracy: 0.9600 - val_loss: 0.7435 - val_accuracy: 0.8203
#
# Epoch 00131: val_loss did not improve from 0.64554
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 132/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.1942 - accuracy: 0.9655 - val_loss: 0.7307 - val_accuracy: 0.8203
#
# Epoch 00132: val_loss did not improve from 0.64554
# Epoch 133/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.2058 - accuracy: 0.9605 - val_loss: 0.7354 - val_accuracy: 0.8242
#
# Epoch 00133: val_loss did not improve from 0.64554
# Epoch 134/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 0.2101 - accuracy: 0.9665 - val_loss: 0.7405 - val_accuracy: 0.8281
#
# Epoch 00134: val_loss did not improve from 0.64554
# Epoch 135/2000
# 34/34 [==============================] - 16s 471ms/step - loss: 0.2013 - accuracy: 0.9614 - val_loss: 0.7398 - val_accuracy: 0.8203
#
# Epoch 00135: val_loss did not improve from 0.64554
# Epoch 136/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.2028 - accuracy: 0.9669 - val_loss: 0.7377 - val_accuracy: 0.8281
#
# Epoch 00136: val_loss did not improve from 0.64554
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5947 - accuracy: 0.8512
# [0.5946868062019348, 0.8511999845504761]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
