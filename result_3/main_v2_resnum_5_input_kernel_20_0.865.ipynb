# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 20, # #10#, #20#
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 5 # #3#, ##5##, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      1460        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1020)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_59[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_62[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 150, 60)      240         add_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,423,931
# Trainable params: 2,416,311
# Non-trainable params: 7,620
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 63s 573ms/step - loss: 22.4190 - accuracy: 0.4177 - val_loss: 16.7915 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 16.79145, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 12.0931 - accuracy: 0.5731 - val_loss: 10.1800 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 16.79145 to 10.18000, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 6.7371 - accuracy: 0.6540 - val_loss: 7.1073 - val_accuracy: 0.3672
#
# Epoch 00003: val_loss improved from 10.18000 to 7.10733, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 4.2441 - accuracy: 0.6599 - val_loss: 6.1313 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 7.10733 to 6.13133, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 2.8348 - accuracy: 0.6903 - val_loss: 5.4326 - val_accuracy: 0.4531
#
# Epoch 00005: val_loss improved from 6.13133 to 5.43260, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 2.0901 - accuracy: 0.6949 - val_loss: 4.6688 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 5.43260 to 4.66877, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 1.6308 - accuracy: 0.7312 - val_loss: 4.9772 - val_accuracy: 0.4141
#
# Epoch 00007: val_loss did not improve from 4.66877
# Epoch 8/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 1.3655 - accuracy: 0.7592 - val_loss: 4.8675 - val_accuracy: 0.3789
#
# Epoch 00008: val_loss did not improve from 4.66877
# Epoch 9/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 1.1814 - accuracy: 0.7785 - val_loss: 4.6467 - val_accuracy: 0.3867
#
# Epoch 00009: val_loss improved from 4.66877 to 4.64671, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 1.2361 - accuracy: 0.7495 - val_loss: 6.3195 - val_accuracy: 0.0781
#
# Epoch 00010: val_loss did not improve from 4.64671
# Epoch 11/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 1.1953 - accuracy: 0.7578 - val_loss: 5.1675 - val_accuracy: 0.3672
#
# Epoch 00011: val_loss did not improve from 4.64671
# Epoch 12/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 1.1591 - accuracy: 0.7592 - val_loss: 4.6489 - val_accuracy: 0.2266
#
# Epoch 00012: val_loss did not improve from 4.64671
# Epoch 13/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 1.0303 - accuracy: 0.7808 - val_loss: 4.3233 - val_accuracy: 0.4570
#
# Epoch 00013: val_loss improved from 4.64671 to 4.32332, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.9986 - accuracy: 0.7854 - val_loss: 4.7314 - val_accuracy: 0.2461
#
# Epoch 00014: val_loss did not improve from 4.32332
# Epoch 15/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 1.0462 - accuracy: 0.7849 - val_loss: 4.0739 - val_accuracy: 0.3945
#
# Epoch 00015: val_loss improved from 4.32332 to 4.07388, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 1.0401 - accuracy: 0.7794 - val_loss: 3.5088 - val_accuracy: 0.4180
#
# Epoch 00016: val_loss improved from 4.07388 to 3.50880, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 1.0727 - accuracy: 0.7790 - val_loss: 3.3803 - val_accuracy: 0.3945
#
# Epoch 00017: val_loss improved from 3.50880 to 3.38030, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.9224 - accuracy: 0.8093 - val_loss: 2.3808 - val_accuracy: 0.5898
#
# Epoch 00018: val_loss improved from 3.38030 to 2.38075, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.8450 - accuracy: 0.8212 - val_loss: 1.9316 - val_accuracy: 0.6406
#
# Epoch 00019: val_loss improved from 2.38075 to 1.93164, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 1.0573 - accuracy: 0.7679 - val_loss: 1.9660 - val_accuracy: 0.6250
#
# Epoch 00020: val_loss did not improve from 1.93164
# Epoch 21/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.9525 - accuracy: 0.7950 - val_loss: 1.6196 - val_accuracy: 0.6445
#
# Epoch 00021: val_loss improved from 1.93164 to 1.61963, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.9371 - accuracy: 0.8010 - val_loss: 1.4881 - val_accuracy: 0.6914
#
# Epoch 00022: val_loss improved from 1.61963 to 1.48807, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.9022 - accuracy: 0.8203 - val_loss: 1.3744 - val_accuracy: 0.7070
#
# Epoch 00023: val_loss improved from 1.48807 to 1.37441, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.8435 - accuracy: 0.8235 - val_loss: 1.3217 - val_accuracy: 0.7305
#
# Epoch 00024: val_loss improved from 1.37441 to 1.32169, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.8387 - accuracy: 0.8203 - val_loss: 1.3112 - val_accuracy: 0.7305
#
# Epoch 00025: val_loss improved from 1.32169 to 1.31117, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.7933 - accuracy: 0.8364 - val_loss: 1.1792 - val_accuracy: 0.7305
#
# Epoch 00026: val_loss improved from 1.31117 to 1.17920, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.8482 - accuracy: 0.8327 - val_loss: 1.2587 - val_accuracy: 0.7461
#
# Epoch 00027: val_loss did not improve from 1.17920
# Epoch 28/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.8853 - accuracy: 0.8194 - val_loss: 1.3566 - val_accuracy: 0.7109
#
# Epoch 00028: val_loss did not improve from 1.17920
# Epoch 29/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.8903 - accuracy: 0.8176 - val_loss: 1.2724 - val_accuracy: 0.7148
#
# Epoch 00029: val_loss did not improve from 1.17920
# Epoch 30/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.7593 - accuracy: 0.8557 - val_loss: 1.1162 - val_accuracy: 0.7695
#
# Epoch 00030: val_loss improved from 1.17920 to 1.11621, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.7249 - accuracy: 0.8548 - val_loss: 1.1803 - val_accuracy: 0.7422
#
# Epoch 00031: val_loss did not improve from 1.11621
# Epoch 32/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.7588 - accuracy: 0.8493 - val_loss: 1.3234 - val_accuracy: 0.7227
#
# Epoch 00032: val_loss did not improve from 1.11621
# Epoch 33/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.7827 - accuracy: 0.8451 - val_loss: 1.6145 - val_accuracy: 0.6680
#
# Epoch 00033: val_loss did not improve from 1.11621
# Epoch 34/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.7333 - accuracy: 0.8557 - val_loss: 1.2587 - val_accuracy: 0.7266
#
# Epoch 00034: val_loss did not improve from 1.11621
# Epoch 35/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.7717 - accuracy: 0.8543 - val_loss: 1.2210 - val_accuracy: 0.7461
#
# Epoch 00035: val_loss did not improve from 1.11621
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 36/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.6900 - accuracy: 0.8663 - val_loss: 1.0386 - val_accuracy: 0.7539
#
# Epoch 00036: val_loss improved from 1.11621 to 1.03863, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.5815 - accuracy: 0.8824 - val_loss: 0.9910 - val_accuracy: 0.7734
#
# Epoch 00037: val_loss improved from 1.03863 to 0.99103, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.5160 - accuracy: 0.9012 - val_loss: 0.9334 - val_accuracy: 0.7812
#
# Epoch 00038: val_loss improved from 0.99103 to 0.93343, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.5361 - accuracy: 0.8856 - val_loss: 0.9196 - val_accuracy: 0.8008
#
# Epoch 00039: val_loss improved from 0.93343 to 0.91955, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.5510 - accuracy: 0.8847 - val_loss: 0.9750 - val_accuracy: 0.8047
#
# Epoch 00040: val_loss did not improve from 0.91955
# Epoch 41/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.5113 - accuracy: 0.8952 - val_loss: 0.8995 - val_accuracy: 0.8125
#
# Epoch 00041: val_loss improved from 0.91955 to 0.89955, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.5493 - accuracy: 0.8727 - val_loss: 1.1156 - val_accuracy: 0.7578
#
# Epoch 00042: val_loss did not improve from 0.89955
# Epoch 43/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.5329 - accuracy: 0.8975 - val_loss: 1.0245 - val_accuracy: 0.7734
#
# Epoch 00043: val_loss did not improve from 0.89955
# Epoch 44/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.4159 - accuracy: 0.9242 - val_loss: 1.0554 - val_accuracy: 0.7617
#
# Epoch 00044: val_loss did not improve from 0.89955
# Epoch 45/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.5530 - accuracy: 0.8778 - val_loss: 0.9951 - val_accuracy: 0.8164
#
# Epoch 00045: val_loss did not improve from 0.89955
# Epoch 46/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.3960 - accuracy: 0.9301 - val_loss: 1.0133 - val_accuracy: 0.7773
#
# Epoch 00046: val_loss did not improve from 0.89955
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 47/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.4386 - accuracy: 0.9118 - val_loss: 0.8904 - val_accuracy: 0.8047
#
# Epoch 00047: val_loss improved from 0.89955 to 0.89040, saving model to ./save/cnn_gru_best.hdf5
# Epoch 48/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.3684 - accuracy: 0.9334 - val_loss: 0.8219 - val_accuracy: 0.8203
#
# Epoch 00048: val_loss improved from 0.89040 to 0.82194, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.5109 - accuracy: 0.8837 - val_loss: 0.9106 - val_accuracy: 0.8047
#
# Epoch 00049: val_loss did not improve from 0.82194
# Epoch 50/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.4476 - accuracy: 0.8998 - val_loss: 0.8864 - val_accuracy: 0.7891
#
# Epoch 00050: val_loss did not improve from 0.82194
# Epoch 51/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.3349 - accuracy: 0.9352 - val_loss: 0.7755 - val_accuracy: 0.8086
#
# Epoch 00051: val_loss improved from 0.82194 to 0.77545, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.3521 - accuracy: 0.9278 - val_loss: 0.8262 - val_accuracy: 0.8086
#
# Epoch 00052: val_loss did not improve from 0.77545
# Epoch 53/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.3476 - accuracy: 0.9343 - val_loss: 0.8589 - val_accuracy: 0.8086
#
# Epoch 00053: val_loss did not improve from 0.77545
# Epoch 54/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.4059 - accuracy: 0.9168 - val_loss: 0.8278 - val_accuracy: 0.8242
#
# Epoch 00054: val_loss did not improve from 0.77545
# Epoch 55/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.3716 - accuracy: 0.9187 - val_loss: 0.8880 - val_accuracy: 0.8008
#
# Epoch 00055: val_loss did not improve from 0.77545
# Epoch 56/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.3823 - accuracy: 0.9150 - val_loss: 0.9076 - val_accuracy: 0.8164
#
# Epoch 00056: val_loss did not improve from 0.77545
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 57/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.3007 - accuracy: 0.9393 - val_loss: 0.8670 - val_accuracy: 0.8047
#
# Epoch 00057: val_loss did not improve from 0.77545
# Epoch 58/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.3315 - accuracy: 0.9311 - val_loss: 0.8377 - val_accuracy: 0.8164
#
# Epoch 00058: val_loss did not improve from 0.77545
# Epoch 59/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2887 - accuracy: 0.9449 - val_loss: 0.7856 - val_accuracy: 0.8164
#
# Epoch 00059: val_loss did not improve from 0.77545
# Epoch 60/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2973 - accuracy: 0.9407 - val_loss: 0.7853 - val_accuracy: 0.8203
#
# Epoch 00060: val_loss did not improve from 0.77545
# Epoch 61/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.3126 - accuracy: 0.9380 - val_loss: 0.8070 - val_accuracy: 0.7969
#
# Epoch 00061: val_loss did not improve from 0.77545
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 62/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.3061 - accuracy: 0.9412 - val_loss: 0.8004 - val_accuracy: 0.8047
#
# Epoch 00062: val_loss did not improve from 0.77545
# Epoch 63/2000
# 34/34 [==============================] - 13s 366ms/step - loss: 0.2480 - accuracy: 0.9573 - val_loss: 0.8224 - val_accuracy: 0.8164
#
# Epoch 00063: val_loss did not improve from 0.77545
# Epoch 64/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.2708 - accuracy: 0.9476 - val_loss: 0.7491 - val_accuracy: 0.8320
#
# Epoch 00064: val_loss improved from 0.77545 to 0.74907, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2401 - accuracy: 0.9623 - val_loss: 0.8031 - val_accuracy: 0.8125
#
# Epoch 00065: val_loss did not improve from 0.74907
# Epoch 66/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2586 - accuracy: 0.9490 - val_loss: 0.8297 - val_accuracy: 0.7969
#
# Epoch 00066: val_loss did not improve from 0.74907
# Epoch 67/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2016 - accuracy: 0.9665 - val_loss: 0.7491 - val_accuracy: 0.8242
#
# Epoch 00067: val_loss did not improve from 0.74907
# Epoch 68/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2279 - accuracy: 0.9554 - val_loss: 0.7999 - val_accuracy: 0.8203
#
# Epoch 00068: val_loss did not improve from 0.74907
# Epoch 69/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2407 - accuracy: 0.9508 - val_loss: 0.8020 - val_accuracy: 0.8125
#
# Epoch 00069: val_loss did not improve from 0.74907
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 70/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.2561 - accuracy: 0.9407 - val_loss: 0.7992 - val_accuracy: 0.8242
#
# Epoch 00070: val_loss did not improve from 0.74907
# Epoch 71/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 0.2388 - accuracy: 0.9531 - val_loss: 0.7863 - val_accuracy: 0.8164
#
# Epoch 00071: val_loss did not improve from 0.74907
# Epoch 72/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.2231 - accuracy: 0.9577 - val_loss: 0.8163 - val_accuracy: 0.8164
#
# Epoch 00072: val_loss did not improve from 0.74907
# Epoch 73/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2419 - accuracy: 0.9494 - val_loss: 0.8050 - val_accuracy: 0.8047
#
# Epoch 00073: val_loss did not improve from 0.74907
# Epoch 74/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.2422 - accuracy: 0.9527 - val_loss: 0.8160 - val_accuracy: 0.8203
#
# Epoch 00074: val_loss did not improve from 0.74907
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 75/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.1888 - accuracy: 0.9692 - val_loss: 0.7938 - val_accuracy: 0.8164
#
# Epoch 00075: val_loss did not improve from 0.74907
# Epoch 76/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2135 - accuracy: 0.9609 - val_loss: 0.7499 - val_accuracy: 0.8242
#
# Epoch 00076: val_loss did not improve from 0.74907
# Epoch 77/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.1868 - accuracy: 0.9683 - val_loss: 0.7921 - val_accuracy: 0.8203
#
# Epoch 00077: val_loss did not improve from 0.74907
# Epoch 78/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.1994 - accuracy: 0.9642 - val_loss: 0.7832 - val_accuracy: 0.8203
#
# Epoch 00078: val_loss did not improve from 0.74907
# Epoch 79/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2722 - accuracy: 0.9398 - val_loss: 0.8179 - val_accuracy: 0.8008
#
# Epoch 00079: val_loss did not improve from 0.74907
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 80/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2138 - accuracy: 0.9596 - val_loss: 0.8009 - val_accuracy: 0.8008
#
# Epoch 00080: val_loss did not improve from 0.74907
# Epoch 81/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2095 - accuracy: 0.9619 - val_loss: 0.7707 - val_accuracy: 0.8125
#
# Epoch 00081: val_loss did not improve from 0.74907
# Epoch 82/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2044 - accuracy: 0.9623 - val_loss: 0.7502 - val_accuracy: 0.8203
#
# Epoch 00082: val_loss did not improve from 0.74907
# Epoch 83/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.1587 - accuracy: 0.9775 - val_loss: 0.7757 - val_accuracy: 0.8281
#
# Epoch 00083: val_loss did not improve from 0.74907
# Epoch 84/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.1726 - accuracy: 0.9683 - val_loss: 0.8031 - val_accuracy: 0.8203
#
# Epoch 00084: val_loss did not improve from 0.74907
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 85/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.1594 - accuracy: 0.9770 - val_loss: 0.7914 - val_accuracy: 0.8359
#
# Epoch 00085: val_loss did not improve from 0.74907
# Epoch 86/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.1488 - accuracy: 0.9784 - val_loss: 0.7907 - val_accuracy: 0.8242
#
# Epoch 00086: val_loss did not improve from 0.74907
# Epoch 87/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2364 - accuracy: 0.9522 - val_loss: 0.7921 - val_accuracy: 0.8320
#
# Epoch 00087: val_loss did not improve from 0.74907
# Epoch 88/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2138 - accuracy: 0.9582 - val_loss: 0.8090 - val_accuracy: 0.8203
#
# Epoch 00088: val_loss did not improve from 0.74907
# Epoch 89/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.1861 - accuracy: 0.9715 - val_loss: 0.7848 - val_accuracy: 0.8320
#
# Epoch 00089: val_loss did not improve from 0.74907
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 90/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.1991 - accuracy: 0.9674 - val_loss: 0.7819 - val_accuracy: 0.8320
#
# Epoch 00090: val_loss did not improve from 0.74907
# Epoch 91/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2001 - accuracy: 0.9605 - val_loss: 0.7766 - val_accuracy: 0.8242
#
# Epoch 00091: val_loss did not improve from 0.74907
# Epoch 92/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.1805 - accuracy: 0.9678 - val_loss: 0.7641 - val_accuracy: 0.8320
#
# Epoch 00092: val_loss did not improve from 0.74907
# Epoch 93/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2119 - accuracy: 0.9628 - val_loss: 0.7690 - val_accuracy: 0.8281
#
# Epoch 00093: val_loss did not improve from 0.74907
# Epoch 94/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.1658 - accuracy: 0.9752 - val_loss: 0.7950 - val_accuracy: 0.8242
#
# Epoch 00094: val_loss did not improve from 0.74907
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 00094: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6176 - accuracy: 0.8656
# [0.6176012754440308, 0.8655999898910522]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
