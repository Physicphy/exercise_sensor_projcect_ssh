# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset #, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 2
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      1460        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1020)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,270,331
# Trainable params: 2,263,671
# Non-trainable params: 6,660
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 58s 550ms/step - loss: 15.2693 - accuracy: 0.3975 - val_loss: 11.6400 - val_accuracy: 0.4648
#
# Epoch 00001: val_loss improved from inf to 11.63997, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 8.4494 - accuracy: 0.5662 - val_loss: 7.5334 - val_accuracy: 0.4648
#
# Epoch 00002: val_loss improved from 11.63997 to 7.53343, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 5.0225 - accuracy: 0.6314 - val_loss: 5.8040 - val_accuracy: 0.4688
#
# Epoch 00003: val_loss improved from 7.53343 to 5.80401, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 3.1414 - accuracy: 0.6870 - val_loss: 4.8399 - val_accuracy: 0.2969
#
# Epoch 00004: val_loss improved from 5.80401 to 4.83994, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 2.3483 - accuracy: 0.6884 - val_loss: 5.4120 - val_accuracy: 0.0117
#
# Epoch 00005: val_loss did not improve from 4.83994
# Epoch 6/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 1.8651 - accuracy: 0.7086 - val_loss: 5.1576 - val_accuracy: 0.0156
#
# Epoch 00006: val_loss did not improve from 4.83994
# Epoch 7/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 1.4974 - accuracy: 0.7390 - val_loss: 6.4256 - val_accuracy: 0.0156
#
# Epoch 00007: val_loss did not improve from 4.83994
# Epoch 8/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 1.3595 - accuracy: 0.7325 - val_loss: 5.6224 - val_accuracy: 0.0391
#
# Epoch 00008: val_loss did not improve from 4.83994
# Epoch 9/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 1.3149 - accuracy: 0.7312 - val_loss: 4.8779 - val_accuracy: 0.2070
#
# Epoch 00009: val_loss did not improve from 4.83994
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 1.0670 - accuracy: 0.7886 - val_loss: 5.1241 - val_accuracy: 0.1172
#
# Epoch 00010: val_loss did not improve from 4.83994
# Epoch 11/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.9628 - accuracy: 0.8102 - val_loss: 4.5762 - val_accuracy: 0.1953
#
# Epoch 00011: val_loss improved from 4.83994 to 4.57616, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.9306 - accuracy: 0.8015 - val_loss: 4.6521 - val_accuracy: 0.1719
#
# Epoch 00012: val_loss did not improve from 4.57616
# Epoch 13/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 1.0023 - accuracy: 0.7849 - val_loss: 3.6592 - val_accuracy: 0.4023
#
# Epoch 00013: val_loss improved from 4.57616 to 3.65918, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.9251 - accuracy: 0.8042 - val_loss: 3.3626 - val_accuracy: 0.5273
#
# Epoch 00014: val_loss improved from 3.65918 to 3.36257, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.8733 - accuracy: 0.8093 - val_loss: 3.0103 - val_accuracy: 0.3945
#
# Epoch 00015: val_loss improved from 3.36257 to 3.01028, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.8033 - accuracy: 0.8286 - val_loss: 2.4081 - val_accuracy: 0.5547
#
# Epoch 00016: val_loss improved from 3.01028 to 2.40812, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.8746 - accuracy: 0.8166 - val_loss: 1.9023 - val_accuracy: 0.6172
#
# Epoch 00017: val_loss improved from 2.40812 to 1.90227, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.8155 - accuracy: 0.8222 - val_loss: 1.4798 - val_accuracy: 0.6680
#
# Epoch 00018: val_loss improved from 1.90227 to 1.47984, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.8109 - accuracy: 0.8212 - val_loss: 1.3133 - val_accuracy: 0.7070
#
# Epoch 00019: val_loss improved from 1.47984 to 1.31333, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.8372 - accuracy: 0.8125 - val_loss: 1.2002 - val_accuracy: 0.7305
#
# Epoch 00020: val_loss improved from 1.31333 to 1.20017, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.7875 - accuracy: 0.8318 - val_loss: 1.1478 - val_accuracy: 0.7773
#
# Epoch 00021: val_loss improved from 1.20017 to 1.14778, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.7645 - accuracy: 0.8479 - val_loss: 1.0976 - val_accuracy: 0.7695
#
# Epoch 00022: val_loss improved from 1.14778 to 1.09755, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.7047 - accuracy: 0.8465 - val_loss: 0.8795 - val_accuracy: 0.7852
#
# Epoch 00023: val_loss improved from 1.09755 to 0.87949, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.7961 - accuracy: 0.8341 - val_loss: 0.8377 - val_accuracy: 0.7891
#
# Epoch 00024: val_loss improved from 0.87949 to 0.83774, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.6251 - accuracy: 0.8695 - val_loss: 0.9133 - val_accuracy: 0.7656
#
# Epoch 00025: val_loss did not improve from 0.83774
# Epoch 26/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.7568 - accuracy: 0.8309 - val_loss: 0.9297 - val_accuracy: 0.7773
#
# Epoch 00026: val_loss did not improve from 0.83774
# Epoch 27/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.6820 - accuracy: 0.8580 - val_loss: 0.9616 - val_accuracy: 0.7617
#
# Epoch 00027: val_loss did not improve from 0.83774
# Epoch 28/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.6964 - accuracy: 0.8539 - val_loss: 1.1089 - val_accuracy: 0.7539
#
# Epoch 00028: val_loss did not improve from 0.83774
# Epoch 29/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.6642 - accuracy: 0.8529 - val_loss: 0.9850 - val_accuracy: 0.7695
#
# Epoch 00029: val_loss did not improve from 0.83774
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.5981 - accuracy: 0.8805 - val_loss: 0.9539 - val_accuracy: 0.7656
#
# Epoch 00030: val_loss did not improve from 0.83774
# Epoch 31/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.5666 - accuracy: 0.8791 - val_loss: 0.8257 - val_accuracy: 0.7852
#
# Epoch 00031: val_loss improved from 0.83774 to 0.82568, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.5403 - accuracy: 0.8851 - val_loss: 0.8144 - val_accuracy: 0.7930
#
# Epoch 00032: val_loss improved from 0.82568 to 0.81444, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.5377 - accuracy: 0.8906 - val_loss: 0.8020 - val_accuracy: 0.8125
#
# Epoch 00033: val_loss improved from 0.81444 to 0.80200, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.6014 - accuracy: 0.8631 - val_loss: 0.8958 - val_accuracy: 0.7852
#
# Epoch 00034: val_loss did not improve from 0.80200
# Epoch 35/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.5389 - accuracy: 0.8865 - val_loss: 0.8606 - val_accuracy: 0.7773
#
# Epoch 00035: val_loss did not improve from 0.80200
# Epoch 36/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.5007 - accuracy: 0.8989 - val_loss: 0.8477 - val_accuracy: 0.7695
#
# Epoch 00036: val_loss did not improve from 0.80200
# Epoch 37/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.4082 - accuracy: 0.9168 - val_loss: 0.8342 - val_accuracy: 0.7852
#
# Epoch 00037: val_loss did not improve from 0.80200
# Epoch 38/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.4794 - accuracy: 0.8984 - val_loss: 0.7914 - val_accuracy: 0.8047
#
# Epoch 00038: val_loss improved from 0.80200 to 0.79140, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.4848 - accuracy: 0.9007 - val_loss: 0.8444 - val_accuracy: 0.7891
#
# Epoch 00039: val_loss did not improve from 0.79140
# Epoch 40/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.5041 - accuracy: 0.8874 - val_loss: 0.7641 - val_accuracy: 0.8086
#
# Epoch 00040: val_loss improved from 0.79140 to 0.76413, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.5262 - accuracy: 0.8828 - val_loss: 0.7782 - val_accuracy: 0.8047
#
# Epoch 00041: val_loss did not improve from 0.76413
# Epoch 42/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.5513 - accuracy: 0.8814 - val_loss: 0.8618 - val_accuracy: 0.7891
#
# Epoch 00042: val_loss did not improve from 0.76413
# Epoch 43/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.5624 - accuracy: 0.8686 - val_loss: 0.7856 - val_accuracy: 0.8164
#
# Epoch 00043: val_loss did not improve from 0.76413
# Epoch 44/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.5405 - accuracy: 0.8814 - val_loss: 0.7874 - val_accuracy: 0.8008
#
# Epoch 00044: val_loss did not improve from 0.76413
# Epoch 45/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.4069 - accuracy: 0.9246 - val_loss: 0.8692 - val_accuracy: 0.8047
#
# Epoch 00045: val_loss did not improve from 0.76413
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 46/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.4494 - accuracy: 0.9067 - val_loss: 0.7646 - val_accuracy: 0.8164
#
# Epoch 00046: val_loss did not improve from 0.76413
# Epoch 47/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.4173 - accuracy: 0.9131 - val_loss: 0.7679 - val_accuracy: 0.8281
#
# Epoch 00047: val_loss did not improve from 0.76413
# Epoch 48/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.3705 - accuracy: 0.9301 - val_loss: 0.7366 - val_accuracy: 0.8320
#
# Epoch 00048: val_loss improved from 0.76413 to 0.73659, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.3420 - accuracy: 0.9338 - val_loss: 0.7509 - val_accuracy: 0.8242
#
# Epoch 00049: val_loss did not improve from 0.73659
# Epoch 50/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.3840 - accuracy: 0.9242 - val_loss: 0.7812 - val_accuracy: 0.8164
#
# Epoch 00050: val_loss did not improve from 0.73659
# Epoch 51/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.4090 - accuracy: 0.9122 - val_loss: 0.7066 - val_accuracy: 0.8164
#
# Epoch 00051: val_loss improved from 0.73659 to 0.70663, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3269 - accuracy: 0.9370 - val_loss: 0.6669 - val_accuracy: 0.8242
#
# Epoch 00052: val_loss improved from 0.70663 to 0.66692, saving model to ./save/cnn_gru_best.hdf5
# Epoch 53/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.4149 - accuracy: 0.9145 - val_loss: 0.7242 - val_accuracy: 0.8359
#
# Epoch 00053: val_loss did not improve from 0.66692
# Epoch 54/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.3737 - accuracy: 0.9205 - val_loss: 0.7191 - val_accuracy: 0.8320
#
# Epoch 00054: val_loss did not improve from 0.66692
# Epoch 55/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.4006 - accuracy: 0.9127 - val_loss: 0.7216 - val_accuracy: 0.8281
#
# Epoch 00055: val_loss did not improve from 0.66692
# Epoch 56/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.3936 - accuracy: 0.9269 - val_loss: 0.7689 - val_accuracy: 0.7891
#
# Epoch 00056: val_loss did not improve from 0.66692
# Epoch 57/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3155 - accuracy: 0.9453 - val_loss: 0.6907 - val_accuracy: 0.8398
#
# Epoch 00057: val_loss did not improve from 0.66692
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 58/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3752 - accuracy: 0.9301 - val_loss: 0.7229 - val_accuracy: 0.8359
#
# Epoch 00058: val_loss did not improve from 0.66692
# Epoch 59/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.3364 - accuracy: 0.9315 - val_loss: 0.7255 - val_accuracy: 0.8359
#
# Epoch 00059: val_loss did not improve from 0.66692
# Epoch 60/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.3109 - accuracy: 0.9384 - val_loss: 0.7161 - val_accuracy: 0.8281
#
# Epoch 00060: val_loss did not improve from 0.66692
# Epoch 61/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2866 - accuracy: 0.9522 - val_loss: 0.7564 - val_accuracy: 0.8125
#
# Epoch 00061: val_loss did not improve from 0.66692
# Epoch 62/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2776 - accuracy: 0.9522 - val_loss: 0.7304 - val_accuracy: 0.8320
#
# Epoch 00062: val_loss did not improve from 0.66692
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 63/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2635 - accuracy: 0.9582 - val_loss: 0.6750 - val_accuracy: 0.8516
#
# Epoch 00063: val_loss did not improve from 0.66692
# Epoch 64/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.3617 - accuracy: 0.9237 - val_loss: 0.6762 - val_accuracy: 0.8281
#
# Epoch 00064: val_loss did not improve from 0.66692
# Epoch 65/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.2704 - accuracy: 0.9439 - val_loss: 0.6997 - val_accuracy: 0.8203
#
# Epoch 00065: val_loss did not improve from 0.66692
# Epoch 66/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2942 - accuracy: 0.9458 - val_loss: 0.6899 - val_accuracy: 0.8320
#
# Epoch 00066: val_loss did not improve from 0.66692
# Epoch 67/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3081 - accuracy: 0.9366 - val_loss: 0.7046 - val_accuracy: 0.8242
#
# Epoch 00067: val_loss did not improve from 0.66692
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 68/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2798 - accuracy: 0.9494 - val_loss: 0.6807 - val_accuracy: 0.8281
#
# Epoch 00068: val_loss did not improve from 0.66692
# Epoch 69/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2735 - accuracy: 0.9439 - val_loss: 0.7016 - val_accuracy: 0.8398
#
# Epoch 00069: val_loss did not improve from 0.66692
# Epoch 70/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2779 - accuracy: 0.9458 - val_loss: 0.6753 - val_accuracy: 0.8359
#
# Epoch 00070: val_loss did not improve from 0.66692
# Epoch 71/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.3262 - accuracy: 0.9338 - val_loss: 0.6911 - val_accuracy: 0.8438
#
# Epoch 00071: val_loss did not improve from 0.66692
# Epoch 72/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2933 - accuracy: 0.9435 - val_loss: 0.7001 - val_accuracy: 0.8438
#
# Epoch 00072: val_loss did not improve from 0.66692
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 73/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2091 - accuracy: 0.9683 - val_loss: 0.6814 - val_accuracy: 0.8516
#
# Epoch 00073: val_loss did not improve from 0.66692
# Epoch 74/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2277 - accuracy: 0.9623 - val_loss: 0.6993 - val_accuracy: 0.8477
#
# Epoch 00074: val_loss did not improve from 0.66692
# Epoch 75/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2647 - accuracy: 0.9499 - val_loss: 0.6753 - val_accuracy: 0.8438
#
# Epoch 00075: val_loss did not improve from 0.66692
# Epoch 76/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2865 - accuracy: 0.9426 - val_loss: 0.6640 - val_accuracy: 0.8359
#
# Epoch 00076: val_loss improved from 0.66692 to 0.66405, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2585 - accuracy: 0.9522 - val_loss: 0.6786 - val_accuracy: 0.8398
#
# Epoch 00077: val_loss did not improve from 0.66405
# Epoch 78/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2768 - accuracy: 0.9494 - val_loss: 0.6475 - val_accuracy: 0.8516
#
# Epoch 00078: val_loss improved from 0.66405 to 0.64755, saving model to ./save/cnn_gru_best.hdf5
# Epoch 79/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2205 - accuracy: 0.9655 - val_loss: 0.6647 - val_accuracy: 0.8516
#
# Epoch 00079: val_loss did not improve from 0.64755
# Epoch 80/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2402 - accuracy: 0.9563 - val_loss: 0.6872 - val_accuracy: 0.8438
#
# Epoch 00080: val_loss did not improve from 0.64755
# Epoch 81/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.2849 - accuracy: 0.9481 - val_loss: 0.6931 - val_accuracy: 0.8438
#
# Epoch 00081: val_loss did not improve from 0.64755
# Epoch 82/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2561 - accuracy: 0.9527 - val_loss: 0.6841 - val_accuracy: 0.8477
#
# Epoch 00082: val_loss did not improve from 0.64755
# Epoch 83/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2646 - accuracy: 0.9467 - val_loss: 0.6852 - val_accuracy: 0.8398
#
# Epoch 00083: val_loss did not improve from 0.64755
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 84/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2803 - accuracy: 0.9412 - val_loss: 0.6655 - val_accuracy: 0.8438
#
# Epoch 00084: val_loss did not improve from 0.64755
# Epoch 85/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2522 - accuracy: 0.9508 - val_loss: 0.6777 - val_accuracy: 0.8438
#
# Epoch 00085: val_loss did not improve from 0.64755
# Epoch 86/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2334 - accuracy: 0.9545 - val_loss: 0.6791 - val_accuracy: 0.8398
#
# Epoch 00086: val_loss did not improve from 0.64755
# Epoch 87/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.3029 - accuracy: 0.9389 - val_loss: 0.6989 - val_accuracy: 0.8359
#
# Epoch 00087: val_loss did not improve from 0.64755
# Epoch 88/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2463 - accuracy: 0.9628 - val_loss: 0.6953 - val_accuracy: 0.8359
#
# Epoch 00088: val_loss did not improve from 0.64755
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 89/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2851 - accuracy: 0.9453 - val_loss: 0.6977 - val_accuracy: 0.8398
#
# Epoch 00089: val_loss did not improve from 0.64755
# Epoch 90/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2860 - accuracy: 0.9453 - val_loss: 0.7078 - val_accuracy: 0.8359
#
# Epoch 00090: val_loss did not improve from 0.64755
# Epoch 91/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2371 - accuracy: 0.9577 - val_loss: 0.7045 - val_accuracy: 0.8359
#
# Epoch 00091: val_loss did not improve from 0.64755
# Epoch 92/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2397 - accuracy: 0.9628 - val_loss: 0.6752 - val_accuracy: 0.8516
#
# Epoch 00092: val_loss did not improve from 0.64755
# Epoch 93/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2490 - accuracy: 0.9536 - val_loss: 0.6934 - val_accuracy: 0.8438
#
# Epoch 00093: val_loss did not improve from 0.64755
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 94/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2417 - accuracy: 0.9540 - val_loss: 0.6781 - val_accuracy: 0.8477
#
# Epoch 00094: val_loss did not improve from 0.64755
# Epoch 95/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.2219 - accuracy: 0.9683 - val_loss: 0.6637 - val_accuracy: 0.8477
#
# Epoch 00095: val_loss did not improve from 0.64755
# Epoch 96/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2034 - accuracy: 0.9720 - val_loss: 0.6903 - val_accuracy: 0.8438
#
# Epoch 00096: val_loss did not improve from 0.64755
# Epoch 97/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2677 - accuracy: 0.9545 - val_loss: 0.6984 - val_accuracy: 0.8438
#
# Epoch 00097: val_loss did not improve from 0.64755
# Epoch 98/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2473 - accuracy: 0.9563 - val_loss: 0.6753 - val_accuracy: 0.8477
#
# Epoch 00098: val_loss did not improve from 0.64755
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 99/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2834 - accuracy: 0.9393 - val_loss: 0.6540 - val_accuracy: 0.8477
#
# Epoch 00099: val_loss did not improve from 0.64755
# Epoch 100/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2335 - accuracy: 0.9577 - val_loss: 0.6408 - val_accuracy: 0.8516
#
# Epoch 00100: val_loss improved from 0.64755 to 0.64080, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2721 - accuracy: 0.9444 - val_loss: 0.6851 - val_accuracy: 0.8398
#
# Epoch 00101: val_loss did not improve from 0.64080
# Epoch 102/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2586 - accuracy: 0.9540 - val_loss: 0.7001 - val_accuracy: 0.8359
#
# Epoch 00102: val_loss did not improve from 0.64080
# Epoch 103/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2368 - accuracy: 0.9582 - val_loss: 0.6950 - val_accuracy: 0.8359
#
# Epoch 00103: val_loss did not improve from 0.64080
# Epoch 104/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2435 - accuracy: 0.9554 - val_loss: 0.6919 - val_accuracy: 0.8438
#
# Epoch 00104: val_loss did not improve from 0.64080
# Epoch 105/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2737 - accuracy: 0.9444 - val_loss: 0.6879 - val_accuracy: 0.8438
#
# Epoch 00105: val_loss did not improve from 0.64080
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 106/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2648 - accuracy: 0.9490 - val_loss: 0.6505 - val_accuracy: 0.8438
#
# Epoch 00106: val_loss did not improve from 0.64080
# Epoch 107/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2307 - accuracy: 0.9605 - val_loss: 0.6969 - val_accuracy: 0.8359
#
# Epoch 00107: val_loss did not improve from 0.64080
# Epoch 108/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2345 - accuracy: 0.9545 - val_loss: 0.6481 - val_accuracy: 0.8516
#
# Epoch 00108: val_loss did not improve from 0.64080
# Epoch 109/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2356 - accuracy: 0.9536 - val_loss: 0.6966 - val_accuracy: 0.8398
#
# Epoch 00109: val_loss did not improve from 0.64080
# Epoch 110/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2638 - accuracy: 0.9499 - val_loss: 0.6620 - val_accuracy: 0.8398
#
# Epoch 00110: val_loss did not improve from 0.64080
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 111/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2261 - accuracy: 0.9642 - val_loss: 0.6599 - val_accuracy: 0.8516
#
# Epoch 00111: val_loss did not improve from 0.64080
# Epoch 112/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2634 - accuracy: 0.9430 - val_loss: 0.6773 - val_accuracy: 0.8477
#
# Epoch 00112: val_loss did not improve from 0.64080
# Epoch 113/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2870 - accuracy: 0.9403 - val_loss: 0.6968 - val_accuracy: 0.8398
#
# Epoch 00113: val_loss did not improve from 0.64080
# Epoch 114/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.2296 - accuracy: 0.9586 - val_loss: 0.6865 - val_accuracy: 0.8477
#
# Epoch 00114: val_loss did not improve from 0.64080
# Epoch 115/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2709 - accuracy: 0.9426 - val_loss: 0.6780 - val_accuracy: 0.8438
#
# Epoch 00115: val_loss did not improve from 0.64080
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 116/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2706 - accuracy: 0.9462 - val_loss: 0.6836 - val_accuracy: 0.8438
#
# Epoch 00116: val_loss did not improve from 0.64080
# Epoch 117/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2407 - accuracy: 0.9540 - val_loss: 0.7000 - val_accuracy: 0.8438
#
# Epoch 00117: val_loss did not improve from 0.64080
# Epoch 118/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2639 - accuracy: 0.9517 - val_loss: 0.6306 - val_accuracy: 0.8555
#
# Epoch 00118: val_loss improved from 0.64080 to 0.63058, saving model to ./save/cnn_gru_best.hdf5
# Epoch 119/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2860 - accuracy: 0.9416 - val_loss: 0.6959 - val_accuracy: 0.8438
#
# Epoch 00119: val_loss did not improve from 0.63058
# Epoch 120/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2781 - accuracy: 0.9398 - val_loss: 0.6983 - val_accuracy: 0.8438
#
# Epoch 00120: val_loss did not improve from 0.63058
# Epoch 121/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2337 - accuracy: 0.9600 - val_loss: 0.6674 - val_accuracy: 0.8477
#
# Epoch 00121: val_loss did not improve from 0.63058
# Epoch 122/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2652 - accuracy: 0.9508 - val_loss: 0.6993 - val_accuracy: 0.8398
#
# Epoch 00122: val_loss did not improve from 0.63058
# Epoch 123/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2823 - accuracy: 0.9426 - val_loss: 0.7030 - val_accuracy: 0.8398
#
# Epoch 00123: val_loss did not improve from 0.63058
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 124/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2412 - accuracy: 0.9540 - val_loss: 0.6995 - val_accuracy: 0.8398
#
# Epoch 00124: val_loss did not improve from 0.63058
# Epoch 125/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2472 - accuracy: 0.9550 - val_loss: 0.6605 - val_accuracy: 0.8477
#
# Epoch 00125: val_loss did not improve from 0.63058
# Epoch 126/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2716 - accuracy: 0.9435 - val_loss: 0.6595 - val_accuracy: 0.8555
#
# Epoch 00126: val_loss did not improve from 0.63058
# Epoch 127/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2325 - accuracy: 0.9609 - val_loss: 0.6993 - val_accuracy: 0.8398
#
# Epoch 00127: val_loss did not improve from 0.63058
# Epoch 128/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2632 - accuracy: 0.9490 - val_loss: 0.6941 - val_accuracy: 0.8438
#
# Epoch 00128: val_loss did not improve from 0.63058
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 129/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2507 - accuracy: 0.9554 - val_loss: 0.6981 - val_accuracy: 0.8398
#
# Epoch 00129: val_loss did not improve from 0.63058
# Epoch 130/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2377 - accuracy: 0.9554 - val_loss: 0.6622 - val_accuracy: 0.8438
#
# Epoch 00130: val_loss did not improve from 0.63058
# Epoch 131/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2430 - accuracy: 0.9568 - val_loss: 0.6864 - val_accuracy: 0.8398
#
# Epoch 00131: val_loss did not improve from 0.63058
# Epoch 132/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2912 - accuracy: 0.9375 - val_loss: 0.6886 - val_accuracy: 0.8398
#
# Epoch 00132: val_loss did not improve from 0.63058
# Epoch 133/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2590 - accuracy: 0.9531 - val_loss: 0.6870 - val_accuracy: 0.8516
#
# Epoch 00133: val_loss did not improve from 0.63058
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 134/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2172 - accuracy: 0.9632 - val_loss: 0.6991 - val_accuracy: 0.8398
#
# Epoch 00134: val_loss did not improve from 0.63058
# Epoch 135/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2602 - accuracy: 0.9485 - val_loss: 0.6421 - val_accuracy: 0.8516
#
# Epoch 00135: val_loss did not improve from 0.63058
# Epoch 136/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2596 - accuracy: 0.9499 - val_loss: 0.7001 - val_accuracy: 0.8438
#
# Epoch 00136: val_loss did not improve from 0.63058
# Epoch 137/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2682 - accuracy: 0.9499 - val_loss: 0.6965 - val_accuracy: 0.8438
#
# Epoch 00137: val_loss did not improve from 0.63058
# Epoch 138/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2120 - accuracy: 0.9701 - val_loss: 0.6907 - val_accuracy: 0.8477
#
# Epoch 00138: val_loss did not improve from 0.63058
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 139/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2358 - accuracy: 0.9619 - val_loss: 0.6854 - val_accuracy: 0.8477
#
# Epoch 00139: val_loss did not improve from 0.63058
# Epoch 140/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2750 - accuracy: 0.9494 - val_loss: 0.6900 - val_accuracy: 0.8477
#
# Epoch 00140: val_loss did not improve from 0.63058
# Epoch 141/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.2366 - accuracy: 0.9536 - val_loss: 0.6902 - val_accuracy: 0.8438
#
# Epoch 00141: val_loss did not improve from 0.63058
# Epoch 142/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2775 - accuracy: 0.9476 - val_loss: 0.6979 - val_accuracy: 0.8359
#
# Epoch 00142: val_loss did not improve from 0.63058
# Epoch 143/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2664 - accuracy: 0.9449 - val_loss: 0.6890 - val_accuracy: 0.8438
#
# Epoch 00143: val_loss did not improve from 0.63058
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 144/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.3042 - accuracy: 0.9361 - val_loss: 0.6993 - val_accuracy: 0.8359
#
# Epoch 00144: val_loss did not improve from 0.63058
# Epoch 145/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2243 - accuracy: 0.9651 - val_loss: 0.6794 - val_accuracy: 0.8398
#
# Epoch 00145: val_loss did not improve from 0.63058
# Epoch 146/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2568 - accuracy: 0.9499 - val_loss: 0.6962 - val_accuracy: 0.8398
#
# Epoch 00146: val_loss did not improve from 0.63058
# Epoch 147/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2669 - accuracy: 0.9435 - val_loss: 0.6988 - val_accuracy: 0.8398
#
# Epoch 00147: val_loss did not improve from 0.63058
# Epoch 148/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2320 - accuracy: 0.9619 - val_loss: 0.6551 - val_accuracy: 0.8477
#
# Epoch 00148: val_loss did not improve from 0.63058
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 00148: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5540 - accuracy: 0.8592
# [0.5540470480918884, 0.8592000007629395]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
