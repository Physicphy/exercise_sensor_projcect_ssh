# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 2 # #3#, ##5##, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      910         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 10)      1450        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 10)      730         concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 10)      730         concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1810        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      1810        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1810        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 5)       1805        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 10)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 10)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 10)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 5)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 10)      40          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 10)      40          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 10)      40          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 5)       20          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 20)      1920        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 20)      1920        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 20)      1920        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 10)      510         batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 20)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 20)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 20)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 10)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 20)      80          leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 20)      80          leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 20)      80          leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 10)      40          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      3660        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      3660        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      3660        batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      7260        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      7260        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 30)      1830        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 30)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 30)      120         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 60)      21960       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 60)      21960       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 60)      21960       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 30)      5580        batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 30)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 30)      120         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 510)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      275460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      275460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         add_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 928,526
# Trainable params: 924,896
# Non-trainable params: 3,630
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 53s 495ms/step - loss: 11.7514 - accuracy: 0.4099 - val_loss: 9.5748 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 9.57484, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 7.1096 - accuracy: 0.5630 - val_loss: 6.7479 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 9.57484 to 6.74788, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 4.4570 - accuracy: 0.6494 - val_loss: 5.4571 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 6.74788 to 5.45712, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 3.2460 - accuracy: 0.6590 - val_loss: 5.0704 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 5.45712 to 5.07038, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 2.4743 - accuracy: 0.6756 - val_loss: 5.2087 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss did not improve from 5.07038
# Epoch 6/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 1.9866 - accuracy: 0.6880 - val_loss: 4.5079 - val_accuracy: 0.4531
#
# Epoch 00006: val_loss improved from 5.07038 to 4.50794, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 1.6183 - accuracy: 0.7220 - val_loss: 4.4872 - val_accuracy: 0.3906
#
# Epoch 00007: val_loss improved from 4.50794 to 4.48716, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 1.4163 - accuracy: 0.7454 - val_loss: 4.8136 - val_accuracy: 0.4414
#
# Epoch 00008: val_loss did not improve from 4.48716
# Epoch 9/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 1.2252 - accuracy: 0.7642 - val_loss: 4.5044 - val_accuracy: 0.2188
#
# Epoch 00009: val_loss did not improve from 4.48716
# Epoch 10/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 1.2873 - accuracy: 0.7390 - val_loss: 4.3614 - val_accuracy: 0.3555
#
# Epoch 00010: val_loss improved from 4.48716 to 4.36135, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 1.2272 - accuracy: 0.7468 - val_loss: 5.2778 - val_accuracy: 0.1367
#
# Epoch 00011: val_loss did not improve from 4.36135
# Epoch 12/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 1.1923 - accuracy: 0.7500 - val_loss: 4.1255 - val_accuracy: 0.2812
#
# Epoch 00012: val_loss improved from 4.36135 to 4.12553, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 1.0943 - accuracy: 0.7730 - val_loss: 4.0123 - val_accuracy: 0.2969
#
# Epoch 00013: val_loss improved from 4.12553 to 4.01225, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 1.0270 - accuracy: 0.7757 - val_loss: 3.2837 - val_accuracy: 0.4688
#
# Epoch 00014: val_loss improved from 4.01225 to 3.28372, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 1.0077 - accuracy: 0.7794 - val_loss: 3.6849 - val_accuracy: 0.3477
#
# Epoch 00015: val_loss did not improve from 3.28372
# Epoch 16/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 1.0490 - accuracy: 0.7665 - val_loss: 3.3706 - val_accuracy: 0.3867
#
# Epoch 00016: val_loss did not improve from 3.28372
# Epoch 17/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 1.0672 - accuracy: 0.7675 - val_loss: 2.5469 - val_accuracy: 0.4883
#
# Epoch 00017: val_loss improved from 3.28372 to 2.54694, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.9132 - accuracy: 0.7973 - val_loss: 1.9371 - val_accuracy: 0.5977
#
# Epoch 00018: val_loss improved from 2.54694 to 1.93713, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.8953 - accuracy: 0.8015 - val_loss: 1.6095 - val_accuracy: 0.6602
#
# Epoch 00019: val_loss improved from 1.93713 to 1.60946, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 1.0568 - accuracy: 0.7569 - val_loss: 1.5233 - val_accuracy: 0.6836
#
# Epoch 00020: val_loss improved from 1.60946 to 1.52327, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.9387 - accuracy: 0.7868 - val_loss: 1.5957 - val_accuracy: 0.6641
#
# Epoch 00021: val_loss did not improve from 1.52327
# Epoch 22/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.8953 - accuracy: 0.8038 - val_loss: 1.6893 - val_accuracy: 0.6680
#
# Epoch 00022: val_loss did not improve from 1.52327
# Epoch 23/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.8685 - accuracy: 0.8130 - val_loss: 1.5070 - val_accuracy: 0.6836
#
# Epoch 00023: val_loss improved from 1.52327 to 1.50697, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.8594 - accuracy: 0.8111 - val_loss: 1.2795 - val_accuracy: 0.7266
#
# Epoch 00024: val_loss improved from 1.50697 to 1.27951, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.8129 - accuracy: 0.8180 - val_loss: 1.4494 - val_accuracy: 0.6875
#
# Epoch 00025: val_loss did not improve from 1.27951
# Epoch 26/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.8129 - accuracy: 0.8199 - val_loss: 1.2768 - val_accuracy: 0.7031
#
# Epoch 00026: val_loss improved from 1.27951 to 1.27682, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.8314 - accuracy: 0.8162 - val_loss: 1.1316 - val_accuracy: 0.7227
#
# Epoch 00027: val_loss improved from 1.27682 to 1.13158, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.8839 - accuracy: 0.7895 - val_loss: 1.4055 - val_accuracy: 0.6914
#
# Epoch 00028: val_loss did not improve from 1.13158
# Epoch 29/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.8810 - accuracy: 0.7969 - val_loss: 1.3782 - val_accuracy: 0.6992
#
# Epoch 00029: val_loss did not improve from 1.13158
# Epoch 30/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.7807 - accuracy: 0.8286 - val_loss: 1.1126 - val_accuracy: 0.7227
#
# Epoch 00030: val_loss improved from 1.13158 to 1.11255, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.7311 - accuracy: 0.8387 - val_loss: 1.1720 - val_accuracy: 0.7227
#
# Epoch 00031: val_loss did not improve from 1.11255
# Epoch 32/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 0.7734 - accuracy: 0.8244 - val_loss: 1.8730 - val_accuracy: 0.6016
#
# Epoch 00032: val_loss did not improve from 1.11255
# Epoch 33/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.7995 - accuracy: 0.8222 - val_loss: 1.2791 - val_accuracy: 0.6992
#
# Epoch 00033: val_loss did not improve from 1.11255
# Epoch 34/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.7392 - accuracy: 0.8350 - val_loss: 1.1179 - val_accuracy: 0.7773
#
# Epoch 00034: val_loss did not improve from 1.11255
# Epoch 35/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.8103 - accuracy: 0.8199 - val_loss: 1.5255 - val_accuracy: 0.6953
#
# Epoch 00035: val_loss did not improve from 1.11255
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 36/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.7271 - accuracy: 0.8382 - val_loss: 1.1239 - val_accuracy: 0.7422
#
# Epoch 00036: val_loss did not improve from 1.11255
# Epoch 37/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.6336 - accuracy: 0.8667 - val_loss: 1.0121 - val_accuracy: 0.7695
#
# Epoch 00037: val_loss improved from 1.11255 to 1.01212, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.5585 - accuracy: 0.8801 - val_loss: 0.9764 - val_accuracy: 0.7617
#
# Epoch 00038: val_loss improved from 1.01212 to 0.97645, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.5897 - accuracy: 0.8759 - val_loss: 0.8736 - val_accuracy: 0.8125
#
# Epoch 00039: val_loss improved from 0.97645 to 0.87360, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.5882 - accuracy: 0.8621 - val_loss: 0.9511 - val_accuracy: 0.7891
#
# Epoch 00040: val_loss did not improve from 0.87360
# Epoch 41/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.5676 - accuracy: 0.8741 - val_loss: 1.0559 - val_accuracy: 0.7812
#
# Epoch 00041: val_loss did not improve from 0.87360
# Epoch 42/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.6025 - accuracy: 0.8552 - val_loss: 0.9938 - val_accuracy: 0.7539
#
# Epoch 00042: val_loss did not improve from 0.87360
# Epoch 43/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.6077 - accuracy: 0.8580 - val_loss: 1.0414 - val_accuracy: 0.7656
#
# Epoch 00043: val_loss did not improve from 0.87360
# Epoch 44/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.4629 - accuracy: 0.9095 - val_loss: 0.9965 - val_accuracy: 0.7695
#
# Epoch 00044: val_loss did not improve from 0.87360
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 45/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.5353 - accuracy: 0.8796 - val_loss: 0.8933 - val_accuracy: 0.7852
#
# Epoch 00045: val_loss did not improve from 0.87360
# Epoch 46/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.3700 - accuracy: 0.9278 - val_loss: 0.8665 - val_accuracy: 0.7695
#
# Epoch 00046: val_loss improved from 0.87360 to 0.86652, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.4577 - accuracy: 0.8984 - val_loss: 0.9866 - val_accuracy: 0.7812
#
# Epoch 00047: val_loss did not improve from 0.86652
# Epoch 48/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.4092 - accuracy: 0.9145 - val_loss: 0.8174 - val_accuracy: 0.8086
#
# Epoch 00048: val_loss improved from 0.86652 to 0.81740, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.5942 - accuracy: 0.8557 - val_loss: 0.8888 - val_accuracy: 0.7891
#
# Epoch 00049: val_loss did not improve from 0.81740
# Epoch 50/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.5148 - accuracy: 0.8736 - val_loss: 0.8807 - val_accuracy: 0.7891
#
# Epoch 00050: val_loss did not improve from 0.81740
# Epoch 51/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3945 - accuracy: 0.9187 - val_loss: 0.7990 - val_accuracy: 0.8008
#
# Epoch 00051: val_loss improved from 0.81740 to 0.79899, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.4157 - accuracy: 0.9076 - val_loss: 0.8399 - val_accuracy: 0.8086
#
# Epoch 00052: val_loss did not improve from 0.79899
# Epoch 53/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.4010 - accuracy: 0.9136 - val_loss: 0.8300 - val_accuracy: 0.7891
#
# Epoch 00053: val_loss did not improve from 0.79899
# Epoch 54/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.4713 - accuracy: 0.8915 - val_loss: 0.8716 - val_accuracy: 0.7969
#
# Epoch 00054: val_loss did not improve from 0.79899
# Epoch 55/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.4423 - accuracy: 0.9021 - val_loss: 0.9272 - val_accuracy: 0.7773
#
# Epoch 00055: val_loss did not improve from 0.79899
# Epoch 56/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.4368 - accuracy: 0.8957 - val_loss: 0.8902 - val_accuracy: 0.8047
#
# Epoch 00056: val_loss did not improve from 0.79899
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 57/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3765 - accuracy: 0.9104 - val_loss: 0.8484 - val_accuracy: 0.7969
#
# Epoch 00057: val_loss did not improve from 0.79899
# Epoch 58/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.4133 - accuracy: 0.9081 - val_loss: 0.7997 - val_accuracy: 0.8047
#
# Epoch 00058: val_loss did not improve from 0.79899
# Epoch 59/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.3511 - accuracy: 0.9233 - val_loss: 0.7766 - val_accuracy: 0.8125
#
# Epoch 00059: val_loss improved from 0.79899 to 0.77657, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.3704 - accuracy: 0.9191 - val_loss: 0.8072 - val_accuracy: 0.8086
#
# Epoch 00060: val_loss did not improve from 0.77657
# Epoch 61/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.3870 - accuracy: 0.9127 - val_loss: 0.8230 - val_accuracy: 0.8008
#
# Epoch 00061: val_loss did not improve from 0.77657
# Epoch 62/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.3864 - accuracy: 0.9095 - val_loss: 0.8170 - val_accuracy: 0.7969
#
# Epoch 00062: val_loss did not improve from 0.77657
# Epoch 63/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3486 - accuracy: 0.9269 - val_loss: 0.9403 - val_accuracy: 0.7773
#
# Epoch 00063: val_loss did not improve from 0.77657
# Epoch 64/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.3765 - accuracy: 0.9044 - val_loss: 0.7928 - val_accuracy: 0.8164
#
# Epoch 00064: val_loss did not improve from 0.77657
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 65/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.3211 - accuracy: 0.9389 - val_loss: 0.8004 - val_accuracy: 0.8008
#
# Epoch 00065: val_loss did not improve from 0.77657
# Epoch 66/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.3393 - accuracy: 0.9260 - val_loss: 0.8358 - val_accuracy: 0.7930
#
# Epoch 00066: val_loss did not improve from 0.77657
# Epoch 67/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2710 - accuracy: 0.9517 - val_loss: 0.8213 - val_accuracy: 0.7969
#
# Epoch 00067: val_loss did not improve from 0.77657
# Epoch 68/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2932 - accuracy: 0.9393 - val_loss: 0.8183 - val_accuracy: 0.7969
#
# Epoch 00068: val_loss did not improve from 0.77657
# Epoch 69/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3047 - accuracy: 0.9343 - val_loss: 0.8038 - val_accuracy: 0.8164
#
# Epoch 00069: val_loss did not improve from 0.77657
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 70/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.3563 - accuracy: 0.9159 - val_loss: 0.8271 - val_accuracy: 0.8008
#
# Epoch 00070: val_loss did not improve from 0.77657
# Epoch 71/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3367 - accuracy: 0.9246 - val_loss: 0.7891 - val_accuracy: 0.8047
#
# Epoch 00071: val_loss did not improve from 0.77657
# Epoch 72/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3081 - accuracy: 0.9370 - val_loss: 0.7839 - val_accuracy: 0.8164
#
# Epoch 00072: val_loss did not improve from 0.77657
# Epoch 73/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3335 - accuracy: 0.9237 - val_loss: 0.7924 - val_accuracy: 0.7969
#
# Epoch 00073: val_loss did not improve from 0.77657
# Epoch 74/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.3251 - accuracy: 0.9320 - val_loss: 0.7979 - val_accuracy: 0.8008
#
# Epoch 00074: val_loss did not improve from 0.77657
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 75/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.2614 - accuracy: 0.9494 - val_loss: 0.7597 - val_accuracy: 0.8047
#
# Epoch 00075: val_loss improved from 0.77657 to 0.75970, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2973 - accuracy: 0.9384 - val_loss: 0.7435 - val_accuracy: 0.8086
#
# Epoch 00076: val_loss improved from 0.75970 to 0.74354, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2643 - accuracy: 0.9499 - val_loss: 0.7788 - val_accuracy: 0.8008
#
# Epoch 00077: val_loss did not improve from 0.74354
# Epoch 78/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2844 - accuracy: 0.9375 - val_loss: 0.7579 - val_accuracy: 0.8008
#
# Epoch 00078: val_loss did not improve from 0.74354
# Epoch 79/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.3931 - accuracy: 0.9030 - val_loss: 0.7948 - val_accuracy: 0.7969
#
# Epoch 00079: val_loss did not improve from 0.74354
# Epoch 80/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3076 - accuracy: 0.9338 - val_loss: 0.7964 - val_accuracy: 0.7930
#
# Epoch 00080: val_loss did not improve from 0.74354
# Epoch 81/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2996 - accuracy: 0.9366 - val_loss: 0.7555 - val_accuracy: 0.8008
#
# Epoch 00081: val_loss did not improve from 0.74354
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 82/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2904 - accuracy: 0.9352 - val_loss: 0.7400 - val_accuracy: 0.8047
#
# Epoch 00082: val_loss improved from 0.74354 to 0.73995, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.2322 - accuracy: 0.9573 - val_loss: 0.7586 - val_accuracy: 0.7969
#
# Epoch 00083: val_loss did not improve from 0.73995
# Epoch 84/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2454 - accuracy: 0.9545 - val_loss: 0.7824 - val_accuracy: 0.7930
#
# Epoch 00084: val_loss did not improve from 0.73995
# Epoch 85/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.2361 - accuracy: 0.9568 - val_loss: 0.7599 - val_accuracy: 0.8008
#
# Epoch 00085: val_loss did not improve from 0.73995
# Epoch 86/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.2201 - accuracy: 0.9614 - val_loss: 0.7683 - val_accuracy: 0.7930
#
# Epoch 00086: val_loss did not improve from 0.73995
# Epoch 87/2000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.3388 - accuracy: 0.9214 - val_loss: 0.7719 - val_accuracy: 0.7969
#
# Epoch 00087: val_loss did not improve from 0.73995
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 88/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.3086 - accuracy: 0.9315 - val_loss: 0.7931 - val_accuracy: 0.7891
#
# Epoch 00088: val_loss did not improve from 0.73995
# Epoch 89/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.2725 - accuracy: 0.9430 - val_loss: 0.7689 - val_accuracy: 0.7969
#
# Epoch 00089: val_loss did not improve from 0.73995
# Epoch 90/2000
# 34/34 [==============================] - 11s 307ms/step - loss: 0.2686 - accuracy: 0.9449 - val_loss: 0.7484 - val_accuracy: 0.8086
#
# Epoch 00090: val_loss did not improve from 0.73995
# Epoch 91/2000
# 34/34 [==============================] - 11s 307ms/step - loss: 0.2815 - accuracy: 0.9366 - val_loss: 0.7462 - val_accuracy: 0.8086
#
# Epoch 00091: val_loss did not improve from 0.73995
# Epoch 92/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2610 - accuracy: 0.9517 - val_loss: 0.7546 - val_accuracy: 0.8086
#
# Epoch 00092: val_loss did not improve from 0.73995
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 93/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2971 - accuracy: 0.9384 - val_loss: 0.7664 - val_accuracy: 0.8008
#
# Epoch 00093: val_loss did not improve from 0.73995
# Epoch 94/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.2432 - accuracy: 0.9531 - val_loss: 0.7727 - val_accuracy: 0.8008
#
# Epoch 00094: val_loss did not improve from 0.73995
# Epoch 95/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.2567 - accuracy: 0.9527 - val_loss: 0.7699 - val_accuracy: 0.8008
#
# Epoch 00095: val_loss did not improve from 0.73995
# Epoch 96/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3015 - accuracy: 0.9334 - val_loss: 0.7453 - val_accuracy: 0.8008
#
# Epoch 00096: val_loss did not improve from 0.73995
# Epoch 97/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.3350 - accuracy: 0.9219 - val_loss: 0.7931 - val_accuracy: 0.8047
#
# Epoch 00097: val_loss did not improve from 0.73995
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 98/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.2684 - accuracy: 0.9449 - val_loss: 0.7525 - val_accuracy: 0.8164
#
# Epoch 00098: val_loss did not improve from 0.73995
# Epoch 99/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.3149 - accuracy: 0.9320 - val_loss: 0.7621 - val_accuracy: 0.8125
#
# Epoch 00099: val_loss did not improve from 0.73995
# Epoch 100/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2531 - accuracy: 0.9462 - val_loss: 0.7285 - val_accuracy: 0.8125
#
# Epoch 00100: val_loss improved from 0.73995 to 0.72852, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.2669 - accuracy: 0.9449 - val_loss: 0.7912 - val_accuracy: 0.8008
#
# Epoch 00101: val_loss did not improve from 0.72852
# Epoch 102/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2903 - accuracy: 0.9412 - val_loss: 0.7541 - val_accuracy: 0.8047
#
# Epoch 00102: val_loss did not improve from 0.72852
# Epoch 103/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.3133 - accuracy: 0.9301 - val_loss: 0.7615 - val_accuracy: 0.8086
#
# Epoch 00103: val_loss did not improve from 0.72852
# Epoch 104/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.2427 - accuracy: 0.9540 - val_loss: 0.7727 - val_accuracy: 0.7969
#
# Epoch 00104: val_loss did not improve from 0.72852
# Epoch 105/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2863 - accuracy: 0.9403 - val_loss: 0.7479 - val_accuracy: 0.8047
#
# Epoch 00105: val_loss did not improve from 0.72852
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 106/2000
# 34/34 [==============================] - 11s 307ms/step - loss: 0.2763 - accuracy: 0.9435 - val_loss: 0.6983 - val_accuracy: 0.8086
#
# Epoch 00106: val_loss improved from 0.72852 to 0.69825, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.2481 - accuracy: 0.9504 - val_loss: 0.7170 - val_accuracy: 0.8047
#
# Epoch 00107: val_loss did not improve from 0.69825
# Epoch 108/2000
# 34/34 [==============================] - 11s 307ms/step - loss: 0.2697 - accuracy: 0.9398 - val_loss: 0.6891 - val_accuracy: 0.8125
#
# Epoch 00108: val_loss improved from 0.69825 to 0.68909, saving model to ./save/cnn_gru_best.hdf5
# Epoch 109/2000
# 34/34 [==============================] - 11s 309ms/step - loss: 0.2977 - accuracy: 0.9380 - val_loss: 0.7149 - val_accuracy: 0.8086
#
# Epoch 00109: val_loss did not improve from 0.68909
# Epoch 110/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.2694 - accuracy: 0.9449 - val_loss: 0.7555 - val_accuracy: 0.8086
#
# Epoch 00110: val_loss did not improve from 0.68909
# Epoch 111/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.3361 - accuracy: 0.9210 - val_loss: 0.7771 - val_accuracy: 0.8047
#
# Epoch 00111: val_loss did not improve from 0.68909
# Epoch 112/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.2676 - accuracy: 0.9485 - val_loss: 0.7834 - val_accuracy: 0.8008
#
# Epoch 00112: val_loss did not improve from 0.68909
# Epoch 113/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2692 - accuracy: 0.9467 - val_loss: 0.7532 - val_accuracy: 0.8125
#
# Epoch 00113: val_loss did not improve from 0.68909
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 114/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.2963 - accuracy: 0.9292 - val_loss: 0.7871 - val_accuracy: 0.8008
#
# Epoch 00114: val_loss did not improve from 0.68909
# Epoch 115/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2639 - accuracy: 0.9472 - val_loss: 0.7560 - val_accuracy: 0.7969
#
# Epoch 00115: val_loss did not improve from 0.68909
# Epoch 116/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2670 - accuracy: 0.9458 - val_loss: 0.7669 - val_accuracy: 0.7969
#
# Epoch 00116: val_loss did not improve from 0.68909
# Epoch 117/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.3043 - accuracy: 0.9334 - val_loss: 0.7545 - val_accuracy: 0.8086
#
# Epoch 00117: val_loss did not improve from 0.68909
# Epoch 118/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2565 - accuracy: 0.9476 - val_loss: 0.7553 - val_accuracy: 0.8008
#
# Epoch 00118: val_loss did not improve from 0.68909
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 119/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2906 - accuracy: 0.9361 - val_loss: 0.7983 - val_accuracy: 0.7930
#
# Epoch 00119: val_loss did not improve from 0.68909
# Epoch 120/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.3418 - accuracy: 0.9154 - val_loss: 0.8031 - val_accuracy: 0.8047
#
# Epoch 00120: val_loss did not improve from 0.68909
# Epoch 121/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.3249 - accuracy: 0.9242 - val_loss: 0.7890 - val_accuracy: 0.8047
#
# Epoch 00121: val_loss did not improve from 0.68909
# Epoch 122/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2515 - accuracy: 0.9472 - val_loss: 0.7395 - val_accuracy: 0.8086
#
# Epoch 00122: val_loss did not improve from 0.68909
# Epoch 123/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.3028 - accuracy: 0.9288 - val_loss: 0.7665 - val_accuracy: 0.8086
#
# Epoch 00123: val_loss did not improve from 0.68909
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 124/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2922 - accuracy: 0.9357 - val_loss: 0.7753 - val_accuracy: 0.8086
#
# Epoch 00124: val_loss did not improve from 0.68909
# Epoch 125/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2943 - accuracy: 0.9421 - val_loss: 0.7941 - val_accuracy: 0.7969
#
# Epoch 00125: val_loss did not improve from 0.68909
# Epoch 126/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2856 - accuracy: 0.9343 - val_loss: 0.7872 - val_accuracy: 0.8008
#
# Epoch 00126: val_loss did not improve from 0.68909
# Epoch 127/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.3273 - accuracy: 0.9274 - val_loss: 0.7792 - val_accuracy: 0.8047
#
# Epoch 00127: val_loss did not improve from 0.68909
# Epoch 128/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2472 - accuracy: 0.9504 - val_loss: 0.7361 - val_accuracy: 0.8125
#
# Epoch 00128: val_loss did not improve from 0.68909
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 129/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2899 - accuracy: 0.9412 - val_loss: 0.7982 - val_accuracy: 0.7930
#
# Epoch 00129: val_loss did not improve from 0.68909
# Epoch 130/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2303 - accuracy: 0.9577 - val_loss: 0.7936 - val_accuracy: 0.7891
#
# Epoch 00130: val_loss did not improve from 0.68909
# Epoch 131/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2984 - accuracy: 0.9329 - val_loss: 0.7730 - val_accuracy: 0.8047
#
# Epoch 00131: val_loss did not improve from 0.68909
# Epoch 132/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2890 - accuracy: 0.9311 - val_loss: 0.7569 - val_accuracy: 0.8125
#
# Epoch 00132: val_loss did not improve from 0.68909
# Epoch 133/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.3000 - accuracy: 0.9357 - val_loss: 0.7780 - val_accuracy: 0.8008
#
# Epoch 00133: val_loss did not improve from 0.68909
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 134/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2908 - accuracy: 0.9393 - val_loss: 0.7759 - val_accuracy: 0.8008
#
# Epoch 00134: val_loss did not improve from 0.68909
# Epoch 135/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2897 - accuracy: 0.9393 - val_loss: 0.7812 - val_accuracy: 0.8008
#
# Epoch 00135: val_loss did not improve from 0.68909
# Epoch 136/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3005 - accuracy: 0.9370 - val_loss: 0.7818 - val_accuracy: 0.8047
#
# Epoch 00136: val_loss did not improve from 0.68909
# Epoch 137/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2959 - accuracy: 0.9366 - val_loss: 0.7760 - val_accuracy: 0.8086
#
# Epoch 00137: val_loss did not improve from 0.68909
# Epoch 138/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.2456 - accuracy: 0.9499 - val_loss: 0.7467 - val_accuracy: 0.8047
#
# Epoch 00138: val_loss did not improve from 0.68909
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 00138: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6097 - accuracy: 0.8496
# [0.6096840500831604, 0.8496000170707703]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
