# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset #, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 15 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# _______________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      1460        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1020)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_59[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_62[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 150, 60)      240         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 150, 120)     480         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 150, 60)      240         conv1d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_65[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 150, 60)      240         conv1d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 150, 120)     480         conv1d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 150, 60)      240         conv1d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_68[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 150, 60)      240         conv1d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 150, 120)     480         conv1d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 150, 60)      240         conv1d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_71[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 150, 60)      240         conv1d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 150, 120)     480         conv1d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 150, 60)      240         conv1d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_74[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 150, 60)      32460       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 150, 60)      240         conv1d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 150, 120)     480         conv1d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 150, 60)      240         conv1d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 150, 60)      0           leaky_re_lu_77[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 150, 60)      32460       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 150, 60)      240         conv1d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 150, 120)     480         conv1d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 150, 60)      240         conv1d_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 150, 60)      0           leaky_re_lu_80[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 150, 60)      32460       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 150, 60)      240         conv1d_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 150, 120)     480         conv1d_59[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 150, 60)      240         conv1d_60[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 150, 60)      0           leaky_re_lu_83[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 150, 60)      32460       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 150, 60)      240         conv1d_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 150, 120)     480         conv1d_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_85 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 150, 60)      240         conv1d_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_86 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 150, 60)      0           leaky_re_lu_86[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 150, 60)      32460       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 150, 60)      240         conv1d_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_87 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 150, 120)     480         conv1d_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_88 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 150, 60)      240         conv1d_66[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_89 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 150, 60)      0           leaky_re_lu_89[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 150, 60)      32460       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 150, 60)      240         conv1d_67[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_90 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 150, 120)     480         conv1d_68[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_91 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 150, 60)      240         conv1d_69[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_92 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 150, 60)      0           leaky_re_lu_92[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 150, 60)      240         add_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 3,191,931
# Trainable params: 3,179,511
# Non-trainable params: 12,420
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 62s 577ms/step - loss: 57.3972 - accuracy: 0.3865 - val_loss: 40.2252 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 40.22521, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 28.7133 - accuracy: 0.5689 - val_loss: 20.9288 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 40.22521 to 20.92881, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 14.5025 - accuracy: 0.6282 - val_loss: 11.8739 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 20.92881 to 11.87388, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 7.8713 - accuracy: 0.6347 - val_loss: 8.0515 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 11.87388 to 8.05147, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 4.5647 - accuracy: 0.6645 - val_loss: 6.4065 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 8.05147 to 6.40654, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 2.9177 - accuracy: 0.6806 - val_loss: 5.0056 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 6.40654 to 5.00560, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 2.0518 - accuracy: 0.7142 - val_loss: 5.0180 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss did not improve from 5.00560
# Epoch 8/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 1.6298 - accuracy: 0.7266 - val_loss: 4.5787 - val_accuracy: 0.3828
#
# Epoch 00008: val_loss improved from 5.00560 to 4.57875, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 13s 378ms/step - loss: 1.4032 - accuracy: 0.7505 - val_loss: 4.2999 - val_accuracy: 0.4570
#
# Epoch 00009: val_loss improved from 4.57875 to 4.29993, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 1.4102 - accuracy: 0.7302 - val_loss: 5.2289 - val_accuracy: 0.1641
#
# Epoch 00010: val_loss did not improve from 4.29993
# Epoch 11/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 1.3131 - accuracy: 0.7449 - val_loss: 4.8542 - val_accuracy: 0.4023
#
# Epoch 00011: val_loss did not improve from 4.29993
# Epoch 12/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 1.2809 - accuracy: 0.7463 - val_loss: 4.9629 - val_accuracy: 0.1797
#
# Epoch 00012: val_loss did not improve from 4.29993
# Epoch 13/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 1.1849 - accuracy: 0.7702 - val_loss: 4.3584 - val_accuracy: 0.3555
#
# Epoch 00013: val_loss did not improve from 4.29993
# Epoch 14/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 1.1272 - accuracy: 0.7725 - val_loss: 4.6814 - val_accuracy: 0.1992
#
# Epoch 00014: val_loss did not improve from 4.29993
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 1.0442 - accuracy: 0.7918 - val_loss: 4.1273 - val_accuracy: 0.3125
#
# Epoch 00015: val_loss improved from 4.29993 to 4.12730, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.9412 - accuracy: 0.8015 - val_loss: 3.2842 - val_accuracy: 0.4414
#
# Epoch 00016: val_loss improved from 4.12730 to 3.28425, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.9407 - accuracy: 0.7996 - val_loss: 2.3479 - val_accuracy: 0.5312
#
# Epoch 00017: val_loss improved from 3.28425 to 2.34795, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.8521 - accuracy: 0.8272 - val_loss: 1.8382 - val_accuracy: 0.5977
#
# Epoch 00018: val_loss improved from 2.34795 to 1.83820, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.7860 - accuracy: 0.8433 - val_loss: 1.8417 - val_accuracy: 0.6289
#
# Epoch 00019: val_loss did not improve from 1.83820
# Epoch 20/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.9753 - accuracy: 0.7900 - val_loss: 1.6128 - val_accuracy: 0.6875
#
# Epoch 00020: val_loss improved from 1.83820 to 1.61283, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.8984 - accuracy: 0.8028 - val_loss: 1.2263 - val_accuracy: 0.7383
#
# Epoch 00021: val_loss improved from 1.61283 to 1.22634, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.8278 - accuracy: 0.8263 - val_loss: 1.2228 - val_accuracy: 0.7422
#
# Epoch 00022: val_loss improved from 1.22634 to 1.22277, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.8160 - accuracy: 0.8346 - val_loss: 1.3708 - val_accuracy: 0.6875
#
# Epoch 00023: val_loss did not improve from 1.22277
# Epoch 24/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.7832 - accuracy: 0.8350 - val_loss: 1.1671 - val_accuracy: 0.7539
#
# Epoch 00024: val_loss improved from 1.22277 to 1.16706, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.7552 - accuracy: 0.8442 - val_loss: 1.3684 - val_accuracy: 0.7266
#
# Epoch 00025: val_loss did not improve from 1.16706
# Epoch 26/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.7568 - accuracy: 0.8433 - val_loss: 1.1276 - val_accuracy: 0.7891
#
# Epoch 00026: val_loss improved from 1.16706 to 1.12761, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.7810 - accuracy: 0.8428 - val_loss: 1.3018 - val_accuracy: 0.7148
#
# Epoch 00027: val_loss did not improve from 1.12761
# Epoch 28/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.8453 - accuracy: 0.8240 - val_loss: 1.2717 - val_accuracy: 0.7148
#
# Epoch 00028: val_loss did not improve from 1.12761
# Epoch 29/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.8399 - accuracy: 0.8176 - val_loss: 1.3153 - val_accuracy: 0.7422
#
# Epoch 00029: val_loss did not improve from 1.12761
# Epoch 30/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.7418 - accuracy: 0.8534 - val_loss: 1.1023 - val_accuracy: 0.7656
#
# Epoch 00030: val_loss improved from 1.12761 to 1.10233, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.6874 - accuracy: 0.8690 - val_loss: 1.1402 - val_accuracy: 0.7266
#
# Epoch 00031: val_loss did not improve from 1.10233
# Epoch 32/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.7001 - accuracy: 0.8502 - val_loss: 1.2098 - val_accuracy: 0.7305
#
# Epoch 00032: val_loss did not improve from 1.10233
# Epoch 33/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.7280 - accuracy: 0.8483 - val_loss: 1.4415 - val_accuracy: 0.7227
#
# Epoch 00033: val_loss did not improve from 1.10233
# Epoch 34/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.6872 - accuracy: 0.8699 - val_loss: 1.1461 - val_accuracy: 0.7578
#
# Epoch 00034: val_loss did not improve from 1.10233
# Epoch 35/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.7304 - accuracy: 0.8566 - val_loss: 1.0666 - val_accuracy: 0.7695
#
# Epoch 00035: val_loss improved from 1.10233 to 1.06664, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.7654 - accuracy: 0.8419 - val_loss: 1.2683 - val_accuracy: 0.7344
#
# Epoch 00036: val_loss did not improve from 1.06664
# Epoch 37/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.7194 - accuracy: 0.8594 - val_loss: 1.2696 - val_accuracy: 0.7188
#
# Epoch 00037: val_loss did not improve from 1.06664
# Epoch 38/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.6567 - accuracy: 0.8764 - val_loss: 1.5113 - val_accuracy: 0.7070
#
# Epoch 00038: val_loss did not improve from 1.06664
# Epoch 39/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.6798 - accuracy: 0.8649 - val_loss: 1.0368 - val_accuracy: 0.7891
#
# Epoch 00039: val_loss improved from 1.06664 to 1.03679, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.6789 - accuracy: 0.8722 - val_loss: 1.1380 - val_accuracy: 0.7852
#
# Epoch 00040: val_loss did not improve from 1.03679
# Epoch 41/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.6760 - accuracy: 0.8718 - val_loss: 1.1585 - val_accuracy: 0.7617
#
# Epoch 00041: val_loss did not improve from 1.03679
# Epoch 42/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.6941 - accuracy: 0.8497 - val_loss: 1.6740 - val_accuracy: 0.6797
#
# Epoch 00042: val_loss did not improve from 1.03679
# Epoch 43/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.6815 - accuracy: 0.8681 - val_loss: 1.1517 - val_accuracy: 0.7500
#
# Epoch 00043: val_loss did not improve from 1.03679
# Epoch 44/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.5521 - accuracy: 0.9030 - val_loss: 1.1677 - val_accuracy: 0.7383
#
# Epoch 00044: val_loss did not improve from 1.03679
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 45/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.6036 - accuracy: 0.8709 - val_loss: 1.0814 - val_accuracy: 0.7695
#
# Epoch 00045: val_loss did not improve from 1.03679
# Epoch 46/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.4077 - accuracy: 0.9384 - val_loss: 1.1397 - val_accuracy: 0.7500
#
# Epoch 00046: val_loss did not improve from 1.03679
# Epoch 47/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.4965 - accuracy: 0.8966 - val_loss: 1.0450 - val_accuracy: 0.7578
#
# Epoch 00047: val_loss did not improve from 1.03679
# Epoch 48/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.4385 - accuracy: 0.9200 - val_loss: 0.9749 - val_accuracy: 0.7812
#
# Epoch 00048: val_loss improved from 1.03679 to 0.97488, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.6116 - accuracy: 0.8649 - val_loss: 1.0331 - val_accuracy: 0.7617
#
# Epoch 00049: val_loss did not improve from 0.97488
# Epoch 50/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.5642 - accuracy: 0.8791 - val_loss: 0.9476 - val_accuracy: 0.7773
#
# Epoch 00050: val_loss improved from 0.97488 to 0.94762, saving model to ./save/cnn_gru_best.hdf5
# Epoch 51/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.4338 - accuracy: 0.9205 - val_loss: 0.9084 - val_accuracy: 0.7812
#
# Epoch 00051: val_loss improved from 0.94762 to 0.90838, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.4486 - accuracy: 0.9131 - val_loss: 0.9058 - val_accuracy: 0.8086
#
# Epoch 00052: val_loss improved from 0.90838 to 0.90580, saving model to ./save/cnn_gru_best.hdf5
# Epoch 53/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.4445 - accuracy: 0.9127 - val_loss: 0.9583 - val_accuracy: 0.7852
#
# Epoch 00053: val_loss did not improve from 0.90580
# Epoch 54/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.4982 - accuracy: 0.8984 - val_loss: 1.0626 - val_accuracy: 0.7695
#
# Epoch 00054: val_loss did not improve from 0.90580
# Epoch 55/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.4645 - accuracy: 0.9053 - val_loss: 1.0066 - val_accuracy: 0.7812
#
# Epoch 00055: val_loss did not improve from 0.90580
# Epoch 56/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.4887 - accuracy: 0.9012 - val_loss: 1.0527 - val_accuracy: 0.7969
#
# Epoch 00056: val_loss did not improve from 0.90580
# Epoch 57/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.4206 - accuracy: 0.9196 - val_loss: 1.0560 - val_accuracy: 0.7891
#
# Epoch 00057: val_loss did not improve from 0.90580
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 58/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.4490 - accuracy: 0.9136 - val_loss: 0.9548 - val_accuracy: 0.8008
#
# Epoch 00058: val_loss did not improve from 0.90580
# Epoch 59/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.3785 - accuracy: 0.9288 - val_loss: 0.9006 - val_accuracy: 0.8047
#
# Epoch 00059: val_loss improved from 0.90580 to 0.90057, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.3755 - accuracy: 0.9306 - val_loss: 0.9258 - val_accuracy: 0.8008
#
# Epoch 00060: val_loss did not improve from 0.90057
# Epoch 61/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.3929 - accuracy: 0.9242 - val_loss: 0.9041 - val_accuracy: 0.8008
#
# Epoch 00061: val_loss did not improve from 0.90057
# Epoch 62/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.3841 - accuracy: 0.9214 - val_loss: 0.9002 - val_accuracy: 0.7695
#
# Epoch 00062: val_loss improved from 0.90057 to 0.90016, saving model to ./save/cnn_gru_best.hdf5
# Epoch 63/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.3349 - accuracy: 0.9380 - val_loss: 0.9687 - val_accuracy: 0.7852
#
# Epoch 00063: val_loss did not improve from 0.90016
# Epoch 64/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.3724 - accuracy: 0.9242 - val_loss: 0.8702 - val_accuracy: 0.8047
#
# Epoch 00064: val_loss improved from 0.90016 to 0.87017, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.3451 - accuracy: 0.9366 - val_loss: 0.9412 - val_accuracy: 0.7969
#
# Epoch 00065: val_loss did not improve from 0.87017
# Epoch 66/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.3593 - accuracy: 0.9315 - val_loss: 0.9620 - val_accuracy: 0.7656
#
# Epoch 00066: val_loss did not improve from 0.87017
# Epoch 67/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2983 - accuracy: 0.9490 - val_loss: 0.8701 - val_accuracy: 0.8125
#
# Epoch 00067: val_loss improved from 0.87017 to 0.87010, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.3029 - accuracy: 0.9453 - val_loss: 0.9134 - val_accuracy: 0.7852
#
# Epoch 00068: val_loss did not improve from 0.87010
# Epoch 69/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.3451 - accuracy: 0.9251 - val_loss: 1.0197 - val_accuracy: 0.7930
#
# Epoch 00069: val_loss did not improve from 0.87010
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 70/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.3531 - accuracy: 0.9301 - val_loss: 0.9330 - val_accuracy: 0.7734
#
# Epoch 00070: val_loss did not improve from 0.87010
# Epoch 71/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.3280 - accuracy: 0.9357 - val_loss: 0.9164 - val_accuracy: 0.7852
#
# Epoch 00071: val_loss did not improve from 0.87010
# Epoch 72/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.3036 - accuracy: 0.9407 - val_loss: 0.9217 - val_accuracy: 0.7969
#
# Epoch 00072: val_loss did not improve from 0.87010
# Epoch 73/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.3162 - accuracy: 0.9338 - val_loss: 0.8899 - val_accuracy: 0.7930
#
# Epoch 00073: val_loss did not improve from 0.87010
# Epoch 74/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.3129 - accuracy: 0.9361 - val_loss: 0.9114 - val_accuracy: 0.7891
#
# Epoch 00074: val_loss did not improve from 0.87010
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 75/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2508 - accuracy: 0.9527 - val_loss: 0.8550 - val_accuracy: 0.8125
#
# Epoch 00075: val_loss improved from 0.87010 to 0.85499, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2721 - accuracy: 0.9527 - val_loss: 0.8182 - val_accuracy: 0.7969
#
# Epoch 00076: val_loss improved from 0.85499 to 0.81818, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2585 - accuracy: 0.9527 - val_loss: 0.8510 - val_accuracy: 0.7969
#
# Epoch 00077: val_loss did not improve from 0.81818
# Epoch 78/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2493 - accuracy: 0.9591 - val_loss: 0.8477 - val_accuracy: 0.7930
#
# Epoch 00078: val_loss did not improve from 0.81818
# Epoch 79/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.3464 - accuracy: 0.9283 - val_loss: 0.8591 - val_accuracy: 0.7930
#
# Epoch 00079: val_loss did not improve from 0.81818
# Epoch 80/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2707 - accuracy: 0.9494 - val_loss: 0.8164 - val_accuracy: 0.8008
#
# Epoch 00080: val_loss improved from 0.81818 to 0.81639, saving model to ./save/cnn_gru_best.hdf5
# Epoch 81/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.2726 - accuracy: 0.9494 - val_loss: 0.8003 - val_accuracy: 0.8047
#
# Epoch 00081: val_loss improved from 0.81639 to 0.80034, saving model to ./save/cnn_gru_best.hdf5
# Epoch 82/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2513 - accuracy: 0.9573 - val_loss: 0.8043 - val_accuracy: 0.8125
#
# Epoch 00082: val_loss did not improve from 0.80034
# Epoch 83/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2169 - accuracy: 0.9637 - val_loss: 0.8183 - val_accuracy: 0.8164
#
# Epoch 00083: val_loss did not improve from 0.80034
# Epoch 84/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2233 - accuracy: 0.9646 - val_loss: 0.8939 - val_accuracy: 0.8047
#
# Epoch 00084: val_loss did not improve from 0.80034
# Epoch 85/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2046 - accuracy: 0.9609 - val_loss: 0.8534 - val_accuracy: 0.8086
#
# Epoch 00085: val_loss did not improve from 0.80034
# Epoch 86/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.1896 - accuracy: 0.9697 - val_loss: 0.8649 - val_accuracy: 0.8086
#
# Epoch 00086: val_loss did not improve from 0.80034
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 87/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2833 - accuracy: 0.9407 - val_loss: 0.8208 - val_accuracy: 0.8008
#
# Epoch 00087: val_loss did not improve from 0.80034
# Epoch 88/2000
# 34/34 [==============================] - 13s 377ms/step - loss: 0.2608 - accuracy: 0.9522 - val_loss: 0.8537 - val_accuracy: 0.8086
#
# Epoch 00088: val_loss did not improve from 0.80034
# Epoch 89/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2252 - accuracy: 0.9614 - val_loss: 0.8293 - val_accuracy: 0.8047
#
# Epoch 00089: val_loss did not improve from 0.80034
# Epoch 90/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2409 - accuracy: 0.9527 - val_loss: 0.8395 - val_accuracy: 0.8086
#
# Epoch 00090: val_loss did not improve from 0.80034
# Epoch 91/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2360 - accuracy: 0.9540 - val_loss: 0.8005 - val_accuracy: 0.8125
#
# Epoch 00091: val_loss did not improve from 0.80034
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 92/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2183 - accuracy: 0.9582 - val_loss: 0.8340 - val_accuracy: 0.8203
#
# Epoch 00092: val_loss did not improve from 0.80034
# Epoch 93/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2592 - accuracy: 0.9517 - val_loss: 0.8076 - val_accuracy: 0.8125
#
# Epoch 00093: val_loss did not improve from 0.80034
# Epoch 94/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.1967 - accuracy: 0.9646 - val_loss: 0.8336 - val_accuracy: 0.7969
#
# Epoch 00094: val_loss did not improve from 0.80034
# Epoch 95/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2200 - accuracy: 0.9609 - val_loss: 0.8427 - val_accuracy: 0.8008
#
# Epoch 00095: val_loss did not improve from 0.80034
# Epoch 96/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2571 - accuracy: 0.9458 - val_loss: 0.8069 - val_accuracy: 0.8047
#
# Epoch 00096: val_loss did not improve from 0.80034
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 97/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2820 - accuracy: 0.9444 - val_loss: 0.8761 - val_accuracy: 0.7930
#
# Epoch 00097: val_loss did not improve from 0.80034
# Epoch 98/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2135 - accuracy: 0.9678 - val_loss: 0.8041 - val_accuracy: 0.8164
#
# Epoch 00098: val_loss did not improve from 0.80034
# Epoch 99/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.2456 - accuracy: 0.9517 - val_loss: 0.8101 - val_accuracy: 0.8164
#
# Epoch 00099: val_loss did not improve from 0.80034
# Epoch 100/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.1979 - accuracy: 0.9683 - val_loss: 0.7959 - val_accuracy: 0.8164
#
# Epoch 00100: val_loss improved from 0.80034 to 0.79595, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2052 - accuracy: 0.9609 - val_loss: 0.8559 - val_accuracy: 0.8008
#
# Epoch 00101: val_loss did not improve from 0.79595
# Epoch 102/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2233 - accuracy: 0.9614 - val_loss: 0.8119 - val_accuracy: 0.8164
#
# Epoch 00102: val_loss did not improve from 0.79595
# Epoch 103/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2546 - accuracy: 0.9494 - val_loss: 0.8342 - val_accuracy: 0.8047
#
# Epoch 00103: val_loss did not improve from 0.79595
# Epoch 104/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.1915 - accuracy: 0.9674 - val_loss: 0.8300 - val_accuracy: 0.8047
#
# Epoch 00104: val_loss did not improve from 0.79595
# Epoch 105/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2182 - accuracy: 0.9591 - val_loss: 0.8175 - val_accuracy: 0.8086
#
# Epoch 00105: val_loss did not improve from 0.79595
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 106/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2080 - accuracy: 0.9678 - val_loss: 0.7571 - val_accuracy: 0.8242
#
# Epoch 00106: val_loss improved from 0.79595 to 0.75706, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.1833 - accuracy: 0.9715 - val_loss: 0.7650 - val_accuracy: 0.8203
#
# Epoch 00107: val_loss did not improve from 0.75706
# Epoch 108/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2110 - accuracy: 0.9596 - val_loss: 0.7496 - val_accuracy: 0.8281
#
# Epoch 00108: val_loss improved from 0.75706 to 0.74959, saving model to ./save/cnn_gru_best.hdf5
# Epoch 109/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2337 - accuracy: 0.9586 - val_loss: 0.7805 - val_accuracy: 0.8125
#
# Epoch 00109: val_loss did not improve from 0.74959
# Epoch 110/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.2105 - accuracy: 0.9586 - val_loss: 0.8014 - val_accuracy: 0.8125
#
# Epoch 00110: val_loss did not improve from 0.74959
# Epoch 111/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.2560 - accuracy: 0.9485 - val_loss: 0.8240 - val_accuracy: 0.7969
#
# Epoch 00111: val_loss did not improve from 0.74959
# Epoch 112/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2065 - accuracy: 0.9632 - val_loss: 0.8458 - val_accuracy: 0.8008
#
# Epoch 00112: val_loss did not improve from 0.74959
# Epoch 113/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2111 - accuracy: 0.9600 - val_loss: 0.8166 - val_accuracy: 0.8008
#
# Epoch 00113: val_loss did not improve from 0.74959
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 114/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.2215 - accuracy: 0.9540 - val_loss: 0.8567 - val_accuracy: 0.7930
#
# Epoch 00114: val_loss did not improve from 0.74959
# Epoch 115/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2078 - accuracy: 0.9623 - val_loss: 0.8181 - val_accuracy: 0.8008
#
# Epoch 00115: val_loss did not improve from 0.74959
# Epoch 116/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2011 - accuracy: 0.9628 - val_loss: 0.8255 - val_accuracy: 0.8125
#
# Epoch 00116: val_loss did not improve from 0.74959
# Epoch 117/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.2178 - accuracy: 0.9655 - val_loss: 0.8353 - val_accuracy: 0.8125
#
# Epoch 00117: val_loss did not improve from 0.74959
# Epoch 118/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2012 - accuracy: 0.9642 - val_loss: 0.8227 - val_accuracy: 0.8242
#
# Epoch 00118: val_loss did not improve from 0.74959
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 119/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.2184 - accuracy: 0.9614 - val_loss: 0.8699 - val_accuracy: 0.8125
#
# Epoch 00119: val_loss did not improve from 0.74959
# Epoch 120/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2464 - accuracy: 0.9476 - val_loss: 0.8780 - val_accuracy: 0.8008
#
# Epoch 00120: val_loss did not improve from 0.74959
# Epoch 121/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2366 - accuracy: 0.9596 - val_loss: 0.8624 - val_accuracy: 0.8047
#
# Epoch 00121: val_loss did not improve from 0.74959
# Epoch 122/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.1853 - accuracy: 0.9715 - val_loss: 0.8191 - val_accuracy: 0.8125
#
# Epoch 00122: val_loss did not improve from 0.74959
# Epoch 123/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2103 - accuracy: 0.9605 - val_loss: 0.8581 - val_accuracy: 0.8047
#
# Epoch 00123: val_loss did not improve from 0.74959
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 124/2000
# 34/34 [==============================] - 13s 370ms/step - loss: 0.2164 - accuracy: 0.9623 - val_loss: 0.8400 - val_accuracy: 0.8086
#
# Epoch 00124: val_loss did not improve from 0.74959
# Epoch 125/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2136 - accuracy: 0.9586 - val_loss: 0.8577 - val_accuracy: 0.8086
#
# Epoch 00125: val_loss did not improve from 0.74959
# Epoch 126/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2105 - accuracy: 0.9623 - val_loss: 0.8624 - val_accuracy: 0.8086
#
# Epoch 00126: val_loss did not improve from 0.74959
# Epoch 127/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2442 - accuracy: 0.9485 - val_loss: 0.8590 - val_accuracy: 0.8086
#
# Epoch 00127: val_loss did not improve from 0.74959
# Epoch 128/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.1785 - accuracy: 0.9775 - val_loss: 0.7997 - val_accuracy: 0.8242
#
# Epoch 00128: val_loss did not improve from 0.74959
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 129/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.2144 - accuracy: 0.9651 - val_loss: 0.8759 - val_accuracy: 0.8047
#
# Epoch 00129: val_loss did not improve from 0.74959
# Epoch 130/2000
# 34/34 [==============================] - 13s 369ms/step - loss: 0.1690 - accuracy: 0.9761 - val_loss: 0.8671 - val_accuracy: 0.8047
#
# Epoch 00130: val_loss did not improve from 0.74959
# Epoch 131/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2172 - accuracy: 0.9596 - val_loss: 0.8487 - val_accuracy: 0.8164
#
# Epoch 00131: val_loss did not improve from 0.74959
# Epoch 132/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.2123 - accuracy: 0.9637 - val_loss: 0.8468 - val_accuracy: 0.8164
#
# Epoch 00132: val_loss did not improve from 0.74959
# Epoch 133/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2143 - accuracy: 0.9632 - val_loss: 0.8501 - val_accuracy: 0.8086
#
# Epoch 00133: val_loss did not improve from 0.74959
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 134/2000
# 34/34 [==============================] - 13s 373ms/step - loss: 0.2211 - accuracy: 0.9573 - val_loss: 0.8395 - val_accuracy: 0.8086
#
# Epoch 00134: val_loss did not improve from 0.74959
# Epoch 135/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.2034 - accuracy: 0.9637 - val_loss: 0.8513 - val_accuracy: 0.8008
#
# Epoch 00135: val_loss did not improve from 0.74959
# Epoch 136/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2263 - accuracy: 0.9568 - val_loss: 0.8353 - val_accuracy: 0.8203
#
# Epoch 00136: val_loss did not improve from 0.74959
# Epoch 137/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.2283 - accuracy: 0.9596 - val_loss: 0.8510 - val_accuracy: 0.8047
#
# Epoch 00137: val_loss did not improve from 0.74959
# Epoch 138/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.1859 - accuracy: 0.9655 - val_loss: 0.8203 - val_accuracy: 0.8164
#
# Epoch 00138: val_loss did not improve from 0.74959
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 00138: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.5917 - accuracy: 0.8576
# [0.5916858315467834, 0.8575999736785889]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
