# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 11, # 3, 5, 7, #9#, ##11##, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      910         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 10)      1450        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 10)      730         concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 10)      730         concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1810        concatenate_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 10)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 10)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 10)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 10)      40          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 10)      40          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 10)      40          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 20)      1920        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 20)      1920        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 20)      1920        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 20)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 20)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 20)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 20)      80          leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 20)      80          leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 20)      80          leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      3660        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      3660        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      3660        batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 60)      21960       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 60)      21960       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 60)      21960       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      194460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      194460      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_59[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_62[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 150, 60)      240         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 150, 120)     480         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 150, 60)      240         conv1d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_65[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 150, 60)      240         conv1d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 150, 120)     480         conv1d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 150, 60)      240         conv1d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_68[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 150, 60)      240         conv1d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 150, 120)     480         conv1d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 150, 60)      240         conv1d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_71[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 150, 60)      240         conv1d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 150, 120)     480         conv1d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 150, 60)      240         conv1d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_74[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 150, 60)      32460       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 150, 60)      240         conv1d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 150, 120)     480         conv1d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 150, 60)      240         conv1d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 150, 60)      0           leaky_re_lu_77[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 150, 60)      32460       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 150, 60)      240         conv1d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 150, 120)     480         conv1d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 150, 60)      240         conv1d_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 150, 60)      0           leaky_re_lu_80[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 150, 60)      240         add_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,380,601
# Trainable params: 1,373,401
# Non-trainable params: 7,200
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=1))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 51s 451ms/step - loss: 44.0135 - accuracy: 0.3649 - val_loss: 32.1856 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.18557, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 23.6176 - accuracy: 0.5147 - val_loss: 17.8587 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 32.18557 to 17.85866, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 12.7329 - accuracy: 0.5928 - val_loss: 10.7128 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 17.85866 to 10.71283, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 7.4463 - accuracy: 0.6043 - val_loss: 7.6296 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 10.71283 to 7.62960, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 10s 304ms/step - loss: 4.6801 - accuracy: 0.6218 - val_loss: 6.1000 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 7.62960 to 6.09998, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 3.1371 - accuracy: 0.6461 - val_loss: 5.1466 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 6.09998 to 5.14660, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 10s 304ms/step - loss: 2.2945 - accuracy: 0.6682 - val_loss: 4.9344 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 5.14660 to 4.93444, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 1.8309 - accuracy: 0.7022 - val_loss: 5.1345 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss did not improve from 4.93444
# Epoch 9/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 1.5504 - accuracy: 0.7220 - val_loss: 3.7875 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss improved from 4.93444 to 3.78752, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 1.5342 - accuracy: 0.7040 - val_loss: 4.7102 - val_accuracy: 0.4414
#
# Epoch 00010: val_loss did not improve from 3.78752
# Epoch 11/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 1.4289 - accuracy: 0.7151 - val_loss: 3.7777 - val_accuracy: 0.4375
#
# Epoch 00011: val_loss improved from 3.78752 to 3.77770, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 10s 297ms/step - loss: 1.3911 - accuracy: 0.7188 - val_loss: 3.5107 - val_accuracy: 0.4727
#
# Epoch 00012: val_loss improved from 3.77770 to 3.51071, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 1.2950 - accuracy: 0.7362 - val_loss: 3.5865 - val_accuracy: 0.4453
#
# Epoch 00013: val_loss did not improve from 3.51071
# Epoch 14/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 1.2329 - accuracy: 0.7353 - val_loss: 3.3526 - val_accuracy: 0.4375
#
# Epoch 00014: val_loss improved from 3.51071 to 3.35262, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 1.2665 - accuracy: 0.7335 - val_loss: 3.5101 - val_accuracy: 0.4492
#
# Epoch 00015: val_loss did not improve from 3.35262
# Epoch 16/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 1.2447 - accuracy: 0.7302 - val_loss: 2.4399 - val_accuracy: 0.5273
#
# Epoch 00016: val_loss improved from 3.35262 to 2.43985, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 1.2423 - accuracy: 0.7302 - val_loss: 2.3225 - val_accuracy: 0.5703
#
# Epoch 00017: val_loss improved from 2.43985 to 2.32250, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 1.1110 - accuracy: 0.7711 - val_loss: 1.8602 - val_accuracy: 0.5977
#
# Epoch 00018: val_loss improved from 2.32250 to 1.86024, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 1.0625 - accuracy: 0.7812 - val_loss: 1.7242 - val_accuracy: 0.6133
#
# Epoch 00019: val_loss improved from 1.86024 to 1.72417, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 1.1746 - accuracy: 0.7422 - val_loss: 1.7245 - val_accuracy: 0.6641
#
# Epoch 00020: val_loss did not improve from 1.72417
# Epoch 21/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 1.1215 - accuracy: 0.7537 - val_loss: 1.7661 - val_accuracy: 0.6289
#
# Epoch 00021: val_loss did not improve from 1.72417
# Epoch 22/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 1.0488 - accuracy: 0.7670 - val_loss: 1.4646 - val_accuracy: 0.6836
#
# Epoch 00022: val_loss improved from 1.72417 to 1.46458, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 1.0299 - accuracy: 0.7822 - val_loss: 1.4324 - val_accuracy: 0.6406
#
# Epoch 00023: val_loss improved from 1.46458 to 1.43236, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.9952 - accuracy: 0.7808 - val_loss: 1.3965 - val_accuracy: 0.6875
#
# Epoch 00024: val_loss improved from 1.43236 to 1.39646, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 10s 305ms/step - loss: 1.0049 - accuracy: 0.7803 - val_loss: 1.7592 - val_accuracy: 0.6484
#
# Epoch 00025: val_loss did not improve from 1.39646
# Epoch 26/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 1.0207 - accuracy: 0.7845 - val_loss: 1.4271 - val_accuracy: 0.7031
#
# Epoch 00026: val_loss did not improve from 1.39646
# Epoch 27/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.9702 - accuracy: 0.7992 - val_loss: 1.3505 - val_accuracy: 0.7070
#
# Epoch 00027: val_loss improved from 1.39646 to 1.35046, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 1.0550 - accuracy: 0.7702 - val_loss: 1.5511 - val_accuracy: 0.6836
#
# Epoch 00028: val_loss did not improve from 1.35046
# Epoch 29/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 1.0580 - accuracy: 0.7753 - val_loss: 1.3985 - val_accuracy: 0.7031
#
# Epoch 00029: val_loss did not improve from 1.35046
# Epoch 30/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.9313 - accuracy: 0.8010 - val_loss: 1.6577 - val_accuracy: 0.6523
#
# Epoch 00030: val_loss did not improve from 1.35046
# Epoch 31/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.9392 - accuracy: 0.8074 - val_loss: 1.4897 - val_accuracy: 0.6719
#
# Epoch 00031: val_loss did not improve from 1.35046
# Epoch 32/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.9124 - accuracy: 0.8010 - val_loss: 1.6369 - val_accuracy: 0.6289
#
# Epoch 00032: val_loss did not improve from 1.35046
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 33/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.8697 - accuracy: 0.8130 - val_loss: 1.2277 - val_accuracy: 0.7266
#
# Epoch 00033: val_loss improved from 1.35046 to 1.22773, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.7870 - accuracy: 0.8226 - val_loss: 1.0764 - val_accuracy: 0.7500
#
# Epoch 00034: val_loss improved from 1.22773 to 1.07639, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.7912 - accuracy: 0.8231 - val_loss: 1.0709 - val_accuracy: 0.7578
#
# Epoch 00035: val_loss improved from 1.07639 to 1.07086, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.7894 - accuracy: 0.8166 - val_loss: 1.0644 - val_accuracy: 0.7383
#
# Epoch 00036: val_loss improved from 1.07086 to 1.06440, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.7522 - accuracy: 0.8382 - val_loss: 1.0483 - val_accuracy: 0.7539
#
# Epoch 00037: val_loss improved from 1.06440 to 1.04833, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.6906 - accuracy: 0.8456 - val_loss: 1.0158 - val_accuracy: 0.7578
#
# Epoch 00038: val_loss improved from 1.04833 to 1.01579, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.7286 - accuracy: 0.8336 - val_loss: 1.0624 - val_accuracy: 0.7539
#
# Epoch 00039: val_loss did not improve from 1.01579
# Epoch 40/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.7381 - accuracy: 0.8277 - val_loss: 1.0888 - val_accuracy: 0.7461
#
# Epoch 00040: val_loss did not improve from 1.01579
# Epoch 41/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.7130 - accuracy: 0.8405 - val_loss: 1.0006 - val_accuracy: 0.7656
#
# Epoch 00041: val_loss improved from 1.01579 to 1.00060, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.7464 - accuracy: 0.8212 - val_loss: 0.9932 - val_accuracy: 0.7656
#
# Epoch 00042: val_loss improved from 1.00060 to 0.99316, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 10s 306ms/step - loss: 0.7262 - accuracy: 0.8295 - val_loss: 1.2624 - val_accuracy: 0.6719
#
# Epoch 00043: val_loss did not improve from 0.99316
# Epoch 44/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.6059 - accuracy: 0.8672 - val_loss: 1.4045 - val_accuracy: 0.6719
#
# Epoch 00044: val_loss did not improve from 0.99316
# Epoch 45/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.7182 - accuracy: 0.8387 - val_loss: 1.1012 - val_accuracy: 0.7500
#
# Epoch 00045: val_loss did not improve from 0.99316
# Epoch 46/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.5627 - accuracy: 0.8824 - val_loss: 1.0167 - val_accuracy: 0.7500
#
# Epoch 00046: val_loss did not improve from 0.99316
# Epoch 47/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.6638 - accuracy: 0.8442 - val_loss: 1.1563 - val_accuracy: 0.7578
#
# Epoch 00047: val_loss did not improve from 0.99316
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 48/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.5993 - accuracy: 0.8736 - val_loss: 0.9963 - val_accuracy: 0.7852
#
# Epoch 00048: val_loss did not improve from 0.99316
# Epoch 49/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.7268 - accuracy: 0.8309 - val_loss: 0.9616 - val_accuracy: 0.7422
#
# Epoch 00049: val_loss improved from 0.99316 to 0.96162, saving model to ./save/cnn_gru_best.hdf5
# Epoch 50/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.6602 - accuracy: 0.8483 - val_loss: 0.8995 - val_accuracy: 0.7930
#
# Epoch 00050: val_loss improved from 0.96162 to 0.89954, saving model to ./save/cnn_gru_best.hdf5
# Epoch 51/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.5406 - accuracy: 0.8847 - val_loss: 0.8767 - val_accuracy: 0.7812
#
# Epoch 00051: val_loss improved from 0.89954 to 0.87668, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.5474 - accuracy: 0.8741 - val_loss: 0.8824 - val_accuracy: 0.7773
#
# Epoch 00052: val_loss did not improve from 0.87668
# Epoch 53/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.5413 - accuracy: 0.8851 - val_loss: 0.9075 - val_accuracy: 0.7773
#
# Epoch 00053: val_loss did not improve from 0.87668
# Epoch 54/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.5831 - accuracy: 0.8663 - val_loss: 0.9403 - val_accuracy: 0.7812
#
# Epoch 00054: val_loss did not improve from 0.87668
# Epoch 55/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.5582 - accuracy: 0.8727 - val_loss: 0.9677 - val_accuracy: 0.7617
#
# Epoch 00055: val_loss did not improve from 0.87668
# Epoch 56/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.5723 - accuracy: 0.8640 - val_loss: 0.8947 - val_accuracy: 0.7930
#
# Epoch 00056: val_loss did not improve from 0.87668
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 57/2000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.5047 - accuracy: 0.8892 - val_loss: 0.9211 - val_accuracy: 0.7773
#
# Epoch 00057: val_loss did not improve from 0.87668
# Epoch 58/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.5262 - accuracy: 0.8732 - val_loss: 0.8850 - val_accuracy: 0.7773
#
# Epoch 00058: val_loss did not improve from 0.87668
# Epoch 59/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.4783 - accuracy: 0.8971 - val_loss: 0.8451 - val_accuracy: 0.7891
#
# Epoch 00059: val_loss improved from 0.87668 to 0.84515, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.4805 - accuracy: 0.8897 - val_loss: 0.8496 - val_accuracy: 0.7891
#
# Epoch 00060: val_loss did not improve from 0.84515
# Epoch 61/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.5178 - accuracy: 0.8805 - val_loss: 0.8631 - val_accuracy: 0.7891
#
# Epoch 00061: val_loss did not improve from 0.84515
# Epoch 62/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.4983 - accuracy: 0.8837 - val_loss: 0.8559 - val_accuracy: 0.8008
#
# Epoch 00062: val_loss did not improve from 0.84515
# Epoch 63/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.4680 - accuracy: 0.8938 - val_loss: 0.9228 - val_accuracy: 0.7500
#
# Epoch 00063: val_loss did not improve from 0.84515
# Epoch 64/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.4833 - accuracy: 0.8911 - val_loss: 0.8240 - val_accuracy: 0.7930
#
# Epoch 00064: val_loss improved from 0.84515 to 0.82396, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.4412 - accuracy: 0.8980 - val_loss: 0.8275 - val_accuracy: 0.7891
#
# Epoch 00065: val_loss did not improve from 0.82396
# Epoch 66/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.4671 - accuracy: 0.8920 - val_loss: 0.8519 - val_accuracy: 0.7891
#
# Epoch 00066: val_loss did not improve from 0.82396
# Epoch 67/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.4081 - accuracy: 0.9177 - val_loss: 0.7990 - val_accuracy: 0.7969
#
# Epoch 00067: val_loss improved from 0.82396 to 0.79902, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.4278 - accuracy: 0.9040 - val_loss: 0.8759 - val_accuracy: 0.7734
#
# Epoch 00068: val_loss did not improve from 0.79902
# Epoch 69/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.4529 - accuracy: 0.8883 - val_loss: 0.8273 - val_accuracy: 0.7734
#
# Epoch 00069: val_loss did not improve from 0.79902
# Epoch 70/2000
# 34/34 [==============================] - 10s 304ms/step - loss: 0.4879 - accuracy: 0.8856 - val_loss: 0.8862 - val_accuracy: 0.7539
#
# Epoch 00070: val_loss did not improve from 0.79902
# Epoch 71/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.4697 - accuracy: 0.8828 - val_loss: 0.9237 - val_accuracy: 0.7500
#
# Epoch 00071: val_loss did not improve from 0.79902
# Epoch 72/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.4595 - accuracy: 0.8906 - val_loss: 0.9563 - val_accuracy: 0.7539
#
# Epoch 00072: val_loss did not improve from 0.79902
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 73/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.4613 - accuracy: 0.8874 - val_loss: 0.8350 - val_accuracy: 0.7812
#
# Epoch 00073: val_loss did not improve from 0.79902
# Epoch 74/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.4615 - accuracy: 0.8966 - val_loss: 0.8250 - val_accuracy: 0.7773
#
# Epoch 00074: val_loss did not improve from 0.79902
# Epoch 75/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3857 - accuracy: 0.9118 - val_loss: 0.7739 - val_accuracy: 0.7969
#
# Epoch 00075: val_loss improved from 0.79902 to 0.77387, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.4101 - accuracy: 0.9085 - val_loss: 0.7545 - val_accuracy: 0.8164
#
# Epoch 00076: val_loss improved from 0.77387 to 0.75446, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3886 - accuracy: 0.9104 - val_loss: 0.7901 - val_accuracy: 0.7969
#
# Epoch 00077: val_loss did not improve from 0.75446
# Epoch 78/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.4022 - accuracy: 0.9131 - val_loss: 0.7794 - val_accuracy: 0.7852
#
# Epoch 00078: val_loss did not improve from 0.75446
# Epoch 79/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.5258 - accuracy: 0.8608 - val_loss: 0.8326 - val_accuracy: 0.7773
#
# Epoch 00079: val_loss did not improve from 0.75446
# Epoch 80/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.4182 - accuracy: 0.9030 - val_loss: 0.8115 - val_accuracy: 0.7891
#
# Epoch 00080: val_loss did not improve from 0.75446
# Epoch 81/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.4216 - accuracy: 0.8952 - val_loss: 0.7915 - val_accuracy: 0.8008
#
# Epoch 00081: val_loss did not improve from 0.75446
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 82/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.4024 - accuracy: 0.9017 - val_loss: 0.7615 - val_accuracy: 0.7930
#
# Epoch 00082: val_loss did not improve from 0.75446
# Epoch 83/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3387 - accuracy: 0.9265 - val_loss: 0.7881 - val_accuracy: 0.7969
#
# Epoch 00083: val_loss did not improve from 0.75446
# Epoch 84/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.3515 - accuracy: 0.9219 - val_loss: 0.7934 - val_accuracy: 0.7969
#
# Epoch 00084: val_loss did not improve from 0.75446
# Epoch 85/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3463 - accuracy: 0.9260 - val_loss: 0.7901 - val_accuracy: 0.8125
#
# Epoch 00085: val_loss did not improve from 0.75446
# Epoch 86/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.3137 - accuracy: 0.9334 - val_loss: 0.8086 - val_accuracy: 0.7969
#
# Epoch 00086: val_loss did not improve from 0.75446
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 87/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.4148 - accuracy: 0.9012 - val_loss: 0.8023 - val_accuracy: 0.8086
#
# Epoch 00087: val_loss did not improve from 0.75446
# Epoch 88/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.4078 - accuracy: 0.9058 - val_loss: 0.8251 - val_accuracy: 0.7891
#
# Epoch 00088: val_loss did not improve from 0.75446
# Epoch 89/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.3464 - accuracy: 0.9219 - val_loss: 0.8047 - val_accuracy: 0.7969
#
# Epoch 00089: val_loss did not improve from 0.75446
# Epoch 90/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3635 - accuracy: 0.9191 - val_loss: 0.8089 - val_accuracy: 0.7852
#
# Epoch 00090: val_loss did not improve from 0.75446
# Epoch 91/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3606 - accuracy: 0.9191 - val_loss: 0.7805 - val_accuracy: 0.8047
#
# Epoch 00091: val_loss did not improve from 0.75446
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 92/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3467 - accuracy: 0.9278 - val_loss: 0.7714 - val_accuracy: 0.8047
#
# Epoch 00092: val_loss did not improve from 0.75446
# Epoch 93/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3856 - accuracy: 0.9108 - val_loss: 0.7965 - val_accuracy: 0.8008
#
# Epoch 00093: val_loss did not improve from 0.75446
# Epoch 94/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3133 - accuracy: 0.9315 - val_loss: 0.7992 - val_accuracy: 0.7891
#
# Epoch 00094: val_loss did not improve from 0.75446
# Epoch 95/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3306 - accuracy: 0.9274 - val_loss: 0.7781 - val_accuracy: 0.7891
#
# Epoch 00095: val_loss did not improve from 0.75446
# Epoch 96/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3819 - accuracy: 0.9118 - val_loss: 0.7497 - val_accuracy: 0.7969
#
# Epoch 00096: val_loss improved from 0.75446 to 0.74973, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.4184 - accuracy: 0.9030 - val_loss: 0.7928 - val_accuracy: 0.8008
#
# Epoch 00097: val_loss did not improve from 0.74973
# Epoch 98/2000
# 34/34 [==============================] - 11s 308ms/step - loss: 0.3400 - accuracy: 0.9219 - val_loss: 0.7635 - val_accuracy: 0.8047
#
# Epoch 00098: val_loss did not improve from 0.74973
# Epoch 99/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.3789 - accuracy: 0.9131 - val_loss: 0.7609 - val_accuracy: 0.8047
#
# Epoch 00099: val_loss did not improve from 0.74973
# Epoch 100/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3205 - accuracy: 0.9260 - val_loss: 0.7376 - val_accuracy: 0.8086
#
# Epoch 00100: val_loss improved from 0.74973 to 0.73757, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3405 - accuracy: 0.9210 - val_loss: 0.8068 - val_accuracy: 0.7930
#
# Epoch 00101: val_loss did not improve from 0.73757
# Epoch 102/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3600 - accuracy: 0.9173 - val_loss: 0.7580 - val_accuracy: 0.8047
#
# Epoch 00102: val_loss did not improve from 0.73757
# Epoch 103/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3947 - accuracy: 0.9062 - val_loss: 0.7642 - val_accuracy: 0.7969
#
# Epoch 00103: val_loss did not improve from 0.73757
# Epoch 104/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3013 - accuracy: 0.9324 - val_loss: 0.7746 - val_accuracy: 0.8008
#
# Epoch 00104: val_loss did not improve from 0.73757
# Epoch 105/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3488 - accuracy: 0.9288 - val_loss: 0.7743 - val_accuracy: 0.8047
#
# Epoch 00105: val_loss did not improve from 0.73757
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 106/2000
# 34/34 [==============================] - 10s 298ms/step - loss: 0.3422 - accuracy: 0.9265 - val_loss: 0.6677 - val_accuracy: 0.8203
#
# Epoch 00106: val_loss improved from 0.73757 to 0.66768, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3146 - accuracy: 0.9334 - val_loss: 0.7336 - val_accuracy: 0.8125
#
# Epoch 00107: val_loss did not improve from 0.66768
# Epoch 108/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3302 - accuracy: 0.9269 - val_loss: 0.7241 - val_accuracy: 0.8164
#
# Epoch 00108: val_loss did not improve from 0.66768
# Epoch 109/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3486 - accuracy: 0.9214 - val_loss: 0.7186 - val_accuracy: 0.8047
#
# Epoch 00109: val_loss did not improve from 0.66768
# Epoch 110/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3219 - accuracy: 0.9297 - val_loss: 0.7586 - val_accuracy: 0.8203
#
# Epoch 00110: val_loss did not improve from 0.66768
# Epoch 111/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3985 - accuracy: 0.8998 - val_loss: 0.7747 - val_accuracy: 0.8242
#
# Epoch 00111: val_loss did not improve from 0.66768
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 112/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3229 - accuracy: 0.9274 - val_loss: 0.7853 - val_accuracy: 0.8086
#
# Epoch 00112: val_loss did not improve from 0.66768
# Epoch 113/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3302 - accuracy: 0.9288 - val_loss: 0.7414 - val_accuracy: 0.8242
#
# Epoch 00113: val_loss did not improve from 0.66768
# Epoch 114/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3570 - accuracy: 0.9090 - val_loss: 0.7931 - val_accuracy: 0.8086
#
# Epoch 00114: val_loss did not improve from 0.66768
# Epoch 115/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3145 - accuracy: 0.9366 - val_loss: 0.7535 - val_accuracy: 0.8086
#
# Epoch 00115: val_loss did not improve from 0.66768
# Epoch 116/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3271 - accuracy: 0.9265 - val_loss: 0.7674 - val_accuracy: 0.8008
#
# Epoch 00116: val_loss did not improve from 0.66768
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 117/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3418 - accuracy: 0.9260 - val_loss: 0.7617 - val_accuracy: 0.8047
#
# Epoch 00117: val_loss did not improve from 0.66768
# Epoch 118/2000
# 34/34 [==============================] - 10s 296ms/step - loss: 0.3115 - accuracy: 0.9361 - val_loss: 0.7686 - val_accuracy: 0.8008
#
# Epoch 00118: val_loss did not improve from 0.66768
# Epoch 119/2000
# 34/34 [==============================] - 10s 302ms/step - loss: 0.3482 - accuracy: 0.9242 - val_loss: 0.7976 - val_accuracy: 0.7969
#
# Epoch 00119: val_loss did not improve from 0.66768
# Epoch 120/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3817 - accuracy: 0.9122 - val_loss: 0.8078 - val_accuracy: 0.8008
#
# Epoch 00120: val_loss did not improve from 0.66768
# Epoch 121/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3706 - accuracy: 0.9145 - val_loss: 0.7849 - val_accuracy: 0.8008
#
# Epoch 00121: val_loss did not improve from 0.66768
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 122/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.3146 - accuracy: 0.9343 - val_loss: 0.7647 - val_accuracy: 0.8125
#
# Epoch 00122: val_loss did not improve from 0.66768
# Epoch 123/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3570 - accuracy: 0.9113 - val_loss: 0.7762 - val_accuracy: 0.8125
#
# Epoch 00123: val_loss did not improve from 0.66768
# Epoch 124/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3531 - accuracy: 0.9118 - val_loss: 0.7713 - val_accuracy: 0.8164
#
# Epoch 00124: val_loss did not improve from 0.66768
# Epoch 125/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.3370 - accuracy: 0.9233 - val_loss: 0.7955 - val_accuracy: 0.8086
#
# Epoch 00125: val_loss did not improve from 0.66768
# Epoch 126/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3229 - accuracy: 0.9228 - val_loss: 0.7910 - val_accuracy: 0.8086
#
# Epoch 00126: val_loss did not improve from 0.66768
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 127/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3686 - accuracy: 0.9118 - val_loss: 0.7837 - val_accuracy: 0.8164
#
# Epoch 00127: val_loss did not improve from 0.66768
# Epoch 128/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.2863 - accuracy: 0.9412 - val_loss: 0.7484 - val_accuracy: 0.8164
#
# Epoch 00128: val_loss did not improve from 0.66768
# Epoch 129/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.3437 - accuracy: 0.9214 - val_loss: 0.7981 - val_accuracy: 0.8047
#
# Epoch 00129: val_loss did not improve from 0.66768
# Epoch 130/2000
# 34/34 [==============================] - 10s 300ms/step - loss: 0.2918 - accuracy: 0.9343 - val_loss: 0.7930 - val_accuracy: 0.8008
#
# Epoch 00130: val_loss did not improve from 0.66768
# Epoch 131/2000
# 34/34 [==============================] - 10s 299ms/step - loss: 0.3488 - accuracy: 0.9182 - val_loss: 0.7719 - val_accuracy: 0.8086
#
# Epoch 00131: val_loss did not improve from 0.66768
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 132/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3251 - accuracy: 0.9297 - val_loss: 0.7599 - val_accuracy: 0.8164
#
# Epoch 00132: val_loss did not improve from 0.66768
# Epoch 133/2000
# 34/34 [==============================] - 10s 303ms/step - loss: 0.3497 - accuracy: 0.9177 - val_loss: 0.7903 - val_accuracy: 0.8086
#
# Epoch 00133: val_loss did not improve from 0.66768
# Epoch 134/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3431 - accuracy: 0.9210 - val_loss: 0.7797 - val_accuracy: 0.8086
#
# Epoch 00134: val_loss did not improve from 0.66768
# Epoch 135/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3383 - accuracy: 0.9191 - val_loss: 0.7855 - val_accuracy: 0.8008
#
# Epoch 00135: val_loss did not improve from 0.66768
# Epoch 136/2000
# 34/34 [==============================] - 10s 301ms/step - loss: 0.3425 - accuracy: 0.9246 - val_loss: 0.7765 - val_accuracy: 0.8164
#
# Epoch 00136: val_loss did not improve from 0.66768
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6208 - accuracy: 0.8416
# [0.6207514405250549, 0.8416000008583069]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
