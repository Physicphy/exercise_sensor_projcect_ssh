# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//4, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1450        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1810        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,227,001
# Trainable params: 1,220,761
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 43s 357ms/step - loss: 44.2904 - accuracy: 0.3410 - val_loss: 34.0525 - val_accuracy: 0.3555
#
# Epoch 00001: val_loss improved from inf to 34.05247, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 30.3637 - accuracy: 0.5119 - val_loss: 23.4095 - val_accuracy: 0.0117
#
# Epoch 00002: val_loss improved from 34.05247 to 23.40946, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 20.8791 - accuracy: 0.5873 - val_loss: 16.7021 - val_accuracy: 0.0391
#
# Epoch 00003: val_loss improved from 23.40946 to 16.70213, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 15.3726 - accuracy: 0.6020 - val_loss: 12.4220 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 16.70213 to 12.42202, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 11.4988 - accuracy: 0.6144 - val_loss: 9.7803 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 12.42202 to 9.78027, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 8.9841 - accuracy: 0.6457 - val_loss: 8.2962 - val_accuracy: 0.4453
#
# Epoch 00006: val_loss improved from 9.78027 to 8.29619, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 6.9611 - accuracy: 0.6843 - val_loss: 7.1760 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 8.29619 to 7.17601, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 5.7151 - accuracy: 0.7073 - val_loss: 6.4743 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 7.17601 to 6.47429, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 4.7054 - accuracy: 0.7394 - val_loss: 6.1072 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss improved from 6.47429 to 6.10717, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 4.5842 - accuracy: 0.7031 - val_loss: 6.4531 - val_accuracy: 0.2617
#
# Epoch 00010: val_loss did not improve from 6.10717
# Epoch 11/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 4.1040 - accuracy: 0.7155 - val_loss: 5.1162 - val_accuracy: 0.4570
#
# Epoch 00011: val_loss improved from 6.10717 to 5.11624, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 3.9023 - accuracy: 0.7197 - val_loss: 4.7844 - val_accuracy: 0.4453
#
# Epoch 00012: val_loss improved from 5.11624 to 4.78443, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 3.4902 - accuracy: 0.7495 - val_loss: 5.0777 - val_accuracy: 0.4609
#
# Epoch 00013: val_loss did not improve from 4.78443
# Epoch 14/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 3.1748 - accuracy: 0.7578 - val_loss: 4.0171 - val_accuracy: 0.4648
#
# Epoch 00014: val_loss improved from 4.78443 to 4.01712, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 3.2921 - accuracy: 0.7353 - val_loss: 3.5235 - val_accuracy: 0.4844
#
# Epoch 00015: val_loss improved from 4.01712 to 3.52348, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 3.2103 - accuracy: 0.7463 - val_loss: 2.7616 - val_accuracy: 0.5469
#
# Epoch 00016: val_loss improved from 3.52348 to 2.76157, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 3.0346 - accuracy: 0.7610 - val_loss: 2.6461 - val_accuracy: 0.5352
#
# Epoch 00017: val_loss improved from 2.76157 to 2.64606, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 2.6825 - accuracy: 0.7808 - val_loss: 2.3737 - val_accuracy: 0.6172
#
# Epoch 00018: val_loss improved from 2.64606 to 2.37372, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 2.5433 - accuracy: 0.7895 - val_loss: 2.2489 - val_accuracy: 0.6094
#
# Epoch 00019: val_loss improved from 2.37372 to 2.24889, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 3.0718 - accuracy: 0.7376 - val_loss: 2.0577 - val_accuracy: 0.6445
#
# Epoch 00020: val_loss improved from 2.24889 to 2.05767, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 2.7233 - accuracy: 0.7716 - val_loss: 1.9316 - val_accuracy: 0.6445
#
# Epoch 00021: val_loss improved from 2.05767 to 1.93163, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 2.5592 - accuracy: 0.7808 - val_loss: 1.8792 - val_accuracy: 0.6797
#
# Epoch 00022: val_loss improved from 1.93163 to 1.87915, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 2.5373 - accuracy: 0.7904 - val_loss: 1.9337 - val_accuracy: 0.6523
#
# Epoch 00023: val_loss did not improve from 1.87915
# Epoch 24/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 2.4116 - accuracy: 0.8010 - val_loss: 1.8704 - val_accuracy: 0.6680
#
# Epoch 00024: val_loss improved from 1.87915 to 1.87040, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 2.3745 - accuracy: 0.7932 - val_loss: 1.7783 - val_accuracy: 0.6719
#
# Epoch 00025: val_loss improved from 1.87040 to 1.77832, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 2.2450 - accuracy: 0.8079 - val_loss: 1.4795 - val_accuracy: 0.7500
#
# Epoch 00026: val_loss improved from 1.77832 to 1.47950, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 2.3630 - accuracy: 0.8019 - val_loss: 1.6626 - val_accuracy: 0.7227
#
# Epoch 00027: val_loss did not improve from 1.47950
# Epoch 28/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 2.4931 - accuracy: 0.7767 - val_loss: 1.7953 - val_accuracy: 0.6953
#
# Epoch 00028: val_loss did not improve from 1.47950
# Epoch 29/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 2.4011 - accuracy: 0.7904 - val_loss: 1.5138 - val_accuracy: 0.7422
#
# Epoch 00029: val_loss did not improve from 1.47950
# Epoch 30/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 2.1057 - accuracy: 0.8235 - val_loss: 1.8546 - val_accuracy: 0.6836
#
# Epoch 00030: val_loss did not improve from 1.47950
# Epoch 31/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 2.1196 - accuracy: 0.8116 - val_loss: 1.5407 - val_accuracy: 0.7188
#
# Epoch 00031: val_loss did not improve from 1.47950
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.8814 - accuracy: 0.8474 - val_loss: 1.4496 - val_accuracy: 0.7109
#
# Epoch 00032: val_loss improved from 1.47950 to 1.44962, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.7930 - accuracy: 0.8511 - val_loss: 1.4577 - val_accuracy: 0.7305
#
# Epoch 00033: val_loss did not improve from 1.44962
# Epoch 34/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.7171 - accuracy: 0.8552 - val_loss: 1.2475 - val_accuracy: 0.7578
#
# Epoch 00034: val_loss improved from 1.44962 to 1.24747, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.8264 - accuracy: 0.8442 - val_loss: 1.3807 - val_accuracy: 0.7344
#
# Epoch 00035: val_loss did not improve from 1.24747
# Epoch 36/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.7968 - accuracy: 0.8543 - val_loss: 1.2788 - val_accuracy: 0.7383
#
# Epoch 00036: val_loss did not improve from 1.24747
# Epoch 37/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.7419 - accuracy: 0.8493 - val_loss: 1.3855 - val_accuracy: 0.7344
#
# Epoch 00037: val_loss did not improve from 1.24747
# Epoch 38/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 1.5944 - accuracy: 0.8681 - val_loss: 1.3135 - val_accuracy: 0.7461
#
# Epoch 00038: val_loss did not improve from 1.24747
# Epoch 39/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.6332 - accuracy: 0.8649 - val_loss: 1.2800 - val_accuracy: 0.7656
#
# Epoch 00039: val_loss did not improve from 1.24747
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 40/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.5381 - accuracy: 0.8681 - val_loss: 1.2374 - val_accuracy: 0.7539
#
# Epoch 00040: val_loss improved from 1.24747 to 1.23736, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 1.4380 - accuracy: 0.8938 - val_loss: 1.1951 - val_accuracy: 0.7500
#
# Epoch 00041: val_loss improved from 1.23736 to 1.19511, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.5017 - accuracy: 0.8718 - val_loss: 1.1943 - val_accuracy: 0.7695
#
# Epoch 00042: val_loss improved from 1.19511 to 1.19427, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.4937 - accuracy: 0.8663 - val_loss: 1.1058 - val_accuracy: 0.7969
#
# Epoch 00043: val_loss improved from 1.19427 to 1.10578, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 1.1342 - accuracy: 0.9131 - val_loss: 1.1800 - val_accuracy: 0.7617
#
# Epoch 00044: val_loss did not improve from 1.10578
# Epoch 45/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.5197 - accuracy: 0.8704 - val_loss: 1.2161 - val_accuracy: 0.7539
#
# Epoch 00045: val_loss did not improve from 1.10578
# Epoch 46/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.1030 - accuracy: 0.9017 - val_loss: 1.1604 - val_accuracy: 0.7695
#
# Epoch 00046: val_loss did not improve from 1.10578
# Epoch 47/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.3389 - accuracy: 0.8860 - val_loss: 1.1173 - val_accuracy: 0.7656
#
# Epoch 00047: val_loss did not improve from 1.10578
# Epoch 48/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.2158 - accuracy: 0.8961 - val_loss: 1.0915 - val_accuracy: 0.7891
#
# Epoch 00048: val_loss improved from 1.10578 to 1.09150, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.6538 - accuracy: 0.8442 - val_loss: 1.2410 - val_accuracy: 0.7383
#
# Epoch 00049: val_loss did not improve from 1.09150
# Epoch 50/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.4446 - accuracy: 0.8718 - val_loss: 1.2201 - val_accuracy: 0.7578
#
# Epoch 00050: val_loss did not improve from 1.09150
# Epoch 51/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.1880 - accuracy: 0.9030 - val_loss: 1.0682 - val_accuracy: 0.7852
#
# Epoch 00051: val_loss improved from 1.09150 to 1.06821, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.2575 - accuracy: 0.8957 - val_loss: 1.0958 - val_accuracy: 0.7812
#
# Epoch 00052: val_loss did not improve from 1.06821
# Epoch 53/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 1.2077 - accuracy: 0.8925 - val_loss: 1.2510 - val_accuracy: 0.7422
#
# Epoch 00053: val_loss did not improve from 1.06821
# Epoch 54/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.3966 - accuracy: 0.8699 - val_loss: 1.1519 - val_accuracy: 0.8125
#
# Epoch 00054: val_loss did not improve from 1.06821
# Epoch 55/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.2906 - accuracy: 0.8842 - val_loss: 1.3265 - val_accuracy: 0.7383
#
# Epoch 00055: val_loss did not improve from 1.06821
# Epoch 56/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 1.2887 - accuracy: 0.8860 - val_loss: 1.1320 - val_accuracy: 0.7969
#
# Epoch 00056: val_loss did not improve from 1.06821
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 57/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.1340 - accuracy: 0.9049 - val_loss: 1.1177 - val_accuracy: 0.8125
#
# Epoch 00057: val_loss did not improve from 1.06821
# Epoch 58/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 1.1964 - accuracy: 0.9035 - val_loss: 1.0368 - val_accuracy: 0.8086
#
# Epoch 00058: val_loss improved from 1.06821 to 1.03678, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.0826 - accuracy: 0.9145 - val_loss: 1.0055 - val_accuracy: 0.7969
#
# Epoch 00059: val_loss improved from 1.03678 to 1.00553, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.1150 - accuracy: 0.9030 - val_loss: 1.0879 - val_accuracy: 0.7773
#
# Epoch 00060: val_loss did not improve from 1.00553
# Epoch 61/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.1510 - accuracy: 0.8966 - val_loss: 1.0657 - val_accuracy: 0.7812
#
# Epoch 00061: val_loss did not improve from 1.00553
# Epoch 62/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.1312 - accuracy: 0.9003 - val_loss: 1.0464 - val_accuracy: 0.7969
#
# Epoch 00062: val_loss did not improve from 1.00553
# Epoch 63/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.0577 - accuracy: 0.9053 - val_loss: 1.1327 - val_accuracy: 0.7930
#
# Epoch 00063: val_loss did not improve from 1.00553
# Epoch 64/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 1.1333 - accuracy: 0.9044 - val_loss: 1.0557 - val_accuracy: 0.7930
#
# Epoch 00064: val_loss did not improve from 1.00553
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 65/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9727 - accuracy: 0.9246 - val_loss: 1.0244 - val_accuracy: 0.8125
#
# Epoch 00065: val_loss did not improve from 1.00553
# Epoch 66/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9750 - accuracy: 0.9228 - val_loss: 1.0378 - val_accuracy: 0.8047
#
# Epoch 00066: val_loss did not improve from 1.00553
# Epoch 67/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8614 - accuracy: 0.9288 - val_loss: 0.9856 - val_accuracy: 0.8203
#
# Epoch 00067: val_loss improved from 1.00553 to 0.98555, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9373 - accuracy: 0.9260 - val_loss: 0.9984 - val_accuracy: 0.8164
#
# Epoch 00068: val_loss did not improve from 0.98555
# Epoch 69/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.9495 - accuracy: 0.9219 - val_loss: 0.9777 - val_accuracy: 0.8242
#
# Epoch 00069: val_loss improved from 0.98555 to 0.97767, saving model to ./save/cnn_gru_best.hdf5
# Epoch 70/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.0498 - accuracy: 0.9003 - val_loss: 1.0146 - val_accuracy: 0.7930
#
# Epoch 00070: val_loss did not improve from 0.97767
# Epoch 71/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.0436 - accuracy: 0.9058 - val_loss: 0.9753 - val_accuracy: 0.8203
#
# Epoch 00071: val_loss improved from 0.97767 to 0.97532, saving model to ./save/cnn_gru_best.hdf5
# Epoch 72/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.9600 - accuracy: 0.9154 - val_loss: 1.0155 - val_accuracy: 0.8164
#
# Epoch 00072: val_loss did not improve from 0.97532
# Epoch 73/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.0225 - accuracy: 0.9131 - val_loss: 1.0306 - val_accuracy: 0.8008
#
# Epoch 00073: val_loss did not improve from 0.97532
# Epoch 74/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.0050 - accuracy: 0.9108 - val_loss: 1.0121 - val_accuracy: 0.8086
#
# Epoch 00074: val_loss did not improve from 0.97532
# Epoch 75/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.8435 - accuracy: 0.9320 - val_loss: 0.9923 - val_accuracy: 0.8047
#
# Epoch 00075: val_loss did not improve from 0.97532
# Epoch 76/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.9350 - accuracy: 0.9219 - val_loss: 0.9657 - val_accuracy: 0.8125
#
# Epoch 00076: val_loss improved from 0.97532 to 0.96566, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8606 - accuracy: 0.9278 - val_loss: 0.9838 - val_accuracy: 0.8203
#
# Epoch 00077: val_loss did not improve from 0.96566
# Epoch 78/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.8882 - accuracy: 0.9269 - val_loss: 0.9908 - val_accuracy: 0.8242
#
# Epoch 00078: val_loss did not improve from 0.96566
# Epoch 79/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.1335 - accuracy: 0.8966 - val_loss: 1.0173 - val_accuracy: 0.8203
#
# Epoch 00079: val_loss did not improve from 0.96566
# Epoch 80/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.9183 - accuracy: 0.9237 - val_loss: 1.0113 - val_accuracy: 0.8242
#
# Epoch 00080: val_loss did not improve from 0.96566
# Epoch 81/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.9102 - accuracy: 0.9182 - val_loss: 0.9795 - val_accuracy: 0.8203
#
# Epoch 00081: val_loss did not improve from 0.96566
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 82/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.8694 - accuracy: 0.9269 - val_loss: 0.9691 - val_accuracy: 0.8203
#
# Epoch 00082: val_loss did not improve from 0.96566
# Epoch 83/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.7313 - accuracy: 0.9453 - val_loss: 0.9771 - val_accuracy: 0.8164
#
# Epoch 00083: val_loss did not improve from 0.96566
# Epoch 84/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.7656 - accuracy: 0.9370 - val_loss: 0.9968 - val_accuracy: 0.8203
#
# Epoch 00084: val_loss did not improve from 0.96566
# Epoch 85/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.7368 - accuracy: 0.9481 - val_loss: 0.9625 - val_accuracy: 0.8203
#
# Epoch 00085: val_loss improved from 0.96566 to 0.96252, saving model to ./save/cnn_gru_best.hdf5
# Epoch 86/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.6700 - accuracy: 0.9527 - val_loss: 0.9681 - val_accuracy: 0.8203
#
# Epoch 00086: val_loss did not improve from 0.96252
# Epoch 87/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.9643 - accuracy: 0.9090 - val_loss: 0.9861 - val_accuracy: 0.8125
#
# Epoch 00087: val_loss did not improve from 0.96252
# Epoch 88/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.9276 - accuracy: 0.9196 - val_loss: 0.9877 - val_accuracy: 0.8125
#
# Epoch 00088: val_loss did not improve from 0.96252
# Epoch 89/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.8230 - accuracy: 0.9343 - val_loss: 0.9590 - val_accuracy: 0.8242
#
# Epoch 00089: val_loss improved from 0.96252 to 0.95904, saving model to ./save/cnn_gru_best.hdf5
# Epoch 90/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7860 - accuracy: 0.9393 - val_loss: 0.9812 - val_accuracy: 0.8047
#
# Epoch 00090: val_loss did not improve from 0.95904
# Epoch 91/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8476 - accuracy: 0.9297 - val_loss: 0.9381 - val_accuracy: 0.8164
#
# Epoch 00091: val_loss improved from 0.95904 to 0.93814, saving model to ./save/cnn_gru_best.hdf5
# Epoch 92/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.8172 - accuracy: 0.9352 - val_loss: 0.9731 - val_accuracy: 0.8164
#
# Epoch 00092: val_loss did not improve from 0.93814
# Epoch 93/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9067 - accuracy: 0.9233 - val_loss: 0.9901 - val_accuracy: 0.8008
#
# Epoch 00093: val_loss did not improve from 0.93814
# Epoch 94/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7447 - accuracy: 0.9412 - val_loss: 1.0017 - val_accuracy: 0.8164
#
# Epoch 00094: val_loss did not improve from 0.93814
# Epoch 95/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7971 - accuracy: 0.9398 - val_loss: 0.9754 - val_accuracy: 0.8164
#
# Epoch 00095: val_loss did not improve from 0.93814
# Epoch 96/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.8527 - accuracy: 0.9237 - val_loss: 0.9454 - val_accuracy: 0.8242
#
# Epoch 00096: val_loss did not improve from 0.93814
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 97/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.9671 - accuracy: 0.9085 - val_loss: 1.0143 - val_accuracy: 0.8008
#
# Epoch 00097: val_loss did not improve from 0.93814
# Epoch 98/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7851 - accuracy: 0.9393 - val_loss: 0.9805 - val_accuracy: 0.8125
#
# Epoch 00098: val_loss did not improve from 0.93814
# Epoch 99/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.8643 - accuracy: 0.9292 - val_loss: 0.9833 - val_accuracy: 0.8164
#
# Epoch 00099: val_loss did not improve from 0.93814
# Epoch 100/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7091 - accuracy: 0.9435 - val_loss: 0.9447 - val_accuracy: 0.8242
#
# Epoch 00100: val_loss did not improve from 0.93814
# Epoch 101/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.7366 - accuracy: 0.9444 - val_loss: 1.0082 - val_accuracy: 0.8008
#
# Epoch 00101: val_loss did not improve from 0.93814
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 102/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7541 - accuracy: 0.9393 - val_loss: 0.9745 - val_accuracy: 0.8125
#
# Epoch 00102: val_loss did not improve from 0.93814
# Epoch 103/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.8410 - accuracy: 0.9278 - val_loss: 0.9584 - val_accuracy: 0.8164
#
# Epoch 00103: val_loss did not improve from 0.93814
# Epoch 104/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.6772 - accuracy: 0.9476 - val_loss: 0.9546 - val_accuracy: 0.8242
#
# Epoch 00104: val_loss did not improve from 0.93814
# Epoch 105/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8010 - accuracy: 0.9352 - val_loss: 0.9400 - val_accuracy: 0.8281
#
# Epoch 00105: val_loss did not improve from 0.93814
# Epoch 106/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7655 - accuracy: 0.9315 - val_loss: 0.8684 - val_accuracy: 0.8398
#
# Epoch 00106: val_loss improved from 0.93814 to 0.86840, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.6885 - accuracy: 0.9504 - val_loss: 0.9275 - val_accuracy: 0.8281
#
# Epoch 00107: val_loss did not improve from 0.86840
# Epoch 108/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7471 - accuracy: 0.9407 - val_loss: 0.8849 - val_accuracy: 0.8359
#
# Epoch 00108: val_loss did not improve from 0.86840
# Epoch 109/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8355 - accuracy: 0.9274 - val_loss: 0.9197 - val_accuracy: 0.8242
#
# Epoch 00109: val_loss did not improve from 0.86840
# Epoch 110/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7071 - accuracy: 0.9485 - val_loss: 0.9574 - val_accuracy: 0.8164
#
# Epoch 00110: val_loss did not improve from 0.86840
# Epoch 111/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.9044 - accuracy: 0.9205 - val_loss: 0.9677 - val_accuracy: 0.8242
#
# Epoch 00111: val_loss did not improve from 0.86840
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 112/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.7687 - accuracy: 0.9366 - val_loss: 0.9981 - val_accuracy: 0.8164
#
# Epoch 00112: val_loss did not improve from 0.86840
# Epoch 113/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.7352 - accuracy: 0.9393 - val_loss: 0.9754 - val_accuracy: 0.8242
#
# Epoch 00113: val_loss did not improve from 0.86840
# Epoch 114/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 0.8071 - accuracy: 0.9315 - val_loss: 0.9752 - val_accuracy: 0.8203
#
# Epoch 00114: val_loss did not improve from 0.86840
# Epoch 115/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7346 - accuracy: 0.9398 - val_loss: 0.9585 - val_accuracy: 0.8164
#
# Epoch 00115: val_loss did not improve from 0.86840
# Epoch 116/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7496 - accuracy: 0.9370 - val_loss: 0.9503 - val_accuracy: 0.8203
#
# Epoch 00116: val_loss did not improve from 0.86840
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 117/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7876 - accuracy: 0.9384 - val_loss: 0.9544 - val_accuracy: 0.8164
#
# Epoch 00117: val_loss did not improve from 0.86840
# Epoch 118/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7016 - accuracy: 0.9499 - val_loss: 0.9560 - val_accuracy: 0.8203
#
# Epoch 00118: val_loss did not improve from 0.86840
# Epoch 119/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7499 - accuracy: 0.9398 - val_loss: 0.9939 - val_accuracy: 0.8125
#
# Epoch 00119: val_loss did not improve from 0.86840
# Epoch 120/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.8674 - accuracy: 0.9210 - val_loss: 1.0093 - val_accuracy: 0.8125
#
# Epoch 00120: val_loss did not improve from 0.86840
# Epoch 121/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.8261 - accuracy: 0.9338 - val_loss: 0.9777 - val_accuracy: 0.8203
#
# Epoch 00121: val_loss did not improve from 0.86840
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 122/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.6469 - accuracy: 0.9527 - val_loss: 0.9420 - val_accuracy: 0.8281
#
# Epoch 00122: val_loss did not improve from 0.86840
# Epoch 123/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.8008 - accuracy: 0.9343 - val_loss: 0.9825 - val_accuracy: 0.8242
#
# Epoch 00123: val_loss did not improve from 0.86840
# Epoch 124/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7500 - accuracy: 0.9398 - val_loss: 1.0059 - val_accuracy: 0.8164
#
# Epoch 00124: val_loss did not improve from 0.86840
# Epoch 125/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7591 - accuracy: 0.9338 - val_loss: 1.0082 - val_accuracy: 0.8086
#
# Epoch 00125: val_loss did not improve from 0.86840
# Epoch 126/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.7701 - accuracy: 0.9366 - val_loss: 1.0013 - val_accuracy: 0.8125
#
# Epoch 00126: val_loss did not improve from 0.86840
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 127/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.8422 - accuracy: 0.9324 - val_loss: 1.0019 - val_accuracy: 0.8125
#
# Epoch 00127: val_loss did not improve from 0.86840
# Epoch 128/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.6723 - accuracy: 0.9476 - val_loss: 0.9414 - val_accuracy: 0.8281
#
# Epoch 00128: val_loss did not improve from 0.86840
# Epoch 129/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7208 - accuracy: 0.9398 - val_loss: 1.0041 - val_accuracy: 0.8125
#
# Epoch 00129: val_loss did not improve from 0.86840
# Epoch 130/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.6416 - accuracy: 0.9568 - val_loss: 0.9901 - val_accuracy: 0.8164
#
# Epoch 00130: val_loss did not improve from 0.86840
# Epoch 131/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.7781 - accuracy: 0.9384 - val_loss: 0.9782 - val_accuracy: 0.8164
#
# Epoch 00131: val_loss did not improve from 0.86840
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 132/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.8007 - accuracy: 0.9324 - val_loss: 0.9769 - val_accuracy: 0.8164
#
# Epoch 00132: val_loss did not improve from 0.86840
# Epoch 133/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 0.7362 - accuracy: 0.9439 - val_loss: 0.9772 - val_accuracy: 0.8125
#
# Epoch 00133: val_loss did not improve from 0.86840
# Epoch 134/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7535 - accuracy: 0.9361 - val_loss: 0.9944 - val_accuracy: 0.8047
#
# Epoch 00134: val_loss did not improve from 0.86840
# Epoch 135/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7643 - accuracy: 0.9384 - val_loss: 0.9918 - val_accuracy: 0.8047
#
# Epoch 00135: val_loss did not improve from 0.86840
# Epoch 136/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7830 - accuracy: 0.9301 - val_loss: 0.9833 - val_accuracy: 0.8203
#
# Epoch 00136: val_loss did not improve from 0.86840
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7433 - accuracy: 0.8448
# [0.7432503700256348, 0.8447999954223633]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
