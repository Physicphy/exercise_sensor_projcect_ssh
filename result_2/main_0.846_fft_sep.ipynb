# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

# def scheduler(epoch, lr):
#     if (epoch>20) and (lr > 0.00001):
#         lr = lr*0.9
#         return lr
#     else:
#         return lr

# lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 6)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 3)       0           input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      1090        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      730         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 10)      550         concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1090        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 10)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 10)      40          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 20)      1920        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 20)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 20)      80          leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      3660        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 60)      21960       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 150, 420)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      226860      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 120)     480         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      226860      concatenate_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_30[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 120)     480         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_33[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_36[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_39[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 120)     480         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_42[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 120)     480         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_45[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 120)     480         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_48[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 120)     480         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_51[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 120)     480         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_54[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,319,231
# Trainable params: 1,312,691
# Non-trainable params: 6,540
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 43s 367ms/step - loss: 43.2783 - accuracy: 0.3258 - val_loss: 31.9947 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 31.99468, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 27.9860 - accuracy: 0.5694 - val_loss: 21.0604 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 31.99468 to 21.06037, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 18.3055 - accuracy: 0.6484 - val_loss: 14.2765 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 21.06037 to 14.27649, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 12.8267 - accuracy: 0.6673 - val_loss: 10.5199 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 14.27649 to 10.51989, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 9.3988 - accuracy: 0.6801 - val_loss: 8.3443 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 10.51989 to 8.34429, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 7.0250 - accuracy: 0.7233 - val_loss: 6.9504 - val_accuracy: 0.0117
#
# Epoch 00006: val_loss improved from 8.34429 to 6.95041, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 5.5851 - accuracy: 0.7279 - val_loss: 5.9039 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 6.95041 to 5.90394, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 4.5563 - accuracy: 0.7403 - val_loss: 5.7645 - val_accuracy: 0.0117
#
# Epoch 00008: val_loss improved from 5.90394 to 5.76450, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 3.8821 - accuracy: 0.7615 - val_loss: 5.3946 - val_accuracy: 0.0195
#
# Epoch 00009: val_loss improved from 5.76450 to 5.39465, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 3.6755 - accuracy: 0.7495 - val_loss: 6.3261 - val_accuracy: 0.0273
#
# Epoch 00010: val_loss did not improve from 5.39465
# Epoch 11/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 3.2957 - accuracy: 0.7675 - val_loss: 7.1633 - val_accuracy: 0.0195
#
# Epoch 00011: val_loss did not improve from 5.39465
# Epoch 12/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 3.0185 - accuracy: 0.7725 - val_loss: 6.1776 - val_accuracy: 0.0273
#
# Epoch 00012: val_loss did not improve from 5.39465
# Epoch 13/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 2.7252 - accuracy: 0.8024 - val_loss: 6.6701 - val_accuracy: 0.0312
#
# Epoch 00013: val_loss did not improve from 5.39465
# Epoch 14/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 2.5861 - accuracy: 0.7937 - val_loss: 6.6740 - val_accuracy: 0.0312
#
# Epoch 00014: val_loss did not improve from 5.39465
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 2.3320 - accuracy: 0.8194 - val_loss: 6.0214 - val_accuracy: 0.0625
#
# Epoch 00015: val_loss did not improve from 5.39465
# Epoch 16/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 2.1379 - accuracy: 0.8263 - val_loss: 4.6507 - val_accuracy: 0.1875
#
# Epoch 00016: val_loss improved from 5.39465 to 4.65074, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 2.1204 - accuracy: 0.8258 - val_loss: 2.8741 - val_accuracy: 0.4727
#
# Epoch 00017: val_loss improved from 4.65074 to 2.87412, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 1.8955 - accuracy: 0.8539 - val_loss: 2.3979 - val_accuracy: 0.5742
#
# Epoch 00018: val_loss improved from 2.87412 to 2.39787, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.7847 - accuracy: 0.8608 - val_loss: 2.1596 - val_accuracy: 0.6055
#
# Epoch 00019: val_loss improved from 2.39787 to 2.15960, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 2.0504 - accuracy: 0.8189 - val_loss: 1.9801 - val_accuracy: 0.6055
#
# Epoch 00020: val_loss improved from 2.15960 to 1.98011, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.8942 - accuracy: 0.8424 - val_loss: 2.0020 - val_accuracy: 0.6719
#
# Epoch 00021: val_loss did not improve from 1.98011
# Epoch 22/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.7709 - accuracy: 0.8585 - val_loss: 2.3172 - val_accuracy: 0.5859
#
# Epoch 00022: val_loss did not improve from 1.98011
# Epoch 23/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.7394 - accuracy: 0.8598 - val_loss: 1.6998 - val_accuracy: 0.6836
#
# Epoch 00023: val_loss improved from 1.98011 to 1.69982, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 1.6644 - accuracy: 0.8626 - val_loss: 1.4629 - val_accuracy: 0.7227
#
# Epoch 00024: val_loss improved from 1.69982 to 1.46285, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 1.6768 - accuracy: 0.8649 - val_loss: 2.0989 - val_accuracy: 0.5508
#
# Epoch 00025: val_loss did not improve from 1.46285
# Epoch 26/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.6531 - accuracy: 0.8653 - val_loss: 1.5411 - val_accuracy: 0.7383
#
# Epoch 00026: val_loss did not improve from 1.46285
# Epoch 27/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 1.6384 - accuracy: 0.8589 - val_loss: 1.4895 - val_accuracy: 0.7344
#
# Epoch 00027: val_loss did not improve from 1.46285
# Epoch 28/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.6318 - accuracy: 0.8626 - val_loss: 1.4141 - val_accuracy: 0.7461
#
# Epoch 00028: val_loss improved from 1.46285 to 1.41408, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 1.6240 - accuracy: 0.8612 - val_loss: 1.6089 - val_accuracy: 0.6992
#
# Epoch 00029: val_loss did not improve from 1.41408
# Epoch 30/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 1.5111 - accuracy: 0.8782 - val_loss: 1.7562 - val_accuracy: 0.7031
#
# Epoch 00030: val_loss did not improve from 1.41408
# Epoch 31/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 1.4809 - accuracy: 0.8745 - val_loss: 1.4403 - val_accuracy: 0.7188
#
# Epoch 00031: val_loss did not improve from 1.41408
# Epoch 32/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 1.4607 - accuracy: 0.8865 - val_loss: 1.3871 - val_accuracy: 0.7266
#
# Epoch 00032: val_loss improved from 1.41408 to 1.38706, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.5242 - accuracy: 0.8626 - val_loss: 1.7350 - val_accuracy: 0.7031
#
# Epoch 00033: val_loss did not improve from 1.38706
# Epoch 34/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.4960 - accuracy: 0.8727 - val_loss: 1.5315 - val_accuracy: 0.7422
#
# Epoch 00034: val_loss did not improve from 1.38706
# Epoch 35/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.4815 - accuracy: 0.8736 - val_loss: 2.0635 - val_accuracy: 0.6133
#
# Epoch 00035: val_loss did not improve from 1.38706
# Epoch 36/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.4306 - accuracy: 0.8755 - val_loss: 1.3438 - val_accuracy: 0.7617
#
# Epoch 00036: val_loss improved from 1.38706 to 1.34381, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.4185 - accuracy: 0.8851 - val_loss: 1.7339 - val_accuracy: 0.6562
#
# Epoch 00037: val_loss did not improve from 1.34381
# Epoch 38/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 1.3342 - accuracy: 0.8879 - val_loss: 1.3986 - val_accuracy: 0.7305
#
# Epoch 00038: val_loss did not improve from 1.34381
# Epoch 39/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.3626 - accuracy: 0.8833 - val_loss: 1.3496 - val_accuracy: 0.7656
#
# Epoch 00039: val_loss did not improve from 1.34381
# Epoch 40/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.3463 - accuracy: 0.8888 - val_loss: 1.8040 - val_accuracy: 0.6758
#
# Epoch 00040: val_loss did not improve from 1.34381
# Epoch 41/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 1.2656 - accuracy: 0.8980 - val_loss: 1.5292 - val_accuracy: 0.7148
#
# Epoch 00041: val_loss did not improve from 1.34381
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 42/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.1975 - accuracy: 0.9017 - val_loss: 1.2260 - val_accuracy: 0.7695
#
# Epoch 00042: val_loss improved from 1.34381 to 1.22598, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 8s 247ms/step - loss: 1.0885 - accuracy: 0.9145 - val_loss: 1.4211 - val_accuracy: 0.7031
#
# Epoch 00043: val_loss did not improve from 1.22598
# Epoch 44/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.8873 - accuracy: 0.9407 - val_loss: 1.2116 - val_accuracy: 0.7539
#
# Epoch 00044: val_loss improved from 1.22598 to 1.21159, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.0568 - accuracy: 0.9154 - val_loss: 1.1364 - val_accuracy: 0.7891
#
# Epoch 00045: val_loss improved from 1.21159 to 1.13639, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.8537 - accuracy: 0.9412 - val_loss: 1.3607 - val_accuracy: 0.7344
#
# Epoch 00046: val_loss did not improve from 1.13639
# Epoch 47/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.9561 - accuracy: 0.9246 - val_loss: 1.1849 - val_accuracy: 0.7422
#
# Epoch 00047: val_loss did not improve from 1.13639
# Epoch 48/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.9132 - accuracy: 0.9256 - val_loss: 1.3658 - val_accuracy: 0.7422
#
# Epoch 00048: val_loss did not improve from 1.13639
# Epoch 49/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.1012 - accuracy: 0.8984 - val_loss: 1.5125 - val_accuracy: 0.6875
#
# Epoch 00049: val_loss did not improve from 1.13639
# Epoch 50/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.0288 - accuracy: 0.9191 - val_loss: 1.4718 - val_accuracy: 0.7266
#
# Epoch 00050: val_loss did not improve from 1.13639
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 51/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.8381 - accuracy: 0.9421 - val_loss: 0.9530 - val_accuracy: 0.8203
#
# Epoch 00051: val_loss improved from 1.13639 to 0.95301, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.7977 - accuracy: 0.9439 - val_loss: 1.0132 - val_accuracy: 0.8086
#
# Epoch 00052: val_loss did not improve from 0.95301
# Epoch 53/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.7921 - accuracy: 0.9458 - val_loss: 1.0579 - val_accuracy: 0.7969
#
# Epoch 00053: val_loss did not improve from 0.95301
# Epoch 54/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.8613 - accuracy: 0.9324 - val_loss: 1.0110 - val_accuracy: 0.8281
#
# Epoch 00054: val_loss did not improve from 0.95301
# Epoch 55/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.7834 - accuracy: 0.9439 - val_loss: 1.0866 - val_accuracy: 0.7969
#
# Epoch 00055: val_loss did not improve from 0.95301
# Epoch 56/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.7790 - accuracy: 0.9430 - val_loss: 1.0726 - val_accuracy: 0.8008
#
# Epoch 00056: val_loss did not improve from 0.95301
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.6764 - accuracy: 0.9563 - val_loss: 1.0082 - val_accuracy: 0.8398
#
# Epoch 00057: val_loss did not improve from 0.95301
# Epoch 58/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.7314 - accuracy: 0.9462 - val_loss: 1.0254 - val_accuracy: 0.8125
#
# Epoch 00058: val_loss did not improve from 0.95301
# Epoch 59/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.6681 - accuracy: 0.9573 - val_loss: 0.9581 - val_accuracy: 0.8164
#
# Epoch 00059: val_loss did not improve from 0.95301
# Epoch 60/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.7015 - accuracy: 0.9504 - val_loss: 1.0097 - val_accuracy: 0.8086
#
# Epoch 00060: val_loss did not improve from 0.95301
# Epoch 61/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.7038 - accuracy: 0.9517 - val_loss: 1.0173 - val_accuracy: 0.8008
#
# Epoch 00061: val_loss did not improve from 0.95301
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 62/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.6598 - accuracy: 0.9582 - val_loss: 1.0158 - val_accuracy: 0.8203
#
# Epoch 00062: val_loss did not improve from 0.95301
# Epoch 63/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.6235 - accuracy: 0.9586 - val_loss: 1.0104 - val_accuracy: 0.7930
#
# Epoch 00063: val_loss did not improve from 0.95301
# Epoch 64/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.6210 - accuracy: 0.9586 - val_loss: 1.0040 - val_accuracy: 0.8047
#
# Epoch 00064: val_loss did not improve from 0.95301
# Epoch 65/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.6074 - accuracy: 0.9586 - val_loss: 0.9872 - val_accuracy: 0.8281
#
# Epoch 00065: val_loss did not improve from 0.95301
# Epoch 66/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5940 - accuracy: 0.9596 - val_loss: 1.0115 - val_accuracy: 0.8281
#
# Epoch 00066: val_loss did not improve from 0.95301
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 67/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5437 - accuracy: 0.9715 - val_loss: 0.9274 - val_accuracy: 0.8516
#
# Epoch 00067: val_loss improved from 0.95301 to 0.92745, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5696 - accuracy: 0.9632 - val_loss: 0.9507 - val_accuracy: 0.8438
#
# Epoch 00068: val_loss did not improve from 0.92745
# Epoch 69/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5820 - accuracy: 0.9628 - val_loss: 0.9255 - val_accuracy: 0.8477
#
# Epoch 00069: val_loss improved from 0.92745 to 0.92549, saving model to ./save/cnn_gru_best.hdf5
# Epoch 70/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.6074 - accuracy: 0.9605 - val_loss: 0.9545 - val_accuracy: 0.8398
#
# Epoch 00070: val_loss did not improve from 0.92549
# Epoch 71/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5734 - accuracy: 0.9669 - val_loss: 0.9447 - val_accuracy: 0.8438
#
# Epoch 00071: val_loss did not improve from 0.92549
# Epoch 72/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5611 - accuracy: 0.9655 - val_loss: 0.9752 - val_accuracy: 0.8320
#
# Epoch 00072: val_loss did not improve from 0.92549
# Epoch 73/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5992 - accuracy: 0.9605 - val_loss: 0.9957 - val_accuracy: 0.8164
#
# Epoch 00073: val_loss did not improve from 0.92549
# Epoch 74/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5828 - accuracy: 0.9632 - val_loss: 0.9835 - val_accuracy: 0.8320
#
# Epoch 00074: val_loss did not improve from 0.92549
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 75/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5233 - accuracy: 0.9701 - val_loss: 0.9273 - val_accuracy: 0.8398
#
# Epoch 00075: val_loss did not improve from 0.92549
# Epoch 76/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5399 - accuracy: 0.9665 - val_loss: 0.9367 - val_accuracy: 0.8477
#
# Epoch 00076: val_loss did not improve from 0.92549
# Epoch 77/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5318 - accuracy: 0.9692 - val_loss: 0.9704 - val_accuracy: 0.8320
#
# Epoch 00077: val_loss did not improve from 0.92549
# Epoch 78/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.5309 - accuracy: 0.9724 - val_loss: 0.9420 - val_accuracy: 0.8320
#
# Epoch 00078: val_loss did not improve from 0.92549
# Epoch 79/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.6019 - accuracy: 0.9600 - val_loss: 0.9808 - val_accuracy: 0.8359
#
# Epoch 00079: val_loss did not improve from 0.92549
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 80/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5713 - accuracy: 0.9614 - val_loss: 0.9866 - val_accuracy: 0.8320
#
# Epoch 00080: val_loss did not improve from 0.92549
# Epoch 81/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.5637 - accuracy: 0.9632 - val_loss: 0.9556 - val_accuracy: 0.8477
#
# Epoch 00081: val_loss did not improve from 0.92549
# Epoch 82/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.5536 - accuracy: 0.9605 - val_loss: 0.9336 - val_accuracy: 0.8438
#
# Epoch 00082: val_loss did not improve from 0.92549
# Epoch 83/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.4728 - accuracy: 0.9789 - val_loss: 0.9676 - val_accuracy: 0.8320
#
# Epoch 00083: val_loss did not improve from 0.92549
# Epoch 84/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5075 - accuracy: 0.9752 - val_loss: 0.9761 - val_accuracy: 0.8320
#
# Epoch 00084: val_loss did not improve from 0.92549
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 85/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.4838 - accuracy: 0.9743 - val_loss: 0.9489 - val_accuracy: 0.8398
#
# Epoch 00085: val_loss did not improve from 0.92549
# Epoch 86/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.4640 - accuracy: 0.9784 - val_loss: 0.9675 - val_accuracy: 0.8516
#
# Epoch 00086: val_loss did not improve from 0.92549
# Epoch 87/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5659 - accuracy: 0.9665 - val_loss: 0.9784 - val_accuracy: 0.8359
#
# Epoch 00087: val_loss did not improve from 0.92549
# Epoch 88/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5715 - accuracy: 0.9614 - val_loss: 0.9878 - val_accuracy: 0.8359
#
# Epoch 00088: val_loss did not improve from 0.92549
# Epoch 89/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5144 - accuracy: 0.9678 - val_loss: 0.9187 - val_accuracy: 0.8359
#
# Epoch 00089: val_loss improved from 0.92549 to 0.91875, saving model to ./save/cnn_gru_best.hdf5
# Epoch 90/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5245 - accuracy: 0.9706 - val_loss: 0.9530 - val_accuracy: 0.8438
#
# Epoch 00090: val_loss did not improve from 0.91875
# Epoch 91/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5640 - accuracy: 0.9655 - val_loss: 0.9645 - val_accuracy: 0.8320
#
# Epoch 00091: val_loss did not improve from 0.91875
# Epoch 92/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5261 - accuracy: 0.9692 - val_loss: 0.9587 - val_accuracy: 0.8398
#
# Epoch 00092: val_loss did not improve from 0.91875
# Epoch 93/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5732 - accuracy: 0.9600 - val_loss: 0.9663 - val_accuracy: 0.8398
#
# Epoch 00093: val_loss did not improve from 0.91875
# Epoch 94/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.4870 - accuracy: 0.9733 - val_loss: 0.9856 - val_accuracy: 0.8359
#
# Epoch 00094: val_loss did not improve from 0.91875
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 95/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5001 - accuracy: 0.9752 - val_loss: 0.9654 - val_accuracy: 0.8359
#
# Epoch 00095: val_loss did not improve from 0.91875
# Epoch 96/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5096 - accuracy: 0.9706 - val_loss: 0.9153 - val_accuracy: 0.8438
#
# Epoch 00096: val_loss improved from 0.91875 to 0.91527, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5918 - accuracy: 0.9600 - val_loss: 0.9890 - val_accuracy: 0.8320
#
# Epoch 00097: val_loss did not improve from 0.91527
# Epoch 98/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5141 - accuracy: 0.9724 - val_loss: 0.8990 - val_accuracy: 0.8438
#
# Epoch 00098: val_loss improved from 0.91527 to 0.89897, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5352 - accuracy: 0.9692 - val_loss: 0.9469 - val_accuracy: 0.8398
#
# Epoch 00099: val_loss did not improve from 0.89897
# Epoch 100/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.4996 - accuracy: 0.9710 - val_loss: 0.9057 - val_accuracy: 0.8438
#
# Epoch 00100: val_loss did not improve from 0.89897
# Epoch 101/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.5031 - accuracy: 0.9733 - val_loss: 0.9931 - val_accuracy: 0.8281
#
# Epoch 00101: val_loss did not improve from 0.89897
# Epoch 102/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.5137 - accuracy: 0.9710 - val_loss: 0.9434 - val_accuracy: 0.8359
#
# Epoch 00102: val_loss did not improve from 0.89897
# Epoch 103/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5645 - accuracy: 0.9665 - val_loss: 0.9465 - val_accuracy: 0.8359
#
# Epoch 00103: val_loss did not improve from 0.89897
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 104/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4962 - accuracy: 0.9720 - val_loss: 0.9591 - val_accuracy: 0.8398
#
# Epoch 00104: val_loss did not improve from 0.89897
# Epoch 105/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5221 - accuracy: 0.9729 - val_loss: 0.9499 - val_accuracy: 0.8398
#
# Epoch 00105: val_loss did not improve from 0.89897
# Epoch 106/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5116 - accuracy: 0.9688 - val_loss: 0.8641 - val_accuracy: 0.8477
#
# Epoch 00106: val_loss improved from 0.89897 to 0.86407, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4929 - accuracy: 0.9775 - val_loss: 0.9116 - val_accuracy: 0.8516
#
# Epoch 00107: val_loss did not improve from 0.86407
# Epoch 108/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5186 - accuracy: 0.9697 - val_loss: 0.9080 - val_accuracy: 0.8516
#
# Epoch 00108: val_loss did not improve from 0.86407
# Epoch 109/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5394 - accuracy: 0.9710 - val_loss: 0.9148 - val_accuracy: 0.8438
#
# Epoch 00109: val_loss did not improve from 0.86407
# Epoch 110/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.5049 - accuracy: 0.9701 - val_loss: 0.9645 - val_accuracy: 0.8359
#
# Epoch 00110: val_loss did not improve from 0.86407
# Epoch 111/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5762 - accuracy: 0.9692 - val_loss: 0.9745 - val_accuracy: 0.8359
#
# Epoch 00111: val_loss did not improve from 0.86407
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 112/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.5113 - accuracy: 0.9733 - val_loss: 0.9902 - val_accuracy: 0.8320
#
# Epoch 00112: val_loss did not improve from 0.86407
# Epoch 113/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5127 - accuracy: 0.9720 - val_loss: 0.9362 - val_accuracy: 0.8438
#
# Epoch 00113: val_loss did not improve from 0.86407
# Epoch 114/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5464 - accuracy: 0.9692 - val_loss: 0.9929 - val_accuracy: 0.8320
#
# Epoch 00114: val_loss did not improve from 0.86407
# Epoch 115/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5036 - accuracy: 0.9701 - val_loss: 0.9426 - val_accuracy: 0.8359
#
# Epoch 00115: val_loss did not improve from 0.86407
# Epoch 116/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5281 - accuracy: 0.9715 - val_loss: 0.9387 - val_accuracy: 0.8398
#
# Epoch 00116: val_loss did not improve from 0.86407
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 117/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.5429 - accuracy: 0.9683 - val_loss: 0.9497 - val_accuracy: 0.8398
#
# Epoch 00117: val_loss did not improve from 0.86407
# Epoch 118/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5025 - accuracy: 0.9733 - val_loss: 0.9486 - val_accuracy: 0.8398
#
# Epoch 00118: val_loss did not improve from 0.86407
# Epoch 119/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5378 - accuracy: 0.9669 - val_loss: 0.9889 - val_accuracy: 0.8281
#
# Epoch 00119: val_loss did not improve from 0.86407
# Epoch 120/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5688 - accuracy: 0.9642 - val_loss: 1.0061 - val_accuracy: 0.8242
#
# Epoch 00120: val_loss did not improve from 0.86407
# Epoch 121/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5563 - accuracy: 0.9646 - val_loss: 0.9750 - val_accuracy: 0.8320
#
# Epoch 00121: val_loss did not improve from 0.86407
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 122/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.4861 - accuracy: 0.9756 - val_loss: 0.9476 - val_accuracy: 0.8398
#
# Epoch 00122: val_loss did not improve from 0.86407
# Epoch 123/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5430 - accuracy: 0.9692 - val_loss: 0.9570 - val_accuracy: 0.8359
#
# Epoch 00123: val_loss did not improve from 0.86407
# Epoch 124/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.5362 - accuracy: 0.9692 - val_loss: 0.9867 - val_accuracy: 0.8320
#
# Epoch 00124: val_loss did not improve from 0.86407
# Epoch 125/2000
# 34/34 [==============================] - 8s 244ms/step - loss: 0.5107 - accuracy: 0.9733 - val_loss: 0.9905 - val_accuracy: 0.8281
#
# Epoch 00125: val_loss did not improve from 0.86407
# Epoch 126/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5357 - accuracy: 0.9683 - val_loss: 0.9720 - val_accuracy: 0.8281
#
# Epoch 00126: val_loss did not improve from 0.86407
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 127/2000
# 34/34 [==============================] - 8s 245ms/step - loss: 0.5809 - accuracy: 0.9609 - val_loss: 0.9908 - val_accuracy: 0.8320
#
# Epoch 00127: val_loss did not improve from 0.86407
# Epoch 128/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4937 - accuracy: 0.9756 - val_loss: 0.9357 - val_accuracy: 0.8477
#
# Epoch 00128: val_loss did not improve from 0.86407
# Epoch 129/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5096 - accuracy: 0.9692 - val_loss: 0.9883 - val_accuracy: 0.8281
#
# Epoch 00129: val_loss did not improve from 0.86407
# Epoch 130/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.4847 - accuracy: 0.9770 - val_loss: 0.9789 - val_accuracy: 0.8398
#
# Epoch 00130: val_loss did not improve from 0.86407
# Epoch 131/2000
# 34/34 [==============================] - 8s 244ms/step - loss: 0.5240 - accuracy: 0.9688 - val_loss: 0.9619 - val_accuracy: 0.8398
#
# Epoch 00131: val_loss did not improve from 0.86407
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 132/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.5334 - accuracy: 0.9637 - val_loss: 0.9288 - val_accuracy: 0.8438
#
# Epoch 00132: val_loss did not improve from 0.86407
# Epoch 133/2000
# 34/34 [==============================] - 8s 245ms/step - loss: 0.5314 - accuracy: 0.9655 - val_loss: 0.9695 - val_accuracy: 0.8320
#
# Epoch 00133: val_loss did not improve from 0.86407
# Epoch 134/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.5537 - accuracy: 0.9651 - val_loss: 0.9482 - val_accuracy: 0.8320
#
# Epoch 00134: val_loss did not improve from 0.86407
# Epoch 135/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5450 - accuracy: 0.9660 - val_loss: 0.9862 - val_accuracy: 0.8242
#
# Epoch 00135: val_loss did not improve from 0.86407
# Epoch 136/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.5182 - accuracy: 0.9674 - val_loss: 0.9776 - val_accuracy: 0.8359
#
# Epoch 00136: val_loss did not improve from 0.86407
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7857 - accuracy: 0.8464
# [0.7856651544570923, 0.8464000225067139]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
