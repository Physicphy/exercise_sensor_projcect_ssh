# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1450        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1810        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,227,001
# Trainable params: 1,220,761
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 39s 334ms/step - loss: 42.9290 - accuracy: 0.3589 - val_loss: 31.1644 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 31.16440, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 27.5033 - accuracy: 0.5051 - val_loss: 20.1797 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 31.16440 to 20.17974, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 18.2098 - accuracy: 0.5712 - val_loss: 13.6293 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 20.17974 to 13.62927, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 12.9601 - accuracy: 0.5988 - val_loss: 9.8900 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 13.62927 to 9.89003, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 9.6772 - accuracy: 0.6167 - val_loss: 7.8109 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 9.89003 to 7.81087, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 7.4652 - accuracy: 0.6535 - val_loss: 6.4145 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 7.81087 to 6.41452, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 5.8931 - accuracy: 0.6774 - val_loss: 6.1155 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 6.41452 to 6.11553, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 4.9212 - accuracy: 0.7151 - val_loss: 5.3224 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 6.11553 to 5.32242, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 4.1425 - accuracy: 0.7440 - val_loss: 4.9331 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss improved from 5.32242 to 4.93305, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 4.0249 - accuracy: 0.7022 - val_loss: 5.2837 - val_accuracy: 0.4062
#
# Epoch 00010: val_loss did not improve from 4.93305
# Epoch 11/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 3.6778 - accuracy: 0.7293 - val_loss: 5.3657 - val_accuracy: 0.0625
#
# Epoch 00011: val_loss did not improve from 4.93305
# Epoch 12/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 3.5951 - accuracy: 0.7224 - val_loss: 4.8336 - val_accuracy: 0.0938
#
# Epoch 00012: val_loss improved from 4.93305 to 4.83364, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 3.2293 - accuracy: 0.7486 - val_loss: 4.8243 - val_accuracy: 0.4727
#
# Epoch 00013: val_loss improved from 4.83364 to 4.82432, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.9543 - accuracy: 0.7564 - val_loss: 4.0982 - val_accuracy: 0.3594
#
# Epoch 00014: val_loss improved from 4.82432 to 4.09821, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 3.0779 - accuracy: 0.7505 - val_loss: 6.5765 - val_accuracy: 0.0430
#
# Epoch 00015: val_loss did not improve from 4.09821
# Epoch 16/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.9436 - accuracy: 0.7601 - val_loss: 4.2584 - val_accuracy: 0.3086
#
# Epoch 00016: val_loss did not improve from 4.09821
# Epoch 17/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.8797 - accuracy: 0.7583 - val_loss: 2.8788 - val_accuracy: 0.5039
#
# Epoch 00017: val_loss improved from 4.09821 to 2.87877, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 2.5576 - accuracy: 0.7721 - val_loss: 2.4451 - val_accuracy: 0.5703
#
# Epoch 00018: val_loss improved from 2.87877 to 2.44510, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 2.4705 - accuracy: 0.7808 - val_loss: 2.3848 - val_accuracy: 0.5820
#
# Epoch 00019: val_loss improved from 2.44510 to 2.38481, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.8069 - accuracy: 0.7491 - val_loss: 2.4243 - val_accuracy: 0.6133
#
# Epoch 00020: val_loss did not improve from 2.38481
# Epoch 21/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.5544 - accuracy: 0.7707 - val_loss: 2.0141 - val_accuracy: 0.6367
#
# Epoch 00021: val_loss improved from 2.38481 to 2.01414, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 2.3783 - accuracy: 0.7868 - val_loss: 1.8431 - val_accuracy: 0.6641
#
# Epoch 00022: val_loss improved from 2.01414 to 1.84305, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.3606 - accuracy: 0.7964 - val_loss: 1.4836 - val_accuracy: 0.7305
#
# Epoch 00023: val_loss improved from 1.84305 to 1.48362, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 2.3333 - accuracy: 0.7946 - val_loss: 2.0048 - val_accuracy: 0.6172
#
# Epoch 00024: val_loss did not improve from 1.48362
# Epoch 25/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 2.2143 - accuracy: 0.7955 - val_loss: 1.9704 - val_accuracy: 0.6602
#
# Epoch 00025: val_loss did not improve from 1.48362
# Epoch 26/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.1041 - accuracy: 0.8180 - val_loss: 1.4373 - val_accuracy: 0.7422
#
# Epoch 00026: val_loss improved from 1.48362 to 1.43733, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.1957 - accuracy: 0.7987 - val_loss: 1.5219 - val_accuracy: 0.6953
#
# Epoch 00027: val_loss did not improve from 1.43733
# Epoch 28/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.2387 - accuracy: 0.7927 - val_loss: 1.5669 - val_accuracy: 0.7148
#
# Epoch 00028: val_loss did not improve from 1.43733
# Epoch 29/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 2.2388 - accuracy: 0.7983 - val_loss: 1.3930 - val_accuracy: 0.7539
#
# Epoch 00029: val_loss improved from 1.43733 to 1.39301, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.9839 - accuracy: 0.8258 - val_loss: 1.4850 - val_accuracy: 0.6953
#
# Epoch 00030: val_loss did not improve from 1.39301
# Epoch 31/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.9132 - accuracy: 0.8254 - val_loss: 1.7578 - val_accuracy: 0.6875
#
# Epoch 00031: val_loss did not improve from 1.39301
# Epoch 32/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.9712 - accuracy: 0.8208 - val_loss: 2.8506 - val_accuracy: 0.4375
#
# Epoch 00032: val_loss did not improve from 1.39301
# Epoch 33/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.9188 - accuracy: 0.8212 - val_loss: 1.3951 - val_accuracy: 0.7500
#
# Epoch 00033: val_loss did not improve from 1.39301
# Epoch 34/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.9152 - accuracy: 0.8295 - val_loss: 1.4458 - val_accuracy: 0.7344
#
# Epoch 00034: val_loss did not improve from 1.39301
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 35/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.7660 - accuracy: 0.8373 - val_loss: 1.6788 - val_accuracy: 0.6953
#
# Epoch 00035: val_loss did not improve from 1.39301
# Epoch 36/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.6580 - accuracy: 0.8438 - val_loss: 1.1337 - val_accuracy: 0.7891
#
# Epoch 00036: val_loss improved from 1.39301 to 1.13370, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.5712 - accuracy: 0.8571 - val_loss: 1.4420 - val_accuracy: 0.7070
#
# Epoch 00037: val_loss did not improve from 1.13370
# Epoch 38/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.4838 - accuracy: 0.8663 - val_loss: 1.1984 - val_accuracy: 0.7305
#
# Epoch 00038: val_loss did not improve from 1.13370
# Epoch 39/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.4754 - accuracy: 0.8585 - val_loss: 1.1811 - val_accuracy: 0.7617
#
# Epoch 00039: val_loss did not improve from 1.13370
# Epoch 40/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.4637 - accuracy: 0.8626 - val_loss: 1.2160 - val_accuracy: 0.7500
#
# Epoch 00040: val_loss did not improve from 1.13370
# Epoch 41/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.4239 - accuracy: 0.8704 - val_loss: 1.2100 - val_accuracy: 0.7656
#
# Epoch 00041: val_loss did not improve from 1.13370
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 42/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.3974 - accuracy: 0.8722 - val_loss: 1.1422 - val_accuracy: 0.7578
#
# Epoch 00042: val_loss did not improve from 1.13370
# Epoch 43/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.3605 - accuracy: 0.8764 - val_loss: 1.0735 - val_accuracy: 0.7852
#
# Epoch 00043: val_loss improved from 1.13370 to 1.07349, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.0530 - accuracy: 0.9164 - val_loss: 1.0421 - val_accuracy: 0.7891
#
# Epoch 00044: val_loss improved from 1.07349 to 1.04205, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.3336 - accuracy: 0.8755 - val_loss: 1.0338 - val_accuracy: 0.7852
#
# Epoch 00045: val_loss improved from 1.04205 to 1.03379, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.0138 - accuracy: 0.9145 - val_loss: 0.9591 - val_accuracy: 0.7969
#
# Epoch 00046: val_loss improved from 1.03379 to 0.95912, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.2075 - accuracy: 0.8851 - val_loss: 1.0172 - val_accuracy: 0.7734
#
# Epoch 00047: val_loss did not improve from 0.95912
# Epoch 48/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.0998 - accuracy: 0.9058 - val_loss: 0.9209 - val_accuracy: 0.8125
#
# Epoch 00048: val_loss improved from 0.95912 to 0.92088, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.4674 - accuracy: 0.8594 - val_loss: 1.0868 - val_accuracy: 0.7656
#
# Epoch 00049: val_loss did not improve from 0.92088
# Epoch 50/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.2871 - accuracy: 0.8750 - val_loss: 0.9488 - val_accuracy: 0.7891
#
# Epoch 00050: val_loss did not improve from 0.92088
# Epoch 51/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.0933 - accuracy: 0.9090 - val_loss: 0.9659 - val_accuracy: 0.7812
#
# Epoch 00051: val_loss did not improve from 0.92088
# Epoch 52/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.1461 - accuracy: 0.8948 - val_loss: 0.9737 - val_accuracy: 0.7930
#
# Epoch 00052: val_loss did not improve from 0.92088
# Epoch 53/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.1234 - accuracy: 0.8925 - val_loss: 1.0124 - val_accuracy: 0.7695
#
# Epoch 00053: val_loss did not improve from 0.92088
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 54/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.1995 - accuracy: 0.8856 - val_loss: 0.9453 - val_accuracy: 0.8164
#
# Epoch 00054: val_loss did not improve from 0.92088
# Epoch 55/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.0669 - accuracy: 0.9012 - val_loss: 0.9823 - val_accuracy: 0.8047
#
# Epoch 00055: val_loss did not improve from 0.92088
# Epoch 56/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.0533 - accuracy: 0.9104 - val_loss: 0.9192 - val_accuracy: 0.8125
#
# Epoch 00056: val_loss improved from 0.92088 to 0.91921, saving model to ./save/cnn_gru_best.hdf5
# Epoch 57/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9382 - accuracy: 0.9191 - val_loss: 0.9426 - val_accuracy: 0.8047
#
# Epoch 00057: val_loss did not improve from 0.91921
# Epoch 58/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.0834 - accuracy: 0.8957 - val_loss: 0.9272 - val_accuracy: 0.7852
#
# Epoch 00058: val_loss did not improve from 0.91921
# Epoch 59/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9895 - accuracy: 0.9104 - val_loss: 0.8783 - val_accuracy: 0.8281
#
# Epoch 00059: val_loss improved from 0.91921 to 0.87829, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.0355 - accuracy: 0.9012 - val_loss: 0.9151 - val_accuracy: 0.8164
#
# Epoch 00060: val_loss did not improve from 0.87829
# Epoch 61/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.0410 - accuracy: 0.8989 - val_loss: 0.9265 - val_accuracy: 0.7930
#
# Epoch 00061: val_loss did not improve from 0.87829
# Epoch 62/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.0009 - accuracy: 0.9136 - val_loss: 0.9858 - val_accuracy: 0.7852
#
# Epoch 00062: val_loss did not improve from 0.87829
# Epoch 63/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9543 - accuracy: 0.9136 - val_loss: 1.0445 - val_accuracy: 0.7812
#
# Epoch 00063: val_loss did not improve from 0.87829
# Epoch 64/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.0322 - accuracy: 0.9021 - val_loss: 1.0243 - val_accuracy: 0.7695
#
# Epoch 00064: val_loss did not improve from 0.87829
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 65/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.9088 - accuracy: 0.9205 - val_loss: 0.9558 - val_accuracy: 0.8086
#
# Epoch 00065: val_loss did not improve from 0.87829
# Epoch 66/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.8857 - accuracy: 0.9205 - val_loss: 0.9502 - val_accuracy: 0.7891
#
# Epoch 00066: val_loss did not improve from 0.87829
# Epoch 67/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8035 - accuracy: 0.9320 - val_loss: 0.8712 - val_accuracy: 0.8125
#
# Epoch 00067: val_loss improved from 0.87829 to 0.87124, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8456 - accuracy: 0.9260 - val_loss: 0.9127 - val_accuracy: 0.7969
#
# Epoch 00068: val_loss did not improve from 0.87124
# Epoch 69/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.8726 - accuracy: 0.9191 - val_loss: 0.8956 - val_accuracy: 0.8125
#
# Epoch 00069: val_loss did not improve from 0.87124
# Epoch 70/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9359 - accuracy: 0.9072 - val_loss: 0.9217 - val_accuracy: 0.8047
#
# Epoch 00070: val_loss did not improve from 0.87124
# Epoch 71/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9014 - accuracy: 0.9205 - val_loss: 0.9233 - val_accuracy: 0.8047
#
# Epoch 00071: val_loss did not improve from 0.87124
# Epoch 72/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.8410 - accuracy: 0.9251 - val_loss: 0.9295 - val_accuracy: 0.8008
#
# Epoch 00072: val_loss did not improve from 0.87124
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 73/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8939 - accuracy: 0.9223 - val_loss: 0.9251 - val_accuracy: 0.7695
#
# Epoch 00073: val_loss did not improve from 0.87124
# Epoch 74/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9013 - accuracy: 0.9173 - val_loss: 0.9229 - val_accuracy: 0.8008
#
# Epoch 00074: val_loss did not improve from 0.87124
# Epoch 75/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.7606 - accuracy: 0.9352 - val_loss: 0.8879 - val_accuracy: 0.8125
#
# Epoch 00075: val_loss did not improve from 0.87124
# Epoch 76/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.8177 - accuracy: 0.9256 - val_loss: 0.8838 - val_accuracy: 0.7852
#
# Epoch 00076: val_loss did not improve from 0.87124
# Epoch 77/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7872 - accuracy: 0.9288 - val_loss: 0.8951 - val_accuracy: 0.8047
#
# Epoch 00077: val_loss did not improve from 0.87124
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 78/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7709 - accuracy: 0.9357 - val_loss: 0.8892 - val_accuracy: 0.7930
#
# Epoch 00078: val_loss did not improve from 0.87124
# Epoch 79/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9592 - accuracy: 0.9173 - val_loss: 0.9182 - val_accuracy: 0.7930
#
# Epoch 00079: val_loss did not improve from 0.87124
# Epoch 80/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.8042 - accuracy: 0.9315 - val_loss: 0.9163 - val_accuracy: 0.8008
#
# Epoch 00080: val_loss did not improve from 0.87124
# Epoch 81/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7859 - accuracy: 0.9352 - val_loss: 0.8880 - val_accuracy: 0.8125
#
# Epoch 00081: val_loss did not improve from 0.87124
# Epoch 82/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8053 - accuracy: 0.9343 - val_loss: 0.8711 - val_accuracy: 0.8164
#
# Epoch 00082: val_loss improved from 0.87124 to 0.87111, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.6625 - accuracy: 0.9513 - val_loss: 0.8890 - val_accuracy: 0.8203
#
# Epoch 00083: val_loss did not improve from 0.87111
# Epoch 84/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7205 - accuracy: 0.9398 - val_loss: 0.9197 - val_accuracy: 0.8047
#
# Epoch 00084: val_loss did not improve from 0.87111
# Epoch 85/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.6832 - accuracy: 0.9453 - val_loss: 0.8917 - val_accuracy: 0.8047
#
# Epoch 00085: val_loss did not improve from 0.87111
# Epoch 86/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.6390 - accuracy: 0.9499 - val_loss: 0.8965 - val_accuracy: 0.8047
#
# Epoch 00086: val_loss did not improve from 0.87111
# Epoch 87/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8623 - accuracy: 0.9214 - val_loss: 0.8999 - val_accuracy: 0.8125
#
# Epoch 00087: val_loss did not improve from 0.87111
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 88/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.8423 - accuracy: 0.9223 - val_loss: 0.9100 - val_accuracy: 0.7969
#
# Epoch 00088: val_loss did not improve from 0.87111
# Epoch 89/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7648 - accuracy: 0.9361 - val_loss: 0.8920 - val_accuracy: 0.8086
#
# Epoch 00089: val_loss did not improve from 0.87111
# Epoch 90/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7225 - accuracy: 0.9384 - val_loss: 0.8827 - val_accuracy: 0.8008
#
# Epoch 00090: val_loss did not improve from 0.87111
# Epoch 91/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7835 - accuracy: 0.9269 - val_loss: 0.8819 - val_accuracy: 0.7969
#
# Epoch 00091: val_loss did not improve from 0.87111
# Epoch 92/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7105 - accuracy: 0.9403 - val_loss: 0.8751 - val_accuracy: 0.8086
#
# Epoch 00092: val_loss did not improve from 0.87111
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 93/2000
# 34/34 [==============================] - 8s 217ms/step - loss: 0.7824 - accuracy: 0.9297 - val_loss: 0.8978 - val_accuracy: 0.7969
#
# Epoch 00093: val_loss did not improve from 0.87111
# Epoch 94/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.6842 - accuracy: 0.9384 - val_loss: 0.9089 - val_accuracy: 0.7930
#
# Epoch 00094: val_loss did not improve from 0.87111
# Epoch 95/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.7269 - accuracy: 0.9398 - val_loss: 0.8922 - val_accuracy: 0.8008
#
# Epoch 00095: val_loss did not improve from 0.87111
# Epoch 96/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7612 - accuracy: 0.9366 - val_loss: 0.8678 - val_accuracy: 0.7969
#
# Epoch 00096: val_loss improved from 0.87111 to 0.86783, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8580 - accuracy: 0.9237 - val_loss: 0.9106 - val_accuracy: 0.8047
#
# Epoch 00097: val_loss did not improve from 0.86783
# Epoch 98/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7066 - accuracy: 0.9453 - val_loss: 0.8897 - val_accuracy: 0.8008
#
# Epoch 00098: val_loss did not improve from 0.86783
# Epoch 99/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7849 - accuracy: 0.9370 - val_loss: 0.8984 - val_accuracy: 0.7969
#
# Epoch 00099: val_loss did not improve from 0.86783
# Epoch 100/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.6745 - accuracy: 0.9412 - val_loss: 0.8588 - val_accuracy: 0.8125
#
# Epoch 00100: val_loss improved from 0.86783 to 0.85881, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7357 - accuracy: 0.9380 - val_loss: 0.9156 - val_accuracy: 0.7969
#
# Epoch 00101: val_loss did not improve from 0.85881
# Epoch 102/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7288 - accuracy: 0.9403 - val_loss: 0.8863 - val_accuracy: 0.8086
#
# Epoch 00102: val_loss did not improve from 0.85881
# Epoch 103/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8305 - accuracy: 0.9205 - val_loss: 0.8950 - val_accuracy: 0.7969
#
# Epoch 00103: val_loss did not improve from 0.85881
# Epoch 104/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.6627 - accuracy: 0.9467 - val_loss: 0.8956 - val_accuracy: 0.8047
#
# Epoch 00104: val_loss did not improve from 0.85881
# Epoch 105/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7454 - accuracy: 0.9393 - val_loss: 0.8850 - val_accuracy: 0.8086
#
# Epoch 00105: val_loss did not improve from 0.85881
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 106/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7218 - accuracy: 0.9347 - val_loss: 0.8207 - val_accuracy: 0.8125
#
# Epoch 00106: val_loss improved from 0.85881 to 0.82072, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.6840 - accuracy: 0.9485 - val_loss: 0.8538 - val_accuracy: 0.8125
#
# Epoch 00107: val_loss did not improve from 0.82072
# Epoch 108/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7023 - accuracy: 0.9403 - val_loss: 0.7967 - val_accuracy: 0.8242
#
# Epoch 00108: val_loss improved from 0.82072 to 0.79666, saving model to ./save/cnn_gru_best.hdf5
# Epoch 109/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7983 - accuracy: 0.9196 - val_loss: 0.8447 - val_accuracy: 0.8164
#
# Epoch 00109: val_loss did not improve from 0.79666
# Epoch 110/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.6854 - accuracy: 0.9412 - val_loss: 0.8810 - val_accuracy: 0.8203
#
# Epoch 00110: val_loss did not improve from 0.79666
# Epoch 111/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8261 - accuracy: 0.9283 - val_loss: 0.9038 - val_accuracy: 0.8125
#
# Epoch 00111: val_loss did not improve from 0.79666
# Epoch 112/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7096 - accuracy: 0.9430 - val_loss: 0.9275 - val_accuracy: 0.7969
#
# Epoch 00112: val_loss did not improve from 0.79666
# Epoch 113/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7153 - accuracy: 0.9426 - val_loss: 0.8981 - val_accuracy: 0.8164
#
# Epoch 00113: val_loss did not improve from 0.79666
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 114/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7702 - accuracy: 0.9278 - val_loss: 0.9240 - val_accuracy: 0.7930
#
# Epoch 00114: val_loss did not improve from 0.79666
# Epoch 115/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7277 - accuracy: 0.9380 - val_loss: 0.8864 - val_accuracy: 0.7969
#
# Epoch 00115: val_loss did not improve from 0.79666
# Epoch 116/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7219 - accuracy: 0.9352 - val_loss: 0.8870 - val_accuracy: 0.8047
#
# Epoch 00116: val_loss did not improve from 0.79666
# Epoch 117/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7781 - accuracy: 0.9297 - val_loss: 0.8909 - val_accuracy: 0.7969
#
# Epoch 00117: val_loss did not improve from 0.79666
# Epoch 118/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.6992 - accuracy: 0.9472 - val_loss: 0.8914 - val_accuracy: 0.8008
#
# Epoch 00118: val_loss did not improve from 0.79666
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 119/2000
# 34/34 [==============================] - 9s 274ms/step - loss: 0.7447 - accuracy: 0.9384 - val_loss: 0.9263 - val_accuracy: 0.7969
#
# Epoch 00119: val_loss did not improve from 0.79666
# Epoch 120/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.8101 - accuracy: 0.9219 - val_loss: 0.9404 - val_accuracy: 0.7969
#
# Epoch 00120: val_loss did not improve from 0.79666
# Epoch 121/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7818 - accuracy: 0.9324 - val_loss: 0.9323 - val_accuracy: 0.7969
#
# Epoch 00121: val_loss did not improve from 0.79666
# Epoch 122/2000
# 34/34 [==============================] - 9s 266ms/step - loss: 0.6590 - accuracy: 0.9481 - val_loss: 0.8828 - val_accuracy: 0.8125
#
# Epoch 00122: val_loss did not improve from 0.79666
# Epoch 123/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.7607 - accuracy: 0.9311 - val_loss: 0.9105 - val_accuracy: 0.8047
#
# Epoch 00123: val_loss did not improve from 0.79666
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 124/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.7455 - accuracy: 0.9357 - val_loss: 0.9283 - val_accuracy: 0.8086
#
# Epoch 00124: val_loss did not improve from 0.79666
# Epoch 125/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7336 - accuracy: 0.9352 - val_loss: 0.9240 - val_accuracy: 0.8008
#
# Epoch 00125: val_loss did not improve from 0.79666
# Epoch 126/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7660 - accuracy: 0.9265 - val_loss: 0.9309 - val_accuracy: 0.8047
#
# Epoch 00126: val_loss did not improve from 0.79666
# Epoch 127/2000
# 34/34 [==============================] - 8s 245ms/step - loss: 0.8247 - accuracy: 0.9246 - val_loss: 0.9282 - val_accuracy: 0.7969
#
# Epoch 00127: val_loss did not improve from 0.79666
# Epoch 128/2000
# 34/34 [==============================] - 9s 250ms/step - loss: 0.6817 - accuracy: 0.9462 - val_loss: 0.8820 - val_accuracy: 0.8047
#
# Epoch 00128: val_loss did not improve from 0.79666
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 129/2000
# 34/34 [==============================] - 8s 246ms/step - loss: 0.7160 - accuracy: 0.9412 - val_loss: 0.9325 - val_accuracy: 0.7930
#
# Epoch 00129: val_loss did not improve from 0.79666
# Epoch 130/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.6671 - accuracy: 0.9426 - val_loss: 0.9294 - val_accuracy: 0.7969
#
# Epoch 00130: val_loss did not improve from 0.79666
# Epoch 131/2000
# 34/34 [==============================] - 9s 267ms/step - loss: 0.7497 - accuracy: 0.9324 - val_loss: 0.9181 - val_accuracy: 0.8008
#
# Epoch 00131: val_loss did not improve from 0.79666
# Epoch 132/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.7312 - accuracy: 0.9403 - val_loss: 0.9078 - val_accuracy: 0.8086
#
# Epoch 00132: val_loss did not improve from 0.79666
# Epoch 133/2000
# 34/34 [==============================] - 8s 223ms/step - loss: 0.7605 - accuracy: 0.9324 - val_loss: 0.9177 - val_accuracy: 0.8047
#
# Epoch 00133: val_loss did not improve from 0.79666
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 134/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7201 - accuracy: 0.9380 - val_loss: 0.9238 - val_accuracy: 0.8008
#
# Epoch 00134: val_loss did not improve from 0.79666
# Epoch 135/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.7733 - accuracy: 0.9366 - val_loss: 0.9126 - val_accuracy: 0.8008
#
# Epoch 00135: val_loss did not improve from 0.79666
# Epoch 136/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7542 - accuracy: 0.9292 - val_loss: 0.9280 - val_accuracy: 0.8086
#
# Epoch 00136: val_loss did not improve from 0.79666
# Epoch 137/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.7600 - accuracy: 0.9352 - val_loss: 0.9023 - val_accuracy: 0.8086
#
# Epoch 00137: val_loss did not improve from 0.79666
# Epoch 138/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 0.6550 - accuracy: 0.9494 - val_loss: 0.8995 - val_accuracy: 0.8125
#
# Epoch 00138: val_loss did not improve from 0.79666
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 00138: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7494 - accuracy: 0.8368
# [0.7493772506713867, 0.8367999792098999]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
