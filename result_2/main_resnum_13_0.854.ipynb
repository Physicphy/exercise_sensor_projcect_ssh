# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//4, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 13, # 3, 5, 7, #9#, ##11##
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1450        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1810        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 60)      32460       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 150, 60)      32460       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 150, 60)      32460       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         conv1d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 150, 120)     480         conv1d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 150, 60)      240         conv1d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 150, 60)      0           leaky_re_lu_59[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 150, 60)      32460       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 150, 60)      240         conv1d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 150, 120)     480         conv1d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 150, 60)      240         conv1d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 150, 60)      0           leaky_re_lu_62[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 150, 60)      240         add_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,534,201
# Trainable params: 1,526,041
# Non-trainable params: 8,160
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 45s 374ms/step - loss: 58.0869 - accuracy: 0.2872 - val_loss: 42.8060 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 42.80599, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 37.0347 - accuracy: 0.4651 - val_loss: 27.1398 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 42.80599 to 27.13984, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 23.9296 - accuracy: 0.5630 - val_loss: 17.9189 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 27.13984 to 17.91886, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 16.5459 - accuracy: 0.5915 - val_loss: 12.8405 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 17.91886 to 12.84052, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 11.7558 - accuracy: 0.6158 - val_loss: 9.6963 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 12.84052 to 9.69632, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 8.8615 - accuracy: 0.6507 - val_loss: 7.9023 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 9.69632 to 7.90230, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 6.7760 - accuracy: 0.6778 - val_loss: 6.9220 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 7.90230 to 6.92200, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 5.4852 - accuracy: 0.7178 - val_loss: 6.3135 - val_accuracy: 0.4414
#
# Epoch 00008: val_loss improved from 6.92200 to 6.31347, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 4.5744 - accuracy: 0.7321 - val_loss: 5.6859 - val_accuracy: 0.3438
#
# Epoch 00009: val_loss improved from 6.31347 to 5.68594, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 4.3836 - accuracy: 0.7128 - val_loss: 5.4006 - val_accuracy: 0.4219
#
# Epoch 00010: val_loss improved from 5.68594 to 5.40058, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 4.0176 - accuracy: 0.7174 - val_loss: 5.9475 - val_accuracy: 0.0742
#
# Epoch 00011: val_loss did not improve from 5.40058
# Epoch 12/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 3.7647 - accuracy: 0.7289 - val_loss: 4.3936 - val_accuracy: 0.3945
#
# Epoch 00012: val_loss improved from 5.40058 to 4.39364, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 3.3716 - accuracy: 0.7551 - val_loss: 4.1963 - val_accuracy: 0.4453
#
# Epoch 00013: val_loss improved from 4.39364 to 4.19625, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 3.1208 - accuracy: 0.7610 - val_loss: 4.3779 - val_accuracy: 0.3086
#
# Epoch 00014: val_loss did not improve from 4.19625
# Epoch 15/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 3.1880 - accuracy: 0.7505 - val_loss: 4.4136 - val_accuracy: 0.3438
#
# Epoch 00015: val_loss did not improve from 4.19625
# Epoch 16/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 3.1278 - accuracy: 0.7551 - val_loss: 3.1811 - val_accuracy: 0.5430
#
# Epoch 00016: val_loss improved from 4.19625 to 3.18113, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 3.1687 - accuracy: 0.7477 - val_loss: 3.8872 - val_accuracy: 0.3750
#
# Epoch 00017: val_loss did not improve from 3.18113
# Epoch 18/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 2.7403 - accuracy: 0.7831 - val_loss: 2.4204 - val_accuracy: 0.5898
#
# Epoch 00018: val_loss improved from 3.18113 to 2.42039, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 2.6115 - accuracy: 0.7877 - val_loss: 2.0694 - val_accuracy: 0.6094
#
# Epoch 00019: val_loss improved from 2.42039 to 2.06940, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 2.9904 - accuracy: 0.7505 - val_loss: 2.1123 - val_accuracy: 0.6250
#
# Epoch 00020: val_loss did not improve from 2.06940
# Epoch 21/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 2.7223 - accuracy: 0.7767 - val_loss: 1.9913 - val_accuracy: 0.6445
#
# Epoch 00021: val_loss improved from 2.06940 to 1.99130, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 2.6470 - accuracy: 0.7762 - val_loss: 1.8079 - val_accuracy: 0.6758
#
# Epoch 00022: val_loss improved from 1.99130 to 1.80788, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 2.5251 - accuracy: 0.7992 - val_loss: 1.8549 - val_accuracy: 0.6680
#
# Epoch 00023: val_loss did not improve from 1.80788
# Epoch 24/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 2.5131 - accuracy: 0.7992 - val_loss: 1.9951 - val_accuracy: 0.6680
#
# Epoch 00024: val_loss did not improve from 1.80788
# Epoch 25/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 2.3545 - accuracy: 0.8028 - val_loss: 1.7726 - val_accuracy: 0.7031
#
# Epoch 00025: val_loss improved from 1.80788 to 1.77262, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 2.2853 - accuracy: 0.8033 - val_loss: 1.7839 - val_accuracy: 0.6953
#
# Epoch 00026: val_loss did not improve from 1.77262
# Epoch 27/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 2.4531 - accuracy: 0.7964 - val_loss: 1.9484 - val_accuracy: 0.6523
#
# Epoch 00027: val_loss did not improve from 1.77262
# Epoch 28/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 2.5697 - accuracy: 0.7886 - val_loss: 1.8115 - val_accuracy: 0.6641
#
# Epoch 00028: val_loss did not improve from 1.77262
# Epoch 29/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 2.5398 - accuracy: 0.7822 - val_loss: 1.9982 - val_accuracy: 0.6367
#
# Epoch 00029: val_loss did not improve from 1.77262
# Epoch 30/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 2.1909 - accuracy: 0.8203 - val_loss: 2.4078 - val_accuracy: 0.5547
#
# Epoch 00030: val_loss did not improve from 1.77262
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 31/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.9766 - accuracy: 0.8382 - val_loss: 1.7651 - val_accuracy: 0.6875
#
# Epoch 00031: val_loss improved from 1.77262 to 1.76510, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.8544 - accuracy: 0.8456 - val_loss: 1.5486 - val_accuracy: 0.7266
#
# Epoch 00032: val_loss improved from 1.76510 to 1.54856, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.8537 - accuracy: 0.8456 - val_loss: 1.4403 - val_accuracy: 0.7227
#
# Epoch 00033: val_loss improved from 1.54856 to 1.44032, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.7592 - accuracy: 0.8548 - val_loss: 1.4981 - val_accuracy: 0.7031
#
# Epoch 00034: val_loss did not improve from 1.44032
# Epoch 35/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.9021 - accuracy: 0.8364 - val_loss: 1.4641 - val_accuracy: 0.6992
#
# Epoch 00035: val_loss did not improve from 1.44032
# Epoch 36/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 1.8621 - accuracy: 0.8401 - val_loss: 1.3637 - val_accuracy: 0.7188
#
# Epoch 00036: val_loss improved from 1.44032 to 1.36371, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.7914 - accuracy: 0.8529 - val_loss: 1.3393 - val_accuracy: 0.7578
#
# Epoch 00037: val_loss improved from 1.36371 to 1.33934, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.6191 - accuracy: 0.8653 - val_loss: 1.2586 - val_accuracy: 0.7812
#
# Epoch 00038: val_loss improved from 1.33934 to 1.25855, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.7211 - accuracy: 0.8442 - val_loss: 1.2916 - val_accuracy: 0.7773
#
# Epoch 00039: val_loss did not improve from 1.25855
# Epoch 40/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.7014 - accuracy: 0.8626 - val_loss: 1.3303 - val_accuracy: 0.7500
#
# Epoch 00040: val_loss did not improve from 1.25855
# Epoch 41/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.6506 - accuracy: 0.8672 - val_loss: 1.3573 - val_accuracy: 0.7461
#
# Epoch 00041: val_loss did not improve from 1.25855
# Epoch 42/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.7864 - accuracy: 0.8419 - val_loss: 1.5583 - val_accuracy: 0.6953
#
# Epoch 00042: val_loss did not improve from 1.25855
# Epoch 43/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.8224 - accuracy: 0.8479 - val_loss: 1.5465 - val_accuracy: 0.7031
#
# Epoch 00043: val_loss did not improve from 1.25855
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 44/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.3199 - accuracy: 0.9049 - val_loss: 1.3802 - val_accuracy: 0.7188
#
# Epoch 00044: val_loss did not improve from 1.25855
# Epoch 45/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.6236 - accuracy: 0.8603 - val_loss: 1.2149 - val_accuracy: 0.7578
#
# Epoch 00045: val_loss improved from 1.25855 to 1.21491, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.1522 - accuracy: 0.9122 - val_loss: 1.2263 - val_accuracy: 0.7344
#
# Epoch 00046: val_loss did not improve from 1.21491
# Epoch 47/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.3957 - accuracy: 0.8824 - val_loss: 1.2048 - val_accuracy: 0.7422
#
# Epoch 00047: val_loss improved from 1.21491 to 1.20477, saving model to ./save/cnn_gru_best.hdf5
# Epoch 48/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 1.2500 - accuracy: 0.9003 - val_loss: 1.1208 - val_accuracy: 0.7812
#
# Epoch 00048: val_loss improved from 1.20477 to 1.12079, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.7098 - accuracy: 0.8497 - val_loss: 1.1272 - val_accuracy: 0.7930
#
# Epoch 00049: val_loss did not improve from 1.12079
# Epoch 50/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.5186 - accuracy: 0.8713 - val_loss: 1.2049 - val_accuracy: 0.7695
#
# Epoch 00050: val_loss did not improve from 1.12079
# Epoch 51/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 1.2422 - accuracy: 0.9017 - val_loss: 1.0783 - val_accuracy: 0.7812
#
# Epoch 00051: val_loss improved from 1.12079 to 1.07833, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.3082 - accuracy: 0.8869 - val_loss: 1.0889 - val_accuracy: 0.7773
#
# Epoch 00052: val_loss did not improve from 1.07833
# Epoch 53/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.2406 - accuracy: 0.8975 - val_loss: 1.1757 - val_accuracy: 0.7500
#
# Epoch 00053: val_loss did not improve from 1.07833
# Epoch 54/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 1.4101 - accuracy: 0.8732 - val_loss: 1.0806 - val_accuracy: 0.8008
#
# Epoch 00054: val_loss did not improve from 1.07833
# Epoch 55/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.3241 - accuracy: 0.8865 - val_loss: 1.1671 - val_accuracy: 0.7617
#
# Epoch 00055: val_loss did not improve from 1.07833
# Epoch 56/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.3857 - accuracy: 0.8773 - val_loss: 1.1450 - val_accuracy: 0.7656
#
# Epoch 00056: val_loss did not improve from 1.07833
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 57/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.1558 - accuracy: 0.9067 - val_loss: 1.1090 - val_accuracy: 0.7930
#
# Epoch 00057: val_loss did not improve from 1.07833
# Epoch 58/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.2517 - accuracy: 0.8948 - val_loss: 1.0352 - val_accuracy: 0.7891
#
# Epoch 00058: val_loss improved from 1.07833 to 1.03517, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.1352 - accuracy: 0.9081 - val_loss: 1.0112 - val_accuracy: 0.7812
#
# Epoch 00059: val_loss improved from 1.03517 to 1.01118, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.1577 - accuracy: 0.9044 - val_loss: 1.0829 - val_accuracy: 0.7500
#
# Epoch 00060: val_loss did not improve from 1.01118
# Epoch 61/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.1893 - accuracy: 0.8966 - val_loss: 1.0461 - val_accuracy: 0.7930
#
# Epoch 00061: val_loss did not improve from 1.01118
# Epoch 62/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 1.1396 - accuracy: 0.9053 - val_loss: 1.0805 - val_accuracy: 0.7695
#
# Epoch 00062: val_loss did not improve from 1.01118
# Epoch 63/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.0598 - accuracy: 0.9154 - val_loss: 1.1078 - val_accuracy: 0.7812
#
# Epoch 00063: val_loss did not improve from 1.01118
# Epoch 64/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.1536 - accuracy: 0.9030 - val_loss: 1.0618 - val_accuracy: 0.7812
#
# Epoch 00064: val_loss did not improve from 1.01118
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 65/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.9998 - accuracy: 0.9242 - val_loss: 1.0457 - val_accuracy: 0.7930
#
# Epoch 00065: val_loss did not improve from 1.01118
# Epoch 66/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 1.0313 - accuracy: 0.9154 - val_loss: 1.0593 - val_accuracy: 0.7695
#
# Epoch 00066: val_loss did not improve from 1.01118
# Epoch 67/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8989 - accuracy: 0.9338 - val_loss: 0.9995 - val_accuracy: 0.7812
#
# Epoch 00067: val_loss improved from 1.01118 to 0.99945, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.9890 - accuracy: 0.9182 - val_loss: 1.0422 - val_accuracy: 0.7930
#
# Epoch 00068: val_loss did not improve from 0.99945
# Epoch 69/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.0177 - accuracy: 0.9168 - val_loss: 1.0088 - val_accuracy: 0.7969
#
# Epoch 00069: val_loss did not improve from 0.99945
# Epoch 70/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.0718 - accuracy: 0.8971 - val_loss: 1.0271 - val_accuracy: 0.7773
#
# Epoch 00070: val_loss did not improve from 0.99945
# Epoch 71/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.0200 - accuracy: 0.9104 - val_loss: 1.0278 - val_accuracy: 0.7734
#
# Epoch 00071: val_loss did not improve from 0.99945
# Epoch 72/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.9771 - accuracy: 0.9182 - val_loss: 1.0149 - val_accuracy: 0.7930
#
# Epoch 00072: val_loss did not improve from 0.99945
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 73/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 1.0616 - accuracy: 0.9044 - val_loss: 1.0300 - val_accuracy: 0.7812
#
# Epoch 00073: val_loss did not improve from 0.99945
# Epoch 74/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.9951 - accuracy: 0.9131 - val_loss: 1.0179 - val_accuracy: 0.7930
#
# Epoch 00074: val_loss did not improve from 0.99945
# Epoch 75/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.8575 - accuracy: 0.9320 - val_loss: 0.9970 - val_accuracy: 0.7891
#
# Epoch 00075: val_loss improved from 0.99945 to 0.99699, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8976 - accuracy: 0.9292 - val_loss: 0.9803 - val_accuracy: 0.8008
#
# Epoch 00076: val_loss improved from 0.99699 to 0.98026, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.8639 - accuracy: 0.9283 - val_loss: 0.9902 - val_accuracy: 0.8086
#
# Epoch 00077: val_loss did not improve from 0.98026
# Epoch 78/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.8977 - accuracy: 0.9256 - val_loss: 0.9874 - val_accuracy: 0.7930
#
# Epoch 00078: val_loss did not improve from 0.98026
# Epoch 79/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.1350 - accuracy: 0.8929 - val_loss: 1.0261 - val_accuracy: 0.7773
#
# Epoch 00079: val_loss did not improve from 0.98026
# Epoch 80/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.9508 - accuracy: 0.9269 - val_loss: 1.0166 - val_accuracy: 0.7852
#
# Epoch 00080: val_loss did not improve from 0.98026
# Epoch 81/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.9539 - accuracy: 0.9150 - val_loss: 0.9805 - val_accuracy: 0.7969
#
# Epoch 00081: val_loss did not improve from 0.98026
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 82/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.8972 - accuracy: 0.9269 - val_loss: 0.9530 - val_accuracy: 0.8125
#
# Epoch 00082: val_loss improved from 0.98026 to 0.95303, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.7743 - accuracy: 0.9426 - val_loss: 0.9815 - val_accuracy: 0.8125
#
# Epoch 00083: val_loss did not improve from 0.95303
# Epoch 84/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7973 - accuracy: 0.9416 - val_loss: 0.9916 - val_accuracy: 0.8125
#
# Epoch 00084: val_loss did not improve from 0.95303
# Epoch 85/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.7895 - accuracy: 0.9421 - val_loss: 0.9758 - val_accuracy: 0.8164
#
# Epoch 00085: val_loss did not improve from 0.95303
# Epoch 86/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7213 - accuracy: 0.9550 - val_loss: 0.9668 - val_accuracy: 0.8125
#
# Epoch 00086: val_loss did not improve from 0.95303
# Epoch 87/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 1.0043 - accuracy: 0.9104 - val_loss: 0.9755 - val_accuracy: 0.8008
#
# Epoch 00087: val_loss did not improve from 0.95303
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 88/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.9383 - accuracy: 0.9210 - val_loss: 0.9949 - val_accuracy: 0.7891
#
# Epoch 00088: val_loss did not improve from 0.95303
# Epoch 89/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8470 - accuracy: 0.9347 - val_loss: 0.9638 - val_accuracy: 0.8047
#
# Epoch 00089: val_loss did not improve from 0.95303
# Epoch 90/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.8193 - accuracy: 0.9366 - val_loss: 0.9693 - val_accuracy: 0.8047
#
# Epoch 00090: val_loss did not improve from 0.95303
# Epoch 91/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8829 - accuracy: 0.9214 - val_loss: 0.9449 - val_accuracy: 0.8203
#
# Epoch 00091: val_loss improved from 0.95303 to 0.94490, saving model to ./save/cnn_gru_best.hdf5
# Epoch 92/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8238 - accuracy: 0.9361 - val_loss: 0.9597 - val_accuracy: 0.8125
#
# Epoch 00092: val_loss did not improve from 0.94490
# Epoch 93/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.9212 - accuracy: 0.9320 - val_loss: 0.9612 - val_accuracy: 0.8086
#
# Epoch 00093: val_loss did not improve from 0.94490
# Epoch 94/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.7307 - accuracy: 0.9494 - val_loss: 0.9743 - val_accuracy: 0.8086
#
# Epoch 00094: val_loss did not improve from 0.94490
# Epoch 95/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.7911 - accuracy: 0.9407 - val_loss: 0.9631 - val_accuracy: 0.8086
#
# Epoch 00095: val_loss did not improve from 0.94490
# Epoch 96/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.9131 - accuracy: 0.9251 - val_loss: 0.9170 - val_accuracy: 0.8047
#
# Epoch 00096: val_loss improved from 0.94490 to 0.91697, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 1.0172 - accuracy: 0.9067 - val_loss: 0.9843 - val_accuracy: 0.8125
#
# Epoch 00097: val_loss did not improve from 0.91697
# Epoch 98/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.8278 - accuracy: 0.9366 - val_loss: 0.9477 - val_accuracy: 0.8125
#
# Epoch 00098: val_loss did not improve from 0.91697
# Epoch 99/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.9259 - accuracy: 0.9210 - val_loss: 0.9442 - val_accuracy: 0.8281
#
# Epoch 00099: val_loss did not improve from 0.91697
# Epoch 100/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.7542 - accuracy: 0.9481 - val_loss: 0.9025 - val_accuracy: 0.8281
#
# Epoch 00100: val_loss improved from 0.91697 to 0.90253, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.8115 - accuracy: 0.9361 - val_loss: 0.9771 - val_accuracy: 0.8086
#
# Epoch 00101: val_loss did not improve from 0.90253
# Epoch 102/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8740 - accuracy: 0.9228 - val_loss: 0.9503 - val_accuracy: 0.8125
#
# Epoch 00102: val_loss did not improve from 0.90253
# Epoch 103/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.9555 - accuracy: 0.9131 - val_loss: 0.9481 - val_accuracy: 0.8086
#
# Epoch 00103: val_loss did not improve from 0.90253
# Epoch 104/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7477 - accuracy: 0.9412 - val_loss: 0.9267 - val_accuracy: 0.8203
#
# Epoch 00104: val_loss did not improve from 0.90253
# Epoch 105/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.8492 - accuracy: 0.9324 - val_loss: 0.9207 - val_accuracy: 0.8242
#
# Epoch 00105: val_loss did not improve from 0.90253
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 106/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.8539 - accuracy: 0.9329 - val_loss: 0.8545 - val_accuracy: 0.8242
#
# Epoch 00106: val_loss improved from 0.90253 to 0.85446, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7668 - accuracy: 0.9481 - val_loss: 0.8960 - val_accuracy: 0.8164
#
# Epoch 00107: val_loss did not improve from 0.85446
# Epoch 108/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7884 - accuracy: 0.9370 - val_loss: 0.8576 - val_accuracy: 0.8320
#
# Epoch 00108: val_loss did not improve from 0.85446
# Epoch 109/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.8574 - accuracy: 0.9233 - val_loss: 0.8785 - val_accuracy: 0.8320
#
# Epoch 00109: val_loss did not improve from 0.85446
# Epoch 110/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.7601 - accuracy: 0.9366 - val_loss: 0.9084 - val_accuracy: 0.8281
#
# Epoch 00110: val_loss did not improve from 0.85446
# Epoch 111/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.9963 - accuracy: 0.9049 - val_loss: 0.9528 - val_accuracy: 0.8125
#
# Epoch 00111: val_loss did not improve from 0.85446
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 112/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8092 - accuracy: 0.9421 - val_loss: 0.9696 - val_accuracy: 0.8047
#
# Epoch 00112: val_loss did not improve from 0.85446
# Epoch 113/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.8059 - accuracy: 0.9380 - val_loss: 0.9248 - val_accuracy: 0.8242
#
# Epoch 00113: val_loss did not improve from 0.85446
# Epoch 114/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.8535 - accuracy: 0.9260 - val_loss: 0.9590 - val_accuracy: 0.8086
#
# Epoch 00114: val_loss did not improve from 0.85446
# Epoch 115/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.7589 - accuracy: 0.9444 - val_loss: 0.9271 - val_accuracy: 0.8125
#
# Epoch 00115: val_loss did not improve from 0.85446
# Epoch 116/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7745 - accuracy: 0.9357 - val_loss: 0.9301 - val_accuracy: 0.8125
#
# Epoch 00116: val_loss did not improve from 0.85446
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 117/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.8727 - accuracy: 0.9256 - val_loss: 0.9246 - val_accuracy: 0.8125
#
# Epoch 00117: val_loss did not improve from 0.85446
# Epoch 118/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.7598 - accuracy: 0.9421 - val_loss: 0.9362 - val_accuracy: 0.8164
#
# Epoch 00118: val_loss did not improve from 0.85446
# Epoch 119/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.8429 - accuracy: 0.9329 - val_loss: 0.9738 - val_accuracy: 0.8008
#
# Epoch 00119: val_loss did not improve from 0.85446
# Epoch 120/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.9407 - accuracy: 0.9182 - val_loss: 0.9870 - val_accuracy: 0.8047
#
# Epoch 00120: val_loss did not improve from 0.85446
# Epoch 121/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.8686 - accuracy: 0.9288 - val_loss: 0.9515 - val_accuracy: 0.8047
#
# Epoch 00121: val_loss did not improve from 0.85446
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 122/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7359 - accuracy: 0.9439 - val_loss: 0.9159 - val_accuracy: 0.8281
#
# Epoch 00122: val_loss did not improve from 0.85446
# Epoch 123/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.8615 - accuracy: 0.9251 - val_loss: 0.9491 - val_accuracy: 0.8164
#
# Epoch 00123: val_loss did not improve from 0.85446
# Epoch 124/2000
# 34/34 [==============================] - 8s 236ms/step - loss: 0.8534 - accuracy: 0.9320 - val_loss: 0.9483 - val_accuracy: 0.8242
#
# Epoch 00124: val_loss did not improve from 0.85446
# Epoch 125/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8434 - accuracy: 0.9242 - val_loss: 0.9848 - val_accuracy: 0.8125
#
# Epoch 00125: val_loss did not improve from 0.85446
# Epoch 126/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.8043 - accuracy: 0.9283 - val_loss: 0.9700 - val_accuracy: 0.8164
#
# Epoch 00126: val_loss did not improve from 0.85446
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 127/2000
# 34/34 [==============================] - 8s 238ms/step - loss: 0.9609 - accuracy: 0.9141 - val_loss: 0.9779 - val_accuracy: 0.8086
#
# Epoch 00127: val_loss did not improve from 0.85446
# Epoch 128/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7134 - accuracy: 0.9430 - val_loss: 0.9249 - val_accuracy: 0.8242
#
# Epoch 00128: val_loss did not improve from 0.85446
# Epoch 129/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8341 - accuracy: 0.9357 - val_loss: 0.9770 - val_accuracy: 0.8086
#
# Epoch 00129: val_loss did not improve from 0.85446
# Epoch 130/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.7462 - accuracy: 0.9421 - val_loss: 0.9773 - val_accuracy: 0.8047
#
# Epoch 00130: val_loss did not improve from 0.85446
# Epoch 131/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8759 - accuracy: 0.9265 - val_loss: 0.9588 - val_accuracy: 0.8164
#
# Epoch 00131: val_loss did not improve from 0.85446
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 132/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8376 - accuracy: 0.9265 - val_loss: 0.9436 - val_accuracy: 0.8281
#
# Epoch 00132: val_loss did not improve from 0.85446
# Epoch 133/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.8354 - accuracy: 0.9334 - val_loss: 0.9649 - val_accuracy: 0.8125
#
# Epoch 00133: val_loss did not improve from 0.85446
# Epoch 134/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.8491 - accuracy: 0.9283 - val_loss: 0.9646 - val_accuracy: 0.8164
#
# Epoch 00134: val_loss did not improve from 0.85446
# Epoch 135/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8397 - accuracy: 0.9315 - val_loss: 0.9637 - val_accuracy: 0.8164
#
# Epoch 00135: val_loss did not improve from 0.85446
# Epoch 136/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 0.8308 - accuracy: 0.9297 - val_loss: 0.9427 - val_accuracy: 0.8242
#
# Epoch 00136: val_loss did not improve from 0.85446
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7717 - accuracy: 0.8544
# [0.7716837525367737, 0.8543999791145325]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
