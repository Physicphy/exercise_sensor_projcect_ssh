# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

# def scheduler(epoch, lr):
#     if (epoch>20) and (lr > 0.00001):
#         lr = lr*0.9
#         return lr
#     else:
#         return lr

# lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 3)       0           input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 7)       0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      730         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 10)      550         concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1270        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 10)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 10)      40          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 20)      1920        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 20)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 20)      80          leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      3660        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 60)      21960       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 150, 420)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      226860      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 120)     480         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      226860      concatenate_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_30[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 120)     480         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_33[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_36[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_39[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 120)     480         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_42[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 120)     480         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_45[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 120)     480         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_48[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 120)     480         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_51[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 120)     480         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_54[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,319,231
# Trainable params: 1,312,691
# Non-trainable params: 6,540
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 45s 381ms/step - loss: 43.0270 - accuracy: 0.3529 - val_loss: 31.6588 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 31.65881, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 27.6636 - accuracy: 0.5676 - val_loss: 20.6064 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 31.65881 to 20.60638, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 18.0402 - accuracy: 0.6507 - val_loss: 14.0435 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 20.60638 to 14.04353, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 12.5858 - accuracy: 0.6746 - val_loss: 10.5921 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 14.04353 to 10.59210, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 9.1986 - accuracy: 0.6870 - val_loss: 8.5755 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 10.59210 to 8.57550, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 6.8820 - accuracy: 0.7233 - val_loss: 6.8394 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 8.57550 to 6.83939, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 5.5059 - accuracy: 0.7261 - val_loss: 6.2361 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 6.83939 to 6.23613, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 4.5500 - accuracy: 0.7523 - val_loss: 5.7046 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 6.23613 to 5.70457, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 3.8279 - accuracy: 0.7730 - val_loss: 5.7117 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss did not improve from 5.70457
# Epoch 10/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 3.5786 - accuracy: 0.7638 - val_loss: 5.5000 - val_accuracy: 0.1055
#
# Epoch 00010: val_loss improved from 5.70457 to 5.50003, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 3.2213 - accuracy: 0.7698 - val_loss: 6.7448 - val_accuracy: 0.0156
#
# Epoch 00011: val_loss did not improve from 5.50003
# Epoch 12/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 3.0092 - accuracy: 0.7780 - val_loss: 5.6611 - val_accuracy: 0.0195
#
# Epoch 00012: val_loss did not improve from 5.50003
# Epoch 13/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 2.7573 - accuracy: 0.7891 - val_loss: 6.0609 - val_accuracy: 0.0312
#
# Epoch 00013: val_loss did not improve from 5.50003
# Epoch 14/2000
# 34/34 [==============================] - 8s 245ms/step - loss: 2.5238 - accuracy: 0.8125 - val_loss: 5.5250 - val_accuracy: 0.0430
#
# Epoch 00014: val_loss did not improve from 5.50003
# Epoch 15/2000
# 34/34 [==============================] - 8s 245ms/step - loss: 2.4994 - accuracy: 0.8093 - val_loss: 8.0869 - val_accuracy: 0.0547
#
# Epoch 00015: val_loss did not improve from 5.50003
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/2000
# 34/34 [==============================] - 8s 246ms/step - loss: 2.2123 - accuracy: 0.8263 - val_loss: 3.5440 - val_accuracy: 0.4023
#
# Epoch 00016: val_loss improved from 5.50003 to 3.54396, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 2.0350 - accuracy: 0.8438 - val_loss: 2.8218 - val_accuracy: 0.4844
#
# Epoch 00017: val_loss improved from 3.54396 to 2.82179, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.8361 - accuracy: 0.8557 - val_loss: 2.3820 - val_accuracy: 0.5820
#
# Epoch 00018: val_loss improved from 2.82179 to 2.38199, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 1.7372 - accuracy: 0.8644 - val_loss: 2.1762 - val_accuracy: 0.5938
#
# Epoch 00019: val_loss improved from 2.38199 to 2.17620, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.9917 - accuracy: 0.8199 - val_loss: 1.8580 - val_accuracy: 0.6836
#
# Epoch 00020: val_loss improved from 2.17620 to 1.85803, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.8074 - accuracy: 0.8415 - val_loss: 1.7234 - val_accuracy: 0.6641
#
# Epoch 00021: val_loss improved from 1.85803 to 1.72340, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.6812 - accuracy: 0.8681 - val_loss: 2.2900 - val_accuracy: 0.5820
#
# Epoch 00022: val_loss did not improve from 1.72340
# Epoch 23/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.7098 - accuracy: 0.8497 - val_loss: 1.8513 - val_accuracy: 0.6367
#
# Epoch 00023: val_loss did not improve from 1.72340
# Epoch 24/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 1.6545 - accuracy: 0.8543 - val_loss: 1.8957 - val_accuracy: 0.6172
#
# Epoch 00024: val_loss did not improve from 1.72340
# Epoch 25/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.6107 - accuracy: 0.8764 - val_loss: 1.6663 - val_accuracy: 0.6836
#
# Epoch 00025: val_loss improved from 1.72340 to 1.66630, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 1.5914 - accuracy: 0.8672 - val_loss: 1.3779 - val_accuracy: 0.7812
#
# Epoch 00026: val_loss improved from 1.66630 to 1.37788, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.5792 - accuracy: 0.8644 - val_loss: 1.3374 - val_accuracy: 0.7852
#
# Epoch 00027: val_loss improved from 1.37788 to 1.33740, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 1.6063 - accuracy: 0.8603 - val_loss: 1.2578 - val_accuracy: 0.7656
#
# Epoch 00028: val_loss improved from 1.33740 to 1.25780, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.5855 - accuracy: 0.8653 - val_loss: 1.4435 - val_accuracy: 0.7109
#
# Epoch 00029: val_loss did not improve from 1.25780
# Epoch 30/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.4565 - accuracy: 0.8874 - val_loss: 1.4328 - val_accuracy: 0.7305
#
# Epoch 00030: val_loss did not improve from 1.25780
# Epoch 31/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 1.3987 - accuracy: 0.8814 - val_loss: 1.2849 - val_accuracy: 0.7695
#
# Epoch 00031: val_loss did not improve from 1.25780
# Epoch 32/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.4097 - accuracy: 0.8805 - val_loss: 1.5644 - val_accuracy: 0.7031
#
# Epoch 00032: val_loss did not improve from 1.25780
# Epoch 33/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.4646 - accuracy: 0.8695 - val_loss: 2.5442 - val_accuracy: 0.5117
#
# Epoch 00033: val_loss did not improve from 1.25780
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 34/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.3569 - accuracy: 0.8874 - val_loss: 1.3266 - val_accuracy: 0.7695
#
# Epoch 00034: val_loss did not improve from 1.25780
# Epoch 35/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.2818 - accuracy: 0.8934 - val_loss: 1.2134 - val_accuracy: 0.7695
#
# Epoch 00035: val_loss improved from 1.25780 to 1.21337, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.2039 - accuracy: 0.8984 - val_loss: 1.1861 - val_accuracy: 0.7734
#
# Epoch 00036: val_loss improved from 1.21337 to 1.18612, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 1.1529 - accuracy: 0.9095 - val_loss: 1.1829 - val_accuracy: 0.7617
#
# Epoch 00037: val_loss improved from 1.18612 to 1.18295, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.0756 - accuracy: 0.9076 - val_loss: 1.2350 - val_accuracy: 0.7578
#
# Epoch 00038: val_loss did not improve from 1.18295
# Epoch 39/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 1.0847 - accuracy: 0.9141 - val_loss: 1.2494 - val_accuracy: 0.7461
#
# Epoch 00039: val_loss did not improve from 1.18295
# Epoch 40/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.0712 - accuracy: 0.9145 - val_loss: 1.1123 - val_accuracy: 0.7930
#
# Epoch 00040: val_loss improved from 1.18295 to 1.11235, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 1.0785 - accuracy: 0.9154 - val_loss: 1.7632 - val_accuracy: 0.6719
#
# Epoch 00041: val_loss did not improve from 1.11235
# Epoch 42/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.0912 - accuracy: 0.9099 - val_loss: 1.3536 - val_accuracy: 0.7422
#
# Epoch 00042: val_loss did not improve from 1.11235
# Epoch 43/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 1.0712 - accuracy: 0.9108 - val_loss: 1.5953 - val_accuracy: 0.7070
#
# Epoch 00043: val_loss did not improve from 1.11235
# Epoch 44/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.9222 - accuracy: 0.9269 - val_loss: 1.1727 - val_accuracy: 0.7812
#
# Epoch 00044: val_loss did not improve from 1.11235
# Epoch 45/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 1.0330 - accuracy: 0.9099 - val_loss: 1.1794 - val_accuracy: 0.7656
#
# Epoch 00045: val_loss did not improve from 1.11235
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 46/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.8193 - accuracy: 0.9412 - val_loss: 1.1956 - val_accuracy: 0.7695
#
# Epoch 00046: val_loss did not improve from 1.11235
# Epoch 47/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.8630 - accuracy: 0.9343 - val_loss: 1.0902 - val_accuracy: 0.7812
#
# Epoch 00047: val_loss improved from 1.11235 to 1.09020, saving model to ./save/cnn_gru_best.hdf5
# Epoch 48/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.8031 - accuracy: 0.9398 - val_loss: 1.3519 - val_accuracy: 0.7266
#
# Epoch 00048: val_loss did not improve from 1.09020
# Epoch 49/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.9332 - accuracy: 0.9228 - val_loss: 1.2724 - val_accuracy: 0.7500
#
# Epoch 00049: val_loss did not improve from 1.09020
# Epoch 50/2000
# 34/34 [==============================] - 8s 245ms/step - loss: 0.8533 - accuracy: 0.9320 - val_loss: 1.1059 - val_accuracy: 0.7773
#
# Epoch 00050: val_loss did not improve from 1.09020
# Epoch 51/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.7799 - accuracy: 0.9407 - val_loss: 1.0170 - val_accuracy: 0.8086
#
# Epoch 00051: val_loss improved from 1.09020 to 1.01705, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.7601 - accuracy: 0.9439 - val_loss: 1.0620 - val_accuracy: 0.8164
#
# Epoch 00052: val_loss did not improve from 1.01705
# Epoch 53/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.7899 - accuracy: 0.9426 - val_loss: 1.0416 - val_accuracy: 0.7930
#
# Epoch 00053: val_loss did not improve from 1.01705
# Epoch 54/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.8624 - accuracy: 0.9292 - val_loss: 1.1022 - val_accuracy: 0.7969
#
# Epoch 00054: val_loss did not improve from 1.01705
# Epoch 55/2000
# 34/34 [==============================] - 8s 244ms/step - loss: 0.7819 - accuracy: 0.9380 - val_loss: 1.0659 - val_accuracy: 0.7930
#
# Epoch 00055: val_loss did not improve from 1.01705
# Epoch 56/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.7724 - accuracy: 0.9398 - val_loss: 1.0738 - val_accuracy: 0.7891
#
# Epoch 00056: val_loss did not improve from 1.01705
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.6822 - accuracy: 0.9531 - val_loss: 1.1639 - val_accuracy: 0.7812
#
# Epoch 00057: val_loss did not improve from 1.01705
# Epoch 58/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.7130 - accuracy: 0.9499 - val_loss: 1.1426 - val_accuracy: 0.7656
#
# Epoch 00058: val_loss did not improve from 1.01705
# Epoch 59/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.6232 - accuracy: 0.9609 - val_loss: 0.9746 - val_accuracy: 0.8008
#
# Epoch 00059: val_loss improved from 1.01705 to 0.97460, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.6900 - accuracy: 0.9504 - val_loss: 0.9899 - val_accuracy: 0.8125
#
# Epoch 00060: val_loss did not improve from 0.97460
# Epoch 61/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.6820 - accuracy: 0.9499 - val_loss: 1.0608 - val_accuracy: 0.7852
#
# Epoch 00061: val_loss did not improve from 0.97460
# Epoch 62/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.6604 - accuracy: 0.9490 - val_loss: 1.0439 - val_accuracy: 0.8047
#
# Epoch 00062: val_loss did not improve from 0.97460
# Epoch 63/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.6454 - accuracy: 0.9531 - val_loss: 1.0691 - val_accuracy: 0.8008
#
# Epoch 00063: val_loss did not improve from 0.97460
# Epoch 64/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.6528 - accuracy: 0.9531 - val_loss: 1.0432 - val_accuracy: 0.7969
#
# Epoch 00064: val_loss did not improve from 0.97460
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 65/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5994 - accuracy: 0.9591 - val_loss: 1.0111 - val_accuracy: 0.8047
#
# Epoch 00065: val_loss did not improve from 0.97460
# Epoch 66/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5688 - accuracy: 0.9600 - val_loss: 1.0394 - val_accuracy: 0.8086
#
# Epoch 00066: val_loss did not improve from 0.97460
# Epoch 67/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5499 - accuracy: 0.9614 - val_loss: 0.9672 - val_accuracy: 0.8320
#
# Epoch 00067: val_loss improved from 0.97460 to 0.96723, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5691 - accuracy: 0.9619 - val_loss: 1.0083 - val_accuracy: 0.8125
#
# Epoch 00068: val_loss did not improve from 0.96723
# Epoch 69/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.5632 - accuracy: 0.9559 - val_loss: 0.9915 - val_accuracy: 0.8047
#
# Epoch 00069: val_loss did not improve from 0.96723
# Epoch 70/2000
# 34/34 [==============================] - 9s 257ms/step - loss: 0.5709 - accuracy: 0.9605 - val_loss: 1.0239 - val_accuracy: 0.8008
#
# Epoch 00070: val_loss did not improve from 0.96723
# Epoch 71/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5568 - accuracy: 0.9619 - val_loss: 1.0745 - val_accuracy: 0.7930
#
# Epoch 00071: val_loss did not improve from 0.96723
# Epoch 72/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5586 - accuracy: 0.9596 - val_loss: 1.0355 - val_accuracy: 0.8047
#
# Epoch 00072: val_loss did not improve from 0.96723
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 73/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5624 - accuracy: 0.9605 - val_loss: 1.0507 - val_accuracy: 0.7930
#
# Epoch 00073: val_loss did not improve from 0.96723
# Epoch 74/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5621 - accuracy: 0.9591 - val_loss: 1.0471 - val_accuracy: 0.8008
#
# Epoch 00074: val_loss did not improve from 0.96723
# Epoch 75/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4900 - accuracy: 0.9743 - val_loss: 0.9843 - val_accuracy: 0.8047
#
# Epoch 00075: val_loss did not improve from 0.96723
# Epoch 76/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5175 - accuracy: 0.9683 - val_loss: 0.9923 - val_accuracy: 0.8008
#
# Epoch 00076: val_loss did not improve from 0.96723
# Epoch 77/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5098 - accuracy: 0.9697 - val_loss: 1.0106 - val_accuracy: 0.8086
#
# Epoch 00077: val_loss did not improve from 0.96723
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 78/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.4969 - accuracy: 0.9706 - val_loss: 1.0188 - val_accuracy: 0.8086
#
# Epoch 00078: val_loss did not improve from 0.96723
# Epoch 79/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.5653 - accuracy: 0.9651 - val_loss: 1.0375 - val_accuracy: 0.8008
#
# Epoch 00079: val_loss did not improve from 0.96723
# Epoch 80/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5452 - accuracy: 0.9591 - val_loss: 1.0454 - val_accuracy: 0.7969
#
# Epoch 00080: val_loss did not improve from 0.96723
# Epoch 81/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.5247 - accuracy: 0.9660 - val_loss: 1.0057 - val_accuracy: 0.8164
#
# Epoch 00081: val_loss did not improve from 0.96723
# Epoch 82/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5087 - accuracy: 0.9701 - val_loss: 0.9871 - val_accuracy: 0.8125
#
# Epoch 00082: val_loss did not improve from 0.96723
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 83/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.4523 - accuracy: 0.9761 - val_loss: 0.9980 - val_accuracy: 0.8125
#
# Epoch 00083: val_loss did not improve from 0.96723
# Epoch 84/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4543 - accuracy: 0.9802 - val_loss: 1.0393 - val_accuracy: 0.8086
#
# Epoch 00084: val_loss did not improve from 0.96723
# Epoch 85/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4371 - accuracy: 0.9816 - val_loss: 0.9967 - val_accuracy: 0.8242
#
# Epoch 00085: val_loss did not improve from 0.96723
# Epoch 86/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4471 - accuracy: 0.9743 - val_loss: 1.0398 - val_accuracy: 0.8164
#
# Epoch 00086: val_loss did not improve from 0.96723
# Epoch 87/2000
# 34/34 [==============================] - 8s 244ms/step - loss: 0.5250 - accuracy: 0.9669 - val_loss: 1.0403 - val_accuracy: 0.8086
#
# Epoch 00087: val_loss did not improve from 0.96723
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 88/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5163 - accuracy: 0.9655 - val_loss: 1.0454 - val_accuracy: 0.7969
#
# Epoch 00088: val_loss did not improve from 0.96723
# Epoch 89/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.4867 - accuracy: 0.9729 - val_loss: 1.0145 - val_accuracy: 0.8008
#
# Epoch 00089: val_loss did not improve from 0.96723
# Epoch 90/2000
# 34/34 [==============================] - 8s 239ms/step - loss: 0.4733 - accuracy: 0.9779 - val_loss: 1.0063 - val_accuracy: 0.8125
#
# Epoch 00090: val_loss did not improve from 0.96723
# Epoch 91/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5015 - accuracy: 0.9738 - val_loss: 1.0170 - val_accuracy: 0.8008
#
# Epoch 00091: val_loss did not improve from 0.96723
# Epoch 92/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.4956 - accuracy: 0.9692 - val_loss: 1.0201 - val_accuracy: 0.8047
#
# Epoch 00092: val_loss did not improve from 0.96723
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 93/2000
# 34/34 [==============================] - 8s 244ms/step - loss: 0.5071 - accuracy: 0.9692 - val_loss: 1.0213 - val_accuracy: 0.8047
#
# Epoch 00093: val_loss did not improve from 0.96723
# Epoch 94/2000
# 34/34 [==============================] - 8s 243ms/step - loss: 0.4536 - accuracy: 0.9766 - val_loss: 1.0495 - val_accuracy: 0.7969
#
# Epoch 00094: val_loss did not improve from 0.96723
# Epoch 95/2000
# 34/34 [==============================] - 8s 240ms/step - loss: 0.4507 - accuracy: 0.9775 - val_loss: 1.0352 - val_accuracy: 0.7969
#
# Epoch 00095: val_loss did not improve from 0.96723
# Epoch 96/2000
# 34/34 [==============================] - 8s 242ms/step - loss: 0.4820 - accuracy: 0.9720 - val_loss: 0.9886 - val_accuracy: 0.8008
#
# Epoch 00096: val_loss did not improve from 0.96723
# Epoch 97/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.5525 - accuracy: 0.9628 - val_loss: 1.0588 - val_accuracy: 0.7930
#
# Epoch 00097: val_loss did not improve from 0.96723
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 00097: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7966 - accuracy: 0.8336
# [0.7965977787971497, 0.8335999846458435]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
