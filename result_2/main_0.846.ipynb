# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

# def scheduler(epoch, lr):
#     if (epoch>20) and (lr > 0.00001):
#         lr = lr*0.9
#         return lr
#     else:
#         return lr

# lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 3)       0           input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      730         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      550         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1450        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1090        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,226,101
# Trainable params: 1,219,861
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 39s 326ms/step - loss: 43.2923 - accuracy: 0.3663 - val_loss: 31.8347 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 31.83469, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 28.1329 - accuracy: 0.5460 - val_loss: 21.3605 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 31.83469 to 21.36051, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 18.5399 - accuracy: 0.6356 - val_loss: 14.6683 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 21.36051 to 14.66832, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 12.9582 - accuracy: 0.6613 - val_loss: 10.5123 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 14.66832 to 10.51230, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 9.4551 - accuracy: 0.6857 - val_loss: 8.2140 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 10.51230 to 8.21398, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 7.0908 - accuracy: 0.7224 - val_loss: 6.6772 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 8.21398 to 6.67720, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 5.5680 - accuracy: 0.7445 - val_loss: 5.8679 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 6.67720 to 5.86792, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 4.6465 - accuracy: 0.7472 - val_loss: 6.1046 - val_accuracy: 0.0156
#
# Epoch 00008: val_loss did not improve from 5.86792
# Epoch 9/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 3.8570 - accuracy: 0.7665 - val_loss: 5.0826 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss improved from 5.86792 to 5.08263, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 3.5923 - accuracy: 0.7592 - val_loss: 5.0504 - val_accuracy: 0.0391
#
# Epoch 00010: val_loss improved from 5.08263 to 5.05039, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 3.2889 - accuracy: 0.7711 - val_loss: 5.4592 - val_accuracy: 0.0273
#
# Epoch 00011: val_loss did not improve from 5.05039
# Epoch 12/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 3.1028 - accuracy: 0.7656 - val_loss: 6.6091 - val_accuracy: 0.0156
#
# Epoch 00012: val_loss did not improve from 5.05039
# Epoch 13/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 2.7590 - accuracy: 0.7969 - val_loss: 6.0813 - val_accuracy: 0.0234
#
# Epoch 00013: val_loss did not improve from 5.05039
# Epoch 14/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 2.5849 - accuracy: 0.8001 - val_loss: 5.4481 - val_accuracy: 0.0352
#
# Epoch 00014: val_loss did not improve from 5.05039
# Epoch 15/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 2.5221 - accuracy: 0.8042 - val_loss: 4.6028 - val_accuracy: 0.1641
#
# Epoch 00015: val_loss improved from 5.05039 to 4.60282, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 2.4277 - accuracy: 0.8061 - val_loss: 5.2488 - val_accuracy: 0.1445
#
# Epoch 00016: val_loss did not improve from 4.60282
# Epoch 17/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 2.3986 - accuracy: 0.8079 - val_loss: 3.0902 - val_accuracy: 0.5586
#
# Epoch 00017: val_loss improved from 4.60282 to 3.09017, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 2.1745 - accuracy: 0.8286 - val_loss: 2.3357 - val_accuracy: 0.6133
#
# Epoch 00018: val_loss improved from 3.09017 to 2.33573, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 2.0201 - accuracy: 0.8327 - val_loss: 2.3735 - val_accuracy: 0.5469
#
# Epoch 00019: val_loss did not improve from 2.33573
# Epoch 20/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 2.1939 - accuracy: 0.8153 - val_loss: 2.9297 - val_accuracy: 0.5547
#
# Epoch 00020: val_loss did not improve from 2.33573
# Epoch 21/2000
# 34/34 [==============================] - 7s 206ms/step - loss: 2.0535 - accuracy: 0.8254 - val_loss: 1.9361 - val_accuracy: 0.6406
#
# Epoch 00021: val_loss improved from 2.33573 to 1.93613, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.9453 - accuracy: 0.8378 - val_loss: 1.9057 - val_accuracy: 0.6484
#
# Epoch 00022: val_loss improved from 1.93613 to 1.90570, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.9035 - accuracy: 0.8479 - val_loss: 2.3435 - val_accuracy: 0.5391
#
# Epoch 00023: val_loss did not improve from 1.90570
# Epoch 24/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.8316 - accuracy: 0.8511 - val_loss: 1.9224 - val_accuracy: 0.6016
#
# Epoch 00024: val_loss did not improve from 1.90570
# Epoch 25/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.7767 - accuracy: 0.8516 - val_loss: 1.5001 - val_accuracy: 0.7148
#
# Epoch 00025: val_loss improved from 1.90570 to 1.50008, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.6960 - accuracy: 0.8566 - val_loss: 1.8177 - val_accuracy: 0.6680
#
# Epoch 00026: val_loss did not improve from 1.50008
# Epoch 27/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.7094 - accuracy: 0.8474 - val_loss: 2.6268 - val_accuracy: 0.5312
#
# Epoch 00027: val_loss did not improve from 1.50008
# Epoch 28/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.7862 - accuracy: 0.8534 - val_loss: 1.8672 - val_accuracy: 0.6680
#
# Epoch 00028: val_loss did not improve from 1.50008
# Epoch 29/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 1.6843 - accuracy: 0.8502 - val_loss: 1.6444 - val_accuracy: 0.6953
#
# Epoch 00029: val_loss did not improve from 1.50008
# Epoch 30/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 1.5564 - accuracy: 0.8686 - val_loss: 1.9905 - val_accuracy: 0.6328
#
# Epoch 00030: val_loss did not improve from 1.50008
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 31/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.3574 - accuracy: 0.8906 - val_loss: 1.4144 - val_accuracy: 0.7227
#
# Epoch 00031: val_loss improved from 1.50008 to 1.41436, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.2497 - accuracy: 0.8980 - val_loss: 1.2680 - val_accuracy: 0.7070
#
# Epoch 00032: val_loss improved from 1.41436 to 1.26796, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.1926 - accuracy: 0.9021 - val_loss: 1.2897 - val_accuracy: 0.7539
#
# Epoch 00033: val_loss did not improve from 1.26796
# Epoch 34/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 1.1891 - accuracy: 0.9012 - val_loss: 1.4101 - val_accuracy: 0.7109
#
# Epoch 00034: val_loss did not improve from 1.26796
# Epoch 35/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.1734 - accuracy: 0.8984 - val_loss: 1.4256 - val_accuracy: 0.7148
#
# Epoch 00035: val_loss did not improve from 1.26796
# Epoch 36/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.1359 - accuracy: 0.9044 - val_loss: 1.2975 - val_accuracy: 0.7500
#
# Epoch 00036: val_loss did not improve from 1.26796
# Epoch 37/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.0885 - accuracy: 0.9154 - val_loss: 1.5642 - val_accuracy: 0.7070
#
# Epoch 00037: val_loss did not improve from 1.26796
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 38/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.0110 - accuracy: 0.9150 - val_loss: 1.2465 - val_accuracy: 0.7422
#
# Epoch 00038: val_loss improved from 1.26796 to 1.24652, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.9524 - accuracy: 0.9219 - val_loss: 1.1834 - val_accuracy: 0.7422
#
# Epoch 00039: val_loss improved from 1.24652 to 1.18341, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.9512 - accuracy: 0.9233 - val_loss: 1.1387 - val_accuracy: 0.7617
#
# Epoch 00040: val_loss improved from 1.18341 to 1.13869, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.8912 - accuracy: 0.9288 - val_loss: 1.2178 - val_accuracy: 0.7422
#
# Epoch 00041: val_loss did not improve from 1.13869
# Epoch 42/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.9406 - accuracy: 0.9136 - val_loss: 1.0461 - val_accuracy: 0.7773
#
# Epoch 00042: val_loss improved from 1.13869 to 1.04614, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.9459 - accuracy: 0.9150 - val_loss: 1.1300 - val_accuracy: 0.7812
#
# Epoch 00043: val_loss did not improve from 1.04614
# Epoch 44/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7743 - accuracy: 0.9426 - val_loss: 1.0767 - val_accuracy: 0.7930
#
# Epoch 00044: val_loss did not improve from 1.04614
# Epoch 45/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.9203 - accuracy: 0.9237 - val_loss: 1.0946 - val_accuracy: 0.7617
#
# Epoch 00045: val_loss did not improve from 1.04614
# Epoch 46/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.7449 - accuracy: 0.9407 - val_loss: 1.0880 - val_accuracy: 0.7656
#
# Epoch 00046: val_loss did not improve from 1.04614
# Epoch 47/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.8164 - accuracy: 0.9320 - val_loss: 0.9837 - val_accuracy: 0.7773
#
# Epoch 00047: val_loss improved from 1.04614 to 0.98368, saving model to ./save/cnn_gru_best.hdf5
# Epoch 48/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7869 - accuracy: 0.9407 - val_loss: 1.1683 - val_accuracy: 0.7539
#
# Epoch 00048: val_loss did not improve from 0.98368
# Epoch 49/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9667 - accuracy: 0.9058 - val_loss: 1.1821 - val_accuracy: 0.7656
#
# Epoch 00049: val_loss did not improve from 0.98368
# Epoch 50/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.8645 - accuracy: 0.9228 - val_loss: 0.9433 - val_accuracy: 0.7930
#
# Epoch 00050: val_loss improved from 0.98368 to 0.94332, saving model to ./save/cnn_gru_best.hdf5
# Epoch 51/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7902 - accuracy: 0.9389 - val_loss: 0.9976 - val_accuracy: 0.8125
#
# Epoch 00051: val_loss did not improve from 0.94332
# Epoch 52/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7874 - accuracy: 0.9343 - val_loss: 1.0252 - val_accuracy: 0.7969
#
# Epoch 00052: val_loss did not improve from 0.94332
# Epoch 53/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7886 - accuracy: 0.9334 - val_loss: 1.1637 - val_accuracy: 0.7344
#
# Epoch 00053: val_loss did not improve from 0.94332
# Epoch 54/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.8367 - accuracy: 0.9269 - val_loss: 1.1482 - val_accuracy: 0.7891
#
# Epoch 00054: val_loss did not improve from 0.94332
# Epoch 55/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.7913 - accuracy: 0.9393 - val_loss: 1.0948 - val_accuracy: 0.7930
#
# Epoch 00055: val_loss did not improve from 0.94332
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 56/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7644 - accuracy: 0.9403 - val_loss: 1.0370 - val_accuracy: 0.8125
#
# Epoch 00056: val_loss did not improve from 0.94332
# Epoch 57/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.6693 - accuracy: 0.9494 - val_loss: 1.0391 - val_accuracy: 0.8086
#
# Epoch 00057: val_loss did not improve from 0.94332
# Epoch 58/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.7294 - accuracy: 0.9449 - val_loss: 1.0393 - val_accuracy: 0.7695
#
# Epoch 00058: val_loss did not improve from 0.94332
# Epoch 59/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.6308 - accuracy: 0.9504 - val_loss: 0.9960 - val_accuracy: 0.7891
#
# Epoch 00059: val_loss did not improve from 0.94332
# Epoch 60/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.6755 - accuracy: 0.9472 - val_loss: 1.0640 - val_accuracy: 0.7773
#
# Epoch 00060: val_loss did not improve from 0.94332
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 61/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.6521 - accuracy: 0.9462 - val_loss: 0.9453 - val_accuracy: 0.8047
#
# Epoch 00061: val_loss did not improve from 0.94332
# Epoch 62/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.6076 - accuracy: 0.9573 - val_loss: 0.9583 - val_accuracy: 0.8164
#
# Epoch 00062: val_loss did not improve from 0.94332
# Epoch 63/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5648 - accuracy: 0.9600 - val_loss: 0.9692 - val_accuracy: 0.8086
#
# Epoch 00063: val_loss did not improve from 0.94332
# Epoch 64/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5948 - accuracy: 0.9586 - val_loss: 0.9162 - val_accuracy: 0.8047
#
# Epoch 00064: val_loss improved from 0.94332 to 0.91624, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5718 - accuracy: 0.9582 - val_loss: 0.9558 - val_accuracy: 0.8008
#
# Epoch 00065: val_loss did not improve from 0.91624
# Epoch 66/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.5622 - accuracy: 0.9550 - val_loss: 0.9459 - val_accuracy: 0.8047
#
# Epoch 00066: val_loss did not improve from 0.91624
# Epoch 67/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.5198 - accuracy: 0.9642 - val_loss: 0.8641 - val_accuracy: 0.8281
#
# Epoch 00067: val_loss improved from 0.91624 to 0.86406, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.5368 - accuracy: 0.9628 - val_loss: 0.9150 - val_accuracy: 0.8242
#
# Epoch 00068: val_loss did not improve from 0.86406
# Epoch 69/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.5573 - accuracy: 0.9586 - val_loss: 0.9258 - val_accuracy: 0.8359
#
# Epoch 00069: val_loss did not improve from 0.86406
# Epoch 70/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.5804 - accuracy: 0.9527 - val_loss: 0.9683 - val_accuracy: 0.8164
#
# Epoch 00070: val_loss did not improve from 0.86406
# Epoch 71/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.5476 - accuracy: 0.9632 - val_loss: 0.9876 - val_accuracy: 0.8047
#
# Epoch 00071: val_loss did not improve from 0.86406
# Epoch 72/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5290 - accuracy: 0.9628 - val_loss: 0.9584 - val_accuracy: 0.8242
#
# Epoch 00072: val_loss did not improve from 0.86406
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 73/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.5392 - accuracy: 0.9619 - val_loss: 0.9255 - val_accuracy: 0.8086
#
# Epoch 00073: val_loss did not improve from 0.86406
# Epoch 74/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5211 - accuracy: 0.9591 - val_loss: 0.9405 - val_accuracy: 0.8008
#
# Epoch 00074: val_loss did not improve from 0.86406
# Epoch 75/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4702 - accuracy: 0.9701 - val_loss: 0.8558 - val_accuracy: 0.8242
#
# Epoch 00075: val_loss improved from 0.86406 to 0.85584, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.5031 - accuracy: 0.9669 - val_loss: 0.8719 - val_accuracy: 0.8086
#
# Epoch 00076: val_loss did not improve from 0.85584
# Epoch 77/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4821 - accuracy: 0.9665 - val_loss: 0.9246 - val_accuracy: 0.8047
#
# Epoch 00077: val_loss did not improve from 0.85584
# Epoch 78/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4762 - accuracy: 0.9674 - val_loss: 0.9149 - val_accuracy: 0.8086
#
# Epoch 00078: val_loss did not improve from 0.85584
# Epoch 79/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.5590 - accuracy: 0.9550 - val_loss: 0.9111 - val_accuracy: 0.7930
#
# Epoch 00079: val_loss did not improve from 0.85584
# Epoch 80/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.5181 - accuracy: 0.9609 - val_loss: 0.9111 - val_accuracy: 0.8203
#
# Epoch 00080: val_loss did not improve from 0.85584
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 81/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4812 - accuracy: 0.9674 - val_loss: 0.8864 - val_accuracy: 0.8125
#
# Epoch 00081: val_loss did not improve from 0.85584
# Epoch 82/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4761 - accuracy: 0.9669 - val_loss: 0.8644 - val_accuracy: 0.8203
#
# Epoch 00082: val_loss did not improve from 0.85584
# Epoch 83/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4036 - accuracy: 0.9761 - val_loss: 0.8955 - val_accuracy: 0.8203
#
# Epoch 00083: val_loss did not improve from 0.85584
# Epoch 84/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4335 - accuracy: 0.9729 - val_loss: 0.9074 - val_accuracy: 0.8203
#
# Epoch 00084: val_loss did not improve from 0.85584
# Epoch 85/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.3973 - accuracy: 0.9756 - val_loss: 0.8892 - val_accuracy: 0.8242
#
# Epoch 00085: val_loss did not improve from 0.85584
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 86/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.3984 - accuracy: 0.9724 - val_loss: 0.9083 - val_accuracy: 0.8086
#
# Epoch 00086: val_loss did not improve from 0.85584
# Epoch 87/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4829 - accuracy: 0.9715 - val_loss: 0.9106 - val_accuracy: 0.8203
#
# Epoch 00087: val_loss did not improve from 0.85584
# Epoch 88/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4827 - accuracy: 0.9669 - val_loss: 0.9225 - val_accuracy: 0.8203
#
# Epoch 00088: val_loss did not improve from 0.85584
# Epoch 89/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.4504 - accuracy: 0.9669 - val_loss: 0.8848 - val_accuracy: 0.8203
#
# Epoch 00089: val_loss did not improve from 0.85584
# Epoch 90/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4392 - accuracy: 0.9747 - val_loss: 0.8778 - val_accuracy: 0.8125
#
# Epoch 00090: val_loss did not improve from 0.85584
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 91/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4743 - accuracy: 0.9710 - val_loss: 0.8983 - val_accuracy: 0.8164
#
# Epoch 00091: val_loss did not improve from 0.85584
# Epoch 92/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4273 - accuracy: 0.9743 - val_loss: 0.9002 - val_accuracy: 0.8281
#
# Epoch 00092: val_loss did not improve from 0.85584
# Epoch 93/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4638 - accuracy: 0.9697 - val_loss: 0.8997 - val_accuracy: 0.8320
#
# Epoch 00093: val_loss did not improve from 0.85584
# Epoch 94/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.3972 - accuracy: 0.9779 - val_loss: 0.9239 - val_accuracy: 0.8086
#
# Epoch 00094: val_loss did not improve from 0.85584
# Epoch 95/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.4098 - accuracy: 0.9756 - val_loss: 0.8954 - val_accuracy: 0.8125
#
# Epoch 00095: val_loss did not improve from 0.85584
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 96/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4458 - accuracy: 0.9678 - val_loss: 0.8536 - val_accuracy: 0.8164
#
# Epoch 00096: val_loss improved from 0.85584 to 0.85357, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4824 - accuracy: 0.9632 - val_loss: 0.9054 - val_accuracy: 0.8281
#
# Epoch 00097: val_loss did not improve from 0.85357
# Epoch 98/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4224 - accuracy: 0.9743 - val_loss: 0.8393 - val_accuracy: 0.8320
#
# Epoch 00098: val_loss improved from 0.85357 to 0.83928, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4481 - accuracy: 0.9683 - val_loss: 0.8858 - val_accuracy: 0.8359
#
# Epoch 00099: val_loss did not improve from 0.83928
# Epoch 100/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4176 - accuracy: 0.9720 - val_loss: 0.8519 - val_accuracy: 0.8320
#
# Epoch 00100: val_loss did not improve from 0.83928
# Epoch 101/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4040 - accuracy: 0.9775 - val_loss: 0.9342 - val_accuracy: 0.8203
#
# Epoch 00101: val_loss did not improve from 0.83928
# Epoch 102/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4319 - accuracy: 0.9775 - val_loss: 0.8714 - val_accuracy: 0.8281
#
# Epoch 00102: val_loss did not improve from 0.83928
# Epoch 103/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4721 - accuracy: 0.9674 - val_loss: 0.8744 - val_accuracy: 0.8242
#
# Epoch 00103: val_loss did not improve from 0.83928
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 104/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.3966 - accuracy: 0.9770 - val_loss: 0.9156 - val_accuracy: 0.8203
#
# Epoch 00104: val_loss did not improve from 0.83928
# Epoch 105/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4358 - accuracy: 0.9756 - val_loss: 0.8899 - val_accuracy: 0.8281
#
# Epoch 00105: val_loss did not improve from 0.83928
# Epoch 106/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4191 - accuracy: 0.9710 - val_loss: 0.8233 - val_accuracy: 0.8320
#
# Epoch 00106: val_loss improved from 0.83928 to 0.82327, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4126 - accuracy: 0.9779 - val_loss: 0.8572 - val_accuracy: 0.8320
#
# Epoch 00107: val_loss did not improve from 0.82327
# Epoch 108/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4245 - accuracy: 0.9766 - val_loss: 0.8298 - val_accuracy: 0.8320
#
# Epoch 00108: val_loss did not improve from 0.82327
# Epoch 109/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4517 - accuracy: 0.9697 - val_loss: 0.8422 - val_accuracy: 0.8281
#
# Epoch 00109: val_loss did not improve from 0.82327
# Epoch 110/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4204 - accuracy: 0.9733 - val_loss: 0.9128 - val_accuracy: 0.8203
#
# Epoch 00110: val_loss did not improve from 0.82327
# Epoch 111/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4840 - accuracy: 0.9655 - val_loss: 0.8974 - val_accuracy: 0.8281
#
# Epoch 00111: val_loss did not improve from 0.82327
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 112/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4156 - accuracy: 0.9770 - val_loss: 0.9219 - val_accuracy: 0.8203
#
# Epoch 00112: val_loss did not improve from 0.82327
# Epoch 113/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4027 - accuracy: 0.9733 - val_loss: 0.8784 - val_accuracy: 0.8320
#
# Epoch 00113: val_loss did not improve from 0.82327
# Epoch 114/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.4543 - accuracy: 0.9665 - val_loss: 0.9163 - val_accuracy: 0.8203
#
# Epoch 00114: val_loss did not improve from 0.82327
# Epoch 115/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4177 - accuracy: 0.9738 - val_loss: 0.8628 - val_accuracy: 0.8242
#
# Epoch 00115: val_loss did not improve from 0.82327
# Epoch 116/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4440 - accuracy: 0.9729 - val_loss: 0.8885 - val_accuracy: 0.8203
#
# Epoch 00116: val_loss did not improve from 0.82327
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 117/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4503 - accuracy: 0.9729 - val_loss: 0.8794 - val_accuracy: 0.8281
#
# Epoch 00117: val_loss did not improve from 0.82327
# Epoch 118/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 0.4126 - accuracy: 0.9743 - val_loss: 0.8955 - val_accuracy: 0.8203
#
# Epoch 00118: val_loss did not improve from 0.82327
# Epoch 119/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.4423 - accuracy: 0.9715 - val_loss: 0.9144 - val_accuracy: 0.8203
#
# Epoch 00119: val_loss did not improve from 0.82327
# Epoch 120/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.4378 - accuracy: 0.9733 - val_loss: 0.9319 - val_accuracy: 0.8164
#
# Epoch 00120: val_loss did not improve from 0.82327
# Epoch 121/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4583 - accuracy: 0.9674 - val_loss: 0.9028 - val_accuracy: 0.8320
#
# Epoch 00121: val_loss did not improve from 0.82327
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 122/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4038 - accuracy: 0.9779 - val_loss: 0.8558 - val_accuracy: 0.8320
#
# Epoch 00122: val_loss did not improve from 0.82327
# Epoch 123/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4388 - accuracy: 0.9701 - val_loss: 0.8914 - val_accuracy: 0.8281
#
# Epoch 00123: val_loss did not improve from 0.82327
# Epoch 124/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4183 - accuracy: 0.9720 - val_loss: 0.9143 - val_accuracy: 0.8203
#
# Epoch 00124: val_loss did not improve from 0.82327
# Epoch 125/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4165 - accuracy: 0.9733 - val_loss: 0.9196 - val_accuracy: 0.8242
#
# Epoch 00125: val_loss did not improve from 0.82327
# Epoch 126/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4458 - accuracy: 0.9674 - val_loss: 0.9100 - val_accuracy: 0.8242
#
# Epoch 00126: val_loss did not improve from 0.82327
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 127/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4736 - accuracy: 0.9720 - val_loss: 0.9085 - val_accuracy: 0.8281
#
# Epoch 00127: val_loss did not improve from 0.82327
# Epoch 128/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4152 - accuracy: 0.9720 - val_loss: 0.8701 - val_accuracy: 0.8320
#
# Epoch 00128: val_loss did not improve from 0.82327
# Epoch 129/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.4139 - accuracy: 0.9761 - val_loss: 0.9299 - val_accuracy: 0.8125
#
# Epoch 00129: val_loss did not improve from 0.82327
# Epoch 130/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.3928 - accuracy: 0.9779 - val_loss: 0.9304 - val_accuracy: 0.8164
#
# Epoch 00130: val_loss did not improve from 0.82327
# Epoch 131/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4407 - accuracy: 0.9724 - val_loss: 0.9061 - val_accuracy: 0.8242
#
# Epoch 00131: val_loss did not improve from 0.82327
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 132/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4337 - accuracy: 0.9710 - val_loss: 0.8698 - val_accuracy: 0.8398
#
# Epoch 00132: val_loss did not improve from 0.82327
# Epoch 133/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4304 - accuracy: 0.9674 - val_loss: 0.8983 - val_accuracy: 0.8320
#
# Epoch 00133: val_loss did not improve from 0.82327
# Epoch 134/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4249 - accuracy: 0.9697 - val_loss: 0.8917 - val_accuracy: 0.8320
#
# Epoch 00134: val_loss did not improve from 0.82327
# Epoch 135/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4450 - accuracy: 0.9697 - val_loss: 0.9052 - val_accuracy: 0.8242
#
# Epoch 00135: val_loss did not improve from 0.82327
# Epoch 136/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4359 - accuracy: 0.9720 - val_loss: 0.9224 - val_accuracy: 0.8281
#
# Epoch 00136: val_loss did not improve from 0.82327
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7247 - accuracy: 0.8464
# [0.7246597409248352, 0.8464000225067139]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
