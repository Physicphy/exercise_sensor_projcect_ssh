# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1450        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1810        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,227,001
# Trainable params: 1,220,761
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 42s 348ms/step - loss: 42.5481 - accuracy: 0.3304 - val_loss: 30.4189 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 30.41889, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 26.8353 - accuracy: 0.4995 - val_loss: 19.3064 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 30.41889 to 19.30644, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 17.2951 - accuracy: 0.5915 - val_loss: 12.8192 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 19.30644 to 12.81925, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 12.1309 - accuracy: 0.6218 - val_loss: 9.3307 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 12.81925 to 9.33066, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 8.8633 - accuracy: 0.6498 - val_loss: 7.4196 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 9.33066 to 7.41964, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 6.8421 - accuracy: 0.6710 - val_loss: 6.2291 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 7.41964 to 6.22911, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 5.4920 - accuracy: 0.6944 - val_loss: 5.9902 - val_accuracy: 0.0156
#
# Epoch 00007: val_loss improved from 6.22911 to 5.99022, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 4.6241 - accuracy: 0.7022 - val_loss: 5.2522 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 5.99022 to 5.25224, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 3.9383 - accuracy: 0.7307 - val_loss: 5.0270 - val_accuracy: 0.2188
#
# Epoch 00009: val_loss improved from 5.25224 to 5.02701, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 3.8334 - accuracy: 0.7123 - val_loss: 5.5375 - val_accuracy: 0.2578
#
# Epoch 00010: val_loss did not improve from 5.02701
# Epoch 11/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 3.5263 - accuracy: 0.7312 - val_loss: 5.5611 - val_accuracy: 0.0352
#
# Epoch 00011: val_loss did not improve from 5.02701
# Epoch 12/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 3.4204 - accuracy: 0.7261 - val_loss: 4.8591 - val_accuracy: 0.1797
#
# Epoch 00012: val_loss improved from 5.02701 to 4.85914, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 3.1514 - accuracy: 0.7472 - val_loss: 5.5934 - val_accuracy: 0.1211
#
# Epoch 00013: val_loss did not improve from 4.85914
# Epoch 14/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.8452 - accuracy: 0.7688 - val_loss: 5.0191 - val_accuracy: 0.0898
#
# Epoch 00014: val_loss did not improve from 4.85914
# Epoch 15/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.8932 - accuracy: 0.7675 - val_loss: 4.9014 - val_accuracy: 0.1641
#
# Epoch 00015: val_loss did not improve from 4.85914
# Epoch 16/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.9621 - accuracy: 0.7482 - val_loss: 3.6606 - val_accuracy: 0.4414
#
# Epoch 00016: val_loss improved from 4.85914 to 3.66061, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.8725 - accuracy: 0.7555 - val_loss: 3.7462 - val_accuracy: 0.4102
#
# Epoch 00017: val_loss did not improve from 3.66061
# Epoch 18/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.5370 - accuracy: 0.7845 - val_loss: 2.6148 - val_accuracy: 0.5625
#
# Epoch 00018: val_loss improved from 3.66061 to 2.61483, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.4421 - accuracy: 0.7996 - val_loss: 2.3422 - val_accuracy: 0.6016
#
# Epoch 00019: val_loss improved from 2.61483 to 2.34222, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.7593 - accuracy: 0.7491 - val_loss: 2.7156 - val_accuracy: 0.5547
#
# Epoch 00020: val_loss did not improve from 2.34222
# Epoch 21/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.4986 - accuracy: 0.7702 - val_loss: 2.4578 - val_accuracy: 0.5859
#
# Epoch 00021: val_loss did not improve from 2.34222
# Epoch 22/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.3865 - accuracy: 0.7909 - val_loss: 2.0755 - val_accuracy: 0.6484
#
# Epoch 00022: val_loss improved from 2.34222 to 2.07546, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.3168 - accuracy: 0.8038 - val_loss: 1.9493 - val_accuracy: 0.6719
#
# Epoch 00023: val_loss improved from 2.07546 to 1.94926, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 2.2708 - accuracy: 0.7987 - val_loss: 1.7022 - val_accuracy: 0.7031
#
# Epoch 00024: val_loss improved from 1.94926 to 1.70220, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 2.1750 - accuracy: 0.8015 - val_loss: 1.5770 - val_accuracy: 0.7266
#
# Epoch 00025: val_loss improved from 1.70220 to 1.57705, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.0574 - accuracy: 0.8180 - val_loss: 1.3704 - val_accuracy: 0.7891
#
# Epoch 00026: val_loss improved from 1.57705 to 1.37036, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 2.1418 - accuracy: 0.8120 - val_loss: 1.4766 - val_accuracy: 0.7266
#
# Epoch 00027: val_loss did not improve from 1.37036
# Epoch 28/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.2566 - accuracy: 0.8038 - val_loss: 1.8201 - val_accuracy: 0.5898
#
# Epoch 00028: val_loss did not improve from 1.37036
# Epoch 29/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.2187 - accuracy: 0.7955 - val_loss: 1.8532 - val_accuracy: 0.6562
#
# Epoch 00029: val_loss did not improve from 1.37036
# Epoch 30/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.9473 - accuracy: 0.8332 - val_loss: 1.6425 - val_accuracy: 0.6914
#
# Epoch 00030: val_loss did not improve from 1.37036
# Epoch 31/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.9002 - accuracy: 0.8249 - val_loss: 1.3588 - val_accuracy: 0.7266
#
# Epoch 00031: val_loss improved from 1.37036 to 1.35878, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.8308 - accuracy: 0.8323 - val_loss: 1.9483 - val_accuracy: 0.6211
#
# Epoch 00032: val_loss did not improve from 1.35878
# Epoch 33/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.9511 - accuracy: 0.8231 - val_loss: 2.2620 - val_accuracy: 0.6211
#
# Epoch 00033: val_loss did not improve from 1.35878
# Epoch 34/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.9053 - accuracy: 0.8199 - val_loss: 1.7321 - val_accuracy: 0.6680
#
# Epoch 00034: val_loss did not improve from 1.35878
# Epoch 35/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.0452 - accuracy: 0.8272 - val_loss: 1.3185 - val_accuracy: 0.7500
#
# Epoch 00035: val_loss improved from 1.35878 to 1.31851, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.9748 - accuracy: 0.8166 - val_loss: 1.5964 - val_accuracy: 0.6523
#
# Epoch 00036: val_loss did not improve from 1.31851
# Epoch 37/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.8633 - accuracy: 0.8382 - val_loss: 1.9603 - val_accuracy: 0.6211
#
# Epoch 00037: val_loss did not improve from 1.31851
# Epoch 38/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.7306 - accuracy: 0.8456 - val_loss: 1.3488 - val_accuracy: 0.7266
#
# Epoch 00038: val_loss did not improve from 1.31851
# Epoch 39/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.7479 - accuracy: 0.8451 - val_loss: 1.6157 - val_accuracy: 0.7070
#
# Epoch 00039: val_loss did not improve from 1.31851
# Epoch 40/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.7436 - accuracy: 0.8438 - val_loss: 1.4041 - val_accuracy: 0.7148
#
# Epoch 00040: val_loss did not improve from 1.31851
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 41/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.5811 - accuracy: 0.8608 - val_loss: 1.2831 - val_accuracy: 0.7539
#
# Epoch 00041: val_loss improved from 1.31851 to 1.28305, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.5482 - accuracy: 0.8603 - val_loss: 1.2163 - val_accuracy: 0.7188
#
# Epoch 00042: val_loss improved from 1.28305 to 1.21633, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.5143 - accuracy: 0.8571 - val_loss: 1.3137 - val_accuracy: 0.7422
#
# Epoch 00043: val_loss did not improve from 1.21633
# Epoch 44/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.1917 - accuracy: 0.8989 - val_loss: 1.2363 - val_accuracy: 0.7500
#
# Epoch 00044: val_loss did not improve from 1.21633
# Epoch 45/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.4304 - accuracy: 0.8690 - val_loss: 1.0877 - val_accuracy: 0.7656
#
# Epoch 00045: val_loss improved from 1.21633 to 1.08774, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.1242 - accuracy: 0.9072 - val_loss: 1.2264 - val_accuracy: 0.7695
#
# Epoch 00046: val_loss did not improve from 1.08774
# Epoch 47/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.3080 - accuracy: 0.8805 - val_loss: 1.4119 - val_accuracy: 0.7344
#
# Epoch 00047: val_loss did not improve from 1.08774
# Epoch 48/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.2337 - accuracy: 0.8984 - val_loss: 1.0546 - val_accuracy: 0.8164
#
# Epoch 00048: val_loss improved from 1.08774 to 1.05456, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.6851 - accuracy: 0.8369 - val_loss: 1.2656 - val_accuracy: 0.7578
#
# Epoch 00049: val_loss did not improve from 1.05456
# Epoch 50/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.4376 - accuracy: 0.8704 - val_loss: 1.1607 - val_accuracy: 0.7930
#
# Epoch 00050: val_loss did not improve from 1.05456
# Epoch 51/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.2064 - accuracy: 0.9003 - val_loss: 1.0318 - val_accuracy: 0.7891
#
# Epoch 00051: val_loss improved from 1.05456 to 1.03178, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.2020 - accuracy: 0.8975 - val_loss: 1.1283 - val_accuracy: 0.7617
#
# Epoch 00052: val_loss did not improve from 1.03178
# Epoch 53/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.2163 - accuracy: 0.8938 - val_loss: 1.1883 - val_accuracy: 0.7578
#
# Epoch 00053: val_loss did not improve from 1.03178
# Epoch 54/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.3552 - accuracy: 0.8764 - val_loss: 1.0449 - val_accuracy: 0.8086
#
# Epoch 00054: val_loss did not improve from 1.03178
# Epoch 55/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.2759 - accuracy: 0.8782 - val_loss: 1.2633 - val_accuracy: 0.6797
#
# Epoch 00055: val_loss did not improve from 1.03178
# Epoch 56/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.2760 - accuracy: 0.8860 - val_loss: 1.1002 - val_accuracy: 0.7930
#
# Epoch 00056: val_loss did not improve from 1.03178
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 57/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.0831 - accuracy: 0.9053 - val_loss: 1.0418 - val_accuracy: 0.7812
#
# Epoch 00057: val_loss did not improve from 1.03178
# Epoch 58/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.1471 - accuracy: 0.9017 - val_loss: 0.9887 - val_accuracy: 0.7930
#
# Epoch 00058: val_loss improved from 1.03178 to 0.98874, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.0226 - accuracy: 0.9104 - val_loss: 0.9470 - val_accuracy: 0.8008
#
# Epoch 00059: val_loss improved from 0.98874 to 0.94700, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.0681 - accuracy: 0.9040 - val_loss: 1.0355 - val_accuracy: 0.7656
#
# Epoch 00060: val_loss did not improve from 0.94700
# Epoch 61/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.0677 - accuracy: 0.9003 - val_loss: 1.0694 - val_accuracy: 0.7695
#
# Epoch 00061: val_loss did not improve from 0.94700
# Epoch 62/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.0284 - accuracy: 0.9076 - val_loss: 0.9390 - val_accuracy: 0.7969
#
# Epoch 00062: val_loss improved from 0.94700 to 0.93900, saving model to ./save/cnn_gru_best.hdf5
# Epoch 63/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.9783 - accuracy: 0.9164 - val_loss: 1.0864 - val_accuracy: 0.7695
#
# Epoch 00063: val_loss did not improve from 0.93900
# Epoch 64/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9979 - accuracy: 0.9113 - val_loss: 0.9753 - val_accuracy: 0.7969
#
# Epoch 00064: val_loss did not improve from 0.93900
# Epoch 65/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9343 - accuracy: 0.9164 - val_loss: 1.0099 - val_accuracy: 0.7852
#
# Epoch 00065: val_loss did not improve from 0.93900
# Epoch 66/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9696 - accuracy: 0.9200 - val_loss: 1.0121 - val_accuracy: 0.8047
#
# Epoch 00066: val_loss did not improve from 0.93900
# Epoch 67/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8849 - accuracy: 0.9242 - val_loss: 0.9734 - val_accuracy: 0.8281
#
# Epoch 00067: val_loss did not improve from 0.93900
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 68/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.8623 - accuracy: 0.9278 - val_loss: 0.9884 - val_accuracy: 0.7891
#
# Epoch 00068: val_loss did not improve from 0.93900
# Epoch 69/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8951 - accuracy: 0.9214 - val_loss: 0.9254 - val_accuracy: 0.8047
#
# Epoch 00069: val_loss improved from 0.93900 to 0.92540, saving model to ./save/cnn_gru_best.hdf5
# Epoch 70/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9195 - accuracy: 0.9182 - val_loss: 0.9701 - val_accuracy: 0.7891
#
# Epoch 00070: val_loss did not improve from 0.92540
# Epoch 71/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8735 - accuracy: 0.9251 - val_loss: 0.9133 - val_accuracy: 0.8164
#
# Epoch 00071: val_loss improved from 0.92540 to 0.91331, saving model to ./save/cnn_gru_best.hdf5
# Epoch 72/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8413 - accuracy: 0.9260 - val_loss: 0.9977 - val_accuracy: 0.7930
#
# Epoch 00072: val_loss did not improve from 0.91331
# Epoch 73/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9039 - accuracy: 0.9150 - val_loss: 0.9495 - val_accuracy: 0.7891
#
# Epoch 00073: val_loss did not improve from 0.91331
# Epoch 74/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8872 - accuracy: 0.9164 - val_loss: 0.9701 - val_accuracy: 0.8047
#
# Epoch 00074: val_loss did not improve from 0.91331
# Epoch 75/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7560 - accuracy: 0.9384 - val_loss: 0.9087 - val_accuracy: 0.8203
#
# Epoch 00075: val_loss improved from 0.91331 to 0.90874, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.7925 - accuracy: 0.9306 - val_loss: 0.9314 - val_accuracy: 0.8008
#
# Epoch 00076: val_loss did not improve from 0.90874
# Epoch 77/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7441 - accuracy: 0.9361 - val_loss: 0.9026 - val_accuracy: 0.8281
#
# Epoch 00077: val_loss improved from 0.90874 to 0.90263, saving model to ./save/cnn_gru_best.hdf5
# Epoch 78/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7657 - accuracy: 0.9357 - val_loss: 0.9253 - val_accuracy: 0.7930
#
# Epoch 00078: val_loss did not improve from 0.90263
# Epoch 79/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9965 - accuracy: 0.9007 - val_loss: 0.9676 - val_accuracy: 0.7930
#
# Epoch 00079: val_loss did not improve from 0.90263
# Epoch 80/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.8219 - accuracy: 0.9228 - val_loss: 0.9371 - val_accuracy: 0.8125
#
# Epoch 00080: val_loss did not improve from 0.90263
# Epoch 81/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7906 - accuracy: 0.9288 - val_loss: 0.9501 - val_accuracy: 0.7969
#
# Epoch 00081: val_loss did not improve from 0.90263
# Epoch 82/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7980 - accuracy: 0.9352 - val_loss: 0.8785 - val_accuracy: 0.8086
#
# Epoch 00082: val_loss improved from 0.90263 to 0.87845, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.6832 - accuracy: 0.9398 - val_loss: 0.9660 - val_accuracy: 0.8086
#
# Epoch 00083: val_loss did not improve from 0.87845
# Epoch 84/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7118 - accuracy: 0.9462 - val_loss: 0.9631 - val_accuracy: 0.7852
#
# Epoch 00084: val_loss did not improve from 0.87845
# Epoch 85/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.6609 - accuracy: 0.9513 - val_loss: 0.8939 - val_accuracy: 0.8281
#
# Epoch 00085: val_loss did not improve from 0.87845
# Epoch 86/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.6092 - accuracy: 0.9540 - val_loss: 0.9041 - val_accuracy: 0.8281
#
# Epoch 00086: val_loss did not improve from 0.87845
# Epoch 87/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8756 - accuracy: 0.9182 - val_loss: 0.9058 - val_accuracy: 0.8164
#
# Epoch 00087: val_loss did not improve from 0.87845
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 88/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.8114 - accuracy: 0.9233 - val_loss: 0.8903 - val_accuracy: 0.8164
#
# Epoch 00088: val_loss did not improve from 0.87845
# Epoch 89/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.6970 - accuracy: 0.9403 - val_loss: 0.8627 - val_accuracy: 0.8281
#
# Epoch 00089: val_loss improved from 0.87845 to 0.86270, saving model to ./save/cnn_gru_best.hdf5
# Epoch 90/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7151 - accuracy: 0.9347 - val_loss: 0.8879 - val_accuracy: 0.8242
#
# Epoch 00090: val_loss did not improve from 0.86270
# Epoch 91/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7230 - accuracy: 0.9416 - val_loss: 0.8863 - val_accuracy: 0.8008
#
# Epoch 00091: val_loss did not improve from 0.86270
# Epoch 92/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.6680 - accuracy: 0.9462 - val_loss: 0.9016 - val_accuracy: 0.7891
#
# Epoch 00092: val_loss did not improve from 0.86270
# Epoch 93/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7597 - accuracy: 0.9352 - val_loss: 0.9057 - val_accuracy: 0.8164
#
# Epoch 00093: val_loss did not improve from 0.86270
# Epoch 94/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.6313 - accuracy: 0.9490 - val_loss: 0.9308 - val_accuracy: 0.8047
#
# Epoch 00094: val_loss did not improve from 0.86270
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 95/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.6293 - accuracy: 0.9517 - val_loss: 0.9046 - val_accuracy: 0.8008
#
# Epoch 00095: val_loss did not improve from 0.86270
# Epoch 96/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7211 - accuracy: 0.9324 - val_loss: 0.8545 - val_accuracy: 0.8086
#
# Epoch 00096: val_loss improved from 0.86270 to 0.85452, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.7826 - accuracy: 0.9278 - val_loss: 0.8968 - val_accuracy: 0.8008
#
# Epoch 00097: val_loss did not improve from 0.85452
# Epoch 98/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.6231 - accuracy: 0.9527 - val_loss: 0.8916 - val_accuracy: 0.8086
#
# Epoch 00098: val_loss did not improve from 0.85452
# Epoch 99/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7492 - accuracy: 0.9334 - val_loss: 0.8664 - val_accuracy: 0.8086
#
# Epoch 00099: val_loss did not improve from 0.85452
# Epoch 100/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.5834 - accuracy: 0.9508 - val_loss: 0.8457 - val_accuracy: 0.8125
#
# Epoch 00100: val_loss improved from 0.85452 to 0.84570, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.6038 - accuracy: 0.9531 - val_loss: 0.9031 - val_accuracy: 0.7969
#
# Epoch 00101: val_loss did not improve from 0.84570
# Epoch 102/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.6617 - accuracy: 0.9430 - val_loss: 0.8893 - val_accuracy: 0.8047
#
# Epoch 00102: val_loss did not improve from 0.84570
# Epoch 103/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7652 - accuracy: 0.9338 - val_loss: 0.8789 - val_accuracy: 0.8047
#
# Epoch 00103: val_loss did not improve from 0.84570
# Epoch 104/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.5626 - accuracy: 0.9577 - val_loss: 0.8835 - val_accuracy: 0.8164
#
# Epoch 00104: val_loss did not improve from 0.84570
# Epoch 105/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.6638 - accuracy: 0.9449 - val_loss: 0.8803 - val_accuracy: 0.8203
#
# Epoch 00105: val_loss did not improve from 0.84570
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 106/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.6114 - accuracy: 0.9494 - val_loss: 0.8021 - val_accuracy: 0.8203
#
# Epoch 00106: val_loss improved from 0.84570 to 0.80209, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.5615 - accuracy: 0.9586 - val_loss: 0.8366 - val_accuracy: 0.8125
#
# Epoch 00107: val_loss did not improve from 0.80209
# Epoch 108/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.5969 - accuracy: 0.9522 - val_loss: 0.7830 - val_accuracy: 0.8281
#
# Epoch 00108: val_loss improved from 0.80209 to 0.78297, saving model to ./save/cnn_gru_best.hdf5
# Epoch 109/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.6479 - accuracy: 0.9481 - val_loss: 0.8278 - val_accuracy: 0.8086
#
# Epoch 00109: val_loss did not improve from 0.78297
# Epoch 110/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.5850 - accuracy: 0.9540 - val_loss: 0.8639 - val_accuracy: 0.8086
#
# Epoch 00110: val_loss did not improve from 0.78297
# Epoch 111/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7288 - accuracy: 0.9352 - val_loss: 0.8699 - val_accuracy: 0.8008
#
# Epoch 00111: val_loss did not improve from 0.78297
# Epoch 112/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.5704 - accuracy: 0.9586 - val_loss: 0.8951 - val_accuracy: 0.7969
#
# Epoch 00112: val_loss did not improve from 0.78297
# Epoch 113/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.6061 - accuracy: 0.9494 - val_loss: 0.8433 - val_accuracy: 0.8164
#
# Epoch 00113: val_loss did not improve from 0.78297
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 114/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.6420 - accuracy: 0.9449 - val_loss: 0.8962 - val_accuracy: 0.7969
#
# Epoch 00114: val_loss did not improve from 0.78297
# Epoch 115/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.5715 - accuracy: 0.9545 - val_loss: 0.8607 - val_accuracy: 0.8008
#
# Epoch 00115: val_loss did not improve from 0.78297
# Epoch 116/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.6062 - accuracy: 0.9481 - val_loss: 0.8703 - val_accuracy: 0.8086
#
# Epoch 00116: val_loss did not improve from 0.78297
# Epoch 117/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.6469 - accuracy: 0.9485 - val_loss: 0.8891 - val_accuracy: 0.8047
#
# Epoch 00117: val_loss did not improve from 0.78297
# Epoch 118/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.5418 - accuracy: 0.9591 - val_loss: 0.8708 - val_accuracy: 0.8047
#
# Epoch 00118: val_loss did not improve from 0.78297
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 119/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.5992 - accuracy: 0.9490 - val_loss: 0.9085 - val_accuracy: 0.8008
#
# Epoch 00119: val_loss did not improve from 0.78297
# Epoch 120/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.6692 - accuracy: 0.9380 - val_loss: 0.9173 - val_accuracy: 0.7969
#
# Epoch 00120: val_loss did not improve from 0.78297
# Epoch 121/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.6589 - accuracy: 0.9462 - val_loss: 0.9042 - val_accuracy: 0.8008
#
# Epoch 00121: val_loss did not improve from 0.78297
# Epoch 122/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.5325 - accuracy: 0.9605 - val_loss: 0.8518 - val_accuracy: 0.8086
#
# Epoch 00122: val_loss did not improve from 0.78297
# Epoch 123/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.6428 - accuracy: 0.9407 - val_loss: 0.9007 - val_accuracy: 0.8125
#
# Epoch 00123: val_loss did not improve from 0.78297
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 124/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.6023 - accuracy: 0.9494 - val_loss: 0.9042 - val_accuracy: 0.8125
#
# Epoch 00124: val_loss did not improve from 0.78297
# Epoch 125/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.5934 - accuracy: 0.9568 - val_loss: 0.9088 - val_accuracy: 0.8008
#
# Epoch 00125: val_loss did not improve from 0.78297
# Epoch 126/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.5772 - accuracy: 0.9536 - val_loss: 0.8971 - val_accuracy: 0.8086
#
# Epoch 00126: val_loss did not improve from 0.78297
# Epoch 127/2000
# 34/34 [==============================] - 8s 248ms/step - loss: 0.6687 - accuracy: 0.9426 - val_loss: 0.8941 - val_accuracy: 0.8047
#
# Epoch 00127: val_loss did not improve from 0.78297
# Epoch 128/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.5147 - accuracy: 0.9623 - val_loss: 0.8519 - val_accuracy: 0.8164
#
# Epoch 00128: val_loss did not improve from 0.78297
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 129/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.6130 - accuracy: 0.9513 - val_loss: 0.9094 - val_accuracy: 0.7930
#
# Epoch 00129: val_loss did not improve from 0.78297
# Epoch 130/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.5066 - accuracy: 0.9665 - val_loss: 0.9123 - val_accuracy: 0.8047
#
# Epoch 00130: val_loss did not improve from 0.78297
# Epoch 131/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.5945 - accuracy: 0.9508 - val_loss: 0.8920 - val_accuracy: 0.8086
#
# Epoch 00131: val_loss did not improve from 0.78297
# Epoch 132/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.5934 - accuracy: 0.9536 - val_loss: 0.8862 - val_accuracy: 0.8164
#
# Epoch 00132: val_loss did not improve from 0.78297
# Epoch 133/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.5963 - accuracy: 0.9563 - val_loss: 0.8891 - val_accuracy: 0.8047
#
# Epoch 00133: val_loss did not improve from 0.78297
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 134/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.5873 - accuracy: 0.9508 - val_loss: 0.8931 - val_accuracy: 0.8047
#
# Epoch 00134: val_loss did not improve from 0.78297
# Epoch 135/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.6115 - accuracy: 0.9481 - val_loss: 0.8922 - val_accuracy: 0.8047
#
# Epoch 00135: val_loss did not improve from 0.78297
# Epoch 136/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.6340 - accuracy: 0.9467 - val_loss: 0.9013 - val_accuracy: 0.8125
#
# Epoch 00136: val_loss did not improve from 0.78297
# Epoch 137/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.5794 - accuracy: 0.9536 - val_loss: 0.8750 - val_accuracy: 0.8047
#
# Epoch 00137: val_loss did not improve from 0.78297
# Epoch 138/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.5178 - accuracy: 0.9605 - val_loss: 0.8827 - val_accuracy: 0.8164
#
# Epoch 00138: val_loss did not improve from 0.78297
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 00138: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7174 - accuracy: 0.8400
# [0.7173665761947632, 0.8399999737739563]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
