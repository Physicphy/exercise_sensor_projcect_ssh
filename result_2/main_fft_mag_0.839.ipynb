# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

# def scheduler(epoch, lr):
#     if (epoch>20) and (lr > 0.00001):
#         lr = lr*0.9
#         return lr
#     else:
#         return lr

# lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 2)       0           input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 6)       0           input_4[0][0]
#                                                                  input_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      730         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      370         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1090        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1090        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,225,561
# Trainable params: 1,219,321
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 40s 330ms/step - loss: 43.0962 - accuracy: 0.3667 - val_loss: 31.4794 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 31.47938, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 27.7927 - accuracy: 0.5556 - val_loss: 20.7402 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 31.47938 to 20.74021, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 18.3044 - accuracy: 0.6287 - val_loss: 14.0963 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 20.74021 to 14.09632, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 12.8826 - accuracy: 0.6631 - val_loss: 10.4618 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 14.09632 to 10.46182, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 9.3780 - accuracy: 0.6801 - val_loss: 8.4344 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 10.46182 to 8.43442, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 7.1190 - accuracy: 0.7050 - val_loss: 7.3877 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 8.43442 to 7.38768, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 5.5462 - accuracy: 0.7381 - val_loss: 6.6651 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 7.38768 to 6.66513, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 4.6800 - accuracy: 0.7463 - val_loss: 5.9698 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 6.66513 to 5.96982, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 3.9185 - accuracy: 0.7670 - val_loss: 5.6834 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss improved from 5.96982 to 5.68345, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 3.6363 - accuracy: 0.7390 - val_loss: 5.2508 - val_accuracy: 0.4375
#
# Epoch 00010: val_loss improved from 5.68345 to 5.25082, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 3.3205 - accuracy: 0.7642 - val_loss: 5.2688 - val_accuracy: 0.3672
#
# Epoch 00011: val_loss did not improve from 5.25082
# Epoch 12/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 3.1296 - accuracy: 0.7619 - val_loss: 5.1146 - val_accuracy: 0.1875
#
# Epoch 00012: val_loss improved from 5.25082 to 5.11461, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 2.7632 - accuracy: 0.7987 - val_loss: 4.8293 - val_accuracy: 0.3672
#
# Epoch 00013: val_loss improved from 5.11461 to 4.82927, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 2.5934 - accuracy: 0.7927 - val_loss: 4.3695 - val_accuracy: 0.3633
#
# Epoch 00014: val_loss improved from 4.82927 to 4.36952, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 2.5873 - accuracy: 0.7950 - val_loss: 4.8925 - val_accuracy: 0.2188
#
# Epoch 00015: val_loss did not improve from 4.36952
# Epoch 16/2000
# 34/34 [==============================] - 9s 250ms/step - loss: 2.5263 - accuracy: 0.7900 - val_loss: 3.2653 - val_accuracy: 0.4219
#
# Epoch 00016: val_loss improved from 4.36952 to 3.26529, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 2.4616 - accuracy: 0.8093 - val_loss: 3.8948 - val_accuracy: 0.2617
#
# Epoch 00017: val_loss did not improve from 3.26529
# Epoch 18/2000
# 34/34 [==============================] - 9s 252ms/step - loss: 2.1709 - accuracy: 0.8272 - val_loss: 2.4513 - val_accuracy: 0.5898
#
# Epoch 00018: val_loss improved from 3.26529 to 2.45127, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 9s 260ms/step - loss: 2.0854 - accuracy: 0.8300 - val_loss: 2.8399 - val_accuracy: 0.4609
#
# Epoch 00019: val_loss did not improve from 2.45127
# Epoch 20/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 2.3404 - accuracy: 0.7918 - val_loss: 3.2795 - val_accuracy: 0.3711
#
# Epoch 00020: val_loss did not improve from 2.45127
# Epoch 21/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.1558 - accuracy: 0.8153 - val_loss: 1.6255 - val_accuracy: 0.6914
#
# Epoch 00021: val_loss improved from 2.45127 to 1.62546, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 2.0127 - accuracy: 0.8290 - val_loss: 1.8153 - val_accuracy: 0.6719
#
# Epoch 00022: val_loss did not improve from 1.62546
# Epoch 23/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.9503 - accuracy: 0.8447 - val_loss: 1.7455 - val_accuracy: 0.6328
#
# Epoch 00023: val_loss did not improve from 1.62546
# Epoch 24/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.8836 - accuracy: 0.8419 - val_loss: 1.9650 - val_accuracy: 0.6250
#
# Epoch 00024: val_loss did not improve from 1.62546
# Epoch 25/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 1.8074 - accuracy: 0.8470 - val_loss: 1.4463 - val_accuracy: 0.7227
#
# Epoch 00025: val_loss improved from 1.62546 to 1.44625, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.7889 - accuracy: 0.8525 - val_loss: 1.3996 - val_accuracy: 0.7461
#
# Epoch 00026: val_loss improved from 1.44625 to 1.39960, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.8203 - accuracy: 0.8424 - val_loss: 2.0396 - val_accuracy: 0.6289
#
# Epoch 00027: val_loss did not improve from 1.39960
# Epoch 28/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.8627 - accuracy: 0.8433 - val_loss: 1.5189 - val_accuracy: 0.6953
#
# Epoch 00028: val_loss did not improve from 1.39960
# Epoch 29/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.8001 - accuracy: 0.8442 - val_loss: 1.7049 - val_accuracy: 0.6875
#
# Epoch 00029: val_loss did not improve from 1.39960
# Epoch 30/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.6127 - accuracy: 0.8612 - val_loss: 1.9619 - val_accuracy: 0.6406
#
# Epoch 00030: val_loss did not improve from 1.39960
# Epoch 31/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.5818 - accuracy: 0.8631 - val_loss: 2.9714 - val_accuracy: 0.4688
#
# Epoch 00031: val_loss did not improve from 1.39960
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 1.4366 - accuracy: 0.8814 - val_loss: 1.6980 - val_accuracy: 0.6914
#
# Epoch 00032: val_loss did not improve from 1.39960
# Epoch 33/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.2815 - accuracy: 0.8934 - val_loss: 2.4779 - val_accuracy: 0.5312
#
# Epoch 00033: val_loss did not improve from 1.39960
# Epoch 34/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.2082 - accuracy: 0.8984 - val_loss: 1.2285 - val_accuracy: 0.7461
#
# Epoch 00034: val_loss improved from 1.39960 to 1.22852, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.2706 - accuracy: 0.8961 - val_loss: 1.1668 - val_accuracy: 0.7500
#
# Epoch 00035: val_loss improved from 1.22852 to 1.16684, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 1.2162 - accuracy: 0.8957 - val_loss: 1.2482 - val_accuracy: 0.7344
#
# Epoch 00036: val_loss did not improve from 1.16684
# Epoch 37/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 1.1885 - accuracy: 0.8980 - val_loss: 1.2919 - val_accuracy: 0.7344
#
# Epoch 00037: val_loss did not improve from 1.16684
# Epoch 38/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 1.1514 - accuracy: 0.8980 - val_loss: 1.6120 - val_accuracy: 0.6758
#
# Epoch 00038: val_loss did not improve from 1.16684
# Epoch 39/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 1.1618 - accuracy: 0.8994 - val_loss: 1.1662 - val_accuracy: 0.7812
#
# Epoch 00039: val_loss improved from 1.16684 to 1.16619, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.1385 - accuracy: 0.9035 - val_loss: 1.2135 - val_accuracy: 0.7656
#
# Epoch 00040: val_loss did not improve from 1.16619
# Epoch 41/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.1142 - accuracy: 0.9131 - val_loss: 1.3105 - val_accuracy: 0.7500
#
# Epoch 00041: val_loss did not improve from 1.16619
# Epoch 42/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.1811 - accuracy: 0.8948 - val_loss: 1.4994 - val_accuracy: 0.7148
#
# Epoch 00042: val_loss did not improve from 1.16619
# Epoch 43/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.1655 - accuracy: 0.8966 - val_loss: 1.3394 - val_accuracy: 0.7305
#
# Epoch 00043: val_loss did not improve from 1.16619
# Epoch 44/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.9758 - accuracy: 0.9210 - val_loss: 1.1877 - val_accuracy: 0.7773
#
# Epoch 00044: val_loss did not improve from 1.16619
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 45/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.9827 - accuracy: 0.9233 - val_loss: 1.2373 - val_accuracy: 0.7422
#
# Epoch 00045: val_loss did not improve from 1.16619
# Epoch 46/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7568 - accuracy: 0.9453 - val_loss: 1.0702 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss improved from 1.16619 to 1.07022, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.8786 - accuracy: 0.9315 - val_loss: 1.1752 - val_accuracy: 0.7539
#
# Epoch 00047: val_loss did not improve from 1.07022
# Epoch 48/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.7963 - accuracy: 0.9421 - val_loss: 1.1223 - val_accuracy: 0.7812
#
# Epoch 00048: val_loss did not improve from 1.07022
# Epoch 49/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.9565 - accuracy: 0.9150 - val_loss: 1.2371 - val_accuracy: 0.7383
#
# Epoch 00049: val_loss did not improve from 1.07022
# Epoch 50/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.8602 - accuracy: 0.9283 - val_loss: 1.0500 - val_accuracy: 0.7812
#
# Epoch 00050: val_loss improved from 1.07022 to 1.05004, saving model to ./save/cnn_gru_best.hdf5
# Epoch 51/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.7666 - accuracy: 0.9403 - val_loss: 1.0095 - val_accuracy: 0.7773
#
# Epoch 00051: val_loss improved from 1.05004 to 1.00950, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.7512 - accuracy: 0.9393 - val_loss: 1.0918 - val_accuracy: 0.7891
#
# Epoch 00052: val_loss did not improve from 1.00950
# Epoch 53/2000
# 34/34 [==============================] - 7s 206ms/step - loss: 0.7778 - accuracy: 0.9403 - val_loss: 1.0882 - val_accuracy: 0.7695
#
# Epoch 00053: val_loss did not improve from 1.00950
# Epoch 54/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.8042 - accuracy: 0.9343 - val_loss: 1.0618 - val_accuracy: 0.7852
#
# Epoch 00054: val_loss did not improve from 1.00950
# Epoch 55/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7781 - accuracy: 0.9393 - val_loss: 1.0922 - val_accuracy: 0.7578
#
# Epoch 00055: val_loss did not improve from 1.00950
# Epoch 56/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.8553 - accuracy: 0.9237 - val_loss: 1.1446 - val_accuracy: 0.7617
#
# Epoch 00056: val_loss did not improve from 1.00950
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 57/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.6971 - accuracy: 0.9485 - val_loss: 1.0825 - val_accuracy: 0.7773
#
# Epoch 00057: val_loss did not improve from 1.00950
# Epoch 58/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.7434 - accuracy: 0.9449 - val_loss: 1.0223 - val_accuracy: 0.8008
#
# Epoch 00058: val_loss did not improve from 1.00950
# Epoch 59/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.6660 - accuracy: 0.9476 - val_loss: 1.0211 - val_accuracy: 0.7969
#
# Epoch 00059: val_loss did not improve from 1.00950
# Epoch 60/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.7374 - accuracy: 0.9421 - val_loss: 1.0135 - val_accuracy: 0.7969
#
# Epoch 00060: val_loss did not improve from 1.00950
# Epoch 61/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.7003 - accuracy: 0.9485 - val_loss: 1.0301 - val_accuracy: 0.7930
#
# Epoch 00061: val_loss did not improve from 1.00950
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 62/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.6670 - accuracy: 0.9517 - val_loss: 1.0233 - val_accuracy: 0.8047
#
# Epoch 00062: val_loss did not improve from 1.00950
# Epoch 63/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.6042 - accuracy: 0.9605 - val_loss: 1.0482 - val_accuracy: 0.7969
#
# Epoch 00063: val_loss did not improve from 1.00950
# Epoch 64/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.6250 - accuracy: 0.9527 - val_loss: 0.9791 - val_accuracy: 0.8047
#
# Epoch 00064: val_loss improved from 1.00950 to 0.97912, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.5714 - accuracy: 0.9605 - val_loss: 1.0086 - val_accuracy: 0.8008
#
# Epoch 00065: val_loss did not improve from 0.97912
# Epoch 66/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.5706 - accuracy: 0.9568 - val_loss: 1.0310 - val_accuracy: 0.7969
#
# Epoch 00066: val_loss did not improve from 0.97912
# Epoch 67/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.5290 - accuracy: 0.9609 - val_loss: 0.9605 - val_accuracy: 0.8086
#
# Epoch 00067: val_loss improved from 0.97912 to 0.96052, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.5218 - accuracy: 0.9628 - val_loss: 0.9826 - val_accuracy: 0.8203
#
# Epoch 00068: val_loss did not improve from 0.96052
# Epoch 69/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5805 - accuracy: 0.9563 - val_loss: 0.9789 - val_accuracy: 0.8242
#
# Epoch 00069: val_loss did not improve from 0.96052
# Epoch 70/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 0.5893 - accuracy: 0.9499 - val_loss: 1.0123 - val_accuracy: 0.7656
#
# Epoch 00070: val_loss did not improve from 0.96052
# Epoch 71/2000
# 34/34 [==============================] - 7s 206ms/step - loss: 0.5679 - accuracy: 0.9577 - val_loss: 0.9988 - val_accuracy: 0.8047
#
# Epoch 00071: val_loss did not improve from 0.96052
# Epoch 72/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.5415 - accuracy: 0.9609 - val_loss: 1.0176 - val_accuracy: 0.8047
#
# Epoch 00072: val_loss did not improve from 0.96052
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 73/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.5941 - accuracy: 0.9582 - val_loss: 1.0044 - val_accuracy: 0.8008
#
# Epoch 00073: val_loss did not improve from 0.96052
# Epoch 74/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.5539 - accuracy: 0.9596 - val_loss: 1.0152 - val_accuracy: 0.8008
#
# Epoch 00074: val_loss did not improve from 0.96052
# Epoch 75/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4855 - accuracy: 0.9710 - val_loss: 0.9571 - val_accuracy: 0.8203
#
# Epoch 00075: val_loss improved from 0.96052 to 0.95714, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5375 - accuracy: 0.9614 - val_loss: 0.9743 - val_accuracy: 0.8086
#
# Epoch 00076: val_loss did not improve from 0.95714
# Epoch 77/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4925 - accuracy: 0.9678 - val_loss: 1.0179 - val_accuracy: 0.8164
#
# Epoch 00077: val_loss did not improve from 0.95714
# Epoch 78/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.4973 - accuracy: 0.9646 - val_loss: 0.9965 - val_accuracy: 0.8203
#
# Epoch 00078: val_loss did not improve from 0.95714
# Epoch 79/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.5786 - accuracy: 0.9522 - val_loss: 1.0212 - val_accuracy: 0.8047
#
# Epoch 00079: val_loss did not improve from 0.95714
# Epoch 80/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.5475 - accuracy: 0.9596 - val_loss: 0.9823 - val_accuracy: 0.8125
#
# Epoch 00080: val_loss did not improve from 0.95714
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 81/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5081 - accuracy: 0.9646 - val_loss: 0.9665 - val_accuracy: 0.8086
#
# Epoch 00081: val_loss did not improve from 0.95714
# Epoch 82/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.4979 - accuracy: 0.9637 - val_loss: 0.9410 - val_accuracy: 0.8164
#
# Epoch 00082: val_loss improved from 0.95714 to 0.94103, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4239 - accuracy: 0.9729 - val_loss: 0.9890 - val_accuracy: 0.8242
#
# Epoch 00083: val_loss did not improve from 0.94103
# Epoch 84/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4508 - accuracy: 0.9701 - val_loss: 1.0036 - val_accuracy: 0.8164
#
# Epoch 00084: val_loss did not improve from 0.94103
# Epoch 85/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4239 - accuracy: 0.9729 - val_loss: 0.9971 - val_accuracy: 0.8281
#
# Epoch 00085: val_loss did not improve from 0.94103
# Epoch 86/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4102 - accuracy: 0.9706 - val_loss: 0.9954 - val_accuracy: 0.8125
#
# Epoch 00086: val_loss did not improve from 0.94103
# Epoch 87/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.5073 - accuracy: 0.9655 - val_loss: 0.9888 - val_accuracy: 0.8086
#
# Epoch 00087: val_loss did not improve from 0.94103
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 88/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.5309 - accuracy: 0.9554 - val_loss: 1.0205 - val_accuracy: 0.8047
#
# Epoch 00088: val_loss did not improve from 0.94103
# Epoch 89/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4477 - accuracy: 0.9733 - val_loss: 0.9717 - val_accuracy: 0.8086
#
# Epoch 00089: val_loss did not improve from 0.94103
# Epoch 90/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4730 - accuracy: 0.9651 - val_loss: 0.9738 - val_accuracy: 0.8164
#
# Epoch 00090: val_loss did not improve from 0.94103
# Epoch 91/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 0.4996 - accuracy: 0.9632 - val_loss: 0.9934 - val_accuracy: 0.8125
#
# Epoch 00091: val_loss did not improve from 0.94103
# Epoch 92/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4517 - accuracy: 0.9715 - val_loss: 0.9808 - val_accuracy: 0.8164
#
# Epoch 00092: val_loss did not improve from 0.94103
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 93/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4774 - accuracy: 0.9697 - val_loss: 0.9795 - val_accuracy: 0.8281
#
# Epoch 00093: val_loss did not improve from 0.94103
# Epoch 94/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4157 - accuracy: 0.9738 - val_loss: 1.0241 - val_accuracy: 0.8164
#
# Epoch 00094: val_loss did not improve from 0.94103
# Epoch 95/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4292 - accuracy: 0.9733 - val_loss: 0.9903 - val_accuracy: 0.8125
#
# Epoch 00095: val_loss did not improve from 0.94103
# Epoch 96/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4552 - accuracy: 0.9660 - val_loss: 0.9443 - val_accuracy: 0.8242
#
# Epoch 00096: val_loss did not improve from 0.94103
# Epoch 97/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.5048 - accuracy: 0.9637 - val_loss: 1.0189 - val_accuracy: 0.8047
#
# Epoch 00097: val_loss did not improve from 0.94103
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 98/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4372 - accuracy: 0.9715 - val_loss: 0.9589 - val_accuracy: 0.8203
#
# Epoch 00098: val_loss did not improve from 0.94103
# Epoch 99/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4807 - accuracy: 0.9637 - val_loss: 0.9894 - val_accuracy: 0.8164
#
# Epoch 00099: val_loss did not improve from 0.94103
# Epoch 100/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4310 - accuracy: 0.9743 - val_loss: 0.9442 - val_accuracy: 0.8242
#
# Epoch 00100: val_loss did not improve from 0.94103
# Epoch 101/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4240 - accuracy: 0.9761 - val_loss: 1.0278 - val_accuracy: 0.8164
#
# Epoch 00101: val_loss did not improve from 0.94103
# Epoch 102/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 0.4235 - accuracy: 0.9756 - val_loss: 0.9740 - val_accuracy: 0.8242
#
# Epoch 00102: val_loss did not improve from 0.94103
#
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 103/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4733 - accuracy: 0.9646 - val_loss: 0.9854 - val_accuracy: 0.8164
#
# Epoch 00103: val_loss did not improve from 0.94103
# Epoch 104/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4243 - accuracy: 0.9743 - val_loss: 0.9975 - val_accuracy: 0.8203
#
# Epoch 00104: val_loss did not improve from 0.94103
# Epoch 105/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4504 - accuracy: 0.9747 - val_loss: 0.9678 - val_accuracy: 0.8281
#
# Epoch 00105: val_loss did not improve from 0.94103
# Epoch 106/2000
# 34/34 [==============================] - 7s 206ms/step - loss: 0.4297 - accuracy: 0.9674 - val_loss: 0.8966 - val_accuracy: 0.8320
#
# Epoch 00106: val_loss improved from 0.94103 to 0.89659, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4245 - accuracy: 0.9715 - val_loss: 0.9235 - val_accuracy: 0.8281
#
# Epoch 00107: val_loss did not improve from 0.89659
# Epoch 108/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4429 - accuracy: 0.9733 - val_loss: 0.9273 - val_accuracy: 0.8281
#
# Epoch 00108: val_loss did not improve from 0.89659
# Epoch 109/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4488 - accuracy: 0.9697 - val_loss: 0.9340 - val_accuracy: 0.8281
#
# Epoch 00109: val_loss did not improve from 0.89659
# Epoch 110/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4558 - accuracy: 0.9674 - val_loss: 0.9925 - val_accuracy: 0.8203
#
# Epoch 00110: val_loss did not improve from 0.89659
# Epoch 111/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4764 - accuracy: 0.9642 - val_loss: 1.0061 - val_accuracy: 0.8125
#
# Epoch 00111: val_loss did not improve from 0.89659
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 112/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.4212 - accuracy: 0.9761 - val_loss: 1.0215 - val_accuracy: 0.8047
#
# Epoch 00112: val_loss did not improve from 0.89659
# Epoch 113/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4381 - accuracy: 0.9692 - val_loss: 0.9907 - val_accuracy: 0.8164
#
# Epoch 00113: val_loss did not improve from 0.89659
# Epoch 114/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4792 - accuracy: 0.9688 - val_loss: 1.0201 - val_accuracy: 0.8008
#
# Epoch 00114: val_loss did not improve from 0.89659
# Epoch 115/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4473 - accuracy: 0.9665 - val_loss: 0.9743 - val_accuracy: 0.8086
#
# Epoch 00115: val_loss did not improve from 0.89659
# Epoch 116/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 0.4649 - accuracy: 0.9715 - val_loss: 0.9871 - val_accuracy: 0.8281
#
# Epoch 00116: val_loss did not improve from 0.89659
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 117/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4922 - accuracy: 0.9609 - val_loss: 0.9955 - val_accuracy: 0.8203
#
# Epoch 00117: val_loss did not improve from 0.89659
# Epoch 118/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4435 - accuracy: 0.9729 - val_loss: 0.9900 - val_accuracy: 0.8125
#
# Epoch 00118: val_loss did not improve from 0.89659
# Epoch 119/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4825 - accuracy: 0.9628 - val_loss: 1.0288 - val_accuracy: 0.8125
#
# Epoch 00119: val_loss did not improve from 0.89659
# Epoch 120/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4544 - accuracy: 0.9692 - val_loss: 1.0371 - val_accuracy: 0.8008
#
# Epoch 00120: val_loss did not improve from 0.89659
# Epoch 121/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4959 - accuracy: 0.9646 - val_loss: 1.0265 - val_accuracy: 0.8008
#
# Epoch 00121: val_loss did not improve from 0.89659
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 122/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4144 - accuracy: 0.9729 - val_loss: 0.9585 - val_accuracy: 0.8164
#
# Epoch 00122: val_loss did not improve from 0.89659
# Epoch 123/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4726 - accuracy: 0.9665 - val_loss: 0.9937 - val_accuracy: 0.8086
#
# Epoch 00123: val_loss did not improve from 0.89659
# Epoch 124/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4589 - accuracy: 0.9692 - val_loss: 1.0148 - val_accuracy: 0.8086
#
# Epoch 00124: val_loss did not improve from 0.89659
# Epoch 125/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4334 - accuracy: 0.9729 - val_loss: 1.0246 - val_accuracy: 0.8047
#
# Epoch 00125: val_loss did not improve from 0.89659
# Epoch 126/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4500 - accuracy: 0.9683 - val_loss: 1.0102 - val_accuracy: 0.8086
#
# Epoch 00126: val_loss did not improve from 0.89659
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 127/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.5132 - accuracy: 0.9605 - val_loss: 1.0176 - val_accuracy: 0.8008
#
# Epoch 00127: val_loss did not improve from 0.89659
# Epoch 128/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4183 - accuracy: 0.9724 - val_loss: 0.9525 - val_accuracy: 0.8281
#
# Epoch 00128: val_loss did not improve from 0.89659
# Epoch 129/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4410 - accuracy: 0.9706 - val_loss: 1.0288 - val_accuracy: 0.8125
#
# Epoch 00129: val_loss did not improve from 0.89659
# Epoch 130/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.3982 - accuracy: 0.9766 - val_loss: 1.0218 - val_accuracy: 0.8203
#
# Epoch 00130: val_loss did not improve from 0.89659
# Epoch 131/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.4486 - accuracy: 0.9683 - val_loss: 1.0110 - val_accuracy: 0.8125
#
# Epoch 00131: val_loss did not improve from 0.89659
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 132/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 0.4621 - accuracy: 0.9683 - val_loss: 0.9751 - val_accuracy: 0.8203
#
# Epoch 00132: val_loss did not improve from 0.89659
# Epoch 133/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4385 - accuracy: 0.9697 - val_loss: 0.9930 - val_accuracy: 0.8164
#
# Epoch 00133: val_loss did not improve from 0.89659
# Epoch 134/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 0.4498 - accuracy: 0.9683 - val_loss: 0.9984 - val_accuracy: 0.8125
#
# Epoch 00134: val_loss did not improve from 0.89659
# Epoch 135/2000
# 34/34 [==============================] - 7s 208ms/step - loss: 0.4599 - accuracy: 0.9619 - val_loss: 1.0132 - val_accuracy: 0.8047
#
# Epoch 00135: val_loss did not improve from 0.89659
# Epoch 136/2000
# 34/34 [==============================] - 7s 209ms/step - loss: 0.4466 - accuracy: 0.9697 - val_loss: 1.0249 - val_accuracy: 0.8164
#
# Epoch 00136: val_loss did not improve from 0.89659
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7613 - accuracy: 0.8400
# [0.7612767815589905, 0.8399999737739563]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
