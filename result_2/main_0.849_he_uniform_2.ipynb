# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//4, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1450        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1810        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,227,001
# Trainable params: 1,220,761
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 41s 347ms/step - loss: 43.7234 - accuracy: 0.2900 - val_loss: 32.5688 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.56876, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 29.3738 - accuracy: 0.4724 - val_loss: 21.8815 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 32.56876 to 21.88155, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 19.9072 - accuracy: 0.5758 - val_loss: 15.4098 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 21.88155 to 15.40982, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 14.4616 - accuracy: 0.6052 - val_loss: 11.5964 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 15.40982 to 11.59639, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 10.6772 - accuracy: 0.6406 - val_loss: 9.1263 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 11.59639 to 9.12626, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 8.2762 - accuracy: 0.6677 - val_loss: 7.6396 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 9.12626 to 7.63964, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 6.5210 - accuracy: 0.6880 - val_loss: 6.8146 - val_accuracy: 0.3711
#
# Epoch 00007: val_loss improved from 7.63964 to 6.81456, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 5.2504 - accuracy: 0.7339 - val_loss: 6.1938 - val_accuracy: 0.3242
#
# Epoch 00008: val_loss improved from 6.81456 to 6.19383, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 4.4545 - accuracy: 0.7417 - val_loss: 5.8588 - val_accuracy: 0.2070
#
# Epoch 00009: val_loss improved from 6.19383 to 5.85880, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 4.3310 - accuracy: 0.7210 - val_loss: 5.3355 - val_accuracy: 0.3867
#
# Epoch 00010: val_loss improved from 5.85880 to 5.33551, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 3.9982 - accuracy: 0.7210 - val_loss: 5.5116 - val_accuracy: 0.2656
#
# Epoch 00011: val_loss did not improve from 5.33551
# Epoch 12/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 3.6986 - accuracy: 0.7325 - val_loss: 4.4249 - val_accuracy: 0.3789
#
# Epoch 00012: val_loss improved from 5.33551 to 4.42494, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 3.2897 - accuracy: 0.7619 - val_loss: 5.2553 - val_accuracy: 0.2383
#
# Epoch 00013: val_loss did not improve from 4.42494
# Epoch 14/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 3.0699 - accuracy: 0.7601 - val_loss: 4.4899 - val_accuracy: 0.3516
#
# Epoch 00014: val_loss did not improve from 4.42494
# Epoch 15/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 3.0954 - accuracy: 0.7597 - val_loss: 4.2217 - val_accuracy: 0.3867
#
# Epoch 00015: val_loss improved from 4.42494 to 4.22172, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 3.0006 - accuracy: 0.7569 - val_loss: 3.2850 - val_accuracy: 0.4805
#
# Epoch 00016: val_loss improved from 4.22172 to 3.28502, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 3.0665 - accuracy: 0.7551 - val_loss: 2.8954 - val_accuracy: 0.5156
#
# Epoch 00017: val_loss improved from 3.28502 to 2.89538, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.6197 - accuracy: 0.7941 - val_loss: 2.2816 - val_accuracy: 0.6172
#
# Epoch 00018: val_loss improved from 2.89538 to 2.28164, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.4983 - accuracy: 0.7969 - val_loss: 2.0111 - val_accuracy: 0.6328
#
# Epoch 00019: val_loss improved from 2.28164 to 2.01112, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.9613 - accuracy: 0.7486 - val_loss: 2.0162 - val_accuracy: 0.6328
#
# Epoch 00020: val_loss did not improve from 2.01112
# Epoch 21/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 2.6289 - accuracy: 0.7794 - val_loss: 1.9075 - val_accuracy: 0.6641
#
# Epoch 00021: val_loss improved from 2.01112 to 1.90754, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.4785 - accuracy: 0.7937 - val_loss: 1.8726 - val_accuracy: 0.6836
#
# Epoch 00022: val_loss improved from 1.90754 to 1.87256, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.4391 - accuracy: 0.8042 - val_loss: 1.7222 - val_accuracy: 0.6953
#
# Epoch 00023: val_loss improved from 1.87256 to 1.72216, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.4064 - accuracy: 0.8033 - val_loss: 1.5339 - val_accuracy: 0.7422
#
# Epoch 00024: val_loss improved from 1.72216 to 1.53387, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.2798 - accuracy: 0.8120 - val_loss: 1.7448 - val_accuracy: 0.6953
#
# Epoch 00025: val_loss did not improve from 1.53387
# Epoch 26/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.1950 - accuracy: 0.8180 - val_loss: 1.5115 - val_accuracy: 0.7266
#
# Epoch 00026: val_loss improved from 1.53387 to 1.51154, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 2.3151 - accuracy: 0.8015 - val_loss: 1.6643 - val_accuracy: 0.6875
#
# Epoch 00027: val_loss did not improve from 1.51154
# Epoch 28/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.4408 - accuracy: 0.7891 - val_loss: 1.8829 - val_accuracy: 0.6719
#
# Epoch 00028: val_loss did not improve from 1.51154
# Epoch 29/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.3317 - accuracy: 0.7950 - val_loss: 1.5406 - val_accuracy: 0.7383
#
# Epoch 00029: val_loss did not improve from 1.51154
# Epoch 30/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.1144 - accuracy: 0.8290 - val_loss: 2.4240 - val_accuracy: 0.5586
#
# Epoch 00030: val_loss did not improve from 1.51154
# Epoch 31/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.9958 - accuracy: 0.8295 - val_loss: 1.8660 - val_accuracy: 0.6523
#
# Epoch 00031: val_loss did not improve from 1.51154
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.8889 - accuracy: 0.8433 - val_loss: 1.4843 - val_accuracy: 0.6914
#
# Epoch 00032: val_loss improved from 1.51154 to 1.48429, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.7482 - accuracy: 0.8539 - val_loss: 1.3435 - val_accuracy: 0.7461
#
# Epoch 00033: val_loss improved from 1.48429 to 1.34354, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.7039 - accuracy: 0.8543 - val_loss: 1.2691 - val_accuracy: 0.7266
#
# Epoch 00034: val_loss improved from 1.34354 to 1.26910, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.7995 - accuracy: 0.8433 - val_loss: 1.4120 - val_accuracy: 0.6992
#
# Epoch 00035: val_loss did not improve from 1.26910
# Epoch 36/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.7614 - accuracy: 0.8493 - val_loss: 1.2308 - val_accuracy: 0.7461
#
# Epoch 00036: val_loss improved from 1.26910 to 1.23080, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.6927 - accuracy: 0.8594 - val_loss: 1.2394 - val_accuracy: 0.7500
#
# Epoch 00037: val_loss did not improve from 1.23080
# Epoch 38/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.5470 - accuracy: 0.8709 - val_loss: 1.1704 - val_accuracy: 0.7656
#
# Epoch 00038: val_loss improved from 1.23080 to 1.17037, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.5959 - accuracy: 0.8598 - val_loss: 1.2128 - val_accuracy: 0.7461
#
# Epoch 00039: val_loss did not improve from 1.17037
# Epoch 40/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.6824 - accuracy: 0.8502 - val_loss: 1.2955 - val_accuracy: 0.7812
#
# Epoch 00040: val_loss did not improve from 1.17037
# Epoch 41/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.6037 - accuracy: 0.8649 - val_loss: 1.2905 - val_accuracy: 0.7461
#
# Epoch 00041: val_loss did not improve from 1.17037
# Epoch 42/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.6510 - accuracy: 0.8474 - val_loss: 1.3465 - val_accuracy: 0.7109
#
# Epoch 00042: val_loss did not improve from 1.17037
# Epoch 43/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.6467 - accuracy: 0.8575 - val_loss: 1.2165 - val_accuracy: 0.7656
#
# Epoch 00043: val_loss did not improve from 1.17037
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 44/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.2443 - accuracy: 0.9072 - val_loss: 1.1199 - val_accuracy: 0.7930
#
# Epoch 00044: val_loss improved from 1.17037 to 1.11989, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.4899 - accuracy: 0.8755 - val_loss: 1.0787 - val_accuracy: 0.8008
#
# Epoch 00045: val_loss improved from 1.11989 to 1.07870, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.0813 - accuracy: 0.9154 - val_loss: 1.0701 - val_accuracy: 0.7891
#
# Epoch 00046: val_loss improved from 1.07870 to 1.07013, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.3372 - accuracy: 0.8828 - val_loss: 1.0905 - val_accuracy: 0.7695
#
# Epoch 00047: val_loss did not improve from 1.07013
# Epoch 48/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.2065 - accuracy: 0.8961 - val_loss: 1.0425 - val_accuracy: 0.7852
#
# Epoch 00048: val_loss improved from 1.07013 to 1.04247, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.6153 - accuracy: 0.8483 - val_loss: 1.1214 - val_accuracy: 0.7422
#
# Epoch 00049: val_loss did not improve from 1.04247
# Epoch 50/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.4117 - accuracy: 0.8755 - val_loss: 1.0616 - val_accuracy: 0.7812
#
# Epoch 00050: val_loss did not improve from 1.04247
# Epoch 51/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.1619 - accuracy: 0.9053 - val_loss: 1.0057 - val_accuracy: 0.7891
#
# Epoch 00051: val_loss improved from 1.04247 to 1.00566, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.2158 - accuracy: 0.9007 - val_loss: 1.0121 - val_accuracy: 0.8008
#
# Epoch 00052: val_loss did not improve from 1.00566
# Epoch 53/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.1900 - accuracy: 0.9044 - val_loss: 1.0436 - val_accuracy: 0.7891
#
# Epoch 00053: val_loss did not improve from 1.00566
# Epoch 54/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.3388 - accuracy: 0.8791 - val_loss: 1.0831 - val_accuracy: 0.7773
#
# Epoch 00054: val_loss did not improve from 1.00566
# Epoch 55/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.2766 - accuracy: 0.8814 - val_loss: 1.1109 - val_accuracy: 0.7812
#
# Epoch 00055: val_loss did not improve from 1.00566
# Epoch 56/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.2960 - accuracy: 0.8865 - val_loss: 1.0944 - val_accuracy: 0.7695
#
# Epoch 00056: val_loss did not improve from 1.00566
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 57/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.0901 - accuracy: 0.9122 - val_loss: 1.0403 - val_accuracy: 0.8047
#
# Epoch 00057: val_loss did not improve from 1.00566
# Epoch 58/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 1.1863 - accuracy: 0.8975 - val_loss: 0.9894 - val_accuracy: 0.7930
#
# Epoch 00058: val_loss improved from 1.00566 to 0.98935, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 1.0369 - accuracy: 0.9141 - val_loss: 0.9500 - val_accuracy: 0.8086
#
# Epoch 00059: val_loss improved from 0.98935 to 0.95002, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 1.1144 - accuracy: 0.8998 - val_loss: 1.0129 - val_accuracy: 0.7852
#
# Epoch 00060: val_loss did not improve from 0.95002
# Epoch 61/2000
# 34/34 [==============================] - 7s 210ms/step - loss: 1.1550 - accuracy: 0.8952 - val_loss: 0.9573 - val_accuracy: 0.8125
#
# Epoch 00061: val_loss did not improve from 0.95002
# Epoch 62/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.0684 - accuracy: 0.9072 - val_loss: 0.9980 - val_accuracy: 0.7930
#
# Epoch 00062: val_loss did not improve from 0.95002
# Epoch 63/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.0402 - accuracy: 0.9150 - val_loss: 1.0728 - val_accuracy: 0.7969
#
# Epoch 00063: val_loss did not improve from 0.95002
# Epoch 64/2000
# 34/34 [==============================] - 7s 211ms/step - loss: 1.0926 - accuracy: 0.9099 - val_loss: 0.9913 - val_accuracy: 0.7969
#
# Epoch 00064: val_loss did not improve from 0.95002
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 65/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9678 - accuracy: 0.9256 - val_loss: 0.9618 - val_accuracy: 0.7969
#
# Epoch 00065: val_loss did not improve from 0.95002
# Epoch 66/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9798 - accuracy: 0.9210 - val_loss: 0.9837 - val_accuracy: 0.8008
#
# Epoch 00066: val_loss did not improve from 0.95002
# Epoch 67/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 0.8602 - accuracy: 0.9338 - val_loss: 0.9171 - val_accuracy: 0.8320
#
# Epoch 00067: val_loss improved from 0.95002 to 0.91707, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.8899 - accuracy: 0.9334 - val_loss: 0.9663 - val_accuracy: 0.8242
#
# Epoch 00068: val_loss did not improve from 0.91707
# Epoch 69/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.9509 - accuracy: 0.9205 - val_loss: 0.9764 - val_accuracy: 0.7930
#
# Epoch 00069: val_loss did not improve from 0.91707
# Epoch 70/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.0171 - accuracy: 0.9067 - val_loss: 0.9758 - val_accuracy: 0.8008
#
# Epoch 00070: val_loss did not improve from 0.91707
# Epoch 71/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.9846 - accuracy: 0.9182 - val_loss: 0.9773 - val_accuracy: 0.7773
#
# Epoch 00071: val_loss did not improve from 0.91707
# Epoch 72/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9480 - accuracy: 0.9200 - val_loss: 0.9624 - val_accuracy: 0.8047
#
# Epoch 00072: val_loss did not improve from 0.91707
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 73/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.0389 - accuracy: 0.9012 - val_loss: 0.9798 - val_accuracy: 0.8086
#
# Epoch 00073: val_loss did not improve from 0.91707
# Epoch 74/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9453 - accuracy: 0.9177 - val_loss: 0.9809 - val_accuracy: 0.8125
#
# Epoch 00074: val_loss did not improve from 0.91707
# Epoch 75/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8125 - accuracy: 0.9389 - val_loss: 0.9575 - val_accuracy: 0.8125
#
# Epoch 00075: val_loss did not improve from 0.91707
# Epoch 76/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8543 - accuracy: 0.9334 - val_loss: 0.9384 - val_accuracy: 0.8281
#
# Epoch 00076: val_loss did not improve from 0.91707
# Epoch 77/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8143 - accuracy: 0.9315 - val_loss: 0.9616 - val_accuracy: 0.8281
#
# Epoch 00077: val_loss did not improve from 0.91707
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 78/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8481 - accuracy: 0.9274 - val_loss: 0.9434 - val_accuracy: 0.8359
#
# Epoch 00078: val_loss did not improve from 0.91707
# Epoch 79/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.0854 - accuracy: 0.9058 - val_loss: 0.9727 - val_accuracy: 0.8047
#
# Epoch 00079: val_loss did not improve from 0.91707
# Epoch 80/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.9031 - accuracy: 0.9246 - val_loss: 0.9683 - val_accuracy: 0.8008
#
# Epoch 00080: val_loss did not improve from 0.91707
# Epoch 81/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.9045 - accuracy: 0.9278 - val_loss: 0.9374 - val_accuracy: 0.8086
#
# Epoch 00081: val_loss did not improve from 0.91707
# Epoch 82/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.8710 - accuracy: 0.9297 - val_loss: 0.9268 - val_accuracy: 0.8203
#
# Epoch 00082: val_loss did not improve from 0.91707
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 83/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7125 - accuracy: 0.9481 - val_loss: 0.9313 - val_accuracy: 0.8242
#
# Epoch 00083: val_loss did not improve from 0.91707
# Epoch 84/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7750 - accuracy: 0.9435 - val_loss: 0.9641 - val_accuracy: 0.8242
#
# Epoch 00084: val_loss did not improve from 0.91707
# Epoch 85/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7371 - accuracy: 0.9476 - val_loss: 0.9467 - val_accuracy: 0.8320
#
# Epoch 00085: val_loss did not improve from 0.91707
# Epoch 86/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7037 - accuracy: 0.9481 - val_loss: 0.9447 - val_accuracy: 0.8203
#
# Epoch 00086: val_loss did not improve from 0.91707
# Epoch 87/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9860 - accuracy: 0.9095 - val_loss: 0.9419 - val_accuracy: 0.8320
#
# Epoch 00087: val_loss did not improve from 0.91707
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 88/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9334 - accuracy: 0.9187 - val_loss: 0.9612 - val_accuracy: 0.8203
#
# Epoch 00088: val_loss did not improve from 0.91707
# Epoch 89/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.8065 - accuracy: 0.9311 - val_loss: 0.9445 - val_accuracy: 0.8242
#
# Epoch 00089: val_loss did not improve from 0.91707
# Epoch 90/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8171 - accuracy: 0.9366 - val_loss: 0.9350 - val_accuracy: 0.8320
#
# Epoch 00090: val_loss did not improve from 0.91707
# Epoch 91/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8429 - accuracy: 0.9320 - val_loss: 0.9246 - val_accuracy: 0.8281
#
# Epoch 00091: val_loss did not improve from 0.91707
# Epoch 92/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8136 - accuracy: 0.9430 - val_loss: 0.9354 - val_accuracy: 0.8203
#
# Epoch 00092: val_loss did not improve from 0.91707
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 93/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8903 - accuracy: 0.9315 - val_loss: 0.9385 - val_accuracy: 0.8203
#
# Epoch 00093: val_loss did not improve from 0.91707
# Epoch 94/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7418 - accuracy: 0.9453 - val_loss: 0.9502 - val_accuracy: 0.8242
#
# Epoch 00094: val_loss did not improve from 0.91707
# Epoch 95/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7761 - accuracy: 0.9449 - val_loss: 0.9417 - val_accuracy: 0.8125
#
# Epoch 00095: val_loss did not improve from 0.91707
# Epoch 96/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.9065 - accuracy: 0.9233 - val_loss: 0.9128 - val_accuracy: 0.8164
#
# Epoch 00096: val_loss improved from 0.91707 to 0.91283, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.9929 - accuracy: 0.9154 - val_loss: 0.9794 - val_accuracy: 0.8086
#
# Epoch 00097: val_loss did not improve from 0.91283
# Epoch 98/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8413 - accuracy: 0.9315 - val_loss: 0.9358 - val_accuracy: 0.8164
#
# Epoch 00098: val_loss did not improve from 0.91283
# Epoch 99/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.9394 - accuracy: 0.9219 - val_loss: 0.9352 - val_accuracy: 0.8164
#
# Epoch 00099: val_loss did not improve from 0.91283
# Epoch 100/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7477 - accuracy: 0.9389 - val_loss: 0.8903 - val_accuracy: 0.8242
#
# Epoch 00100: val_loss improved from 0.91283 to 0.89032, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7976 - accuracy: 0.9357 - val_loss: 0.9585 - val_accuracy: 0.8086
#
# Epoch 00101: val_loss did not improve from 0.89032
# Epoch 102/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8433 - accuracy: 0.9278 - val_loss: 0.9317 - val_accuracy: 0.8164
#
# Epoch 00102: val_loss did not improve from 0.89032
# Epoch 103/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.9494 - accuracy: 0.9205 - val_loss: 0.9287 - val_accuracy: 0.8242
#
# Epoch 00103: val_loss did not improve from 0.89032
# Epoch 104/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.7525 - accuracy: 0.9476 - val_loss: 0.9246 - val_accuracy: 0.8203
#
# Epoch 00104: val_loss did not improve from 0.89032
# Epoch 105/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8610 - accuracy: 0.9278 - val_loss: 0.9204 - val_accuracy: 0.8203
#
# Epoch 00105: val_loss did not improve from 0.89032
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 106/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8519 - accuracy: 0.9292 - val_loss: 0.8478 - val_accuracy: 0.8320
#
# Epoch 00106: val_loss improved from 0.89032 to 0.84781, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7668 - accuracy: 0.9421 - val_loss: 0.8836 - val_accuracy: 0.8281
#
# Epoch 00107: val_loss did not improve from 0.84781
# Epoch 108/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7975 - accuracy: 0.9407 - val_loss: 0.8663 - val_accuracy: 0.8281
#
# Epoch 00108: val_loss did not improve from 0.84781
# Epoch 109/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8831 - accuracy: 0.9251 - val_loss: 0.8870 - val_accuracy: 0.8242
#
# Epoch 00109: val_loss did not improve from 0.84781
# Epoch 110/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7900 - accuracy: 0.9393 - val_loss: 0.9183 - val_accuracy: 0.8203
#
# Epoch 00110: val_loss did not improve from 0.84781
# Epoch 111/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9656 - accuracy: 0.9164 - val_loss: 0.9509 - val_accuracy: 0.8164
#
# Epoch 00111: val_loss did not improve from 0.84781
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 112/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8156 - accuracy: 0.9380 - val_loss: 0.9576 - val_accuracy: 0.8125
#
# Epoch 00112: val_loss did not improve from 0.84781
# Epoch 113/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8399 - accuracy: 0.9315 - val_loss: 0.9275 - val_accuracy: 0.8164
#
# Epoch 00113: val_loss did not improve from 0.84781
# Epoch 114/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8572 - accuracy: 0.9274 - val_loss: 0.9594 - val_accuracy: 0.8086
#
# Epoch 00114: val_loss did not improve from 0.84781
# Epoch 115/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7895 - accuracy: 0.9380 - val_loss: 0.9295 - val_accuracy: 0.8086
#
# Epoch 00115: val_loss did not improve from 0.84781
# Epoch 116/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7890 - accuracy: 0.9338 - val_loss: 0.9274 - val_accuracy: 0.8164
#
# Epoch 00116: val_loss did not improve from 0.84781
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 117/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8635 - accuracy: 0.9311 - val_loss: 0.9277 - val_accuracy: 0.8164
#
# Epoch 00117: val_loss did not improve from 0.84781
# Epoch 118/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7769 - accuracy: 0.9384 - val_loss: 0.9280 - val_accuracy: 0.8164
#
# Epoch 00118: val_loss did not improve from 0.84781
# Epoch 119/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8796 - accuracy: 0.9283 - val_loss: 0.9686 - val_accuracy: 0.8047
#
# Epoch 00119: val_loss did not improve from 0.84781
# Epoch 120/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.9506 - accuracy: 0.9182 - val_loss: 0.9830 - val_accuracy: 0.8047
#
# Epoch 00120: val_loss did not improve from 0.84781
# Epoch 121/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9179 - accuracy: 0.9214 - val_loss: 0.9576 - val_accuracy: 0.8047
#
# Epoch 00121: val_loss did not improve from 0.84781
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 122/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7619 - accuracy: 0.9412 - val_loss: 0.9152 - val_accuracy: 0.8242
#
# Epoch 00122: val_loss did not improve from 0.84781
# Epoch 123/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8879 - accuracy: 0.9196 - val_loss: 0.9495 - val_accuracy: 0.8203
#
# Epoch 00123: val_loss did not improve from 0.84781
# Epoch 124/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8803 - accuracy: 0.9265 - val_loss: 0.9447 - val_accuracy: 0.8203
#
# Epoch 00124: val_loss did not improve from 0.84781
# Epoch 125/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 0.8769 - accuracy: 0.9256 - val_loss: 0.9795 - val_accuracy: 0.8008
#
# Epoch 00125: val_loss did not improve from 0.84781
# Epoch 126/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8319 - accuracy: 0.9256 - val_loss: 0.9603 - val_accuracy: 0.8125
#
# Epoch 00126: val_loss did not improve from 0.84781
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 127/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.9592 - accuracy: 0.9173 - val_loss: 0.9673 - val_accuracy: 0.8164
#
# Epoch 00127: val_loss did not improve from 0.84781
# Epoch 128/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7464 - accuracy: 0.9430 - val_loss: 0.9163 - val_accuracy: 0.8203
#
# Epoch 00128: val_loss did not improve from 0.84781
# Epoch 129/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8368 - accuracy: 0.9338 - val_loss: 0.9658 - val_accuracy: 0.8086
#
# Epoch 00129: val_loss did not improve from 0.84781
# Epoch 130/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7404 - accuracy: 0.9453 - val_loss: 0.9625 - val_accuracy: 0.8086
#
# Epoch 00130: val_loss did not improve from 0.84781
# Epoch 131/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8690 - accuracy: 0.9306 - val_loss: 0.9458 - val_accuracy: 0.8125
#
# Epoch 00131: val_loss did not improve from 0.84781
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 132/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8517 - accuracy: 0.9265 - val_loss: 0.9332 - val_accuracy: 0.8242
#
# Epoch 00132: val_loss did not improve from 0.84781
# Epoch 133/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8649 - accuracy: 0.9288 - val_loss: 0.9546 - val_accuracy: 0.8125
#
# Epoch 00133: val_loss did not improve from 0.84781
# Epoch 134/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8586 - accuracy: 0.9242 - val_loss: 0.9560 - val_accuracy: 0.8125
#
# Epoch 00134: val_loss did not improve from 0.84781
# Epoch 135/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.8416 - accuracy: 0.9274 - val_loss: 0.9568 - val_accuracy: 0.8047
#
# Epoch 00135: val_loss did not improve from 0.84781
# Epoch 136/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8550 - accuracy: 0.9278 - val_loss: 0.9344 - val_accuracy: 0.8164
#
# Epoch 00136: val_loss did not improve from 0.84781
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7782 - accuracy: 0.8480
# [0.778189480304718, 0.8479999899864197]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
