# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//4, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 11, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1450        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1810        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 60)      32460       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 150, 60)      32460       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,380,601
# Trainable params: 1,373,401
# Non-trainable params: 7,200
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 41s 364ms/step - loss: 50.9021 - accuracy: 0.2877 - val_loss: 37.5748 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 37.57476, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 33.0911 - accuracy: 0.4591 - val_loss: 24.3650 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 37.57476 to 24.36497, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 21.7273 - accuracy: 0.5749 - val_loss: 16.3726 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 24.36497 to 16.37262, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 15.2834 - accuracy: 0.5924 - val_loss: 11.9646 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 16.37262 to 11.96457, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 11.0508 - accuracy: 0.6163 - val_loss: 9.2333 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 11.96457 to 9.23330, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 8.4249 - accuracy: 0.6576 - val_loss: 7.5467 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 9.23330 to 7.54671, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 6.5546 - accuracy: 0.6746 - val_loss: 6.8122 - val_accuracy: 0.4297
#
# Epoch 00007: val_loss improved from 7.54671 to 6.81222, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 5.3207 - accuracy: 0.7178 - val_loss: 5.9750 - val_accuracy: 0.4258
#
# Epoch 00008: val_loss improved from 6.81222 to 5.97502, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 4.4989 - accuracy: 0.7344 - val_loss: 5.2537 - val_accuracy: 0.4375
#
# Epoch 00009: val_loss improved from 5.97502 to 5.25365, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 4.3270 - accuracy: 0.7192 - val_loss: 5.5212 - val_accuracy: 0.4102
#
# Epoch 00010: val_loss did not improve from 5.25365
# Epoch 11/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 3.9635 - accuracy: 0.7220 - val_loss: 4.9961 - val_accuracy: 0.4688
#
# Epoch 00011: val_loss improved from 5.25365 to 4.99614, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 3.7278 - accuracy: 0.7210 - val_loss: 4.2854 - val_accuracy: 0.4727
#
# Epoch 00012: val_loss improved from 4.99614 to 4.28536, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 3.3701 - accuracy: 0.7587 - val_loss: 4.3184 - val_accuracy: 0.3633
#
# Epoch 00013: val_loss did not improve from 4.28536
# Epoch 14/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 3.1270 - accuracy: 0.7587 - val_loss: 4.3188 - val_accuracy: 0.3438
#
# Epoch 00014: val_loss did not improve from 4.28536
# Epoch 15/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 3.1402 - accuracy: 0.7601 - val_loss: 4.5396 - val_accuracy: 0.3359
#
# Epoch 00015: val_loss did not improve from 4.28536
# Epoch 16/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 3.0733 - accuracy: 0.7518 - val_loss: 3.0520 - val_accuracy: 0.5195
#
# Epoch 00016: val_loss improved from 4.28536 to 3.05195, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 3.0801 - accuracy: 0.7505 - val_loss: 2.8938 - val_accuracy: 0.5508
#
# Epoch 00017: val_loss improved from 3.05195 to 2.89381, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 2.6558 - accuracy: 0.7840 - val_loss: 2.3287 - val_accuracy: 0.6133
#
# Epoch 00018: val_loss improved from 2.89381 to 2.32875, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 2.6276 - accuracy: 0.7817 - val_loss: 2.1155 - val_accuracy: 0.6406
#
# Epoch 00019: val_loss improved from 2.32875 to 2.11546, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 2.9792 - accuracy: 0.7505 - val_loss: 2.1718 - val_accuracy: 0.5977
#
# Epoch 00020: val_loss did not improve from 2.11546
# Epoch 21/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 2.7003 - accuracy: 0.7725 - val_loss: 2.1260 - val_accuracy: 0.6367
#
# Epoch 00021: val_loss did not improve from 2.11546
# Epoch 22/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 2.6073 - accuracy: 0.7817 - val_loss: 1.6665 - val_accuracy: 0.7266
#
# Epoch 00022: val_loss improved from 2.11546 to 1.66652, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 2.4793 - accuracy: 0.7969 - val_loss: 1.7231 - val_accuracy: 0.7148
#
# Epoch 00023: val_loss did not improve from 1.66652
# Epoch 24/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 2.4261 - accuracy: 0.8074 - val_loss: 1.5545 - val_accuracy: 0.7461
#
# Epoch 00024: val_loss improved from 1.66652 to 1.55450, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 2.3211 - accuracy: 0.8070 - val_loss: 1.9367 - val_accuracy: 0.6328
#
# Epoch 00025: val_loss did not improve from 1.55450
# Epoch 26/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 2.2676 - accuracy: 0.8047 - val_loss: 2.0590 - val_accuracy: 0.6094
#
# Epoch 00026: val_loss did not improve from 1.55450
# Epoch 27/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 2.4116 - accuracy: 0.7950 - val_loss: 1.7998 - val_accuracy: 0.6680
#
# Epoch 00027: val_loss did not improve from 1.55450
# Epoch 28/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 2.5800 - accuracy: 0.7803 - val_loss: 1.9632 - val_accuracy: 0.6484
#
# Epoch 00028: val_loss did not improve from 1.55450
# Epoch 29/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 2.4915 - accuracy: 0.7904 - val_loss: 1.7744 - val_accuracy: 0.6445
#
# Epoch 00029: val_loss did not improve from 1.55450
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 30/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 2.0381 - accuracy: 0.8465 - val_loss: 1.6030 - val_accuracy: 0.6758
#
# Epoch 00030: val_loss did not improve from 1.55450
# Epoch 31/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.8466 - accuracy: 0.8451 - val_loss: 1.4354 - val_accuracy: 0.7031
#
# Epoch 00031: val_loss improved from 1.55450 to 1.43537, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.8051 - accuracy: 0.8474 - val_loss: 1.5118 - val_accuracy: 0.7031
#
# Epoch 00032: val_loss did not improve from 1.43537
# Epoch 33/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.7610 - accuracy: 0.8525 - val_loss: 1.3742 - val_accuracy: 0.7422
#
# Epoch 00033: val_loss improved from 1.43537 to 1.37420, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.7684 - accuracy: 0.8410 - val_loss: 1.2935 - val_accuracy: 0.7500
#
# Epoch 00034: val_loss improved from 1.37420 to 1.29353, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.9046 - accuracy: 0.8332 - val_loss: 1.5253 - val_accuracy: 0.7031
#
# Epoch 00035: val_loss did not improve from 1.29353
# Epoch 36/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.7976 - accuracy: 0.8428 - val_loss: 1.3139 - val_accuracy: 0.7188
#
# Epoch 00036: val_loss did not improve from 1.29353
# Epoch 37/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.7490 - accuracy: 0.8543 - val_loss: 1.2591 - val_accuracy: 0.7734
#
# Epoch 00037: val_loss improved from 1.29353 to 1.25912, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.5979 - accuracy: 0.8649 - val_loss: 1.2904 - val_accuracy: 0.7539
#
# Epoch 00038: val_loss did not improve from 1.25912
# Epoch 39/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.7155 - accuracy: 0.8488 - val_loss: 1.2860 - val_accuracy: 0.7383
#
# Epoch 00039: val_loss did not improve from 1.25912
# Epoch 40/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.7197 - accuracy: 0.8465 - val_loss: 1.2043 - val_accuracy: 0.7539
#
# Epoch 00040: val_loss improved from 1.25912 to 1.20432, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.6462 - accuracy: 0.8552 - val_loss: 1.2387 - val_accuracy: 0.7539
#
# Epoch 00041: val_loss did not improve from 1.20432
# Epoch 42/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.7307 - accuracy: 0.8433 - val_loss: 1.3816 - val_accuracy: 0.7070
#
# Epoch 00042: val_loss did not improve from 1.20432
# Epoch 43/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.7371 - accuracy: 0.8470 - val_loss: 1.4048 - val_accuracy: 0.7148
#
# Epoch 00043: val_loss did not improve from 1.20432
# Epoch 44/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.3975 - accuracy: 0.8847 - val_loss: 1.2607 - val_accuracy: 0.7461
#
# Epoch 00044: val_loss did not improve from 1.20432
# Epoch 45/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.7590 - accuracy: 0.8438 - val_loss: 1.2285 - val_accuracy: 0.7656
#
# Epoch 00045: val_loss did not improve from 1.20432
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 46/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.2271 - accuracy: 0.8980 - val_loss: 1.2025 - val_accuracy: 0.7695
#
# Epoch 00046: val_loss improved from 1.20432 to 1.20249, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.3942 - accuracy: 0.8837 - val_loss: 1.2200 - val_accuracy: 0.7305
#
# Epoch 00047: val_loss did not improve from 1.20249
# Epoch 48/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.2808 - accuracy: 0.8943 - val_loss: 1.1433 - val_accuracy: 0.7539
#
# Epoch 00048: val_loss improved from 1.20249 to 1.14332, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.6967 - accuracy: 0.8456 - val_loss: 1.3230 - val_accuracy: 0.7383
#
# Epoch 00049: val_loss did not improve from 1.14332
# Epoch 50/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.5108 - accuracy: 0.8649 - val_loss: 1.1213 - val_accuracy: 0.7734
#
# Epoch 00050: val_loss improved from 1.14332 to 1.12125, saving model to ./save/cnn_gru_best.hdf5
# Epoch 51/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.2357 - accuracy: 0.8934 - val_loss: 1.1069 - val_accuracy: 0.7578
#
# Epoch 00051: val_loss improved from 1.12125 to 1.10691, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.2500 - accuracy: 0.9003 - val_loss: 1.1814 - val_accuracy: 0.7617
#
# Epoch 00052: val_loss did not improve from 1.10691
# Epoch 53/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.2203 - accuracy: 0.8911 - val_loss: 1.2103 - val_accuracy: 0.7500
#
# Epoch 00053: val_loss did not improve from 1.10691
# Epoch 54/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.4205 - accuracy: 0.8773 - val_loss: 1.0629 - val_accuracy: 0.8203
#
# Epoch 00054: val_loss improved from 1.10691 to 1.06286, saving model to ./save/cnn_gru_best.hdf5
# Epoch 55/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.3181 - accuracy: 0.8810 - val_loss: 1.0789 - val_accuracy: 0.7773
#
# Epoch 00055: val_loss did not improve from 1.06286
# Epoch 56/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.3484 - accuracy: 0.8851 - val_loss: 1.1481 - val_accuracy: 0.7656
#
# Epoch 00056: val_loss did not improve from 1.06286
# Epoch 57/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.2065 - accuracy: 0.8948 - val_loss: 1.1415 - val_accuracy: 0.7852
#
# Epoch 00057: val_loss did not improve from 1.06286
# Epoch 58/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.3463 - accuracy: 0.8791 - val_loss: 1.0444 - val_accuracy: 0.7773
#
# Epoch 00058: val_loss improved from 1.06286 to 1.04445, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.2039 - accuracy: 0.8998 - val_loss: 0.9715 - val_accuracy: 0.7930
#
# Epoch 00059: val_loss improved from 1.04445 to 0.97146, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.2390 - accuracy: 0.8874 - val_loss: 1.0570 - val_accuracy: 0.7773
#
# Epoch 00060: val_loss did not improve from 0.97146
# Epoch 61/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.2831 - accuracy: 0.8847 - val_loss: 1.0769 - val_accuracy: 0.8008
#
# Epoch 00061: val_loss did not improve from 0.97146
# Epoch 62/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.2561 - accuracy: 0.8869 - val_loss: 1.0697 - val_accuracy: 0.7852
#
# Epoch 00062: val_loss did not improve from 0.97146
# Epoch 63/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.1608 - accuracy: 0.9062 - val_loss: 1.2199 - val_accuracy: 0.7578
#
# Epoch 00063: val_loss did not improve from 0.97146
# Epoch 64/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 1.2523 - accuracy: 0.8915 - val_loss: 1.1292 - val_accuracy: 0.7500
#
# Epoch 00064: val_loss did not improve from 0.97146
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 65/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.0601 - accuracy: 0.9122 - val_loss: 1.0375 - val_accuracy: 0.7773
#
# Epoch 00065: val_loss did not improve from 0.97146
# Epoch 66/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.0974 - accuracy: 0.9058 - val_loss: 1.0286 - val_accuracy: 0.7812
#
# Epoch 00066: val_loss did not improve from 0.97146
# Epoch 67/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 0.9482 - accuracy: 0.9246 - val_loss: 0.9754 - val_accuracy: 0.7969
#
# Epoch 00067: val_loss did not improve from 0.97146
# Epoch 68/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.9943 - accuracy: 0.9182 - val_loss: 1.0554 - val_accuracy: 0.7773
#
# Epoch 00068: val_loss did not improve from 0.97146
# Epoch 69/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.0488 - accuracy: 0.9122 - val_loss: 0.9976 - val_accuracy: 0.7891
#
# Epoch 00069: val_loss did not improve from 0.97146
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 70/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.0747 - accuracy: 0.9067 - val_loss: 1.0008 - val_accuracy: 0.7852
#
# Epoch 00070: val_loss did not improve from 0.97146
# Epoch 71/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 1.0287 - accuracy: 0.9131 - val_loss: 0.9819 - val_accuracy: 0.7969
#
# Epoch 00071: val_loss did not improve from 0.97146
# Epoch 72/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.9906 - accuracy: 0.9182 - val_loss: 0.9915 - val_accuracy: 0.8047
#
# Epoch 00072: val_loss did not improve from 0.97146
# Epoch 73/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 1.0602 - accuracy: 0.9040 - val_loss: 0.9874 - val_accuracy: 0.7930
#
# Epoch 00073: val_loss did not improve from 0.97146
# Epoch 74/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 1.0169 - accuracy: 0.9108 - val_loss: 0.9767 - val_accuracy: 0.8203
#
# Epoch 00074: val_loss did not improve from 0.97146
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 75/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8351 - accuracy: 0.9361 - val_loss: 0.9419 - val_accuracy: 0.8281
#
# Epoch 00075: val_loss improved from 0.97146 to 0.94194, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8775 - accuracy: 0.9292 - val_loss: 0.9299 - val_accuracy: 0.8125
#
# Epoch 00076: val_loss improved from 0.94194 to 0.92987, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8414 - accuracy: 0.9311 - val_loss: 0.9483 - val_accuracy: 0.8281
#
# Epoch 00077: val_loss did not improve from 0.92987
# Epoch 78/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.9177 - accuracy: 0.9200 - val_loss: 0.9337 - val_accuracy: 0.8047
#
# Epoch 00078: val_loss did not improve from 0.92987
# Epoch 79/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 1.1179 - accuracy: 0.8989 - val_loss: 0.9561 - val_accuracy: 0.8008
#
# Epoch 00079: val_loss did not improve from 0.92987
# Epoch 80/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.9317 - accuracy: 0.9251 - val_loss: 0.9657 - val_accuracy: 0.8125
#
# Epoch 00080: val_loss did not improve from 0.92987
# Epoch 81/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.9394 - accuracy: 0.9205 - val_loss: 0.9353 - val_accuracy: 0.8125
#
# Epoch 00081: val_loss did not improve from 0.92987
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 82/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.8666 - accuracy: 0.9292 - val_loss: 0.9170 - val_accuracy: 0.8008
#
# Epoch 00082: val_loss improved from 0.92987 to 0.91700, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.7775 - accuracy: 0.9467 - val_loss: 0.9387 - val_accuracy: 0.8086
#
# Epoch 00083: val_loss did not improve from 0.91700
# Epoch 84/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.7817 - accuracy: 0.9449 - val_loss: 0.9578 - val_accuracy: 0.8047
#
# Epoch 00084: val_loss did not improve from 0.91700
# Epoch 85/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.7613 - accuracy: 0.9439 - val_loss: 0.9378 - val_accuracy: 0.8164
#
# Epoch 00085: val_loss did not improve from 0.91700
# Epoch 86/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.7052 - accuracy: 0.9481 - val_loss: 0.9297 - val_accuracy: 0.8125
#
# Epoch 00086: val_loss did not improve from 0.91700
# Epoch 87/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 0.9846 - accuracy: 0.9168 - val_loss: 0.9425 - val_accuracy: 0.8086
#
# Epoch 00087: val_loss did not improve from 0.91700
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 88/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9292 - accuracy: 0.9219 - val_loss: 0.9558 - val_accuracy: 0.8086
#
# Epoch 00088: val_loss did not improve from 0.91700
# Epoch 89/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8180 - accuracy: 0.9347 - val_loss: 0.9295 - val_accuracy: 0.8164
#
# Epoch 00089: val_loss did not improve from 0.91700
# Epoch 90/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8213 - accuracy: 0.9361 - val_loss: 0.9342 - val_accuracy: 0.8281
#
# Epoch 00090: val_loss did not improve from 0.91700
# Epoch 91/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8671 - accuracy: 0.9251 - val_loss: 0.9304 - val_accuracy: 0.8203
#
# Epoch 00091: val_loss did not improve from 0.91700
# Epoch 92/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8201 - accuracy: 0.9439 - val_loss: 0.9402 - val_accuracy: 0.8047
#
# Epoch 00092: val_loss did not improve from 0.91700
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 93/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9286 - accuracy: 0.9292 - val_loss: 0.9321 - val_accuracy: 0.8164
#
# Epoch 00093: val_loss did not improve from 0.91700
# Epoch 94/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.7522 - accuracy: 0.9467 - val_loss: 0.9538 - val_accuracy: 0.8125
#
# Epoch 00094: val_loss did not improve from 0.91700
# Epoch 95/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.7948 - accuracy: 0.9421 - val_loss: 0.9400 - val_accuracy: 0.8125
#
# Epoch 00095: val_loss did not improve from 0.91700
# Epoch 96/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8979 - accuracy: 0.9233 - val_loss: 0.9088 - val_accuracy: 0.8164
#
# Epoch 00096: val_loss improved from 0.91700 to 0.90884, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.0162 - accuracy: 0.9141 - val_loss: 0.9644 - val_accuracy: 0.8125
#
# Epoch 00097: val_loss did not improve from 0.90884
# Epoch 98/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8111 - accuracy: 0.9444 - val_loss: 0.9242 - val_accuracy: 0.8164
#
# Epoch 00098: val_loss did not improve from 0.90884
# Epoch 99/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.9198 - accuracy: 0.9223 - val_loss: 0.9288 - val_accuracy: 0.8086
#
# Epoch 00099: val_loss did not improve from 0.90884
# Epoch 100/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.7476 - accuracy: 0.9462 - val_loss: 0.8946 - val_accuracy: 0.8164
#
# Epoch 00100: val_loss improved from 0.90884 to 0.89461, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.7851 - accuracy: 0.9430 - val_loss: 0.9515 - val_accuracy: 0.8047
#
# Epoch 00101: val_loss did not improve from 0.89461
# Epoch 102/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8532 - accuracy: 0.9278 - val_loss: 0.9285 - val_accuracy: 0.8203
#
# Epoch 00102: val_loss did not improve from 0.89461
# Epoch 103/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.9601 - accuracy: 0.9182 - val_loss: 0.9205 - val_accuracy: 0.8203
#
# Epoch 00103: val_loss did not improve from 0.89461
# Epoch 104/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.7534 - accuracy: 0.9435 - val_loss: 0.9208 - val_accuracy: 0.8164
#
# Epoch 00104: val_loss did not improve from 0.89461
# Epoch 105/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.8349 - accuracy: 0.9366 - val_loss: 0.9122 - val_accuracy: 0.8203
#
# Epoch 00105: val_loss did not improve from 0.89461
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 106/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8386 - accuracy: 0.9352 - val_loss: 0.8495 - val_accuracy: 0.8320
#
# Epoch 00106: val_loss improved from 0.89461 to 0.84947, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.7721 - accuracy: 0.9458 - val_loss: 0.8838 - val_accuracy: 0.8281
#
# Epoch 00107: val_loss did not improve from 0.84947
# Epoch 108/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.7978 - accuracy: 0.9398 - val_loss: 0.8703 - val_accuracy: 0.8281
#
# Epoch 00108: val_loss did not improve from 0.84947
# Epoch 109/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8926 - accuracy: 0.9301 - val_loss: 0.8836 - val_accuracy: 0.8320
#
# Epoch 00109: val_loss did not improve from 0.84947
# Epoch 110/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.7715 - accuracy: 0.9393 - val_loss: 0.9145 - val_accuracy: 0.8242
#
# Epoch 00110: val_loss did not improve from 0.84947
# Epoch 111/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 1.0027 - accuracy: 0.9127 - val_loss: 0.9395 - val_accuracy: 0.8164
#
# Epoch 00111: val_loss did not improve from 0.84947
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 112/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8156 - accuracy: 0.9393 - val_loss: 0.9510 - val_accuracy: 0.8164
#
# Epoch 00112: val_loss did not improve from 0.84947
# Epoch 113/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8199 - accuracy: 0.9347 - val_loss: 0.9114 - val_accuracy: 0.8242
#
# Epoch 00113: val_loss did not improve from 0.84947
# Epoch 114/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8698 - accuracy: 0.9352 - val_loss: 0.9457 - val_accuracy: 0.8164
#
# Epoch 00114: val_loss did not improve from 0.84947
# Epoch 115/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.7495 - accuracy: 0.9499 - val_loss: 0.9209 - val_accuracy: 0.8164
#
# Epoch 00115: val_loss did not improve from 0.84947
# Epoch 116/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8037 - accuracy: 0.9324 - val_loss: 0.9265 - val_accuracy: 0.8203
#
# Epoch 00116: val_loss did not improve from 0.84947
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 117/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.8680 - accuracy: 0.9256 - val_loss: 0.9242 - val_accuracy: 0.8164
#
# Epoch 00117: val_loss did not improve from 0.84947
# Epoch 118/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.7607 - accuracy: 0.9421 - val_loss: 0.9210 - val_accuracy: 0.8242
#
# Epoch 00118: val_loss did not improve from 0.84947
# Epoch 119/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.8699 - accuracy: 0.9251 - val_loss: 0.9598 - val_accuracy: 0.8125
#
# Epoch 00119: val_loss did not improve from 0.84947
# Epoch 120/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.9210 - accuracy: 0.9269 - val_loss: 0.9681 - val_accuracy: 0.8164
#
# Epoch 00120: val_loss did not improve from 0.84947
# Epoch 121/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.9175 - accuracy: 0.9233 - val_loss: 0.9442 - val_accuracy: 0.8086
#
# Epoch 00121: val_loss did not improve from 0.84947
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 122/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.7230 - accuracy: 0.9467 - val_loss: 0.9036 - val_accuracy: 0.8242
#
# Epoch 00122: val_loss did not improve from 0.84947
# Epoch 123/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8679 - accuracy: 0.9219 - val_loss: 0.9375 - val_accuracy: 0.8203
#
# Epoch 00123: val_loss did not improve from 0.84947
# Epoch 124/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8762 - accuracy: 0.9283 - val_loss: 0.9397 - val_accuracy: 0.8164
#
# Epoch 00124: val_loss did not improve from 0.84947
# Epoch 125/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 0.8397 - accuracy: 0.9283 - val_loss: 0.9504 - val_accuracy: 0.8203
#
# Epoch 00125: val_loss did not improve from 0.84947
# Epoch 126/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8242 - accuracy: 0.9324 - val_loss: 0.9547 - val_accuracy: 0.8125
#
# Epoch 00126: val_loss did not improve from 0.84947
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 127/2000
# 34/34 [==============================] - 8s 224ms/step - loss: 0.9562 - accuracy: 0.9159 - val_loss: 0.9522 - val_accuracy: 0.8164
#
# Epoch 00127: val_loss did not improve from 0.84947
# Epoch 128/2000
# 34/34 [==============================] - 8s 228ms/step - loss: 0.7397 - accuracy: 0.9416 - val_loss: 0.9048 - val_accuracy: 0.8281
#
# Epoch 00128: val_loss did not improve from 0.84947
# Epoch 129/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8557 - accuracy: 0.9283 - val_loss: 0.9613 - val_accuracy: 0.8086
#
# Epoch 00129: val_loss did not improve from 0.84947
# Epoch 130/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.7547 - accuracy: 0.9389 - val_loss: 0.9572 - val_accuracy: 0.8125
#
# Epoch 00130: val_loss did not improve from 0.84947
# Epoch 131/2000
# 34/34 [==============================] - 8s 225ms/step - loss: 0.8672 - accuracy: 0.9278 - val_loss: 0.9393 - val_accuracy: 0.8242
#
# Epoch 00131: val_loss did not improve from 0.84947
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 132/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8449 - accuracy: 0.9288 - val_loss: 0.9217 - val_accuracy: 0.8242
#
# Epoch 00132: val_loss did not improve from 0.84947
# Epoch 133/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8493 - accuracy: 0.9297 - val_loss: 0.9410 - val_accuracy: 0.8164
#
# Epoch 00133: val_loss did not improve from 0.84947
# Epoch 134/2000
# 34/34 [==============================] - 8s 226ms/step - loss: 0.8386 - accuracy: 0.9343 - val_loss: 0.9385 - val_accuracy: 0.8164
#
# Epoch 00134: val_loss did not improve from 0.84947
# Epoch 135/2000
# 34/34 [==============================] - 8s 227ms/step - loss: 0.8635 - accuracy: 0.9228 - val_loss: 0.9401 - val_accuracy: 0.8164
#
# Epoch 00135: val_loss did not improve from 0.84947
# Epoch 136/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.8386 - accuracy: 0.9315 - val_loss: 0.9252 - val_accuracy: 0.8242
#
# Epoch 00136: val_loss did not improve from 0.84947
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7587 - accuracy: 0.8544
# [0.7586825489997864, 0.8543999791145325]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
