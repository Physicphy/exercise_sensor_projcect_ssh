# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=BATCH_SIZE//4, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3, # #3#
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1450        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      730         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      730         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1810        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      3660        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 150, 360)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 120)     480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 60)      194460      concatenate_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_26[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 120)     480         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_29[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 120)     480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_32[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_35[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_38[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_41[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_44[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 120)     480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_47[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,227,001
# Trainable params: 1,220,761
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=30,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 45s 340ms/step - loss: 43.7232 - accuracy: 0.2891 - val_loss: 32.5697 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.56974, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 29.3747 - accuracy: 0.4747 - val_loss: 21.8846 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 32.56974 to 21.88461, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 19.9116 - accuracy: 0.5722 - val_loss: 15.4278 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 21.88461 to 15.42780, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 212ms/step - loss: 14.4674 - accuracy: 0.6029 - val_loss: 11.5855 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 15.42780 to 11.58545, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 10.6810 - accuracy: 0.6273 - val_loss: 9.0886 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 11.58545 to 9.08859, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 8.2827 - accuracy: 0.6654 - val_loss: 7.5898 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 9.08859 to 7.58983, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 6.5133 - accuracy: 0.6912 - val_loss: 6.7340 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 7.58983 to 6.73399, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 5.2603 - accuracy: 0.7367 - val_loss: 6.0723 - val_accuracy: 0.4453
#
# Epoch 00008: val_loss improved from 6.73399 to 6.07231, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 4.4607 - accuracy: 0.7394 - val_loss: 5.9799 - val_accuracy: 0.1641
#
# Epoch 00009: val_loss improved from 6.07231 to 5.97989, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 4.3177 - accuracy: 0.7284 - val_loss: 5.4946 - val_accuracy: 0.2656
#
# Epoch 00010: val_loss improved from 5.97989 to 5.49458, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 3.9784 - accuracy: 0.7298 - val_loss: 5.9698 - val_accuracy: 0.1094
#
# Epoch 00011: val_loss did not improve from 5.49458
# Epoch 12/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 3.7167 - accuracy: 0.7312 - val_loss: 4.0800 - val_accuracy: 0.4766
#
# Epoch 00012: val_loss improved from 5.49458 to 4.07996, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 3.2953 - accuracy: 0.7587 - val_loss: 4.3669 - val_accuracy: 0.4219
#
# Epoch 00013: val_loss did not improve from 4.07996
# Epoch 14/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 3.0506 - accuracy: 0.7638 - val_loss: 4.1952 - val_accuracy: 0.4609
#
# Epoch 00014: val_loss did not improve from 4.07996
# Epoch 15/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 3.0806 - accuracy: 0.7647 - val_loss: 3.9335 - val_accuracy: 0.4414
#
# Epoch 00015: val_loss improved from 4.07996 to 3.93353, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.9871 - accuracy: 0.7578 - val_loss: 3.2067 - val_accuracy: 0.5352
#
# Epoch 00016: val_loss improved from 3.93353 to 3.20672, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 3.0375 - accuracy: 0.7532 - val_loss: 3.1099 - val_accuracy: 0.5078
#
# Epoch 00017: val_loss improved from 3.20672 to 3.10986, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.6654 - accuracy: 0.7872 - val_loss: 2.4147 - val_accuracy: 0.6172
#
# Epoch 00018: val_loss improved from 3.10986 to 2.41471, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.5077 - accuracy: 0.8042 - val_loss: 1.9968 - val_accuracy: 0.6523
#
# Epoch 00019: val_loss improved from 2.41471 to 1.99680, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.9344 - accuracy: 0.7482 - val_loss: 2.0795 - val_accuracy: 0.6602
#
# Epoch 00020: val_loss did not improve from 1.99680
# Epoch 21/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.6108 - accuracy: 0.7762 - val_loss: 1.9074 - val_accuracy: 0.6836
#
# Epoch 00021: val_loss improved from 1.99680 to 1.90735, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 2.4713 - accuracy: 0.7932 - val_loss: 1.7157 - val_accuracy: 0.6875
#
# Epoch 00022: val_loss improved from 1.90735 to 1.71575, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.4243 - accuracy: 0.8015 - val_loss: 1.6356 - val_accuracy: 0.7422
#
# Epoch 00023: val_loss improved from 1.71575 to 1.63559, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.3761 - accuracy: 0.8056 - val_loss: 1.7227 - val_accuracy: 0.6992
#
# Epoch 00024: val_loss did not improve from 1.63559
# Epoch 25/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 2.3046 - accuracy: 0.8084 - val_loss: 1.6625 - val_accuracy: 0.7070
#
# Epoch 00025: val_loss did not improve from 1.63559
# Epoch 26/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 2.2057 - accuracy: 0.8153 - val_loss: 1.5521 - val_accuracy: 0.7461
#
# Epoch 00026: val_loss improved from 1.63559 to 1.55207, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.2840 - accuracy: 0.8162 - val_loss: 1.6166 - val_accuracy: 0.6992
#
# Epoch 00027: val_loss did not improve from 1.55207
# Epoch 28/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.4352 - accuracy: 0.7886 - val_loss: 1.5599 - val_accuracy: 0.7266
#
# Epoch 00028: val_loss did not improve from 1.55207
# Epoch 29/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.3461 - accuracy: 0.7886 - val_loss: 1.4811 - val_accuracy: 0.7578
#
# Epoch 00029: val_loss improved from 1.55207 to 1.48111, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.1004 - accuracy: 0.8263 - val_loss: 1.8501 - val_accuracy: 0.6328
#
# Epoch 00030: val_loss did not improve from 1.48111
# Epoch 31/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.0000 - accuracy: 0.8355 - val_loss: 1.8780 - val_accuracy: 0.6523
#
# Epoch 00031: val_loss did not improve from 1.48111
# Epoch 32/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.0895 - accuracy: 0.8162 - val_loss: 2.6809 - val_accuracy: 0.4492
#
# Epoch 00032: val_loss did not improve from 1.48111
# Epoch 33/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 2.0589 - accuracy: 0.8272 - val_loss: 2.2827 - val_accuracy: 0.5703
#
# Epoch 00033: val_loss did not improve from 1.48111
# Epoch 34/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.9742 - accuracy: 0.8332 - val_loss: 1.3422 - val_accuracy: 0.7656
#
# Epoch 00034: val_loss improved from 1.48111 to 1.34224, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 2.0764 - accuracy: 0.8281 - val_loss: 2.1015 - val_accuracy: 0.5273
#
# Epoch 00035: val_loss did not improve from 1.34224
# Epoch 36/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 2.0562 - accuracy: 0.8208 - val_loss: 1.5754 - val_accuracy: 0.6758
#
# Epoch 00036: val_loss did not improve from 1.34224
# Epoch 37/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.9541 - accuracy: 0.8359 - val_loss: 2.0969 - val_accuracy: 0.6055
#
# Epoch 00037: val_loss did not improve from 1.34224
# Epoch 38/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.8625 - accuracy: 0.8493 - val_loss: 1.5520 - val_accuracy: 0.6953
#
# Epoch 00038: val_loss did not improve from 1.34224
# Epoch 39/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.9167 - accuracy: 0.8318 - val_loss: 1.7164 - val_accuracy: 0.7031
#
# Epoch 00039: val_loss did not improve from 1.34224
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 40/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.7443 - accuracy: 0.8598 - val_loss: 1.3242 - val_accuracy: 0.7773
#
# Epoch 00040: val_loss improved from 1.34224 to 1.32419, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.5830 - accuracy: 0.8690 - val_loss: 1.3873 - val_accuracy: 0.7617
#
# Epoch 00041: val_loss did not improve from 1.32419
# Epoch 42/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.6169 - accuracy: 0.8562 - val_loss: 1.3197 - val_accuracy: 0.7109
#
# Epoch 00042: val_loss improved from 1.32419 to 1.31973, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.6504 - accuracy: 0.8589 - val_loss: 1.4696 - val_accuracy: 0.7070
#
# Epoch 00043: val_loss did not improve from 1.31973
# Epoch 44/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.2699 - accuracy: 0.9021 - val_loss: 1.2348 - val_accuracy: 0.7578
#
# Epoch 00044: val_loss improved from 1.31973 to 1.23479, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.6329 - accuracy: 0.8552 - val_loss: 1.2449 - val_accuracy: 0.7695
#
# Epoch 00045: val_loss did not improve from 1.23479
# Epoch 46/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.1771 - accuracy: 0.9049 - val_loss: 1.1615 - val_accuracy: 0.7969
#
# Epoch 00046: val_loss improved from 1.23479 to 1.16150, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.4614 - accuracy: 0.8603 - val_loss: 1.2665 - val_accuracy: 0.7461
#
# Epoch 00047: val_loss did not improve from 1.16150
# Epoch 48/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.3183 - accuracy: 0.8915 - val_loss: 1.2630 - val_accuracy: 0.7500
#
# Epoch 00048: val_loss did not improve from 1.16150
# Epoch 49/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.7378 - accuracy: 0.8405 - val_loss: 1.5629 - val_accuracy: 0.7148
#
# Epoch 00049: val_loss did not improve from 1.16150
# Epoch 50/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 1.6026 - accuracy: 0.8543 - val_loss: 1.1745 - val_accuracy: 0.7930
#
# Epoch 00050: val_loss did not improve from 1.16150
# Epoch 51/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.2922 - accuracy: 0.8902 - val_loss: 1.1000 - val_accuracy: 0.7930
#
# Epoch 00051: val_loss improved from 1.16150 to 1.09997, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 1.3364 - accuracy: 0.8860 - val_loss: 1.1999 - val_accuracy: 0.7773
#
# Epoch 00052: val_loss did not improve from 1.09997
# Epoch 53/2000
# 34/34 [==============================] - 7s 219ms/step - loss: 1.3064 - accuracy: 0.8874 - val_loss: 1.2680 - val_accuracy: 0.7461
#
# Epoch 00053: val_loss did not improve from 1.09997
# Epoch 54/2000
# 34/34 [==============================] - 8s 222ms/step - loss: 1.4915 - accuracy: 0.8676 - val_loss: 1.4457 - val_accuracy: 0.7148
#
# Epoch 00054: val_loss did not improve from 1.09997
# Epoch 55/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 1.4208 - accuracy: 0.8722 - val_loss: 1.2274 - val_accuracy: 0.7461
#
# Epoch 00055: val_loss did not improve from 1.09997
# Epoch 56/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 1.4655 - accuracy: 0.8782 - val_loss: 1.2781 - val_accuracy: 0.7500
#
# Epoch 00056: val_loss did not improve from 1.09997
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 57/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 1.2090 - accuracy: 0.9017 - val_loss: 1.1123 - val_accuracy: 0.7773
#
# Epoch 00057: val_loss did not improve from 1.09997
# Epoch 58/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 1.2505 - accuracy: 0.8929 - val_loss: 1.0515 - val_accuracy: 0.7930
#
# Epoch 00058: val_loss improved from 1.09997 to 1.05154, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 1.0856 - accuracy: 0.9131 - val_loss: 1.0203 - val_accuracy: 0.7969
#
# Epoch 00059: val_loss improved from 1.05154 to 1.02033, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.1987 - accuracy: 0.8934 - val_loss: 1.1336 - val_accuracy: 0.7656
#
# Epoch 00060: val_loss did not improve from 1.02033
# Epoch 61/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 1.1894 - accuracy: 0.8952 - val_loss: 1.0679 - val_accuracy: 0.7891
#
# Epoch 00061: val_loss did not improve from 1.02033
# Epoch 62/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 1.1330 - accuracy: 0.9067 - val_loss: 1.0618 - val_accuracy: 0.8008
#
# Epoch 00062: val_loss did not improve from 1.02033
# Epoch 63/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 1.0522 - accuracy: 0.9191 - val_loss: 1.1445 - val_accuracy: 0.7461
#
# Epoch 00063: val_loss did not improve from 1.02033
# Epoch 64/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 1.1592 - accuracy: 0.9062 - val_loss: 1.1297 - val_accuracy: 0.7500
#
# Epoch 00064: val_loss did not improve from 1.02033
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 65/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.9929 - accuracy: 0.9228 - val_loss: 1.0236 - val_accuracy: 0.7969
#
# Epoch 00065: val_loss did not improve from 1.02033
# Epoch 66/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 1.0004 - accuracy: 0.9154 - val_loss: 1.0379 - val_accuracy: 0.7969
#
# Epoch 00066: val_loss did not improve from 1.02033
# Epoch 67/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 0.8798 - accuracy: 0.9361 - val_loss: 0.9564 - val_accuracy: 0.8086
#
# Epoch 00067: val_loss improved from 1.02033 to 0.95640, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8972 - accuracy: 0.9256 - val_loss: 1.0023 - val_accuracy: 0.8086
#
# Epoch 00068: val_loss did not improve from 0.95640
# Epoch 69/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.9636 - accuracy: 0.9233 - val_loss: 0.9736 - val_accuracy: 0.8008
#
# Epoch 00069: val_loss did not improve from 0.95640
# Epoch 70/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 1.0278 - accuracy: 0.9053 - val_loss: 1.0285 - val_accuracy: 0.7812
#
# Epoch 00070: val_loss did not improve from 0.95640
# Epoch 71/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.9861 - accuracy: 0.9191 - val_loss: 1.0174 - val_accuracy: 0.7734
#
# Epoch 00071: val_loss did not improve from 0.95640
# Epoch 72/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.9414 - accuracy: 0.9228 - val_loss: 1.0162 - val_accuracy: 0.8047
#
# Epoch 00072: val_loss did not improve from 0.95640
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 73/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 1.0075 - accuracy: 0.9118 - val_loss: 1.0195 - val_accuracy: 0.8008
#
# Epoch 00073: val_loss did not improve from 0.95640
# Epoch 74/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9570 - accuracy: 0.9159 - val_loss: 0.9978 - val_accuracy: 0.8047
#
# Epoch 00074: val_loss did not improve from 0.95640
# Epoch 75/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7850 - accuracy: 0.9412 - val_loss: 0.9652 - val_accuracy: 0.8203
#
# Epoch 00075: val_loss did not improve from 0.95640
# Epoch 76/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8360 - accuracy: 0.9324 - val_loss: 0.9476 - val_accuracy: 0.8164
#
# Epoch 00076: val_loss improved from 0.95640 to 0.94764, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 7s 213ms/step - loss: 0.7851 - accuracy: 0.9370 - val_loss: 0.9559 - val_accuracy: 0.8203
#
# Epoch 00077: val_loss did not improve from 0.94764
# Epoch 78/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8209 - accuracy: 0.9357 - val_loss: 0.9532 - val_accuracy: 0.8203
#
# Epoch 00078: val_loss did not improve from 0.94764
# Epoch 79/2000
# 34/34 [==============================] - 7s 219ms/step - loss: 1.0898 - accuracy: 0.8925 - val_loss: 0.9958 - val_accuracy: 0.7852
#
# Epoch 00079: val_loss did not improve from 0.94764
# Epoch 80/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.9022 - accuracy: 0.9233 - val_loss: 0.9779 - val_accuracy: 0.7969
#
# Epoch 00080: val_loss did not improve from 0.94764
# Epoch 81/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8721 - accuracy: 0.9251 - val_loss: 0.9266 - val_accuracy: 0.8125
#
# Epoch 00081: val_loss improved from 0.94764 to 0.92662, saving model to ./save/cnn_gru_best.hdf5
# Epoch 82/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8400 - accuracy: 0.9343 - val_loss: 0.9354 - val_accuracy: 0.8125
#
# Epoch 00082: val_loss did not improve from 0.92662
# Epoch 83/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.7016 - accuracy: 0.9527 - val_loss: 0.9406 - val_accuracy: 0.8242
#
# Epoch 00083: val_loss did not improve from 0.92662
# Epoch 84/2000
# 34/34 [==============================] - 7s 214ms/step - loss: 0.7281 - accuracy: 0.9458 - val_loss: 0.9948 - val_accuracy: 0.8164
#
# Epoch 00084: val_loss did not improve from 0.92662
# Epoch 85/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.6861 - accuracy: 0.9508 - val_loss: 0.9722 - val_accuracy: 0.8203
#
# Epoch 00085: val_loss did not improve from 0.92662
# Epoch 86/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 0.6772 - accuracy: 0.9462 - val_loss: 0.9595 - val_accuracy: 0.8164
#
# Epoch 00086: val_loss did not improve from 0.92662
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 87/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.9319 - accuracy: 0.9196 - val_loss: 0.9565 - val_accuracy: 0.8203
#
# Epoch 00087: val_loss did not improve from 0.92662
# Epoch 88/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8793 - accuracy: 0.9301 - val_loss: 0.9843 - val_accuracy: 0.7930
#
# Epoch 00088: val_loss did not improve from 0.92662
# Epoch 89/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7639 - accuracy: 0.9306 - val_loss: 0.9742 - val_accuracy: 0.8086
#
# Epoch 00089: val_loss did not improve from 0.92662
# Epoch 90/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7798 - accuracy: 0.9329 - val_loss: 0.9403 - val_accuracy: 0.8203
#
# Epoch 00090: val_loss did not improve from 0.92662
# Epoch 91/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8095 - accuracy: 0.9334 - val_loss: 0.9391 - val_accuracy: 0.8203
#
# Epoch 00091: val_loss did not improve from 0.92662
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 92/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7595 - accuracy: 0.9430 - val_loss: 0.9404 - val_accuracy: 0.8086
#
# Epoch 00092: val_loss did not improve from 0.92662
# Epoch 93/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.8185 - accuracy: 0.9338 - val_loss: 0.9387 - val_accuracy: 0.8047
#
# Epoch 00093: val_loss did not improve from 0.92662
# Epoch 94/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.6765 - accuracy: 0.9504 - val_loss: 0.9511 - val_accuracy: 0.8047
#
# Epoch 00094: val_loss did not improve from 0.92662
# Epoch 95/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7035 - accuracy: 0.9485 - val_loss: 0.9453 - val_accuracy: 0.8086
#
# Epoch 00095: val_loss did not improve from 0.92662
# Epoch 96/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8380 - accuracy: 0.9233 - val_loss: 0.9137 - val_accuracy: 0.8125
#
# Epoch 00096: val_loss improved from 0.92662 to 0.91368, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 7s 216ms/step - loss: 0.9266 - accuracy: 0.9210 - val_loss: 0.9729 - val_accuracy: 0.8047
#
# Epoch 00097: val_loss did not improve from 0.91368
# Epoch 98/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7488 - accuracy: 0.9384 - val_loss: 0.9382 - val_accuracy: 0.8164
#
# Epoch 00098: val_loss did not improve from 0.91368
# Epoch 99/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.8521 - accuracy: 0.9269 - val_loss: 0.9379 - val_accuracy: 0.8164
#
# Epoch 00099: val_loss did not improve from 0.91368
# Epoch 100/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.6734 - accuracy: 0.9403 - val_loss: 0.8948 - val_accuracy: 0.8203
#
# Epoch 00100: val_loss improved from 0.91368 to 0.89475, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7046 - accuracy: 0.9444 - val_loss: 0.9633 - val_accuracy: 0.8047
#
# Epoch 00101: val_loss did not improve from 0.89475
# Epoch 102/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7604 - accuracy: 0.9375 - val_loss: 0.9243 - val_accuracy: 0.8164
#
# Epoch 00102: val_loss did not improve from 0.89475
# Epoch 103/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.8586 - accuracy: 0.9223 - val_loss: 0.9244 - val_accuracy: 0.8086
#
# Epoch 00103: val_loss did not improve from 0.89475
# Epoch 104/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.6589 - accuracy: 0.9536 - val_loss: 0.9093 - val_accuracy: 0.8203
#
# Epoch 00104: val_loss did not improve from 0.89475
# Epoch 105/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7839 - accuracy: 0.9301 - val_loss: 0.8979 - val_accuracy: 0.8242
#
# Epoch 00105: val_loss did not improve from 0.89475
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 106/2000
# 34/34 [==============================] - 7s 215ms/step - loss: 0.7718 - accuracy: 0.9324 - val_loss: 0.8475 - val_accuracy: 0.8320
#
# Epoch 00106: val_loss improved from 0.89475 to 0.84749, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.6559 - accuracy: 0.9554 - val_loss: 0.8771 - val_accuracy: 0.8164
#
# Epoch 00107: val_loss did not improve from 0.84749
# Epoch 108/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.6862 - accuracy: 0.9490 - val_loss: 0.8459 - val_accuracy: 0.8320
#
# Epoch 00108: val_loss improved from 0.84749 to 0.84590, saving model to ./save/cnn_gru_best.hdf5
# Epoch 109/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7743 - accuracy: 0.9347 - val_loss: 0.8805 - val_accuracy: 0.8125
#
# Epoch 00109: val_loss did not improve from 0.84590
# Epoch 110/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7089 - accuracy: 0.9421 - val_loss: 0.9132 - val_accuracy: 0.8164
#
# Epoch 00110: val_loss did not improve from 0.84590
# Epoch 111/2000
# 34/34 [==============================] - 7s 219ms/step - loss: 0.8598 - accuracy: 0.9242 - val_loss: 0.9561 - val_accuracy: 0.8125
#
# Epoch 00111: val_loss did not improve from 0.84590
# Epoch 112/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7092 - accuracy: 0.9458 - val_loss: 0.9638 - val_accuracy: 0.8008
#
# Epoch 00112: val_loss did not improve from 0.84590
# Epoch 113/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7323 - accuracy: 0.9426 - val_loss: 0.9217 - val_accuracy: 0.8125
#
# Epoch 00113: val_loss did not improve from 0.84590
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 114/2000
# 34/34 [==============================] - 7s 217ms/step - loss: 0.7574 - accuracy: 0.9361 - val_loss: 0.9695 - val_accuracy: 0.8047
#
# Epoch 00114: val_loss did not improve from 0.84590
# Epoch 115/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.6789 - accuracy: 0.9462 - val_loss: 0.9327 - val_accuracy: 0.8086
#
# Epoch 00115: val_loss did not improve from 0.84590
# Epoch 116/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 0.6710 - accuracy: 0.9449 - val_loss: 0.9386 - val_accuracy: 0.8047
#
# Epoch 00116: val_loss did not improve from 0.84590
# Epoch 117/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7588 - accuracy: 0.9435 - val_loss: 0.9323 - val_accuracy: 0.8047
#
# Epoch 00117: val_loss did not improve from 0.84590
# Epoch 118/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.6672 - accuracy: 0.9499 - val_loss: 0.9307 - val_accuracy: 0.8164
#
# Epoch 00118: val_loss did not improve from 0.84590
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 119/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7593 - accuracy: 0.9301 - val_loss: 0.9728 - val_accuracy: 0.8008
#
# Epoch 00119: val_loss did not improve from 0.84590
# Epoch 120/2000
# 34/34 [==============================] - 8s 218ms/step - loss: 0.8225 - accuracy: 0.9269 - val_loss: 0.9914 - val_accuracy: 0.8008
#
# Epoch 00120: val_loss did not improve from 0.84590
# Epoch 121/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.8029 - accuracy: 0.9320 - val_loss: 0.9647 - val_accuracy: 0.8047
#
# Epoch 00121: val_loss did not improve from 0.84590
# Epoch 122/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.6446 - accuracy: 0.9494 - val_loss: 0.9283 - val_accuracy: 0.8203
#
# Epoch 00122: val_loss did not improve from 0.84590
# Epoch 123/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7638 - accuracy: 0.9306 - val_loss: 0.9508 - val_accuracy: 0.8164
#
# Epoch 00123: val_loss did not improve from 0.84590
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 124/2000
# 34/34 [==============================] - 8s 221ms/step - loss: 0.7449 - accuracy: 0.9370 - val_loss: 0.9569 - val_accuracy: 0.8125
#
# Epoch 00124: val_loss did not improve from 0.84590
# Epoch 125/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.7568 - accuracy: 0.9375 - val_loss: 0.9912 - val_accuracy: 0.8008
#
# Epoch 00125: val_loss did not improve from 0.84590
# Epoch 126/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7210 - accuracy: 0.9334 - val_loss: 0.9727 - val_accuracy: 0.8086
#
# Epoch 00126: val_loss did not improve from 0.84590
# Epoch 127/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.8251 - accuracy: 0.9237 - val_loss: 0.9812 - val_accuracy: 0.8125
#
# Epoch 00127: val_loss did not improve from 0.84590
# Epoch 128/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.6405 - accuracy: 0.9517 - val_loss: 0.9158 - val_accuracy: 0.8359
#
# Epoch 00128: val_loss did not improve from 0.84590
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 129/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7243 - accuracy: 0.9375 - val_loss: 0.9772 - val_accuracy: 0.8125
#
# Epoch 00129: val_loss did not improve from 0.84590
# Epoch 130/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.6329 - accuracy: 0.9536 - val_loss: 0.9720 - val_accuracy: 0.8203
#
# Epoch 00130: val_loss did not improve from 0.84590
# Epoch 131/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7312 - accuracy: 0.9416 - val_loss: 0.9501 - val_accuracy: 0.8125
#
# Epoch 00131: val_loss did not improve from 0.84590
# Epoch 132/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7216 - accuracy: 0.9393 - val_loss: 0.9266 - val_accuracy: 0.8320
#
# Epoch 00132: val_loss did not improve from 0.84590
# Epoch 133/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7418 - accuracy: 0.9389 - val_loss: 0.9609 - val_accuracy: 0.8125
#
# Epoch 00133: val_loss did not improve from 0.84590
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 134/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7437 - accuracy: 0.9306 - val_loss: 0.9671 - val_accuracy: 0.8047
#
# Epoch 00134: val_loss did not improve from 0.84590
# Epoch 135/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.7309 - accuracy: 0.9380 - val_loss: 0.9723 - val_accuracy: 0.8086
#
# Epoch 00135: val_loss did not improve from 0.84590
# Epoch 136/2000
# 34/34 [==============================] - 8s 219ms/step - loss: 0.7042 - accuracy: 0.9453 - val_loss: 0.9448 - val_accuracy: 0.8164
#
# Epoch 00136: val_loss did not improve from 0.84590
# Epoch 137/2000
# 34/34 [==============================] - 7s 218ms/step - loss: 0.7579 - accuracy: 0.9380 - val_loss: 0.9577 - val_accuracy: 0.8164
#
# Epoch 00137: val_loss did not improve from 0.84590
# Epoch 138/2000
# 34/34 [==============================] - 8s 220ms/step - loss: 0.6233 - accuracy: 0.9536 - val_loss: 0.9374 - val_accuracy: 0.8281
#
# Epoch 00138: val_loss did not improve from 0.84590
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 00138: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7532 - accuracy: 0.8496
# [0.7531896829605103, 0.8496000170707703]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
