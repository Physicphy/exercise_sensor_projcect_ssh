# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3,
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, #0.2
    res_num = 9, # 3, 5, 7
    )

model.summary()
# Out:
# zation_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 120)     480         conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_22[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 120)     480         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_25[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_28[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 120)     480         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_31[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_34[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_37[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_40[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,132,251
# Trainable params: 1,126,311
# Non-trainable params: 5,940
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=20,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 37s 314ms/step - loss: 43.8469 - accuracy: 0.3203 - val_loss: 32.7059 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.70592, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 28.8276 - accuracy: 0.5528 - val_loss: 21.4938 - val_accuracy: 0.4531
#
# Epoch 00002: val_loss improved from 32.70592 to 21.49380, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 19.0017 - accuracy: 0.6466 - val_loss: 14.7255 - val_accuracy: 0.4414
#
# Epoch 00003: val_loss improved from 21.49380 to 14.72552, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 201ms/step - loss: 13.0218 - accuracy: 0.6889 - val_loss: 10.6246 - val_accuracy: 0.4648
#
# Epoch 00004: val_loss improved from 14.72552 to 10.62456, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 9.7025 - accuracy: 0.6907 - val_loss: 8.3082 - val_accuracy: 0.4570
#
# Epoch 00005: val_loss improved from 10.62456 to 8.30817, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 7.3761 - accuracy: 0.7206 - val_loss: 7.0582 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 8.30817 to 7.05820, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 5.8183 - accuracy: 0.7381 - val_loss: 6.0080 - val_accuracy: 0.4570
#
# Epoch 00007: val_loss improved from 7.05820 to 6.00803, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 4.8306 - accuracy: 0.7399 - val_loss: 5.8851 - val_accuracy: 0.4219
#
# Epoch 00008: val_loss improved from 6.00803 to 5.88507, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 4.3270 - accuracy: 0.7293 - val_loss: 6.2150 - val_accuracy: 0.3242
#
# Epoch 00009: val_loss did not improve from 5.88507
# Epoch 10/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 3.7977 - accuracy: 0.7486 - val_loss: 7.0489 - val_accuracy: 0.0078
#
# Epoch 00010: val_loss did not improve from 5.88507
# Epoch 11/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 3.3286 - accuracy: 0.7652 - val_loss: 5.2155 - val_accuracy: 0.2969
#
# Epoch 00011: val_loss improved from 5.88507 to 5.21549, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 2.9388 - accuracy: 0.7923 - val_loss: 6.4102 - val_accuracy: 0.0312
#
# Epoch 00012: val_loss did not improve from 5.21549
# Epoch 13/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.9250 - accuracy: 0.7790 - val_loss: 5.6114 - val_accuracy: 0.1445
#
# Epoch 00013: val_loss did not improve from 5.21549
# Epoch 14/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 2.6812 - accuracy: 0.7964 - val_loss: 7.5155 - val_accuracy: 0.0234
#
# Epoch 00014: val_loss did not improve from 5.21549
# Epoch 15/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 2.5085 - accuracy: 0.8019 - val_loss: 4.6657 - val_accuracy: 0.1914
#
# Epoch 00015: val_loss improved from 5.21549 to 4.66573, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.4633 - accuracy: 0.7960 - val_loss: 5.4600 - val_accuracy: 0.1641
#
# Epoch 00016: val_loss did not improve from 4.66573
# Epoch 17/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 2.4248 - accuracy: 0.7927 - val_loss: 4.0803 - val_accuracy: 0.2500
#
# Epoch 00017: val_loss improved from 4.66573 to 4.08025, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 2.1881 - accuracy: 0.8199 - val_loss: 2.1872 - val_accuracy: 0.5742
#
# Epoch 00018: val_loss improved from 4.08025 to 2.18722, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.2820 - accuracy: 0.8070 - val_loss: 2.1552 - val_accuracy: 0.5977
#
# Epoch 00019: val_loss improved from 2.18722 to 2.15521, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.1735 - accuracy: 0.8203 - val_loss: 2.4781 - val_accuracy: 0.4727
#
# Epoch 00020: val_loss did not improve from 2.15521
# Epoch 21/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.1200 - accuracy: 0.8300 - val_loss: 1.8705 - val_accuracy: 0.6289
#
# Epoch 00021: val_loss improved from 2.15521 to 1.87050, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.9424 - accuracy: 0.8396 - val_loss: 1.5095 - val_accuracy: 0.7266
#
# Epoch 00022: val_loss improved from 1.87050 to 1.50948, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.6995 - accuracy: 0.8653 - val_loss: 1.4775 - val_accuracy: 0.7227
#
# Epoch 00023: val_loss improved from 1.50948 to 1.47749, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.6849 - accuracy: 0.8589 - val_loss: 1.7936 - val_accuracy: 0.6445
#
# Epoch 00024: val_loss did not improve from 1.47749
# Epoch 25/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.6333 - accuracy: 0.8612 - val_loss: 1.5107 - val_accuracy: 0.7188
#
# Epoch 00025: val_loss did not improve from 1.47749
# Epoch 26/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.5053 - accuracy: 0.8768 - val_loss: 1.3657 - val_accuracy: 0.7031
#
# Epoch 00026: val_loss improved from 1.47749 to 1.36567, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.4365 - accuracy: 0.8699 - val_loss: 1.4514 - val_accuracy: 0.7070
#
# Epoch 00027: val_loss did not improve from 1.36567
# Epoch 28/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.4313 - accuracy: 0.8810 - val_loss: 1.1276 - val_accuracy: 0.7812
#
# Epoch 00028: val_loss improved from 1.36567 to 1.12755, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.3179 - accuracy: 0.8888 - val_loss: 1.1746 - val_accuracy: 0.7656
#
# Epoch 00029: val_loss did not improve from 1.12755
# Epoch 30/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.3453 - accuracy: 0.8791 - val_loss: 1.1442 - val_accuracy: 0.7812
#
# Epoch 00030: val_loss did not improve from 1.12755
# Epoch 31/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.2659 - accuracy: 0.8865 - val_loss: 1.1616 - val_accuracy: 0.7461
#
# Epoch 00031: val_loss did not improve from 1.12755
# Epoch 32/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.2463 - accuracy: 0.8975 - val_loss: 1.0893 - val_accuracy: 0.7617
#
# Epoch 00032: val_loss improved from 1.12755 to 1.08932, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.2635 - accuracy: 0.8952 - val_loss: 1.1243 - val_accuracy: 0.7617
#
# Epoch 00033: val_loss did not improve from 1.08932
# Epoch 34/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.1491 - accuracy: 0.9072 - val_loss: 1.0596 - val_accuracy: 0.7695
#
# Epoch 00034: val_loss improved from 1.08932 to 1.05963, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.0545 - accuracy: 0.9182 - val_loss: 1.1045 - val_accuracy: 0.7500
#
# Epoch 00035: val_loss did not improve from 1.05963
# Epoch 36/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.0115 - accuracy: 0.9200 - val_loss: 0.9445 - val_accuracy: 0.8047
#
# Epoch 00036: val_loss improved from 1.05963 to 0.94450, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.9281 - accuracy: 0.9288 - val_loss: 1.0221 - val_accuracy: 0.7852
#
# Epoch 00037: val_loss did not improve from 0.94450
# Epoch 38/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.1760 - accuracy: 0.8957 - val_loss: 0.9743 - val_accuracy: 0.7969
#
# Epoch 00038: val_loss did not improve from 0.94450
# Epoch 39/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.9314 - accuracy: 0.9265 - val_loss: 0.9542 - val_accuracy: 0.8086
#
# Epoch 00039: val_loss did not improve from 0.94450
# Epoch 40/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.9414 - accuracy: 0.9219 - val_loss: 0.9112 - val_accuracy: 0.8125
#
# Epoch 00040: val_loss improved from 0.94450 to 0.91124, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.9702 - accuracy: 0.9150 - val_loss: 0.9589 - val_accuracy: 0.7930
#
# Epoch 00041: val_loss did not improve from 0.91124
# Epoch 42/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.9233 - accuracy: 0.9283 - val_loss: 0.9018 - val_accuracy: 0.7969
#
# Epoch 00042: val_loss improved from 0.91124 to 0.90181, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7939 - accuracy: 0.9403 - val_loss: 0.8520 - val_accuracy: 0.8281
#
# Epoch 00043: val_loss improved from 0.90181 to 0.85204, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.9035 - accuracy: 0.9256 - val_loss: 0.9315 - val_accuracy: 0.8008
#
# Epoch 00044: val_loss did not improve from 0.85204
# Epoch 45/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.8526 - accuracy: 0.9265 - val_loss: 0.9529 - val_accuracy: 0.8086
#
# Epoch 00045: val_loss did not improve from 0.85204
# Epoch 46/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7875 - accuracy: 0.9449 - val_loss: 0.9660 - val_accuracy: 0.8086
#
# Epoch 00046: val_loss did not improve from 0.85204
# Epoch 47/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.8398 - accuracy: 0.9343 - val_loss: 0.9163 - val_accuracy: 0.8164
#
# Epoch 00047: val_loss did not improve from 0.85204
# Epoch 48/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8439 - accuracy: 0.9320 - val_loss: 0.9512 - val_accuracy: 0.8281
#
# Epoch 00048: val_loss did not improve from 0.85204
# Epoch 49/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8072 - accuracy: 0.9343 - val_loss: 0.9106 - val_accuracy: 0.8125
#
# Epoch 00049: val_loss did not improve from 0.85204
# Epoch 50/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7429 - accuracy: 0.9481 - val_loss: 0.9294 - val_accuracy: 0.8242
#
# Epoch 00050: val_loss did not improve from 0.85204
# Epoch 51/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7638 - accuracy: 0.9384 - val_loss: 0.9728 - val_accuracy: 0.8125
#
# Epoch 00051: val_loss did not improve from 0.85204
# Epoch 52/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.7913 - accuracy: 0.9435 - val_loss: 0.9630 - val_accuracy: 0.8086
#
# Epoch 00052: val_loss did not improve from 0.85204
# Epoch 53/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6787 - accuracy: 0.9573 - val_loss: 0.9062 - val_accuracy: 0.8242
#
# Epoch 00053: val_loss did not improve from 0.85204
# Epoch 54/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.7921 - accuracy: 0.9352 - val_loss: 0.9370 - val_accuracy: 0.8086
#
# Epoch 00054: val_loss did not improve from 0.85204
# Epoch 55/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.8231 - accuracy: 0.9283 - val_loss: 0.9584 - val_accuracy: 0.8203
#
# Epoch 00055: val_loss did not improve from 0.85204
# Epoch 56/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7163 - accuracy: 0.9412 - val_loss: 0.9398 - val_accuracy: 0.8242
#
# Epoch 00056: val_loss did not improve from 0.85204
# Epoch 57/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6981 - accuracy: 0.9494 - val_loss: 0.9398 - val_accuracy: 0.8164
#
# Epoch 00057: val_loss did not improve from 0.85204
# Epoch 58/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6803 - accuracy: 0.9485 - val_loss: 0.9125 - val_accuracy: 0.8242
#
# Epoch 00058: val_loss did not improve from 0.85204
# Epoch 59/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6763 - accuracy: 0.9559 - val_loss: 0.9165 - val_accuracy: 0.8203
#
# Epoch 00059: val_loss did not improve from 0.85204
# Epoch 60/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6288 - accuracy: 0.9577 - val_loss: 0.9233 - val_accuracy: 0.8242
#
# Epoch 00060: val_loss did not improve from 0.85204
# Epoch 61/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.5806 - accuracy: 0.9651 - val_loss: 0.8224 - val_accuracy: 0.8398
#
# Epoch 00061: val_loss improved from 0.85204 to 0.82242, saving model to ./save/cnn_gru_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6419 - accuracy: 0.9586 - val_loss: 0.9458 - val_accuracy: 0.8320
#
# Epoch 00062: val_loss did not improve from 0.82242
# Epoch 63/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6290 - accuracy: 0.9563 - val_loss: 0.9196 - val_accuracy: 0.8281
#
# Epoch 00063: val_loss did not improve from 0.82242
# Epoch 64/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6179 - accuracy: 0.9559 - val_loss: 0.9247 - val_accuracy: 0.8242
#
# Epoch 00064: val_loss did not improve from 0.82242
# Epoch 65/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6895 - accuracy: 0.9476 - val_loss: 0.9317 - val_accuracy: 0.8242
#
# Epoch 00065: val_loss did not improve from 0.82242
# Epoch 66/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6592 - accuracy: 0.9531 - val_loss: 0.9309 - val_accuracy: 0.8125
#
# Epoch 00066: val_loss did not improve from 0.82242
# Epoch 67/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6073 - accuracy: 0.9609 - val_loss: 0.9227 - val_accuracy: 0.8203
#
# Epoch 00067: val_loss did not improve from 0.82242
# Epoch 68/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6686 - accuracy: 0.9517 - val_loss: 0.9217 - val_accuracy: 0.8125
#
# Epoch 00068: val_loss did not improve from 0.82242
# Epoch 69/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.7414 - accuracy: 0.9412 - val_loss: 0.9219 - val_accuracy: 0.8242
#
# Epoch 00069: val_loss did not improve from 0.82242
# Epoch 70/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6798 - accuracy: 0.9554 - val_loss: 0.9457 - val_accuracy: 0.8203
#
# Epoch 00070: val_loss did not improve from 0.82242
# Epoch 71/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6791 - accuracy: 0.9485 - val_loss: 0.9525 - val_accuracy: 0.8203
#
# Epoch 00071: val_loss did not improve from 0.82242
# Epoch 72/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.5850 - accuracy: 0.9623 - val_loss: 0.9184 - val_accuracy: 0.8242
#
# Epoch 00072: val_loss did not improve from 0.82242
# Epoch 73/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.5862 - accuracy: 0.9623 - val_loss: 0.9435 - val_accuracy: 0.8203
#
# Epoch 00073: val_loss did not improve from 0.82242
# Epoch 74/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6137 - accuracy: 0.9554 - val_loss: 0.9298 - val_accuracy: 0.8320
#
# Epoch 00074: val_loss did not improve from 0.82242
# Epoch 75/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6751 - accuracy: 0.9540 - val_loss: 0.9777 - val_accuracy: 0.8242
#
# Epoch 00075: val_loss did not improve from 0.82242
# Epoch 76/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6330 - accuracy: 0.9504 - val_loss: 0.9414 - val_accuracy: 0.8164
#
# Epoch 00076: val_loss did not improve from 0.82242
# Epoch 77/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6156 - accuracy: 0.9582 - val_loss: 0.9694 - val_accuracy: 0.8008
#
# Epoch 00077: val_loss did not improve from 0.82242
# Epoch 78/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7201 - accuracy: 0.9476 - val_loss: 0.8925 - val_accuracy: 0.8281
#
# Epoch 00078: val_loss did not improve from 0.82242
# Epoch 79/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6001 - accuracy: 0.9577 - val_loss: 0.9351 - val_accuracy: 0.8164
#
# Epoch 00079: val_loss did not improve from 0.82242
# Epoch 80/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.6138 - accuracy: 0.9563 - val_loss: 0.9551 - val_accuracy: 0.8281
#
# Epoch 00080: val_loss did not improve from 0.82242
# Epoch 81/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6302 - accuracy: 0.9554 - val_loss: 0.9419 - val_accuracy: 0.8047
#
# Epoch 00081: val_loss did not improve from 0.82242
# Epoch 00081: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7448 - accuracy: 0.8352
# [0.7448343634605408, 0.8352000117301941]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
