# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset

import os

os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
eval_dir = './data/train'
eval_label_dir = './data/data_y_train.csv'
label_dir = './data/data_y_train.csv'

def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

train_y = pd.read_csv('./data/data_y_train.csv')  # label load
label_dict = dict()
for label, label_desc in zip(train_y.label, train_y.label_desc):
    label_dict[label] = label_desc
# 'Squat (kettlebell / goblet)'에서 [/]를 [,]으로 변경
label_dict[45] = 'Squat (kettlebell , goblet)'

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(
    'balanced',
    np.unique(train_y.label),
    train_y.label)

class_weight_dict = dict(zip(
    list(range(61)),
    class_weights+1
    ))

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Input, GlobalAveragePooling1D, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import he_normal

# %%
kernel_size1 = 19
kernel_size2 = 3
kernel_size3 = 5
kk = 10
stride = 2

acc_input_1 = layers.Input(shape=(600, 3))
acc_input_2 = layers.Input(shape=(600, 1))
acc_input_3 = layers.Input(shape=(600, 1))
gy_input_1 = layers.Input(shape=(600, 3))
gy_input_2 = layers.Input(shape=(600, 1))
gy_input_3 = layers.Input(shape=(600, 1))


# conv1_inputs = layers.concatenate([acc_input_1, acc_input_2, gy_input_1, gy_input_2])
conv1_inputs = layers.concatenate([acc_input_1, acc_input_2, acc_input_3])

conv1 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv1_inputs)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*2,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)
conv1 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru1)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*6,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)

acc_model = Model([acc_input_1, acc_input_2, acc_input_3], gru1)


conv2_inputs = layers.concatenate([gy_input_1, gy_input_2, gy_input_3])

conv2 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv2_inputs)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*2,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)
conv2 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru2)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*6,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)

gy_model = Model([gy_input_1, gy_input_2, gy_input_3], gru2)

conv3_inputs = layers.concatenate([acc_input_2,gy_input_2, acc_input_3, gy_input_3])

conv3 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv3_inputs)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*2,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)
conv3 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru3)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*6,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)

mag_model = Model([acc_input_2,gy_input_2, acc_input_3, gy_input_3], gru3)

conv4_inputs = layers.concatenate([acc_input_1, gy_input_1])

conv4 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv4_inputs)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*2,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)
conv4 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru4)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*6,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)

xyz_model = Model([acc_input_1, gy_input_1], gru4)

concat = layers.concatenate([
    acc_model.output,gy_model.output,
    mag_model.output,xyz_model.output
    ])
    
conv_tot = Conv1D(
    kk*6,kernel_size3,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(concat)
conv_tot = BatchNormalization()(conv_tot)

# pool = layers.AveragePooling1D(9,strides=3,padding='same')(conv1)

# gru = layers.GRU(60)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
#gru = Dropout(0.2,seed=42)(gru)
# gru = layers.GRU(120,return_sequences=True)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.5,seed=42)(gru)
# gru = layers.GRU(60)(gru)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.2,seed=42)(gru)
# outputs = Dense(61, activation='softmax')(gru)

pool = GlobalAveragePooling1D()(conv_tot)
outputs = Dense(61, activation='softmax')(pool)

model = Model([acc_input_1,gy_input_1,acc_input_2,gy_input_2,acc_input_3,gy_input_3],outputs)

model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_5[0][0]
#                                                                  input_3[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      960         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      960         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      770         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1150        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          conv1d_6[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         conv1d_7[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 150, 240)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 75, 60)       72060       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 60)       240         conv1d_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 192,421
# Trainable params: 191,101
# Non-trainable params: 1,320
# __________________________________________________________________________________________________

# %%
checkpoint_filepath = "simple_cnn_best.hdf5"

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=50,verbose=1)

history = model.fit_generator(
    generator=train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# racy: 0.8824 - val_loss: 0.8580 - val_accuracy: 0.7539
#
# Epoch 00026: val_loss improved from 0.93603 to 0.85802, saving model to simple_cnn_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.9221 - accuracy: 0.8952 - val_loss: 0.9734 - val_accuracy: 0.7188
#
# Epoch 00027: val_loss did not improve from 0.85802
# Epoch 28/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 1.0709 - accuracy: 0.8791 - val_loss: 0.8673 - val_accuracy: 0.7500
#
# Epoch 00028: val_loss did not improve from 0.85802
# Epoch 29/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 1.0209 - accuracy: 0.8860 - val_loss: 0.7914 - val_accuracy: 0.7656
#
# Epoch 00029: val_loss improved from 0.85802 to 0.79140, saving model to simple_cnn_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.9470 - accuracy: 0.8943 - val_loss: 0.8163 - val_accuracy: 0.7773
#
# Epoch 00030: val_loss did not improve from 0.79140
# Epoch 31/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.9118 - accuracy: 0.8925 - val_loss: 0.7947 - val_accuracy: 0.7656
#
# Epoch 00031: val_loss did not improve from 0.79140
# Epoch 32/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.8076 - accuracy: 0.9099 - val_loss: 0.8059 - val_accuracy: 0.7734
#
# Epoch 00032: val_loss did not improve from 0.79140
# Epoch 33/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.7947 - accuracy: 0.9182 - val_loss: 0.8095 - val_accuracy: 0.7617
#
# Epoch 00033: val_loss did not improve from 0.79140
# Epoch 34/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.8730 - accuracy: 0.9049 - val_loss: 0.8116 - val_accuracy: 0.7500
#
# Epoch 00034: val_loss did not improve from 0.79140
# Epoch 35/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7461 - accuracy: 0.9200 - val_loss: 0.7828 - val_accuracy: 0.7695
#
# Epoch 00035: val_loss improved from 0.79140 to 0.78277, saving model to simple_cnn_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6993 - accuracy: 0.9233 - val_loss: 0.7984 - val_accuracy: 0.7695
#
# Epoch 00036: val_loss did not improve from 0.78277
# Epoch 37/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.8854 - accuracy: 0.9058 - val_loss: 0.8644 - val_accuracy: 0.7617
#
# Epoch 00037: val_loss did not improve from 0.78277
# Epoch 38/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.8272 - accuracy: 0.9081 - val_loss: 0.7883 - val_accuracy: 0.7734
#
# Epoch 00038: val_loss did not improve from 0.78277
# Epoch 39/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7363 - accuracy: 0.9228 - val_loss: 0.7550 - val_accuracy: 0.7734
#
# Epoch 00039: val_loss improved from 0.78277 to 0.75498, saving model to simple_cnn_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7204 - accuracy: 0.9256 - val_loss: 0.7535 - val_accuracy: 0.7773
#
# Epoch 00040: val_loss improved from 0.75498 to 0.75346, saving model to simple_cnn_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7589 - accuracy: 0.9122 - val_loss: 0.8168 - val_accuracy: 0.7656
#
# Epoch 00041: val_loss did not improve from 0.75346
# Epoch 42/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6906 - accuracy: 0.9269 - val_loss: 0.7768 - val_accuracy: 0.7773
#
# Epoch 00042: val_loss did not improve from 0.75346
# Epoch 43/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7284 - accuracy: 0.9191 - val_loss: 0.7726 - val_accuracy: 0.7656
#
# Epoch 00043: val_loss did not improve from 0.75346
# Epoch 44/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.7615 - accuracy: 0.9177 - val_loss: 0.8011 - val_accuracy: 0.7734
#
# Epoch 00044: val_loss did not improve from 0.75346
# Epoch 45/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6819 - accuracy: 0.9265 - val_loss: 0.7773 - val_accuracy: 0.7695
#
# Epoch 00045: val_loss did not improve from 0.75346
# Epoch 46/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7135 - accuracy: 0.9210 - val_loss: 0.7673 - val_accuracy: 0.7891
#
# Epoch 00046: val_loss did not improve from 0.75346
# Epoch 47/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.7015 - accuracy: 0.9237 - val_loss: 0.8106 - val_accuracy: 0.7773
#
# Epoch 00047: val_loss did not improve from 0.75346
# Epoch 48/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7029 - accuracy: 0.9246 - val_loss: 0.7966 - val_accuracy: 0.7812
#
# Epoch 00048: val_loss did not improve from 0.75346
# Epoch 49/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7149 - accuracy: 0.9283 - val_loss: 0.7839 - val_accuracy: 0.7773
#
# Epoch 00049: val_loss did not improve from 0.75346
# Epoch 50/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.7483 - accuracy: 0.9164 - val_loss: 0.7872 - val_accuracy: 0.7734
#
# Epoch 00050: val_loss did not improve from 0.75346
# Epoch 51/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.7615 - accuracy: 0.9205 - val_loss: 0.7938 - val_accuracy: 0.7734
#
# Epoch 00051: val_loss did not improve from 0.75346
# Epoch 52/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7834 - accuracy: 0.9164 - val_loss: 0.7397 - val_accuracy: 0.7773
#
# Epoch 00052: val_loss improved from 0.75346 to 0.73969, saving model to simple_cnn_best.hdf5
# Epoch 53/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6720 - accuracy: 0.9315 - val_loss: 0.7656 - val_accuracy: 0.7734
#
# Epoch 00053: val_loss did not improve from 0.73969
# Epoch 54/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6800 - accuracy: 0.9246 - val_loss: 0.7807 - val_accuracy: 0.7734
#
# Epoch 00054: val_loss did not improve from 0.73969
# Epoch 55/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6850 - accuracy: 0.9246 - val_loss: 0.7228 - val_accuracy: 0.7734
#
# Epoch 00055: val_loss improved from 0.73969 to 0.72275, saving model to simple_cnn_best.hdf5
# Epoch 56/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.7958 - accuracy: 0.9122 - val_loss: 0.7550 - val_accuracy: 0.7734
#
# Epoch 00056: val_loss did not improve from 0.72275
# Epoch 57/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6225 - accuracy: 0.9380 - val_loss: 0.7764 - val_accuracy: 0.7734
#
# Epoch 00057: val_loss did not improve from 0.72275
# Epoch 58/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6815 - accuracy: 0.9278 - val_loss: 0.8039 - val_accuracy: 0.7734
#
# Epoch 00058: val_loss did not improve from 0.72275
# Epoch 59/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.7381 - accuracy: 0.9210 - val_loss: 0.7855 - val_accuracy: 0.7695
#
# Epoch 00059: val_loss did not improve from 0.72275
# Epoch 60/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6448 - accuracy: 0.9384 - val_loss: 0.7696 - val_accuracy: 0.7773
#
# Epoch 00060: val_loss did not improve from 0.72275
# Epoch 61/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6027 - accuracy: 0.9416 - val_loss: 0.7424 - val_accuracy: 0.7891
#
# Epoch 00061: val_loss did not improve from 0.72275
# Epoch 62/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7402 - accuracy: 0.9205 - val_loss: 0.7901 - val_accuracy: 0.7695
#
# Epoch 00062: val_loss did not improve from 0.72275
# Epoch 63/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6620 - accuracy: 0.9311 - val_loss: 0.7960 - val_accuracy: 0.7734
#
# Epoch 00063: val_loss did not improve from 0.72275
# Epoch 64/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6405 - accuracy: 0.9265 - val_loss: 0.7869 - val_accuracy: 0.7812
#
# Epoch 00064: val_loss did not improve from 0.72275
# Epoch 65/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6561 - accuracy: 0.9334 - val_loss: 0.7379 - val_accuracy: 0.7891
#
# Epoch 00065: val_loss did not improve from 0.72275
# Epoch 66/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.7075 - accuracy: 0.9205 - val_loss: 0.7982 - val_accuracy: 0.7734
#
# Epoch 00066: val_loss did not improve from 0.72275
# Epoch 67/2000
# 34/34 [==============================] - 5s 142ms/step - loss: 0.6827 - accuracy: 0.9237 - val_loss: 0.7797 - val_accuracy: 0.7812
#
# Epoch 00067: val_loss did not improve from 0.72275
# Epoch 68/2000
# 34/34 [==============================] - 5s 156ms/step - loss: 0.6814 - accuracy: 0.9242 - val_loss: 0.7746 - val_accuracy: 0.7656
#
# Epoch 00068: val_loss did not improve from 0.72275
# Epoch 69/2000
# 34/34 [==============================] - 4s 128ms/step - loss: 0.6317 - accuracy: 0.9292 - val_loss: 0.8056 - val_accuracy: 0.7617
#
# Epoch 00069: val_loss did not improve from 0.72275
# Epoch 70/2000
# 34/34 [==============================] - 5s 133ms/step - loss: 0.6623 - accuracy: 0.9274 - val_loss: 0.7659 - val_accuracy: 0.7695
#
# Epoch 00070: val_loss did not improve from 0.72275
# Epoch 71/2000
# 34/34 [==============================] - 5s 144ms/step - loss: 0.6455 - accuracy: 0.9357 - val_loss: 0.7923 - val_accuracy: 0.7812
#
# Epoch 00071: val_loss did not improve from 0.72275
# Epoch 72/2000
# 34/34 [==============================] - 4s 127ms/step - loss: 0.6453 - accuracy: 0.9301 - val_loss: 0.7986 - val_accuracy: 0.7812
#
# Epoch 00072: val_loss did not improve from 0.72275
# Epoch 73/2000
# 34/34 [==============================] - 5s 138ms/step - loss: 0.5288 - accuracy: 0.9458 - val_loss: 0.7705 - val_accuracy: 0.7852
#
# Epoch 00073: val_loss did not improve from 0.72275
# Epoch 74/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6622 - accuracy: 0.9297 - val_loss: 0.7612 - val_accuracy: 0.7969
#
# Epoch 00074: val_loss did not improve from 0.72275
# Epoch 75/2000
# 34/34 [==============================] - 5s 142ms/step - loss: 0.6025 - accuracy: 0.9297 - val_loss: 0.7201 - val_accuracy: 0.7930
#
# Epoch 00075: val_loss improved from 0.72275 to 0.72014, saving model to simple_cnn_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6621 - accuracy: 0.9352 - val_loss: 0.7726 - val_accuracy: 0.7852
#
# Epoch 00076: val_loss did not improve from 0.72014
# Epoch 77/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.7040 - accuracy: 0.9283 - val_loss: 0.7928 - val_accuracy: 0.7734
#
# Epoch 00077: val_loss did not improve from 0.72014
# Epoch 78/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6841 - accuracy: 0.9214 - val_loss: 0.8044 - val_accuracy: 0.7656
#
# Epoch 00078: val_loss did not improve from 0.72014
# Epoch 79/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5873 - accuracy: 0.9407 - val_loss: 0.8013 - val_accuracy: 0.7656
#
# Epoch 00079: val_loss did not improve from 0.72014
# Epoch 80/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6234 - accuracy: 0.9398 - val_loss: 0.7709 - val_accuracy: 0.7734
#
# Epoch 00080: val_loss did not improve from 0.72014
# Epoch 81/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6250 - accuracy: 0.9301 - val_loss: 0.7790 - val_accuracy: 0.7734
#
# Epoch 00081: val_loss did not improve from 0.72014
# Epoch 82/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6773 - accuracy: 0.9292 - val_loss: 0.7307 - val_accuracy: 0.7891
#
# Epoch 00082: val_loss did not improve from 0.72014
# Epoch 83/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6925 - accuracy: 0.9265 - val_loss: 0.7840 - val_accuracy: 0.7773
#
# Epoch 00083: val_loss did not improve from 0.72014
# Epoch 84/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6792 - accuracy: 0.9311 - val_loss: 0.7503 - val_accuracy: 0.7773
#
# Epoch 00084: val_loss did not improve from 0.72014
# Epoch 85/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7165 - accuracy: 0.9233 - val_loss: 0.8174 - val_accuracy: 0.7617
#
# Epoch 00085: val_loss did not improve from 0.72014
# Epoch 86/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6104 - accuracy: 0.9329 - val_loss: 0.8038 - val_accuracy: 0.7695
#
# Epoch 00086: val_loss did not improve from 0.72014
# Epoch 87/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6291 - accuracy: 0.9347 - val_loss: 0.7772 - val_accuracy: 0.7773
#
# Epoch 00087: val_loss did not improve from 0.72014
# Epoch 88/2000
# 34/34 [==============================] - 6s 179ms/step - loss: 0.6744 - accuracy: 0.9288 - val_loss: 0.7636 - val_accuracy: 0.7773
#
# Epoch 00088: val_loss did not improve from 0.72014
# Epoch 89/2000
# 34/34 [==============================] - 5s 144ms/step - loss: 0.5790 - accuracy: 0.9407 - val_loss: 0.7476 - val_accuracy: 0.7812
#
# Epoch 00089: val_loss did not improve from 0.72014
# Epoch 90/2000
# 34/34 [==============================] - 4s 127ms/step - loss: 0.6743 - accuracy: 0.9301 - val_loss: 0.8147 - val_accuracy: 0.7578
#
# Epoch 00090: val_loss did not improve from 0.72014
# Epoch 91/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6332 - accuracy: 0.9297 - val_loss: 0.7912 - val_accuracy: 0.7734
#
# Epoch 00091: val_loss did not improve from 0.72014
# Epoch 92/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6200 - accuracy: 0.9393 - val_loss: 0.7535 - val_accuracy: 0.7695
#
# Epoch 00092: val_loss did not improve from 0.72014
# Epoch 93/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6954 - accuracy: 0.9237 - val_loss: 0.7709 - val_accuracy: 0.7812
#
# Epoch 00093: val_loss did not improve from 0.72014
# Epoch 94/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6609 - accuracy: 0.9306 - val_loss: 0.7660 - val_accuracy: 0.7852
#
# Epoch 00094: val_loss did not improve from 0.72014
# Epoch 95/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6471 - accuracy: 0.9320 - val_loss: 0.7731 - val_accuracy: 0.7812
#
# Epoch 00095: val_loss did not improve from 0.72014
# Epoch 96/2000
# 34/34 [==============================] - 5s 152ms/step - loss: 0.6333 - accuracy: 0.9393 - val_loss: 0.7907 - val_accuracy: 0.7695
#
# Epoch 00096: val_loss did not improve from 0.72014
# Epoch 97/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6371 - accuracy: 0.9320 - val_loss: 0.7923 - val_accuracy: 0.7695
#
# Epoch 00097: val_loss did not improve from 0.72014
# Epoch 98/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6328 - accuracy: 0.9366 - val_loss: 0.7820 - val_accuracy: 0.7656
#
# Epoch 00098: val_loss did not improve from 0.72014
# Epoch 99/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6891 - accuracy: 0.9256 - val_loss: 0.7952 - val_accuracy: 0.7617
#
# Epoch 00099: val_loss did not improve from 0.72014
# Epoch 100/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6881 - accuracy: 0.9251 - val_loss: 0.8014 - val_accuracy: 0.7734
#
# Epoch 00100: val_loss did not improve from 0.72014
# Epoch 101/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6960 - accuracy: 0.9306 - val_loss: 0.7915 - val_accuracy: 0.7773
#
# Epoch 00101: val_loss did not improve from 0.72014
# Epoch 102/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6428 - accuracy: 0.9311 - val_loss: 0.8092 - val_accuracy: 0.7695
#
# Epoch 00102: val_loss did not improve from 0.72014
# Epoch 103/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6496 - accuracy: 0.9324 - val_loss: 0.7882 - val_accuracy: 0.7734
#
# Epoch 00103: val_loss did not improve from 0.72014
# Epoch 104/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6284 - accuracy: 0.9306 - val_loss: 0.7978 - val_accuracy: 0.7734
#
# Epoch 00104: val_loss did not improve from 0.72014
# Epoch 105/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7006 - accuracy: 0.9251 - val_loss: 0.7952 - val_accuracy: 0.7734
#
# Epoch 00105: val_loss did not improve from 0.72014
# Epoch 106/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6696 - accuracy: 0.9338 - val_loss: 0.7955 - val_accuracy: 0.7773
#
# Epoch 00106: val_loss did not improve from 0.72014
# Epoch 107/2000
# 34/34 [==============================] - 5s 147ms/step - loss: 0.7091 - accuracy: 0.9182 - val_loss: 0.7322 - val_accuracy: 0.7852
#
# Epoch 00107: val_loss did not improve from 0.72014
# Epoch 108/2000
# 34/34 [==============================] - 5s 136ms/step - loss: 0.6396 - accuracy: 0.9393 - val_loss: 0.7690 - val_accuracy: 0.7891
#
# Epoch 00108: val_loss did not improve from 0.72014
# Epoch 109/2000
# 34/34 [==============================] - 5s 156ms/step - loss: 0.6557 - accuracy: 0.9301 - val_loss: 0.7518 - val_accuracy: 0.7812
#
# Epoch 00109: val_loss did not improve from 0.72014
# Epoch 110/2000
# 34/34 [==============================] - 5s 145ms/step - loss: 0.5501 - accuracy: 0.9375 - val_loss: 0.7822 - val_accuracy: 0.7812
#
# Epoch 00110: val_loss did not improve from 0.72014
# Epoch 111/2000
# 34/34 [==============================] - 5s 132ms/step - loss: 0.5973 - accuracy: 0.9393 - val_loss: 0.7771 - val_accuracy: 0.7852
#
# Epoch 00111: val_loss did not improve from 0.72014
# Epoch 112/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.5618 - accuracy: 0.9494 - val_loss: 0.7962 - val_accuracy: 0.7773
#
# Epoch 00112: val_loss did not improve from 0.72014
# Epoch 113/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6932 - accuracy: 0.9233 - val_loss: 0.7732 - val_accuracy: 0.7773
#
# Epoch 00113: val_loss did not improve from 0.72014
# Epoch 114/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6224 - accuracy: 0.9334 - val_loss: 0.7824 - val_accuracy: 0.7734
#
# Epoch 00114: val_loss did not improve from 0.72014
# Epoch 115/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.5891 - accuracy: 0.9435 - val_loss: 0.7759 - val_accuracy: 0.7773
#
# Epoch 00115: val_loss did not improve from 0.72014
# Epoch 116/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6162 - accuracy: 0.9329 - val_loss: 0.7464 - val_accuracy: 0.7812
#
# Epoch 00116: val_loss did not improve from 0.72014
# Epoch 117/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6508 - accuracy: 0.9278 - val_loss: 0.7681 - val_accuracy: 0.7773
#
# Epoch 00117: val_loss did not improve from 0.72014
# Epoch 118/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6469 - accuracy: 0.9306 - val_loss: 0.7837 - val_accuracy: 0.7734
#
# Epoch 00118: val_loss did not improve from 0.72014
# Epoch 119/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.5944 - accuracy: 0.9426 - val_loss: 0.7780 - val_accuracy: 0.7656
#
# Epoch 00119: val_loss did not improve from 0.72014
# Epoch 120/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6256 - accuracy: 0.9329 - val_loss: 0.7497 - val_accuracy: 0.7852
#
# Epoch 00120: val_loss did not improve from 0.72014
# Epoch 121/2000
# 34/34 [==============================] - 4s 128ms/step - loss: 0.6167 - accuracy: 0.9361 - val_loss: 0.7787 - val_accuracy: 0.7891
#
# Epoch 00121: val_loss did not improve from 0.72014
# Epoch 122/2000
# 34/34 [==============================] - 5s 137ms/step - loss: 0.6969 - accuracy: 0.9210 - val_loss: 0.7802 - val_accuracy: 0.7812
#
# Epoch 00122: val_loss did not improve from 0.72014
# Epoch 123/2000
# 34/34 [==============================] - 6s 179ms/step - loss: 0.6825 - accuracy: 0.9301 - val_loss: 0.7420 - val_accuracy: 0.7891
#
# Epoch 00123: val_loss did not improve from 0.72014
# Epoch 124/2000
# 34/34 [==============================] - 6s 161ms/step - loss: 0.6308 - accuracy: 0.9329 - val_loss: 0.7814 - val_accuracy: 0.7812
#
# Epoch 00124: val_loss did not improve from 0.72014
# Epoch 125/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7165 - accuracy: 0.9237 - val_loss: 0.7959 - val_accuracy: 0.7734
#
# Epoch 00125: val_loss did not improve from 0.72014
# Epoch 00125: early stopping

# %%
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'

# %%
test_loader = Workout_dataset(
        test_dir, test_label_dir, mode='Test', batch_size=625, shuffle=False)

# %%
model.load_weights(checkpoint_filepath)
model.evaluate_generator(generator=test_loader,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1973: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# 1/1 [==============================] - 1s 1s/step - loss: 0.6061 - accuracy: 0.8272
# [0.606100857257843, 0.8271999955177307]
