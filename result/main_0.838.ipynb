# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3,
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, #0.2
    res_num = 9, # 3, 5, 7
    )

model.summary()
# Out:
# zation_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 120)     480         conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_22[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 120)     480         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_25[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_28[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 120)     480         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_31[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_34[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_37[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_40[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,132,251
# Trainable params: 1,126,311
# Non-trainable params: 5,940
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=20,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 37s 319ms/step - loss: 44.7033 - accuracy: 0.3810 - val_loss: 34.9755 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 34.97549, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 30.9549 - accuracy: 0.5772 - val_loss: 24.0378 - val_accuracy: 0.4531
#
# Epoch 00002: val_loss improved from 34.97549 to 24.03779, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 21.1612 - accuracy: 0.6558 - val_loss: 17.0222 - val_accuracy: 0.4414
#
# Epoch 00003: val_loss improved from 24.03779 to 17.02216, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 14.9668 - accuracy: 0.6981 - val_loss: 12.5615 - val_accuracy: 0.4648
#
# Epoch 00004: val_loss improved from 17.02216 to 12.56153, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 11.0781 - accuracy: 0.7096 - val_loss: 10.0608 - val_accuracy: 0.4570
#
# Epoch 00005: val_loss improved from 12.56153 to 10.06078, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 206ms/step - loss: 8.4044 - accuracy: 0.7348 - val_loss: 8.6491 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 10.06078 to 8.64907, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 6.5603 - accuracy: 0.7463 - val_loss: 7.0222 - val_accuracy: 0.4570
#
# Epoch 00007: val_loss improved from 8.64907 to 7.02217, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 5.3435 - accuracy: 0.7587 - val_loss: 6.3359 - val_accuracy: 0.4531
#
# Epoch 00008: val_loss improved from 7.02217 to 6.33588, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 4.5880 - accuracy: 0.7482 - val_loss: 6.2461 - val_accuracy: 0.4453
#
# Epoch 00009: val_loss improved from 6.33588 to 6.24609, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 3.9364 - accuracy: 0.7633 - val_loss: 7.2588 - val_accuracy: 0.0078
#
# Epoch 00010: val_loss did not improve from 6.24609
# Epoch 11/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 3.4813 - accuracy: 0.7721 - val_loss: 6.0128 - val_accuracy: 0.0938
#
# Epoch 00011: val_loss improved from 6.24609 to 6.01283, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 3.0914 - accuracy: 0.7932 - val_loss: 6.9842 - val_accuracy: 0.0391
#
# Epoch 00012: val_loss did not improve from 6.01283
# Epoch 13/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 2.9431 - accuracy: 0.7904 - val_loss: 7.9453 - val_accuracy: 0.0508
#
# Epoch 00013: val_loss did not improve from 6.01283
# Epoch 14/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.7067 - accuracy: 0.7927 - val_loss: 7.3900 - val_accuracy: 0.0586
#
# Epoch 00014: val_loss did not improve from 6.01283
# Epoch 15/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 2.5028 - accuracy: 0.8088 - val_loss: 5.4628 - val_accuracy: 0.1562
#
# Epoch 00015: val_loss improved from 6.01283 to 5.46284, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.4176 - accuracy: 0.8097 - val_loss: 4.0596 - val_accuracy: 0.3359
#
# Epoch 00016: val_loss improved from 5.46284 to 4.05958, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.4504 - accuracy: 0.8033 - val_loss: 4.0713 - val_accuracy: 0.4570
#
# Epoch 00017: val_loss did not improve from 4.05958
# Epoch 18/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.1850 - accuracy: 0.8199 - val_loss: 2.5044 - val_accuracy: 0.5703
#
# Epoch 00018: val_loss improved from 4.05958 to 2.50435, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.2573 - accuracy: 0.8079 - val_loss: 2.2590 - val_accuracy: 0.5703
#
# Epoch 00019: val_loss improved from 2.50435 to 2.25903, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.1842 - accuracy: 0.8189 - val_loss: 4.8850 - val_accuracy: 0.2539
#
# Epoch 00020: val_loss did not improve from 2.25903
# Epoch 21/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 2.1483 - accuracy: 0.8240 - val_loss: 1.9905 - val_accuracy: 0.6484
#
# Epoch 00021: val_loss improved from 2.25903 to 1.99047, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 1.9076 - accuracy: 0.8410 - val_loss: 2.0763 - val_accuracy: 0.6250
#
# Epoch 00022: val_loss did not improve from 1.99047
# Epoch 23/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 1.7469 - accuracy: 0.8598 - val_loss: 1.7511 - val_accuracy: 0.6797
#
# Epoch 00023: val_loss improved from 1.99047 to 1.75111, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.6605 - accuracy: 0.8603 - val_loss: 1.4472 - val_accuracy: 0.7344
#
# Epoch 00024: val_loss improved from 1.75111 to 1.44724, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.6417 - accuracy: 0.8562 - val_loss: 1.6297 - val_accuracy: 0.6836
#
# Epoch 00025: val_loss did not improve from 1.44724
# Epoch 26/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.5197 - accuracy: 0.8695 - val_loss: 1.3777 - val_accuracy: 0.7188
#
# Epoch 00026: val_loss improved from 1.44724 to 1.37775, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.4483 - accuracy: 0.8801 - val_loss: 1.3197 - val_accuracy: 0.7344
#
# Epoch 00027: val_loss improved from 1.37775 to 1.31975, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 1.4319 - accuracy: 0.8819 - val_loss: 1.2629 - val_accuracy: 0.7344
#
# Epoch 00028: val_loss improved from 1.31975 to 1.26292, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 1.3825 - accuracy: 0.8814 - val_loss: 1.2295 - val_accuracy: 0.7422
#
# Epoch 00029: val_loss improved from 1.26292 to 1.22954, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.3429 - accuracy: 0.8824 - val_loss: 1.3877 - val_accuracy: 0.7031
#
# Epoch 00030: val_loss did not improve from 1.22954
# Epoch 31/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.2564 - accuracy: 0.8920 - val_loss: 1.2195 - val_accuracy: 0.7344
#
# Epoch 00031: val_loss improved from 1.22954 to 1.21953, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.2365 - accuracy: 0.8984 - val_loss: 1.1386 - val_accuracy: 0.7734
#
# Epoch 00032: val_loss improved from 1.21953 to 1.13862, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.2892 - accuracy: 0.8925 - val_loss: 1.2091 - val_accuracy: 0.7539
#
# Epoch 00033: val_loss did not improve from 1.13862
# Epoch 34/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 1.1969 - accuracy: 0.8929 - val_loss: 1.0673 - val_accuracy: 0.7734
#
# Epoch 00034: val_loss improved from 1.13862 to 1.06725, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 1.0675 - accuracy: 0.9104 - val_loss: 1.1273 - val_accuracy: 0.7461
#
# Epoch 00035: val_loss did not improve from 1.06725
# Epoch 36/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.0345 - accuracy: 0.9200 - val_loss: 1.0654 - val_accuracy: 0.7852
#
# Epoch 00036: val_loss improved from 1.06725 to 1.06542, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 8s 241ms/step - loss: 0.9320 - accuracy: 0.9269 - val_loss: 1.0942 - val_accuracy: 0.7773
#
# Epoch 00037: val_loss did not improve from 1.06542
# Epoch 38/2000
# 34/34 [==============================] - 7s 204ms/step - loss: 1.1679 - accuracy: 0.9012 - val_loss: 1.0840 - val_accuracy: 0.7656
#
# Epoch 00038: val_loss did not improve from 1.06542
# Epoch 39/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.9370 - accuracy: 0.9306 - val_loss: 1.0862 - val_accuracy: 0.7539
#
# Epoch 00039: val_loss did not improve from 1.06542
# Epoch 40/2000
# 34/34 [==============================] - 7s 200ms/step - loss: 0.9386 - accuracy: 0.9278 - val_loss: 1.0448 - val_accuracy: 0.7617
#
# Epoch 00040: val_loss improved from 1.06542 to 1.04479, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.9966 - accuracy: 0.9182 - val_loss: 1.0819 - val_accuracy: 0.7539
#
# Epoch 00041: val_loss did not improve from 1.04479
# Epoch 42/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.8782 - accuracy: 0.9320 - val_loss: 1.0105 - val_accuracy: 0.7695
#
# Epoch 00042: val_loss improved from 1.04479 to 1.01050, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.8143 - accuracy: 0.9403 - val_loss: 0.9582 - val_accuracy: 0.7969
#
# Epoch 00043: val_loss improved from 1.01050 to 0.95821, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.9052 - accuracy: 0.9288 - val_loss: 1.0090 - val_accuracy: 0.7852
#
# Epoch 00044: val_loss did not improve from 0.95821
# Epoch 45/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.8865 - accuracy: 0.9256 - val_loss: 1.0208 - val_accuracy: 0.7734
#
# Epoch 00045: val_loss did not improve from 0.95821
# Epoch 46/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.8022 - accuracy: 0.9412 - val_loss: 1.0296 - val_accuracy: 0.7852
#
# Epoch 00046: val_loss did not improve from 0.95821
# Epoch 47/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.8544 - accuracy: 0.9306 - val_loss: 0.9911 - val_accuracy: 0.7852
#
# Epoch 00047: val_loss did not improve from 0.95821
# Epoch 48/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.8363 - accuracy: 0.9352 - val_loss: 0.9832 - val_accuracy: 0.8047
#
# Epoch 00048: val_loss did not improve from 0.95821
# Epoch 49/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7890 - accuracy: 0.9352 - val_loss: 0.9850 - val_accuracy: 0.7773
#
# Epoch 00049: val_loss did not improve from 0.95821
# Epoch 50/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.7370 - accuracy: 0.9499 - val_loss: 0.9893 - val_accuracy: 0.7852
#
# Epoch 00050: val_loss did not improve from 0.95821
# Epoch 51/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.7697 - accuracy: 0.9343 - val_loss: 1.0071 - val_accuracy: 0.7812
#
# Epoch 00051: val_loss did not improve from 0.95821
# Epoch 52/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7962 - accuracy: 0.9412 - val_loss: 0.9927 - val_accuracy: 0.7734
#
# Epoch 00052: val_loss did not improve from 0.95821
# Epoch 53/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6910 - accuracy: 0.9554 - val_loss: 0.9574 - val_accuracy: 0.8008
#
# Epoch 00053: val_loss improved from 0.95821 to 0.95743, saving model to ./save/cnn_gru_best.hdf5
# Epoch 54/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7787 - accuracy: 0.9380 - val_loss: 0.9707 - val_accuracy: 0.7969
#
# Epoch 00054: val_loss did not improve from 0.95743
# Epoch 55/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7837 - accuracy: 0.9380 - val_loss: 0.9847 - val_accuracy: 0.7969
#
# Epoch 00055: val_loss did not improve from 0.95743
# Epoch 56/2000
# 34/34 [==============================] - 7s 198ms/step - loss: 0.7575 - accuracy: 0.9361 - val_loss: 0.9682 - val_accuracy: 0.8047
#
# Epoch 00056: val_loss did not improve from 0.95743
# Epoch 57/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6978 - accuracy: 0.9517 - val_loss: 0.9754 - val_accuracy: 0.8086
#
# Epoch 00057: val_loss did not improve from 0.95743
# Epoch 58/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6797 - accuracy: 0.9508 - val_loss: 0.9634 - val_accuracy: 0.7969
#
# Epoch 00058: val_loss did not improve from 0.95743
# Epoch 59/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.6871 - accuracy: 0.9485 - val_loss: 0.9732 - val_accuracy: 0.7891
#
# Epoch 00059: val_loss did not improve from 0.95743
# Epoch 60/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6413 - accuracy: 0.9499 - val_loss: 0.9733 - val_accuracy: 0.7891
#
# Epoch 00060: val_loss did not improve from 0.95743
# Epoch 61/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.5938 - accuracy: 0.9582 - val_loss: 0.8871 - val_accuracy: 0.7969
#
# Epoch 00061: val_loss improved from 0.95743 to 0.88706, saving model to ./save/cnn_gru_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6404 - accuracy: 0.9545 - val_loss: 0.9985 - val_accuracy: 0.7852
#
# Epoch 00062: val_loss did not improve from 0.88706
# Epoch 63/2000
# 34/34 [==============================] - 7s 207ms/step - loss: 0.6183 - accuracy: 0.9586 - val_loss: 0.9457 - val_accuracy: 0.8008
#
# Epoch 00063: val_loss did not improve from 0.88706
# Epoch 64/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6207 - accuracy: 0.9586 - val_loss: 0.9672 - val_accuracy: 0.7930
#
# Epoch 00064: val_loss did not improve from 0.88706
# Epoch 65/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6696 - accuracy: 0.9499 - val_loss: 0.9702 - val_accuracy: 0.7891
#
# Epoch 00065: val_loss did not improve from 0.88706
# Epoch 66/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6500 - accuracy: 0.9554 - val_loss: 0.9709 - val_accuracy: 0.7969
#
# Epoch 00066: val_loss did not improve from 0.88706
# Epoch 67/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6061 - accuracy: 0.9591 - val_loss: 0.9691 - val_accuracy: 0.8086
#
# Epoch 00067: val_loss did not improve from 0.88706
# Epoch 68/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6955 - accuracy: 0.9458 - val_loss: 0.9591 - val_accuracy: 0.7930
#
# Epoch 00068: val_loss did not improve from 0.88706
# Epoch 69/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.7388 - accuracy: 0.9421 - val_loss: 0.9369 - val_accuracy: 0.7969
#
# Epoch 00069: val_loss did not improve from 0.88706
# Epoch 70/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6715 - accuracy: 0.9563 - val_loss: 0.9815 - val_accuracy: 0.8008
#
# Epoch 00070: val_loss did not improve from 0.88706
# Epoch 71/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6443 - accuracy: 0.9545 - val_loss: 0.9896 - val_accuracy: 0.8047
#
# Epoch 00071: val_loss did not improve from 0.88706
# Epoch 72/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.5766 - accuracy: 0.9623 - val_loss: 0.9701 - val_accuracy: 0.8008
#
# Epoch 00072: val_loss did not improve from 0.88706
# Epoch 73/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.5666 - accuracy: 0.9669 - val_loss: 0.9837 - val_accuracy: 0.7930
#
# Epoch 00073: val_loss did not improve from 0.88706
# Epoch 74/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6122 - accuracy: 0.9596 - val_loss: 0.9842 - val_accuracy: 0.7930
#
# Epoch 00074: val_loss did not improve from 0.88706
# Epoch 75/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6813 - accuracy: 0.9490 - val_loss: 1.0079 - val_accuracy: 0.7812
#
# Epoch 00075: val_loss did not improve from 0.88706
# Epoch 76/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6324 - accuracy: 0.9573 - val_loss: 0.9724 - val_accuracy: 0.7852
#
# Epoch 00076: val_loss did not improve from 0.88706
# Epoch 77/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6358 - accuracy: 0.9573 - val_loss: 1.0030 - val_accuracy: 0.7812
#
# Epoch 00077: val_loss did not improve from 0.88706
# Epoch 78/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7272 - accuracy: 0.9407 - val_loss: 0.9329 - val_accuracy: 0.8047
#
# Epoch 00078: val_loss did not improve from 0.88706
# Epoch 79/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.5994 - accuracy: 0.9573 - val_loss: 0.9810 - val_accuracy: 0.7695
#
# Epoch 00079: val_loss did not improve from 0.88706
# Epoch 80/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6004 - accuracy: 0.9559 - val_loss: 0.9749 - val_accuracy: 0.7812
#
# Epoch 00080: val_loss did not improve from 0.88706
# Epoch 81/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6156 - accuracy: 0.9596 - val_loss: 0.9833 - val_accuracy: 0.7852
#
# Epoch 00081: val_loss did not improve from 0.88706
# Epoch 00081: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7695 - accuracy: 0.8384
# [0.7695387601852417, 0.8384000062942505]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
