# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset

import os

os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
eval_dir = './data/train'
eval_label_dir = './data/data_y_train.csv'
label_dir = './data/data_y_train.csv'

def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

train_y = pd.read_csv('./data/data_y_train.csv')  # label load
label_dict = dict()
for label, label_desc in zip(train_y.label, train_y.label_desc):
    label_dict[label] = label_desc
# 'Squat (kettlebell / goblet)'에서 [/]를 [,]으로 변경
label_dict[45] = 'Squat (kettlebell , goblet)'

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(
    'balanced',
    np.unique(train_y.label),
    train_y.label)

class_weight_dict = dict(zip(
    list(range(61)),
    class_weights+1
    ))

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Input, GlobalAveragePooling1D, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import he_normal

# %%
kernel_size1 = 19
kernel_size2 = 3
kernel_size3 = 5
kk = 10
stride = 2

acc_input_1 = layers.Input(shape=(600, 3))
acc_input_2 = layers.Input(shape=(600, 1))
acc_input_3 = layers.Input(shape=(600, 1))
gy_input_1 = layers.Input(shape=(600, 3))
gy_input_2 = layers.Input(shape=(600, 1))
gy_input_3 = layers.Input(shape=(600, 1))


# conv1_inputs = layers.concatenate([acc_input_1, acc_input_2, gy_input_1, gy_input_2])
conv1_inputs = layers.concatenate([acc_input_1, acc_input_2])

conv1 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv1_inputs)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*2,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)
conv1 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru1)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*6,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)

acc_model = Model([acc_input_1, acc_input_2], gru1)


conv2_inputs = layers.concatenate([gy_input_1, gy_input_2])

conv2 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv2_inputs)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*2,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)
conv2 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru2)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*6,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)

gy_model = Model([gy_input_1, gy_input_2], gru2)

conv3_inputs = layers.concatenate([acc_input_2,gy_input_2])

conv3 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv3_inputs)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*2,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)
conv3 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru3)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*6,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)

mag_model = Model([acc_input_2,gy_input_2], gru3)

conv4_inputs = layers.concatenate([acc_input_1, gy_input_1])

conv4 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv4_inputs)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*2,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)
conv4 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru4)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*6,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)

xyz_model = Model([acc_input_1, gy_input_1], gru4)

concat = layers.concatenate([
    acc_model.output,gy_model.output,
    mag_model.output,xyz_model.output
    ])
    
conv_tot = Conv1D(
    kk*6,kernel_size3,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(concat)
conv_tot = BatchNormalization()(conv_tot)

# pool = layers.AveragePooling1D(9,strides=3,padding='same')(conv1)

# gru = layers.GRU(60)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
#gru = Dropout(0.2,seed=42)(gru)
# gru = layers.GRU(120,return_sequences=True)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.5,seed=42)(gru)
# gru = layers.GRU(60)(gru)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.2,seed=42)(gru)
# outputs = Dense(61, activation='softmax')(gru)

pool = GlobalAveragePooling1D()(conv_tot)
outputs = Dense(61, activation='softmax')(pool)

model = Model([acc_input_1,gy_input_1,acc_input_2,gy_input_2,acc_input_3,gy_input_3],outputs)

model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 4)       0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 2)       0           input_2[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      770         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      770         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      390         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1150        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          conv1d_6[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         conv1d_7[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 150, 240)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 75, 60)       72060       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 60)       240         conv1d_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 191,661
# Trainable params: 190,341
# Non-trainable params: 1,320
# __________________________________________________________________________________________________

# %%
checkpoint_filepath = "simple_cnn_best.hdf5"

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=50,verbose=1)

history = model.fit_generator(
    generator=train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# val_loss: 0.7140 - val_accuracy: 0.7969
#
# Epoch 00053: val_loss did not improve from 0.70817
# Epoch 54/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6303 - accuracy: 0.9361 - val_loss: 0.7480 - val_accuracy: 0.7773
#
# Epoch 00054: val_loss did not improve from 0.70817
# Epoch 55/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6267 - accuracy: 0.9352 - val_loss: 0.7426 - val_accuracy: 0.7891
#
# Epoch 00055: val_loss did not improve from 0.70817
# Epoch 56/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7016 - accuracy: 0.9233 - val_loss: 0.7338 - val_accuracy: 0.7852
#
# Epoch 00056: val_loss did not improve from 0.70817
# Epoch 57/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5992 - accuracy: 0.9375 - val_loss: 0.7284 - val_accuracy: 0.7812
#
# Epoch 00057: val_loss did not improve from 0.70817
# Epoch 58/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6662 - accuracy: 0.9320 - val_loss: 0.7791 - val_accuracy: 0.7656
#
# Epoch 00058: val_loss did not improve from 0.70817
# Epoch 59/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6437 - accuracy: 0.9301 - val_loss: 0.7669 - val_accuracy: 0.7734
#
# Epoch 00059: val_loss did not improve from 0.70817
# Epoch 60/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5718 - accuracy: 0.9472 - val_loss: 0.7096 - val_accuracy: 0.7852
#
# Epoch 00060: val_loss did not improve from 0.70817
# Epoch 61/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.7197 - accuracy: 0.9177 - val_loss: 0.7607 - val_accuracy: 0.7695
#
# Epoch 00061: val_loss did not improve from 0.70817
# Epoch 62/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6665 - accuracy: 0.9288 - val_loss: 0.7608 - val_accuracy: 0.7656
#
# Epoch 00062: val_loss did not improve from 0.70817
# Epoch 63/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7196 - accuracy: 0.9292 - val_loss: 0.7060 - val_accuracy: 0.7969
#
# Epoch 00063: val_loss improved from 0.70817 to 0.70595, saving model to simple_cnn_best.hdf5
# Epoch 64/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6029 - accuracy: 0.9412 - val_loss: 0.7635 - val_accuracy: 0.7734
#
# Epoch 00064: val_loss did not improve from 0.70595
# Epoch 65/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6711 - accuracy: 0.9256 - val_loss: 0.7652 - val_accuracy: 0.7695
#
# Epoch 00065: val_loss did not improve from 0.70595
# Epoch 66/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6324 - accuracy: 0.9283 - val_loss: 0.7684 - val_accuracy: 0.7656
#
# Epoch 00066: val_loss did not improve from 0.70595
# Epoch 67/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6643 - accuracy: 0.9260 - val_loss: 0.7366 - val_accuracy: 0.7734
#
# Epoch 00067: val_loss did not improve from 0.70595
# Epoch 68/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5975 - accuracy: 0.9338 - val_loss: 0.7211 - val_accuracy: 0.7891
#
# Epoch 00068: val_loss did not improve from 0.70595
# Epoch 69/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7253 - accuracy: 0.9237 - val_loss: 0.7329 - val_accuracy: 0.7891
#
# Epoch 00069: val_loss did not improve from 0.70595
# Epoch 70/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6348 - accuracy: 0.9338 - val_loss: 0.7744 - val_accuracy: 0.7656
#
# Epoch 00070: val_loss did not improve from 0.70595
# Epoch 71/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6439 - accuracy: 0.9338 - val_loss: 0.7593 - val_accuracy: 0.7734
#
# Epoch 00071: val_loss did not improve from 0.70595
# Epoch 72/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5672 - accuracy: 0.9416 - val_loss: 0.7210 - val_accuracy: 0.7891
#
# Epoch 00072: val_loss did not improve from 0.70595
# Epoch 73/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6387 - accuracy: 0.9370 - val_loss: 0.6999 - val_accuracy: 0.7969
#
# Epoch 00073: val_loss improved from 0.70595 to 0.69988, saving model to simple_cnn_best.hdf5
# Epoch 74/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.6003 - accuracy: 0.9403 - val_loss: 0.7099 - val_accuracy: 0.7891
#
# Epoch 00074: val_loss did not improve from 0.69988
# Epoch 75/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.5880 - accuracy: 0.9407 - val_loss: 0.7212 - val_accuracy: 0.7930
#
# Epoch 00075: val_loss did not improve from 0.69988
# Epoch 76/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6211 - accuracy: 0.9384 - val_loss: 0.7381 - val_accuracy: 0.7734
#
# Epoch 00076: val_loss did not improve from 0.69988
# Epoch 77/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.6735 - accuracy: 0.9265 - val_loss: 0.7334 - val_accuracy: 0.7891
#
# Epoch 00077: val_loss did not improve from 0.69988
# Epoch 78/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6196 - accuracy: 0.9384 - val_loss: 0.7225 - val_accuracy: 0.7891
#
# Epoch 00078: val_loss did not improve from 0.69988
# Epoch 79/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6686 - accuracy: 0.9223 - val_loss: 0.7490 - val_accuracy: 0.7773
#
# Epoch 00079: val_loss did not improve from 0.69988
# Epoch 80/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6629 - accuracy: 0.9237 - val_loss: 0.7407 - val_accuracy: 0.7734
#
# Epoch 00080: val_loss did not improve from 0.69988
# Epoch 81/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6436 - accuracy: 0.9375 - val_loss: 0.7458 - val_accuracy: 0.7734
#
# Epoch 00081: val_loss did not improve from 0.69988
# Epoch 82/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6333 - accuracy: 0.9347 - val_loss: 0.7585 - val_accuracy: 0.7773
#
# Epoch 00082: val_loss did not improve from 0.69988
# Epoch 83/2000
# 34/34 [==============================] - 4s 113ms/step - loss: 0.6715 - accuracy: 0.9320 - val_loss: 0.7525 - val_accuracy: 0.7773
#
# Epoch 00083: val_loss did not improve from 0.69988
# Epoch 84/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.7218 - accuracy: 0.9274 - val_loss: 0.7443 - val_accuracy: 0.7734
#
# Epoch 00084: val_loss did not improve from 0.69988
# Epoch 85/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.5877 - accuracy: 0.9380 - val_loss: 0.7355 - val_accuracy: 0.7812
#
# Epoch 00085: val_loss did not improve from 0.69988
# Epoch 86/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6261 - accuracy: 0.9361 - val_loss: 0.7824 - val_accuracy: 0.7578
#
# Epoch 00086: val_loss did not improve from 0.69988
# Epoch 87/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.7109 - accuracy: 0.9210 - val_loss: 0.7772 - val_accuracy: 0.7617
#
# Epoch 00087: val_loss did not improve from 0.69988
# Epoch 88/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6233 - accuracy: 0.9320 - val_loss: 0.7247 - val_accuracy: 0.7812
#
# Epoch 00088: val_loss did not improve from 0.69988
# Epoch 89/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.6241 - accuracy: 0.9297 - val_loss: 0.7704 - val_accuracy: 0.7773
#
# Epoch 00089: val_loss did not improve from 0.69988
# Epoch 90/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.7284 - accuracy: 0.9256 - val_loss: 0.7591 - val_accuracy: 0.7734
#
# Epoch 00090: val_loss did not improve from 0.69988
# Epoch 91/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.7242 - accuracy: 0.9191 - val_loss: 0.7748 - val_accuracy: 0.7695
#
# Epoch 00091: val_loss did not improve from 0.69988
# Epoch 92/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6423 - accuracy: 0.9311 - val_loss: 0.7667 - val_accuracy: 0.7695
#
# Epoch 00092: val_loss did not improve from 0.69988
# Epoch 93/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6789 - accuracy: 0.9306 - val_loss: 0.7445 - val_accuracy: 0.7734
#
# Epoch 00093: val_loss did not improve from 0.69988
# Epoch 94/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6204 - accuracy: 0.9288 - val_loss: 0.7274 - val_accuracy: 0.7891
#
# Epoch 00094: val_loss did not improve from 0.69988
# Epoch 95/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6418 - accuracy: 0.9393 - val_loss: 0.7370 - val_accuracy: 0.7891
#
# Epoch 00095: val_loss did not improve from 0.69988
# Epoch 96/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6638 - accuracy: 0.9283 - val_loss: 0.7107 - val_accuracy: 0.7891
#
# Epoch 00096: val_loss did not improve from 0.69988
# Epoch 97/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6450 - accuracy: 0.9274 - val_loss: 0.7499 - val_accuracy: 0.7773
#
# Epoch 00097: val_loss did not improve from 0.69988
# Epoch 98/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7034 - accuracy: 0.9219 - val_loss: 0.7420 - val_accuracy: 0.7812
#
# Epoch 00098: val_loss did not improve from 0.69988
# Epoch 99/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6697 - accuracy: 0.9306 - val_loss: 0.7397 - val_accuracy: 0.7852
#
# Epoch 00099: val_loss did not improve from 0.69988
# Epoch 100/2000
# 34/34 [==============================] - 4s 113ms/step - loss: 0.6064 - accuracy: 0.9380 - val_loss: 0.7201 - val_accuracy: 0.7891
#
# Epoch 00100: val_loss did not improve from 0.69988
# Epoch 101/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.7294 - accuracy: 0.9187 - val_loss: 0.7154 - val_accuracy: 0.7773
#
# Epoch 00101: val_loss did not improve from 0.69988
# Epoch 102/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6245 - accuracy: 0.9343 - val_loss: 0.7426 - val_accuracy: 0.7812
#
# Epoch 00102: val_loss did not improve from 0.69988
# Epoch 103/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7194 - accuracy: 0.9233 - val_loss: 0.6897 - val_accuracy: 0.7930
#
# Epoch 00103: val_loss improved from 0.69988 to 0.68971, saving model to simple_cnn_best.hdf5
# Epoch 104/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6226 - accuracy: 0.9370 - val_loss: 0.7763 - val_accuracy: 0.7734
#
# Epoch 00104: val_loss did not improve from 0.68971
# Epoch 105/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6618 - accuracy: 0.9347 - val_loss: 0.7229 - val_accuracy: 0.7852
#
# Epoch 00105: val_loss did not improve from 0.68971
# Epoch 106/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6822 - accuracy: 0.9306 - val_loss: 0.7587 - val_accuracy: 0.7695
#
# Epoch 00106: val_loss did not improve from 0.68971
# Epoch 107/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6512 - accuracy: 0.9338 - val_loss: 0.7737 - val_accuracy: 0.7695
#
# Epoch 00107: val_loss did not improve from 0.68971
# Epoch 108/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6386 - accuracy: 0.9315 - val_loss: 0.7773 - val_accuracy: 0.7656
#
# Epoch 00108: val_loss did not improve from 0.68971
# Epoch 109/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5614 - accuracy: 0.9412 - val_loss: 0.7365 - val_accuracy: 0.7891
#
# Epoch 00109: val_loss did not improve from 0.68971
# Epoch 110/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5427 - accuracy: 0.9453 - val_loss: 0.7103 - val_accuracy: 0.7930
#
# Epoch 00110: val_loss did not improve from 0.68971
# Epoch 111/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6245 - accuracy: 0.9361 - val_loss: 0.7701 - val_accuracy: 0.7734
#
# Epoch 00111: val_loss did not improve from 0.68971
# Epoch 112/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5985 - accuracy: 0.9366 - val_loss: 0.7615 - val_accuracy: 0.7695
#
# Epoch 00112: val_loss did not improve from 0.68971
# Epoch 113/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5792 - accuracy: 0.9430 - val_loss: 0.7271 - val_accuracy: 0.7852
#
# Epoch 00113: val_loss did not improve from 0.68971
# Epoch 114/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7344 - accuracy: 0.9173 - val_loss: 0.7693 - val_accuracy: 0.7617
#
# Epoch 00114: val_loss did not improve from 0.68971
# Epoch 115/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5583 - accuracy: 0.9384 - val_loss: 0.7522 - val_accuracy: 0.7773
#
# Epoch 00115: val_loss did not improve from 0.68971
# Epoch 116/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5672 - accuracy: 0.9366 - val_loss: 0.7285 - val_accuracy: 0.7930
#
# Epoch 00116: val_loss did not improve from 0.68971
# Epoch 117/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7118 - accuracy: 0.9242 - val_loss: 0.7360 - val_accuracy: 0.7891
#
# Epoch 00117: val_loss did not improve from 0.68971
# Epoch 118/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6295 - accuracy: 0.9306 - val_loss: 0.6962 - val_accuracy: 0.7891
#
# Epoch 00118: val_loss did not improve from 0.68971
# Epoch 119/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6360 - accuracy: 0.9347 - val_loss: 0.7425 - val_accuracy: 0.7852
#
# Epoch 00119: val_loss did not improve from 0.68971
# Epoch 120/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5896 - accuracy: 0.9393 - val_loss: 0.7230 - val_accuracy: 0.7930
#
# Epoch 00120: val_loss did not improve from 0.68971
# Epoch 121/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.5983 - accuracy: 0.9334 - val_loss: 0.7793 - val_accuracy: 0.7578
#
# Epoch 00121: val_loss did not improve from 0.68971
# Epoch 122/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6347 - accuracy: 0.9324 - val_loss: 0.7629 - val_accuracy: 0.7773
#
# Epoch 00122: val_loss did not improve from 0.68971
# Epoch 123/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6169 - accuracy: 0.9366 - val_loss: 0.7747 - val_accuracy: 0.7656
#
# Epoch 00123: val_loss did not improve from 0.68971
# Epoch 124/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5745 - accuracy: 0.9389 - val_loss: 0.7529 - val_accuracy: 0.7812
#
# Epoch 00124: val_loss did not improve from 0.68971
# Epoch 125/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5807 - accuracy: 0.9366 - val_loss: 0.7418 - val_accuracy: 0.7969
#
# Epoch 00125: val_loss did not improve from 0.68971
# Epoch 126/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6500 - accuracy: 0.9297 - val_loss: 0.7179 - val_accuracy: 0.8047
#
# Epoch 00126: val_loss did not improve from 0.68971
# Epoch 127/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6714 - accuracy: 0.9329 - val_loss: 0.7427 - val_accuracy: 0.8008
#
# Epoch 00127: val_loss did not improve from 0.68971
# Epoch 128/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6652 - accuracy: 0.9352 - val_loss: 0.7499 - val_accuracy: 0.7852
#
# Epoch 00128: val_loss did not improve from 0.68971
# Epoch 129/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.5759 - accuracy: 0.9449 - val_loss: 0.7588 - val_accuracy: 0.7773
#
# Epoch 00129: val_loss did not improve from 0.68971
# Epoch 130/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6403 - accuracy: 0.9352 - val_loss: 0.7655 - val_accuracy: 0.7852
#
# Epoch 00130: val_loss did not improve from 0.68971
# Epoch 131/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6198 - accuracy: 0.9324 - val_loss: 0.7147 - val_accuracy: 0.7852
#
# Epoch 00131: val_loss did not improve from 0.68971
# Epoch 132/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6251 - accuracy: 0.9283 - val_loss: 0.7411 - val_accuracy: 0.7969
#
# Epoch 00132: val_loss did not improve from 0.68971
# Epoch 133/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5962 - accuracy: 0.9403 - val_loss: 0.7699 - val_accuracy: 0.7773
#
# Epoch 00133: val_loss did not improve from 0.68971
# Epoch 134/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6569 - accuracy: 0.9256 - val_loss: 0.7917 - val_accuracy: 0.7695
#
# Epoch 00134: val_loss did not improve from 0.68971
# Epoch 135/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6379 - accuracy: 0.9347 - val_loss: 0.7618 - val_accuracy: 0.7852
#
# Epoch 00135: val_loss did not improve from 0.68971
# Epoch 136/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5693 - accuracy: 0.9435 - val_loss: 0.7671 - val_accuracy: 0.7852
#
# Epoch 00136: val_loss did not improve from 0.68971
# Epoch 137/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6359 - accuracy: 0.9366 - val_loss: 0.7392 - val_accuracy: 0.7969
#
# Epoch 00137: val_loss did not improve from 0.68971
# Epoch 138/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.7036 - accuracy: 0.9233 - val_loss: 0.7924 - val_accuracy: 0.7617
#
# Epoch 00138: val_loss did not improve from 0.68971
# Epoch 139/2000
# 34/34 [==============================] - 6s 187ms/step - loss: 0.5323 - accuracy: 0.9462 - val_loss: 0.7300 - val_accuracy: 0.7852
#
# Epoch 00139: val_loss did not improve from 0.68971
# Epoch 140/2000
# 34/34 [==============================] - 5s 142ms/step - loss: 0.5831 - accuracy: 0.9393 - val_loss: 0.7638 - val_accuracy: 0.7812
#
# Epoch 00140: val_loss did not improve from 0.68971
# Epoch 141/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6058 - accuracy: 0.9329 - val_loss: 0.7682 - val_accuracy: 0.7852
#
# Epoch 00141: val_loss did not improve from 0.68971
# Epoch 142/2000
# 34/34 [==============================] - 6s 176ms/step - loss: 0.5908 - accuracy: 0.9352 - val_loss: 0.7698 - val_accuracy: 0.7812
#
# Epoch 00142: val_loss did not improve from 0.68971
# Epoch 143/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6005 - accuracy: 0.9384 - val_loss: 0.7732 - val_accuracy: 0.7734
#
# Epoch 00143: val_loss did not improve from 0.68971
# Epoch 144/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6677 - accuracy: 0.9320 - val_loss: 0.7810 - val_accuracy: 0.7734
#
# Epoch 00144: val_loss did not improve from 0.68971
# Epoch 145/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6415 - accuracy: 0.9306 - val_loss: 0.7729 - val_accuracy: 0.7773
#
# Epoch 00145: val_loss did not improve from 0.68971
# Epoch 146/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5966 - accuracy: 0.9352 - val_loss: 0.6933 - val_accuracy: 0.7930
#
# Epoch 00146: val_loss did not improve from 0.68971
# Epoch 147/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5569 - accuracy: 0.9508 - val_loss: 0.7047 - val_accuracy: 0.8047
#
# Epoch 00147: val_loss did not improve from 0.68971
# Epoch 148/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.5286 - accuracy: 0.9517 - val_loss: 0.7253 - val_accuracy: 0.8008
#
# Epoch 00148: val_loss did not improve from 0.68971
# Epoch 149/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.7595 - accuracy: 0.9242 - val_loss: 0.7769 - val_accuracy: 0.7852
#
# Epoch 00149: val_loss did not improve from 0.68971
# Epoch 150/2000
# 34/34 [==============================] - 5s 160ms/step - loss: 0.6245 - accuracy: 0.9334 - val_loss: 0.7638 - val_accuracy: 0.7773
#
# Epoch 00150: val_loss did not improve from 0.68971
# Epoch 151/2000
# 34/34 [==============================] - 4s 127ms/step - loss: 0.6372 - accuracy: 0.9292 - val_loss: 0.7499 - val_accuracy: 0.7930
#
# Epoch 00151: val_loss did not improve from 0.68971
# Epoch 152/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.6676 - accuracy: 0.9301 - val_loss: 0.7832 - val_accuracy: 0.7656
#
# Epoch 00152: val_loss did not improve from 0.68971
# Epoch 153/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.5667 - accuracy: 0.9426 - val_loss: 0.7849 - val_accuracy: 0.7773
#
# Epoch 00153: val_loss did not improve from 0.68971
# Epoch 00153: early stopping

# %%
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'

# %%
test_loader = Workout_dataset(
        test_dir, test_label_dir, mode='Test', batch_size=625, shuffle=False)

# %%
model.load_weights(checkpoint_filepath)
model.evaluate_generator(generator=test_loader,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1973: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# 1/1 [==============================] - 1s 826ms/step - loss: 0.6449 - accuracy: 0.8096
# [0.6449459791183472, 0.8095999956130981]
