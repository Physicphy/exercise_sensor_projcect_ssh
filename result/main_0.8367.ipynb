# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3,
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, #0.2
    res_num = 9, # 3, 5, 7
    )

model.summary()
# Out:
# zation_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 120)     480         conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_22[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 120)     480         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_25[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_28[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 120)     480         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_31[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_34[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_37[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_40[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,132,251
# Trainable params: 1,126,311
# Non-trainable params: 5,940
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=20,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 37s 316ms/step - loss: 43.8469 - accuracy: 0.3208 - val_loss: 32.7057 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.70571, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 28.8263 - accuracy: 0.5533 - val_loss: 21.4898 - val_accuracy: 0.4531
#
# Epoch 00002: val_loss improved from 32.70571 to 21.48985, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 18.9964 - accuracy: 0.6489 - val_loss: 14.7282 - val_accuracy: 0.4414
#
# Epoch 00003: val_loss improved from 21.48985 to 14.72824, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 13.0102 - accuracy: 0.6893 - val_loss: 10.6223 - val_accuracy: 0.4648
#
# Epoch 00004: val_loss improved from 14.72824 to 10.62232, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 9.6703 - accuracy: 0.6962 - val_loss: 8.3347 - val_accuracy: 0.4570
#
# Epoch 00005: val_loss improved from 10.62232 to 8.33466, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 7.3595 - accuracy: 0.7178 - val_loss: 7.0181 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 8.33466 to 7.01805, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 5.8129 - accuracy: 0.7344 - val_loss: 6.0479 - val_accuracy: 0.4570
#
# Epoch 00007: val_loss improved from 7.01805 to 6.04792, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 4.8347 - accuracy: 0.7422 - val_loss: 5.7212 - val_accuracy: 0.4531
#
# Epoch 00008: val_loss improved from 6.04792 to 5.72121, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 4.3525 - accuracy: 0.7275 - val_loss: 6.1982 - val_accuracy: 0.3633
#
# Epoch 00009: val_loss did not improve from 5.72121
# Epoch 10/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 3.7766 - accuracy: 0.7560 - val_loss: 6.4813 - val_accuracy: 0.0117
#
# Epoch 00010: val_loss did not improve from 5.72121
# Epoch 11/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 3.3247 - accuracy: 0.7698 - val_loss: 5.6193 - val_accuracy: 0.0664
#
# Epoch 00011: val_loss improved from 5.72121 to 5.61929, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.9358 - accuracy: 0.7950 - val_loss: 6.6450 - val_accuracy: 0.0352
#
# Epoch 00012: val_loss did not improve from 5.61929
# Epoch 13/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.9385 - accuracy: 0.7734 - val_loss: 6.3425 - val_accuracy: 0.0664
#
# Epoch 00013: val_loss did not improve from 5.61929
# Epoch 14/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.6543 - accuracy: 0.7955 - val_loss: 5.6215 - val_accuracy: 0.0586
#
# Epoch 00014: val_loss did not improve from 5.61929
# Epoch 15/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 2.4802 - accuracy: 0.8093 - val_loss: 4.7058 - val_accuracy: 0.1875
#
# Epoch 00015: val_loss improved from 5.61929 to 4.70579, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 2.4635 - accuracy: 0.8028 - val_loss: 4.6603 - val_accuracy: 0.1641
#
# Epoch 00016: val_loss improved from 4.70579 to 4.66027, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.4373 - accuracy: 0.7978 - val_loss: 3.8212 - val_accuracy: 0.3711
#
# Epoch 00017: val_loss improved from 4.66027 to 3.82118, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 2.2025 - accuracy: 0.8222 - val_loss: 2.1926 - val_accuracy: 0.6328
#
# Epoch 00018: val_loss improved from 3.82118 to 2.19261, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.3080 - accuracy: 0.8084 - val_loss: 2.0526 - val_accuracy: 0.6094
#
# Epoch 00019: val_loss improved from 2.19261 to 2.05256, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 2.2360 - accuracy: 0.8166 - val_loss: 2.6579 - val_accuracy: 0.4922
#
# Epoch 00020: val_loss did not improve from 2.05256
# Epoch 21/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 2.1316 - accuracy: 0.8240 - val_loss: 1.6676 - val_accuracy: 0.6914
#
# Epoch 00021: val_loss improved from 2.05256 to 1.66757, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.9530 - accuracy: 0.8369 - val_loss: 1.9177 - val_accuracy: 0.5977
#
# Epoch 00022: val_loss did not improve from 1.66757
# Epoch 23/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.6935 - accuracy: 0.8621 - val_loss: 1.5072 - val_accuracy: 0.6914
#
# Epoch 00023: val_loss improved from 1.66757 to 1.50724, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.7109 - accuracy: 0.8502 - val_loss: 1.7906 - val_accuracy: 0.6523
#
# Epoch 00024: val_loss did not improve from 1.50724
# Epoch 25/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.6477 - accuracy: 0.8571 - val_loss: 1.3835 - val_accuracy: 0.7070
#
# Epoch 00025: val_loss improved from 1.50724 to 1.38355, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.4812 - accuracy: 0.8819 - val_loss: 1.1892 - val_accuracy: 0.7734
#
# Epoch 00026: val_loss improved from 1.38355 to 1.18919, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.4403 - accuracy: 0.8713 - val_loss: 1.3704 - val_accuracy: 0.7070
#
# Epoch 00027: val_loss did not improve from 1.18919
# Epoch 28/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.4206 - accuracy: 0.8805 - val_loss: 1.1435 - val_accuracy: 0.7812
#
# Epoch 00028: val_loss improved from 1.18919 to 1.14350, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.3554 - accuracy: 0.8842 - val_loss: 1.1277 - val_accuracy: 0.7695
#
# Epoch 00029: val_loss improved from 1.14350 to 1.12770, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.3474 - accuracy: 0.8819 - val_loss: 1.2672 - val_accuracy: 0.7227
#
# Epoch 00030: val_loss did not improve from 1.12770
# Epoch 31/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.2491 - accuracy: 0.8952 - val_loss: 1.2535 - val_accuracy: 0.7305
#
# Epoch 00031: val_loss did not improve from 1.12770
# Epoch 32/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.2424 - accuracy: 0.8989 - val_loss: 1.1373 - val_accuracy: 0.7539
#
# Epoch 00032: val_loss did not improve from 1.12770
# Epoch 33/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.2753 - accuracy: 0.8934 - val_loss: 1.1081 - val_accuracy: 0.7695
#
# Epoch 00033: val_loss improved from 1.12770 to 1.10808, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 1.1729 - accuracy: 0.8984 - val_loss: 0.9651 - val_accuracy: 0.8008
#
# Epoch 00034: val_loss improved from 1.10808 to 0.96507, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 1.0582 - accuracy: 0.9145 - val_loss: 1.0636 - val_accuracy: 0.7617
#
# Epoch 00035: val_loss did not improve from 0.96507
# Epoch 36/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.0312 - accuracy: 0.9150 - val_loss: 0.9325 - val_accuracy: 0.8203
#
# Epoch 00036: val_loss improved from 0.96507 to 0.93252, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.9275 - accuracy: 0.9260 - val_loss: 0.9884 - val_accuracy: 0.7969
#
# Epoch 00037: val_loss did not improve from 0.93252
# Epoch 38/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.1774 - accuracy: 0.8998 - val_loss: 0.9708 - val_accuracy: 0.7734
#
# Epoch 00038: val_loss did not improve from 0.93252
# Epoch 39/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.9379 - accuracy: 0.9283 - val_loss: 0.9502 - val_accuracy: 0.7930
#
# Epoch 00039: val_loss did not improve from 0.93252
# Epoch 40/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.9530 - accuracy: 0.9228 - val_loss: 0.9259 - val_accuracy: 0.8281
#
# Epoch 00040: val_loss improved from 0.93252 to 0.92588, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.9963 - accuracy: 0.9154 - val_loss: 1.0132 - val_accuracy: 0.7852
#
# Epoch 00041: val_loss did not improve from 0.92588
# Epoch 42/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.9404 - accuracy: 0.9246 - val_loss: 0.8944 - val_accuracy: 0.8164
#
# Epoch 00042: val_loss improved from 0.92588 to 0.89439, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8046 - accuracy: 0.9393 - val_loss: 0.8544 - val_accuracy: 0.8164
#
# Epoch 00043: val_loss improved from 0.89439 to 0.85441, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.9109 - accuracy: 0.9274 - val_loss: 0.9546 - val_accuracy: 0.7812
#
# Epoch 00044: val_loss did not improve from 0.85441
# Epoch 45/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8729 - accuracy: 0.9278 - val_loss: 0.9735 - val_accuracy: 0.7969
#
# Epoch 00045: val_loss did not improve from 0.85441
# Epoch 46/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7980 - accuracy: 0.9403 - val_loss: 0.9614 - val_accuracy: 0.8125
#
# Epoch 00046: val_loss did not improve from 0.85441
# Epoch 47/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.8600 - accuracy: 0.9301 - val_loss: 0.9406 - val_accuracy: 0.8164
#
# Epoch 00047: val_loss did not improve from 0.85441
# Epoch 48/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.8474 - accuracy: 0.9320 - val_loss: 0.9634 - val_accuracy: 0.7969
#
# Epoch 00048: val_loss did not improve from 0.85441
# Epoch 49/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8301 - accuracy: 0.9343 - val_loss: 0.9202 - val_accuracy: 0.7969
#
# Epoch 00049: val_loss did not improve from 0.85441
# Epoch 50/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.7542 - accuracy: 0.9462 - val_loss: 0.9455 - val_accuracy: 0.8164
#
# Epoch 00050: val_loss did not improve from 0.85441
# Epoch 51/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7787 - accuracy: 0.9389 - val_loss: 0.9491 - val_accuracy: 0.7969
#
# Epoch 00051: val_loss did not improve from 0.85441
# Epoch 52/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.8001 - accuracy: 0.9338 - val_loss: 0.9543 - val_accuracy: 0.7969
#
# Epoch 00052: val_loss did not improve from 0.85441
# Epoch 53/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.6998 - accuracy: 0.9513 - val_loss: 0.9093 - val_accuracy: 0.8047
#
# Epoch 00053: val_loss did not improve from 0.85441
# Epoch 54/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.7880 - accuracy: 0.9380 - val_loss: 0.9138 - val_accuracy: 0.7930
#
# Epoch 00054: val_loss did not improve from 0.85441
# Epoch 55/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8338 - accuracy: 0.9251 - val_loss: 0.9418 - val_accuracy: 0.7891
#
# Epoch 00055: val_loss did not improve from 0.85441
# Epoch 56/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7319 - accuracy: 0.9398 - val_loss: 0.9508 - val_accuracy: 0.8047
#
# Epoch 00056: val_loss did not improve from 0.85441
# Epoch 57/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6960 - accuracy: 0.9462 - val_loss: 0.9282 - val_accuracy: 0.8008
#
# Epoch 00057: val_loss did not improve from 0.85441
# Epoch 58/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6989 - accuracy: 0.9485 - val_loss: 0.9220 - val_accuracy: 0.7930
#
# Epoch 00058: val_loss did not improve from 0.85441
# Epoch 59/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6974 - accuracy: 0.9453 - val_loss: 0.9067 - val_accuracy: 0.8008
#
# Epoch 00059: val_loss did not improve from 0.85441
# Epoch 60/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6381 - accuracy: 0.9554 - val_loss: 0.9144 - val_accuracy: 0.7969
#
# Epoch 00060: val_loss did not improve from 0.85441
# Epoch 61/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.5907 - accuracy: 0.9642 - val_loss: 0.8345 - val_accuracy: 0.8203
#
# Epoch 00061: val_loss improved from 0.85441 to 0.83451, saving model to ./save/cnn_gru_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6498 - accuracy: 0.9540 - val_loss: 0.9385 - val_accuracy: 0.7969
#
# Epoch 00062: val_loss did not improve from 0.83451
# Epoch 63/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6304 - accuracy: 0.9577 - val_loss: 0.9098 - val_accuracy: 0.8242
#
# Epoch 00063: val_loss did not improve from 0.83451
# Epoch 64/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6160 - accuracy: 0.9545 - val_loss: 0.9255 - val_accuracy: 0.8008
#
# Epoch 00064: val_loss did not improve from 0.83451
# Epoch 65/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7091 - accuracy: 0.9449 - val_loss: 0.9311 - val_accuracy: 0.8047
#
# Epoch 00065: val_loss did not improve from 0.83451
# Epoch 66/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6739 - accuracy: 0.9499 - val_loss: 0.9315 - val_accuracy: 0.8047
#
# Epoch 00066: val_loss did not improve from 0.83451
# Epoch 67/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6029 - accuracy: 0.9628 - val_loss: 0.9235 - val_accuracy: 0.8008
#
# Epoch 00067: val_loss did not improve from 0.83451
# Epoch 68/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6716 - accuracy: 0.9494 - val_loss: 0.9187 - val_accuracy: 0.8008
#
# Epoch 00068: val_loss did not improve from 0.83451
# Epoch 69/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7519 - accuracy: 0.9352 - val_loss: 0.9056 - val_accuracy: 0.8164
#
# Epoch 00069: val_loss did not improve from 0.83451
# Epoch 70/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6943 - accuracy: 0.9490 - val_loss: 0.9251 - val_accuracy: 0.8008
#
# Epoch 00070: val_loss did not improve from 0.83451
# Epoch 71/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6896 - accuracy: 0.9467 - val_loss: 0.9352 - val_accuracy: 0.7930
#
# Epoch 00071: val_loss did not improve from 0.83451
# Epoch 72/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.5936 - accuracy: 0.9563 - val_loss: 0.9111 - val_accuracy: 0.8008
#
# Epoch 00072: val_loss did not improve from 0.83451
# Epoch 73/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.5872 - accuracy: 0.9605 - val_loss: 0.9339 - val_accuracy: 0.8125
#
# Epoch 00073: val_loss did not improve from 0.83451
# Epoch 74/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.6172 - accuracy: 0.9517 - val_loss: 0.9247 - val_accuracy: 0.8164
#
# Epoch 00074: val_loss did not improve from 0.83451
# Epoch 75/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6964 - accuracy: 0.9472 - val_loss: 0.9661 - val_accuracy: 0.8008
#
# Epoch 00075: val_loss did not improve from 0.83451
# Epoch 76/2000
# 34/34 [==============================] - 7s 202ms/step - loss: 0.6533 - accuracy: 0.9490 - val_loss: 0.9246 - val_accuracy: 0.7969
#
# Epoch 00076: val_loss did not improve from 0.83451
# Epoch 77/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6439 - accuracy: 0.9568 - val_loss: 0.9545 - val_accuracy: 0.7930
#
# Epoch 00077: val_loss did not improve from 0.83451
# Epoch 78/2000
# 34/34 [==============================] - 7s 203ms/step - loss: 0.7246 - accuracy: 0.9398 - val_loss: 0.9033 - val_accuracy: 0.7969
#
# Epoch 00078: val_loss did not improve from 0.83451
# Epoch 79/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6092 - accuracy: 0.9540 - val_loss: 0.9367 - val_accuracy: 0.7891
#
# Epoch 00079: val_loss did not improve from 0.83451
# Epoch 80/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.6202 - accuracy: 0.9540 - val_loss: 0.9510 - val_accuracy: 0.7852
#
# Epoch 00080: val_loss did not improve from 0.83451
# Epoch 81/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.6309 - accuracy: 0.9527 - val_loss: 0.9379 - val_accuracy: 0.7969
#
# Epoch 00081: val_loss did not improve from 0.83451
# Epoch 00081: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 985ms/step - loss: 0.7585 - accuracy: 0.8368
# [0.7584889531135559, 0.8367999792098999]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
