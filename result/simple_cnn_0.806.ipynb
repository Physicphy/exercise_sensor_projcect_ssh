# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset

import os

os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
eval_dir = './data/train'
eval_label_dir = './data/data_y_train.csv'
label_dir = './data/data_y_train.csv'

def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

train_y = pd.read_csv('./data/data_y_train.csv')  # label load
label_dict = dict()
for label, label_desc in zip(train_y.label, train_y.label_desc):
    label_dict[label] = label_desc
# 'Squat (kettlebell / goblet)'에서 [/]를 [,]으로 변경
label_dict[45] = 'Squat (kettlebell , goblet)'

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(
    'balanced',
    np.unique(train_y.label),
    train_y.label)

class_weight_dict = dict(zip(
    list(range(61)),
    class_weights+1
    ))

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Input, GlobalAveragePooling1D, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import he_normal

# %%
kernel_size1 = 19
kernel_size2 = 3
kernel_size3 = 5
kk = 10
stride = 2

acc_input_1 = layers.Input(shape=(600, 3))
acc_input_2 = layers.Input(shape=(600, 1))
acc_input_3 = layers.Input(shape=(600, 1))
gy_input_1 = layers.Input(shape=(600, 3))
gy_input_2 = layers.Input(shape=(600, 1))
gy_input_3 = layers.Input(shape=(600, 1))


# conv1_inputs = layers.concatenate([acc_input_1, acc_input_2, gy_input_1, gy_input_2])
conv1_inputs = layers.concatenate([acc_input_1, acc_input_2, acc_input_3])

conv1 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv1_inputs)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*2,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)
conv1 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru1)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*6,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)

acc_model = Model([acc_input_1, acc_input_2, acc_input_3], gru1)


conv2_inputs = layers.concatenate([gy_input_1, gy_input_2, gy_input_3])

conv2 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv2_inputs)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*2,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)
conv2 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru2)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*6,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)

gy_model = Model([gy_input_1, gy_input_2, gy_input_3], gru2)

conv3_inputs = layers.concatenate([acc_input_2,gy_input_2, acc_input_3, gy_input_3])

conv3 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv3_inputs)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*2,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)
conv3 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru3)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*6,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)

mag_model = Model([acc_input_2,gy_input_2, acc_input_3, gy_input_3], gru3)

conv4_inputs = layers.concatenate([acc_input_1, gy_input_1])

conv4 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv4_inputs)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*2,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)
conv4 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru4)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*6,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)

xyz_model = Model([acc_input_1, gy_input_1], gru4)

concat = layers.concatenate([
    acc_model.output,gy_model.output,
    mag_model.output,xyz_model.output
    ])
    
conv_tot = Conv1D(
    kk*6,kernel_size3,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(concat)
conv_tot = BatchNormalization()(conv_tot)

# pool = layers.AveragePooling1D(9,strides=3,padding='same')(conv1)

# gru = layers.GRU(60)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
#gru = Dropout(0.2,seed=42)(gru)
# gru = layers.GRU(120,return_sequences=True)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.5,seed=42)(gru)
# gru = layers.GRU(60)(gru)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.2,seed=42)(gru)
# outputs = Dense(61, activation='softmax')(gru)

pool = GlobalAveragePooling1D()(conv_tot)
outputs = Dense(61, activation='softmax')(pool)

model = Model([acc_input_1,gy_input_1,acc_input_2,gy_input_2,acc_input_3,gy_input_3],outputs)

model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_4[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_5[0][0]
#                                                                  input_3[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      960         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      960         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      770         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1150        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          conv1d_6[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         conv1d_7[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 150, 240)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 75, 60)       72060       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 60)       240         conv1d_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 192,421
# Trainable params: 191,101
# Non-trainable params: 1,320
# __________________________________________________________________________________________________

# %%
checkpoint_filepath = "simple_cnn_best.hdf5"

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=50,verbose=1)

history = model.fit_generator(
    generator=train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# loss did not improve from 0.82170
# Epoch 28/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.9542 - accuracy: 0.8948 - val_loss: 0.8065 - val_accuracy: 0.7500
#
# Epoch 00028: val_loss improved from 0.82170 to 0.80649, saving model to simple_cnn_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.9449 - accuracy: 0.9021 - val_loss: 0.9506 - val_accuracy: 0.7383
#
# Epoch 00029: val_loss did not improve from 0.80649
# Epoch 30/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.9849 - accuracy: 0.8897 - val_loss: 0.9373 - val_accuracy: 0.7305
#
# Epoch 00030: val_loss did not improve from 0.80649
# Epoch 31/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 1.0272 - accuracy: 0.8860 - val_loss: 0.8524 - val_accuracy: 0.7734
#
# Epoch 00031: val_loss did not improve from 0.80649
# Epoch 32/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.8597 - accuracy: 0.9026 - val_loss: 0.8970 - val_accuracy: 0.7617
#
# Epoch 00032: val_loss did not improve from 0.80649
# Epoch 33/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.8410 - accuracy: 0.9090 - val_loss: 0.7937 - val_accuracy: 0.7656
#
# Epoch 00033: val_loss improved from 0.80649 to 0.79370, saving model to simple_cnn_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.8129 - accuracy: 0.9159 - val_loss: 0.8128 - val_accuracy: 0.7852
#
# Epoch 00034: val_loss did not improve from 0.79370
# Epoch 35/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.8324 - accuracy: 0.9113 - val_loss: 0.8155 - val_accuracy: 0.7734
#
# Epoch 00035: val_loss did not improve from 0.79370
# Epoch 36/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.8250 - accuracy: 0.9127 - val_loss: 0.7726 - val_accuracy: 0.7930
#
# Epoch 00036: val_loss improved from 0.79370 to 0.77261, saving model to simple_cnn_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7889 - accuracy: 0.9113 - val_loss: 0.6904 - val_accuracy: 0.8047
#
# Epoch 00037: val_loss improved from 0.77261 to 0.69043, saving model to simple_cnn_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6465 - accuracy: 0.9329 - val_loss: 0.7609 - val_accuracy: 0.7969
#
# Epoch 00038: val_loss did not improve from 0.69043
# Epoch 39/2000
# 34/34 [==============================] - 4s 130ms/step - loss: 0.7559 - accuracy: 0.9233 - val_loss: 0.7718 - val_accuracy: 0.7852
#
# Epoch 00039: val_loss did not improve from 0.69043
# Epoch 40/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.8065 - accuracy: 0.9154 - val_loss: 0.7767 - val_accuracy: 0.7812
#
# Epoch 00040: val_loss did not improve from 0.69043
# Epoch 41/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7370 - accuracy: 0.9251 - val_loss: 0.7488 - val_accuracy: 0.7891
#
# Epoch 00041: val_loss did not improve from 0.69043
# Epoch 42/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.7524 - accuracy: 0.9251 - val_loss: 0.7706 - val_accuracy: 0.7930
#
# Epoch 00042: val_loss did not improve from 0.69043
# Epoch 43/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7414 - accuracy: 0.9187 - val_loss: 0.7513 - val_accuracy: 0.7773
#
# Epoch 00043: val_loss did not improve from 0.69043
# Epoch 44/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7725 - accuracy: 0.9164 - val_loss: 0.7513 - val_accuracy: 0.7891
#
# Epoch 00044: val_loss did not improve from 0.69043
# Epoch 45/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6465 - accuracy: 0.9334 - val_loss: 0.7613 - val_accuracy: 0.8047
#
# Epoch 00045: val_loss did not improve from 0.69043
# Epoch 46/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6945 - accuracy: 0.9237 - val_loss: 0.7197 - val_accuracy: 0.8164
#
# Epoch 00046: val_loss did not improve from 0.69043
# Epoch 47/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6819 - accuracy: 0.9301 - val_loss: 0.7735 - val_accuracy: 0.7930
#
# Epoch 00047: val_loss did not improve from 0.69043
# Epoch 48/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6862 - accuracy: 0.9292 - val_loss: 0.7764 - val_accuracy: 0.7891
#
# Epoch 00048: val_loss did not improve from 0.69043
# Epoch 49/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6819 - accuracy: 0.9274 - val_loss: 0.7741 - val_accuracy: 0.7891
#
# Epoch 00049: val_loss did not improve from 0.69043
# Epoch 50/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7319 - accuracy: 0.9205 - val_loss: 0.7569 - val_accuracy: 0.7969
#
# Epoch 00050: val_loss did not improve from 0.69043
# Epoch 51/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6820 - accuracy: 0.9334 - val_loss: 0.7404 - val_accuracy: 0.8008
#
# Epoch 00051: val_loss did not improve from 0.69043
# Epoch 52/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6372 - accuracy: 0.9366 - val_loss: 0.7404 - val_accuracy: 0.8008
#
# Epoch 00052: val_loss did not improve from 0.69043
# Epoch 53/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6493 - accuracy: 0.9306 - val_loss: 0.7641 - val_accuracy: 0.7852
#
# Epoch 00053: val_loss did not improve from 0.69043
# Epoch 54/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7093 - accuracy: 0.9283 - val_loss: 0.7522 - val_accuracy: 0.7891
#
# Epoch 00054: val_loss did not improve from 0.69043
# Epoch 55/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.5790 - accuracy: 0.9430 - val_loss: 0.7354 - val_accuracy: 0.7891
#
# Epoch 00055: val_loss did not improve from 0.69043
# Epoch 56/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.7256 - accuracy: 0.9210 - val_loss: 0.7363 - val_accuracy: 0.8047
#
# Epoch 00056: val_loss did not improve from 0.69043
# Epoch 57/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.8127 - accuracy: 0.9154 - val_loss: 0.7682 - val_accuracy: 0.7891
#
# Epoch 00057: val_loss did not improve from 0.69043
# Epoch 58/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6669 - accuracy: 0.9283 - val_loss: 0.7682 - val_accuracy: 0.7852
#
# Epoch 00058: val_loss did not improve from 0.69043
# Epoch 59/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7252 - accuracy: 0.9233 - val_loss: 0.7371 - val_accuracy: 0.7969
#
# Epoch 00059: val_loss did not improve from 0.69043
# Epoch 60/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.5751 - accuracy: 0.9375 - val_loss: 0.7317 - val_accuracy: 0.8008
#
# Epoch 00060: val_loss did not improve from 0.69043
# Epoch 61/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.7331 - accuracy: 0.9246 - val_loss: 0.7614 - val_accuracy: 0.7852
#
# Epoch 00061: val_loss did not improve from 0.69043
# Epoch 62/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6780 - accuracy: 0.9361 - val_loss: 0.7623 - val_accuracy: 0.7852
#
# Epoch 00062: val_loss did not improve from 0.69043
# Epoch 63/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7257 - accuracy: 0.9242 - val_loss: 0.7556 - val_accuracy: 0.8008
#
# Epoch 00063: val_loss did not improve from 0.69043
# Epoch 64/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6130 - accuracy: 0.9389 - val_loss: 0.7485 - val_accuracy: 0.7930
#
# Epoch 00064: val_loss did not improve from 0.69043
# Epoch 65/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6273 - accuracy: 0.9370 - val_loss: 0.7282 - val_accuracy: 0.8125
#
# Epoch 00065: val_loss did not improve from 0.69043
# Epoch 66/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7069 - accuracy: 0.9246 - val_loss: 0.7502 - val_accuracy: 0.7930
#
# Epoch 00066: val_loss did not improve from 0.69043
# Epoch 67/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6808 - accuracy: 0.9306 - val_loss: 0.7610 - val_accuracy: 0.7891
#
# Epoch 00067: val_loss did not improve from 0.69043
# Epoch 68/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7393 - accuracy: 0.9200 - val_loss: 0.7510 - val_accuracy: 0.7891
#
# Epoch 00068: val_loss did not improve from 0.69043
# Epoch 69/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.7441 - accuracy: 0.9177 - val_loss: 0.7263 - val_accuracy: 0.7852
#
# Epoch 00069: val_loss did not improve from 0.69043
# Epoch 70/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.6995 - accuracy: 0.9292 - val_loss: 0.7216 - val_accuracy: 0.8047
#
# Epoch 00070: val_loss did not improve from 0.69043
# Epoch 71/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6110 - accuracy: 0.9375 - val_loss: 0.7347 - val_accuracy: 0.8008
#
# Epoch 00071: val_loss did not improve from 0.69043
# Epoch 72/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7471 - accuracy: 0.9191 - val_loss: 0.7376 - val_accuracy: 0.8047
#
# Epoch 00072: val_loss did not improve from 0.69043
# Epoch 73/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6480 - accuracy: 0.9338 - val_loss: 0.7393 - val_accuracy: 0.7969
#
# Epoch 00073: val_loss did not improve from 0.69043
# Epoch 74/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6400 - accuracy: 0.9375 - val_loss: 0.7101 - val_accuracy: 0.7930
#
# Epoch 00074: val_loss did not improve from 0.69043
# Epoch 75/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.5962 - accuracy: 0.9370 - val_loss: 0.7138 - val_accuracy: 0.8047
#
# Epoch 00075: val_loss did not improve from 0.69043
# Epoch 76/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6283 - accuracy: 0.9288 - val_loss: 0.7610 - val_accuracy: 0.7891
#
# Epoch 00076: val_loss did not improve from 0.69043
# Epoch 77/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.5829 - accuracy: 0.9389 - val_loss: 0.6682 - val_accuracy: 0.8086
#
# Epoch 00077: val_loss improved from 0.69043 to 0.66819, saving model to simple_cnn_best.hdf5
# Epoch 78/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6621 - accuracy: 0.9320 - val_loss: 0.6948 - val_accuracy: 0.8008
#
# Epoch 00078: val_loss did not improve from 0.66819
# Epoch 79/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6591 - accuracy: 0.9324 - val_loss: 0.7197 - val_accuracy: 0.7969
#
# Epoch 00079: val_loss did not improve from 0.66819
# Epoch 80/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6828 - accuracy: 0.9265 - val_loss: 0.7042 - val_accuracy: 0.8047
#
# Epoch 00080: val_loss did not improve from 0.66819
# Epoch 81/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7703 - accuracy: 0.9145 - val_loss: 0.6908 - val_accuracy: 0.8164
#
# Epoch 00081: val_loss did not improve from 0.66819
# Epoch 82/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6160 - accuracy: 0.9347 - val_loss: 0.7279 - val_accuracy: 0.8047
#
# Epoch 00082: val_loss did not improve from 0.66819
# Epoch 83/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6831 - accuracy: 0.9251 - val_loss: 0.7328 - val_accuracy: 0.8047
#
# Epoch 00083: val_loss did not improve from 0.66819
# Epoch 84/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5828 - accuracy: 0.9375 - val_loss: 0.6790 - val_accuracy: 0.8008
#
# Epoch 00084: val_loss did not improve from 0.66819
# Epoch 85/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6267 - accuracy: 0.9370 - val_loss: 0.7368 - val_accuracy: 0.7891
#
# Epoch 00085: val_loss did not improve from 0.66819
# Epoch 86/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5647 - accuracy: 0.9380 - val_loss: 0.7354 - val_accuracy: 0.7891
#
# Epoch 00086: val_loss did not improve from 0.66819
# Epoch 87/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6303 - accuracy: 0.9352 - val_loss: 0.7000 - val_accuracy: 0.7891
#
# Epoch 00087: val_loss did not improve from 0.66819
# Epoch 88/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7168 - accuracy: 0.9173 - val_loss: 0.7583 - val_accuracy: 0.7812
#
# Epoch 00088: val_loss did not improve from 0.66819
# Epoch 89/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6716 - accuracy: 0.9320 - val_loss: 0.7552 - val_accuracy: 0.7891
#
# Epoch 00089: val_loss did not improve from 0.66819
# Epoch 90/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6398 - accuracy: 0.9366 - val_loss: 0.7029 - val_accuracy: 0.7969
#
# Epoch 00090: val_loss did not improve from 0.66819
# Epoch 91/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6757 - accuracy: 0.9288 - val_loss: 0.7432 - val_accuracy: 0.7852
#
# Epoch 00091: val_loss did not improve from 0.66819
# Epoch 92/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7087 - accuracy: 0.9265 - val_loss: 0.7255 - val_accuracy: 0.7930
#
# Epoch 00092: val_loss did not improve from 0.66819
# Epoch 93/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6540 - accuracy: 0.9347 - val_loss: 0.7632 - val_accuracy: 0.7969
#
# Epoch 00093: val_loss did not improve from 0.66819
# Epoch 94/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6633 - accuracy: 0.9292 - val_loss: 0.7560 - val_accuracy: 0.7891
#
# Epoch 00094: val_loss did not improve from 0.66819
# Epoch 95/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6458 - accuracy: 0.9366 - val_loss: 0.7297 - val_accuracy: 0.7930
#
# Epoch 00095: val_loss did not improve from 0.66819
# Epoch 96/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6973 - accuracy: 0.9228 - val_loss: 0.7432 - val_accuracy: 0.7891
#
# Epoch 00096: val_loss did not improve from 0.66819
# Epoch 97/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6199 - accuracy: 0.9324 - val_loss: 0.7487 - val_accuracy: 0.7930
#
# Epoch 00097: val_loss did not improve from 0.66819
# Epoch 98/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6757 - accuracy: 0.9315 - val_loss: 0.7085 - val_accuracy: 0.8047
#
# Epoch 00098: val_loss did not improve from 0.66819
# Epoch 99/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7608 - accuracy: 0.9104 - val_loss: 0.7356 - val_accuracy: 0.7969
#
# Epoch 00099: val_loss did not improve from 0.66819
# Epoch 100/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6155 - accuracy: 0.9329 - val_loss: 0.7351 - val_accuracy: 0.7969
#
# Epoch 00100: val_loss did not improve from 0.66819
# Epoch 101/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7481 - accuracy: 0.9136 - val_loss: 0.7062 - val_accuracy: 0.8047
#
# Epoch 00101: val_loss did not improve from 0.66819
# Epoch 102/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6737 - accuracy: 0.9256 - val_loss: 0.7477 - val_accuracy: 0.7812
#
# Epoch 00102: val_loss did not improve from 0.66819
# Epoch 103/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6536 - accuracy: 0.9246 - val_loss: 0.7596 - val_accuracy: 0.7812
#
# Epoch 00103: val_loss did not improve from 0.66819
# Epoch 104/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7206 - accuracy: 0.9187 - val_loss: 0.7676 - val_accuracy: 0.7930
#
# Epoch 00104: val_loss did not improve from 0.66819
# Epoch 105/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6386 - accuracy: 0.9288 - val_loss: 0.7045 - val_accuracy: 0.8008
#
# Epoch 00105: val_loss did not improve from 0.66819
# Epoch 106/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6741 - accuracy: 0.9338 - val_loss: 0.7643 - val_accuracy: 0.7891
#
# Epoch 00106: val_loss did not improve from 0.66819
# Epoch 107/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6796 - accuracy: 0.9210 - val_loss: 0.7418 - val_accuracy: 0.7969
#
# Epoch 00107: val_loss did not improve from 0.66819
# Epoch 108/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7275 - accuracy: 0.9205 - val_loss: 0.7701 - val_accuracy: 0.7891
#
# Epoch 00108: val_loss did not improve from 0.66819
# Epoch 109/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6586 - accuracy: 0.9315 - val_loss: 0.7427 - val_accuracy: 0.7969
#
# Epoch 00109: val_loss did not improve from 0.66819
# Epoch 110/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5898 - accuracy: 0.9370 - val_loss: 0.7549 - val_accuracy: 0.7891
#
# Epoch 00110: val_loss did not improve from 0.66819
# Epoch 111/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6916 - accuracy: 0.9242 - val_loss: 0.7554 - val_accuracy: 0.7891
#
# Epoch 00111: val_loss did not improve from 0.66819
# Epoch 112/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.7127 - accuracy: 0.9223 - val_loss: 0.6995 - val_accuracy: 0.8086
#
# Epoch 00112: val_loss did not improve from 0.66819
# Epoch 113/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6958 - accuracy: 0.9237 - val_loss: 0.7689 - val_accuracy: 0.7891
#
# Epoch 00113: val_loss did not improve from 0.66819
# Epoch 114/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6073 - accuracy: 0.9370 - val_loss: 0.7397 - val_accuracy: 0.7969
#
# Epoch 00114: val_loss did not improve from 0.66819
# Epoch 115/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.5982 - accuracy: 0.9426 - val_loss: 0.7511 - val_accuracy: 0.7891
#
# Epoch 00115: val_loss did not improve from 0.66819
# Epoch 116/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.6218 - accuracy: 0.9347 - val_loss: 0.7457 - val_accuracy: 0.7891
#
# Epoch 00116: val_loss did not improve from 0.66819
# Epoch 117/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6752 - accuracy: 0.9315 - val_loss: 0.7395 - val_accuracy: 0.7969
#
# Epoch 00117: val_loss did not improve from 0.66819
# Epoch 118/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.7314 - accuracy: 0.9223 - val_loss: 0.7423 - val_accuracy: 0.7852
#
# Epoch 00118: val_loss did not improve from 0.66819
# Epoch 119/2000
# 34/34 [==============================] - 4s 116ms/step - loss: 0.6561 - accuracy: 0.9269 - val_loss: 0.7729 - val_accuracy: 0.7891
#
# Epoch 00119: val_loss did not improve from 0.66819
# Epoch 120/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6541 - accuracy: 0.9311 - val_loss: 0.7613 - val_accuracy: 0.7812
#
# Epoch 00120: val_loss did not improve from 0.66819
# Epoch 121/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.7407 - accuracy: 0.9219 - val_loss: 0.7463 - val_accuracy: 0.7812
#
# Epoch 00121: val_loss did not improve from 0.66819
# Epoch 122/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.5818 - accuracy: 0.9352 - val_loss: 0.7327 - val_accuracy: 0.7969
#
# Epoch 00122: val_loss did not improve from 0.66819
# Epoch 123/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.6909 - accuracy: 0.9265 - val_loss: 0.7053 - val_accuracy: 0.8008
#
# Epoch 00123: val_loss did not improve from 0.66819
# Epoch 124/2000
# 34/34 [==============================] - 4s 114ms/step - loss: 0.6559 - accuracy: 0.9292 - val_loss: 0.7349 - val_accuracy: 0.7891
#
# Epoch 00124: val_loss did not improve from 0.66819
# Epoch 125/2000
# 34/34 [==============================] - 4s 117ms/step - loss: 0.7027 - accuracy: 0.9260 - val_loss: 0.7766 - val_accuracy: 0.7812
#
# Epoch 00125: val_loss did not improve from 0.66819
# Epoch 126/2000
# 34/34 [==============================] - 4s 115ms/step - loss: 0.6773 - accuracy: 0.9210 - val_loss: 0.7480 - val_accuracy: 0.7969
#
# Epoch 00126: val_loss did not improve from 0.66819
# Epoch 127/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6840 - accuracy: 0.9301 - val_loss: 0.7359 - val_accuracy: 0.8047
#
# Epoch 00127: val_loss did not improve from 0.66819
# Epoch 00127: early stopping

# %%
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'

# %%
test_loader = Workout_dataset(
        test_dir, test_label_dir, mode='Test', batch_size=625, shuffle=False)

# %%
model.load_weights(checkpoint_filepath)
model.evaluate_generator(generator=test_loader,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1973: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# 1/1 [==============================] - 1s 981ms/step - loss: 0.6063 - accuracy: 0.8064
# [0.606344997882843, 0.8064000010490417]
