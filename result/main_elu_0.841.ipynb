# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3,
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 6)       0           input_4[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      730         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1090        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1090        concatenate_2[0][0]
# __________________________________________________________________________________________________
# elu (ELU)                       (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# elu_4 (ELU)                     (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# elu_12 (ELU)                    (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# elu_16 (ELU)                    (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# elu_8 (ELU)                     (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          elu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          elu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          elu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          elu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          elu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# elu_1 (ELU)                     (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# elu_5 (ELU)                     (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# elu_13 (ELU)                    (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# elu_17 (ELU)                    (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# elu_9 (ELU)                     (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          elu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          elu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          elu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          elu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          elu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# elu_2 (ELU)                     (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# elu_6 (ELU)                     (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# elu_14 (ELU)                    (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# elu_18 (ELU)                    (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# elu_10 (ELU)                    (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         elu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         elu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         elu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         elu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         elu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# elu_3 (ELU)                     (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# elu_7 (ELU)                     (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# elu_15 (ELU)                    (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# elu_19 (ELU)                    (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# elu_11 (ELU)                    (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         elu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         elu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         elu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         elu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         elu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 150, 300)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# elu_20 (ELU)                    (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 120)     21720       elu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 120)     480         conv1d_12[0][0]
# __________________________________________________________________________________________________
# elu_21 (ELU)                    (None, 150, 120)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      21660       elu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# elu_22 (ELU)                    (None, 150, 60)      0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           elu_22[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         conv1d_14[0][0]
# __________________________________________________________________________________________________
# elu_23 (ELU)                    (None, 150, 60)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 120)     21720       elu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 120)     480         conv1d_15[0][0]
# __________________________________________________________________________________________________
# elu_24 (ELU)                    (None, 150, 120)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       elu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# elu_25 (ELU)                    (None, 150, 60)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           elu_25[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# elu_26 (ELU)                    (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 120)     21720       elu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         conv1d_18[0][0]
# __________________________________________________________________________________________________
# elu_27 (ELU)                    (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      21660       elu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# elu_28 (ELU)                    (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           elu_28[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# elu_29 (ELU)                    (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     21720       elu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 120)     480         conv1d_21[0][0]
# __________________________________________________________________________________________________
# elu_30 (ELU)                    (None, 150, 120)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      21660       elu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# elu_31 (ELU)                    (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           elu_31[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# elu_32 (ELU)                    (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       elu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# elu_33 (ELU)                    (None, 150, 120)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       elu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# elu_34 (ELU)                    (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           elu_34[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# elu_35 (ELU)                    (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       elu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# elu_36 (ELU)                    (None, 150, 120)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       elu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# elu_37 (ELU)                    (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           elu_37[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# elu_38 (ELU)                    (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       elu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# elu_39 (ELU)                    (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       elu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# elu_40 (ELU)                    (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           elu_40[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# elu_41 (ELU)                    (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 120)     21720       elu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         conv1d_33[0][0]
# __________________________________________________________________________________________________
# elu_42 (ELU)                    (None, 150, 120)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      21660       elu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# elu_43 (ELU)                    (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           elu_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# elu_44 (ELU)                    (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 120)     21720       elu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_36[0][0]
# __________________________________________________________________________________________________
# elu_45 (ELU)                    (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      21660       elu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# elu_46 (ELU)                    (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           elu_46[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,132,251
# Trainable params: 1,126,311
# Non-trainable params: 5,940
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=20,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 38s 315ms/step - loss: 43.9801 - accuracy: 0.2886 - val_loss: 32.9740 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.97396, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 29.1855 - accuracy: 0.4917 - val_loss: 21.3731 - val_accuracy: 0.4531
#
# Epoch 00002: val_loss improved from 32.97396 to 21.37307, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 19.4996 - accuracy: 0.5855 - val_loss: 14.8263 - val_accuracy: 0.4414
#
# Epoch 00003: val_loss improved from 21.37307 to 14.82632, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 13.5088 - accuracy: 0.6397 - val_loss: 10.8099 - val_accuracy: 0.4648
#
# Epoch 00004: val_loss improved from 14.82632 to 10.80986, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 10.0088 - accuracy: 0.6751 - val_loss: 8.5966 - val_accuracy: 0.4570
#
# Epoch 00005: val_loss improved from 10.80986 to 8.59657, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 7.5498 - accuracy: 0.6962 - val_loss: 7.0957 - val_accuracy: 0.4531
#
# Epoch 00006: val_loss improved from 8.59657 to 7.09575, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 5.9927 - accuracy: 0.7022 - val_loss: 6.1981 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 7.09575 to 6.19812, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 4.9503 - accuracy: 0.7261 - val_loss: 5.6224 - val_accuracy: 0.4531
#
# Epoch 00008: val_loss improved from 6.19812 to 5.62240, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 4.4313 - accuracy: 0.7224 - val_loss: 5.5077 - val_accuracy: 0.4180
#
# Epoch 00009: val_loss improved from 5.62240 to 5.50775, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 3.8512 - accuracy: 0.7390 - val_loss: 6.7427 - val_accuracy: 0.0156
#
# Epoch 00010: val_loss did not improve from 5.50775
# Epoch 11/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 3.3175 - accuracy: 0.7528 - val_loss: 4.6623 - val_accuracy: 0.3633
#
# Epoch 00011: val_loss improved from 5.50775 to 4.66227, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.9634 - accuracy: 0.7771 - val_loss: 5.1953 - val_accuracy: 0.0977
#
# Epoch 00012: val_loss did not improve from 4.66227
# Epoch 13/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 2.9091 - accuracy: 0.7684 - val_loss: 5.5750 - val_accuracy: 0.1172
#
# Epoch 00013: val_loss did not improve from 4.66227
# Epoch 14/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 2.6615 - accuracy: 0.7812 - val_loss: 5.1116 - val_accuracy: 0.0391
#
# Epoch 00014: val_loss did not improve from 4.66227
# Epoch 15/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 2.4709 - accuracy: 0.7987 - val_loss: 3.7327 - val_accuracy: 0.3438
#
# Epoch 00015: val_loss improved from 4.66227 to 3.73267, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 2.3822 - accuracy: 0.7900 - val_loss: 3.1191 - val_accuracy: 0.4609
#
# Epoch 00016: val_loss improved from 3.73267 to 3.11909, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.3544 - accuracy: 0.7822 - val_loss: 2.8071 - val_accuracy: 0.5352
#
# Epoch 00017: val_loss improved from 3.11909 to 2.80714, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 204ms/step - loss: 2.1026 - accuracy: 0.8208 - val_loss: 2.3001 - val_accuracy: 0.5664
#
# Epoch 00018: val_loss improved from 2.80714 to 2.30007, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 2.1677 - accuracy: 0.7978 - val_loss: 2.1872 - val_accuracy: 0.6055
#
# Epoch 00019: val_loss improved from 2.30007 to 2.18718, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.0750 - accuracy: 0.8171 - val_loss: 1.9250 - val_accuracy: 0.6055
#
# Epoch 00020: val_loss improved from 2.18718 to 1.92498, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 2.0652 - accuracy: 0.8171 - val_loss: 1.9837 - val_accuracy: 0.6016
#
# Epoch 00021: val_loss did not improve from 1.92498
# Epoch 22/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 1.8616 - accuracy: 0.8336 - val_loss: 1.8802 - val_accuracy: 0.6289
#
# Epoch 00022: val_loss improved from 1.92498 to 1.88015, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 1.6550 - accuracy: 0.8612 - val_loss: 1.4559 - val_accuracy: 0.6953
#
# Epoch 00023: val_loss improved from 1.88015 to 1.45589, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 1.6090 - accuracy: 0.8539 - val_loss: 1.4479 - val_accuracy: 0.6719
#
# Epoch 00024: val_loss improved from 1.45589 to 1.44789, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.5683 - accuracy: 0.8653 - val_loss: 1.2120 - val_accuracy: 0.7500
#
# Epoch 00025: val_loss improved from 1.44789 to 1.21196, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.4698 - accuracy: 0.8704 - val_loss: 1.3234 - val_accuracy: 0.7031
#
# Epoch 00026: val_loss did not improve from 1.21196
# Epoch 27/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.4115 - accuracy: 0.8699 - val_loss: 1.2350 - val_accuracy: 0.7227
#
# Epoch 00027: val_loss did not improve from 1.21196
# Epoch 28/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.4294 - accuracy: 0.8699 - val_loss: 1.2091 - val_accuracy: 0.7383
#
# Epoch 00028: val_loss improved from 1.21196 to 1.20913, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.3447 - accuracy: 0.8764 - val_loss: 1.3370 - val_accuracy: 0.7031
#
# Epoch 00029: val_loss did not improve from 1.20913
# Epoch 30/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.3144 - accuracy: 0.8796 - val_loss: 1.0886 - val_accuracy: 0.7500
#
# Epoch 00030: val_loss improved from 1.20913 to 1.08855, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.2684 - accuracy: 0.8782 - val_loss: 1.1691 - val_accuracy: 0.7422
#
# Epoch 00031: val_loss did not improve from 1.08855
# Epoch 32/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.2559 - accuracy: 0.8860 - val_loss: 1.1309 - val_accuracy: 0.7383
#
# Epoch 00032: val_loss did not improve from 1.08855
# Epoch 33/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.3013 - accuracy: 0.8759 - val_loss: 1.1185 - val_accuracy: 0.7461
#
# Epoch 00033: val_loss did not improve from 1.08855
# Epoch 34/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.1971 - accuracy: 0.8943 - val_loss: 1.0118 - val_accuracy: 0.7617
#
# Epoch 00034: val_loss improved from 1.08855 to 1.01175, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.1028 - accuracy: 0.9012 - val_loss: 0.9748 - val_accuracy: 0.7773
#
# Epoch 00035: val_loss improved from 1.01175 to 0.97483, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.0753 - accuracy: 0.9104 - val_loss: 0.9162 - val_accuracy: 0.8164
#
# Epoch 00036: val_loss improved from 0.97483 to 0.91615, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.9826 - accuracy: 0.9200 - val_loss: 1.0401 - val_accuracy: 0.7617
#
# Epoch 00037: val_loss did not improve from 0.91615
# Epoch 38/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.1793 - accuracy: 0.8869 - val_loss: 1.0530 - val_accuracy: 0.7461
#
# Epoch 00038: val_loss did not improve from 0.91615
# Epoch 39/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.9811 - accuracy: 0.9196 - val_loss: 1.0566 - val_accuracy: 0.7695
#
# Epoch 00039: val_loss did not improve from 0.91615
# Epoch 40/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.9932 - accuracy: 0.9150 - val_loss: 0.9314 - val_accuracy: 0.8125
#
# Epoch 00040: val_loss did not improve from 0.91615
# Epoch 41/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 1.0507 - accuracy: 0.9044 - val_loss: 0.9563 - val_accuracy: 0.7812
#
# Epoch 00041: val_loss did not improve from 0.91615
# Epoch 42/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.9420 - accuracy: 0.9237 - val_loss: 0.9403 - val_accuracy: 0.7891
#
# Epoch 00042: val_loss did not improve from 0.91615
# Epoch 43/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.8600 - accuracy: 0.9269 - val_loss: 0.8772 - val_accuracy: 0.7930
#
# Epoch 00043: val_loss improved from 0.91615 to 0.87724, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.9804 - accuracy: 0.9164 - val_loss: 0.9383 - val_accuracy: 0.7773
#
# Epoch 00044: val_loss did not improve from 0.87724
# Epoch 45/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.9437 - accuracy: 0.9164 - val_loss: 0.9261 - val_accuracy: 0.7930
#
# Epoch 00045: val_loss did not improve from 0.87724
# Epoch 46/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8518 - accuracy: 0.9315 - val_loss: 0.9623 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss did not improve from 0.87724
# Epoch 47/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.9637 - accuracy: 0.9168 - val_loss: 0.8885 - val_accuracy: 0.8008
#
# Epoch 00047: val_loss did not improve from 0.87724
# Epoch 48/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.9223 - accuracy: 0.9200 - val_loss: 0.9923 - val_accuracy: 0.7734
#
# Epoch 00048: val_loss did not improve from 0.87724
# Epoch 49/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8680 - accuracy: 0.9292 - val_loss: 0.9235 - val_accuracy: 0.7969
#
# Epoch 00049: val_loss did not improve from 0.87724
# Epoch 50/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8130 - accuracy: 0.9389 - val_loss: 0.9013 - val_accuracy: 0.8164
#
# Epoch 00050: val_loss did not improve from 0.87724
# Epoch 51/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8601 - accuracy: 0.9315 - val_loss: 0.8949 - val_accuracy: 0.7969
#
# Epoch 00051: val_loss did not improve from 0.87724
# Epoch 52/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8926 - accuracy: 0.9228 - val_loss: 0.9294 - val_accuracy: 0.7891
#
# Epoch 00052: val_loss did not improve from 0.87724
# Epoch 53/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.8060 - accuracy: 0.9380 - val_loss: 0.8651 - val_accuracy: 0.8203
#
# Epoch 00053: val_loss improved from 0.87724 to 0.86507, saving model to ./save/cnn_gru_best.hdf5
# Epoch 54/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.8801 - accuracy: 0.9265 - val_loss: 0.8936 - val_accuracy: 0.8164
#
# Epoch 00054: val_loss did not improve from 0.86507
# Epoch 55/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.9134 - accuracy: 0.9182 - val_loss: 0.9124 - val_accuracy: 0.8008
#
# Epoch 00055: val_loss did not improve from 0.86507
# Epoch 56/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.8572 - accuracy: 0.9278 - val_loss: 0.9164 - val_accuracy: 0.7852
#
# Epoch 00056: val_loss did not improve from 0.86507
# Epoch 57/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8070 - accuracy: 0.9324 - val_loss: 0.9149 - val_accuracy: 0.7852
#
# Epoch 00057: val_loss did not improve from 0.86507
# Epoch 58/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8052 - accuracy: 0.9324 - val_loss: 0.8977 - val_accuracy: 0.8047
#
# Epoch 00058: val_loss did not improve from 0.86507
# Epoch 59/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7784 - accuracy: 0.9384 - val_loss: 0.8680 - val_accuracy: 0.8008
#
# Epoch 00059: val_loss did not improve from 0.86507
# Epoch 60/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7445 - accuracy: 0.9403 - val_loss: 0.8888 - val_accuracy: 0.8047
#
# Epoch 00060: val_loss did not improve from 0.86507
# Epoch 61/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6953 - accuracy: 0.9453 - val_loss: 0.8118 - val_accuracy: 0.8125
#
# Epoch 00061: val_loss improved from 0.86507 to 0.81182, saving model to ./save/cnn_gru_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.7547 - accuracy: 0.9389 - val_loss: 0.9081 - val_accuracy: 0.8008
#
# Epoch 00062: val_loss did not improve from 0.81182
# Epoch 63/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.7331 - accuracy: 0.9393 - val_loss: 0.8921 - val_accuracy: 0.8008
#
# Epoch 00063: val_loss did not improve from 0.81182
# Epoch 64/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7407 - accuracy: 0.9398 - val_loss: 0.8874 - val_accuracy: 0.8047
#
# Epoch 00064: val_loss did not improve from 0.81182
# Epoch 65/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.7963 - accuracy: 0.9338 - val_loss: 0.8947 - val_accuracy: 0.7969
#
# Epoch 00065: val_loss did not improve from 0.81182
# Epoch 66/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.7642 - accuracy: 0.9384 - val_loss: 0.8755 - val_accuracy: 0.8125
#
# Epoch 00066: val_loss did not improve from 0.81182
# Epoch 67/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7229 - accuracy: 0.9449 - val_loss: 0.8695 - val_accuracy: 0.8164
#
# Epoch 00067: val_loss did not improve from 0.81182
# Epoch 68/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7966 - accuracy: 0.9352 - val_loss: 0.8698 - val_accuracy: 0.8125
#
# Epoch 00068: val_loss did not improve from 0.81182
# Epoch 69/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8633 - accuracy: 0.9256 - val_loss: 0.8639 - val_accuracy: 0.8086
#
# Epoch 00069: val_loss did not improve from 0.81182
# Epoch 70/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8047 - accuracy: 0.9347 - val_loss: 0.8772 - val_accuracy: 0.8125
#
# Epoch 00070: val_loss did not improve from 0.81182
# Epoch 71/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.7711 - accuracy: 0.9375 - val_loss: 0.9004 - val_accuracy: 0.8086
#
# Epoch 00071: val_loss did not improve from 0.81182
# Epoch 72/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.6798 - accuracy: 0.9536 - val_loss: 0.8674 - val_accuracy: 0.8203
#
# Epoch 00072: val_loss did not improve from 0.81182
# Epoch 73/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6830 - accuracy: 0.9449 - val_loss: 0.8948 - val_accuracy: 0.8164
#
# Epoch 00073: val_loss did not improve from 0.81182
# Epoch 74/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7364 - accuracy: 0.9375 - val_loss: 0.8756 - val_accuracy: 0.8242
#
# Epoch 00074: val_loss did not improve from 0.81182
# Epoch 75/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8092 - accuracy: 0.9320 - val_loss: 0.9118 - val_accuracy: 0.8086
#
# Epoch 00075: val_loss did not improve from 0.81182
# Epoch 76/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7564 - accuracy: 0.9361 - val_loss: 0.8797 - val_accuracy: 0.8086
#
# Epoch 00076: val_loss did not improve from 0.81182
# Epoch 77/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7433 - accuracy: 0.9435 - val_loss: 0.9062 - val_accuracy: 0.7969
#
# Epoch 00077: val_loss did not improve from 0.81182
# Epoch 78/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8495 - accuracy: 0.9320 - val_loss: 0.8569 - val_accuracy: 0.8086
#
# Epoch 00078: val_loss did not improve from 0.81182
# Epoch 79/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7281 - accuracy: 0.9426 - val_loss: 0.8873 - val_accuracy: 0.8086
#
# Epoch 00079: val_loss did not improve from 0.81182
# Epoch 80/2000
# 34/34 [==============================] - 7s 198ms/step - loss: 0.7342 - accuracy: 0.9403 - val_loss: 0.8804 - val_accuracy: 0.8008
#
# Epoch 00080: val_loss did not improve from 0.81182
# Epoch 81/2000
# 34/34 [==============================] - 7s 202ms/step - loss: 0.7462 - accuracy: 0.9407 - val_loss: 0.8742 - val_accuracy: 0.8047
#
# Epoch 00081: val_loss did not improve from 0.81182
# Epoch 00081: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7348 - accuracy: 0.8416
# [0.7347841858863831, 0.8416000008583069]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
