# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3,
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, #0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 6)       0           input_4[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      730         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1090        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1090        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 150, 300)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 120)     480         conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_22[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 120)     480         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_25[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_28[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 120)     480         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_31[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_34[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_37[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_40[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,132,251
# Trainable params: 1,126,311
# Non-trainable params: 5,940
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=20,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 38s 318ms/step - loss: 43.8458 - accuracy: 0.3208 - val_loss: 32.7045 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.70452, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 28.8275 - accuracy: 0.5524 - val_loss: 21.4933 - val_accuracy: 0.4531
#
# Epoch 00002: val_loss improved from 32.70452 to 21.49329, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 19.0003 - accuracy: 0.6489 - val_loss: 14.7368 - val_accuracy: 0.4414
#
# Epoch 00003: val_loss improved from 21.49329 to 14.73684, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 13.0245 - accuracy: 0.6916 - val_loss: 10.6071 - val_accuracy: 0.4648
#
# Epoch 00004: val_loss improved from 14.73684 to 10.60714, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 9.7051 - accuracy: 0.6916 - val_loss: 8.3083 - val_accuracy: 0.4570
#
# Epoch 00005: val_loss improved from 10.60714 to 8.30833, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 7.3573 - accuracy: 0.7224 - val_loss: 6.9707 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 8.30833 to 6.97071, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 5.8075 - accuracy: 0.7385 - val_loss: 6.1305 - val_accuracy: 0.4570
#
# Epoch 00007: val_loss improved from 6.97071 to 6.13046, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 4.8435 - accuracy: 0.7381 - val_loss: 5.7308 - val_accuracy: 0.4531
#
# Epoch 00008: val_loss improved from 6.13046 to 5.73079, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 4.3388 - accuracy: 0.7289 - val_loss: 5.9238 - val_accuracy: 0.4414
#
# Epoch 00009: val_loss did not improve from 5.73079
# Epoch 10/2000
# 34/34 [==============================] - 7s 199ms/step - loss: 3.7572 - accuracy: 0.7528 - val_loss: 7.4454 - val_accuracy: 0.0078
#
# Epoch 00010: val_loss did not improve from 5.73079
# Epoch 11/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 3.3101 - accuracy: 0.7675 - val_loss: 5.4121 - val_accuracy: 0.0898
#
# Epoch 00011: val_loss improved from 5.73079 to 5.41213, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.9217 - accuracy: 0.7978 - val_loss: 6.3914 - val_accuracy: 0.0312
#
# Epoch 00012: val_loss did not improve from 5.41213
# Epoch 13/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.9260 - accuracy: 0.7831 - val_loss: 6.5005 - val_accuracy: 0.0586
#
# Epoch 00013: val_loss did not improve from 5.41213
# Epoch 14/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 2.6586 - accuracy: 0.7941 - val_loss: 7.0720 - val_accuracy: 0.0391
#
# Epoch 00014: val_loss did not improve from 5.41213
# Epoch 15/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 2.5029 - accuracy: 0.8038 - val_loss: 4.7092 - val_accuracy: 0.2422
#
# Epoch 00015: val_loss improved from 5.41213 to 4.70921, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 2.4773 - accuracy: 0.8051 - val_loss: 5.5925 - val_accuracy: 0.1445
#
# Epoch 00016: val_loss did not improve from 4.70921
# Epoch 17/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 2.4367 - accuracy: 0.7937 - val_loss: 4.0485 - val_accuracy: 0.3125
#
# Epoch 00017: val_loss improved from 4.70921 to 4.04851, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 7s 204ms/step - loss: 2.1980 - accuracy: 0.8208 - val_loss: 2.3987 - val_accuracy: 0.5781
#
# Epoch 00018: val_loss improved from 4.04851 to 2.39865, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 2.2882 - accuracy: 0.8084 - val_loss: 2.5091 - val_accuracy: 0.5078
#
# Epoch 00019: val_loss did not improve from 2.39865
# Epoch 20/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.2296 - accuracy: 0.8134 - val_loss: 2.0441 - val_accuracy: 0.6250
#
# Epoch 00020: val_loss improved from 2.39865 to 2.04413, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 2.1407 - accuracy: 0.8226 - val_loss: 2.1359 - val_accuracy: 0.6367
#
# Epoch 00021: val_loss did not improve from 2.04413
# Epoch 22/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.9329 - accuracy: 0.8424 - val_loss: 1.9084 - val_accuracy: 0.6172
#
# Epoch 00022: val_loss improved from 2.04413 to 1.90845, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.7194 - accuracy: 0.8667 - val_loss: 1.5323 - val_accuracy: 0.6992
#
# Epoch 00023: val_loss improved from 1.90845 to 1.53234, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 1.6643 - accuracy: 0.8594 - val_loss: 1.8768 - val_accuracy: 0.6680
#
# Epoch 00024: val_loss did not improve from 1.53234
# Epoch 25/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 1.6227 - accuracy: 0.8653 - val_loss: 1.5130 - val_accuracy: 0.6758
#
# Epoch 00025: val_loss improved from 1.53234 to 1.51302, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.4819 - accuracy: 0.8750 - val_loss: 1.4821 - val_accuracy: 0.7070
#
# Epoch 00026: val_loss improved from 1.51302 to 1.48214, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.4338 - accuracy: 0.8699 - val_loss: 1.4023 - val_accuracy: 0.7305
#
# Epoch 00027: val_loss improved from 1.48214 to 1.40234, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 7s 198ms/step - loss: 1.4216 - accuracy: 0.8810 - val_loss: 1.1736 - val_accuracy: 0.7773
#
# Epoch 00028: val_loss improved from 1.40234 to 1.17359, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 7s 199ms/step - loss: 1.3298 - accuracy: 0.8902 - val_loss: 1.2120 - val_accuracy: 0.7656
#
# Epoch 00029: val_loss did not improve from 1.17359
# Epoch 30/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 1.3346 - accuracy: 0.8869 - val_loss: 1.1860 - val_accuracy: 0.7734
#
# Epoch 00030: val_loss did not improve from 1.17359
# Epoch 31/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.2479 - accuracy: 0.8925 - val_loss: 1.1334 - val_accuracy: 0.7852
#
# Epoch 00031: val_loss improved from 1.17359 to 1.13340, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.2467 - accuracy: 0.8998 - val_loss: 1.1234 - val_accuracy: 0.7891
#
# Epoch 00032: val_loss improved from 1.13340 to 1.12341, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.2728 - accuracy: 0.8929 - val_loss: 1.1165 - val_accuracy: 0.7773
#
# Epoch 00033: val_loss improved from 1.12341 to 1.11650, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 1.1705 - accuracy: 0.9090 - val_loss: 0.9932 - val_accuracy: 0.7969
#
# Epoch 00034: val_loss improved from 1.11650 to 0.99323, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 1.0482 - accuracy: 0.9154 - val_loss: 1.0753 - val_accuracy: 0.7539
#
# Epoch 00035: val_loss did not improve from 0.99323
# Epoch 36/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 1.0040 - accuracy: 0.9187 - val_loss: 0.9098 - val_accuracy: 0.8359
#
# Epoch 00036: val_loss improved from 0.99323 to 0.90975, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.9226 - accuracy: 0.9233 - val_loss: 0.9933 - val_accuracy: 0.8125
#
# Epoch 00037: val_loss did not improve from 0.90975
# Epoch 38/2000
# 34/34 [==============================] - 7s 199ms/step - loss: 1.1723 - accuracy: 0.8989 - val_loss: 1.0217 - val_accuracy: 0.7852
#
# Epoch 00038: val_loss did not improve from 0.90975
# Epoch 39/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.9327 - accuracy: 0.9269 - val_loss: 1.0075 - val_accuracy: 0.7852
#
# Epoch 00039: val_loss did not improve from 0.90975
# Epoch 40/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.9405 - accuracy: 0.9278 - val_loss: 0.9030 - val_accuracy: 0.8203
#
# Epoch 00040: val_loss improved from 0.90975 to 0.90299, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.9675 - accuracy: 0.9159 - val_loss: 0.9498 - val_accuracy: 0.8164
#
# Epoch 00041: val_loss did not improve from 0.90299
# Epoch 42/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.9040 - accuracy: 0.9278 - val_loss: 0.8870 - val_accuracy: 0.8281
#
# Epoch 00042: val_loss improved from 0.90299 to 0.88698, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 7s 199ms/step - loss: 0.7813 - accuracy: 0.9416 - val_loss: 0.8408 - val_accuracy: 0.8438
#
# Epoch 00043: val_loss improved from 0.88698 to 0.84084, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 7s 198ms/step - loss: 0.8880 - accuracy: 0.9334 - val_loss: 0.9626 - val_accuracy: 0.8008
#
# Epoch 00044: val_loss did not improve from 0.84084
# Epoch 45/2000
# 34/34 [==============================] - 7s 198ms/step - loss: 0.8640 - accuracy: 0.9334 - val_loss: 0.9289 - val_accuracy: 0.8242
#
# Epoch 00045: val_loss did not improve from 0.84084
# Epoch 46/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.8004 - accuracy: 0.9439 - val_loss: 0.9781 - val_accuracy: 0.8047
#
# Epoch 00046: val_loss did not improve from 0.84084
# Epoch 47/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.8441 - accuracy: 0.9292 - val_loss: 0.9222 - val_accuracy: 0.8164
#
# Epoch 00047: val_loss did not improve from 0.84084
# Epoch 48/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8353 - accuracy: 0.9357 - val_loss: 0.9339 - val_accuracy: 0.8320
#
# Epoch 00048: val_loss did not improve from 0.84084
# Epoch 49/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.8046 - accuracy: 0.9357 - val_loss: 0.8871 - val_accuracy: 0.8398
#
# Epoch 00049: val_loss did not improve from 0.84084
# Epoch 50/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.7637 - accuracy: 0.9467 - val_loss: 0.9151 - val_accuracy: 0.8398
#
# Epoch 00050: val_loss did not improve from 0.84084
# Epoch 51/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.7622 - accuracy: 0.9416 - val_loss: 0.9358 - val_accuracy: 0.8203
#
# Epoch 00051: val_loss did not improve from 0.84084
# Epoch 52/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7899 - accuracy: 0.9393 - val_loss: 0.9340 - val_accuracy: 0.8164
#
# Epoch 00052: val_loss did not improve from 0.84084
# Epoch 53/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6790 - accuracy: 0.9531 - val_loss: 0.8846 - val_accuracy: 0.8320
#
# Epoch 00053: val_loss did not improve from 0.84084
# Epoch 54/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7772 - accuracy: 0.9407 - val_loss: 0.9276 - val_accuracy: 0.8125
#
# Epoch 00054: val_loss did not improve from 0.84084
# Epoch 55/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.8270 - accuracy: 0.9283 - val_loss: 0.9303 - val_accuracy: 0.8242
#
# Epoch 00055: val_loss did not improve from 0.84084
# Epoch 56/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.7231 - accuracy: 0.9398 - val_loss: 0.9231 - val_accuracy: 0.8203
#
# Epoch 00056: val_loss did not improve from 0.84084
# Epoch 57/2000
# 34/34 [==============================] - 7s 199ms/step - loss: 0.7041 - accuracy: 0.9467 - val_loss: 0.9189 - val_accuracy: 0.8203
#
# Epoch 00057: val_loss did not improve from 0.84084
# Epoch 58/2000
# 34/34 [==============================] - 7s 198ms/step - loss: 0.6839 - accuracy: 0.9508 - val_loss: 0.8831 - val_accuracy: 0.8242
#
# Epoch 00058: val_loss did not improve from 0.84084
# Epoch 59/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.6647 - accuracy: 0.9531 - val_loss: 0.8951 - val_accuracy: 0.8320
#
# Epoch 00059: val_loss did not improve from 0.84084
# Epoch 60/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6279 - accuracy: 0.9586 - val_loss: 0.9077 - val_accuracy: 0.8203
#
# Epoch 00060: val_loss did not improve from 0.84084
# Epoch 61/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.5792 - accuracy: 0.9605 - val_loss: 0.8030 - val_accuracy: 0.8398
#
# Epoch 00061: val_loss improved from 0.84084 to 0.80303, saving model to ./save/cnn_gru_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6373 - accuracy: 0.9554 - val_loss: 0.9259 - val_accuracy: 0.8125
#
# Epoch 00062: val_loss did not improve from 0.80303
# Epoch 63/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6215 - accuracy: 0.9582 - val_loss: 0.9021 - val_accuracy: 0.8242
#
# Epoch 00063: val_loss did not improve from 0.80303
# Epoch 64/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6046 - accuracy: 0.9582 - val_loss: 0.9105 - val_accuracy: 0.8242
#
# Epoch 00064: val_loss did not improve from 0.80303
# Epoch 65/2000
# 34/34 [==============================] - 7s 195ms/step - loss: 0.6995 - accuracy: 0.9462 - val_loss: 0.9215 - val_accuracy: 0.8242
#
# Epoch 00065: val_loss did not improve from 0.80303
# Epoch 66/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6645 - accuracy: 0.9494 - val_loss: 0.9137 - val_accuracy: 0.8164
#
# Epoch 00066: val_loss did not improve from 0.80303
# Epoch 67/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6007 - accuracy: 0.9614 - val_loss: 0.9033 - val_accuracy: 0.8203
#
# Epoch 00067: val_loss did not improve from 0.80303
# Epoch 68/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6587 - accuracy: 0.9550 - val_loss: 0.8957 - val_accuracy: 0.8242
#
# Epoch 00068: val_loss did not improve from 0.80303
# Epoch 69/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7427 - accuracy: 0.9403 - val_loss: 0.8900 - val_accuracy: 0.8320
#
# Epoch 00069: val_loss did not improve from 0.80303
# Epoch 70/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6811 - accuracy: 0.9490 - val_loss: 0.9113 - val_accuracy: 0.8281
#
# Epoch 00070: val_loss did not improve from 0.80303
# Epoch 71/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.6761 - accuracy: 0.9476 - val_loss: 0.9114 - val_accuracy: 0.8320
#
# Epoch 00071: val_loss did not improve from 0.80303
# Epoch 72/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.5844 - accuracy: 0.9573 - val_loss: 0.8847 - val_accuracy: 0.8320
#
# Epoch 00072: val_loss did not improve from 0.80303
# Epoch 73/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.5824 - accuracy: 0.9628 - val_loss: 0.9119 - val_accuracy: 0.8203
#
# Epoch 00073: val_loss did not improve from 0.80303
# Epoch 74/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6062 - accuracy: 0.9559 - val_loss: 0.9040 - val_accuracy: 0.8164
#
# Epoch 00074: val_loss did not improve from 0.80303
# Epoch 75/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6709 - accuracy: 0.9517 - val_loss: 0.9405 - val_accuracy: 0.8086
#
# Epoch 00075: val_loss did not improve from 0.80303
# Epoch 76/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 0.6263 - accuracy: 0.9568 - val_loss: 0.9129 - val_accuracy: 0.8203
#
# Epoch 00076: val_loss did not improve from 0.80303
# Epoch 77/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6230 - accuracy: 0.9586 - val_loss: 0.9354 - val_accuracy: 0.8203
#
# Epoch 00077: val_loss did not improve from 0.80303
# Epoch 78/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.7215 - accuracy: 0.9449 - val_loss: 0.8801 - val_accuracy: 0.8320
#
# Epoch 00078: val_loss did not improve from 0.80303
# Epoch 79/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.5962 - accuracy: 0.9609 - val_loss: 0.9100 - val_accuracy: 0.8320
#
# Epoch 00079: val_loss did not improve from 0.80303
# Epoch 80/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6134 - accuracy: 0.9605 - val_loss: 0.9167 - val_accuracy: 0.8203
#
# Epoch 00080: val_loss did not improve from 0.80303
# Epoch 81/2000
# 34/34 [==============================] - 7s 197ms/step - loss: 0.6263 - accuracy: 0.9609 - val_loss: 0.9137 - val_accuracy: 0.8242
#
# Epoch 00081: val_loss did not improve from 0.80303
# Epoch 00081: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7323 - accuracy: 0.8432
# [0.7323177456855774, 0.8432000279426575]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
