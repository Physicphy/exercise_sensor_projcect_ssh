# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset

import os

os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
eval_dir = './data/train'
eval_label_dir = './data/data_y_train.csv'
label_dir = './data/data_y_train.csv'

def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

train_y = pd.read_csv('./data/data_y_train.csv')  # label load
label_dict = dict()
for label, label_desc in zip(train_y.label, train_y.label_desc):
    label_dict[label] = label_desc
# 'Squat (kettlebell / goblet)'에서 [/]를 [,]으로 변경
label_dict[45] = 'Squat (kettlebell , goblet)'

# %%
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)
BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

# %%
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(
    'balanced',
    np.unique(train_y.label),
    train_y.label)

class_weight_dict = dict(zip(
    list(range(61)),
    class_weights+1
    ))

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Input, GlobalAveragePooling1D, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import he_normal

# %%
kernel_size1 = 19
kernel_size2 = 3
kernel_size3 = 5
kk = 10
stride = 2

acc_input_1 = layers.Input(shape=(600, 3)) # xyz
acc_input_2 = layers.Input(shape=(600, 1)) # tot mag
acc_input_3 = layers.Input(shape=(600, 1)) # vol
acc_input_4 = layers.Input(shape=(600, 3)) # ftt_xyz
gy_input_1 = layers.Input(shape=(600, 3)) 
gy_input_2 = layers.Input(shape=(600, 1)) 
gy_input_3 = layers.Input(shape=(600, 1))
gy_input_4 = layers.Input(shape=(600, 3))



# conv1_inputs = layers.concatenate([acc_input_1, acc_input_2, gy_input_1, gy_input_2])
conv1_inputs = layers.concatenate([acc_input_1, acc_input_2, acc_input_3])

conv1 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv1_inputs)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*2,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)
conv1 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru1)
conv1 = BatchNormalization()(conv1)
#conv1 = Dropout(0.2,seed=42)(conv1)
gru1 = layers.GRU(kk*6,return_sequences=True)(conv1)
gru1 = layers.LeakyReLU(0.2)(gru1)
gru1 = BatchNormalization()(gru1)

acc_model = Model([acc_input_1, acc_input_2, acc_input_3], gru1)


conv2_inputs = layers.concatenate([gy_input_1, gy_input_2, gy_input_3])

conv2 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv2_inputs)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*2,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)
conv2 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru2)
conv2 = BatchNormalization()(conv2)
#conv2 = Dropout(0.1,seed=42)(conv2)
gru2 = layers.GRU(kk*6,return_sequences=True)(conv2)
gru2 = layers.LeakyReLU(0.2)(gru2)
gru2 = BatchNormalization()(gru2)

gy_model = Model([gy_input_1, gy_input_2, gy_input_3], gru2)

conv3_inputs = layers.concatenate([acc_input_2,gy_input_2, acc_input_3, gy_input_3])

conv3 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv3_inputs)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*2,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)
conv3 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru3)
conv3 = BatchNormalization()(conv3)
#conv3 = Dropout(0.1,seed=42)(conv3)
gru3 = layers.GRU(kk*6,return_sequences=True)(conv3)
gru3 = layers.LeakyReLU(0.2)(gru3)
gru3 = BatchNormalization()(gru3)

mag_model = Model([acc_input_2,gy_input_2, acc_input_3, gy_input_3], gru3)

conv4_inputs = layers.concatenate([acc_input_4, gy_input_4])

conv4 = Conv1D(
    kk,kernel_size1,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(conv4_inputs)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*2,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)
conv4 = Conv1D(
    kk*6,kernel_size2,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(gru4)
conv4 = BatchNormalization()(conv4)
#conv4 = Dropout(0.1,seed=42)(conv4)
gru4 = layers.GRU(kk*6,return_sequences=True)(conv4)
gru4 = layers.LeakyReLU(0.2)(gru4)
gru4 = BatchNormalization()(gru4)

fft_xyz_model = Model([acc_input_4, gy_input_4], gru4)


concat = layers.concatenate([
    acc_model.output,gy_model.output,
    mag_model.output,fft_xyz_model.output
    ])
    
conv_tot = Conv1D(
    kk*6,kernel_size3,strides=stride,padding='same',activation='elu',
    kernel_initializer=he_normal(seed=42)
    )(concat)
conv_tot = BatchNormalization()(conv_tot)

# pool = layers.AveragePooling1D(9,strides=3,padding='same')(conv1)

# gru = layers.GRU(60)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
#gru = Dropout(0.2,seed=42)(gru)
# gru = layers.GRU(120,return_sequences=True)(concat)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.5,seed=42)(gru)
# gru = layers.GRU(60)(gru)
# gru = layers.LeakyReLU(0.2)(gru)
# gru = BatchNormalization()(gru)
# gru = Dropout(0.2,seed=42)(gru)
# outputs = Dense(61, activation='softmax')(gru)

pool = GlobalAveragePooling1D()(conv_tot)
outputs = Dense(61, activation='softmax')(pool)

model = Model([acc_input_1,gy_input_1,acc_input_2,gy_input_2,acc_input_3,gy_input_3,acc_input_4,gy_input_4],outputs)

model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_6[0][0]
#                                                                  input_3[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 6)       0           input_4[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      960         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      960         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      770         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      1150        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          conv1d_6[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         conv1d_7[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 150, 240)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 75, 60)       72060       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 60)       240         conv1d_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 192,421
# Trainable params: 191,101
# Non-trainable params: 1,320
# __________________________________________________________________________________________________

# %%
checkpoint_filepath = "simple_cnn_best.hdf5"

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=50,verbose=1)

history = model.fit_generator(
    generator=train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
#  13/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 1.8708 - accuracy: 0.8070 - val_loss: 4.6478 - val_accuracy: 0.1445
#
# Epoch 00013: val_loss did not improve from 3.05520
# Epoch 14/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 1.6650 - accuracy: 0.8300 - val_loss: 4.4941 - val_accuracy: 0.1367
#
# Epoch 00014: val_loss did not improve from 3.05520
# Epoch 15/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 1.5428 - accuracy: 0.8323 - val_loss: 4.4908 - val_accuracy: 0.1250
#
# Epoch 00015: val_loss did not improve from 3.05520
# Epoch 16/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 1.5432 - accuracy: 0.8493 - val_loss: 3.7146 - val_accuracy: 0.2734
#
# Epoch 00016: val_loss did not improve from 3.05520
# Epoch 17/2000
# 34/34 [==============================] - 4s 128ms/step - loss: 1.5024 - accuracy: 0.8415 - val_loss: 2.3897 - val_accuracy: 0.4453
#
# Epoch 00017: val_loss improved from 3.05520 to 2.38975, saving model to simple_cnn_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 1.2999 - accuracy: 0.8571 - val_loss: 2.1295 - val_accuracy: 0.5234
#
# Epoch 00018: val_loss improved from 2.38975 to 2.12953, saving model to simple_cnn_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 1.3497 - accuracy: 0.8585 - val_loss: 1.1981 - val_accuracy: 0.6523
#
# Epoch 00019: val_loss improved from 2.12953 to 1.19814, saving model to simple_cnn_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 5s 134ms/step - loss: 1.3449 - accuracy: 0.8474 - val_loss: 1.4804 - val_accuracy: 0.6602
#
# Epoch 00020: val_loss did not improve from 1.19814
# Epoch 21/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 1.3627 - accuracy: 0.8378 - val_loss: 1.3454 - val_accuracy: 0.6797
#
# Epoch 00021: val_loss did not improve from 1.19814
# Epoch 22/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 1.1885 - accuracy: 0.8598 - val_loss: 1.5522 - val_accuracy: 0.5742
#
# Epoch 00022: val_loss did not improve from 1.19814
# Epoch 23/2000
# 34/34 [==============================] - 4s 130ms/step - loss: 1.0373 - accuracy: 0.8906 - val_loss: 1.1966 - val_accuracy: 0.7031
#
# Epoch 00023: val_loss improved from 1.19814 to 1.19657, saving model to simple_cnn_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 4s 127ms/step - loss: 1.0585 - accuracy: 0.8865 - val_loss: 1.2902 - val_accuracy: 0.6328
#
# Epoch 00024: val_loss did not improve from 1.19657
# Epoch 25/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.9789 - accuracy: 0.9012 - val_loss: 1.0469 - val_accuracy: 0.7031
#
# Epoch 00025: val_loss improved from 1.19657 to 1.04686, saving model to simple_cnn_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.8878 - accuracy: 0.9108 - val_loss: 1.1938 - val_accuracy: 0.7227
#
# Epoch 00026: val_loss did not improve from 1.04686
# Epoch 27/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.8965 - accuracy: 0.9026 - val_loss: 1.4021 - val_accuracy: 0.6875
#
# Epoch 00027: val_loss did not improve from 1.04686
# Epoch 28/2000
# 34/34 [==============================] - 4s 129ms/step - loss: 0.8902 - accuracy: 0.9035 - val_loss: 0.9170 - val_accuracy: 0.7305
#
# Epoch 00028: val_loss improved from 1.04686 to 0.91695, saving model to simple_cnn_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.8620 - accuracy: 0.9081 - val_loss: 0.7261 - val_accuracy: 0.8047
#
# Epoch 00029: val_loss improved from 0.91695 to 0.72612, saving model to simple_cnn_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.8281 - accuracy: 0.9090 - val_loss: 0.7827 - val_accuracy: 0.7734
#
# Epoch 00030: val_loss did not improve from 0.72612
# Epoch 31/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.8028 - accuracy: 0.9122 - val_loss: 0.8483 - val_accuracy: 0.7656
#
# Epoch 00031: val_loss did not improve from 0.72612
# Epoch 32/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.7868 - accuracy: 0.9177 - val_loss: 1.0131 - val_accuracy: 0.7344
#
# Epoch 00032: val_loss did not improve from 0.72612
# Epoch 33/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.8492 - accuracy: 0.9108 - val_loss: 0.9530 - val_accuracy: 0.7500
#
# Epoch 00033: val_loss did not improve from 0.72612
# Epoch 34/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.7881 - accuracy: 0.9154 - val_loss: 0.9016 - val_accuracy: 0.7422
#
# Epoch 00034: val_loss did not improve from 0.72612
# Epoch 35/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6942 - accuracy: 0.9265 - val_loss: 0.8987 - val_accuracy: 0.7539
#
# Epoch 00035: val_loss did not improve from 0.72612
# Epoch 36/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6985 - accuracy: 0.9301 - val_loss: 0.8357 - val_accuracy: 0.7578
#
# Epoch 00036: val_loss did not improve from 0.72612
# Epoch 37/2000
# 34/34 [==============================] - 4s 118ms/step - loss: 0.6307 - accuracy: 0.9320 - val_loss: 0.7706 - val_accuracy: 0.7695
#
# Epoch 00037: val_loss did not improve from 0.72612
# Epoch 38/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.8258 - accuracy: 0.9090 - val_loss: 0.8377 - val_accuracy: 0.7656
#
# Epoch 00038: val_loss did not improve from 0.72612
# Epoch 39/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6337 - accuracy: 0.9380 - val_loss: 0.7268 - val_accuracy: 0.7812
#
# Epoch 00039: val_loss did not improve from 0.72612
# Epoch 40/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6678 - accuracy: 0.9366 - val_loss: 0.7706 - val_accuracy: 0.7930
#
# Epoch 00040: val_loss did not improve from 0.72612
# Epoch 41/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.7453 - accuracy: 0.9219 - val_loss: 0.7258 - val_accuracy: 0.8008
#
# Epoch 00041: val_loss improved from 0.72612 to 0.72577, saving model to simple_cnn_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6625 - accuracy: 0.9334 - val_loss: 0.6701 - val_accuracy: 0.8164
#
# Epoch 00042: val_loss improved from 0.72577 to 0.67009, saving model to simple_cnn_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5656 - accuracy: 0.9499 - val_loss: 0.6432 - val_accuracy: 0.7969
#
# Epoch 00043: val_loss improved from 0.67009 to 0.64322, saving model to simple_cnn_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.7048 - accuracy: 0.9233 - val_loss: 0.7708 - val_accuracy: 0.7656
#
# Epoch 00044: val_loss did not improve from 0.64322
# Epoch 45/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6856 - accuracy: 0.9269 - val_loss: 0.7239 - val_accuracy: 0.7969
#
# Epoch 00045: val_loss did not improve from 0.64322
# Epoch 46/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6247 - accuracy: 0.9403 - val_loss: 0.7444 - val_accuracy: 0.7891
#
# Epoch 00046: val_loss did not improve from 0.64322
# Epoch 47/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6585 - accuracy: 0.9324 - val_loss: 0.7512 - val_accuracy: 0.7773
#
# Epoch 00047: val_loss did not improve from 0.64322
# Epoch 48/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6670 - accuracy: 0.9260 - val_loss: 0.7298 - val_accuracy: 0.7891
#
# Epoch 00048: val_loss did not improve from 0.64322
# Epoch 49/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6428 - accuracy: 0.9306 - val_loss: 0.7211 - val_accuracy: 0.7773
#
# Epoch 00049: val_loss did not improve from 0.64322
# Epoch 50/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.5860 - accuracy: 0.9439 - val_loss: 0.7037 - val_accuracy: 0.8047
#
# Epoch 00050: val_loss did not improve from 0.64322
# Epoch 51/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6446 - accuracy: 0.9324 - val_loss: 0.7161 - val_accuracy: 0.8086
#
# Epoch 00051: val_loss did not improve from 0.64322
# Epoch 52/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.6629 - accuracy: 0.9361 - val_loss: 0.7336 - val_accuracy: 0.8047
#
# Epoch 00052: val_loss did not improve from 0.64322
# Epoch 53/2000
# 34/34 [==============================] - 5s 135ms/step - loss: 0.5767 - accuracy: 0.9476 - val_loss: 0.6918 - val_accuracy: 0.8047
#
# Epoch 00053: val_loss did not improve from 0.64322
# Epoch 54/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.6593 - accuracy: 0.9347 - val_loss: 0.7149 - val_accuracy: 0.7969
#
# Epoch 00054: val_loss did not improve from 0.64322
# Epoch 55/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6914 - accuracy: 0.9269 - val_loss: 0.7389 - val_accuracy: 0.7891
#
# Epoch 00055: val_loss did not improve from 0.64322
# Epoch 56/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6409 - accuracy: 0.9347 - val_loss: 0.7100 - val_accuracy: 0.7969
#
# Epoch 00056: val_loss did not improve from 0.64322
# Epoch 57/2000
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6183 - accuracy: 0.9426 - val_loss: 0.7232 - val_accuracy: 0.7930
#
# Epoch 00057: val_loss did not improve from 0.64322
# Epoch 58/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6110 - accuracy: 0.9403 - val_loss: 0.7301 - val_accuracy: 0.7969
#
# Epoch 00058: val_loss did not improve from 0.64322
# Epoch 59/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5769 - accuracy: 0.9435 - val_loss: 0.7146 - val_accuracy: 0.7930
#
# Epoch 00059: val_loss did not improve from 0.64322
# Epoch 60/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5582 - accuracy: 0.9426 - val_loss: 0.7057 - val_accuracy: 0.7852
#
# Epoch 00060: val_loss did not improve from 0.64322
# Epoch 61/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.5011 - accuracy: 0.9531 - val_loss: 0.6180 - val_accuracy: 0.8086
#
# Epoch 00061: val_loss improved from 0.64322 to 0.61796, saving model to simple_cnn_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.5611 - accuracy: 0.9435 - val_loss: 0.7242 - val_accuracy: 0.7891
#
# Epoch 00062: val_loss did not improve from 0.61796
# Epoch 63/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.5459 - accuracy: 0.9472 - val_loss: 0.7036 - val_accuracy: 0.7969
#
# Epoch 00063: val_loss did not improve from 0.61796
# Epoch 64/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.5579 - accuracy: 0.9490 - val_loss: 0.7087 - val_accuracy: 0.8008
#
# Epoch 00064: val_loss did not improve from 0.61796
# Epoch 65/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6422 - accuracy: 0.9343 - val_loss: 0.7189 - val_accuracy: 0.8008
#
# Epoch 00065: val_loss did not improve from 0.61796
# Epoch 66/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6060 - accuracy: 0.9403 - val_loss: 0.7248 - val_accuracy: 0.7969
#
# Epoch 00066: val_loss did not improve from 0.61796
# Epoch 67/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5331 - accuracy: 0.9522 - val_loss: 0.7167 - val_accuracy: 0.8047
#
# Epoch 00067: val_loss did not improve from 0.61796
# Epoch 68/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6273 - accuracy: 0.9407 - val_loss: 0.7064 - val_accuracy: 0.8008
#
# Epoch 00068: val_loss did not improve from 0.61796
# Epoch 69/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.7010 - accuracy: 0.9320 - val_loss: 0.6916 - val_accuracy: 0.8047
#
# Epoch 00069: val_loss did not improve from 0.61796
# Epoch 70/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6383 - accuracy: 0.9398 - val_loss: 0.7351 - val_accuracy: 0.7812
#
# Epoch 00070: val_loss did not improve from 0.61796
# Epoch 71/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6242 - accuracy: 0.9366 - val_loss: 0.7344 - val_accuracy: 0.7812
#
# Epoch 00071: val_loss did not improve from 0.61796
# Epoch 72/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.5259 - accuracy: 0.9476 - val_loss: 0.7006 - val_accuracy: 0.7930
#
# Epoch 00072: val_loss did not improve from 0.61796
# Epoch 73/2000
# 34/34 [==============================] - 4s 127ms/step - loss: 0.5387 - accuracy: 0.9494 - val_loss: 0.7194 - val_accuracy: 0.8047
#
# Epoch 00073: val_loss did not improve from 0.61796
# Epoch 74/2000
# 34/34 [==============================] - 5s 131ms/step - loss: 0.5770 - accuracy: 0.9439 - val_loss: 0.7076 - val_accuracy: 0.8008
#
# Epoch 00074: val_loss did not improve from 0.61796
# Epoch 75/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6423 - accuracy: 0.9366 - val_loss: 0.7442 - val_accuracy: 0.7773
#
# Epoch 00075: val_loss did not improve from 0.61796
# Epoch 76/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.5920 - accuracy: 0.9453 - val_loss: 0.7186 - val_accuracy: 0.7891
#
# Epoch 00076: val_loss did not improve from 0.61796
# Epoch 77/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.5771 - accuracy: 0.9467 - val_loss: 0.7382 - val_accuracy: 0.7891
#
# Epoch 00077: val_loss did not improve from 0.61796
# Epoch 78/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.7022 - accuracy: 0.9343 - val_loss: 0.6798 - val_accuracy: 0.8047
#
# Epoch 00078: val_loss did not improve from 0.61796
# Epoch 79/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.5765 - accuracy: 0.9421 - val_loss: 0.7279 - val_accuracy: 0.7930
#
# Epoch 00079: val_loss did not improve from 0.61796
# Epoch 80/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.5954 - accuracy: 0.9449 - val_loss: 0.7146 - val_accuracy: 0.7969
#
# Epoch 00080: val_loss did not improve from 0.61796
# Epoch 81/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6109 - accuracy: 0.9403 - val_loss: 0.7131 - val_accuracy: 0.7969
#
# Epoch 00081: val_loss did not improve from 0.61796
# Epoch 82/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5927 - accuracy: 0.9449 - val_loss: 0.7269 - val_accuracy: 0.8008
#
# Epoch 00082: val_loss did not improve from 0.61796
# Epoch 83/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.4793 - accuracy: 0.9577 - val_loss: 0.7117 - val_accuracy: 0.7969
#
# Epoch 00083: val_loss did not improve from 0.61796
# Epoch 84/2000
# 34/34 [==============================] - 4s 127ms/step - loss: 0.5973 - accuracy: 0.9398 - val_loss: 0.7283 - val_accuracy: 0.7969
#
# Epoch 00084: val_loss did not improve from 0.61796
# Epoch 85/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6264 - accuracy: 0.9403 - val_loss: 0.6310 - val_accuracy: 0.8164
#
# Epoch 00085: val_loss did not improve from 0.61796
# Epoch 86/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6327 - accuracy: 0.9398 - val_loss: 0.7349 - val_accuracy: 0.7891
#
# Epoch 00086: val_loss did not improve from 0.61796
# Epoch 87/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6228 - accuracy: 0.9370 - val_loss: 0.6651 - val_accuracy: 0.8008
#
# Epoch 00087: val_loss did not improve from 0.61796
# Epoch 88/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.7063 - accuracy: 0.9256 - val_loss: 0.6717 - val_accuracy: 0.8047
#
# Epoch 00088: val_loss did not improve from 0.61796
# Epoch 89/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5321 - accuracy: 0.9508 - val_loss: 0.6727 - val_accuracy: 0.8047
#
# Epoch 00089: val_loss did not improve from 0.61796
# Epoch 90/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6056 - accuracy: 0.9389 - val_loss: 0.7229 - val_accuracy: 0.7930
#
# Epoch 00090: val_loss did not improve from 0.61796
# Epoch 91/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5457 - accuracy: 0.9513 - val_loss: 0.7331 - val_accuracy: 0.7812
#
# Epoch 00091: val_loss did not improve from 0.61796
# Epoch 92/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.6858 - accuracy: 0.9334 - val_loss: 0.7146 - val_accuracy: 0.7891
#
# Epoch 00092: val_loss did not improve from 0.61796
# Epoch 93/2000
# 34/34 [==============================] - 4s 126ms/step - loss: 0.5168 - accuracy: 0.9559 - val_loss: 0.6613 - val_accuracy: 0.8047
#
# Epoch 00093: val_loss did not improve from 0.61796
# Epoch 94/2000
# 34/34 [==============================] - 4s 125ms/step - loss: 0.6291 - accuracy: 0.9393 - val_loss: 0.7006 - val_accuracy: 0.7891
#
# Epoch 00094: val_loss did not improve from 0.61796
# Epoch 95/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.6940 - accuracy: 0.9343 - val_loss: 0.7095 - val_accuracy: 0.7812
#
# Epoch 00095: val_loss did not improve from 0.61796
# Epoch 96/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.5965 - accuracy: 0.9366 - val_loss: 0.6936 - val_accuracy: 0.7969
#
# Epoch 00096: val_loss did not improve from 0.61796
# Epoch 97/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.5919 - accuracy: 0.9430 - val_loss: 0.7201 - val_accuracy: 0.7852
#
# Epoch 00097: val_loss did not improve from 0.61796
# Epoch 98/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5851 - accuracy: 0.9435 - val_loss: 0.6320 - val_accuracy: 0.8086
#
# Epoch 00098: val_loss did not improve from 0.61796
# Epoch 99/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5965 - accuracy: 0.9398 - val_loss: 0.7025 - val_accuracy: 0.8086
#
# Epoch 00099: val_loss did not improve from 0.61796
# Epoch 100/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6154 - accuracy: 0.9430 - val_loss: 0.6992 - val_accuracy: 0.7930
#
# Epoch 00100: val_loss did not improve from 0.61796
# Epoch 101/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6829 - accuracy: 0.9297 - val_loss: 0.7313 - val_accuracy: 0.7891
#
# Epoch 00101: val_loss did not improve from 0.61796
# Epoch 102/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6654 - accuracy: 0.9334 - val_loss: 0.7229 - val_accuracy: 0.7891
#
# Epoch 00102: val_loss did not improve from 0.61796
# Epoch 103/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5783 - accuracy: 0.9467 - val_loss: 0.7082 - val_accuracy: 0.7969
#
# Epoch 00103: val_loss did not improve from 0.61796
# Epoch 104/2000
# 34/34 [==============================] - 4s 120ms/step - loss: 0.5569 - accuracy: 0.9476 - val_loss: 0.7270 - val_accuracy: 0.7852
#
# Epoch 00104: val_loss did not improve from 0.61796
# Epoch 105/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6059 - accuracy: 0.9439 - val_loss: 0.7186 - val_accuracy: 0.7891
#
# Epoch 00105: val_loss did not improve from 0.61796
# Epoch 106/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.6063 - accuracy: 0.9403 - val_loss: 0.7056 - val_accuracy: 0.7930
#
# Epoch 00106: val_loss did not improve from 0.61796
# Epoch 107/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5963 - accuracy: 0.9412 - val_loss: 0.7423 - val_accuracy: 0.7812
#
# Epoch 00107: val_loss did not improve from 0.61796
# Epoch 108/2000
# 34/34 [==============================] - 4s 124ms/step - loss: 0.5830 - accuracy: 0.9462 - val_loss: 0.6911 - val_accuracy: 0.7852
#
# Epoch 00108: val_loss did not improve from 0.61796
# Epoch 109/2000
# 34/34 [==============================] - 4s 122ms/step - loss: 0.5650 - accuracy: 0.9426 - val_loss: 0.6962 - val_accuracy: 0.7930
#
# Epoch 00109: val_loss did not improve from 0.61796
# Epoch 110/2000
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6229 - accuracy: 0.9393 - val_loss: 0.7162 - val_accuracy: 0.7969
#
# Epoch 00110: val_loss did not improve from 0.61796
# Epoch 111/2000
# 34/34 [==============================] - 4s 121ms/step - loss: 0.5486 - accuracy: 0.9490 - val_loss: 0.6972 - val_accuracy: 0.8047
#
# Epoch 00111: val_loss did not improve from 0.61796
# Epoch 00111: early stopping

# %%
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'

# %%
test_loader = Workout_dataset(
        test_dir, test_label_dir, mode='Test', batch_size=625, shuffle=False)

# %%
model.load_weights(checkpoint_filepath)
model.evaluate_generator(generator=test_loader,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1973: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# 1/1 [==============================] - 1s 990ms/step - loss: 0.5966 - accuracy: 0.8176
# [0.5966230034828186, 0.8176000118255615]
