# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
def scheduler(epoch, lr):
    if (epoch>20) and (lr > 0.00001):
        lr = lr*0.9
        return lr
    else:
        return lr

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, augment=True, shuffle=True)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3,
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, #0.2
    res_num = 15, # 3, #5#, 7, #9#
    )

model.summary()
# Out:
# ____________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_37[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_40[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 150, 60)      32460       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 120)     480         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 60)      240         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 150, 60)      0           leaky_re_lu_49[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 150, 60)      32460       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 120)     480         conv1d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 60)      240         conv1d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 150, 60)      0           leaky_re_lu_52[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 150, 60)      32460       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 120)     480         conv1d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 60)      240         conv1d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 150, 60)      0           leaky_re_lu_55[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 150, 60)      32460       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 120)     480         conv1d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 150, 60)      240         conv1d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 150, 60)      0           leaky_re_lu_58[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 150, 60)      32460       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 150, 60)      240         conv1d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 150, 120)     480         conv1d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 150, 60)      240         conv1d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 150, 60)      0           leaky_re_lu_61[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 150, 60)      32460       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 150, 60)      240         conv1d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 150, 120)     480         conv1d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 150, 60)      240         conv1d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 150, 60)      0           leaky_re_lu_64[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 150, 60)      240         add_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,593,051
# Trainable params: 1,584,231
# Non-trainable params: 8,820
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=20,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 45s 362ms/step - loss: 65.7597 - accuracy: 0.3024 - val_loss: 48.2466 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 48.24656, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 40.5264 - accuracy: 0.5409 - val_loss: 29.9016 - val_accuracy: 0.4531
#
# Epoch 00002: val_loss improved from 48.24656 to 29.90164, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 8s 237ms/step - loss: 25.2888 - accuracy: 0.6347 - val_loss: 19.2145 - val_accuracy: 0.4414
#
# Epoch 00003: val_loss improved from 29.90164 to 19.21450, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 16.5248 - accuracy: 0.6774 - val_loss: 13.0738 - val_accuracy: 0.4648
#
# Epoch 00004: val_loss improved from 19.21450 to 13.07384, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 11.6687 - accuracy: 0.6714 - val_loss: 9.6147 - val_accuracy: 0.4570
#
# Epoch 00005: val_loss improved from 13.07384 to 9.61469, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 8.5319 - accuracy: 0.7063 - val_loss: 7.6363 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 9.61469 to 7.63626, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 6.5354 - accuracy: 0.7073 - val_loss: 6.5371 - val_accuracy: 0.4570
#
# Epoch 00007: val_loss improved from 7.63626 to 6.53709, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 5.2644 - accuracy: 0.7224 - val_loss: 5.8505 - val_accuracy: 0.4531
#
# Epoch 00008: val_loss improved from 6.53709 to 5.85050, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 4.6125 - accuracy: 0.7174 - val_loss: 5.7838 - val_accuracy: 0.4453
#
# Epoch 00009: val_loss improved from 5.85050 to 5.78376, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 4.0374 - accuracy: 0.7339 - val_loss: 7.4964 - val_accuracy: 0.0078
#
# Epoch 00010: val_loss did not improve from 5.78376
# Epoch 11/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 3.5121 - accuracy: 0.7606 - val_loss: 4.8378 - val_accuracy: 0.4766
#
# Epoch 00011: val_loss improved from 5.78376 to 4.83780, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 3.0769 - accuracy: 0.7835 - val_loss: 4.8862 - val_accuracy: 0.4453
#
# Epoch 00012: val_loss did not improve from 4.83780
# Epoch 13/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 3.0909 - accuracy: 0.7665 - val_loss: 5.7995 - val_accuracy: 0.0938
#
# Epoch 00013: val_loss did not improve from 4.83780
# Epoch 14/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 2.8048 - accuracy: 0.7863 - val_loss: 6.2902 - val_accuracy: 0.0352
#
# Epoch 00014: val_loss did not improve from 4.83780
# Epoch 15/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 2.6697 - accuracy: 0.7918 - val_loss: 4.0518 - val_accuracy: 0.3125
#
# Epoch 00015: val_loss improved from 4.83780 to 4.05184, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 2.6180 - accuracy: 0.7886 - val_loss: 5.0227 - val_accuracy: 0.1562
#
# Epoch 00016: val_loss did not improve from 4.05184
# Epoch 17/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 2.5552 - accuracy: 0.7987 - val_loss: 4.0492 - val_accuracy: 0.3086
#
# Epoch 00017: val_loss improved from 4.05184 to 4.04919, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 2.3249 - accuracy: 0.8157 - val_loss: 2.9927 - val_accuracy: 0.5195
#
# Epoch 00018: val_loss improved from 4.04919 to 2.99266, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 2.4363 - accuracy: 0.7973 - val_loss: 3.2388 - val_accuracy: 0.4414
#
# Epoch 00019: val_loss did not improve from 2.99266
# Epoch 20/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 2.3385 - accuracy: 0.8070 - val_loss: 3.4449 - val_accuracy: 0.2695
#
# Epoch 00020: val_loss did not improve from 2.99266
# Epoch 21/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 2.2844 - accuracy: 0.8120 - val_loss: 2.5074 - val_accuracy: 0.5469
#
# Epoch 00021: val_loss improved from 2.99266 to 2.50741, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 2.1212 - accuracy: 0.8222 - val_loss: 1.9498 - val_accuracy: 0.6445
#
# Epoch 00022: val_loss improved from 2.50741 to 1.94982, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.8191 - accuracy: 0.8566 - val_loss: 1.7867 - val_accuracy: 0.6719
#
# Epoch 00023: val_loss improved from 1.94982 to 1.78673, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.8389 - accuracy: 0.8442 - val_loss: 1.6743 - val_accuracy: 0.6797
#
# Epoch 00024: val_loss improved from 1.78673 to 1.67434, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 1.7470 - accuracy: 0.8548 - val_loss: 1.4948 - val_accuracy: 0.6758
#
# Epoch 00025: val_loss improved from 1.67434 to 1.49476, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 1.5789 - accuracy: 0.8667 - val_loss: 1.3491 - val_accuracy: 0.7383
#
# Epoch 00026: val_loss improved from 1.49476 to 1.34905, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 1.5429 - accuracy: 0.8649 - val_loss: 1.2943 - val_accuracy: 0.7383
#
# Epoch 00027: val_loss improved from 1.34905 to 1.29428, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.5388 - accuracy: 0.8709 - val_loss: 1.2293 - val_accuracy: 0.7773
#
# Epoch 00028: val_loss improved from 1.29428 to 1.22934, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.4553 - accuracy: 0.8759 - val_loss: 1.2206 - val_accuracy: 0.7695
#
# Epoch 00029: val_loss improved from 1.22934 to 1.22057, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.4733 - accuracy: 0.8727 - val_loss: 1.1858 - val_accuracy: 0.7578
#
# Epoch 00030: val_loss improved from 1.22057 to 1.18585, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.3494 - accuracy: 0.8856 - val_loss: 1.1525 - val_accuracy: 0.7852
#
# Epoch 00031: val_loss improved from 1.18585 to 1.15247, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.3518 - accuracy: 0.8883 - val_loss: 1.1541 - val_accuracy: 0.7891
#
# Epoch 00032: val_loss did not improve from 1.15247
# Epoch 33/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 1.3782 - accuracy: 0.8759 - val_loss: 1.1753 - val_accuracy: 0.7617
#
# Epoch 00033: val_loss did not improve from 1.15247
# Epoch 34/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.2514 - accuracy: 0.8984 - val_loss: 1.0246 - val_accuracy: 0.8047
#
# Epoch 00034: val_loss improved from 1.15247 to 1.02461, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.1442 - accuracy: 0.9090 - val_loss: 1.1157 - val_accuracy: 0.7617
#
# Epoch 00035: val_loss did not improve from 1.02461
# Epoch 36/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.1061 - accuracy: 0.9067 - val_loss: 1.0187 - val_accuracy: 0.7812
#
# Epoch 00036: val_loss improved from 1.02461 to 1.01868, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.0253 - accuracy: 0.9164 - val_loss: 1.0743 - val_accuracy: 0.8008
#
# Epoch 00037: val_loss did not improve from 1.01868
# Epoch 38/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 1.2803 - accuracy: 0.8920 - val_loss: 1.0782 - val_accuracy: 0.7617
#
# Epoch 00038: val_loss did not improve from 1.01868
# Epoch 39/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 1.0200 - accuracy: 0.9205 - val_loss: 1.0004 - val_accuracy: 0.7891
#
# Epoch 00039: val_loss improved from 1.01868 to 1.00035, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 1.0198 - accuracy: 0.9154 - val_loss: 0.9573 - val_accuracy: 0.7930
#
# Epoch 00040: val_loss improved from 1.00035 to 0.95733, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 1.0933 - accuracy: 0.9049 - val_loss: 1.0162 - val_accuracy: 0.7891
#
# Epoch 00041: val_loss did not improve from 0.95733
# Epoch 42/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.9756 - accuracy: 0.9228 - val_loss: 0.9666 - val_accuracy: 0.8008
#
# Epoch 00042: val_loss did not improve from 0.95733
# Epoch 43/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.8690 - accuracy: 0.9347 - val_loss: 0.9359 - val_accuracy: 0.7891
#
# Epoch 00043: val_loss improved from 0.95733 to 0.93592, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.9954 - accuracy: 0.9150 - val_loss: 0.9994 - val_accuracy: 0.7969
#
# Epoch 00044: val_loss did not improve from 0.93592
# Epoch 45/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.9567 - accuracy: 0.9205 - val_loss: 0.9753 - val_accuracy: 0.7969
#
# Epoch 00045: val_loss did not improve from 0.93592
# Epoch 46/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.8663 - accuracy: 0.9306 - val_loss: 1.0348 - val_accuracy: 0.7891
#
# Epoch 00046: val_loss did not improve from 0.93592
# Epoch 47/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.9245 - accuracy: 0.9297 - val_loss: 0.9586 - val_accuracy: 0.8047
#
# Epoch 00047: val_loss did not improve from 0.93592
# Epoch 48/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.9034 - accuracy: 0.9278 - val_loss: 0.9727 - val_accuracy: 0.8164
#
# Epoch 00048: val_loss did not improve from 0.93592
# Epoch 49/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.8736 - accuracy: 0.9292 - val_loss: 0.9579 - val_accuracy: 0.8008
#
# Epoch 00049: val_loss did not improve from 0.93592
# Epoch 50/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.8149 - accuracy: 0.9347 - val_loss: 0.9385 - val_accuracy: 0.8008
#
# Epoch 00050: val_loss did not improve from 0.93592
# Epoch 51/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.8487 - accuracy: 0.9334 - val_loss: 0.9959 - val_accuracy: 0.7773
#
# Epoch 00051: val_loss did not improve from 0.93592
# Epoch 52/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.8742 - accuracy: 0.9292 - val_loss: 0.9668 - val_accuracy: 0.8008
#
# Epoch 00052: val_loss did not improve from 0.93592
# Epoch 53/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.7482 - accuracy: 0.9472 - val_loss: 0.9236 - val_accuracy: 0.7930
#
# Epoch 00053: val_loss improved from 0.93592 to 0.92358, saving model to ./save/cnn_gru_best.hdf5
# Epoch 54/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.8310 - accuracy: 0.9338 - val_loss: 0.9471 - val_accuracy: 0.7969
#
# Epoch 00054: val_loss did not improve from 0.92358
# Epoch 55/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 0.8586 - accuracy: 0.9237 - val_loss: 0.9868 - val_accuracy: 0.7891
#
# Epoch 00055: val_loss did not improve from 0.92358
# Epoch 56/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 0.7979 - accuracy: 0.9361 - val_loss: 0.9756 - val_accuracy: 0.7969
#
# Epoch 00056: val_loss did not improve from 0.92358
# Epoch 57/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.7518 - accuracy: 0.9389 - val_loss: 0.9590 - val_accuracy: 0.8047
#
# Epoch 00057: val_loss did not improve from 0.92358
# Epoch 58/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.7541 - accuracy: 0.9453 - val_loss: 0.9293 - val_accuracy: 0.8086
#
# Epoch 00058: val_loss did not improve from 0.92358
# Epoch 59/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.7201 - accuracy: 0.9481 - val_loss: 0.9321 - val_accuracy: 0.8008
#
# Epoch 00059: val_loss did not improve from 0.92358
# Epoch 60/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 0.6850 - accuracy: 0.9472 - val_loss: 0.9612 - val_accuracy: 0.8008
#
# Epoch 00060: val_loss did not improve from 0.92358
# Epoch 61/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.6341 - accuracy: 0.9582 - val_loss: 0.8609 - val_accuracy: 0.8164
#
# Epoch 00061: val_loss improved from 0.92358 to 0.86087, saving model to ./save/cnn_gru_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.6902 - accuracy: 0.9508 - val_loss: 0.9718 - val_accuracy: 0.8047
#
# Epoch 00062: val_loss did not improve from 0.86087
# Epoch 63/2000
# 34/34 [==============================] - 8s 230ms/step - loss: 0.6696 - accuracy: 0.9545 - val_loss: 0.9472 - val_accuracy: 0.8086
#
# Epoch 00063: val_loss did not improve from 0.86087
# Epoch 64/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.6669 - accuracy: 0.9494 - val_loss: 0.9624 - val_accuracy: 0.8008
#
# Epoch 00064: val_loss did not improve from 0.86087
# Epoch 65/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.7445 - accuracy: 0.9357 - val_loss: 0.9538 - val_accuracy: 0.8125
#
# Epoch 00065: val_loss did not improve from 0.86087
# Epoch 66/2000
# 34/34 [==============================] - 8s 235ms/step - loss: 0.6917 - accuracy: 0.9504 - val_loss: 0.9458 - val_accuracy: 0.8164
#
# Epoch 00066: val_loss did not improve from 0.86087
# Epoch 67/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.6418 - accuracy: 0.9563 - val_loss: 0.9584 - val_accuracy: 0.8125
#
# Epoch 00067: val_loss did not improve from 0.86087
# Epoch 68/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.7230 - accuracy: 0.9439 - val_loss: 0.9408 - val_accuracy: 0.8203
#
# Epoch 00068: val_loss did not improve from 0.86087
# Epoch 69/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.7917 - accuracy: 0.9375 - val_loss: 0.9312 - val_accuracy: 0.8281
#
# Epoch 00069: val_loss did not improve from 0.86087
# Epoch 70/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.7258 - accuracy: 0.9467 - val_loss: 0.9615 - val_accuracy: 0.8086
#
# Epoch 00070: val_loss did not improve from 0.86087
# Epoch 71/2000
# 34/34 [==============================] - 8s 234ms/step - loss: 0.7131 - accuracy: 0.9476 - val_loss: 0.9646 - val_accuracy: 0.8164
#
# Epoch 00071: val_loss did not improve from 0.86087
# Epoch 72/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.6208 - accuracy: 0.9554 - val_loss: 0.9259 - val_accuracy: 0.8281
#
# Epoch 00072: val_loss did not improve from 0.86087
# Epoch 73/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.6128 - accuracy: 0.9596 - val_loss: 0.9669 - val_accuracy: 0.8125
#
# Epoch 00073: val_loss did not improve from 0.86087
# Epoch 74/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.6664 - accuracy: 0.9494 - val_loss: 0.9599 - val_accuracy: 0.8125
#
# Epoch 00074: val_loss did not improve from 0.86087
# Epoch 75/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.7280 - accuracy: 0.9426 - val_loss: 1.0020 - val_accuracy: 0.8008
#
# Epoch 00075: val_loss did not improve from 0.86087
# Epoch 76/2000
# 34/34 [==============================] - 8s 232ms/step - loss: 0.6808 - accuracy: 0.9467 - val_loss: 0.9637 - val_accuracy: 0.7969
#
# Epoch 00076: val_loss did not improve from 0.86087
# Epoch 77/2000
# 34/34 [==============================] - 8s 229ms/step - loss: 0.6875 - accuracy: 0.9462 - val_loss: 0.9909 - val_accuracy: 0.8047
#
# Epoch 00077: val_loss did not improve from 0.86087
# Epoch 78/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.7677 - accuracy: 0.9403 - val_loss: 0.9301 - val_accuracy: 0.8164
#
# Epoch 00078: val_loss did not improve from 0.86087
# Epoch 79/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.6326 - accuracy: 0.9545 - val_loss: 0.9614 - val_accuracy: 0.8086
#
# Epoch 00079: val_loss did not improve from 0.86087
# Epoch 80/2000
# 34/34 [==============================] - 8s 231ms/step - loss: 0.6614 - accuracy: 0.9485 - val_loss: 0.9736 - val_accuracy: 0.8086
#
# Epoch 00080: val_loss did not improve from 0.86087
# Epoch 81/2000
# 34/34 [==============================] - 8s 233ms/step - loss: 0.6741 - accuracy: 0.9499 - val_loss: 0.9652 - val_accuracy: 0.8164
#
# Epoch 00081: val_loss did not improve from 0.86087
# Epoch 00081: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.7776 - accuracy: 0.8240
# [0.7775841951370239, 0.8240000009536743]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
