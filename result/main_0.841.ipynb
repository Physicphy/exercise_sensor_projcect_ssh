# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 4,verbose = 1,factor = 0.5) 

# def scheduler(epoch, lr):
#     if (epoch>20) and (lr > 0.00001):
#         lr = lr*0.9
#         return lr
#     else:
#         return lr

# lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=0, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=0, batch_size=16, shuffle=True)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.2,
    input_kernels = 10,
    input_kernel_width = 3,
    res_kernels = 60,
    res_kernel_width = 3,
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 9, # 3, 5, 7, #9#
    )

model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 4)       0           input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 6)       0           input_4[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 6)       0           input_1[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 10)      910         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 10)      910         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 10)      730         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 10)      1090        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 10)      1090        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 10)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 10)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 10)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 10)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 10)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 10)      40          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 10)      40          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 10)      40          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 10)      40          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 10)      40          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 20)      1920        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 20)      1920        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 20)      1920        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 20)      1920        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 20)      1920        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 20)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 20)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 20)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 20)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 20)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 20)      80          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 20)      80          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 20)      80          leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 20)      80          leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 20)      80          leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 60)      3660        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 60)      3660        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 60)      3660        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 60)      3660        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 60)      3660        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 60)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 60)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 60)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 60)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 60)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 60)      240         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 60)      240         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 60)      240         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 60)      240         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 60)      240         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 60)      21960       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 60)      21960       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 60)      21960       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 60)      21960       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 60)      21960       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 60)      0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 60)      0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 60)      0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 60)      0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 60)      0           gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 60)      240         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 60)      240         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 60)      240         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 60)      240         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 60)      240         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 150, 300)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 120)     480         conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      162060      concatenate_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_22[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 150, 120)     480         conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_25[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 60)      240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 150, 60)      240         conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_28[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150, 60)      32460       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 150, 60)      240         conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 150, 120)     480         conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 150, 60)      240         conv1d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150, 60)      0           leaky_re_lu_31[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      32460       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150, 60)      0           leaky_re_lu_34[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150, 60)      0           leaky_re_lu_37[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150, 60)      0           leaky_re_lu_40[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 60)      32460       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 150, 60)      240         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 60)      240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150, 60)      0           leaky_re_lu_43[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 150, 60)      32460       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         add_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,132,251
# Trainable params: 1,126,311
# Non-trainable params: 5,940
# __________________________________________________________________________________________________

# %%
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=20,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler],
    class_weight=class_weight_dict)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/2000
# 34/34 [==============================] - 36s 304ms/step - loss: 43.7279 - accuracy: 0.3212 - val_loss: 32.9173 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 32.91728, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 28.9060 - accuracy: 0.5414 - val_loss: 21.7500 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 32.91728 to 21.74999, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 19.2100 - accuracy: 0.6126 - val_loss: 14.7338 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 21.74999 to 14.73376, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 13.6098 - accuracy: 0.6374 - val_loss: 10.7953 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 14.73376 to 10.79526, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 9.8198 - accuracy: 0.6838 - val_loss: 8.5353 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 10.79526 to 8.53526, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 7.4783 - accuracy: 0.7045 - val_loss: 6.9583 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 8.53526 to 6.95834, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 5.9129 - accuracy: 0.7109 - val_loss: 6.1514 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 6.95834 to 6.15144, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 4.8473 - accuracy: 0.7417 - val_loss: 5.5748 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 6.15144 to 5.57479, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 4.0918 - accuracy: 0.7592 - val_loss: 5.3624 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss improved from 5.57479 to 5.36242, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 3.8157 - accuracy: 0.7454 - val_loss: 5.1479 - val_accuracy: 0.4375
#
# Epoch 00010: val_loss improved from 5.36242 to 5.14786, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 3.4925 - accuracy: 0.7514 - val_loss: 6.6865 - val_accuracy: 0.0273
#
# Epoch 00011: val_loss did not improve from 5.14786
# Epoch 12/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 3.2659 - accuracy: 0.7679 - val_loss: 7.7189 - val_accuracy: 0.0195
#
# Epoch 00012: val_loss did not improve from 5.14786
# Epoch 13/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 2.8543 - accuracy: 0.8033 - val_loss: 6.5816 - val_accuracy: 0.0586
#
# Epoch 00013: val_loss did not improve from 5.14786
# Epoch 14/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 2.6491 - accuracy: 0.8010 - val_loss: 5.1403 - val_accuracy: 0.2188
#
# Epoch 00014: val_loss improved from 5.14786 to 5.14027, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 2.6160 - accuracy: 0.7872 - val_loss: 5.2843 - val_accuracy: 0.1992
#
# Epoch 00015: val_loss did not improve from 5.14027
# Epoch 16/2000
# 34/34 [==============================] - 6s 187ms/step - loss: 2.5953 - accuracy: 0.7822 - val_loss: 7.5078 - val_accuracy: 0.1133
#
# Epoch 00016: val_loss did not improve from 5.14027
# Epoch 17/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 2.5446 - accuracy: 0.7872 - val_loss: 5.4244 - val_accuracy: 0.2344
#
# Epoch 00017: val_loss did not improve from 5.14027
# Epoch 18/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 2.2820 - accuracy: 0.8139 - val_loss: 2.6983 - val_accuracy: 0.5625
#
# Epoch 00018: val_loss improved from 5.14027 to 2.69831, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 2.1502 - accuracy: 0.8189 - val_loss: 3.2829 - val_accuracy: 0.4023
#
# Epoch 00019: val_loss did not improve from 2.69831
# Epoch 20/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 2.3544 - accuracy: 0.7932 - val_loss: 2.1011 - val_accuracy: 0.5898
#
# Epoch 00020: val_loss improved from 2.69831 to 2.10107, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 2.2306 - accuracy: 0.8042 - val_loss: 2.4612 - val_accuracy: 0.5195
#
# Epoch 00021: val_loss did not improve from 2.10107
# Epoch 22/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 2.0351 - accuracy: 0.8300 - val_loss: 1.7098 - val_accuracy: 0.7109
#
# Epoch 00022: val_loss improved from 2.10107 to 1.70979, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 2.0008 - accuracy: 0.8336 - val_loss: 1.8187 - val_accuracy: 0.6523
#
# Epoch 00023: val_loss did not improve from 1.70979
# Epoch 24/2000
# 34/34 [==============================] - 6s 188ms/step - loss: 1.9221 - accuracy: 0.8318 - val_loss: 1.7243 - val_accuracy: 0.6523
#
# Epoch 00024: val_loss did not improve from 1.70979
# Epoch 25/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.8541 - accuracy: 0.8387 - val_loss: 2.6949 - val_accuracy: 0.5000
#
# Epoch 00025: val_loss did not improve from 1.70979
# Epoch 26/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.8788 - accuracy: 0.8382 - val_loss: 3.9694 - val_accuracy: 0.3945
#
# Epoch 00026: val_loss did not improve from 1.70979
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 1.6762 - accuracy: 0.8631 - val_loss: 1.4547 - val_accuracy: 0.7344
#
# Epoch 00027: val_loss improved from 1.70979 to 1.45474, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.5809 - accuracy: 0.8699 - val_loss: 1.5934 - val_accuracy: 0.6758
#
# Epoch 00028: val_loss did not improve from 1.45474
# Epoch 29/2000
# 34/34 [==============================] - 6s 189ms/step - loss: 1.5478 - accuracy: 0.8686 - val_loss: 1.3108 - val_accuracy: 0.7227
#
# Epoch 00029: val_loss improved from 1.45474 to 1.31083, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.3613 - accuracy: 0.8805 - val_loss: 1.7235 - val_accuracy: 0.6680
#
# Epoch 00030: val_loss did not improve from 1.31083
# Epoch 31/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.3617 - accuracy: 0.8810 - val_loss: 1.2407 - val_accuracy: 0.7344
#
# Epoch 00031: val_loss improved from 1.31083 to 1.24068, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 1.3517 - accuracy: 0.8828 - val_loss: 1.2620 - val_accuracy: 0.7422
#
# Epoch 00032: val_loss did not improve from 1.24068
# Epoch 33/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.3371 - accuracy: 0.8879 - val_loss: 1.2869 - val_accuracy: 0.7422
#
# Epoch 00033: val_loss did not improve from 1.24068
# Epoch 34/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 1.3603 - accuracy: 0.8796 - val_loss: 1.2504 - val_accuracy: 0.7500
#
# Epoch 00034: val_loss did not improve from 1.24068
# Epoch 35/2000
# 34/34 [==============================] - 7s 196ms/step - loss: 1.3882 - accuracy: 0.8727 - val_loss: 1.3359 - val_accuracy: 0.7500
#
# Epoch 00035: val_loss did not improve from 1.24068
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 36/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 1.2827 - accuracy: 0.8906 - val_loss: 1.1809 - val_accuracy: 0.7695
#
# Epoch 00036: val_loss improved from 1.24068 to 1.18090, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 7s 200ms/step - loss: 1.1518 - accuracy: 0.9030 - val_loss: 1.1235 - val_accuracy: 0.7734
#
# Epoch 00037: val_loss improved from 1.18090 to 1.12352, saving model to ./save/cnn_gru_best.hdf5
# Epoch 38/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 1.0439 - accuracy: 0.9154 - val_loss: 1.0867 - val_accuracy: 0.7930
#
# Epoch 00038: val_loss improved from 1.12352 to 1.08673, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 1.0391 - accuracy: 0.9067 - val_loss: 1.0224 - val_accuracy: 0.8008
#
# Epoch 00039: val_loss improved from 1.08673 to 1.02244, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 1.0609 - accuracy: 0.9099 - val_loss: 1.1479 - val_accuracy: 0.7695
#
# Epoch 00040: val_loss did not improve from 1.02244
# Epoch 41/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.0458 - accuracy: 0.9127 - val_loss: 1.1810 - val_accuracy: 0.7695
#
# Epoch 00041: val_loss did not improve from 1.02244
# Epoch 42/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.0930 - accuracy: 0.8998 - val_loss: 1.1303 - val_accuracy: 0.7656
#
# Epoch 00042: val_loss did not improve from 1.02244
# Epoch 43/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 1.0820 - accuracy: 0.9017 - val_loss: 1.1446 - val_accuracy: 0.7422
#
# Epoch 00043: val_loss did not improve from 1.02244
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 44/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.8400 - accuracy: 0.9347 - val_loss: 1.1136 - val_accuracy: 0.7539
#
# Epoch 00044: val_loss did not improve from 1.02244
# Epoch 45/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.9323 - accuracy: 0.9228 - val_loss: 1.1048 - val_accuracy: 0.7578
#
# Epoch 00045: val_loss did not improve from 1.02244
# Epoch 46/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7516 - accuracy: 0.9412 - val_loss: 0.9991 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss improved from 1.02244 to 0.99913, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 0.8725 - accuracy: 0.9260 - val_loss: 1.0428 - val_accuracy: 0.7461
#
# Epoch 00047: val_loss did not improve from 0.99913
# Epoch 48/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.7909 - accuracy: 0.9366 - val_loss: 0.9405 - val_accuracy: 0.7969
#
# Epoch 00048: val_loss improved from 0.99913 to 0.94053, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.9829 - accuracy: 0.9113 - val_loss: 1.0483 - val_accuracy: 0.7734
#
# Epoch 00049: val_loss did not improve from 0.94053
# Epoch 50/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.9179 - accuracy: 0.9246 - val_loss: 1.0193 - val_accuracy: 0.7812
#
# Epoch 00050: val_loss did not improve from 0.94053
# Epoch 51/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.7987 - accuracy: 0.9320 - val_loss: 0.9356 - val_accuracy: 0.7852
#
# Epoch 00051: val_loss improved from 0.94053 to 0.93560, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.7827 - accuracy: 0.9439 - val_loss: 0.9749 - val_accuracy: 0.7852
#
# Epoch 00052: val_loss did not improve from 0.93560
# Epoch 53/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.8030 - accuracy: 0.9347 - val_loss: 1.0289 - val_accuracy: 0.7695
#
# Epoch 00053: val_loss did not improve from 0.93560
# Epoch 54/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.8720 - accuracy: 0.9260 - val_loss: 1.0095 - val_accuracy: 0.7891
#
# Epoch 00054: val_loss did not improve from 0.93560
# Epoch 55/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.8468 - accuracy: 0.9246 - val_loss: 0.9991 - val_accuracy: 0.7656
#
# Epoch 00055: val_loss did not improve from 0.93560
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 56/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.7647 - accuracy: 0.9393 - val_loss: 0.9421 - val_accuracy: 0.7930
#
# Epoch 00056: val_loss did not improve from 0.93560
# Epoch 57/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6953 - accuracy: 0.9513 - val_loss: 0.9953 - val_accuracy: 0.7930
#
# Epoch 00057: val_loss did not improve from 0.93560
# Epoch 58/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.8145 - accuracy: 0.9343 - val_loss: 0.9091 - val_accuracy: 0.7969
#
# Epoch 00058: val_loss improved from 0.93560 to 0.90913, saving model to ./save/cnn_gru_best.hdf5
# Epoch 59/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 0.6962 - accuracy: 0.9444 - val_loss: 0.9198 - val_accuracy: 0.8008
#
# Epoch 00059: val_loss did not improve from 0.90913
# Epoch 60/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.7510 - accuracy: 0.9393 - val_loss: 0.9597 - val_accuracy: 0.7930
#
# Epoch 00060: val_loss did not improve from 0.90913
# Epoch 61/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.7522 - accuracy: 0.9393 - val_loss: 0.9676 - val_accuracy: 0.7852
#
# Epoch 00061: val_loss did not improve from 0.90913
# Epoch 62/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.7378 - accuracy: 0.9403 - val_loss: 0.9792 - val_accuracy: 0.7930
#
# Epoch 00062: val_loss did not improve from 0.90913
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 63/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.6616 - accuracy: 0.9522 - val_loss: 0.9923 - val_accuracy: 0.7891
#
# Epoch 00063: val_loss did not improve from 0.90913
# Epoch 64/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.6719 - accuracy: 0.9517 - val_loss: 0.9401 - val_accuracy: 0.8086
#
# Epoch 00064: val_loss did not improve from 0.90913
# Epoch 65/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6125 - accuracy: 0.9531 - val_loss: 0.9627 - val_accuracy: 0.7930
#
# Epoch 00065: val_loss did not improve from 0.90913
# Epoch 66/2000
# 34/34 [==============================] - 7s 194ms/step - loss: 0.6365 - accuracy: 0.9540 - val_loss: 0.9777 - val_accuracy: 0.7852
#
# Epoch 00066: val_loss did not improve from 0.90913
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 67/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.5774 - accuracy: 0.9614 - val_loss: 0.9158 - val_accuracy: 0.8008
#
# Epoch 00067: val_loss did not improve from 0.90913
# Epoch 68/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.5954 - accuracy: 0.9596 - val_loss: 0.9507 - val_accuracy: 0.8086
#
# Epoch 00068: val_loss did not improve from 0.90913
# Epoch 69/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 0.6172 - accuracy: 0.9522 - val_loss: 0.9347 - val_accuracy: 0.8047
#
# Epoch 00069: val_loss did not improve from 0.90913
# Epoch 70/2000
# 34/34 [==============================] - 7s 190ms/step - loss: 0.6494 - accuracy: 0.9462 - val_loss: 0.9611 - val_accuracy: 0.7852
#
# Epoch 00070: val_loss did not improve from 0.90913
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 71/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.6004 - accuracy: 0.9540 - val_loss: 0.9489 - val_accuracy: 0.7891
#
# Epoch 00071: val_loss did not improve from 0.90913
# Epoch 72/2000
# 34/34 [==============================] - 7s 193ms/step - loss: 0.6035 - accuracy: 0.9527 - val_loss: 0.9784 - val_accuracy: 0.7773
#
# Epoch 00072: val_loss did not improve from 0.90913
# Epoch 73/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6545 - accuracy: 0.9540 - val_loss: 0.9689 - val_accuracy: 0.7891
#
# Epoch 00073: val_loss did not improve from 0.90913
# Epoch 74/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.6245 - accuracy: 0.9527 - val_loss: 0.9818 - val_accuracy: 0.7812
#
# Epoch 00074: val_loss did not improve from 0.90913
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 75/2000
# 34/34 [==============================] - 7s 189ms/step - loss: 0.5477 - accuracy: 0.9665 - val_loss: 0.9127 - val_accuracy: 0.8047
#
# Epoch 00075: val_loss did not improve from 0.90913
# Epoch 76/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.5895 - accuracy: 0.9563 - val_loss: 0.9315 - val_accuracy: 0.7969
#
# Epoch 00076: val_loss did not improve from 0.90913
# Epoch 77/2000
# 34/34 [==============================] - 7s 191ms/step - loss: 0.5668 - accuracy: 0.9637 - val_loss: 0.9530 - val_accuracy: 0.8008
#
# Epoch 00077: val_loss did not improve from 0.90913
# Epoch 78/2000
# 34/34 [==============================] - 7s 192ms/step - loss: 0.5703 - accuracy: 0.9582 - val_loss: 0.9411 - val_accuracy: 0.8008
#
# Epoch 00078: val_loss did not improve from 0.90913
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 00078: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 1s 996ms/step - loss: 0.7500 - accuracy: 0.8416
# [0.7499587535858154, 0.8416000008583069]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
