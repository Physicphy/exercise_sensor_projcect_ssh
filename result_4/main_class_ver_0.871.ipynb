# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset#, class_weight_dict
from my_model_class import CNN_RNN_Resnet

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = CNN_RNN_Resnet(
    leakyrelu_alpha = 0.1, #-0.2, #-0.1#, #0.05#, #0.1#, 0.2
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    input_regularize_coeff=0.001,
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.1, # #0.01#, #0.02#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )(lr = 0.001,seed=42)

model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 600, 8)       0           input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 300, 20)      1460        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 300, 20)      2900        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 300, 10)      1810        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 300, 10)      1810        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          conv1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 300, 20)      80          conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 300, 20)      80          conv1d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 300, 20)      80          conv1d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          conv1d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 300, 20)      80          conv1d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 300, 10)      40          conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 300, 10)      40          conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 300, 10)      40          conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 300, 10)      0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 300, 10)      0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 300, 10)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# gru_18 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# gru_24 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# gru_27 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 300, 20)      1920        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 300, 20)      1920        leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# gru_15 (GRU)                    (None, 300, 20)      1920        leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         gru[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         gru_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 300, 40)      160         gru_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 300, 40)      160         gru_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 300, 40)      160         gru_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         gru_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 300, 40)      160         gru_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 300, 20)      80          gru_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 300, 20)      80          gru_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 300, 20)      80          gru_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 300, 20)      0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     43320       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     43320       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 150, 60)      21660       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         conv1d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 120)     480         conv1d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 120)     480         conv1d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 120)     480         conv1d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 150, 60)      240         conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 150, 60)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# gru_19 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# gru_22 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# gru_25 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# gru_28 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 150, 60)      21960       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 150, 60)      21960       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 150, 60)      21960       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         gru_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         gru_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         gru_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         gru_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 120)     480         gru_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         gru_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 120)     480         gru_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 150, 60)      240         gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 60)      240         gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 150, 60)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 75, 120)      129720      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 75, 120)      129720      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 75, 60)       64860       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 75, 60)       64860       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 75, 60)       64860       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 120)      480         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 120)      480         conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 75, 120)      480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 75, 120)      480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 75, 120)      480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 75, 120)      480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 75, 120)      480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 75, 60)       240         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 75, 60)       240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 75, 60)       240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 75, 120)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 75, 120)      87120       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 75, 120)      87120       leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# gru_23 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# gru_26 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# gru_14 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# gru_29 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 75, 60)       21960       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 75, 60)       21960       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 75, 60)       21960       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 75, 120)      480         gru_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 75, 120)      480         gru_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 75, 120)      480         gru_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 75, 120)      480         gru_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 75, 120)      480         gru_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 75, 120)      480         gru_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 75, 120)      480         gru_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 75, 60)       240         gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 75, 60)       240         gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 75, 60)       240         gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 75, 120)      0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 75, 1020)     0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
#                                                                  leaky_re_lu_47[0][0]
#                                                                  leaky_re_lu_53[0][0]
#                                                                  leaky_re_lu_29[0][0]
#                                                                  leaky_re_lu_59[0][0]
#                                                                  leaky_re_lu_11[0][0]
#                                                                  leaky_re_lu_23[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 75, 60)       550860      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 75, 60)       240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 75, 120)      480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 75, 60)       240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 75, 60)       1101660     concatenate_10[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 75, 60)       0           leaky_re_lu_62[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 75, 60)       240         add[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 75, 60)       32460       batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 75, 60)       240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 75, 120)      480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 75, 60)       240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 75, 60)       0           leaky_re_lu_65[0][0]
#                                                                  batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 75, 60)       240         add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 75, 60)       32460       batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 75, 60)       240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 75, 120)      480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 75, 60)       240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 75, 60)       0           leaky_re_lu_68[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 75, 60)       240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 4,841,391
# Trainable params: 4,830,411
# Non-trainable params: 10,980
# __________________________________________________________________________________________________

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 4,verbose = 1,factor = 0.5) 

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=0))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 75s 731ms/step - loss: 117.3743 - accuracy: 0.4453 - val_loss: 74.2799 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 74.27991, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 52.0835 - accuracy: 0.5717 - val_loss: 36.5608 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 74.27991 to 36.56078, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 25.8657 - accuracy: 0.6121 - val_loss: 20.2812 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 36.56078 to 20.28118, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 14.8500 - accuracy: 0.6310 - val_loss: 13.4008 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 20.28118 to 13.40081, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 10.0854 - accuracy: 0.6264 - val_loss: 10.4307 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 13.40081 to 10.43071, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 7.7125 - accuracy: 0.6489 - val_loss: 9.0979 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 10.43071 to 9.09793, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 6.3795 - accuracy: 0.6590 - val_loss: 8.5573 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 9.09793 to 8.55732, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 5.5992 - accuracy: 0.6723 - val_loss: 7.8703 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss improved from 8.55732 to 7.87027, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 4.9615 - accuracy: 0.6852 - val_loss: 6.4317 - val_accuracy: 0.4531
#
# Epoch 00009: val_loss improved from 7.87027 to 6.43166, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 4.5831 - accuracy: 0.6631 - val_loss: 6.4954 - val_accuracy: 0.4453
#
# Epoch 00010: val_loss did not improve from 6.43166
# Epoch 11/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 4.1065 - accuracy: 0.6907 - val_loss: 7.2261 - val_accuracy: 0.4531
#
# Epoch 00011: val_loss did not improve from 6.43166
# Epoch 12/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 3.8813 - accuracy: 0.6664 - val_loss: 5.8939 - val_accuracy: 0.4609
#
# Epoch 00012: val_loss improved from 6.43166 to 5.89393, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 3.5338 - accuracy: 0.6962 - val_loss: 5.0900 - val_accuracy: 0.4727
#
# Epoch 00013: val_loss improved from 5.89393 to 5.09000, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 3.3007 - accuracy: 0.7045 - val_loss: 5.2422 - val_accuracy: 0.2188
#
# Epoch 00014: val_loss did not improve from 5.09000
# Epoch 15/2000
# 34/34 [==============================] - 15s 455ms/step - loss: 3.2357 - accuracy: 0.6967 - val_loss: 7.8895 - val_accuracy: 0.0273
#
# Epoch 00015: val_loss did not improve from 5.09000
# Epoch 16/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 2.9676 - accuracy: 0.7132 - val_loss: 4.3909 - val_accuracy: 0.5391
#
# Epoch 00016: val_loss improved from 5.09000 to 4.39086, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 2.8994 - accuracy: 0.7022 - val_loss: 4.5419 - val_accuracy: 0.1836
#
# Epoch 00017: val_loss did not improve from 4.39086
# Epoch 18/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 2.6559 - accuracy: 0.7284 - val_loss: 3.6496 - val_accuracy: 0.5234
#
# Epoch 00018: val_loss improved from 4.39086 to 3.64959, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 2.5461 - accuracy: 0.7376 - val_loss: 3.8568 - val_accuracy: 0.5273
#
# Epoch 00019: val_loss did not improve from 3.64959
# Epoch 20/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 2.5432 - accuracy: 0.7183 - val_loss: 3.6056 - val_accuracy: 0.5234
#
# Epoch 00020: val_loss improved from 3.64959 to 3.60557, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 2.3850 - accuracy: 0.7247 - val_loss: 4.9996 - val_accuracy: 0.1289
#
# Epoch 00021: val_loss did not improve from 3.60557
# Epoch 22/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 2.2901 - accuracy: 0.7403 - val_loss: 11.0654 - val_accuracy: 0.0742
#
# Epoch 00022: val_loss did not improve from 3.60557
# Epoch 23/2000
# 34/34 [==============================] - 15s 455ms/step - loss: 2.2129 - accuracy: 0.7528 - val_loss: 4.1417 - val_accuracy: 0.4453
#
# Epoch 00023: val_loss did not improve from 3.60557
# Epoch 24/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 2.1820 - accuracy: 0.7468 - val_loss: 7.7394 - val_accuracy: 0.0898
#
# Epoch 00024: val_loss did not improve from 3.60557
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 1.8607 - accuracy: 0.7872 - val_loss: 4.6218 - val_accuracy: 0.1250
#
# Epoch 00025: val_loss did not improve from 3.60557
# Epoch 26/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 1.7194 - accuracy: 0.7937 - val_loss: 6.1626 - val_accuracy: 0.1016
#
# Epoch 00026: val_loss did not improve from 3.60557
# Epoch 27/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 1.6458 - accuracy: 0.8074 - val_loss: 7.7290 - val_accuracy: 0.0938
#
# Epoch 00027: val_loss did not improve from 3.60557
# Epoch 28/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 1.6801 - accuracy: 0.7914 - val_loss: 4.6549 - val_accuracy: 0.1406
#
# Epoch 00028: val_loss did not improve from 3.60557
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 1.5251 - accuracy: 0.8171 - val_loss: 2.8466 - val_accuracy: 0.5312
#
# Epoch 00029: val_loss improved from 3.60557 to 2.84656, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 1.3788 - accuracy: 0.8364 - val_loss: 2.6962 - val_accuracy: 0.5430
#
# Epoch 00030: val_loss improved from 2.84656 to 2.69622, saving model to ./save/cnn_gru_best.hdf5
# Epoch 31/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 1.3530 - accuracy: 0.8327 - val_loss: 3.0097 - val_accuracy: 0.4531
#
# Epoch 00031: val_loss did not improve from 2.69622
# Epoch 32/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 1.3369 - accuracy: 0.8428 - val_loss: 2.4260 - val_accuracy: 0.5820
#
# Epoch 00032: val_loss improved from 2.69622 to 2.42604, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 1.3095 - accuracy: 0.8456 - val_loss: 3.0165 - val_accuracy: 0.5781
#
# Epoch 00033: val_loss did not improve from 2.42604
# Epoch 34/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 1.3056 - accuracy: 0.8424 - val_loss: 1.9797 - val_accuracy: 0.6797
#
# Epoch 00034: val_loss improved from 2.42604 to 1.97969, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 1.3482 - accuracy: 0.8355 - val_loss: 1.8797 - val_accuracy: 0.6797
#
# Epoch 00035: val_loss improved from 1.97969 to 1.87966, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 1.3246 - accuracy: 0.8387 - val_loss: 2.3751 - val_accuracy: 0.5781
#
# Epoch 00036: val_loss did not improve from 1.87966
# Epoch 37/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 1.2484 - accuracy: 0.8479 - val_loss: 2.4098 - val_accuracy: 0.6562
#
# Epoch 00037: val_loss did not improve from 1.87966
# Epoch 38/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 1.2435 - accuracy: 0.8506 - val_loss: 2.6016 - val_accuracy: 0.5898
#
# Epoch 00038: val_loss did not improve from 1.87966
# Epoch 39/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 1.2540 - accuracy: 0.8529 - val_loss: 3.2205 - val_accuracy: 0.4570
#
# Epoch 00039: val_loss did not improve from 1.87966
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 40/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 1.1471 - accuracy: 0.8736 - val_loss: 1.9740 - val_accuracy: 0.6562
#
# Epoch 00040: val_loss did not improve from 1.87966
# Epoch 41/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 1.0884 - accuracy: 0.8874 - val_loss: 1.8387 - val_accuracy: 0.7070
#
# Epoch 00041: val_loss improved from 1.87966 to 1.83869, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 1.1139 - accuracy: 0.8649 - val_loss: 2.2556 - val_accuracy: 0.6562
#
# Epoch 00042: val_loss did not improve from 1.83869
# Epoch 43/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 1.0875 - accuracy: 0.8755 - val_loss: 2.1321 - val_accuracy: 0.6836
#
# Epoch 00043: val_loss did not improve from 1.83869
# Epoch 44/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 1.0039 - accuracy: 0.8980 - val_loss: 1.7032 - val_accuracy: 0.7070
#
# Epoch 00044: val_loss improved from 1.83869 to 1.70316, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 1.0896 - accuracy: 0.8764 - val_loss: 1.6621 - val_accuracy: 0.7266
#
# Epoch 00045: val_loss improved from 1.70316 to 1.66206, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.9709 - accuracy: 0.9095 - val_loss: 1.9605 - val_accuracy: 0.6914
#
# Epoch 00046: val_loss did not improve from 1.66206
# Epoch 47/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 1.0326 - accuracy: 0.8869 - val_loss: 4.7836 - val_accuracy: 0.3906
#
# Epoch 00047: val_loss did not improve from 1.66206
# Epoch 48/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.9809 - accuracy: 0.9012 - val_loss: 2.6012 - val_accuracy: 0.6367
#
# Epoch 00048: val_loss did not improve from 1.66206
# Epoch 49/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 1.0739 - accuracy: 0.8676 - val_loss: 1.8491 - val_accuracy: 0.7070
#
# Epoch 00049: val_loss did not improve from 1.66206
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 50/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 1.0201 - accuracy: 0.8961 - val_loss: 1.5595 - val_accuracy: 0.7539
#
# Epoch 00050: val_loss improved from 1.66206 to 1.55953, saving model to ./save/cnn_gru_best.hdf5
# Epoch 51/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.9098 - accuracy: 0.9200 - val_loss: 1.4624 - val_accuracy: 0.7578
#
# Epoch 00051: val_loss improved from 1.55953 to 1.46242, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.9068 - accuracy: 0.9182 - val_loss: 1.3772 - val_accuracy: 0.7852
#
# Epoch 00052: val_loss improved from 1.46242 to 1.37716, saving model to ./save/cnn_gru_best.hdf5
# Epoch 53/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.8934 - accuracy: 0.9154 - val_loss: 1.4368 - val_accuracy: 0.7578
#
# Epoch 00053: val_loss did not improve from 1.37716
# Epoch 54/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.9208 - accuracy: 0.9090 - val_loss: 1.4600 - val_accuracy: 0.7734
#
# Epoch 00054: val_loss did not improve from 1.37716
# Epoch 55/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.8880 - accuracy: 0.9205 - val_loss: 1.4650 - val_accuracy: 0.7617
#
# Epoch 00055: val_loss did not improve from 1.37716
# Epoch 56/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.8981 - accuracy: 0.9090 - val_loss: 1.3825 - val_accuracy: 0.7852
#
# Epoch 00056: val_loss did not improve from 1.37716
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 57/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.8327 - accuracy: 0.9380 - val_loss: 1.2990 - val_accuracy: 0.7891
#
# Epoch 00057: val_loss improved from 1.37716 to 1.29904, saving model to ./save/cnn_gru_best.hdf5
# Epoch 58/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.8555 - accuracy: 0.9214 - val_loss: 1.3549 - val_accuracy: 0.7852
#
# Epoch 00058: val_loss did not improve from 1.29904
# Epoch 59/2000
# 34/34 [==============================] - 16s 467ms/step - loss: 0.8279 - accuracy: 0.9306 - val_loss: 1.4112 - val_accuracy: 0.7930
#
# Epoch 00059: val_loss did not improve from 1.29904
# Epoch 60/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.8421 - accuracy: 0.9274 - val_loss: 1.2835 - val_accuracy: 0.7852
#
# Epoch 00060: val_loss improved from 1.29904 to 1.28347, saving model to ./save/cnn_gru_best.hdf5
# Epoch 61/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 0.8467 - accuracy: 0.9196 - val_loss: 1.2965 - val_accuracy: 0.7812
#
# Epoch 00061: val_loss did not improve from 1.28347
# Epoch 62/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.8370 - accuracy: 0.9246 - val_loss: 1.3425 - val_accuracy: 0.7617
#
# Epoch 00062: val_loss did not improve from 1.28347
# Epoch 63/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.8066 - accuracy: 0.9352 - val_loss: 1.4236 - val_accuracy: 0.7773
#
# Epoch 00063: val_loss did not improve from 1.28347
# Epoch 64/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 0.8251 - accuracy: 0.9288 - val_loss: 1.2313 - val_accuracy: 0.8164
#
# Epoch 00064: val_loss improved from 1.28347 to 1.23128, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.7968 - accuracy: 0.9389 - val_loss: 1.3085 - val_accuracy: 0.7812
#
# Epoch 00065: val_loss did not improve from 1.23128
# Epoch 66/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.8141 - accuracy: 0.9274 - val_loss: 1.2788 - val_accuracy: 0.7969
#
# Epoch 00066: val_loss did not improve from 1.23128
# Epoch 67/2000
# 34/34 [==============================] - 15s 455ms/step - loss: 0.7761 - accuracy: 0.9439 - val_loss: 1.1909 - val_accuracy: 0.8320
#
# Epoch 00067: val_loss improved from 1.23128 to 1.19095, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.7753 - accuracy: 0.9412 - val_loss: 1.1898 - val_accuracy: 0.8359
#
# Epoch 00068: val_loss improved from 1.19095 to 1.18983, saving model to ./save/cnn_gru_best.hdf5
# Epoch 69/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.7872 - accuracy: 0.9334 - val_loss: 1.2559 - val_accuracy: 0.8086
#
# Epoch 00069: val_loss did not improve from 1.18983
# Epoch 70/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.8077 - accuracy: 0.9242 - val_loss: 1.2724 - val_accuracy: 0.8008
#
# Epoch 00070: val_loss did not improve from 1.18983
# Epoch 71/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.7975 - accuracy: 0.9320 - val_loss: 1.2262 - val_accuracy: 0.8125
#
# Epoch 00071: val_loss did not improve from 1.18983
# Epoch 72/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.7925 - accuracy: 0.9338 - val_loss: 1.2058 - val_accuracy: 0.8398
#
# Epoch 00072: val_loss did not improve from 1.18983
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 73/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 0.7827 - accuracy: 0.9334 - val_loss: 1.1747 - val_accuracy: 0.8398
#
# Epoch 00073: val_loss improved from 1.18983 to 1.17470, saving model to ./save/cnn_gru_best.hdf5
# Epoch 74/2000
# 34/34 [==============================] - 16s 455ms/step - loss: 0.7636 - accuracy: 0.9412 - val_loss: 1.2002 - val_accuracy: 0.8281
#
# Epoch 00074: val_loss did not improve from 1.17470
# Epoch 75/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.7218 - accuracy: 0.9582 - val_loss: 1.1555 - val_accuracy: 0.8281
#
# Epoch 00075: val_loss improved from 1.17470 to 1.15555, saving model to ./save/cnn_gru_best.hdf5
# Epoch 76/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 0.7391 - accuracy: 0.9504 - val_loss: 1.1877 - val_accuracy: 0.8164
#
# Epoch 00076: val_loss did not improve from 1.15555
# Epoch 77/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.7211 - accuracy: 0.9554 - val_loss: 1.2463 - val_accuracy: 0.8125
#
# Epoch 00077: val_loss did not improve from 1.15555
# Epoch 78/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.7243 - accuracy: 0.9522 - val_loss: 1.1421 - val_accuracy: 0.8398
#
# Epoch 00078: val_loss improved from 1.15555 to 1.14207, saving model to ./save/cnn_gru_best.hdf5
# Epoch 79/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.7883 - accuracy: 0.9311 - val_loss: 1.1957 - val_accuracy: 0.8164
#
# Epoch 00079: val_loss did not improve from 1.14207
# Epoch 80/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.7437 - accuracy: 0.9421 - val_loss: 1.1870 - val_accuracy: 0.8242
#
# Epoch 00080: val_loss did not improve from 1.14207
# Epoch 81/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.7447 - accuracy: 0.9430 - val_loss: 1.1686 - val_accuracy: 0.8164
#
# Epoch 00081: val_loss did not improve from 1.14207
# Epoch 82/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.7230 - accuracy: 0.9508 - val_loss: 1.1531 - val_accuracy: 0.8398
#
# Epoch 00082: val_loss did not improve from 1.14207
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 83/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.6838 - accuracy: 0.9678 - val_loss: 1.1935 - val_accuracy: 0.8320
#
# Epoch 00083: val_loss did not improve from 1.14207
# Epoch 84/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.6958 - accuracy: 0.9591 - val_loss: 1.1752 - val_accuracy: 0.8594
#
# Epoch 00084: val_loss did not improve from 1.14207
# Epoch 85/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 0.6810 - accuracy: 0.9688 - val_loss: 1.1624 - val_accuracy: 0.8477
#
# Epoch 00085: val_loss did not improve from 1.14207
# Epoch 86/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.6710 - accuracy: 0.9715 - val_loss: 1.1682 - val_accuracy: 0.8438
#
# Epoch 00086: val_loss did not improve from 1.14207
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 87/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.7256 - accuracy: 0.9559 - val_loss: 1.1662 - val_accuracy: 0.8438
#
# Epoch 00087: val_loss did not improve from 1.14207
# Epoch 88/2000
# 34/34 [==============================] - 16s 469ms/step - loss: 0.7047 - accuracy: 0.9540 - val_loss: 1.1788 - val_accuracy: 0.8555
#
# Epoch 00088: val_loss did not improve from 1.14207
# Epoch 89/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.6932 - accuracy: 0.9619 - val_loss: 1.1573 - val_accuracy: 0.8555
#
# Epoch 00089: val_loss did not improve from 1.14207
# Epoch 90/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.6928 - accuracy: 0.9623 - val_loss: 1.1679 - val_accuracy: 0.8555
#
# Epoch 00090: val_loss did not improve from 1.14207
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 91/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.6942 - accuracy: 0.9605 - val_loss: 1.1598 - val_accuracy: 0.8555
#
# Epoch 00091: val_loss did not improve from 1.14207
# Epoch 92/2000
# 34/34 [==============================] - 16s 468ms/step - loss: 0.6734 - accuracy: 0.9715 - val_loss: 1.1574 - val_accuracy: 0.8516
#
# Epoch 00092: val_loss did not improve from 1.14207
# Epoch 93/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.7071 - accuracy: 0.9600 - val_loss: 1.1396 - val_accuracy: 0.8594
#
# Epoch 00093: val_loss improved from 1.14207 to 1.13961, saving model to ./save/cnn_gru_best.hdf5
# Epoch 94/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.6683 - accuracy: 0.9678 - val_loss: 1.1817 - val_accuracy: 0.8516
#
# Epoch 00094: val_loss did not improve from 1.13961
# Epoch 95/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.6825 - accuracy: 0.9642 - val_loss: 1.1678 - val_accuracy: 0.8516
#
# Epoch 00095: val_loss did not improve from 1.13961
# Epoch 96/2000
# 34/34 [==============================] - 16s 470ms/step - loss: 0.6959 - accuracy: 0.9559 - val_loss: 1.1627 - val_accuracy: 0.8477
#
# Epoch 00096: val_loss did not improve from 1.13961
# Epoch 97/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.7075 - accuracy: 0.9586 - val_loss: 1.1873 - val_accuracy: 0.8438
#
# Epoch 00097: val_loss did not improve from 1.13961
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 98/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.6758 - accuracy: 0.9651 - val_loss: 1.1575 - val_accuracy: 0.8594
#
# Epoch 00098: val_loss did not improve from 1.13961
# Epoch 99/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 0.6969 - accuracy: 0.9609 - val_loss: 1.1428 - val_accuracy: 0.8555
#
# Epoch 00099: val_loss did not improve from 1.13961
# Epoch 100/2000
# 34/34 [==============================] - 16s 465ms/step - loss: 0.6593 - accuracy: 0.9743 - val_loss: 1.1269 - val_accuracy: 0.8633
#
# Epoch 00100: val_loss improved from 1.13961 to 1.12686, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.6783 - accuracy: 0.9614 - val_loss: 1.1893 - val_accuracy: 0.8516
#
# Epoch 00101: val_loss did not improve from 1.12686
# Epoch 102/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.6800 - accuracy: 0.9623 - val_loss: 1.1606 - val_accuracy: 0.8594
#
# Epoch 00102: val_loss did not improve from 1.12686
# Epoch 103/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.6955 - accuracy: 0.9600 - val_loss: 1.1541 - val_accuracy: 0.8555
#
# Epoch 00103: val_loss did not improve from 1.12686
# Epoch 104/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.6611 - accuracy: 0.9715 - val_loss: 1.1528 - val_accuracy: 0.8477
#
# Epoch 00104: val_loss did not improve from 1.12686
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 105/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.6848 - accuracy: 0.9609 - val_loss: 1.1486 - val_accuracy: 0.8477
#
# Epoch 00105: val_loss did not improve from 1.12686
# Epoch 106/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.6766 - accuracy: 0.9655 - val_loss: 1.1076 - val_accuracy: 0.8555
#
# Epoch 00106: val_loss improved from 1.12686 to 1.10762, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.6664 - accuracy: 0.9697 - val_loss: 1.1060 - val_accuracy: 0.8555
#
# Epoch 00107: val_loss improved from 1.10762 to 1.10604, saving model to ./save/cnn_gru_best.hdf5
# Epoch 108/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.6825 - accuracy: 0.9642 - val_loss: 1.1109 - val_accuracy: 0.8555
#
# Epoch 00108: val_loss did not improve from 1.10604
# Epoch 109/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.6867 - accuracy: 0.9609 - val_loss: 1.1086 - val_accuracy: 0.8477
#
# Epoch 00109: val_loss did not improve from 1.10604
# Epoch 110/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.6674 - accuracy: 0.9674 - val_loss: 1.1474 - val_accuracy: 0.8516
#
# Epoch 00110: val_loss did not improve from 1.10604
# Epoch 111/2000
# 34/34 [==============================] - 16s 472ms/step - loss: 0.7045 - accuracy: 0.9559 - val_loss: 1.1582 - val_accuracy: 0.8555
#
# Epoch 00111: val_loss did not improve from 1.10604
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 112/2000
# 34/34 [==============================] - 16s 459ms/step - loss: 0.6698 - accuracy: 0.9715 - val_loss: 1.1780 - val_accuracy: 0.8516
#
# Epoch 00112: val_loss did not improve from 1.10604
# Epoch 113/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 0.6887 - accuracy: 0.9596 - val_loss: 1.1498 - val_accuracy: 0.8477
#
# Epoch 00113: val_loss did not improve from 1.10604
# Epoch 114/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 0.6814 - accuracy: 0.9614 - val_loss: 1.1509 - val_accuracy: 0.8594
#
# Epoch 00114: val_loss did not improve from 1.10604
# Epoch 115/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.6671 - accuracy: 0.9697 - val_loss: 1.1577 - val_accuracy: 0.8516
#
# Epoch 00115: val_loss did not improve from 1.10604
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 116/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.6789 - accuracy: 0.9651 - val_loss: 1.1437 - val_accuracy: 0.8438
#
# Epoch 00116: val_loss did not improve from 1.10604
# Epoch 117/2000
# 34/34 [==============================] - 16s 462ms/step - loss: 0.6875 - accuracy: 0.9600 - val_loss: 1.1494 - val_accuracy: 0.8477
#
# Epoch 00117: val_loss did not improve from 1.10604
# Epoch 118/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.6645 - accuracy: 0.9710 - val_loss: 1.1621 - val_accuracy: 0.8477
#
# Epoch 00118: val_loss did not improve from 1.10604
# Epoch 119/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.6791 - accuracy: 0.9651 - val_loss: 1.1830 - val_accuracy: 0.8477
#
# Epoch 00119: val_loss did not improve from 1.10604
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 120/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.6927 - accuracy: 0.9563 - val_loss: 1.1989 - val_accuracy: 0.8438
#
# Epoch 00120: val_loss did not improve from 1.10604
# Epoch 121/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.6954 - accuracy: 0.9600 - val_loss: 1.1844 - val_accuracy: 0.8438
#
# Epoch 00121: val_loss did not improve from 1.10604
# Epoch 122/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.6589 - accuracy: 0.9715 - val_loss: 1.1501 - val_accuracy: 0.8633
#
# Epoch 00122: val_loss did not improve from 1.10604
# Epoch 123/2000
# 34/34 [==============================] - 16s 466ms/step - loss: 0.6781 - accuracy: 0.9678 - val_loss: 1.1647 - val_accuracy: 0.8594
#
# Epoch 00123: val_loss did not improve from 1.10604
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 124/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.6885 - accuracy: 0.9591 - val_loss: 1.1759 - val_accuracy: 0.8516
#
# Epoch 00124: val_loss did not improve from 1.10604
# Epoch 125/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.6766 - accuracy: 0.9623 - val_loss: 1.1925 - val_accuracy: 0.8477
#
# Epoch 00125: val_loss did not improve from 1.10604
# Epoch 126/2000
# 34/34 [==============================] - 16s 455ms/step - loss: 0.6668 - accuracy: 0.9674 - val_loss: 1.1814 - val_accuracy: 0.8477
#
# Epoch 00126: val_loss did not improve from 1.10604
# Epoch 127/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.7082 - accuracy: 0.9554 - val_loss: 1.1749 - val_accuracy: 0.8516
#
# Epoch 00127: val_loss did not improve from 1.10604
#
# Epoch 00127: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 128/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.6590 - accuracy: 0.9710 - val_loss: 1.1220 - val_accuracy: 0.8633
#
# Epoch 00128: val_loss did not improve from 1.10604
# Epoch 129/2000
# 34/34 [==============================] - 16s 460ms/step - loss: 0.6835 - accuracy: 0.9655 - val_loss: 1.1924 - val_accuracy: 0.8477
#
# Epoch 00129: val_loss did not improve from 1.10604
# Epoch 130/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.6551 - accuracy: 0.9766 - val_loss: 1.1887 - val_accuracy: 0.8398
#
# Epoch 00130: val_loss did not improve from 1.10604
# Epoch 131/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.6700 - accuracy: 0.9669 - val_loss: 1.1807 - val_accuracy: 0.8477
#
# Epoch 00131: val_loss did not improve from 1.10604
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 132/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 0.6762 - accuracy: 0.9697 - val_loss: 1.1673 - val_accuracy: 0.8477
#
# Epoch 00132: val_loss did not improve from 1.10604
# Epoch 133/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.6848 - accuracy: 0.9619 - val_loss: 1.1821 - val_accuracy: 0.8438
#
# Epoch 00133: val_loss did not improve from 1.10604
# Epoch 134/2000
# 34/34 [==============================] - 16s 464ms/step - loss: 0.6888 - accuracy: 0.9614 - val_loss: 1.1602 - val_accuracy: 0.8477
#
# Epoch 00134: val_loss did not improve from 1.10604
# Epoch 135/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.6813 - accuracy: 0.9655 - val_loss: 1.1601 - val_accuracy: 0.8477
#
# Epoch 00135: val_loss did not improve from 1.10604
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 136/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.6782 - accuracy: 0.9674 - val_loss: 1.1643 - val_accuracy: 0.8477
#
# Epoch 00136: val_loss did not improve from 1.10604
# Epoch 137/2000
# 34/34 [==============================] - 16s 463ms/step - loss: 0.7000 - accuracy: 0.9577 - val_loss: 1.1521 - val_accuracy: 0.8594
#
# Epoch 00137: val_loss did not improve from 1.10604
# Epoch 00137: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 1.0101 - accuracy: 0.8720
# [1.0101068019866943, 0.871999979019165]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
