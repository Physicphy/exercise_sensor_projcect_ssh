# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset#, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = -0.2, # #-0.1#, #0.05#, #0.1#, 0.2
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 8)       0           input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 300, 20)      1460        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      2900        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 300, 20)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 300, 20)      80          leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_18 (GRU)                    (None, 300, 40)      7440        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 300, 40)      0           gru_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 300, 40)      160         leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     14520       batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_19 (GRU)                    (None, 150, 120)     87120       batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           gru_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 150, 1140)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_39[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      615660      concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      615660      concatenate_11[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_49[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_52[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,513,111
# Trainable params: 2,505,851
# Non-trainable params: 7,260
# __________________________________________________________________________________________________

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=0))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 56s 535ms/step - loss: 14.8338 - accuracy: 0.4632 - val_loss: 11.5903 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 11.59029, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 8.2131 - accuracy: 0.6039 - val_loss: 7.6104 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 11.59029 to 7.61045, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 4.7924 - accuracy: 0.6926 - val_loss: 5.5535 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 7.61045 to 5.55355, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 3.1852 - accuracy: 0.6967 - val_loss: 4.7550 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 5.55355 to 4.75502, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 2.3101 - accuracy: 0.7114 - val_loss: 4.3702 - val_accuracy: 0.4531
#
# Epoch 00005: val_loss improved from 4.75502 to 4.37019, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 1.8101 - accuracy: 0.7238 - val_loss: 5.0037 - val_accuracy: 0.0234
#
# Epoch 00006: val_loss did not improve from 4.37019
# Epoch 7/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 1.4523 - accuracy: 0.7403 - val_loss: 8.2289 - val_accuracy: 0.0117
#
# Epoch 00007: val_loss did not improve from 4.37019
# Epoch 8/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 1.2303 - accuracy: 0.7771 - val_loss: 5.4683 - val_accuracy: 0.0352
#
# Epoch 00008: val_loss did not improve from 4.37019
# Epoch 9/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 1.0893 - accuracy: 0.7996 - val_loss: 5.8016 - val_accuracy: 0.0234
#
# Epoch 00009: val_loss did not improve from 4.37019
# Epoch 10/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 1.1499 - accuracy: 0.7688 - val_loss: 8.1432 - val_accuracy: 0.0273
#
# Epoch 00010: val_loss did not improve from 4.37019
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 1.0349 - accuracy: 0.7992 - val_loss: 7.4680 - val_accuracy: 0.0312
#
# Epoch 00011: val_loss did not improve from 4.37019
# Epoch 12/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.9116 - accuracy: 0.8139 - val_loss: 6.5626 - val_accuracy: 0.0508
#
# Epoch 00012: val_loss did not improve from 4.37019
# Epoch 13/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.7907 - accuracy: 0.8502 - val_loss: 5.8656 - val_accuracy: 0.0586
#
# Epoch 00013: val_loss did not improve from 4.37019
# Epoch 14/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.7527 - accuracy: 0.8355 - val_loss: 4.5236 - val_accuracy: 0.2148
#
# Epoch 00014: val_loss did not improve from 4.37019
# Epoch 15/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.7941 - accuracy: 0.8272 - val_loss: 4.6252 - val_accuracy: 0.1641
#
# Epoch 00015: val_loss did not improve from 4.37019
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.7444 - accuracy: 0.8456 - val_loss: 3.1133 - val_accuracy: 0.4688
#
# Epoch 00016: val_loss improved from 4.37019 to 3.11334, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.7122 - accuracy: 0.8534 - val_loss: 2.4456 - val_accuracy: 0.5195
#
# Epoch 00017: val_loss improved from 3.11334 to 2.44558, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 13s 389ms/step - loss: 0.5918 - accuracy: 0.8842 - val_loss: 1.5893 - val_accuracy: 0.6289
#
# Epoch 00018: val_loss improved from 2.44558 to 1.58925, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.5359 - accuracy: 0.9076 - val_loss: 2.0279 - val_accuracy: 0.5977
#
# Epoch 00019: val_loss did not improve from 1.58925
# Epoch 20/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.6921 - accuracy: 0.8451 - val_loss: 1.5415 - val_accuracy: 0.6875
#
# Epoch 00020: val_loss improved from 1.58925 to 1.54154, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.6163 - accuracy: 0.8640 - val_loss: 1.2489 - val_accuracy: 0.7305
#
# Epoch 00021: val_loss improved from 1.54154 to 1.24886, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.5729 - accuracy: 0.8833 - val_loss: 1.1318 - val_accuracy: 0.7578
#
# Epoch 00022: val_loss improved from 1.24886 to 1.13177, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.5861 - accuracy: 0.8782 - val_loss: 1.1123 - val_accuracy: 0.7695
#
# Epoch 00023: val_loss improved from 1.13177 to 1.11231, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 14s 401ms/step - loss: 0.5597 - accuracy: 0.8791 - val_loss: 1.0417 - val_accuracy: 0.7500
#
# Epoch 00024: val_loss improved from 1.11231 to 1.04167, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 14s 423ms/step - loss: 0.5099 - accuracy: 0.8971 - val_loss: 1.0122 - val_accuracy: 0.7500
#
# Epoch 00025: val_loss improved from 1.04167 to 1.01221, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.5059 - accuracy: 0.8984 - val_loss: 0.8483 - val_accuracy: 0.8164
#
# Epoch 00026: val_loss improved from 1.01221 to 0.84829, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 13s 372ms/step - loss: 0.5309 - accuracy: 0.9007 - val_loss: 0.9000 - val_accuracy: 0.7812
#
# Epoch 00027: val_loss did not improve from 0.84829
# Epoch 28/2000
# 34/34 [==============================] - 13s 388ms/step - loss: 0.5934 - accuracy: 0.8755 - val_loss: 0.8260 - val_accuracy: 0.8125
#
# Epoch 00028: val_loss improved from 0.84829 to 0.82600, saving model to ./save/cnn_gru_best.hdf5
# Epoch 29/2000
# 34/34 [==============================] - 14s 399ms/step - loss: 0.5672 - accuracy: 0.8810 - val_loss: 1.2508 - val_accuracy: 0.7344
#
# Epoch 00029: val_loss did not improve from 0.82600
# Epoch 30/2000
# 34/34 [==============================] - 14s 405ms/step - loss: 0.4945 - accuracy: 0.9007 - val_loss: 0.9167 - val_accuracy: 0.7852
#
# Epoch 00030: val_loss did not improve from 0.82600
# Epoch 31/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.4904 - accuracy: 0.9017 - val_loss: 0.9194 - val_accuracy: 0.7969
#
# Epoch 00031: val_loss did not improve from 0.82600
# Epoch 32/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.4802 - accuracy: 0.9035 - val_loss: 0.9211 - val_accuracy: 0.7695
#
# Epoch 00032: val_loss did not improve from 0.82600
# Epoch 33/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.4971 - accuracy: 0.8938 - val_loss: 0.9786 - val_accuracy: 0.7930
#
# Epoch 00033: val_loss did not improve from 0.82600
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 34/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.4395 - accuracy: 0.9177 - val_loss: 0.7973 - val_accuracy: 0.8242
#
# Epoch 00034: val_loss improved from 0.82600 to 0.79729, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.4468 - accuracy: 0.9095 - val_loss: 0.7754 - val_accuracy: 0.8086
#
# Epoch 00035: val_loss improved from 0.79729 to 0.77544, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 13s 374ms/step - loss: 0.4375 - accuracy: 0.9108 - val_loss: 0.8109 - val_accuracy: 0.8047
#
# Epoch 00036: val_loss did not improve from 0.77544
# Epoch 37/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.4110 - accuracy: 0.9164 - val_loss: 0.8238 - val_accuracy: 0.7969
#
# Epoch 00037: val_loss did not improve from 0.77544
# Epoch 38/2000
# 34/34 [==============================] - 13s 396ms/step - loss: 0.3557 - accuracy: 0.9393 - val_loss: 0.7944 - val_accuracy: 0.8242
#
# Epoch 00038: val_loss did not improve from 0.77544
# Epoch 39/2000
# 34/34 [==============================] - 13s 384ms/step - loss: 0.3909 - accuracy: 0.9228 - val_loss: 0.7591 - val_accuracy: 0.8203
#
# Epoch 00039: val_loss improved from 0.77544 to 0.75905, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 13s 379ms/step - loss: 0.3804 - accuracy: 0.9278 - val_loss: 0.8050 - val_accuracy: 0.8086
#
# Epoch 00040: val_loss did not improve from 0.75905
# Epoch 41/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.3832 - accuracy: 0.9269 - val_loss: 0.8138 - val_accuracy: 0.8008
#
# Epoch 00041: val_loss did not improve from 0.75905
# Epoch 42/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.4161 - accuracy: 0.9104 - val_loss: 0.7801 - val_accuracy: 0.8281
#
# Epoch 00042: val_loss did not improve from 0.75905
# Epoch 43/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.3893 - accuracy: 0.9182 - val_loss: 0.8465 - val_accuracy: 0.7969
#
# Epoch 00043: val_loss did not improve from 0.75905
# Epoch 44/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2860 - accuracy: 0.9550 - val_loss: 0.7910 - val_accuracy: 0.8008
#
# Epoch 00044: val_loss did not improve from 0.75905
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 45/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.3752 - accuracy: 0.9251 - val_loss: 0.7253 - val_accuracy: 0.8359
#
# Epoch 00045: val_loss improved from 0.75905 to 0.72529, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2389 - accuracy: 0.9678 - val_loss: 0.6927 - val_accuracy: 0.8398
#
# Epoch 00046: val_loss improved from 0.72529 to 0.69270, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.3051 - accuracy: 0.9421 - val_loss: 0.7516 - val_accuracy: 0.8047
#
# Epoch 00047: val_loss did not improve from 0.69270
# Epoch 48/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2727 - accuracy: 0.9531 - val_loss: 0.7110 - val_accuracy: 0.8164
#
# Epoch 00048: val_loss did not improve from 0.69270
# Epoch 49/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.4178 - accuracy: 0.9118 - val_loss: 0.6985 - val_accuracy: 0.8242
#
# Epoch 00049: val_loss did not improve from 0.69270
# Epoch 50/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.3686 - accuracy: 0.9274 - val_loss: 0.7220 - val_accuracy: 0.8125
#
# Epoch 00050: val_loss did not improve from 0.69270
# Epoch 51/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2702 - accuracy: 0.9554 - val_loss: 0.6552 - val_accuracy: 0.8398
#
# Epoch 00051: val_loss improved from 0.69270 to 0.65523, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2872 - accuracy: 0.9545 - val_loss: 0.7143 - val_accuracy: 0.8281
#
# Epoch 00052: val_loss did not improve from 0.65523
# Epoch 53/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2754 - accuracy: 0.9494 - val_loss: 0.6997 - val_accuracy: 0.8164
#
# Epoch 00053: val_loss did not improve from 0.65523
# Epoch 54/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.3201 - accuracy: 0.9398 - val_loss: 0.7110 - val_accuracy: 0.8320
#
# Epoch 00054: val_loss did not improve from 0.65523
# Epoch 55/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.3049 - accuracy: 0.9416 - val_loss: 0.7160 - val_accuracy: 0.8164
#
# Epoch 00055: val_loss did not improve from 0.65523
# Epoch 56/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2873 - accuracy: 0.9508 - val_loss: 0.7145 - val_accuracy: 0.8203
#
# Epoch 00056: val_loss did not improve from 0.65523
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 57/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2413 - accuracy: 0.9655 - val_loss: 0.7046 - val_accuracy: 0.8242
#
# Epoch 00057: val_loss did not improve from 0.65523
# Epoch 58/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2968 - accuracy: 0.9380 - val_loss: 0.7001 - val_accuracy: 0.8164
#
# Epoch 00058: val_loss did not improve from 0.65523
# Epoch 59/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2534 - accuracy: 0.9573 - val_loss: 0.6637 - val_accuracy: 0.8398
#
# Epoch 00059: val_loss did not improve from 0.65523
# Epoch 60/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2626 - accuracy: 0.9540 - val_loss: 0.6625 - val_accuracy: 0.8359
#
# Epoch 00060: val_loss did not improve from 0.65523
# Epoch 61/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2703 - accuracy: 0.9517 - val_loss: 0.6571 - val_accuracy: 0.8359
#
# Epoch 00061: val_loss did not improve from 0.65523
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 62/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2682 - accuracy: 0.9485 - val_loss: 0.6774 - val_accuracy: 0.8398
#
# Epoch 00062: val_loss did not improve from 0.65523
# Epoch 63/2000
# 34/34 [==============================] - 15s 432ms/step - loss: 0.2276 - accuracy: 0.9688 - val_loss: 0.6875 - val_accuracy: 0.8438
#
# Epoch 00063: val_loss did not improve from 0.65523
# Epoch 64/2000
# 34/34 [==============================] - 14s 413ms/step - loss: 0.2513 - accuracy: 0.9582 - val_loss: 0.6513 - val_accuracy: 0.8398
#
# Epoch 00064: val_loss improved from 0.65523 to 0.65125, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2220 - accuracy: 0.9678 - val_loss: 0.6743 - val_accuracy: 0.8320
#
# Epoch 00065: val_loss did not improve from 0.65125
# Epoch 66/2000
# 34/34 [==============================] - 15s 422ms/step - loss: 0.2477 - accuracy: 0.9563 - val_loss: 0.6992 - val_accuracy: 0.8164
#
# Epoch 00066: val_loss did not improve from 0.65125
# Epoch 67/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.1890 - accuracy: 0.9770 - val_loss: 0.6611 - val_accuracy: 0.8281
#
# Epoch 00067: val_loss did not improve from 0.65125
# Epoch 68/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2210 - accuracy: 0.9655 - val_loss: 0.6858 - val_accuracy: 0.8320
#
# Epoch 00068: val_loss did not improve from 0.65125
# Epoch 69/2000
# 34/34 [==============================] - 13s 371ms/step - loss: 0.2216 - accuracy: 0.9697 - val_loss: 0.6434 - val_accuracy: 0.8281
#
# Epoch 00069: val_loss improved from 0.65125 to 0.64342, saving model to ./save/cnn_gru_best.hdf5
# Epoch 70/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.2613 - accuracy: 0.9481 - val_loss: 0.6776 - val_accuracy: 0.8320
#
# Epoch 00070: val_loss did not improve from 0.64342
# Epoch 71/2000
# 34/34 [==============================] - 14s 406ms/step - loss: 0.2409 - accuracy: 0.9600 - val_loss: 0.6810 - val_accuracy: 0.8242
#
# Epoch 00071: val_loss did not improve from 0.64342
# Epoch 72/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2357 - accuracy: 0.9554 - val_loss: 0.6993 - val_accuracy: 0.8359
#
# Epoch 00072: val_loss did not improve from 0.64342
# Epoch 73/2000
# 34/34 [==============================] - 13s 363ms/step - loss: 0.2522 - accuracy: 0.9499 - val_loss: 0.7033 - val_accuracy: 0.8203
#
# Epoch 00073: val_loss did not improve from 0.64342
# Epoch 74/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2493 - accuracy: 0.9568 - val_loss: 0.6792 - val_accuracy: 0.8281
#
# Epoch 00074: val_loss did not improve from 0.64342
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 75/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2032 - accuracy: 0.9697 - val_loss: 0.6573 - val_accuracy: 0.8359
#
# Epoch 00075: val_loss did not improve from 0.64342
# Epoch 76/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2234 - accuracy: 0.9623 - val_loss: 0.6382 - val_accuracy: 0.8438
#
# Epoch 00076: val_loss improved from 0.64342 to 0.63821, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2114 - accuracy: 0.9669 - val_loss: 0.6529 - val_accuracy: 0.8359
#
# Epoch 00077: val_loss did not improve from 0.63821
# Epoch 78/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2161 - accuracy: 0.9637 - val_loss: 0.6561 - val_accuracy: 0.8281
#
# Epoch 00078: val_loss did not improve from 0.63821
# Epoch 79/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2896 - accuracy: 0.9407 - val_loss: 0.6760 - val_accuracy: 0.8203
#
# Epoch 00079: val_loss did not improve from 0.63821
# Epoch 80/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2356 - accuracy: 0.9586 - val_loss: 0.6629 - val_accuracy: 0.8242
#
# Epoch 00080: val_loss did not improve from 0.63821
# Epoch 81/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2380 - accuracy: 0.9573 - val_loss: 0.6495 - val_accuracy: 0.8320
#
# Epoch 00081: val_loss did not improve from 0.63821
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 82/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2185 - accuracy: 0.9637 - val_loss: 0.6079 - val_accuracy: 0.8398
#
# Epoch 00082: val_loss improved from 0.63821 to 0.60795, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.1759 - accuracy: 0.9770 - val_loss: 0.6291 - val_accuracy: 0.8438
#
# Epoch 00083: val_loss did not improve from 0.60795
# Epoch 84/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.1963 - accuracy: 0.9729 - val_loss: 0.6595 - val_accuracy: 0.8477
#
# Epoch 00084: val_loss did not improve from 0.60795
# Epoch 85/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.1812 - accuracy: 0.9775 - val_loss: 0.6460 - val_accuracy: 0.8398
#
# Epoch 00085: val_loss did not improve from 0.60795
# Epoch 86/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.1720 - accuracy: 0.9779 - val_loss: 0.6513 - val_accuracy: 0.8359
#
# Epoch 00086: val_loss did not improve from 0.60795
# Epoch 87/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2638 - accuracy: 0.9513 - val_loss: 0.6626 - val_accuracy: 0.8359
#
# Epoch 00087: val_loss did not improve from 0.60795
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 88/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2377 - accuracy: 0.9632 - val_loss: 0.6594 - val_accuracy: 0.8438
#
# Epoch 00088: val_loss did not improve from 0.60795
# Epoch 89/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2136 - accuracy: 0.9655 - val_loss: 0.6291 - val_accuracy: 0.8438
#
# Epoch 00089: val_loss did not improve from 0.60795
# Epoch 90/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2118 - accuracy: 0.9642 - val_loss: 0.6379 - val_accuracy: 0.8477
#
# Epoch 00090: val_loss did not improve from 0.60795
# Epoch 91/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2178 - accuracy: 0.9614 - val_loss: 0.6421 - val_accuracy: 0.8438
#
# Epoch 00091: val_loss did not improve from 0.60795
# Epoch 92/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2059 - accuracy: 0.9678 - val_loss: 0.6366 - val_accuracy: 0.8477
#
# Epoch 00092: val_loss did not improve from 0.60795
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 93/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2511 - accuracy: 0.9527 - val_loss: 0.6236 - val_accuracy: 0.8516
#
# Epoch 00093: val_loss did not improve from 0.60795
# Epoch 94/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1889 - accuracy: 0.9710 - val_loss: 0.6556 - val_accuracy: 0.8398
#
# Epoch 00094: val_loss did not improve from 0.60795
# Epoch 95/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2047 - accuracy: 0.9710 - val_loss: 0.6603 - val_accuracy: 0.8398
#
# Epoch 00095: val_loss did not improve from 0.60795
# Epoch 96/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2342 - accuracy: 0.9582 - val_loss: 0.6047 - val_accuracy: 0.8438
#
# Epoch 00096: val_loss improved from 0.60795 to 0.60470, saving model to ./save/cnn_gru_best.hdf5
# Epoch 97/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2532 - accuracy: 0.9563 - val_loss: 0.6710 - val_accuracy: 0.8320
#
# Epoch 00097: val_loss did not improve from 0.60470
# Epoch 98/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2041 - accuracy: 0.9706 - val_loss: 0.6262 - val_accuracy: 0.8438
#
# Epoch 00098: val_loss did not improve from 0.60470
# Epoch 99/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2371 - accuracy: 0.9591 - val_loss: 0.6439 - val_accuracy: 0.8477
#
# Epoch 00099: val_loss did not improve from 0.60470
# Epoch 100/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1976 - accuracy: 0.9674 - val_loss: 0.6295 - val_accuracy: 0.8398
#
# Epoch 00100: val_loss did not improve from 0.60470
# Epoch 101/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2077 - accuracy: 0.9646 - val_loss: 0.6693 - val_accuracy: 0.8281
#
# Epoch 00101: val_loss did not improve from 0.60470
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 102/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2236 - accuracy: 0.9660 - val_loss: 0.6339 - val_accuracy: 0.8359
#
# Epoch 00102: val_loss did not improve from 0.60470
# Epoch 103/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2478 - accuracy: 0.9577 - val_loss: 0.6532 - val_accuracy: 0.8438
#
# Epoch 00103: val_loss did not improve from 0.60470
# Epoch 104/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1921 - accuracy: 0.9724 - val_loss: 0.6437 - val_accuracy: 0.8477
#
# Epoch 00104: val_loss did not improve from 0.60470
# Epoch 105/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2170 - accuracy: 0.9651 - val_loss: 0.6315 - val_accuracy: 0.8438
#
# Epoch 00105: val_loss did not improve from 0.60470
# Epoch 106/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2009 - accuracy: 0.9710 - val_loss: 0.5734 - val_accuracy: 0.8516
#
# Epoch 00106: val_loss improved from 0.60470 to 0.57342, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1869 - accuracy: 0.9738 - val_loss: 0.5871 - val_accuracy: 0.8516
#
# Epoch 00107: val_loss did not improve from 0.57342
# Epoch 108/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2081 - accuracy: 0.9701 - val_loss: 0.6029 - val_accuracy: 0.8555
#
# Epoch 00108: val_loss did not improve from 0.57342
# Epoch 109/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2218 - accuracy: 0.9637 - val_loss: 0.5954 - val_accuracy: 0.8516
#
# Epoch 00109: val_loss did not improve from 0.57342
# Epoch 110/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2064 - accuracy: 0.9646 - val_loss: 0.6356 - val_accuracy: 0.8438
#
# Epoch 00110: val_loss did not improve from 0.57342
# Epoch 111/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2706 - accuracy: 0.9499 - val_loss: 0.6553 - val_accuracy: 0.8438
#
# Epoch 00111: val_loss did not improve from 0.57342
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 112/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2052 - accuracy: 0.9637 - val_loss: 0.6626 - val_accuracy: 0.8438
#
# Epoch 00112: val_loss did not improve from 0.57342
# Epoch 113/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2103 - accuracy: 0.9646 - val_loss: 0.6365 - val_accuracy: 0.8555
#
# Epoch 00113: val_loss did not improve from 0.57342
# Epoch 114/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2283 - accuracy: 0.9577 - val_loss: 0.6603 - val_accuracy: 0.8359
#
# Epoch 00114: val_loss did not improve from 0.57342
# Epoch 115/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2020 - accuracy: 0.9715 - val_loss: 0.6245 - val_accuracy: 0.8398
#
# Epoch 00115: val_loss did not improve from 0.57342
# Epoch 116/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2136 - accuracy: 0.9651 - val_loss: 0.6434 - val_accuracy: 0.8438
#
# Epoch 00116: val_loss did not improve from 0.57342
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 117/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2256 - accuracy: 0.9605 - val_loss: 0.6542 - val_accuracy: 0.8398
#
# Epoch 00117: val_loss did not improve from 0.57342
# Epoch 118/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.1991 - accuracy: 0.9715 - val_loss: 0.6582 - val_accuracy: 0.8438
#
# Epoch 00118: val_loss did not improve from 0.57342
# Epoch 119/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2158 - accuracy: 0.9632 - val_loss: 0.6692 - val_accuracy: 0.8359
#
# Epoch 00119: val_loss did not improve from 0.57342
# Epoch 120/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2584 - accuracy: 0.9531 - val_loss: 0.6823 - val_accuracy: 0.8242
#
# Epoch 00120: val_loss did not improve from 0.57342
# Epoch 121/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2472 - accuracy: 0.9605 - val_loss: 0.6742 - val_accuracy: 0.8320
#
# Epoch 00121: val_loss did not improve from 0.57342
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 122/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1825 - accuracy: 0.9766 - val_loss: 0.6330 - val_accuracy: 0.8477
#
# Epoch 00122: val_loss did not improve from 0.57342
# Epoch 123/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2378 - accuracy: 0.9591 - val_loss: 0.6601 - val_accuracy: 0.8359
#
# Epoch 00123: val_loss did not improve from 0.57342
# Epoch 124/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2180 - accuracy: 0.9651 - val_loss: 0.6639 - val_accuracy: 0.8438
#
# Epoch 00124: val_loss did not improve from 0.57342
# Epoch 125/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.2306 - accuracy: 0.9605 - val_loss: 0.6752 - val_accuracy: 0.8281
#
# Epoch 00125: val_loss did not improve from 0.57342
# Epoch 126/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2240 - accuracy: 0.9596 - val_loss: 0.6750 - val_accuracy: 0.8359
#
# Epoch 00126: val_loss did not improve from 0.57342
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 127/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2408 - accuracy: 0.9568 - val_loss: 0.6677 - val_accuracy: 0.8359
#
# Epoch 00127: val_loss did not improve from 0.57342
# Epoch 128/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.1871 - accuracy: 0.9724 - val_loss: 0.6287 - val_accuracy: 0.8594
#
# Epoch 00128: val_loss did not improve from 0.57342
# Epoch 129/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2159 - accuracy: 0.9646 - val_loss: 0.6724 - val_accuracy: 0.8359
#
# Epoch 00129: val_loss did not improve from 0.57342
# Epoch 130/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.1835 - accuracy: 0.9756 - val_loss: 0.6715 - val_accuracy: 0.8359
#
# Epoch 00130: val_loss did not improve from 0.57342
# Epoch 131/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2243 - accuracy: 0.9582 - val_loss: 0.6634 - val_accuracy: 0.8398
#
# Epoch 00131: val_loss did not improve from 0.57342
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 132/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2218 - accuracy: 0.9586 - val_loss: 0.6494 - val_accuracy: 0.8438
#
# Epoch 00132: val_loss did not improve from 0.57342
# Epoch 133/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2273 - accuracy: 0.9605 - val_loss: 0.6523 - val_accuracy: 0.8438
#
# Epoch 00133: val_loss did not improve from 0.57342
# Epoch 134/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2216 - accuracy: 0.9646 - val_loss: 0.6565 - val_accuracy: 0.8398
#
# Epoch 00134: val_loss did not improve from 0.57342
# Epoch 135/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2122 - accuracy: 0.9660 - val_loss: 0.6609 - val_accuracy: 0.8359
#
# Epoch 00135: val_loss did not improve from 0.57342
# Epoch 136/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.2254 - accuracy: 0.9632 - val_loss: 0.6478 - val_accuracy: 0.8516
#
# Epoch 00136: val_loss did not improve from 0.57342
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6242 - accuracy: 0.8528
# [0.6241756677627563, 0.8528000116348267]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
