# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset#, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.1, # #0.1#, 0.2
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 8)       0           input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 300, 20)      1460        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      2900        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 300, 20)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 300, 20)      80          leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_18 (GRU)                    (None, 300, 40)      7440        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 300, 40)      0           gru_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 300, 40)      160         leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     14520       batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_19 (GRU)                    (None, 150, 120)     87120       batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           gru_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 150, 1140)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_39[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      615660      concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      615660      concatenate_11[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_49[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_52[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,513,111
# Trainable params: 2,505,851
# Non-trainable params: 7,260
# __________________________________________________________________________________________________

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=0))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 58s 546ms/step - loss: 14.9808 - accuracy: 0.4338 - val_loss: 11.5171 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 11.51713, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 8.2258 - accuracy: 0.5790 - val_loss: 7.6859 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 11.51713 to 7.68593, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 4.7115 - accuracy: 0.6834 - val_loss: 6.0921 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 7.68593 to 6.09212, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 3.1738 - accuracy: 0.6751 - val_loss: 4.9178 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 6.09212 to 4.91776, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 2.2472 - accuracy: 0.7109 - val_loss: 5.6431 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss did not improve from 4.91776
# Epoch 6/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 1.7388 - accuracy: 0.7192 - val_loss: 4.7910 - val_accuracy: 0.1602
#
# Epoch 00006: val_loss improved from 4.91776 to 4.79102, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 1.4167 - accuracy: 0.7426 - val_loss: 7.4483 - val_accuracy: 0.0195
#
# Epoch 00007: val_loss did not improve from 4.79102
# Epoch 8/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 1.1906 - accuracy: 0.7762 - val_loss: 6.3241 - val_accuracy: 0.0273
#
# Epoch 00008: val_loss did not improve from 4.79102
# Epoch 9/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 1.0798 - accuracy: 0.7983 - val_loss: 7.2663 - val_accuracy: 0.0195
#
# Epoch 00009: val_loss did not improve from 4.79102
# Epoch 10/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 1.1427 - accuracy: 0.7734 - val_loss: 8.5357 - val_accuracy: 0.0312
#
# Epoch 00010: val_loss did not improve from 4.79102
# Epoch 11/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 1.1067 - accuracy: 0.7799 - val_loss: 5.7732 - val_accuracy: 0.0742
#
# Epoch 00011: val_loss did not improve from 4.79102
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.9730 - accuracy: 0.7969 - val_loss: 5.7773 - val_accuracy: 0.1172
#
# Epoch 00012: val_loss did not improve from 4.79102
# Epoch 13/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.8013 - accuracy: 0.8424 - val_loss: 5.1652 - val_accuracy: 0.1562
#
# Epoch 00013: val_loss did not improve from 4.79102
# Epoch 14/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.7469 - accuracy: 0.8433 - val_loss: 4.1038 - val_accuracy: 0.3477
#
# Epoch 00014: val_loss improved from 4.79102 to 4.10383, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.7921 - accuracy: 0.8199 - val_loss: 5.4850 - val_accuracy: 0.1016
#
# Epoch 00015: val_loss did not improve from 4.10383
# Epoch 16/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.7974 - accuracy: 0.8226 - val_loss: 3.9757 - val_accuracy: 0.3516
#
# Epoch 00016: val_loss improved from 4.10383 to 3.97570, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.8162 - accuracy: 0.8203 - val_loss: 5.6703 - val_accuracy: 0.1758
#
# Epoch 00017: val_loss did not improve from 3.97570
# Epoch 18/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.6930 - accuracy: 0.8529 - val_loss: 2.0735 - val_accuracy: 0.5977
#
# Epoch 00018: val_loss improved from 3.97570 to 2.07351, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.6540 - accuracy: 0.8603 - val_loss: 2.4427 - val_accuracy: 0.5547
#
# Epoch 00019: val_loss did not improve from 2.07351
# Epoch 20/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.8423 - accuracy: 0.8047 - val_loss: 1.4657 - val_accuracy: 0.6914
#
# Epoch 00020: val_loss improved from 2.07351 to 1.46573, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.7430 - accuracy: 0.8433 - val_loss: 1.5787 - val_accuracy: 0.6758
#
# Epoch 00021: val_loss did not improve from 1.46573
# Epoch 22/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.6811 - accuracy: 0.8543 - val_loss: 1.0731 - val_accuracy: 0.7656
#
# Epoch 00022: val_loss improved from 1.46573 to 1.07314, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.7208 - accuracy: 0.8438 - val_loss: 1.2395 - val_accuracy: 0.7422
#
# Epoch 00023: val_loss did not improve from 1.07314
# Epoch 24/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.6695 - accuracy: 0.8543 - val_loss: 1.0618 - val_accuracy: 0.7812
#
# Epoch 00024: val_loss improved from 1.07314 to 1.06177, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.6141 - accuracy: 0.8709 - val_loss: 1.2064 - val_accuracy: 0.7539
#
# Epoch 00025: val_loss did not improve from 1.06177
# Epoch 26/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.6041 - accuracy: 0.8709 - val_loss: 1.0131 - val_accuracy: 0.7773
#
# Epoch 00026: val_loss improved from 1.06177 to 1.01310, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.6490 - accuracy: 0.8713 - val_loss: 1.2241 - val_accuracy: 0.7188
#
# Epoch 00027: val_loss did not improve from 1.01310
# Epoch 28/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.6905 - accuracy: 0.8428 - val_loss: 1.0286 - val_accuracy: 0.7578
#
# Epoch 00028: val_loss did not improve from 1.01310
# Epoch 29/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.6694 - accuracy: 0.8594 - val_loss: 1.2959 - val_accuracy: 0.7070
#
# Epoch 00029: val_loss did not improve from 1.01310
# Epoch 30/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.6004 - accuracy: 0.8819 - val_loss: 1.2720 - val_accuracy: 0.6992
#
# Epoch 00030: val_loss did not improve from 1.01310
# Epoch 31/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.5801 - accuracy: 0.8814 - val_loss: 1.1265 - val_accuracy: 0.7461
#
# Epoch 00031: val_loss did not improve from 1.01310
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 32/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.5119 - accuracy: 0.8980 - val_loss: 0.9364 - val_accuracy: 0.7695
#
# Epoch 00032: val_loss improved from 1.01310 to 0.93642, saving model to ./save/cnn_gru_best.hdf5
# Epoch 33/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.4705 - accuracy: 0.9067 - val_loss: 0.9018 - val_accuracy: 0.7852
#
# Epoch 00033: val_loss improved from 0.93642 to 0.90185, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.4418 - accuracy: 0.9168 - val_loss: 0.8665 - val_accuracy: 0.7930
#
# Epoch 00034: val_loss improved from 0.90185 to 0.86648, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.4623 - accuracy: 0.9085 - val_loss: 0.8446 - val_accuracy: 0.8047
#
# Epoch 00035: val_loss improved from 0.86648 to 0.84465, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.4991 - accuracy: 0.8906 - val_loss: 0.8301 - val_accuracy: 0.7812
#
# Epoch 00036: val_loss improved from 0.84465 to 0.83006, saving model to ./save/cnn_gru_best.hdf5
# Epoch 37/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.4505 - accuracy: 0.9067 - val_loss: 0.8381 - val_accuracy: 0.7852
#
# Epoch 00037: val_loss did not improve from 0.83006
# Epoch 38/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.4118 - accuracy: 0.9159 - val_loss: 0.7745 - val_accuracy: 0.8008
#
# Epoch 00038: val_loss improved from 0.83006 to 0.77450, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.4279 - accuracy: 0.9131 - val_loss: 0.8512 - val_accuracy: 0.7852
#
# Epoch 00039: val_loss did not improve from 0.77450
# Epoch 40/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.4479 - accuracy: 0.9053 - val_loss: 0.8357 - val_accuracy: 0.8086
#
# Epoch 00040: val_loss did not improve from 0.77450
# Epoch 41/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.4350 - accuracy: 0.9090 - val_loss: 0.8783 - val_accuracy: 0.7852
#
# Epoch 00041: val_loss did not improve from 0.77450
# Epoch 42/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.4548 - accuracy: 0.8948 - val_loss: 0.9095 - val_accuracy: 0.7773
#
# Epoch 00042: val_loss did not improve from 0.77450
# Epoch 43/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.4329 - accuracy: 0.9159 - val_loss: 0.8904 - val_accuracy: 0.7852
#
# Epoch 00043: val_loss did not improve from 0.77450
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 44/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.3031 - accuracy: 0.9504 - val_loss: 0.7655 - val_accuracy: 0.7969
#
# Epoch 00044: val_loss improved from 0.77450 to 0.76548, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.3813 - accuracy: 0.9164 - val_loss: 0.7365 - val_accuracy: 0.8086
#
# Epoch 00045: val_loss improved from 0.76548 to 0.73654, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2478 - accuracy: 0.9715 - val_loss: 0.7141 - val_accuracy: 0.8320
#
# Epoch 00046: val_loss improved from 0.73654 to 0.71412, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.3179 - accuracy: 0.9393 - val_loss: 0.8026 - val_accuracy: 0.7969
#
# Epoch 00047: val_loss did not improve from 0.71412
# Epoch 48/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2858 - accuracy: 0.9522 - val_loss: 0.7228 - val_accuracy: 0.8164
#
# Epoch 00048: val_loss did not improve from 0.71412
# Epoch 49/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.4414 - accuracy: 0.8966 - val_loss: 0.7284 - val_accuracy: 0.8320
#
# Epoch 00049: val_loss did not improve from 0.71412
# Epoch 50/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.3778 - accuracy: 0.9196 - val_loss: 0.7439 - val_accuracy: 0.8281
#
# Epoch 00050: val_loss did not improve from 0.71412
# Epoch 51/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2822 - accuracy: 0.9453 - val_loss: 0.6578 - val_accuracy: 0.8438
#
# Epoch 00051: val_loss improved from 0.71412 to 0.65784, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2899 - accuracy: 0.9527 - val_loss: 0.6974 - val_accuracy: 0.8086
#
# Epoch 00052: val_loss did not improve from 0.65784
# Epoch 53/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2904 - accuracy: 0.9398 - val_loss: 0.6906 - val_accuracy: 0.8320
#
# Epoch 00053: val_loss did not improve from 0.65784
# Epoch 54/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.3317 - accuracy: 0.9357 - val_loss: 0.7141 - val_accuracy: 0.8164
#
# Epoch 00054: val_loss did not improve from 0.65784
# Epoch 55/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.3187 - accuracy: 0.9320 - val_loss: 0.7737 - val_accuracy: 0.8359
#
# Epoch 00055: val_loss did not improve from 0.65784
# Epoch 56/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.3184 - accuracy: 0.9334 - val_loss: 0.7359 - val_accuracy: 0.8281
#
# Epoch 00056: val_loss did not improve from 0.65784
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2472 - accuracy: 0.9586 - val_loss: 0.7447 - val_accuracy: 0.8242
#
# Epoch 00057: val_loss did not improve from 0.65784
# Epoch 58/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2834 - accuracy: 0.9453 - val_loss: 0.7201 - val_accuracy: 0.8320
#
# Epoch 00058: val_loss did not improve from 0.65784
# Epoch 59/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2499 - accuracy: 0.9540 - val_loss: 0.6599 - val_accuracy: 0.8398
#
# Epoch 00059: val_loss did not improve from 0.65784
# Epoch 60/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2618 - accuracy: 0.9476 - val_loss: 0.6841 - val_accuracy: 0.8438
#
# Epoch 00060: val_loss did not improve from 0.65784
# Epoch 61/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2702 - accuracy: 0.9472 - val_loss: 0.6763 - val_accuracy: 0.8359
#
# Epoch 00061: val_loss did not improve from 0.65784
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 62/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2631 - accuracy: 0.9481 - val_loss: 0.7260 - val_accuracy: 0.8281
#
# Epoch 00062: val_loss did not improve from 0.65784
# Epoch 63/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2342 - accuracy: 0.9609 - val_loss: 0.7346 - val_accuracy: 0.8164
#
# Epoch 00063: val_loss did not improve from 0.65784
# Epoch 64/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2442 - accuracy: 0.9490 - val_loss: 0.6775 - val_accuracy: 0.8281
#
# Epoch 00064: val_loss did not improve from 0.65784
# Epoch 65/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2191 - accuracy: 0.9646 - val_loss: 0.7015 - val_accuracy: 0.8242
#
# Epoch 00065: val_loss did not improve from 0.65784
# Epoch 66/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2296 - accuracy: 0.9614 - val_loss: 0.7174 - val_accuracy: 0.8281
#
# Epoch 00066: val_loss did not improve from 0.65784
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 67/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.1824 - accuracy: 0.9715 - val_loss: 0.6658 - val_accuracy: 0.8359
#
# Epoch 00067: val_loss did not improve from 0.65784
# Epoch 68/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.2003 - accuracy: 0.9706 - val_loss: 0.7024 - val_accuracy: 0.8281
#
# Epoch 00068: val_loss did not improve from 0.65784
# Epoch 69/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.2113 - accuracy: 0.9623 - val_loss: 0.6760 - val_accuracy: 0.8320
#
# Epoch 00069: val_loss did not improve from 0.65784
# Epoch 70/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2496 - accuracy: 0.9531 - val_loss: 0.7072 - val_accuracy: 0.8242
#
# Epoch 00070: val_loss did not improve from 0.65784
# Epoch 71/2000
# 34/34 [==============================] - 13s 366ms/step - loss: 0.2291 - accuracy: 0.9591 - val_loss: 0.6690 - val_accuracy: 0.8320
#
# Epoch 00071: val_loss did not improve from 0.65784
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 72/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 0.2164 - accuracy: 0.9563 - val_loss: 0.6974 - val_accuracy: 0.8281
#
# Epoch 00072: val_loss did not improve from 0.65784
# Epoch 73/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2340 - accuracy: 0.9522 - val_loss: 0.6961 - val_accuracy: 0.8281
#
# Epoch 00073: val_loss did not improve from 0.65784
# Epoch 74/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.2295 - accuracy: 0.9609 - val_loss: 0.7005 - val_accuracy: 0.8242
#
# Epoch 00074: val_loss did not improve from 0.65784
# Epoch 75/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.1839 - accuracy: 0.9743 - val_loss: 0.6608 - val_accuracy: 0.8320
#
# Epoch 00075: val_loss did not improve from 0.65784
# Epoch 76/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2063 - accuracy: 0.9678 - val_loss: 0.6531 - val_accuracy: 0.8359
#
# Epoch 00076: val_loss improved from 0.65784 to 0.65314, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1805 - accuracy: 0.9710 - val_loss: 0.6619 - val_accuracy: 0.8320
#
# Epoch 00077: val_loss did not improve from 0.65314
# Epoch 78/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.1976 - accuracy: 0.9674 - val_loss: 0.6578 - val_accuracy: 0.8320
#
# Epoch 00078: val_loss did not improve from 0.65314
# Epoch 79/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2818 - accuracy: 0.9375 - val_loss: 0.6879 - val_accuracy: 0.8359
#
# Epoch 00079: val_loss did not improve from 0.65314
# Epoch 80/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2163 - accuracy: 0.9614 - val_loss: 0.6817 - val_accuracy: 0.8359
#
# Epoch 00080: val_loss did not improve from 0.65314
# Epoch 81/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2157 - accuracy: 0.9628 - val_loss: 0.6616 - val_accuracy: 0.8320
#
# Epoch 00081: val_loss did not improve from 0.65314
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 82/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.1971 - accuracy: 0.9665 - val_loss: 0.6284 - val_accuracy: 0.8398
#
# Epoch 00082: val_loss improved from 0.65314 to 0.62840, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1648 - accuracy: 0.9779 - val_loss: 0.6652 - val_accuracy: 0.8359
#
# Epoch 00083: val_loss did not improve from 0.62840
# Epoch 84/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1786 - accuracy: 0.9729 - val_loss: 0.6695 - val_accuracy: 0.8398
#
# Epoch 00084: val_loss did not improve from 0.62840
# Epoch 85/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.1626 - accuracy: 0.9784 - val_loss: 0.6619 - val_accuracy: 0.8398
#
# Epoch 00085: val_loss did not improve from 0.62840
# Epoch 86/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1594 - accuracy: 0.9784 - val_loss: 0.6591 - val_accuracy: 0.8320
#
# Epoch 00086: val_loss did not improve from 0.62840
# Epoch 87/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2417 - accuracy: 0.9573 - val_loss: 0.6720 - val_accuracy: 0.8398
#
# Epoch 00087: val_loss did not improve from 0.62840
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 88/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 0.2329 - accuracy: 0.9554 - val_loss: 0.6887 - val_accuracy: 0.8281
#
# Epoch 00088: val_loss did not improve from 0.62840
# Epoch 89/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1917 - accuracy: 0.9715 - val_loss: 0.6530 - val_accuracy: 0.8438
#
# Epoch 00089: val_loss did not improve from 0.62840
# Epoch 90/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.1900 - accuracy: 0.9729 - val_loss: 0.6565 - val_accuracy: 0.8359
#
# Epoch 00090: val_loss did not improve from 0.62840
# Epoch 91/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.2073 - accuracy: 0.9614 - val_loss: 0.6604 - val_accuracy: 0.8359
#
# Epoch 00091: val_loss did not improve from 0.62840
# Epoch 92/2000
# 34/34 [==============================] - 13s 366ms/step - loss: 0.1952 - accuracy: 0.9688 - val_loss: 0.6506 - val_accuracy: 0.8438
#
# Epoch 00092: val_loss did not improve from 0.62840
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 93/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2184 - accuracy: 0.9642 - val_loss: 0.6399 - val_accuracy: 0.8477
#
# Epoch 00093: val_loss did not improve from 0.62840
# Epoch 94/2000
# 34/34 [==============================] - 13s 366ms/step - loss: 0.1717 - accuracy: 0.9743 - val_loss: 0.6687 - val_accuracy: 0.8359
#
# Epoch 00094: val_loss did not improve from 0.62840
# Epoch 95/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.1888 - accuracy: 0.9697 - val_loss: 0.6692 - val_accuracy: 0.8320
#
# Epoch 00095: val_loss did not improve from 0.62840
# Epoch 96/2000
# 34/34 [==============================] - 13s 366ms/step - loss: 0.2160 - accuracy: 0.9591 - val_loss: 0.6387 - val_accuracy: 0.8398
#
# Epoch 00096: val_loss did not improve from 0.62840
# Epoch 97/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2538 - accuracy: 0.9540 - val_loss: 0.7024 - val_accuracy: 0.8359
#
# Epoch 00097: val_loss did not improve from 0.62840
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 98/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.1909 - accuracy: 0.9697 - val_loss: 0.6346 - val_accuracy: 0.8477
#
# Epoch 00098: val_loss did not improve from 0.62840
# Epoch 99/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2200 - accuracy: 0.9628 - val_loss: 0.6522 - val_accuracy: 0.8438
#
# Epoch 00099: val_loss did not improve from 0.62840
# Epoch 100/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1783 - accuracy: 0.9738 - val_loss: 0.6308 - val_accuracy: 0.8398
#
# Epoch 00100: val_loss did not improve from 0.62840
# Epoch 101/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 0.1858 - accuracy: 0.9706 - val_loss: 0.6836 - val_accuracy: 0.8320
#
# Epoch 00101: val_loss did not improve from 0.62840
# Epoch 102/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 0.2037 - accuracy: 0.9678 - val_loss: 0.6276 - val_accuracy: 0.8398
#
# Epoch 00102: val_loss improved from 0.62840 to 0.62759, saving model to ./save/cnn_gru_best.hdf5
# Epoch 103/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2214 - accuracy: 0.9605 - val_loss: 0.6682 - val_accuracy: 0.8359
#
# Epoch 00103: val_loss did not improve from 0.62759
# Epoch 104/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.1663 - accuracy: 0.9784 - val_loss: 0.6647 - val_accuracy: 0.8320
#
# Epoch 00104: val_loss did not improve from 0.62759
# Epoch 105/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.2003 - accuracy: 0.9669 - val_loss: 0.6565 - val_accuracy: 0.8398
#
# Epoch 00105: val_loss did not improve from 0.62759
# Epoch 106/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.1918 - accuracy: 0.9738 - val_loss: 0.5887 - val_accuracy: 0.8438
#
# Epoch 00106: val_loss improved from 0.62759 to 0.58870, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 12s 361ms/step - loss: 0.1759 - accuracy: 0.9752 - val_loss: 0.5925 - val_accuracy: 0.8555
#
# Epoch 00107: val_loss did not improve from 0.58870
# Epoch 108/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.1946 - accuracy: 0.9747 - val_loss: 0.5979 - val_accuracy: 0.8555
#
# Epoch 00108: val_loss did not improve from 0.58870
# Epoch 109/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2174 - accuracy: 0.9591 - val_loss: 0.5994 - val_accuracy: 0.8438
#
# Epoch 00109: val_loss did not improve from 0.58870
# Epoch 110/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1904 - accuracy: 0.9660 - val_loss: 0.6479 - val_accuracy: 0.8398
#
# Epoch 00110: val_loss did not improve from 0.58870
# Epoch 111/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2508 - accuracy: 0.9481 - val_loss: 0.6682 - val_accuracy: 0.8398
#
# Epoch 00111: val_loss did not improve from 0.58870
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 112/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.1911 - accuracy: 0.9683 - val_loss: 0.6705 - val_accuracy: 0.8398
#
# Epoch 00112: val_loss did not improve from 0.58870
# Epoch 113/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2037 - accuracy: 0.9688 - val_loss: 0.6357 - val_accuracy: 0.8477
#
# Epoch 00113: val_loss did not improve from 0.58870
# Epoch 114/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2188 - accuracy: 0.9591 - val_loss: 0.6782 - val_accuracy: 0.8398
#
# Epoch 00114: val_loss did not improve from 0.58870
# Epoch 115/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2012 - accuracy: 0.9665 - val_loss: 0.6398 - val_accuracy: 0.8398
#
# Epoch 00115: val_loss did not improve from 0.58870
# Epoch 116/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.1889 - accuracy: 0.9697 - val_loss: 0.6581 - val_accuracy: 0.8398
#
# Epoch 00116: val_loss did not improve from 0.58870
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 117/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2124 - accuracy: 0.9632 - val_loss: 0.6612 - val_accuracy: 0.8438
#
# Epoch 00117: val_loss did not improve from 0.58870
# Epoch 118/2000
# 34/34 [==============================] - 13s 368ms/step - loss: 0.1853 - accuracy: 0.9729 - val_loss: 0.6695 - val_accuracy: 0.8398
#
# Epoch 00118: val_loss did not improve from 0.58870
# Epoch 119/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2004 - accuracy: 0.9678 - val_loss: 0.6856 - val_accuracy: 0.8398
#
# Epoch 00119: val_loss did not improve from 0.58870
# Epoch 120/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.2408 - accuracy: 0.9531 - val_loss: 0.6948 - val_accuracy: 0.8398
#
# Epoch 00120: val_loss did not improve from 0.58870
# Epoch 121/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2354 - accuracy: 0.9563 - val_loss: 0.6764 - val_accuracy: 0.8438
#
# Epoch 00121: val_loss did not improve from 0.58870
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 122/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.1703 - accuracy: 0.9752 - val_loss: 0.6416 - val_accuracy: 0.8477
#
# Epoch 00122: val_loss did not improve from 0.58870
# Epoch 123/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 0.2156 - accuracy: 0.9628 - val_loss: 0.6710 - val_accuracy: 0.8438
#
# Epoch 00123: val_loss did not improve from 0.58870
# Epoch 124/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 0.2067 - accuracy: 0.9669 - val_loss: 0.6761 - val_accuracy: 0.8359
#
# Epoch 00124: val_loss did not improve from 0.58870
# Epoch 125/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.2049 - accuracy: 0.9655 - val_loss: 0.6846 - val_accuracy: 0.8398
#
# Epoch 00125: val_loss did not improve from 0.58870
# Epoch 126/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.1944 - accuracy: 0.9701 - val_loss: 0.6837 - val_accuracy: 0.8398
#
# Epoch 00126: val_loss did not improve from 0.58870
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 127/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2265 - accuracy: 0.9586 - val_loss: 0.6774 - val_accuracy: 0.8438
#
# Epoch 00127: val_loss did not improve from 0.58870
# Epoch 128/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1711 - accuracy: 0.9770 - val_loss: 0.6252 - val_accuracy: 0.8555
#
# Epoch 00128: val_loss did not improve from 0.58870
# Epoch 129/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.1997 - accuracy: 0.9710 - val_loss: 0.6876 - val_accuracy: 0.8320
#
# Epoch 00129: val_loss did not improve from 0.58870
# Epoch 130/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.1628 - accuracy: 0.9789 - val_loss: 0.6796 - val_accuracy: 0.8281
#
# Epoch 00130: val_loss did not improve from 0.58870
# Epoch 131/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2100 - accuracy: 0.9637 - val_loss: 0.6581 - val_accuracy: 0.8320
#
# Epoch 00131: val_loss did not improve from 0.58870
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 132/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.2031 - accuracy: 0.9651 - val_loss: 0.6662 - val_accuracy: 0.8359
#
# Epoch 00132: val_loss did not improve from 0.58870
# Epoch 133/2000
# 34/34 [==============================] - 12s 365ms/step - loss: 0.2026 - accuracy: 0.9655 - val_loss: 0.6721 - val_accuracy: 0.8359
#
# Epoch 00133: val_loss did not improve from 0.58870
# Epoch 134/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2061 - accuracy: 0.9623 - val_loss: 0.6641 - val_accuracy: 0.8359
#
# Epoch 00134: val_loss did not improve from 0.58870
# Epoch 135/2000
# 34/34 [==============================] - 12s 363ms/step - loss: 0.1948 - accuracy: 0.9692 - val_loss: 0.6687 - val_accuracy: 0.8320
#
# Epoch 00135: val_loss did not improve from 0.58870
# Epoch 136/2000
# 34/34 [==============================] - 12s 364ms/step - loss: 0.2098 - accuracy: 0.9614 - val_loss: 0.6616 - val_accuracy: 0.8398
#
# Epoch 00136: val_loss did not improve from 0.58870
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5548 - accuracy: 0.8624
# [0.5547916293144226, 0.8623999953269958]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
