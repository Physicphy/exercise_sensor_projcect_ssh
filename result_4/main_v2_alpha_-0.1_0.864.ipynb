# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset#, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = -0.1, # #0.05#, #0.1#, 0.2
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 8)       0           input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 300, 20)      1460        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      2900        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 300, 20)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 300, 20)      80          leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_18 (GRU)                    (None, 300, 40)      7440        batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 300, 40)      0           gru_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 300, 40)      160         leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     14520       batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_19 (GRU)                    (None, 150, 120)     87120       batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           gru_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 150, 1140)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_39[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150, 60)      615660      concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 60)      240         conv1d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         conv1d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 60)      615660      concatenate_11[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_46[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 150, 60)      240         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 120)     480         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_49[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 120)     480         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_52[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,513,111
# Trainable params: 2,505,851
# Non-trainable params: 7,260
# __________________________________________________________________________________________________

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=0))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 59s 549ms/step - loss: 14.8604 - accuracy: 0.4559 - val_loss: 11.5108 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 11.51077, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 8.1653 - accuracy: 0.5915 - val_loss: 7.4662 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 11.51077 to 7.46624, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 4.6991 - accuracy: 0.6889 - val_loss: 5.5444 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 7.46624 to 5.54441, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 3.1384 - accuracy: 0.6907 - val_loss: 4.6428 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 5.54441 to 4.64275, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 2.2440 - accuracy: 0.7206 - val_loss: 5.0101 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss did not improve from 4.64275
# Epoch 6/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 1.7585 - accuracy: 0.7229 - val_loss: 4.6072 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 4.64275 to 4.60720, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 1.4240 - accuracy: 0.7509 - val_loss: 4.4324 - val_accuracy: 0.4102
#
# Epoch 00007: val_loss improved from 4.60720 to 4.43240, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 1.2006 - accuracy: 0.7835 - val_loss: 4.7853 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss did not improve from 4.43240
# Epoch 9/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 1.1063 - accuracy: 0.7881 - val_loss: 4.7737 - val_accuracy: 0.3203
#
# Epoch 00009: val_loss did not improve from 4.43240
# Epoch 10/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 1.1451 - accuracy: 0.7707 - val_loss: 6.3294 - val_accuracy: 0.0430
#
# Epoch 00010: val_loss did not improve from 4.43240
# Epoch 11/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 1.1149 - accuracy: 0.7702 - val_loss: 6.0222 - val_accuracy: 0.0352
#
# Epoch 00011: val_loss did not improve from 4.43240
# Epoch 12/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 1.0936 - accuracy: 0.7826 - val_loss: 4.2187 - val_accuracy: 0.2617
#
# Epoch 00012: val_loss improved from 4.43240 to 4.21875, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.9503 - accuracy: 0.8180 - val_loss: 5.1133 - val_accuracy: 0.2695
#
# Epoch 00013: val_loss did not improve from 4.21875
# Epoch 14/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.9407 - accuracy: 0.8006 - val_loss: 4.4070 - val_accuracy: 0.2578
#
# Epoch 00014: val_loss did not improve from 4.21875
# Epoch 15/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.9993 - accuracy: 0.7886 - val_loss: 4.8508 - val_accuracy: 0.2422
#
# Epoch 00015: val_loss did not improve from 4.21875
# Epoch 16/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 1.0206 - accuracy: 0.7932 - val_loss: 5.4613 - val_accuracy: 0.2383
#
# Epoch 00016: val_loss did not improve from 4.21875
# Epoch 17/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 1.0397 - accuracy: 0.7891 - val_loss: 3.6555 - val_accuracy: 0.3281
#
# Epoch 00017: val_loss improved from 4.21875 to 3.65551, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.8792 - accuracy: 0.8194 - val_loss: 2.3415 - val_accuracy: 0.5742
#
# Epoch 00018: val_loss improved from 3.65551 to 2.34148, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.8044 - accuracy: 0.8405 - val_loss: 2.1460 - val_accuracy: 0.6211
#
# Epoch 00019: val_loss improved from 2.34148 to 2.14597, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.9878 - accuracy: 0.7918 - val_loss: 1.8035 - val_accuracy: 0.6445
#
# Epoch 00020: val_loss improved from 2.14597 to 1.80347, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.9001 - accuracy: 0.8116 - val_loss: 1.9441 - val_accuracy: 0.6250
#
# Epoch 00021: val_loss did not improve from 1.80347
# Epoch 22/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.8506 - accuracy: 0.8231 - val_loss: 1.4549 - val_accuracy: 0.7227
#
# Epoch 00022: val_loss improved from 1.80347 to 1.45490, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.8526 - accuracy: 0.8300 - val_loss: 1.4175 - val_accuracy: 0.6914
#
# Epoch 00023: val_loss improved from 1.45490 to 1.41752, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.7992 - accuracy: 0.8433 - val_loss: 1.1443 - val_accuracy: 0.7656
#
# Epoch 00024: val_loss improved from 1.41752 to 1.14432, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.7792 - accuracy: 0.8405 - val_loss: 1.5450 - val_accuracy: 0.6953
#
# Epoch 00025: val_loss did not improve from 1.14432
# Epoch 26/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.7324 - accuracy: 0.8539 - val_loss: 1.4750 - val_accuracy: 0.7070
#
# Epoch 00026: val_loss did not improve from 1.14432
# Epoch 27/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.7612 - accuracy: 0.8557 - val_loss: 1.2065 - val_accuracy: 0.7578
#
# Epoch 00027: val_loss did not improve from 1.14432
# Epoch 28/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.8142 - accuracy: 0.8318 - val_loss: 2.4355 - val_accuracy: 0.5430
#
# Epoch 00028: val_loss did not improve from 1.14432
# Epoch 29/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.8308 - accuracy: 0.8364 - val_loss: 2.1612 - val_accuracy: 0.5859
#
# Epoch 00029: val_loss did not improve from 1.14432
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 30/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.6502 - accuracy: 0.8824 - val_loss: 1.2844 - val_accuracy: 0.7148
#
# Epoch 00030: val_loss did not improve from 1.14432
# Epoch 31/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.5451 - accuracy: 0.9030 - val_loss: 0.9376 - val_accuracy: 0.7734
#
# Epoch 00031: val_loss improved from 1.14432 to 0.93760, saving model to ./save/cnn_gru_best.hdf5
# Epoch 32/2000
# 34/34 [==============================] - 12s 360ms/step - loss: 0.5101 - accuracy: 0.8980 - val_loss: 1.0096 - val_accuracy: 0.7656
#
# Epoch 00032: val_loss did not improve from 0.93760
# Epoch 33/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.5212 - accuracy: 0.8975 - val_loss: 1.1057 - val_accuracy: 0.7578
#
# Epoch 00033: val_loss did not improve from 0.93760
# Epoch 34/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.5060 - accuracy: 0.8984 - val_loss: 0.8560 - val_accuracy: 0.8125
#
# Epoch 00034: val_loss improved from 0.93760 to 0.85600, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.5557 - accuracy: 0.8915 - val_loss: 0.8806 - val_accuracy: 0.8047
#
# Epoch 00035: val_loss did not improve from 0.85600
# Epoch 36/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.5556 - accuracy: 0.8874 - val_loss: 0.9741 - val_accuracy: 0.7539
#
# Epoch 00036: val_loss did not improve from 0.85600
# Epoch 37/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.5166 - accuracy: 0.9026 - val_loss: 0.9672 - val_accuracy: 0.7852
#
# Epoch 00037: val_loss did not improve from 0.85600
# Epoch 38/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.4941 - accuracy: 0.9076 - val_loss: 0.9893 - val_accuracy: 0.7656
#
# Epoch 00038: val_loss did not improve from 0.85600
# Epoch 39/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.5283 - accuracy: 0.8980 - val_loss: 1.0876 - val_accuracy: 0.7812
#
# Epoch 00039: val_loss did not improve from 0.85600
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 40/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.4586 - accuracy: 0.9076 - val_loss: 0.9063 - val_accuracy: 0.7852
#
# Epoch 00040: val_loss did not improve from 0.85600
# Epoch 41/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3992 - accuracy: 0.9306 - val_loss: 0.8476 - val_accuracy: 0.8164
#
# Epoch 00041: val_loss improved from 0.85600 to 0.84761, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.4054 - accuracy: 0.9214 - val_loss: 0.7731 - val_accuracy: 0.8203
#
# Epoch 00042: val_loss improved from 0.84761 to 0.77307, saving model to ./save/cnn_gru_best.hdf5
# Epoch 43/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.3844 - accuracy: 0.9246 - val_loss: 0.7636 - val_accuracy: 0.8203
#
# Epoch 00043: val_loss improved from 0.77307 to 0.76363, saving model to ./save/cnn_gru_best.hdf5
# Epoch 44/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2776 - accuracy: 0.9582 - val_loss: 0.7527 - val_accuracy: 0.8242
#
# Epoch 00044: val_loss improved from 0.76363 to 0.75272, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.3792 - accuracy: 0.9278 - val_loss: 0.8084 - val_accuracy: 0.8281
#
# Epoch 00045: val_loss did not improve from 0.75272
# Epoch 46/2000
# 34/34 [==============================] - 12s 359ms/step - loss: 0.2665 - accuracy: 0.9628 - val_loss: 0.7495 - val_accuracy: 0.8203
#
# Epoch 00046: val_loss improved from 0.75272 to 0.74952, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.3341 - accuracy: 0.9334 - val_loss: 0.7577 - val_accuracy: 0.8164
#
# Epoch 00047: val_loss did not improve from 0.74952
# Epoch 48/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2985 - accuracy: 0.9453 - val_loss: 0.6862 - val_accuracy: 0.8320
#
# Epoch 00048: val_loss improved from 0.74952 to 0.68619, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.4534 - accuracy: 0.8975 - val_loss: 0.8320 - val_accuracy: 0.8086
#
# Epoch 00049: val_loss did not improve from 0.68619
# Epoch 50/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.4206 - accuracy: 0.9131 - val_loss: 0.8989 - val_accuracy: 0.7891
#
# Epoch 00050: val_loss did not improve from 0.68619
# Epoch 51/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2939 - accuracy: 0.9527 - val_loss: 0.7556 - val_accuracy: 0.8047
#
# Epoch 00051: val_loss did not improve from 0.68619
# Epoch 52/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2987 - accuracy: 0.9508 - val_loss: 0.8328 - val_accuracy: 0.8203
#
# Epoch 00052: val_loss did not improve from 0.68619
# Epoch 53/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.3082 - accuracy: 0.9380 - val_loss: 0.7724 - val_accuracy: 0.8281
#
# Epoch 00053: val_loss did not improve from 0.68619
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 54/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.3428 - accuracy: 0.9301 - val_loss: 0.7483 - val_accuracy: 0.8203
#
# Epoch 00054: val_loss did not improve from 0.68619
# Epoch 55/2000
# 34/34 [==============================] - 12s 362ms/step - loss: 0.2929 - accuracy: 0.9412 - val_loss: 0.7179 - val_accuracy: 0.8203
#
# Epoch 00055: val_loss did not improve from 0.68619
# Epoch 56/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2713 - accuracy: 0.9582 - val_loss: 0.7065 - val_accuracy: 0.8320
#
# Epoch 00056: val_loss did not improve from 0.68619
# Epoch 57/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2272 - accuracy: 0.9669 - val_loss: 0.7176 - val_accuracy: 0.8438
#
# Epoch 00057: val_loss did not improve from 0.68619
# Epoch 58/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2726 - accuracy: 0.9462 - val_loss: 0.6999 - val_accuracy: 0.8555
#
# Epoch 00058: val_loss did not improve from 0.68619
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 59/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2293 - accuracy: 0.9646 - val_loss: 0.6667 - val_accuracy: 0.8555
#
# Epoch 00059: val_loss improved from 0.68619 to 0.66666, saving model to ./save/cnn_gru_best.hdf5
# Epoch 60/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2467 - accuracy: 0.9554 - val_loss: 0.6476 - val_accuracy: 0.8516
#
# Epoch 00060: val_loss improved from 0.66666 to 0.64757, saving model to ./save/cnn_gru_best.hdf5
# Epoch 61/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2439 - accuracy: 0.9540 - val_loss: 0.6350 - val_accuracy: 0.8398
#
# Epoch 00061: val_loss improved from 0.64757 to 0.63501, saving model to ./save/cnn_gru_best.hdf5
# Epoch 62/2000
# 34/34 [==============================] - 12s 357ms/step - loss: 0.2382 - accuracy: 0.9517 - val_loss: 0.6942 - val_accuracy: 0.8438
#
# Epoch 00062: val_loss did not improve from 0.63501
# Epoch 63/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2061 - accuracy: 0.9665 - val_loss: 0.7259 - val_accuracy: 0.8359
#
# Epoch 00063: val_loss did not improve from 0.63501
# Epoch 64/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2261 - accuracy: 0.9637 - val_loss: 0.6820 - val_accuracy: 0.8438
#
# Epoch 00064: val_loss did not improve from 0.63501
# Epoch 65/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2021 - accuracy: 0.9701 - val_loss: 0.7070 - val_accuracy: 0.8320
#
# Epoch 00065: val_loss did not improve from 0.63501
# Epoch 66/2000
# 34/34 [==============================] - 12s 356ms/step - loss: 0.2095 - accuracy: 0.9651 - val_loss: 0.7163 - val_accuracy: 0.8086
#
# Epoch 00066: val_loss did not improve from 0.63501
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 67/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.1584 - accuracy: 0.9789 - val_loss: 0.6386 - val_accuracy: 0.8320
#
# Epoch 00067: val_loss did not improve from 0.63501
# Epoch 68/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.1777 - accuracy: 0.9752 - val_loss: 0.6725 - val_accuracy: 0.8555
#
# Epoch 00068: val_loss did not improve from 0.63501
# Epoch 69/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1934 - accuracy: 0.9665 - val_loss: 0.6336 - val_accuracy: 0.8516
#
# Epoch 00069: val_loss improved from 0.63501 to 0.63356, saving model to ./save/cnn_gru_best.hdf5
# Epoch 70/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2151 - accuracy: 0.9559 - val_loss: 0.6689 - val_accuracy: 0.8398
#
# Epoch 00070: val_loss did not improve from 0.63356
# Epoch 71/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2085 - accuracy: 0.9577 - val_loss: 0.6526 - val_accuracy: 0.8281
#
# Epoch 00071: val_loss did not improve from 0.63356
# Epoch 72/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.1887 - accuracy: 0.9632 - val_loss: 0.6735 - val_accuracy: 0.8359
#
# Epoch 00072: val_loss did not improve from 0.63356
# Epoch 73/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2062 - accuracy: 0.9605 - val_loss: 0.6657 - val_accuracy: 0.8438
#
# Epoch 00073: val_loss did not improve from 0.63356
# Epoch 74/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1954 - accuracy: 0.9669 - val_loss: 0.6840 - val_accuracy: 0.8516
#
# Epoch 00074: val_loss did not improve from 0.63356
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 75/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1582 - accuracy: 0.9793 - val_loss: 0.6487 - val_accuracy: 0.8477
#
# Epoch 00075: val_loss did not improve from 0.63356
# Epoch 76/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1708 - accuracy: 0.9756 - val_loss: 0.6217 - val_accuracy: 0.8477
#
# Epoch 00076: val_loss improved from 0.63356 to 0.62168, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1583 - accuracy: 0.9807 - val_loss: 0.6406 - val_accuracy: 0.8477
#
# Epoch 00077: val_loss did not improve from 0.62168
# Epoch 78/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1670 - accuracy: 0.9733 - val_loss: 0.6456 - val_accuracy: 0.8477
#
# Epoch 00078: val_loss did not improve from 0.62168
# Epoch 79/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2332 - accuracy: 0.9508 - val_loss: 0.6658 - val_accuracy: 0.8320
#
# Epoch 00079: val_loss did not improve from 0.62168
# Epoch 80/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.1740 - accuracy: 0.9651 - val_loss: 0.6495 - val_accuracy: 0.8438
#
# Epoch 00080: val_loss did not improve from 0.62168
# Epoch 81/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1810 - accuracy: 0.9715 - val_loss: 0.6382 - val_accuracy: 0.8477
#
# Epoch 00081: val_loss did not improve from 0.62168
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 82/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1679 - accuracy: 0.9729 - val_loss: 0.6040 - val_accuracy: 0.8555
#
# Epoch 00082: val_loss improved from 0.62168 to 0.60395, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1374 - accuracy: 0.9821 - val_loss: 0.6190 - val_accuracy: 0.8477
#
# Epoch 00083: val_loss did not improve from 0.60395
# Epoch 84/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1439 - accuracy: 0.9812 - val_loss: 0.6475 - val_accuracy: 0.8398
#
# Epoch 00084: val_loss did not improve from 0.60395
# Epoch 85/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1423 - accuracy: 0.9830 - val_loss: 0.6358 - val_accuracy: 0.8516
#
# Epoch 00085: val_loss did not improve from 0.60395
# Epoch 86/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1330 - accuracy: 0.9812 - val_loss: 0.6403 - val_accuracy: 0.8477
#
# Epoch 00086: val_loss did not improve from 0.60395
# Epoch 87/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.2038 - accuracy: 0.9632 - val_loss: 0.6341 - val_accuracy: 0.8438
#
# Epoch 00087: val_loss did not improve from 0.60395
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 88/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1832 - accuracy: 0.9692 - val_loss: 0.6436 - val_accuracy: 0.8359
#
# Epoch 00088: val_loss did not improve from 0.60395
# Epoch 89/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1586 - accuracy: 0.9747 - val_loss: 0.6225 - val_accuracy: 0.8477
#
# Epoch 00089: val_loss did not improve from 0.60395
# Epoch 90/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1599 - accuracy: 0.9756 - val_loss: 0.6022 - val_accuracy: 0.8477
#
# Epoch 00090: val_loss improved from 0.60395 to 0.60219, saving model to ./save/cnn_gru_best.hdf5
# Epoch 91/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1655 - accuracy: 0.9756 - val_loss: 0.6325 - val_accuracy: 0.8438
#
# Epoch 00091: val_loss did not improve from 0.60219
# Epoch 92/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.1569 - accuracy: 0.9775 - val_loss: 0.6078 - val_accuracy: 0.8516
#
# Epoch 00092: val_loss did not improve from 0.60219
# Epoch 93/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1819 - accuracy: 0.9651 - val_loss: 0.6163 - val_accuracy: 0.8555
#
# Epoch 00093: val_loss did not improve from 0.60219
# Epoch 94/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1406 - accuracy: 0.9816 - val_loss: 0.6485 - val_accuracy: 0.8477
#
# Epoch 00094: val_loss did not improve from 0.60219
# Epoch 95/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1534 - accuracy: 0.9770 - val_loss: 0.6385 - val_accuracy: 0.8438
#
# Epoch 00095: val_loss did not improve from 0.60219
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 96/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1770 - accuracy: 0.9692 - val_loss: 0.6036 - val_accuracy: 0.8555
#
# Epoch 00096: val_loss did not improve from 0.60219
# Epoch 97/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1967 - accuracy: 0.9600 - val_loss: 0.6531 - val_accuracy: 0.8516
#
# Epoch 00097: val_loss did not improve from 0.60219
# Epoch 98/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1543 - accuracy: 0.9766 - val_loss: 0.6041 - val_accuracy: 0.8633
#
# Epoch 00098: val_loss did not improve from 0.60219
# Epoch 99/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1770 - accuracy: 0.9683 - val_loss: 0.6189 - val_accuracy: 0.8477
#
# Epoch 00099: val_loss did not improve from 0.60219
# Epoch 100/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1417 - accuracy: 0.9816 - val_loss: 0.5949 - val_accuracy: 0.8477
#
# Epoch 00100: val_loss improved from 0.60219 to 0.59488, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1539 - accuracy: 0.9747 - val_loss: 0.6515 - val_accuracy: 0.8359
#
# Epoch 00101: val_loss did not improve from 0.59488
# Epoch 102/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.1717 - accuracy: 0.9738 - val_loss: 0.5941 - val_accuracy: 0.8516
#
# Epoch 00102: val_loss improved from 0.59488 to 0.59413, saving model to ./save/cnn_gru_best.hdf5
# Epoch 103/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1797 - accuracy: 0.9669 - val_loss: 0.6229 - val_accuracy: 0.8516
#
# Epoch 00103: val_loss did not improve from 0.59413
# Epoch 104/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1332 - accuracy: 0.9835 - val_loss: 0.6291 - val_accuracy: 0.8555
#
# Epoch 00104: val_loss did not improve from 0.59413
# Epoch 105/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1700 - accuracy: 0.9688 - val_loss: 0.6087 - val_accuracy: 0.8633
#
# Epoch 00105: val_loss did not improve from 0.59413
# Epoch 106/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1537 - accuracy: 0.9779 - val_loss: 0.5631 - val_accuracy: 0.8711
#
# Epoch 00106: val_loss improved from 0.59413 to 0.56310, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1335 - accuracy: 0.9839 - val_loss: 0.5817 - val_accuracy: 0.8516
#
# Epoch 00107: val_loss did not improve from 0.56310
# Epoch 108/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1501 - accuracy: 0.9807 - val_loss: 0.5716 - val_accuracy: 0.8711
#
# Epoch 00108: val_loss did not improve from 0.56310
# Epoch 109/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1674 - accuracy: 0.9715 - val_loss: 0.5860 - val_accuracy: 0.8633
#
# Epoch 00109: val_loss did not improve from 0.56310
# Epoch 110/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1510 - accuracy: 0.9779 - val_loss: 0.6262 - val_accuracy: 0.8516
#
# Epoch 00110: val_loss did not improve from 0.56310
# Epoch 111/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1980 - accuracy: 0.9642 - val_loss: 0.6354 - val_accuracy: 0.8477
#
# Epoch 00111: val_loss did not improve from 0.56310
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 112/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1540 - accuracy: 0.9756 - val_loss: 0.6411 - val_accuracy: 0.8477
#
# Epoch 00112: val_loss did not improve from 0.56310
# Epoch 113/2000
# 34/34 [==============================] - 12s 343ms/step - loss: 0.1591 - accuracy: 0.9724 - val_loss: 0.6087 - val_accuracy: 0.8555
#
# Epoch 00113: val_loss did not improve from 0.56310
# Epoch 114/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1701 - accuracy: 0.9678 - val_loss: 0.6432 - val_accuracy: 0.8438
#
# Epoch 00114: val_loss did not improve from 0.56310
# Epoch 115/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1532 - accuracy: 0.9784 - val_loss: 0.6209 - val_accuracy: 0.8477
#
# Epoch 00115: val_loss did not improve from 0.56310
# Epoch 116/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1485 - accuracy: 0.9789 - val_loss: 0.6258 - val_accuracy: 0.8555
#
# Epoch 00116: val_loss did not improve from 0.56310
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 117/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1656 - accuracy: 0.9743 - val_loss: 0.6280 - val_accuracy: 0.8555
#
# Epoch 00117: val_loss did not improve from 0.56310
# Epoch 118/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1487 - accuracy: 0.9779 - val_loss: 0.6327 - val_accuracy: 0.8555
#
# Epoch 00118: val_loss did not improve from 0.56310
# Epoch 119/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1575 - accuracy: 0.9761 - val_loss: 0.6553 - val_accuracy: 0.8438
#
# Epoch 00119: val_loss did not improve from 0.56310
# Epoch 120/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1931 - accuracy: 0.9596 - val_loss: 0.6567 - val_accuracy: 0.8398
#
# Epoch 00120: val_loss did not improve from 0.56310
# Epoch 121/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1799 - accuracy: 0.9701 - val_loss: 0.6392 - val_accuracy: 0.8438
#
# Epoch 00121: val_loss did not improve from 0.56310
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 122/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1300 - accuracy: 0.9844 - val_loss: 0.6158 - val_accuracy: 0.8594
#
# Epoch 00122: val_loss did not improve from 0.56310
# Epoch 123/2000
# 34/34 [==============================] - 12s 345ms/step - loss: 0.1640 - accuracy: 0.9724 - val_loss: 0.6387 - val_accuracy: 0.8477
#
# Epoch 00123: val_loss did not improve from 0.56310
# Epoch 124/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1624 - accuracy: 0.9733 - val_loss: 0.6394 - val_accuracy: 0.8477
#
# Epoch 00124: val_loss did not improve from 0.56310
# Epoch 125/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1636 - accuracy: 0.9775 - val_loss: 0.6529 - val_accuracy: 0.8477
#
# Epoch 00125: val_loss did not improve from 0.56310
# Epoch 126/2000
# 34/34 [==============================] - 12s 348ms/step - loss: 0.1589 - accuracy: 0.9724 - val_loss: 0.6470 - val_accuracy: 0.8477
#
# Epoch 00126: val_loss did not improve from 0.56310
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 127/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1775 - accuracy: 0.9710 - val_loss: 0.6353 - val_accuracy: 0.8477
#
# Epoch 00127: val_loss did not improve from 0.56310
# Epoch 128/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1378 - accuracy: 0.9812 - val_loss: 0.5983 - val_accuracy: 0.8594
#
# Epoch 00128: val_loss did not improve from 0.56310
# Epoch 129/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1617 - accuracy: 0.9775 - val_loss: 0.6538 - val_accuracy: 0.8438
#
# Epoch 00129: val_loss did not improve from 0.56310
# Epoch 130/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.1338 - accuracy: 0.9839 - val_loss: 0.6503 - val_accuracy: 0.8438
#
# Epoch 00130: val_loss did not improve from 0.56310
# Epoch 131/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1644 - accuracy: 0.9756 - val_loss: 0.6285 - val_accuracy: 0.8516
#
# Epoch 00131: val_loss did not improve from 0.56310
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 132/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1591 - accuracy: 0.9752 - val_loss: 0.6341 - val_accuracy: 0.8516
#
# Epoch 00132: val_loss did not improve from 0.56310
# Epoch 133/2000
# 34/34 [==============================] - 12s 350ms/step - loss: 0.1691 - accuracy: 0.9710 - val_loss: 0.6280 - val_accuracy: 0.8477
#
# Epoch 00133: val_loss did not improve from 0.56310
# Epoch 134/2000
# 34/34 [==============================] - 12s 351ms/step - loss: 0.1722 - accuracy: 0.9733 - val_loss: 0.6337 - val_accuracy: 0.8516
#
# Epoch 00134: val_loss did not improve from 0.56310
# Epoch 135/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.1504 - accuracy: 0.9807 - val_loss: 0.6242 - val_accuracy: 0.8438
#
# Epoch 00135: val_loss did not improve from 0.56310
# Epoch 136/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.1685 - accuracy: 0.9766 - val_loss: 0.6417 - val_accuracy: 0.8477
#
# Epoch 00136: val_loss did not improve from 0.56310
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5972 - accuracy: 0.8640
# [0.5971873998641968, 0.8640000224113464]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
