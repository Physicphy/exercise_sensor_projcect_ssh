# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset#, class_weight_dict
from my_model_class import CNN_RNN_Resnet

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = CNN_RNN_Resnet(
    leakyrelu_alpha = 0.1, #-0.2, #-0.1#, #0.05#, #0.1#, 0.2
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.02, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )(lr = 0.001,seed=42)

model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 600, 8)       0           input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 300, 20)      1460        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 300, 20)      2900        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 300, 10)      1810        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 300, 10)      1810        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          conv1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 300, 20)      80          conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 300, 20)      80          conv1d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 300, 20)      80          conv1d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          conv1d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 300, 20)      80          conv1d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 300, 10)      40          conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 300, 10)      40          conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 300, 10)      40          conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 300, 10)      0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 300, 10)      0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 300, 10)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# gru_18 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# gru_24 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# gru_27 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 300, 20)      1920        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 300, 20)      1920        leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# gru_15 (GRU)                    (None, 300, 20)      1920        leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         gru[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         gru_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 300, 40)      160         gru_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 300, 40)      160         gru_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 300, 40)      160         gru_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         gru_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 300, 40)      160         gru_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 300, 20)      80          gru_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 300, 20)      80          gru_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 300, 20)      80          gru_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 300, 20)      0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     43320       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     43320       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 150, 60)      21660       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         conv1d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 120)     480         conv1d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 120)     480         conv1d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 120)     480         conv1d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 150, 60)      240         conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 150, 60)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# gru_19 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# gru_22 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# gru_25 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# gru_28 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 150, 60)      21960       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 150, 60)      21960       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 150, 60)      21960       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         gru_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         gru_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         gru_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         gru_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 120)     480         gru_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         gru_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 120)     480         gru_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 150, 60)      240         gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 60)      240         gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 150, 60)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 75, 120)      129720      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 75, 120)      129720      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 75, 60)       64860       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 75, 60)       64860       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 75, 60)       64860       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 120)      480         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 120)      480         conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 75, 120)      480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 75, 120)      480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 75, 120)      480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 75, 120)      480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 75, 120)      480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 75, 60)       240         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 75, 60)       240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 75, 60)       240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 75, 120)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 75, 120)      87120       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 75, 120)      87120       leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# gru_23 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# gru_26 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# gru_14 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# gru_29 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 75, 60)       21960       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 75, 60)       21960       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 75, 60)       21960       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 75, 120)      480         gru_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 75, 120)      480         gru_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 75, 120)      480         gru_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 75, 120)      480         gru_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 75, 120)      480         gru_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 75, 120)      480         gru_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 75, 120)      480         gru_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 75, 60)       240         gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 75, 60)       240         gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 75, 60)       240         gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 75, 120)      0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 75, 1020)     0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
#                                                                  leaky_re_lu_47[0][0]
#                                                                  leaky_re_lu_53[0][0]
#                                                                  leaky_re_lu_29[0][0]
#                                                                  leaky_re_lu_59[0][0]
#                                                                  leaky_re_lu_11[0][0]
#                                                                  leaky_re_lu_23[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 75, 60)       550860      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 75, 60)       240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 75, 120)      480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 75, 60)       240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 75, 60)       1101660     concatenate_10[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 75, 60)       0           leaky_re_lu_62[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 75, 60)       240         add[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 75, 60)       32460       batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 75, 60)       240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 75, 120)      480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 75, 60)       240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 75, 60)       0           leaky_re_lu_65[0][0]
#                                                                  batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 75, 60)       240         add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 75, 60)       32460       batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 75, 60)       240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 75, 120)      480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 75, 60)       240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 75, 60)       0           leaky_re_lu_68[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 75, 60)       240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 4,841,391
# Trainable params: 4,830,411
# Non-trainable params: 10,980
# __________________________________________________________________________________________________

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 4,verbose = 1,factor = 0.5) 

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=0))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 73s 697ms/step - loss: 26.2214 - accuracy: 0.4596 - val_loss: 19.5818 - val_accuracy: 0.1211
#
# Epoch 00001: val_loss improved from inf to 19.58178, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 13.4559 - accuracy: 0.6117 - val_loss: 11.7676 - val_accuracy: 0.0352
#
# Epoch 00002: val_loss improved from 19.58178 to 11.76757, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 7.5191 - accuracy: 0.6705 - val_loss: 7.7347 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 11.76757 to 7.73474, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 4.7187 - accuracy: 0.6664 - val_loss: 5.6158 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 7.73474 to 5.61580, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 3.2260 - accuracy: 0.6792 - val_loss: 4.7597 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 5.61580 to 4.75974, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 2.3655 - accuracy: 0.7040 - val_loss: 4.2665 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 4.75974 to 4.26649, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 1.8882 - accuracy: 0.7210 - val_loss: 4.7044 - val_accuracy: 0.0625
#
# Epoch 00007: val_loss did not improve from 4.26649
# Epoch 8/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 1.6274 - accuracy: 0.7385 - val_loss: 4.6980 - val_accuracy: 0.4492
#
# Epoch 00008: val_loss did not improve from 4.26649
# Epoch 9/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 1.4050 - accuracy: 0.7665 - val_loss: 3.5883 - val_accuracy: 0.4414
#
# Epoch 00009: val_loss improved from 4.26649 to 3.58835, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 1.3834 - accuracy: 0.7436 - val_loss: 4.1191 - val_accuracy: 0.4336
#
# Epoch 00010: val_loss did not improve from 3.58835
# Epoch 11/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 1.3180 - accuracy: 0.7642 - val_loss: 3.2980 - val_accuracy: 0.4805
#
# Epoch 00011: val_loss improved from 3.58835 to 3.29805, saving model to ./save/cnn_gru_best.hdf5
# Epoch 12/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 1.2734 - accuracy: 0.7601 - val_loss: 3.4623 - val_accuracy: 0.5117
#
# Epoch 00012: val_loss did not improve from 3.29805
# Epoch 13/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 1.1738 - accuracy: 0.7858 - val_loss: 2.5135 - val_accuracy: 0.5469
#
# Epoch 00013: val_loss improved from 3.29805 to 2.51354, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 1.1479 - accuracy: 0.7790 - val_loss: 2.2783 - val_accuracy: 0.5703
#
# Epoch 00014: val_loss improved from 2.51354 to 2.27829, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 1.1911 - accuracy: 0.7642 - val_loss: 2.2787 - val_accuracy: 0.5781
#
# Epoch 00015: val_loss did not improve from 2.27829
# Epoch 16/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 1.1384 - accuracy: 0.7803 - val_loss: 1.9846 - val_accuracy: 0.5938
#
# Epoch 00016: val_loss improved from 2.27829 to 1.98458, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 1.1006 - accuracy: 0.7748 - val_loss: 1.9665 - val_accuracy: 0.6211
#
# Epoch 00017: val_loss improved from 1.98458 to 1.96649, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 1.0363 - accuracy: 0.8019 - val_loss: 1.9163 - val_accuracy: 0.6289
#
# Epoch 00018: val_loss improved from 1.96649 to 1.91628, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.9326 - accuracy: 0.8387 - val_loss: 3.8631 - val_accuracy: 0.3594
#
# Epoch 00019: val_loss did not improve from 1.91628
# Epoch 20/2000
# 34/34 [==============================] - 16s 461ms/step - loss: 1.0730 - accuracy: 0.7923 - val_loss: 7.8210 - val_accuracy: 0.1016
#
# Epoch 00020: val_loss did not improve from 1.91628
# Epoch 21/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 1.0025 - accuracy: 0.8006 - val_loss: 2.9941 - val_accuracy: 0.3320
#
# Epoch 00021: val_loss did not improve from 1.91628
# Epoch 22/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.9917 - accuracy: 0.8162 - val_loss: 2.4871 - val_accuracy: 0.5039
#
# Epoch 00022: val_loss did not improve from 1.91628
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.8049 - accuracy: 0.8575 - val_loss: 1.6070 - val_accuracy: 0.6875
#
# Epoch 00023: val_loss improved from 1.91628 to 1.60701, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.6578 - accuracy: 0.8699 - val_loss: 1.5764 - val_accuracy: 0.6289
#
# Epoch 00024: val_loss improved from 1.60701 to 1.57642, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.6513 - accuracy: 0.8686 - val_loss: 1.9752 - val_accuracy: 0.5586
#
# Epoch 00025: val_loss did not improve from 1.57642
# Epoch 26/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.6325 - accuracy: 0.8741 - val_loss: 1.3448 - val_accuracy: 0.7148
#
# Epoch 00026: val_loss improved from 1.57642 to 1.34480, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.6223 - accuracy: 0.8787 - val_loss: 1.2076 - val_accuracy: 0.7148
#
# Epoch 00027: val_loss improved from 1.34480 to 1.20762, saving model to ./save/cnn_gru_best.hdf5
# Epoch 28/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.6330 - accuracy: 0.8713 - val_loss: 1.9189 - val_accuracy: 0.6250
#
# Epoch 00028: val_loss did not improve from 1.20762
# Epoch 29/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.6420 - accuracy: 0.8768 - val_loss: 1.0819 - val_accuracy: 0.7773
#
# Epoch 00029: val_loss improved from 1.20762 to 1.08190, saving model to ./save/cnn_gru_best.hdf5
# Epoch 30/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.5578 - accuracy: 0.8989 - val_loss: 1.5136 - val_accuracy: 0.6562
#
# Epoch 00030: val_loss did not improve from 1.08190
# Epoch 31/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.5632 - accuracy: 0.8943 - val_loss: 1.3776 - val_accuracy: 0.7188
#
# Epoch 00031: val_loss did not improve from 1.08190
# Epoch 32/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.5406 - accuracy: 0.8957 - val_loss: 1.5913 - val_accuracy: 0.6797
#
# Epoch 00032: val_loss did not improve from 1.08190
# Epoch 33/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.5708 - accuracy: 0.8842 - val_loss: 1.3640 - val_accuracy: 0.7266
#
# Epoch 00033: val_loss did not improve from 1.08190
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 34/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.4867 - accuracy: 0.9127 - val_loss: 1.1633 - val_accuracy: 0.7188
#
# Epoch 00034: val_loss did not improve from 1.08190
# Epoch 35/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.4457 - accuracy: 0.9191 - val_loss: 1.1263 - val_accuracy: 0.6797
#
# Epoch 00035: val_loss did not improve from 1.08190
# Epoch 36/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.4324 - accuracy: 0.9090 - val_loss: 1.1548 - val_accuracy: 0.7109
#
# Epoch 00036: val_loss did not improve from 1.08190
# Epoch 37/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.3815 - accuracy: 0.9269 - val_loss: 1.1592 - val_accuracy: 0.7031
#
# Epoch 00037: val_loss did not improve from 1.08190
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 38/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.3225 - accuracy: 0.9426 - val_loss: 1.0655 - val_accuracy: 0.7656
#
# Epoch 00038: val_loss improved from 1.08190 to 1.06552, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.3121 - accuracy: 0.9407 - val_loss: 1.0830 - val_accuracy: 0.7578
#
# Epoch 00039: val_loss did not improve from 1.06552
# Epoch 40/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.3023 - accuracy: 0.9435 - val_loss: 1.0264 - val_accuracy: 0.7617
#
# Epoch 00040: val_loss improved from 1.06552 to 1.02635, saving model to ./save/cnn_gru_best.hdf5
# Epoch 41/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.2777 - accuracy: 0.9499 - val_loss: 0.9365 - val_accuracy: 0.7539
#
# Epoch 00041: val_loss improved from 1.02635 to 0.93651, saving model to ./save/cnn_gru_best.hdf5
# Epoch 42/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.3030 - accuracy: 0.9416 - val_loss: 1.1439 - val_accuracy: 0.7695
#
# Epoch 00042: val_loss did not improve from 0.93651
# Epoch 43/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.2948 - accuracy: 0.9439 - val_loss: 1.1853 - val_accuracy: 0.7852
#
# Epoch 00043: val_loss did not improve from 0.93651
# Epoch 44/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.2315 - accuracy: 0.9605 - val_loss: 0.8825 - val_accuracy: 0.8125
#
# Epoch 00044: val_loss improved from 0.93651 to 0.88248, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.2971 - accuracy: 0.9375 - val_loss: 0.9505 - val_accuracy: 0.7812
#
# Epoch 00045: val_loss did not improve from 0.88248
# Epoch 46/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.2001 - accuracy: 0.9738 - val_loss: 0.8566 - val_accuracy: 0.7852
#
# Epoch 00046: val_loss improved from 0.88248 to 0.85662, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.2496 - accuracy: 0.9540 - val_loss: 0.8267 - val_accuracy: 0.8164
#
# Epoch 00047: val_loss improved from 0.85662 to 0.82673, saving model to ./save/cnn_gru_best.hdf5
# Epoch 48/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.2321 - accuracy: 0.9600 - val_loss: 0.7739 - val_accuracy: 0.8203
#
# Epoch 00048: val_loss improved from 0.82673 to 0.77389, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.3284 - accuracy: 0.9260 - val_loss: 0.8795 - val_accuracy: 0.8242
#
# Epoch 00049: val_loss did not improve from 0.77389
# Epoch 50/2000
# 34/34 [==============================] - 15s 439ms/step - loss: 0.2956 - accuracy: 0.9430 - val_loss: 0.9374 - val_accuracy: 0.7930
#
# Epoch 00050: val_loss did not improve from 0.77389
# Epoch 51/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.2301 - accuracy: 0.9646 - val_loss: 1.0628 - val_accuracy: 0.7734
#
# Epoch 00051: val_loss did not improve from 0.77389
# Epoch 52/2000
# 34/34 [==============================] - 15s 455ms/step - loss: 0.2419 - accuracy: 0.9563 - val_loss: 0.8758 - val_accuracy: 0.8125
#
# Epoch 00052: val_loss did not improve from 0.77389
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 53/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.2185 - accuracy: 0.9651 - val_loss: 0.7947 - val_accuracy: 0.8359
#
# Epoch 00053: val_loss did not improve from 0.77389
# Epoch 54/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.2372 - accuracy: 0.9554 - val_loss: 0.7812 - val_accuracy: 0.8438
#
# Epoch 00054: val_loss did not improve from 0.77389
# Epoch 55/2000
# 34/34 [==============================] - 15s 440ms/step - loss: 0.2060 - accuracy: 0.9660 - val_loss: 0.8374 - val_accuracy: 0.8242
#
# Epoch 00055: val_loss did not improve from 0.77389
# Epoch 56/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.2050 - accuracy: 0.9669 - val_loss: 0.7568 - val_accuracy: 0.8359
#
# Epoch 00056: val_loss improved from 0.77389 to 0.75676, saving model to ./save/cnn_gru_best.hdf5
# Epoch 57/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.1683 - accuracy: 0.9770 - val_loss: 0.7995 - val_accuracy: 0.8203
#
# Epoch 00057: val_loss did not improve from 0.75676
# Epoch 58/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1922 - accuracy: 0.9651 - val_loss: 0.9666 - val_accuracy: 0.7656
#
# Epoch 00058: val_loss did not improve from 0.75676
# Epoch 59/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.1824 - accuracy: 0.9715 - val_loss: 1.0162 - val_accuracy: 0.7578
#
# Epoch 00059: val_loss did not improve from 0.75676
# Epoch 60/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.1915 - accuracy: 0.9623 - val_loss: 0.9542 - val_accuracy: 0.7930
#
# Epoch 00060: val_loss did not improve from 0.75676
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 61/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.1898 - accuracy: 0.9669 - val_loss: 0.8332 - val_accuracy: 0.8086
#
# Epoch 00061: val_loss did not improve from 0.75676
# Epoch 62/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.1788 - accuracy: 0.9669 - val_loss: 0.7941 - val_accuracy: 0.8047
#
# Epoch 00062: val_loss did not improve from 0.75676
# Epoch 63/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.1456 - accuracy: 0.9825 - val_loss: 0.7914 - val_accuracy: 0.8164
#
# Epoch 00063: val_loss did not improve from 0.75676
# Epoch 64/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.1596 - accuracy: 0.9715 - val_loss: 0.7073 - val_accuracy: 0.8438
#
# Epoch 00064: val_loss improved from 0.75676 to 0.70733, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.1378 - accuracy: 0.9821 - val_loss: 0.7419 - val_accuracy: 0.8398
#
# Epoch 00065: val_loss did not improve from 0.70733
# Epoch 66/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1517 - accuracy: 0.9733 - val_loss: 0.7506 - val_accuracy: 0.8477
#
# Epoch 00066: val_loss did not improve from 0.70733
# Epoch 67/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.1254 - accuracy: 0.9835 - val_loss: 0.7026 - val_accuracy: 0.8672
#
# Epoch 00067: val_loss improved from 0.70733 to 0.70261, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.1371 - accuracy: 0.9770 - val_loss: 0.7366 - val_accuracy: 0.8398
#
# Epoch 00068: val_loss did not improve from 0.70261
# Epoch 69/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.1496 - accuracy: 0.9724 - val_loss: 0.7134 - val_accuracy: 0.8555
#
# Epoch 00069: val_loss did not improve from 0.70261
# Epoch 70/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.1550 - accuracy: 0.9766 - val_loss: 0.7563 - val_accuracy: 0.8516
#
# Epoch 00070: val_loss did not improve from 0.70261
# Epoch 71/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.1569 - accuracy: 0.9729 - val_loss: 0.7473 - val_accuracy: 0.8516
#
# Epoch 00071: val_loss did not improve from 0.70261
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 72/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1463 - accuracy: 0.9761 - val_loss: 0.7792 - val_accuracy: 0.8398
#
# Epoch 00072: val_loss did not improve from 0.70261
# Epoch 73/2000
# 34/34 [==============================] - 15s 440ms/step - loss: 0.1487 - accuracy: 0.9724 - val_loss: 0.7401 - val_accuracy: 0.8555
#
# Epoch 00073: val_loss did not improve from 0.70261
# Epoch 74/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.1397 - accuracy: 0.9779 - val_loss: 0.7727 - val_accuracy: 0.8555
#
# Epoch 00074: val_loss did not improve from 0.70261
# Epoch 75/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.1155 - accuracy: 0.9825 - val_loss: 0.7367 - val_accuracy: 0.8672
#
# Epoch 00075: val_loss did not improve from 0.70261
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 76/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.1301 - accuracy: 0.9793 - val_loss: 0.7014 - val_accuracy: 0.8594
#
# Epoch 00076: val_loss improved from 0.70261 to 0.70142, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.1131 - accuracy: 0.9853 - val_loss: 0.7055 - val_accuracy: 0.8633
#
# Epoch 00077: val_loss did not improve from 0.70142
# Epoch 78/2000
# 34/34 [==============================] - 16s 458ms/step - loss: 0.1125 - accuracy: 0.9867 - val_loss: 0.7131 - val_accuracy: 0.8594
#
# Epoch 00078: val_loss did not improve from 0.70142
# Epoch 79/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.1490 - accuracy: 0.9724 - val_loss: 0.7573 - val_accuracy: 0.8594
#
# Epoch 00079: val_loss did not improve from 0.70142
# Epoch 80/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.1291 - accuracy: 0.9770 - val_loss: 0.7539 - val_accuracy: 0.8477
#
# Epoch 00080: val_loss did not improve from 0.70142
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 81/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.1303 - accuracy: 0.9793 - val_loss: 0.7064 - val_accuracy: 0.8633
#
# Epoch 00081: val_loss did not improve from 0.70142
# Epoch 82/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.1163 - accuracy: 0.9821 - val_loss: 0.6717 - val_accuracy: 0.8633
#
# Epoch 00082: val_loss improved from 0.70142 to 0.67167, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.0950 - accuracy: 0.9917 - val_loss: 0.7260 - val_accuracy: 0.8594
#
# Epoch 00083: val_loss did not improve from 0.67167
# Epoch 84/2000
# 34/34 [==============================] - 15s 440ms/step - loss: 0.1034 - accuracy: 0.9881 - val_loss: 0.7380 - val_accuracy: 0.8477
#
# Epoch 00084: val_loss did not improve from 0.67167
# Epoch 85/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.0977 - accuracy: 0.9894 - val_loss: 0.7475 - val_accuracy: 0.8555
#
# Epoch 00085: val_loss did not improve from 0.67167
# Epoch 86/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.0876 - accuracy: 0.9926 - val_loss: 0.7294 - val_accuracy: 0.8555
#
# Epoch 00086: val_loss did not improve from 0.67167
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 87/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.1399 - accuracy: 0.9756 - val_loss: 0.7393 - val_accuracy: 0.8555
#
# Epoch 00087: val_loss did not improve from 0.67167
# Epoch 88/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.1240 - accuracy: 0.9789 - val_loss: 0.7515 - val_accuracy: 0.8516
#
# Epoch 00088: val_loss did not improve from 0.67167
# Epoch 89/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.1115 - accuracy: 0.9844 - val_loss: 0.7219 - val_accuracy: 0.8633
#
# Epoch 00089: val_loss did not improve from 0.67167
# Epoch 90/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.1115 - accuracy: 0.9848 - val_loss: 0.7258 - val_accuracy: 0.8633
#
# Epoch 00090: val_loss did not improve from 0.67167
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 91/2000
# 34/34 [==============================] - 16s 457ms/step - loss: 0.1207 - accuracy: 0.9793 - val_loss: 0.7218 - val_accuracy: 0.8516
#
# Epoch 00091: val_loss did not improve from 0.67167
# Epoch 92/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.1059 - accuracy: 0.9876 - val_loss: 0.7157 - val_accuracy: 0.8594
#
# Epoch 00092: val_loss did not improve from 0.67167
# Epoch 93/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1277 - accuracy: 0.9812 - val_loss: 0.7024 - val_accuracy: 0.8672
#
# Epoch 00093: val_loss did not improve from 0.67167
# Epoch 94/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.0972 - accuracy: 0.9871 - val_loss: 0.7509 - val_accuracy: 0.8477
#
# Epoch 00094: val_loss did not improve from 0.67167
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 95/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.1067 - accuracy: 0.9867 - val_loss: 0.7434 - val_accuracy: 0.8477
#
# Epoch 00095: val_loss did not improve from 0.67167
# Epoch 96/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.1186 - accuracy: 0.9802 - val_loss: 0.6913 - val_accuracy: 0.8516
#
# Epoch 00096: val_loss did not improve from 0.67167
# Epoch 97/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1410 - accuracy: 0.9770 - val_loss: 0.7712 - val_accuracy: 0.8516
#
# Epoch 00097: val_loss did not improve from 0.67167
# Epoch 98/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.1089 - accuracy: 0.9853 - val_loss: 0.7094 - val_accuracy: 0.8672
#
# Epoch 00098: val_loss did not improve from 0.67167
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 99/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.1269 - accuracy: 0.9816 - val_loss: 0.7093 - val_accuracy: 0.8672
#
# Epoch 00099: val_loss did not improve from 0.67167
# Epoch 100/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.1001 - accuracy: 0.9876 - val_loss: 0.6906 - val_accuracy: 0.8594
#
# Epoch 00100: val_loss did not improve from 0.67167
# Epoch 101/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.1080 - accuracy: 0.9853 - val_loss: 0.7526 - val_accuracy: 0.8516
#
# Epoch 00101: val_loss did not improve from 0.67167
# Epoch 102/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.1164 - accuracy: 0.9848 - val_loss: 0.7083 - val_accuracy: 0.8555
#
# Epoch 00102: val_loss did not improve from 0.67167
#
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 103/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.1186 - accuracy: 0.9839 - val_loss: 0.7295 - val_accuracy: 0.8555
#
# Epoch 00103: val_loss did not improve from 0.67167
# Epoch 104/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.1035 - accuracy: 0.9862 - val_loss: 0.7254 - val_accuracy: 0.8477
#
# Epoch 00104: val_loss did not improve from 0.67167
# Epoch 105/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1174 - accuracy: 0.9844 - val_loss: 0.7225 - val_accuracy: 0.8516
#
# Epoch 00105: val_loss did not improve from 0.67167
# Epoch 106/2000
# 34/34 [==============================] - 16s 456ms/step - loss: 0.1128 - accuracy: 0.9821 - val_loss: 0.6437 - val_accuracy: 0.8633
#
# Epoch 00106: val_loss improved from 0.67167 to 0.64368, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.0946 - accuracy: 0.9922 - val_loss: 0.6439 - val_accuracy: 0.8594
#
# Epoch 00107: val_loss did not improve from 0.64368
# Epoch 108/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.1055 - accuracy: 0.9881 - val_loss: 0.6728 - val_accuracy: 0.8594
#
# Epoch 00108: val_loss did not improve from 0.64368
# Epoch 109/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.1173 - accuracy: 0.9853 - val_loss: 0.6451 - val_accuracy: 0.8594
#
# Epoch 00109: val_loss did not improve from 0.64368
# Epoch 110/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.1127 - accuracy: 0.9830 - val_loss: 0.7155 - val_accuracy: 0.8477
#
# Epoch 00110: val_loss did not improve from 0.64368
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 111/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 0.1356 - accuracy: 0.9789 - val_loss: 0.7304 - val_accuracy: 0.8633
#
# Epoch 00111: val_loss did not improve from 0.64368
# Epoch 112/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.1059 - accuracy: 0.9862 - val_loss: 0.7509 - val_accuracy: 0.8516
#
# Epoch 00112: val_loss did not improve from 0.64368
# Epoch 113/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.1134 - accuracy: 0.9858 - val_loss: 0.7159 - val_accuracy: 0.8633
#
# Epoch 00113: val_loss did not improve from 0.64368
# Epoch 114/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1256 - accuracy: 0.9789 - val_loss: 0.7398 - val_accuracy: 0.8672
#
# Epoch 00114: val_loss did not improve from 0.64368
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 115/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.1157 - accuracy: 0.9844 - val_loss: 0.6992 - val_accuracy: 0.8555
#
# Epoch 00115: val_loss did not improve from 0.64368
# Epoch 116/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.1129 - accuracy: 0.9807 - val_loss: 0.7332 - val_accuracy: 0.8555
#
# Epoch 00116: val_loss did not improve from 0.64368
# Epoch 117/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.1224 - accuracy: 0.9789 - val_loss: 0.7367 - val_accuracy: 0.8555
#
# Epoch 00117: val_loss did not improve from 0.64368
# Epoch 118/2000
# 34/34 [==============================] - 15s 438ms/step - loss: 0.1058 - accuracy: 0.9894 - val_loss: 0.7299 - val_accuracy: 0.8516
#
# Epoch 00118: val_loss did not improve from 0.64368
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 119/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.1101 - accuracy: 0.9871 - val_loss: 0.7606 - val_accuracy: 0.8477
#
# Epoch 00119: val_loss did not improve from 0.64368
# Epoch 120/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.1260 - accuracy: 0.9789 - val_loss: 0.7730 - val_accuracy: 0.8555
#
# Epoch 00120: val_loss did not improve from 0.64368
# Epoch 121/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.1284 - accuracy: 0.9802 - val_loss: 0.7537 - val_accuracy: 0.8516
#
# Epoch 00121: val_loss did not improve from 0.64368
# Epoch 122/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.0934 - accuracy: 0.9903 - val_loss: 0.7275 - val_accuracy: 0.8672
#
# Epoch 00122: val_loss did not improve from 0.64368
#
# Epoch 00122: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 123/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.1168 - accuracy: 0.9821 - val_loss: 0.7319 - val_accuracy: 0.8633
#
# Epoch 00123: val_loss did not improve from 0.64368
# Epoch 124/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.1205 - accuracy: 0.9835 - val_loss: 0.7520 - val_accuracy: 0.8555
#
# Epoch 00124: val_loss did not improve from 0.64368
# Epoch 125/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.1162 - accuracy: 0.9816 - val_loss: 0.7662 - val_accuracy: 0.8594
#
# Epoch 00125: val_loss did not improve from 0.64368
# Epoch 126/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.1076 - accuracy: 0.9862 - val_loss: 0.7614 - val_accuracy: 0.8555
#
# Epoch 00126: val_loss did not improve from 0.64368
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 127/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.1349 - accuracy: 0.9770 - val_loss: 0.7397 - val_accuracy: 0.8633
#
# Epoch 00127: val_loss did not improve from 0.64368
# Epoch 128/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.1047 - accuracy: 0.9871 - val_loss: 0.6938 - val_accuracy: 0.8594
#
# Epoch 00128: val_loss did not improve from 0.64368
# Epoch 129/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.1133 - accuracy: 0.9844 - val_loss: 0.7632 - val_accuracy: 0.8477
#
# Epoch 00129: val_loss did not improve from 0.64368
# Epoch 130/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.0990 - accuracy: 0.9890 - val_loss: 0.7625 - val_accuracy: 0.8438
#
# Epoch 00130: val_loss did not improve from 0.64368
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 131/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.1127 - accuracy: 0.9807 - val_loss: 0.7432 - val_accuracy: 0.8516
#
# Epoch 00131: val_loss did not improve from 0.64368
# Epoch 132/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.1200 - accuracy: 0.9812 - val_loss: 0.7350 - val_accuracy: 0.8633
#
# Epoch 00132: val_loss did not improve from 0.64368
# Epoch 133/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.1173 - accuracy: 0.9816 - val_loss: 0.7470 - val_accuracy: 0.8516
#
# Epoch 00133: val_loss did not improve from 0.64368
# Epoch 134/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 0.1274 - accuracy: 0.9779 - val_loss: 0.7286 - val_accuracy: 0.8594
#
# Epoch 00134: val_loss did not improve from 0.64368
#
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 135/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.1130 - accuracy: 0.9825 - val_loss: 0.7310 - val_accuracy: 0.8516
#
# Epoch 00135: val_loss did not improve from 0.64368
# Epoch 136/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.1192 - accuracy: 0.9848 - val_loss: 0.7451 - val_accuracy: 0.8516
#
# Epoch 00136: val_loss did not improve from 0.64368
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5733 - accuracy: 0.8720
# [0.5732976794242859, 0.871999979019165]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
