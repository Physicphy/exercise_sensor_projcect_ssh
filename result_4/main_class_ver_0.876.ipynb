# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset#, class_weight_dict
from my_model_class import CNN_RNN_Resnet

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = CNN_RNN_Resnet(
    leakyrelu_alpha = 0.1, #-0.2, #-0.1#, #0.05#, #0.1#, 0.2
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    input_regularize_coeff=0.001,
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.1, # #0.01#, #0.02#, 0.1, 0.2
    res_num = 5 # ##3##, #5#, 7, 9, 11, 13
    )(lr = 0.001,seed=42)

model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 600, 8)       0           input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 300, 20)      1460        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 300, 20)      2900        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 300, 10)      1810        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 300, 10)      1810        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          conv1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 300, 20)      80          conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 300, 20)      80          conv1d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 300, 20)      80          conv1d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          conv1d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 300, 20)      80          conv1d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 300, 10)      40          conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 300, 10)      40          conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 300, 10)      40          conv1d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 300, 10)      0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 300, 10)      0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 300, 10)      0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# gru_18 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# gru_24 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# gru_27 (GRU)                    (None, 300, 40)      7440        leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 300, 20)      1920        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 300, 20)      1920        leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# gru_15 (GRU)                    (None, 300, 20)      1920        leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         gru[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         gru_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 300, 40)      160         gru_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 300, 40)      160         gru_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 300, 40)      160         gru_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         gru_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 300, 40)      160         gru_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 300, 20)      80          gru_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 300, 20)      80          gru_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 300, 20)      80          gru_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 300, 40)      0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 300, 20)      0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 300, 20)      0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     43320       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     43320       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 120)     43320       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 150, 60)      21660       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 150, 120)     480         conv1d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 150, 120)     480         conv1d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 120)     480         conv1d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 120)     480         conv1d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 150, 60)      240         conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 150, 60)      240         conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 150, 60)      240         conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 150, 60)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# gru_19 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# gru_22 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# gru_25 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# gru_28 (GRU)                    (None, 150, 120)     87120       leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 150, 60)      21960       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 150, 60)      21960       leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 150, 60)      21960       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         gru_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         gru_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 150, 120)     480         gru_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 150, 120)     480         gru_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 120)     480         gru_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         gru_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 120)     480         gru_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 150, 60)      240         gru_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 150, 60)      240         gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 150, 60)      240         gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 150, 60)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 75, 120)      129720      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 75, 120)      129720      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 75, 120)      129720      leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 75, 60)       64860       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 75, 60)       64860       leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 75, 60)       64860       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 120)      480         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 75, 120)      480         conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 75, 120)      480         conv1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 75, 120)      480         conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 75, 120)      480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 75, 120)      480         conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 75, 120)      480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 75, 60)       240         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 75, 60)       240         conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 75, 60)       240         conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 75, 120)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 75, 120)      87120       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 75, 120)      87120       leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# gru_23 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# gru_26 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# gru_14 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# gru_29 (GRU)                    (None, 75, 120)      87120       leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 75, 60)       21960       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 75, 60)       21960       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 75, 60)       21960       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 75, 120)      480         gru_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 75, 120)      480         gru_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 75, 120)      480         gru_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 75, 120)      480         gru_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 75, 120)      480         gru_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 75, 120)      480         gru_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 75, 120)      480         gru_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 75, 60)       240         gru_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 75, 60)       240         gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 75, 60)       240         gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 75, 120)      0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 75, 1020)     0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
#                                                                  leaky_re_lu_47[0][0]
#                                                                  leaky_re_lu_53[0][0]
#                                                                  leaky_re_lu_29[0][0]
#                                                                  leaky_re_lu_59[0][0]
#                                                                  leaky_re_lu_11[0][0]
#                                                                  leaky_re_lu_23[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 75, 60)       550860      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 75, 60)       240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 75, 120)      480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 75, 60)       240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 75, 60)       1101660     concatenate_10[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 75, 60)       0           leaky_re_lu_62[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 75, 60)       240         add[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 75, 60)       32460       batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 75, 60)       240         conv1d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 75, 120)      480         conv1d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 75, 60)       240         conv1d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 75, 60)       0           leaky_re_lu_65[0][0]
#                                                                  batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 75, 60)       240         add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 75, 60)       32460       batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 75, 60)       240         conv1d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 75, 120)      480         conv1d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 75, 60)       240         conv1d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 75, 60)       0           leaky_re_lu_68[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 75, 60)       240         add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 75, 60)       32460       batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 75, 60)       240         conv1d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 75, 120)      480         conv1d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 75, 60)       240         conv1d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 75, 60)       0           leaky_re_lu_71[0][0]
#                                                                  batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 75, 60)       240         add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 75, 60)       32460       batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 75, 60)       240         conv1d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 75, 120)      43320       leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 75, 120)      480         conv1d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 75, 120)      0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 75, 60)       21660       leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 75, 60)       240         conv1d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 75, 60)       0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 75, 60)       0           leaky_re_lu_74[0][0]
#                                                                  batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 75, 60)       240         add_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 5,038,671
# Trainable params: 5,026,491
# Non-trainable params: 12,180
# __________________________________________________________________________________________________

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 4,verbose = 1,factor = 0.5) 

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=0))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 74s 698ms/step - loss: 181.6832 - accuracy: 0.4118 - val_loss: 112.6830 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 112.68304, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 76.8271 - accuracy: 0.5620 - val_loss: 50.6206 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 112.68304 to 50.62063, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 34.5825 - accuracy: 0.6016 - val_loss: 25.1548 - val_accuracy: 0.4570
#
# Epoch 00003: val_loss improved from 50.62063 to 25.15475, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 17.7065 - accuracy: 0.6075 - val_loss: 14.7098 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 25.15475 to 14.70978, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 10.9498 - accuracy: 0.6006 - val_loss: 10.6072 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 14.70978 to 10.60721, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 7.9615 - accuracy: 0.6167 - val_loss: 8.6513 - val_accuracy: 0.4570
#
# Epoch 00006: val_loss improved from 10.60721 to 8.65128, saving model to ./save/cnn_gru_best.hdf5
# Epoch 7/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 6.4709 - accuracy: 0.6278 - val_loss: 7.6229 - val_accuracy: 0.4492
#
# Epoch 00007: val_loss improved from 8.65128 to 7.62286, saving model to ./save/cnn_gru_best.hdf5
# Epoch 8/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 5.5057 - accuracy: 0.6659 - val_loss: 7.0424 - val_accuracy: 0.4531
#
# Epoch 00008: val_loss improved from 7.62286 to 7.04243, saving model to ./save/cnn_gru_best.hdf5
# Epoch 9/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 4.9420 - accuracy: 0.6517 - val_loss: 6.8175 - val_accuracy: 0.1797
#
# Epoch 00009: val_loss improved from 7.04243 to 6.81750, saving model to ./save/cnn_gru_best.hdf5
# Epoch 10/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 4.5905 - accuracy: 0.6576 - val_loss: 6.8042 - val_accuracy: 0.2188
#
# Epoch 00010: val_loss improved from 6.81750 to 6.80417, saving model to ./save/cnn_gru_best.hdf5
# Epoch 11/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 4.2070 - accuracy: 0.6627 - val_loss: 6.9467 - val_accuracy: 0.0898
#
# Epoch 00011: val_loss did not improve from 6.80417
# Epoch 12/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 3.9097 - accuracy: 0.6498 - val_loss: 5.1450 - val_accuracy: 0.4688
#
# Epoch 00012: val_loss improved from 6.80417 to 5.14499, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 3.6033 - accuracy: 0.6673 - val_loss: 4.6080 - val_accuracy: 0.4922
#
# Epoch 00013: val_loss improved from 5.14499 to 4.60799, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 3.3079 - accuracy: 0.6847 - val_loss: 8.9080 - val_accuracy: 0.0508
#
# Epoch 00014: val_loss did not improve from 4.60799
# Epoch 15/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 3.2232 - accuracy: 0.6760 - val_loss: 4.2272 - val_accuracy: 0.5078
#
# Epoch 00015: val_loss improved from 4.60799 to 4.22724, saving model to ./save/cnn_gru_best.hdf5
# Epoch 16/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 3.0453 - accuracy: 0.6824 - val_loss: 11.8695 - val_accuracy: 0.0547
#
# Epoch 00016: val_loss did not improve from 4.22724
# Epoch 17/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 2.8807 - accuracy: 0.6972 - val_loss: 4.0154 - val_accuracy: 0.4609
#
# Epoch 00017: val_loss improved from 4.22724 to 4.01541, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 2.7160 - accuracy: 0.7165 - val_loss: 4.0485 - val_accuracy: 0.4922
#
# Epoch 00018: val_loss did not improve from 4.01541
# Epoch 19/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 2.5505 - accuracy: 0.7238 - val_loss: 4.9945 - val_accuracy: 0.4648
#
# Epoch 00019: val_loss did not improve from 4.01541
# Epoch 20/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 2.5827 - accuracy: 0.7013 - val_loss: 4.1169 - val_accuracy: 0.4492
#
# Epoch 00020: val_loss did not improve from 4.01541
# Epoch 21/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 2.5006 - accuracy: 0.6926 - val_loss: 4.5135 - val_accuracy: 0.5273
#
# Epoch 00021: val_loss did not improve from 4.01541
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 2.2947 - accuracy: 0.7440 - val_loss: 3.1152 - val_accuracy: 0.5430
#
# Epoch 00022: val_loss improved from 4.01541 to 3.11524, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 1.9823 - accuracy: 0.7647 - val_loss: 2.7599 - val_accuracy: 0.5469
#
# Epoch 00023: val_loss improved from 3.11524 to 2.75993, saving model to ./save/cnn_gru_best.hdf5
# Epoch 24/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 1.8739 - accuracy: 0.7716 - val_loss: 2.6854 - val_accuracy: 0.5938
#
# Epoch 00024: val_loss improved from 2.75993 to 2.68539, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 1.8239 - accuracy: 0.7739 - val_loss: 2.4972 - val_accuracy: 0.6367
#
# Epoch 00025: val_loss improved from 2.68539 to 2.49722, saving model to ./save/cnn_gru_best.hdf5
# Epoch 26/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 1.8797 - accuracy: 0.7688 - val_loss: 2.3960 - val_accuracy: 0.6211
#
# Epoch 00026: val_loss improved from 2.49722 to 2.39597, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 1.7807 - accuracy: 0.7835 - val_loss: 2.7982 - val_accuracy: 0.5156
#
# Epoch 00027: val_loss did not improve from 2.39597
# Epoch 28/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 1.7676 - accuracy: 0.7812 - val_loss: 2.8316 - val_accuracy: 0.6133
#
# Epoch 00028: val_loss did not improve from 2.39597
# Epoch 29/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 1.7373 - accuracy: 0.7840 - val_loss: 2.7163 - val_accuracy: 0.5703
#
# Epoch 00029: val_loss did not improve from 2.39597
# Epoch 30/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 1.6522 - accuracy: 0.8001 - val_loss: 2.9431 - val_accuracy: 0.5586
#
# Epoch 00030: val_loss did not improve from 2.39597
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 31/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 1.5151 - accuracy: 0.8166 - val_loss: 2.4620 - val_accuracy: 0.5898
#
# Epoch 00031: val_loss did not improve from 2.39597
# Epoch 32/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 1.3837 - accuracy: 0.8369 - val_loss: 2.6069 - val_accuracy: 0.5859
#
# Epoch 00032: val_loss did not improve from 2.39597
# Epoch 33/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 1.3764 - accuracy: 0.8295 - val_loss: 2.0837 - val_accuracy: 0.6523
#
# Epoch 00033: val_loss improved from 2.39597 to 2.08370, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 1.3396 - accuracy: 0.8405 - val_loss: 2.6814 - val_accuracy: 0.5703
#
# Epoch 00034: val_loss did not improve from 2.08370
# Epoch 35/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 1.3674 - accuracy: 0.8304 - val_loss: 2.9907 - val_accuracy: 0.4570
#
# Epoch 00035: val_loss did not improve from 2.08370
# Epoch 36/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 1.3866 - accuracy: 0.8116 - val_loss: 2.9054 - val_accuracy: 0.4805
#
# Epoch 00036: val_loss did not improve from 2.08370
# Epoch 37/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 1.3014 - accuracy: 0.8465 - val_loss: 3.1398 - val_accuracy: 0.5000
#
# Epoch 00037: val_loss did not improve from 2.08370
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 38/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 1.2136 - accuracy: 0.8612 - val_loss: 2.3700 - val_accuracy: 0.6094
#
# Epoch 00038: val_loss did not improve from 2.08370
# Epoch 39/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 1.1520 - accuracy: 0.8644 - val_loss: 1.7079 - val_accuracy: 0.7109
#
# Epoch 00039: val_loss improved from 2.08370 to 1.70790, saving model to ./save/cnn_gru_best.hdf5
# Epoch 40/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 1.1316 - accuracy: 0.8764 - val_loss: 1.8004 - val_accuracy: 0.6914
#
# Epoch 00040: val_loss did not improve from 1.70790
# Epoch 41/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 1.1138 - accuracy: 0.8750 - val_loss: 1.7799 - val_accuracy: 0.6992
#
# Epoch 00041: val_loss did not improve from 1.70790
# Epoch 42/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 1.1605 - accuracy: 0.8497 - val_loss: 1.7759 - val_accuracy: 0.6836
#
# Epoch 00042: val_loss did not improve from 1.70790
# Epoch 43/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 1.1203 - accuracy: 0.8764 - val_loss: 1.7954 - val_accuracy: 0.6914
#
# Epoch 00043: val_loss did not improve from 1.70790
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 44/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.9940 - accuracy: 0.9081 - val_loss: 1.6008 - val_accuracy: 0.7383
#
# Epoch 00044: val_loss improved from 1.70790 to 1.60083, saving model to ./save/cnn_gru_best.hdf5
# Epoch 45/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 1.0354 - accuracy: 0.8819 - val_loss: 1.6858 - val_accuracy: 0.6992
#
# Epoch 00045: val_loss did not improve from 1.60083
# Epoch 46/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.9265 - accuracy: 0.9214 - val_loss: 1.5849 - val_accuracy: 0.7227
#
# Epoch 00046: val_loss improved from 1.60083 to 1.58486, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.9848 - accuracy: 0.8957 - val_loss: 1.6074 - val_accuracy: 0.7305
#
# Epoch 00047: val_loss did not improve from 1.58486
# Epoch 48/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.9343 - accuracy: 0.9191 - val_loss: 1.4428 - val_accuracy: 0.7734
#
# Epoch 00048: val_loss improved from 1.58486 to 1.44276, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 1.0443 - accuracy: 0.8727 - val_loss: 1.4543 - val_accuracy: 0.7656
#
# Epoch 00049: val_loss did not improve from 1.44276
# Epoch 50/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 1.0166 - accuracy: 0.8847 - val_loss: 1.4093 - val_accuracy: 0.7656
#
# Epoch 00050: val_loss improved from 1.44276 to 1.40928, saving model to ./save/cnn_gru_best.hdf5
# Epoch 51/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.9227 - accuracy: 0.9122 - val_loss: 1.4548 - val_accuracy: 0.7617
#
# Epoch 00051: val_loss did not improve from 1.40928
# Epoch 52/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.9315 - accuracy: 0.9072 - val_loss: 1.5041 - val_accuracy: 0.7578
#
# Epoch 00052: val_loss did not improve from 1.40928
# Epoch 53/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.9317 - accuracy: 0.9104 - val_loss: 1.6023 - val_accuracy: 0.7656
#
# Epoch 00053: val_loss did not improve from 1.40928
# Epoch 54/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.9618 - accuracy: 0.8980 - val_loss: 1.4485 - val_accuracy: 0.7930
#
# Epoch 00054: val_loss did not improve from 1.40928
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 55/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.9074 - accuracy: 0.9076 - val_loss: 1.3097 - val_accuracy: 0.7969
#
# Epoch 00055: val_loss improved from 1.40928 to 1.30970, saving model to ./save/cnn_gru_best.hdf5
# Epoch 56/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.8826 - accuracy: 0.9237 - val_loss: 1.2741 - val_accuracy: 0.8086
#
# Epoch 00056: val_loss improved from 1.30970 to 1.27413, saving model to ./save/cnn_gru_best.hdf5
# Epoch 57/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.8447 - accuracy: 0.9301 - val_loss: 1.3666 - val_accuracy: 0.7656
#
# Epoch 00057: val_loss did not improve from 1.27413
# Epoch 58/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.8698 - accuracy: 0.9196 - val_loss: 1.3216 - val_accuracy: 0.7734
#
# Epoch 00058: val_loss did not improve from 1.27413
# Epoch 59/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.8404 - accuracy: 0.9274 - val_loss: 1.3722 - val_accuracy: 0.7812
#
# Epoch 00059: val_loss did not improve from 1.27413
# Epoch 60/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.8669 - accuracy: 0.9154 - val_loss: 1.3867 - val_accuracy: 0.7734
#
# Epoch 00060: val_loss did not improve from 1.27413
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 61/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.8622 - accuracy: 0.9196 - val_loss: 1.2846 - val_accuracy: 0.7969
#
# Epoch 00061: val_loss did not improve from 1.27413
# Epoch 62/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.8444 - accuracy: 0.9242 - val_loss: 1.2503 - val_accuracy: 0.7969
#
# Epoch 00062: val_loss improved from 1.27413 to 1.25029, saving model to ./save/cnn_gru_best.hdf5
# Epoch 63/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7979 - accuracy: 0.9407 - val_loss: 1.3020 - val_accuracy: 0.7852
#
# Epoch 00063: val_loss did not improve from 1.25029
# Epoch 64/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.8233 - accuracy: 0.9265 - val_loss: 1.2365 - val_accuracy: 0.8125
#
# Epoch 00064: val_loss improved from 1.25029 to 1.23654, saving model to ./save/cnn_gru_best.hdf5
# Epoch 65/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7912 - accuracy: 0.9435 - val_loss: 1.2193 - val_accuracy: 0.8242
#
# Epoch 00065: val_loss improved from 1.23654 to 1.21931, saving model to ./save/cnn_gru_best.hdf5
# Epoch 66/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.8054 - accuracy: 0.9324 - val_loss: 1.2472 - val_accuracy: 0.8086
#
# Epoch 00066: val_loss did not improve from 1.21931
# Epoch 67/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.7746 - accuracy: 0.9435 - val_loss: 1.1704 - val_accuracy: 0.8398
#
# Epoch 00067: val_loss improved from 1.21931 to 1.17044, saving model to ./save/cnn_gru_best.hdf5
# Epoch 68/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.7819 - accuracy: 0.9421 - val_loss: 1.2353 - val_accuracy: 0.8047
#
# Epoch 00068: val_loss did not improve from 1.17044
# Epoch 69/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7808 - accuracy: 0.9370 - val_loss: 1.2406 - val_accuracy: 0.8164
#
# Epoch 00069: val_loss did not improve from 1.17044
# Epoch 70/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.8240 - accuracy: 0.9246 - val_loss: 1.2391 - val_accuracy: 0.8281
#
# Epoch 00070: val_loss did not improve from 1.17044
# Epoch 71/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.8045 - accuracy: 0.9338 - val_loss: 1.2077 - val_accuracy: 0.8242
#
# Epoch 00071: val_loss did not improve from 1.17044
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 72/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7737 - accuracy: 0.9407 - val_loss: 1.2011 - val_accuracy: 0.8477
#
# Epoch 00072: val_loss did not improve from 1.17044
# Epoch 73/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7753 - accuracy: 0.9412 - val_loss: 1.1864 - val_accuracy: 0.8203
#
# Epoch 00073: val_loss did not improve from 1.17044
# Epoch 74/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7716 - accuracy: 0.9435 - val_loss: 1.2220 - val_accuracy: 0.8281
#
# Epoch 00074: val_loss did not improve from 1.17044
# Epoch 75/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.7442 - accuracy: 0.9472 - val_loss: 1.1871 - val_accuracy: 0.8398
#
# Epoch 00075: val_loss did not improve from 1.17044
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 76/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.7602 - accuracy: 0.9430 - val_loss: 1.1712 - val_accuracy: 0.8398
#
# Epoch 00076: val_loss did not improve from 1.17044
# Epoch 77/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.7372 - accuracy: 0.9550 - val_loss: 1.1767 - val_accuracy: 0.8398
#
# Epoch 00077: val_loss did not improve from 1.17044
# Epoch 78/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.7334 - accuracy: 0.9568 - val_loss: 1.1724 - val_accuracy: 0.8359
#
# Epoch 00078: val_loss did not improve from 1.17044
# Epoch 79/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.7854 - accuracy: 0.9347 - val_loss: 1.2152 - val_accuracy: 0.8359
#
# Epoch 00079: val_loss did not improve from 1.17044
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 80/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.7431 - accuracy: 0.9513 - val_loss: 1.2087 - val_accuracy: 0.8359
#
# Epoch 00080: val_loss did not improve from 1.17044
# Epoch 81/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.7511 - accuracy: 0.9490 - val_loss: 1.1681 - val_accuracy: 0.8398
#
# Epoch 00081: val_loss improved from 1.17044 to 1.16814, saving model to ./save/cnn_gru_best.hdf5
# Epoch 82/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.7390 - accuracy: 0.9504 - val_loss: 1.1552 - val_accuracy: 0.8477
#
# Epoch 00082: val_loss improved from 1.16814 to 1.15522, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 0.6980 - accuracy: 0.9701 - val_loss: 1.1801 - val_accuracy: 0.8438
#
# Epoch 00083: val_loss did not improve from 1.15522
# Epoch 84/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.7180 - accuracy: 0.9614 - val_loss: 1.2092 - val_accuracy: 0.8555
#
# Epoch 00084: val_loss did not improve from 1.15522
# Epoch 85/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.7098 - accuracy: 0.9637 - val_loss: 1.1849 - val_accuracy: 0.8555
#
# Epoch 00085: val_loss did not improve from 1.15522
# Epoch 86/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.6975 - accuracy: 0.9678 - val_loss: 1.1810 - val_accuracy: 0.8477
#
# Epoch 00086: val_loss did not improve from 1.15522
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 87/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.7609 - accuracy: 0.9449 - val_loss: 1.1674 - val_accuracy: 0.8594
#
# Epoch 00087: val_loss did not improve from 1.15522
# Epoch 88/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7521 - accuracy: 0.9499 - val_loss: 1.2061 - val_accuracy: 0.8438
#
# Epoch 00088: val_loss did not improve from 1.15522
# Epoch 89/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.7344 - accuracy: 0.9517 - val_loss: 1.1810 - val_accuracy: 0.8438
#
# Epoch 00089: val_loss did not improve from 1.15522
# Epoch 90/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.7307 - accuracy: 0.9517 - val_loss: 1.1805 - val_accuracy: 0.8438
#
# Epoch 00090: val_loss did not improve from 1.15522
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 91/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7360 - accuracy: 0.9476 - val_loss: 1.1729 - val_accuracy: 0.8516
#
# Epoch 00091: val_loss did not improve from 1.15522
# Epoch 92/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7151 - accuracy: 0.9586 - val_loss: 1.1590 - val_accuracy: 0.8555
#
# Epoch 00092: val_loss did not improve from 1.15522
# Epoch 93/2000
# 34/34 [==============================] - 15s 454ms/step - loss: 0.7431 - accuracy: 0.9522 - val_loss: 1.1712 - val_accuracy: 0.8477
#
# Epoch 00093: val_loss did not improve from 1.15522
# Epoch 94/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.7074 - accuracy: 0.9651 - val_loss: 1.2036 - val_accuracy: 0.8516
#
# Epoch 00094: val_loss did not improve from 1.15522
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 95/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7238 - accuracy: 0.9577 - val_loss: 1.1778 - val_accuracy: 0.8516
#
# Epoch 00095: val_loss did not improve from 1.15522
# Epoch 96/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.7354 - accuracy: 0.9540 - val_loss: 1.1706 - val_accuracy: 0.8477
#
# Epoch 00096: val_loss did not improve from 1.15522
# Epoch 97/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.7499 - accuracy: 0.9540 - val_loss: 1.2186 - val_accuracy: 0.8438
#
# Epoch 00097: val_loss did not improve from 1.15522
# Epoch 98/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.7232 - accuracy: 0.9586 - val_loss: 1.1760 - val_accuracy: 0.8477
#
# Epoch 00098: val_loss did not improve from 1.15522
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 99/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.7523 - accuracy: 0.9527 - val_loss: 1.1480 - val_accuracy: 0.8594
#
# Epoch 00099: val_loss improved from 1.15522 to 1.14802, saving model to ./save/cnn_gru_best.hdf5
# Epoch 100/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 0.7030 - accuracy: 0.9655 - val_loss: 1.1456 - val_accuracy: 0.8594
#
# Epoch 00100: val_loss improved from 1.14802 to 1.14562, saving model to ./save/cnn_gru_best.hdf5
# Epoch 101/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7303 - accuracy: 0.9517 - val_loss: 1.2029 - val_accuracy: 0.8438
#
# Epoch 00101: val_loss did not improve from 1.14562
# Epoch 102/2000
# 34/34 [==============================] - 15s 440ms/step - loss: 0.7295 - accuracy: 0.9591 - val_loss: 1.1751 - val_accuracy: 0.8477
#
# Epoch 00102: val_loss did not improve from 1.14562
# Epoch 103/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7426 - accuracy: 0.9508 - val_loss: 1.1794 - val_accuracy: 0.8477
#
# Epoch 00103: val_loss did not improve from 1.14562
# Epoch 104/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.7070 - accuracy: 0.9655 - val_loss: 1.1835 - val_accuracy: 0.8516
#
# Epoch 00104: val_loss did not improve from 1.14562
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 105/2000
# 34/34 [==============================] - 15s 453ms/step - loss: 0.7323 - accuracy: 0.9550 - val_loss: 1.1711 - val_accuracy: 0.8555
#
# Epoch 00105: val_loss did not improve from 1.14562
# Epoch 106/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.7351 - accuracy: 0.9513 - val_loss: 1.1275 - val_accuracy: 0.8594
#
# Epoch 00106: val_loss improved from 1.14562 to 1.12745, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 15s 445ms/step - loss: 0.7099 - accuracy: 0.9628 - val_loss: 1.1297 - val_accuracy: 0.8633
#
# Epoch 00107: val_loss did not improve from 1.12745
# Epoch 108/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.7133 - accuracy: 0.9609 - val_loss: 1.1422 - val_accuracy: 0.8594
#
# Epoch 00108: val_loss did not improve from 1.12745
# Epoch 109/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7344 - accuracy: 0.9494 - val_loss: 1.1397 - val_accuracy: 0.8633
#
# Epoch 00109: val_loss did not improve from 1.12745
# Epoch 110/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.7204 - accuracy: 0.9591 - val_loss: 1.1707 - val_accuracy: 0.8594
#
# Epoch 00110: val_loss did not improve from 1.12745
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 111/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.7563 - accuracy: 0.9499 - val_loss: 1.1853 - val_accuracy: 0.8477
#
# Epoch 00111: val_loss did not improve from 1.12745
# Epoch 112/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.7118 - accuracy: 0.9628 - val_loss: 1.1945 - val_accuracy: 0.8516
#
# Epoch 00112: val_loss did not improve from 1.12745
# Epoch 113/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.7327 - accuracy: 0.9568 - val_loss: 1.1707 - val_accuracy: 0.8555
#
# Epoch 00113: val_loss did not improve from 1.12745
# Epoch 114/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7405 - accuracy: 0.9522 - val_loss: 1.1870 - val_accuracy: 0.8516
#
# Epoch 00114: val_loss did not improve from 1.12745
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 115/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 0.7202 - accuracy: 0.9605 - val_loss: 1.1749 - val_accuracy: 0.8477
#
# Epoch 00115: val_loss did not improve from 1.12745
# Epoch 116/2000
# 34/34 [==============================] - 15s 447ms/step - loss: 0.7368 - accuracy: 0.9554 - val_loss: 1.1796 - val_accuracy: 0.8555
#
# Epoch 00116: val_loss did not improve from 1.12745
# Epoch 117/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.7331 - accuracy: 0.9609 - val_loss: 1.1816 - val_accuracy: 0.8555
#
# Epoch 00117: val_loss did not improve from 1.12745
# Epoch 118/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.7177 - accuracy: 0.9600 - val_loss: 1.1777 - val_accuracy: 0.8516
#
# Epoch 00118: val_loss did not improve from 1.12745
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 119/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.7230 - accuracy: 0.9582 - val_loss: 1.2024 - val_accuracy: 0.8477
#
# Epoch 00119: val_loss did not improve from 1.12745
# Epoch 120/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.7534 - accuracy: 0.9407 - val_loss: 1.2156 - val_accuracy: 0.8359
#
# Epoch 00120: val_loss did not improve from 1.12745
# Epoch 121/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.7498 - accuracy: 0.9481 - val_loss: 1.1989 - val_accuracy: 0.8438
#
# Epoch 00121: val_loss did not improve from 1.12745
# Epoch 122/2000
# 34/34 [==============================] - 15s 443ms/step - loss: 0.7104 - accuracy: 0.9623 - val_loss: 1.1810 - val_accuracy: 0.8555
#
# Epoch 00122: val_loss did not improve from 1.12745
#
# Epoch 00122: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 123/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7354 - accuracy: 0.9536 - val_loss: 1.1908 - val_accuracy: 0.8477
#
# Epoch 00123: val_loss did not improve from 1.12745
# Epoch 124/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.7412 - accuracy: 0.9563 - val_loss: 1.1996 - val_accuracy: 0.8438
#
# Epoch 00124: val_loss did not improve from 1.12745
# Epoch 125/2000
# 34/34 [==============================] - 15s 450ms/step - loss: 0.7233 - accuracy: 0.9637 - val_loss: 1.2091 - val_accuracy: 0.8477
#
# Epoch 00125: val_loss did not improve from 1.12745
# Epoch 126/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 0.7319 - accuracy: 0.9517 - val_loss: 1.2026 - val_accuracy: 0.8477
#
# Epoch 00126: val_loss did not improve from 1.12745
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 127/2000
# 34/34 [==============================] - 15s 446ms/step - loss: 0.7627 - accuracy: 0.9444 - val_loss: 1.2000 - val_accuracy: 0.8477
#
# Epoch 00127: val_loss did not improve from 1.12745
# Epoch 128/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.7135 - accuracy: 0.9596 - val_loss: 1.1596 - val_accuracy: 0.8633
#
# Epoch 00128: val_loss did not improve from 1.12745
# Epoch 129/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.7362 - accuracy: 0.9522 - val_loss: 1.2109 - val_accuracy: 0.8438
#
# Epoch 00129: val_loss did not improve from 1.12745
# Epoch 130/2000
# 34/34 [==============================] - 15s 442ms/step - loss: 0.7046 - accuracy: 0.9665 - val_loss: 1.2074 - val_accuracy: 0.8477
#
# Epoch 00130: val_loss did not improve from 1.12745
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 131/2000
# 34/34 [==============================] - 15s 444ms/step - loss: 0.7231 - accuracy: 0.9536 - val_loss: 1.1987 - val_accuracy: 0.8555
#
# Epoch 00131: val_loss did not improve from 1.12745
# Epoch 132/2000
# 34/34 [==============================] - 15s 448ms/step - loss: 0.7269 - accuracy: 0.9554 - val_loss: 1.1791 - val_accuracy: 0.8555
#
# Epoch 00132: val_loss did not improve from 1.12745
# Epoch 133/2000
# 34/34 [==============================] - 15s 451ms/step - loss: 0.7427 - accuracy: 0.9531 - val_loss: 1.1852 - val_accuracy: 0.8555
#
# Epoch 00133: val_loss did not improve from 1.12745
# Epoch 134/2000
# 34/34 [==============================] - 15s 449ms/step - loss: 0.7419 - accuracy: 0.9517 - val_loss: 1.1777 - val_accuracy: 0.8555
#
# Epoch 00134: val_loss did not improve from 1.12745
#
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# Epoch 135/2000
# 34/34 [==============================] - 15s 441ms/step - loss: 0.7283 - accuracy: 0.9531 - val_loss: 1.1886 - val_accuracy: 0.8555
#
# Epoch 00135: val_loss did not improve from 1.12745
# Epoch 136/2000
# 34/34 [==============================] - 15s 452ms/step - loss: 0.7233 - accuracy: 0.9582 - val_loss: 1.1979 - val_accuracy: 0.8477
#
# Epoch 00136: val_loss did not improve from 1.12745
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 1.0083 - accuracy: 0.8768
# [1.0083423852920532, 0.876800000667572]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
