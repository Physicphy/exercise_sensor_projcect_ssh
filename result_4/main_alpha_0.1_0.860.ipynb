# %%
import numpy as np
import tensorflow as tf
import random as rn
from my_utils import Workout_dataset#, class_weight_dict
from my_model import make_CNN_RNN_model

import os

# %%
# seed 고정
os.environ['PYTHONHASHSEED'] = str(42)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

tf.random.set_seed(42)
np.random.seed(42)
rn.seed(42)

# %%
train_dir = './data/train'
label_dir = './data/data_y_train.csv'
test_dir = './data/test'
test_label_dir = './data/data_y_test.csv'
checkpoint_filepath = './save/cnn_gru_best.hdf5'

BATCH_SIZE = 64
valid_ratio = 4
select_fold = 0
train_patience = 30

train_loader = Workout_dataset(
    train_dir, label_dir, mode='Train',
    fold=select_fold, batch_size=BATCH_SIZE, shuffle=True, 
    augment=True, rot_prob=0.5, perm_prob=0.2)

valid_loader = Workout_dataset(
    train_dir, label_dir, mode='Valid',
    fold=select_fold, batch_size=BATCH_SIZE//valid_ratio, shuffle=True)
    #augment=True, rot_prob=0.3, perm_prob=0.1)

test_loader = Workout_dataset(
    test_dir, test_label_dir, mode='Test',
    batch_size=625, shuffle=False)

# %%
model = make_CNN_RNN_model(
    lr = 0.001,
    leakyrelu_alpha = 0.1, # #0.2#
    input_kernels = 20, # #10#, ##20##
    input_kernel_width = 3, # #3#, 5
    res_kernels = 60,# 30, #60#, 120
    res_kernel_width = 3, # #3#, 5
    res_regularize_coeff=0.01, # #0.01#, 0.1, 0.2
    res_num = 3 # ##3##, #5#, 7, 9, 11, 13
    )

model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 600, 1)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 600, 3)]     0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600, 8)       0           input_4[0][0]
#                                                                  input_9[0][0]
#                                                                  input_5[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 600, 4)       0           input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600, 4)       0           input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600, 5)       0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 600, 5)       0           input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 600, 10)      0           input_1[0][0]
#                                                                  input_6[0][0]
#                                                                  input_12[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 300, 20)      1820        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 300, 20)      1820        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 300, 20)      2900        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 300, 20)      1460        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 300, 20)      1460        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 300, 20)      3620        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 300, 20)      3620        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 300, 20)      3620        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 300, 10)      3610        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 300, 20)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 300, 20)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 300, 20)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 300, 20)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 300, 20)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 300, 20)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 300, 20)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 300, 20)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 300, 10)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 300, 20)      80          leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 300, 20)      80          leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 300, 20)      80          leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 300, 20)      80          leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 300, 20)      80          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 300, 20)      80          leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 300, 20)      80          leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 300, 20)      80          leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 300, 10)      40          leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# gru (GRU)                       (None, 300, 40)      7440        batch_normalization[0][0]
# __________________________________________________________________________________________________
# gru_4 (GRU)                     (None, 300, 40)      7440        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    (None, 300, 40)      7440        batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# gru_16 (GRU)                    (None, 300, 40)      7440        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# gru_20 (GRU)                    (None, 300, 40)      7440        batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# gru_8 (GRU)                     (None, 300, 40)      7440        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 300, 40)      7440        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# gru_6 (GRU)                     (None, 300, 40)      7440        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# gru_10 (GRU)                    (None, 300, 20)      1920        batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 300, 40)      0           gru[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 300, 40)      0           gru_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 300, 40)      0           gru_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 300, 40)      0           gru_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 300, 40)      0           gru_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 300, 40)      0           gru_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 300, 40)      0           gru_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 300, 40)      0           gru_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 300, 20)      0           gru_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 300, 40)      160         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 300, 40)      160         leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 300, 40)      160         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 300, 40)      160         leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 300, 40)      160         leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 300, 40)      160         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300, 40)      160         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 300, 40)      160         leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 300, 20)      80          leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 120)     14520       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 120)     14520       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150, 120)     14520       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150, 120)     14520       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150, 120)     14520       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150, 120)     14520       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150, 120)     28920       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150, 120)     28920       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150, 60)      7260        batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 150, 120)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 150, 120)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 150, 120)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 150, 120)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 150, 120)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 150, 120)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 150, 120)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 150, 120)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 150, 60)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 150, 120)     480         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 150, 120)     480         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 150, 120)     480         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 150, 120)     480         leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 150, 120)     480         leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 150, 120)     480         leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 150, 120)     480         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 150, 120)     480         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 150, 60)      240         leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 150, 120)     87120       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# gru_5 (GRU)                     (None, 150, 120)     87120       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 150, 120)     87120       batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# gru_17 (GRU)                    (None, 150, 120)     87120       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 150, 120)     87120       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# gru_9 (GRU)                     (None, 150, 120)     87120       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 150, 120)     87120       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# gru_7 (GRU)                     (None, 150, 120)     87120       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    (None, 150, 60)      21960       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 150, 120)     0           gru_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 150, 120)     0           gru_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 150, 120)     0           gru_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 150, 120)     0           gru_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 150, 120)     0           gru_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 150, 120)     0           gru_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 150, 120)     0           gru_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 150, 120)     0           gru_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 150, 60)      0           gru_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 120)     480         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 150, 120)     480         leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 150, 120)     480         leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 150, 120)     480         leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 150, 120)     480         leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 150, 120)     480         leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 150, 120)     480         leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 150, 120)     480         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 150, 60)      240         leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 150, 1020)    0           batch_normalization_3[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_27[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 150, 60)      240         conv1d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 150, 120)     480         conv1d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 150, 60)      240         conv1d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150, 60)      550860      concatenate_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 60)      0           leaky_re_lu_50[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 150, 60)      32460       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 150, 60)      240         conv1d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 150, 120)     480         conv1d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 150, 60)      240         conv1d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150, 60)      0           leaky_re_lu_53[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 150, 60)      32460       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 150, 60)      240         conv1d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 150, 120)     21720       leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 150, 120)     480         conv1d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 150, 120)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 150, 60)      21660       leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 150, 60)      240         conv1d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 150, 60)      0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150, 60)      0           leaky_re_lu_56[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 150, 60)      240         add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 60)           0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 61)           3721        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 2,270,331
# Trainable params: 2,263,671
# Non-trainable params: 6,660
# __________________________________________________________________________________________________

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(patience = 5,verbose = 1,factor = 0.5) 

save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
    save_weights_only=True, mode='auto', save_freq='epoch', options=None)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',min_delta=0.0001,
    patience=train_patience,verbose=1)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=2000,
    callbacks=[save_best,early_stop,lr_scheduler])
    #class_weight=class_weight_dict(bias=0))
# Out:
# Epoch 1/2000
# 34/34 [==============================] - 51s 490ms/step - loss: 15.1540 - accuracy: 0.4233 - val_loss: 11.7710 - val_accuracy: 0.4453
#
# Epoch 00001: val_loss improved from inf to 11.77103, saving model to ./save/cnn_gru_best.hdf5
# Epoch 2/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 8.4628 - accuracy: 0.5625 - val_loss: 7.7305 - val_accuracy: 0.4492
#
# Epoch 00002: val_loss improved from 11.77103 to 7.73047, saving model to ./save/cnn_gru_best.hdf5
# Epoch 3/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 4.9434 - accuracy: 0.6650 - val_loss: 5.8763 - val_accuracy: 0.4336
#
# Epoch 00003: val_loss improved from 7.73047 to 5.87629, saving model to ./save/cnn_gru_best.hdf5
# Epoch 4/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 3.3348 - accuracy: 0.6682 - val_loss: 5.1042 - val_accuracy: 0.4492
#
# Epoch 00004: val_loss improved from 5.87629 to 5.10422, saving model to ./save/cnn_gru_best.hdf5
# Epoch 5/2000
# 34/34 [==============================] - 11s 320ms/step - loss: 2.3909 - accuracy: 0.6944 - val_loss: 4.8379 - val_accuracy: 0.4492
#
# Epoch 00005: val_loss improved from 5.10422 to 4.83785, saving model to ./save/cnn_gru_best.hdf5
# Epoch 6/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 1.8751 - accuracy: 0.7086 - val_loss: 5.0556 - val_accuracy: 0.0469
#
# Epoch 00006: val_loss did not improve from 4.83785
# Epoch 7/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 1.5247 - accuracy: 0.7298 - val_loss: 5.0147 - val_accuracy: 0.1680
#
# Epoch 00007: val_loss did not improve from 4.83785
# Epoch 8/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 1.2889 - accuracy: 0.7555 - val_loss: 5.2789 - val_accuracy: 0.2422
#
# Epoch 00008: val_loss did not improve from 4.83785
# Epoch 9/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 1.1641 - accuracy: 0.7739 - val_loss: 5.4098 - val_accuracy: 0.2500
#
# Epoch 00009: val_loss did not improve from 4.83785
# Epoch 10/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 1.2100 - accuracy: 0.7578 - val_loss: 5.4481 - val_accuracy: 0.2500
#
# Epoch 00010: val_loss did not improve from 4.83785
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 1.0630 - accuracy: 0.7886 - val_loss: 5.0624 - val_accuracy: 0.2539
#
# Epoch 00011: val_loss did not improve from 4.83785
# Epoch 12/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.9476 - accuracy: 0.8047 - val_loss: 4.2094 - val_accuracy: 0.3203
#
# Epoch 00012: val_loss improved from 4.83785 to 4.20942, saving model to ./save/cnn_gru_best.hdf5
# Epoch 13/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.8469 - accuracy: 0.8272 - val_loss: 4.0309 - val_accuracy: 0.3984
#
# Epoch 00013: val_loss improved from 4.20942 to 4.03094, saving model to ./save/cnn_gru_best.hdf5
# Epoch 14/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.8038 - accuracy: 0.8327 - val_loss: 3.4561 - val_accuracy: 0.4492
#
# Epoch 00014: val_loss improved from 4.03094 to 3.45614, saving model to ./save/cnn_gru_best.hdf5
# Epoch 15/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.8620 - accuracy: 0.8148 - val_loss: 5.0491 - val_accuracy: 0.1523
#
# Epoch 00015: val_loss did not improve from 3.45614
# Epoch 16/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.8722 - accuracy: 0.8047 - val_loss: 2.6947 - val_accuracy: 0.5156
#
# Epoch 00016: val_loss improved from 3.45614 to 2.69471, saving model to ./save/cnn_gru_best.hdf5
# Epoch 17/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.8819 - accuracy: 0.8088 - val_loss: 2.2501 - val_accuracy: 0.5742
#
# Epoch 00017: val_loss improved from 2.69471 to 2.25011, saving model to ./save/cnn_gru_best.hdf5
# Epoch 18/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.7548 - accuracy: 0.8410 - val_loss: 1.9213 - val_accuracy: 0.6562
#
# Epoch 00018: val_loss improved from 2.25011 to 1.92134, saving model to ./save/cnn_gru_best.hdf5
# Epoch 19/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.6925 - accuracy: 0.8562 - val_loss: 1.7244 - val_accuracy: 0.6523
#
# Epoch 00019: val_loss improved from 1.92134 to 1.72439, saving model to ./save/cnn_gru_best.hdf5
# Epoch 20/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.9065 - accuracy: 0.7973 - val_loss: 1.4485 - val_accuracy: 0.6914
#
# Epoch 00020: val_loss improved from 1.72439 to 1.44849, saving model to ./save/cnn_gru_best.hdf5
# Epoch 21/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.8006 - accuracy: 0.8244 - val_loss: 1.2623 - val_accuracy: 0.7109
#
# Epoch 00021: val_loss improved from 1.44849 to 1.26229, saving model to ./save/cnn_gru_best.hdf5
# Epoch 22/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.7435 - accuracy: 0.8415 - val_loss: 1.1794 - val_accuracy: 0.7539
#
# Epoch 00022: val_loss improved from 1.26229 to 1.17941, saving model to ./save/cnn_gru_best.hdf5
# Epoch 23/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.7421 - accuracy: 0.8405 - val_loss: 1.2027 - val_accuracy: 0.7266
#
# Epoch 00023: val_loss did not improve from 1.17941
# Epoch 24/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.7184 - accuracy: 0.8520 - val_loss: 1.0594 - val_accuracy: 0.7656
#
# Epoch 00024: val_loss improved from 1.17941 to 1.05935, saving model to ./save/cnn_gru_best.hdf5
# Epoch 25/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.6728 - accuracy: 0.8557 - val_loss: 1.2151 - val_accuracy: 0.7148
#
# Epoch 00025: val_loss did not improve from 1.05935
# Epoch 26/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.6467 - accuracy: 0.8704 - val_loss: 1.0089 - val_accuracy: 0.7852
#
# Epoch 00026: val_loss improved from 1.05935 to 1.00895, saving model to ./save/cnn_gru_best.hdf5
# Epoch 27/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.6861 - accuracy: 0.8575 - val_loss: 1.0790 - val_accuracy: 0.7695
#
# Epoch 00027: val_loss did not improve from 1.00895
# Epoch 28/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.7464 - accuracy: 0.8369 - val_loss: 1.0298 - val_accuracy: 0.7539
#
# Epoch 00028: val_loss did not improve from 1.00895
# Epoch 29/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.7409 - accuracy: 0.8378 - val_loss: 1.0774 - val_accuracy: 0.7734
#
# Epoch 00029: val_loss did not improve from 1.00895
# Epoch 30/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.6273 - accuracy: 0.8801 - val_loss: 1.0278 - val_accuracy: 0.7695
#
# Epoch 00030: val_loss did not improve from 1.00895
# Epoch 31/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.6015 - accuracy: 0.8778 - val_loss: 1.0827 - val_accuracy: 0.7539
#
# Epoch 00031: val_loss did not improve from 1.00895
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 32/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.5502 - accuracy: 0.8805 - val_loss: 1.0720 - val_accuracy: 0.7461
#
# Epoch 00032: val_loss did not improve from 1.00895
# Epoch 33/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.5158 - accuracy: 0.8957 - val_loss: 0.9964 - val_accuracy: 0.7578
#
# Epoch 00033: val_loss improved from 1.00895 to 0.99636, saving model to ./save/cnn_gru_best.hdf5
# Epoch 34/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.4914 - accuracy: 0.8971 - val_loss: 0.9103 - val_accuracy: 0.7969
#
# Epoch 00034: val_loss improved from 0.99636 to 0.91028, saving model to ./save/cnn_gru_best.hdf5
# Epoch 35/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.5287 - accuracy: 0.8938 - val_loss: 0.8870 - val_accuracy: 0.8086
#
# Epoch 00035: val_loss improved from 0.91028 to 0.88700, saving model to ./save/cnn_gru_best.hdf5
# Epoch 36/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.5469 - accuracy: 0.8842 - val_loss: 0.9196 - val_accuracy: 0.7852
#
# Epoch 00036: val_loss did not improve from 0.88700
# Epoch 37/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.5027 - accuracy: 0.8911 - val_loss: 0.9306 - val_accuracy: 0.7734
#
# Epoch 00037: val_loss did not improve from 0.88700
# Epoch 38/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.4476 - accuracy: 0.9122 - val_loss: 0.8774 - val_accuracy: 0.7969
#
# Epoch 00038: val_loss improved from 0.88700 to 0.87743, saving model to ./save/cnn_gru_best.hdf5
# Epoch 39/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.4784 - accuracy: 0.9026 - val_loss: 0.8949 - val_accuracy: 0.8086
#
# Epoch 00039: val_loss did not improve from 0.87743
# Epoch 40/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.4925 - accuracy: 0.8948 - val_loss: 0.9145 - val_accuracy: 0.7969
#
# Epoch 00040: val_loss did not improve from 0.87743
# Epoch 41/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.4750 - accuracy: 0.9049 - val_loss: 0.9523 - val_accuracy: 0.7852
#
# Epoch 00041: val_loss did not improve from 0.87743
# Epoch 42/2000
# 34/34 [==============================] - 11s 310ms/step - loss: 0.4993 - accuracy: 0.8879 - val_loss: 1.0591 - val_accuracy: 0.7734
#
# Epoch 00042: val_loss did not improve from 0.87743
# Epoch 43/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.4926 - accuracy: 0.9030 - val_loss: 1.0672 - val_accuracy: 0.7617
#
# Epoch 00043: val_loss did not improve from 0.87743
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 44/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3325 - accuracy: 0.9416 - val_loss: 0.9077 - val_accuracy: 0.8008
#
# Epoch 00044: val_loss did not improve from 0.87743
# Epoch 45/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.4423 - accuracy: 0.9040 - val_loss: 0.8465 - val_accuracy: 0.8125
#
# Epoch 00045: val_loss improved from 0.87743 to 0.84649, saving model to ./save/cnn_gru_best.hdf5
# Epoch 46/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2842 - accuracy: 0.9540 - val_loss: 0.8162 - val_accuracy: 0.8203
#
# Epoch 00046: val_loss improved from 0.84649 to 0.81622, saving model to ./save/cnn_gru_best.hdf5
# Epoch 47/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.3698 - accuracy: 0.9223 - val_loss: 0.8579 - val_accuracy: 0.8047
#
# Epoch 00047: val_loss did not improve from 0.81622
# Epoch 48/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3252 - accuracy: 0.9389 - val_loss: 0.7820 - val_accuracy: 0.8125
#
# Epoch 00048: val_loss improved from 0.81622 to 0.78202, saving model to ./save/cnn_gru_best.hdf5
# Epoch 49/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.5130 - accuracy: 0.8787 - val_loss: 0.7978 - val_accuracy: 0.8203
#
# Epoch 00049: val_loss did not improve from 0.78202
# Epoch 50/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.4316 - accuracy: 0.9122 - val_loss: 0.8193 - val_accuracy: 0.8008
#
# Epoch 00050: val_loss did not improve from 0.78202
# Epoch 51/2000
# 34/34 [==============================] - 11s 311ms/step - loss: 0.3236 - accuracy: 0.9384 - val_loss: 0.7703 - val_accuracy: 0.8047
#
# Epoch 00051: val_loss improved from 0.78202 to 0.77030, saving model to ./save/cnn_gru_best.hdf5
# Epoch 52/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.3372 - accuracy: 0.9375 - val_loss: 0.8369 - val_accuracy: 0.8203
#
# Epoch 00052: val_loss did not improve from 0.77030
# Epoch 53/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.3296 - accuracy: 0.9352 - val_loss: 0.8030 - val_accuracy: 0.8320
#
# Epoch 00053: val_loss did not improve from 0.77030
# Epoch 54/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.3826 - accuracy: 0.9196 - val_loss: 0.8142 - val_accuracy: 0.8281
#
# Epoch 00054: val_loss did not improve from 0.77030
# Epoch 55/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.3679 - accuracy: 0.9219 - val_loss: 0.8873 - val_accuracy: 0.7969
#
# Epoch 00055: val_loss did not improve from 0.77030
# Epoch 56/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.3451 - accuracy: 0.9301 - val_loss: 0.8081 - val_accuracy: 0.8203
#
# Epoch 00056: val_loss did not improve from 0.77030
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 57/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.2890 - accuracy: 0.9467 - val_loss: 0.8466 - val_accuracy: 0.8203
#
# Epoch 00057: val_loss did not improve from 0.77030
# Epoch 58/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.3378 - accuracy: 0.9288 - val_loss: 0.8192 - val_accuracy: 0.8203
#
# Epoch 00058: val_loss did not improve from 0.77030
# Epoch 59/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2850 - accuracy: 0.9504 - val_loss: 0.7960 - val_accuracy: 0.8281
#
# Epoch 00059: val_loss did not improve from 0.77030
# Epoch 60/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3052 - accuracy: 0.9380 - val_loss: 0.7908 - val_accuracy: 0.8164
#
# Epoch 00060: val_loss did not improve from 0.77030
# Epoch 61/2000
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3175 - accuracy: 0.9352 - val_loss: 0.7865 - val_accuracy: 0.8125
#
# Epoch 00061: val_loss did not improve from 0.77030
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 62/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.3098 - accuracy: 0.9380 - val_loss: 0.8239 - val_accuracy: 0.8203
#
# Epoch 00062: val_loss did not improve from 0.77030
# Epoch 63/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2659 - accuracy: 0.9550 - val_loss: 0.8394 - val_accuracy: 0.8203
#
# Epoch 00063: val_loss did not improve from 0.77030
# Epoch 64/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2917 - accuracy: 0.9485 - val_loss: 0.7760 - val_accuracy: 0.8320
#
# Epoch 00064: val_loss did not improve from 0.77030
# Epoch 65/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2572 - accuracy: 0.9527 - val_loss: 0.7956 - val_accuracy: 0.8242
#
# Epoch 00065: val_loss did not improve from 0.77030
# Epoch 66/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2754 - accuracy: 0.9453 - val_loss: 0.8357 - val_accuracy: 0.8047
#
# Epoch 00066: val_loss did not improve from 0.77030
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 67/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2172 - accuracy: 0.9669 - val_loss: 0.7872 - val_accuracy: 0.8242
#
# Epoch 00067: val_loss did not improve from 0.77030
# Epoch 68/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2315 - accuracy: 0.9596 - val_loss: 0.8212 - val_accuracy: 0.8125
#
# Epoch 00068: val_loss did not improve from 0.77030
# Epoch 69/2000
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2462 - accuracy: 0.9550 - val_loss: 0.7982 - val_accuracy: 0.8242
#
# Epoch 00069: val_loss did not improve from 0.77030
# Epoch 70/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2891 - accuracy: 0.9421 - val_loss: 0.8289 - val_accuracy: 0.8086
#
# Epoch 00070: val_loss did not improve from 0.77030
# Epoch 71/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2682 - accuracy: 0.9494 - val_loss: 0.8067 - val_accuracy: 0.8203
#
# Epoch 00071: val_loss did not improve from 0.77030
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 72/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2423 - accuracy: 0.9504 - val_loss: 0.8120 - val_accuracy: 0.8281
#
# Epoch 00072: val_loss did not improve from 0.77030
# Epoch 73/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2726 - accuracy: 0.9458 - val_loss: 0.8252 - val_accuracy: 0.8281
#
# Epoch 00073: val_loss did not improve from 0.77030
# Epoch 74/2000
# 34/34 [==============================] - 12s 336ms/step - loss: 0.2685 - accuracy: 0.9476 - val_loss: 0.8115 - val_accuracy: 0.8281
#
# Epoch 00074: val_loss did not improve from 0.77030
# Epoch 75/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2132 - accuracy: 0.9710 - val_loss: 0.7914 - val_accuracy: 0.8320
#
# Epoch 00075: val_loss did not improve from 0.77030
# Epoch 76/2000
# 34/34 [==============================] - 12s 340ms/step - loss: 0.2487 - accuracy: 0.9577 - val_loss: 0.7669 - val_accuracy: 0.8281
#
# Epoch 00076: val_loss improved from 0.77030 to 0.76695, saving model to ./save/cnn_gru_best.hdf5
# Epoch 77/2000
# 34/34 [==============================] - 11s 332ms/step - loss: 0.2231 - accuracy: 0.9600 - val_loss: 0.7978 - val_accuracy: 0.8242
#
# Epoch 00077: val_loss did not improve from 0.76695
# Epoch 78/2000
# 34/34 [==============================] - 11s 336ms/step - loss: 0.2281 - accuracy: 0.9591 - val_loss: 0.7838 - val_accuracy: 0.8320
#
# Epoch 00078: val_loss did not improve from 0.76695
# Epoch 79/2000
# 34/34 [==============================] - 11s 334ms/step - loss: 0.3149 - accuracy: 0.9370 - val_loss: 0.8172 - val_accuracy: 0.8203
#
# Epoch 00079: val_loss did not improve from 0.76695
# Epoch 80/2000
# 34/34 [==============================] - 11s 324ms/step - loss: 0.2576 - accuracy: 0.9476 - val_loss: 0.8008 - val_accuracy: 0.8320
#
# Epoch 00080: val_loss did not improve from 0.76695
# Epoch 81/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2534 - accuracy: 0.9527 - val_loss: 0.7739 - val_accuracy: 0.8320
#
# Epoch 00081: val_loss did not improve from 0.76695
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 82/2000
# 34/34 [==============================] - 12s 349ms/step - loss: 0.2285 - accuracy: 0.9609 - val_loss: 0.7470 - val_accuracy: 0.8320
#
# Epoch 00082: val_loss improved from 0.76695 to 0.74700, saving model to ./save/cnn_gru_best.hdf5
# Epoch 83/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.1879 - accuracy: 0.9752 - val_loss: 0.7658 - val_accuracy: 0.8359
#
# Epoch 00083: val_loss did not improve from 0.74700
# Epoch 84/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2042 - accuracy: 0.9692 - val_loss: 0.8018 - val_accuracy: 0.8281
#
# Epoch 00084: val_loss did not improve from 0.74700
# Epoch 85/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.1875 - accuracy: 0.9729 - val_loss: 0.7869 - val_accuracy: 0.8281
#
# Epoch 00085: val_loss did not improve from 0.74700
# Epoch 86/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.1725 - accuracy: 0.9798 - val_loss: 0.7863 - val_accuracy: 0.8242
#
# Epoch 00086: val_loss did not improve from 0.74700
# Epoch 87/2000
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2830 - accuracy: 0.9426 - val_loss: 0.8039 - val_accuracy: 0.8359
#
# Epoch 00087: val_loss did not improve from 0.74700
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 88/2000
# 34/34 [==============================] - 13s 367ms/step - loss: 0.2577 - accuracy: 0.9508 - val_loss: 0.8112 - val_accuracy: 0.8320
#
# Epoch 00088: val_loss did not improve from 0.74700
# Epoch 89/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.2259 - accuracy: 0.9568 - val_loss: 0.7762 - val_accuracy: 0.8398
#
# Epoch 00089: val_loss did not improve from 0.74700
# Epoch 90/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2315 - accuracy: 0.9600 - val_loss: 0.7774 - val_accuracy: 0.8359
#
# Epoch 00090: val_loss did not improve from 0.74700
# Epoch 91/2000
# 34/34 [==============================] - 11s 316ms/step - loss: 0.2422 - accuracy: 0.9550 - val_loss: 0.7732 - val_accuracy: 0.8320
#
# Epoch 00091: val_loss did not improve from 0.74700
# Epoch 92/2000
# 34/34 [==============================] - 11s 326ms/step - loss: 0.2172 - accuracy: 0.9669 - val_loss: 0.7766 - val_accuracy: 0.8359
#
# Epoch 00092: val_loss did not improve from 0.74700
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 93/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2612 - accuracy: 0.9490 - val_loss: 0.7767 - val_accuracy: 0.8359
#
# Epoch 00093: val_loss did not improve from 0.74700
# Epoch 94/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.1947 - accuracy: 0.9665 - val_loss: 0.7890 - val_accuracy: 0.8320
#
# Epoch 00094: val_loss did not improve from 0.74700
# Epoch 95/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2223 - accuracy: 0.9628 - val_loss: 0.7993 - val_accuracy: 0.8281
#
# Epoch 00095: val_loss did not improve from 0.74700
# Epoch 96/2000
# 34/34 [==============================] - 11s 319ms/step - loss: 0.2509 - accuracy: 0.9536 - val_loss: 0.7472 - val_accuracy: 0.8359
#
# Epoch 00096: val_loss did not improve from 0.74700
# Epoch 97/2000
# 34/34 [==============================] - 11s 323ms/step - loss: 0.3023 - accuracy: 0.9407 - val_loss: 0.8126 - val_accuracy: 0.8164
#
# Epoch 00097: val_loss did not improve from 0.74700
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 98/2000
# 34/34 [==============================] - 14s 414ms/step - loss: 0.2220 - accuracy: 0.9660 - val_loss: 0.7416 - val_accuracy: 0.8359
#
# Epoch 00098: val_loss improved from 0.74700 to 0.74161, saving model to ./save/cnn_gru_best.hdf5
# Epoch 99/2000
# 34/34 [==============================] - 11s 326ms/step - loss: 0.2699 - accuracy: 0.9472 - val_loss: 0.7616 - val_accuracy: 0.8438
#
# Epoch 00099: val_loss did not improve from 0.74161
# Epoch 100/2000
# 34/34 [==============================] - 11s 329ms/step - loss: 0.2057 - accuracy: 0.9678 - val_loss: 0.7498 - val_accuracy: 0.8359
#
# Epoch 00100: val_loss did not improve from 0.74161
# Epoch 101/2000
# 34/34 [==============================] - 11s 314ms/step - loss: 0.2260 - accuracy: 0.9550 - val_loss: 0.8103 - val_accuracy: 0.8203
#
# Epoch 00101: val_loss did not improve from 0.74161
# Epoch 102/2000
# 34/34 [==============================] - 12s 355ms/step - loss: 0.2440 - accuracy: 0.9573 - val_loss: 0.7639 - val_accuracy: 0.8242
#
# Epoch 00102: val_loss did not improve from 0.74161
# Epoch 103/2000
# 34/34 [==============================] - 12s 367ms/step - loss: 0.2701 - accuracy: 0.9513 - val_loss: 0.7819 - val_accuracy: 0.8320
#
# Epoch 00103: val_loss did not improve from 0.74161
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 104/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.2091 - accuracy: 0.9683 - val_loss: 0.7821 - val_accuracy: 0.8320
#
# Epoch 00104: val_loss did not improve from 0.74161
# Epoch 105/2000
# 34/34 [==============================] - 11s 330ms/step - loss: 0.2469 - accuracy: 0.9559 - val_loss: 0.7783 - val_accuracy: 0.8320
#
# Epoch 00105: val_loss did not improve from 0.74161
# Epoch 106/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.2288 - accuracy: 0.9609 - val_loss: 0.6921 - val_accuracy: 0.8438
#
# Epoch 00106: val_loss improved from 0.74161 to 0.69207, saving model to ./save/cnn_gru_best.hdf5
# Epoch 107/2000
# 34/34 [==============================] - 11s 322ms/step - loss: 0.2090 - accuracy: 0.9665 - val_loss: 0.7182 - val_accuracy: 0.8359
#
# Epoch 00107: val_loss did not improve from 0.69207
# Epoch 108/2000
# 34/34 [==============================] - 12s 358ms/step - loss: 0.2291 - accuracy: 0.9614 - val_loss: 0.6926 - val_accuracy: 0.8398
#
# Epoch 00108: val_loss did not improve from 0.69207
# Epoch 109/2000
# 34/34 [==============================] - 12s 347ms/step - loss: 0.2512 - accuracy: 0.9550 - val_loss: 0.7259 - val_accuracy: 0.8398
#
# Epoch 00109: val_loss did not improve from 0.69207
# Epoch 110/2000
# 34/34 [==============================] - 11s 317ms/step - loss: 0.2249 - accuracy: 0.9605 - val_loss: 0.7629 - val_accuracy: 0.8320
#
# Epoch 00110: val_loss did not improve from 0.69207
# Epoch 111/2000
# 34/34 [==============================] - 12s 337ms/step - loss: 0.2930 - accuracy: 0.9407 - val_loss: 0.7857 - val_accuracy: 0.8281
#
# Epoch 00111: val_loss did not improve from 0.69207
#
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 112/2000
# 34/34 [==============================] - 13s 376ms/step - loss: 0.2299 - accuracy: 0.9596 - val_loss: 0.8005 - val_accuracy: 0.8320
#
# Epoch 00112: val_loss did not improve from 0.69207
# Epoch 113/2000
# 34/34 [==============================] - 12s 352ms/step - loss: 0.2391 - accuracy: 0.9540 - val_loss: 0.7617 - val_accuracy: 0.8398
#
# Epoch 00113: val_loss did not improve from 0.69207
# Epoch 114/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2529 - accuracy: 0.9472 - val_loss: 0.8046 - val_accuracy: 0.8281
#
# Epoch 00114: val_loss did not improve from 0.69207
# Epoch 115/2000
# 34/34 [==============================] - 11s 338ms/step - loss: 0.2229 - accuracy: 0.9619 - val_loss: 0.7556 - val_accuracy: 0.8320
#
# Epoch 00115: val_loss did not improve from 0.69207
# Epoch 116/2000
# 34/34 [==============================] - 11s 335ms/step - loss: 0.2236 - accuracy: 0.9596 - val_loss: 0.7821 - val_accuracy: 0.8398
#
# Epoch 00116: val_loss did not improve from 0.69207
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 117/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.2478 - accuracy: 0.9513 - val_loss: 0.7837 - val_accuracy: 0.8359
#
# Epoch 00117: val_loss did not improve from 0.69207
# Epoch 118/2000
# 34/34 [==============================] - 11s 334ms/step - loss: 0.2178 - accuracy: 0.9655 - val_loss: 0.7757 - val_accuracy: 0.8359
#
# Epoch 00118: val_loss did not improve from 0.69207
# Epoch 119/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2410 - accuracy: 0.9531 - val_loss: 0.8064 - val_accuracy: 0.8359
#
# Epoch 00119: val_loss did not improve from 0.69207
# Epoch 120/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2767 - accuracy: 0.9430 - val_loss: 0.8145 - val_accuracy: 0.8203
#
# Epoch 00120: val_loss did not improve from 0.69207
# Epoch 121/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2682 - accuracy: 0.9504 - val_loss: 0.7815 - val_accuracy: 0.8320
#
# Epoch 00121: val_loss did not improve from 0.69207
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 122/2000
# 34/34 [==============================] - 11s 318ms/step - loss: 0.2018 - accuracy: 0.9692 - val_loss: 0.7423 - val_accuracy: 0.8398
#
# Epoch 00122: val_loss did not improve from 0.69207
# Epoch 123/2000
# 34/34 [==============================] - 11s 321ms/step - loss: 0.2482 - accuracy: 0.9522 - val_loss: 0.7749 - val_accuracy: 0.8359
#
# Epoch 00123: val_loss did not improve from 0.69207
# Epoch 124/2000
# 34/34 [==============================] - 12s 344ms/step - loss: 0.2390 - accuracy: 0.9550 - val_loss: 0.7928 - val_accuracy: 0.8359
#
# Epoch 00124: val_loss did not improve from 0.69207
# Epoch 125/2000
# 34/34 [==============================] - 12s 354ms/step - loss: 0.2468 - accuracy: 0.9517 - val_loss: 0.7995 - val_accuracy: 0.8359
#
# Epoch 00125: val_loss did not improve from 0.69207
# Epoch 126/2000
# 34/34 [==============================] - 13s 375ms/step - loss: 0.2363 - accuracy: 0.9545 - val_loss: 0.8048 - val_accuracy: 0.8281
#
# Epoch 00126: val_loss did not improve from 0.69207
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 127/2000
# 34/34 [==============================] - 11s 328ms/step - loss: 0.2843 - accuracy: 0.9421 - val_loss: 0.8022 - val_accuracy: 0.8281
#
# Epoch 00127: val_loss did not improve from 0.69207
# Epoch 128/2000
# 34/34 [==============================] - 12s 346ms/step - loss: 0.2039 - accuracy: 0.9715 - val_loss: 0.7483 - val_accuracy: 0.8398
#
# Epoch 00128: val_loss did not improve from 0.69207
# Epoch 129/2000
# 34/34 [==============================] - 11s 329ms/step - loss: 0.2377 - accuracy: 0.9591 - val_loss: 0.8123 - val_accuracy: 0.8242
#
# Epoch 00129: val_loss did not improve from 0.69207
# Epoch 130/2000
# 34/34 [==============================] - 12s 353ms/step - loss: 0.1868 - accuracy: 0.9697 - val_loss: 0.8089 - val_accuracy: 0.8281
#
# Epoch 00130: val_loss did not improve from 0.69207
# Epoch 131/2000
# 34/34 [==============================] - 13s 364ms/step - loss: 0.2495 - accuracy: 0.9517 - val_loss: 0.7943 - val_accuracy: 0.8359
#
# Epoch 00131: val_loss did not improve from 0.69207
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 132/2000
# 34/34 [==============================] - 11s 329ms/step - loss: 0.2456 - accuracy: 0.9536 - val_loss: 0.7786 - val_accuracy: 0.8320
#
# Epoch 00132: val_loss did not improve from 0.69207
# Epoch 133/2000
# 34/34 [==============================] - 11s 325ms/step - loss: 0.2486 - accuracy: 0.9508 - val_loss: 0.7946 - val_accuracy: 0.8320
#
# Epoch 00133: val_loss did not improve from 0.69207
# Epoch 134/2000
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2445 - accuracy: 0.9582 - val_loss: 0.7827 - val_accuracy: 0.8320
#
# Epoch 00134: val_loss did not improve from 0.69207
# Epoch 135/2000
# 34/34 [==============================] - 13s 392ms/step - loss: 0.2450 - accuracy: 0.9554 - val_loss: 0.7863 - val_accuracy: 0.8359
#
# Epoch 00135: val_loss did not improve from 0.69207
# Epoch 136/2000
# 34/34 [==============================] - 13s 389ms/step - loss: 0.2545 - accuracy: 0.9554 - val_loss: 0.7968 - val_accuracy: 0.8320
#
# Epoch 00136: val_loss did not improve from 0.69207
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 00136: early stopping

# %%
model.load_weights(checkpoint_filepath)
model.evaluate(test_loader,verbose=1)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6265 - accuracy: 0.8608
# [0.6264825463294983, 0.86080002784729]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
